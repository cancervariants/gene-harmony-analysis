# %%
import pandas as pd
import json
import plotly.express as px
import plotly
import ast
from collections import Counter
import numpy as np

# %% [markdown]
# ## Analysis of Gene Terms in DGIdb from 2023
# Reanalysis of the log data obtained from DGIdb user search patterns in Q1/Q2 2023. This is intended to extract the gene terms most often searched from each search type and give them over to Anastasia who will subsequently determine the frequency of searches that have gene collisions.

# %% [markdown]
# ### Load Data

# %%
df = pd.read_excel("../input/log_data.xlsx")
df[0:5]
# Out:
#    Unnamed: 0                        time request_num  \
# 0           0  2023-05-03T11:45:03.737594      #95027
# 1           0  2023-05-03T11:45:06.699989      #95027
# 2           0  2023-05-03T11:45:10.303598      #94988
# 3           0  2023-05-03T11:45:12.311825      #94988
# 4           0  2023-05-03T11:45:15.174727      #94988
#
#                                    uuid method              path format  \
# 0  34b514ef-ea79-498b-83a8-ec5abff01760    GET  /drug_names.json   json
# 1  47c0fa4a-7068-42ce-91d8-525f987568ff    GET      /genes/ICAM3   html
# 2  1fc0e9d3-f6a2-4b00-baba-0fd9ce9b5405    GET        /genes/HTT   html
# 3  205878ef-9bea-47c4-9cff-222a93839525    GET  /gene_names.json   json
# 4  15d9ec98-d825-49ef-ad58-0fd398ea6839    GET  /drug_names.json   json
#
#         controller action  status  duration      view      db  \
# 0  DrugsController  names     200     58.31      0.14    0.00
# 1  GenesController   show     200    895.10    755.20  129.73
# 2  GenesController   show     200  32723.75  31973.05  739.82
# 3  GenesController  names     200    151.56      0.12    0.00
# 4  DrugsController  names     200     54.78      0.10    0.00
#
#               params location error
# 0                 {}      NaN   NaN
# 1  {'name': 'ICAM3'}      NaN   NaN
# 2    {'name': 'HTT'}      NaN   NaN
# 3                 {}      NaN   NaN
# 4                 {}      NaN   NaN

# %% [markdown]
# ### Clean Data

# %% [markdown]
# We are interested in the api/v2/interactions queries

# %%
df["path"].value_counts()[0:10]
# Out:
# path
# /api/v2/interactions.json         25280
# /                                 12654
# /gene_names.json                   7051
# /interaction_search_results        5748
# /search_interactions               5241
# /api/v2/interaction_types.json     3202
# /drug_names.json                   2070
# /search_categories                 1523
# /downloads                         1064
# /categories_search_results         1048
# Name: count, dtype: int64

# %%
data = (
    df[df["path"] == "/api/v2/interactions.json"]
    .drop(labels="Unnamed: 0", axis=1)
    .reset_index(drop=True)
)
data[0:5]
# Out:
#                          time request_num  \
# 0  2023-05-03T11:59:21.273789      #95027
# 1  2023-05-03T12:15:13.185862      #95027
# 2  2023-05-03T12:25:02.801847      #95027
# 3  2023-05-03T12:29:09.147971      #95027
# 4  2023-05-03T12:29:51.541701      #95027
#
#                                    uuid method                       path  \
# 0  5a1bd777-14c2-44b1-87b8-4bcec01433c4    GET  /api/v2/interactions.json
# 1  66a47e2f-c94d-451c-8cdb-c1a29617b3cb    GET  /api/v2/interactions.json
# 2  9f3932bb-5611-4317-ab44-fab33992e283    GET  /api/v2/interactions.json
# 3  3a24f3df-c114-4739-8bdc-f89203ec31a0    GET  /api/v2/interactions.json
# 4  e88c50f0-2b4f-4c7f-ab0d-075095bce6c2    GET  /api/v2/interactions.json
#
#   format            controller        action  status  duration    view     db  \
# 0   json  ServicesV2Controller  interactions     200     46.52    7.66  21.43
# 1   json  ServicesV2Controller  interactions     200    993.19  917.98  61.50
# 2   json  ServicesV2Controller  interactions     200     37.76    3.25  23.25
# 3   json  ServicesV2Controller  interactions     200     35.21    0.52  19.20
# 4   json  ServicesV2Controller  interactions     200     34.51    3.20  20.37
#
#                    params location error
# 0       {'genes': 'ATN1'}      NaN   NaN
# 1  {'drugs': 'Scriptaid'}      NaN   NaN
# 2      {'genes': 'GPR26'}      NaN   NaN
# 3  {'drugs': 'Isoprenol'}      NaN   NaN
# 4     {'genes': 'IL10RA'}      NaN   NaN

# %% [markdown]
# We want to pull out the genes from the params of the query data

# %%
def get_search_type(record):
    try:
        record = record.replace("'", '"')
        record = json.loads(record)
        keys = list(record.keys())
        if len(keys) > 0:
            return keys[0]
        else:
            return "KeyLength"
    except json.JSONDecodeError:
        return "JSONDecode"

# %%
data["params"][0]
test = data["params"][0].replace("'", '"')
test = json.loads(test)
list(test.keys())
# Out:
# ['genes']

# %%
data["type"] = None
data["type"] = data["params"].apply(get_search_type)

# %% [markdown]
# Distribution of Types of Interaction Query sent (drugs vs genes)

# %%
data["type"].value_counts()
# Out:
# type
# genes         23070
# drugs          1647
# KeyLength       543
# JSONDecode       20
# Name: count, dtype: int64

# %%
data = data[data["type"] == "genes"].reset_index(drop=True)
data[0:5]
# Out:
#                          time request_num  \
# 0  2023-05-03T11:59:21.273789      #95027
# 1  2023-05-03T12:25:02.801847      #95027
# 2  2023-05-03T12:29:51.541701      #95027
# 3  2023-05-03T12:29:57.144888      #95027
# 4  2023-05-03T12:30:01.291949      #95027
#
#                                    uuid method                       path  \
# 0  5a1bd777-14c2-44b1-87b8-4bcec01433c4    GET  /api/v2/interactions.json
# 1  9f3932bb-5611-4317-ab44-fab33992e283    GET  /api/v2/interactions.json
# 2  e88c50f0-2b4f-4c7f-ab0d-075095bce6c2    GET  /api/v2/interactions.json
# 3  26747924-e565-43ac-b36e-9d802d4ee5c8    GET  /api/v2/interactions.json
# 4  8c9d7628-ce57-4c3d-b74e-a7acd042cb6b    GET  /api/v2/interactions.json
#
#   format            controller        action  status  duration    view     db  \
# 0   json  ServicesV2Controller  interactions     200     46.52    7.66  21.43
# 1   json  ServicesV2Controller  interactions     200     37.76    3.25  23.25
# 2   json  ServicesV2Controller  interactions     200     34.51    3.20  20.37
# 3   json  ServicesV2Controller  interactions     200     33.73    3.04  20.15
# 4   json  ServicesV2Controller  interactions     200    189.23  115.09  61.95
#
#                 params location error   type
# 0    {'genes': 'ATN1'}      NaN   NaN  genes
# 1   {'genes': 'GPR26'}      NaN   NaN  genes
# 2  {'genes': 'IL10RA'}      NaN   NaN  genes
# 3  {'genes': 'VSTM2A'}      NaN   NaN  genes
# 4   {'genes': 'SH2B3'}      NaN   NaN  genes

# %%
def get_genes(record):
    try:
        record = record.replace("'", '"')
        record = json.loads(record)
        if record["genes"]:
            genes = record["genes"].split(",")
            return genes
        else:
            return "KeyLength"
    except:  
        pass

# %%
data["genes"] = None
data["genes"] = data["params"].apply(get_genes)
data[0:5]
# Out:
#                          time request_num  \
# 0  2023-05-03T11:59:21.273789      #95027
# 1  2023-05-03T12:25:02.801847      #95027
# 2  2023-05-03T12:29:51.541701      #95027
# 3  2023-05-03T12:29:57.144888      #95027
# 4  2023-05-03T12:30:01.291949      #95027
#
#                                    uuid method                       path  \
# 0  5a1bd777-14c2-44b1-87b8-4bcec01433c4    GET  /api/v2/interactions.json
# 1  9f3932bb-5611-4317-ab44-fab33992e283    GET  /api/v2/interactions.json
# 2  e88c50f0-2b4f-4c7f-ab0d-075095bce6c2    GET  /api/v2/interactions.json
# 3  26747924-e565-43ac-b36e-9d802d4ee5c8    GET  /api/v2/interactions.json
# 4  8c9d7628-ce57-4c3d-b74e-a7acd042cb6b    GET  /api/v2/interactions.json
#
#   format            controller        action  status  duration    view     db  \
# 0   json  ServicesV2Controller  interactions     200     46.52    7.66  21.43
# 1   json  ServicesV2Controller  interactions     200     37.76    3.25  23.25
# 2   json  ServicesV2Controller  interactions     200     34.51    3.20  20.37
# 3   json  ServicesV2Controller  interactions     200     33.73    3.04  20.15
# 4   json  ServicesV2Controller  interactions     200    189.23  115.09  61.95
#
#                 params location error   type     genes
# 0    {'genes': 'ATN1'}      NaN   NaN  genes    [ATN1]
# 1   {'genes': 'GPR26'}      NaN   NaN  genes   [GPR26]
# 2  {'genes': 'IL10RA'}      NaN   NaN  genes  [IL10RA]
# 3  {'genes': 'VSTM2A'}      NaN   NaN  genes  [VSTM2A]
# 4   {'genes': 'SH2B3'}      NaN   NaN  genes   [SH2B3]

# %% [markdown]
# ### How many terms idenitfied as gene symbols were queried across all queries? (queries may have more than one gene term)

# %%
def flatten_comprehension(matrix):
    return [item for row in matrix for item in row]

# %%
queried_genes_list = data["genes"].tolist()

# %%
queried_genes_list = flatten_comprehension(queried_genes_list)

# %%
num_queried_gene_terms = len(queried_genes_list)
num_queried_gene_terms
# Out:
# 188832

# %% [markdown]
# ### How many interaction queries are requested using genes?

# %%
num_interaction_queries_using_genes = len(data["genes"])
num_interaction_queries_using_genes
# Out:
# 23070

# %% [markdown]
# ### How many unique gene symbols were queried between the 23,070 queries and 188,832 total symbols?

# %%
data["genes"] = data["genes"].apply(set)
data["genes"]
# Out:
# 0                                         {ATN1}
# 1                                        {GPR26}
# 2                                       {IL10RA}
# 3                                       {VSTM2A}
# 4                                        {SH2B3}
#                           ...
# 23065       {RN7SL5P, QSOX1, RBMY1C, CLIP1, PVR}
# 23066    {GINM1, SNORD15B, ZNF341, MFSD2A, OSR2}
# 23067       {POU4F1, SLPI, VASP, MKRN4P, TFAP2B}
# 23068       {PTHLH, HSD3B2, ITGAM, IDDM9, MTCP1}
# 23069           {MOB2, SRRM4, SLIRP, JAM3, HPDL}
# Name: genes, Length: 23070, dtype: object

# %%
queried_gene_symbols_set = data["genes"].agg(lambda x: set.union(*x))
num_unique_gene_symbols_queried = len(queried_gene_symbols_set)
num_unique_gene_symbols_queried
# Out:
# 43400

# %% [markdown]
# Count each queried gene

# %%
all_genes = [gene for sublist in data["genes"] for gene in sublist]
gene_counts = Counter(all_genes)
gene_counts
# Out:
# Counter({'XYZA': 1549,
#          'TNF': 1001,
#          'AP1': 715,
#          'AP2': 576,
#          'IL6': 429,
#          'IL8': 417,
#          'BRAF': 305,
#          'XYZB': 278,
#          'n': 158,
#          'KRAS': 148,
#          'L': 144,
#          'y': 140,
#          'h': 140,
#          't': 140,
#          'e': 140,
#          'K': 140,
#          'g': 140,
#          'NME1-NME2': 73,
#          'COL1A1': 71,
#          'UCHL1': 62,
#          'NPIPA5': 58,
#          'DSG1': 58,
#          'MMP2': 57,
#          'BASP1': 57,
#          'FBN1': 55,
#          'KRT14': 55,
#          'MARCKS': 54,
#          'CAV1': 54,
#          'MAP2': 53,
#          'DSP': 51,
#          'COL6A1': 50,
#          'TNS3': 50,
#          'CXCL8': 49,
#          'COL3A1': 49,
#          'LRP1': 49,
#          'KIF1A': 49,
#          'RAP1GAP2': 49,
#          'FN1': 48,
#          'C1QA': 48,
#          'RUNX1': 48,
#          'PTPRC': 48,
#          'COL4A1': 48,
#          'NEDD4': 46,
#          'FLT3': 46,
#          'PROSER2': 46,
#          'MAP1A': 46,
#          'PPBP': 45,
#          'AADACL3': 45,
#          'FNDC3B': 44,
#          'APOE': 44,
#          'C1S': 44,
#          'UBE2C': 44,
#          'MFAP4': 44,
#          'PMP22': 44,
#          'VSTM2A': 43,
#          'SPARC': 43,
#          'VCAN': 43,
#          'SFRP4': 43,
#          'IL20RB': 43,
#          'NEFM': 43,
#          'C1QC': 43,
#          'COL4A2': 43,
#          'ADAM28': 42,
#          'SPNS3': 42,
#          'SPINK2': 42,
#          'KRT16': 42,
#          'FLT1': 42,
#          'BRCA1': 41,
#          'ATP8B4': 41,
#          'MGP': 41,
#          'A2ML1': 40,
#          'FABP4': 40,
#          'SMIM24': 40,
#          'NBPF19': 40,
#          'POSTN': 40,
#          'BGN': 40,
#          'TIMP2': 40,
#          'CHRNA3': 40,
#          'CPA3': 39,
#          'TMEM256-PLSCR3': 39,
#          'HTRA1': 39,
#          'COL1A2': 39,
#          'RNASE1': 39,
#          'SPARCL1': 39,
#          'CPE': 39,
#          'CCND1': 39,
#          'ANXA1': 38,
#          'RGPD5': 38,
#          'FXR2': 38,
#          'COL6A2': 38,
#          'TNRC6B': 38,
#          'CD69': 38,
#          'CCNL1': 38,
#          'STK17B': 38,
#          'PLAC8': 38,
#          'CDK6': 37,
#          'PROK2': 37,
#          'ADGRB3': 37,
#          'PRSS57': 37,
#          'LUM': 37,
#          'SERPINA12': 37,
#          'C1QTNF5': 37,
#          'THY1': 37,
#          'DDX3Y': 36,
#          'IGF2BP2': 36,
#          'PLK1': 36,
#          'ANKRD28': 36,
#          'C1R': 36,
#          'RERGL': 36,
#          'CALML5': 36,
#          'C1QB': 36,
#          'SERPINB1': 36,
#          'WWTR1': 36,
#          'APOC2': 35,
#          'NME2': 35,
#          'OR4F17': 35,
#          'MDK': 35,
#          'ADGRA2': 35,
#          'TMEM176A': 35,
#          'EPB41L3': 35,
#          'GAL': 35,
#          'CPZ': 35,
#          'SULT2B1': 35,
#          'TRIM29': 35,
#          'JCHAIN': 35,
#          'PRKCB': 35,
#          'HSH2D': 35,
#          'PRSS21': 34,
#          'GTSF1': 34,
#          'MACC1': 34,
#          'FASN': 34,
#          'AKAP12': 34,
#          'S100A12': 34,
#          'SPP1': 34,
#          'SYNPO2': 34,
#          'DMKN': 34,
#          'GATA3': 34,
#          'ESRP1': 34,
#          'HHEX': 34,
#          'CUX2': 34,
#          'KIT': 33,
#          'AKAP13': 33,
#          'SASH1': 33,
#          'CALD1': 33,
#          'COL8A2': 33,
#          'TMEM39B': 33,
#          'NDST1': 33,
#          'TANC1': 33,
#          'SPHK1': 33,
#          'EPGN': 32,
#          'ID3': 32,
#          'RGS18': 32,
#          'CD24': 32,
#          'ATAT1': 32,
#          'TAGLN': 32,
#          'CBR1': 32,
#          'LMNA': 32,
#          'AKR1C1': 32,
#          'ADH1B': 32,
#          'AIFM2': 32,
#          'CPS1': 32,
#          'CKS2': 32,
#          'COL6A3': 32,
#          'PPEF2': 32,
#          'GABRP': 32,
#          'SDC3': 32,
#          'MFSD2A': 32,
#          'PEG10': 32,
#          'PLA2G10': 32,
#          'NR3C1': 32,
#          'ERI1': 32,
#          'B3GAT3': 32,
#          'SEMA6C': 32,
#          'EHBP1': 32,
#          'ID2B': 32,
#          'JMJD1C': 32,
#          'FILIP1': 32,
#          'UGDH': 32,
#          'NAV1': 32,
#          'SH2B3': 31,
#          'MAPK3': 31,
#          'CT45A5': 31,
#          'HSPB1': 31,
#          'HDC': 31,
#          'CLC': 31,
#          'PTH2R': 31,
#          'GSTP1': 31,
#          'MPST': 31,
#          'AGAP11': 31,
#          'ANTXR1': 31,
#          'ACSL4': 31,
#          'ITGAM': 31,
#          'SHTN1': 31,
#          'KYNU': 31,
#          'SYNM': 31,
#          'PDE3A': 31,
#          'SOD3': 31,
#          'KRT15': 31,
#          'KRT5': 31,
#          'COL5A2': 31,
#          'FGFR3': 31,
#          'PAPPA': 31,
#          'ARID5B': 31,
#          'ARMC3': 31,
#          'DCC': 31,
#          'ITSN2': 31,
#          'CLIP1': 31,
#          'CHAMP1': 31,
#          'NCOA1': 31,
#          'CRIP2': 31,
#          'ARHGEF16': 31,
#          'KIF5B': 31,
#          'GSTM2': 31,
#          'SYNPO': 31,
#          'MIR3161': 31,
#          'LEFTY1': 31,
#          'ZNF536': 31,
#          'DPPA4': 30,
#          'FCER1A': 30,
#          'CT45A10': 30,
#          'MAPKAPK2': 30,
#          'ECE1': 30,
#          'FCER1G': 30,
#          'SRGN': 30,
#          'ADAR': 30,
#          'AFF4': 30,
#          'ALDH3A1': 30,
#          'PCK1': 30,
#          'SLC2A2': 30,
#          'SIGLEC9': 30,
#          'IGLL1': 30,
#          'NHSL2': 30,
#          'NFIB': 30,
#          'SFRP2': 30,
#          'CLDN11': 30,
#          'DLC1': 30,
#          'FOSL2': 30,
#          'PLEK': 30,
#          'MEF2D': 30,
#          'WIPF2': 30,
#          'CA12': 30,
#          'GBF1': 30,
#          'SETD2': 30,
#          'MIR4494': 30,
#          'ENAH': 30,
#          'NFE2': 30,
#          'PAGE1': 30,
#          'DNAJB8': 30,
#          'PTPN14': 30,
#          'VAMP5': 30,
#          'CCDC39': 30,
#          'GSTT1': 30,
#          'CHEK2': 30,
#          'GP2': 30,
#          'PTPN5': 30,
#          'TAGLN3': 30,
#          'TIMP3': 30,
#          'RBP1': 30,
#          'TP53': 29,
#          'PPDPF': 29,
#          'HDGF': 29,
#          'DAPK3': 29,
#          'ABL1': 29,
#          'IGFBP4': 29,
#          'PGD': 29,
#          'AHNAK2': 29,
#          'ADIPOR2': 29,
#          'TMEM176B': 29,
#          'KCNAB1': 29,
#          'MYLK': 29,
#          'DSC3': 29,
#          'S100A2': 29,
#          'CTHRC1': 29,
#          'TMEM88B': 29,
#          'KCNQ2': 29,
#          'TRPM8': 29,
#          'MPO': 29,
#          'PIK3R5': 29,
#          'CPD': 29,
#          'SRRM2': 29,
#          'TTC34': 29,
#          'SLFN12': 29,
#          'PKDCC': 29,
#          'RHOH': 29,
#          'SFXN5': 29,
#          'PPP2R3A': 29,
#          'ATOH8': 29,
#          'DTX3L': 29,
#          'DNAJC25': 29,
#          'KPNB1': 29,
#          'ARHGEF10': 29,
#          'RREB1': 29,
#          'NOTCH2': 29,
#          'IRS2': 29,
#          'FAIM2': 29,
#          'PML': 29,
#          'BAZ1A': 29,
#          'UBE2E3': 29,
#          'PHLDB3': 29,
#          'KIF1B': 29,
#          'PLP2': 29,
#          'F3': 29,
#          'LHCGR': 29,
#          'SKOR1': 29,
#          'PKHD1': 29,
#          'ZCCHC2': 29,
#          'NCAM1': 29,
#          'SPTLC2': 29,
#          'POU3F3': 29,
#          'N4BP1': 29,
#          'FURIN': 29,
#          'POM121C': 29,
#          'TNRC18': 29,
#          'FTHL17': 29,
#          'LOC101927795': 29,
#          'LOC105374561': 29,
#          'LOC101928195': 29,
#          'LOC105376246': 29,
#          'HIST1H3J': 29,
#          'PF4': 28,
#          'HLA-DRB1': 28,
#          'NAGLU': 28,
#          'JUNB': 28,
#          'PRRC2A': 28,
#          'ERBB2': 28,
#          'APOD': 28,
#          'ALDH3A2': 28,
#          'ADAMTS20': 28,
#          'AKAP17A': 28,
#          'HGD': 28,
#          'CES1': 28,
#          'MYB': 28,
#          'MYL9': 28,
#          'HSPA6': 28,
#          'LUZP6': 28,
#          'EFEMP1': 28,
#          'MFAP5': 28,
#          'DPT': 28,
#          'SPRR2E': 28,
#          'PERP': 28,
#          'HHATL': 28,
#          'KLRC2': 28,
#          'IGF2': 28,
#          'ITM2B': 28,
#          'TUBB2B': 28,
#          'MEX3D': 28,
#          'CAP1': 28,
#          'ITPRIP': 28,
#          'NUP153': 28,
#          'SAMD4B': 28,
#          'IQGAP2': 28,
#          'CNIH3': 28,
#          'MCF2L': 28,
#          'ZNF385B': 28,
#          'ZNF135': 28,
#          'CELF1': 28,
#          'ETS2': 28,
#          'DICER1': 28,
#          'MAP4K4': 28,
#          'KSR1': 28,
#          'GBP6': 28,
#          'BUD13': 28,
#          'EP400': 28,
#          'MST1R': 28,
#          'RIC1': 28,
#          'SMOC1': 28,
#          'DRAM1': 28,
#          'KIAA1109': 28,
#          'HES6': 28,
#          'XYLT1': 28,
#          'NES': 28,
#          'RNF111': 28,
#          'MYO5A': 28,
#          'RTN4RL1': 28,
#          'PLD1': 28,
#          'FMO1': 28,
#          'NINL': 28,
#          'PPP2R5A': 28,
#          'MAP1B': 28,
#          'MAP3K5': 28,
#          'SMG1': 28,
#          'SBNO2': 28,
#          'HTT': 28,
#          'RNF13': 28,
#          'PCM1': 28,
#          'UNC79': 28,
#          'RIMS4': 28,
#          'PPFIA1': 28,
#          'NT5C3B': 28,
#          'CADM3': 28,
#          'PLEKHM3': 28,
#          'LOC400997': 28,
#          'LOC388780': 28,
#          'LOC105377035': 28,
#          'LOC105375738': 28,
#          'LOC101927078': 28,
#          'LOC105378737': 28,
#          'HCG26': 28,
#          'CLU': 27,
#          'TBL1XR1': 27,
#          'ZFP36L1': 27,
#          'MMP14': 27,
#          'MYC': 27,
#          'AKR1C3': 27,
#          'IGFBP5': 27,
#          'RARA': 27,
#          'ABCF1': 27,
#          'ADM2': 27,
#          'AGFG1': 27,
#          'SGK2': 27,
#          'UROC1': 27,
#          'CA5A': 27,
#          'TDO2': 27,
#          'COLEC11': 27,
#          'CYP2D6': 27,
#          'CD93': 27,
#          'SGIP1': 27,
#          'LY6D': 27,
#          'PKP1': 27,
#          'CTSG': 27,
#          'CCDC80': 27,
#          'COPZ2': 27,
#          'DOCK5': 27,
#          'KRTAP10-2': 27,
#          'NFE2L2': 27,
#          'LPIN2': 27,
#          'MAGED4B': 27,
#          'CR1': 27,
#          'ST3GAL6': 27,
#          'MAPT': 27,
#          'LINC01277': 27,
#          'ARID1A': 27,
#          'OLFM1': 27,
#          'TCEAL4': 27,
#          'TRIM55': 27,
#          'ACTL7A': 27,
#          'DOCK8': 27,
#          'FAM41C': 27,
#          'IL36A': 27,
#          'NBEAL2': 27,
#          'RTKN': 27,
#          'PDE4D': 27,
#          'SIGLEC1': 27,
#          'CHRNA6': 27,
#          'NOLC1': 27,
#          'ZNF219': 27,
#          'SMAD2': 27,
#          'DENND4C': 27,
#          'APBA1': 27,
#          'KMT2C': 27,
#          'PLEKHG2': 27,
#          'NEDD4L': 27,
#          'TAS2R46': 27,
#          'PLA2G4A': 27,
#          'ARHGAP15': 27,
#          'SMAP1': 27,
#          'NDEL1': 27,
#          'FCGRT': 26,
#          'SPP2': 26,
#          'AEBP1': 26,
#          'CAT': 26,
#          'PER1': 26,
#          'ANXA5': 26,
#          'ANKRD60': 26,
#          'ADAMTS9-AS1': 26,
#          'AIFM3': 26,
#          'ADGRB1': 26,
#          'ANXA11': 26,
#          'SERPINA11': 26,
#          'SDC1': 26,
#          'MAT1A': 26,
#          'CYP4F11': 26,
#          'MLXIPL': 26,
#          'NEDD9': 26,
#          'CXCL14': 26,
#          'SORBS2': 26,
#          'ZEB2': 26,
#          'TROAP': 26,
#          'SCEL': 26,
#          'KRT1': 26,
#          'CALML3': 26,
#          'CRCT1': 26,
#          'S100A14': 26,
#          'CNTN1': 26,
#          'COL5A1': 26,
#          'SEC14L5': 26,
#          'TACC2': 26,
#          'DCN': 26,
#          'DDX60L': 26,
#          'DTX3': 26,
#          'IFITM3': 26,
#          'RIN1': 26,
#          'MAP1LC3B2': 26,
#          'DCP1A': 26,
#          'UMODL1': 26,
#          'ONECUT3': 26,
#          'SYNJ1': 26,
#          'LINC00853': 26,
#          'TCN2': 26,
#          'UAP1L1': 26,
#          'NUTM2G': 26,
#          'CDCP2': 26,
#          'LINC01324': 26,
#          'SPATA16': 26,
#          'SPATA3-AS1': 26,
#          'MIR26B': 26,
#          'KRT34': 26,
#          'TTF2': 26,
#          'TH': 26,
#          'SNORD115-28': 26,
#          'LINC00602': 26,
#          'CIRBP-AS1': 26,
#          'RNF213': 26,
#          'OCLM': 26,
#          'CA7': 26,
#          'HSD3B7': 26,
#          'CLEC18B': 26,
#          'KRT86': 26,
#          'MED1': 26,
#          'AGPAT4-IT1': 26,
#          'SYNGR3': 26,
#          'JADE1': 26,
#          'CLCN1': 26,
#          'LDLRAD2': 26,
#          'ZNF341': 26,
#          'LINC00311': 26,
#          'NKX6-3': 26,
#          'ZNF682': 26,
#          'MIR3182': 26,
#          'MSX2': 26,
#          'LRRC24': 26,
#          'KRT38': 26,
#          'LINC00460': 26,
#          'HES3': 26,
#          'RAB3B': 26,
#          'S100A16': 26,
#          'OR2S2': 26,
#          'DRAIC': 26,
#          'SNORD116-21': 26,
#          'MIR124-1': 26,
#          'GRM5': 26,
#          'SELE': 26,
#          'TMEM114': 26,
#          'DDX12P': 26,
#          'WDR62': 26,
#          'LZTS1': 26,
#          'HPYR1': 26,
#          'KPTN': 26,
#          'NT5DC4': 26,
#          'TAS2R13': 26,
#          'FOSL1': 26,
#          'HSPA2': 26,
#          'PRAMEF2': 26,
#          'FOXH1': 26,
#          'OSTN': 26,
#          'CSGALNACT2': 26,
#          'ASPA': 26,
#          'FABP12': 26,
#          'GCLM': 26,
#          'RHPN2': 26,
#          'MFSD6': 26,
#          'KRTAP15-1': 26,
#          'SIX4': 26,
#          'KCND1': 26,
#          'SOS1': 26,
#          'EML1': 26,
#          'MAGEC3': 26,
#          'OR8D4': 26,
#          'LINC01362': 26,
#          'MLIP-IT1': 26,
#          'MIR4255': 26,
#          'ARID3C': 26,
#          'SLC45A1': 26,
#          'SLMAP': 26,
#          'OR51H1': 26,
#          'LINC01164': 26,
#          'GRM4': 26,
#          'C8ORF74': 26,
#          'SMCO1': 26,
#          'KRTAP19-8': 26,
#          'SLC35A2': 26,
#          'AOAH-IT1': 26,
#          'PXN-AS1': 26,
#          'ATXN2': 26,
#          'BATF2': 26,
#          'TMPRSS15': 26,
#          'PWRN4': 26,
#          'SMG7': 26,
#          'DIAPH1': 26,
#          'RTN3': 26,
#          'CLPSL2': 26,
#          'PEAK1': 26,
#          'LMO4': 26,
#          'DPYD-AS1': 26,
#          'MIR1258': 26,
#          'ZSCAN12P1': 26,
#          'ARSB': 26,
#          'CAV3': 26,
#          'SLC23A2': 26,
#          'LINC00551': 26,
#          'PRAMEF8': 26,
#          'PLEKHS1': 26,
#          'ERLIN1': 26,
#          'CLPS': 26,
#          'DDR2': 26,
#          'PI15': 26,
#          'SELL': 26,
#          'GPRIN2': 26,
#          'GAPT': 26,
#          'ZNF880': 26,
#          'SEC16A': 26,
#          'MED13L': 26,
#          'FXYD6': 26,
#          'SRXN1': 26,
#          'SLC17A8': 26,
#          'MIR210HG': 26,
#          'SRRM1': 26,
#          'LILRA6': 26,
#          'ATXN2L': 26,
#          'STH': 26,
#          'IL10RA': 25,
#          'SORBS3': 25,
#          'HLA-DRB5': 25,
#          'CBR3': 25,
#          'RHOB': 25,
#          'GJA1': 25,
#          'A2M': 25,
#          'APP': 25,
#          'ANKRD17': 25,
#          'AKR1C2': 25,
#          'ADAM12': 25,
#          'SYBU': 25,
#          'CKB': 25,
#          'GK': 25,
#          'LGALS7B': 25,
#          'S100A7': 25,
#          'SBSN': 25,
#          'LGALS7': 25,
#          'KRTDAP': 25,
#          'FAM25A': 25,
#          'CST6': 25,
#          'MXRA5': 25,
#          'COL16A1': 25,
#          'FAM71F2': 25,
#          'PHC3': 25,
#          'B4GALNT4': 25,
#          'LINC01327': 25,
#          'ARNTL2-AS1': 25,
#          'FAM110D': 25,
#          'LINC00838': 25,
#          'MIR199A1': 25,
#          'PCSK4': 25,
#          'SNORD116-28': 25,
#          'TSPAN1': 25,
#          'COMTD1': 25,
#          'KCTD4': 25,
#          'KLLN': 25,
#          'PRDM14': 25,
#          'LYSMD2': 25,
#          'SLC47A2': 25,
#          'OR51T1': 25,
#          'MIR3178': 25,
#          'LILRA3': 25,
#          'IL31RA': 25,
#          'ZIM3': 25,
#          'ENTPD2': 25,
#          'EPG5': 25,
#          'PTENP1': 25,
#          'MIR1250': 25,
#          'CEACAM16': 25,
#          'MIR4748': 25,
#          'IFITM4P': 25,
#          'CIB3': 25,
#          'PCBP4': 25,
#          'RSPH14': 25,
#          'CD244': 25,
#          'RHOT1': 25,
#          'PEX10': 25,
#          'KLHL1': 25,
#          'AVPR2': 25,
#          'RCOR1': 25,
#          'MIR3119-1': 25,
#          'DEFB134': 25,
#          'SAPCD1-AS1': 25,
#          'CRYAB': 25,
#          'SNORD116-27': 25,
#          'GIGYF2': 25,
#          'BSPH1': 25,
#          'LINC01142': 25,
#          'MCHR2': 25,
#          'MIR1252': 25,
#          'CAP2': 25,
#          'KCNQ5-AS1': 25,
#          'RELCH': 25,
#          'GSTA5': 25,
#          'NYAP1': 25,
#          'IGSF9': 25,
#          'RNU5A-1': 25,
#          'CABIN1': 25,
#          'MIR3663HG': 25,
#          'TBX5': 25,
#          'GRN': 25,
#          'CRMP1': 25,
#          'SPN': 25,
#          'NUTM1': 25,
#          'MUSK': 25,
#          'MIR548D1': 25,
#          'STYXL1': 25,
#          'FOXI1': 25,
#          'GNB3': 25,
#          'MIR4525': 25,
#          'BRWD3': 25,
#          'MIR4308': 25,
#          'C16ORF90': 25,
#          'LINC01620': 25,
#          'OR2J3': 25,
#          'LY6G6D': 25,
#          'CFAP52': 25,
#          'TCF19': 25,
#          'FAM161A': 25,
#          'LINC00572': 25,
#          'MTRNR2L7': 25,
#          'FAM99B': 25,
#          'OR10J3': 25,
#          'SLC36A3': 25,
#          'MAMDC2-AS1': 25,
#          'IGHV3OR16-12': 25,
#          'TGM7': 25,
#          'ASB18': 25,
#          'C10ORF53': 25,
#          'MIR4256': 25,
#          'SERPINA13P': 25,
#          'LINC00527': 25,
#          'MIR4732': 25,
#          'CLDN10-AS1': 25,
#          'UPK1A-AS1': 25,
#          'PCDHB19P': 25,
#          'BPIFB6': 25,
#          'C1QTNF9': 25,
#          'FAM138B': 25,
#          'XKRY2': 25,
#          'NDST3': 25,
#          'USP12-AS1': 25,
#          'SPECC1': 25,
#          'MIR2278': 25,
#          'FBXW9': 25,
#          'CDC42EP2': 25,
#          'DCX': 25,
#          'UCMA': 25,
#          'CCDC105': 25,
#          'LINC01507': 25,
#          'MIR4791': 25,
#          'ARGFXP2': 25,
#          'CCDC157': 25,
#          'CHRNB2': 25,
#          'MIR203B': 25,
#          'HOXC6': 25,
#          'KRTAP9-2': 25,
#          'TEX264': 25,
#          'RAG1': 25,
#          'PIH1D2': 25,
#          'MIR572': 25,
#          'RPTN': 25,
#          'DKK3': 25,
#          'PCAT6': 25,
#          'LAMTOR2': 25,
#          'SNORD114-2': 25,
#          'SEBOX': 25,
#          'ITGA2': 25,
#          'IWS1': 25,
#          'PPP1R36': 25,
#          'NCOA6': 25,
#          'SLC17A4': 25,
#          'SLC22A17': 25,
#          'TUBB3': 25,
#          'MAST3': 25,
#          'SNORA55': 25,
#          'BRS3': 25,
#          'OR4C46': 25,
#          'OR52N1': 25,
#          'ZNF497': 25,
#          'KRTAP19-5': 25,
#          'CERS1': 25,
#          'ZEB1-AS1': 25,
#          'CCDC148-AS1': 25,
#          'USP29': 25,
#          'OR2T27': 25,
#          'CCDC81': 25,
#          'BEST4': 25,
#          'EFCAB8': 25,
#          'SH3BP4': 25,
#          'FSHB': 25,
#          'USP3': 25,
#          'SPRED2': 25,
#          'CRLF1': 25,
#          'FBXO16': 25,
#          'CEMP1': 25,
#          'THSD7B': 25,
#          'MIR192': 25,
#          'RMST': 25,
#          'MIR548Z': 25,
#          'MIR3620': 25,
#          'YWHAEP1': 25,
#          'FER1L5': 25,
#          'PRSS29P': 25,
#          'TP53TG3B': 25,
#          'IQCF5': 25,
#          'MIR4289': 25,
#          'MIR623': 25,
#          'MIR4441': 25,
#          'R3HDML': 25,
#          'FSD2': 25,
#          'R3HDM2': 25,
#          'HM13-AS1': 25,
#          'ZFC3H1': 25,
#          'NRON': 25,
#          'KRTAP7-1': 25,
#          'LGALS9B': 25,
#          'LINC00639': 25,
#          'LCE3B': 25,
#          'MIR4312': 25,
#          'LINC01571': 25,
#          'ICAM5': 25,
#          'MIR26A1': 25,
#          'SGCE': 25,
#          'PCDH1': 25,
#          'CSPG4P10': 25,
#          'S100A9': 24,
#          'ST8SIA6': 24,
#          'SERPINH1': 24,
#          'AGA': 24,
#          'ANAPC2': 24,
#          'ADA': 24,
#          'AHCTF1': 24,
#          'RARRES2': 24,
#          'NNMT': 24,
#          'GPX2': 24,
#          'P2RX1': 24,
#          'LCE2B': 24,
#          'LCE2D': 24,
#          'FLG2': 24,
#          'SFN': 24,
#          'FABP7': 24,
#          'ASPRV1': 24,
#          'KRT2': 24,
#          'EDIL3': 24,
#          'TP63': 24,
#          'COL17A1': 24,
#          'SOX10': 24,
#          'GNAO1': 24,
#          'YBX1': 24,
#          'BEX1': 24,
#          'RTN1': 24,
#          'CYTIP': 24,
#          'MEPCE': 24,
#          'LARP4B': 24,
#          'LRBA': 24,
#          'IFI44L': 24,
#          'CBX3': 24,
#          'RANBP2': 24,
#          'MIA3': 24,
#          'FCHO2': 24,
#          'PTGR1': 24,
#          'TC2N': 24,
#          'BCL9': 24,
#          'WRNIP1': 24,
#          'TGFB1I1': 24,
#          'TBC1D2': 24,
#          'RBM15B': 24,
#          'CCAR2': 24,
#          'RAB37': 24,
#          'LARP7': 24,
#          'ELAVL4': 24,
#          'USP34': 24,
#          'ZC3H18': 24,
#          'ITGA4': 24,
#          'CARD14': 24,
#          'ERCC6': 24,
#          'TCOF1': 24,
#          'MISP': 24,
#          'IRF2BP2': 24,
#          'TCP10': 24,
#          'TCL1A': 23,
#          'HLA-C': 23,
#          'IGFBP3': 23,
#          'IFI27': 23,
#          'SCG5': 23,
#          'ADAMTS9': 23,
#          'AZGP1': 23,
#          'DES': 23,
#          'ID4': 23,
#          'DSC1': 23,
#          'KRT79': 23,
#          'WFDC5': 23,
#          'COL11A1': 23,
#          'LCE1C': 23,
#          'FLG': 23,
#          'COL12A1': 23,
#          'KRT6B': 23,
#          'GGT6': 23,
#          'NBL1': 23,
#          'IGF1': 23,
#          'PLP1': 23,
#          'NRXN1': 23,
#          'PCOLCE': 23,
#          'APLP1': 23,
#          'UBN2': 23,
#          'DMTN': 23,
#          'HPS5': 23,
#          'GKN2': 23,
#          'LSR': 23,
#          'SPEN': 23,
#          'TBX2': 23,
#          'SLTM': 23,
#          'L1CAM': 23,
#          'RLF': 23,
#          'GAS2L1': 23,
#          'MICAL1': 23,
#          'RPRD2': 23,
#          'CNN3': 23,
#          'CEP170B': 23,
#          'ZC3HC1': 23,
#          'SHANK3': 23,
#          'RBM15': 23,
#          'GPRC5C': 23,
#          'MED12': 23,
#          'DOCK2': 23,
#          'SIPA1L1': 23,
#          'PTPDC1': 23,
#          'PRR12': 23,
#          'GFRA3': 23,
#          'SNAP25': 23,
#          'INA': 23,
#          'MLPH': 23,
#          'LIMD1': 23,
#          'SRPK1': 23,
#          'SON': 23,
#          'PARN': 23,
#          'ARHGEF17': 23,
#          'JCAD': 23,
#          'ARHGEF11': 23,
#          'NOS3': 23,
#          'TBC1D14': 23,
#          'SETD1B': 23,
#          'ITPKB': 23,
#          'SENP1': 23,
#          'NOP58': 23,
#          'RCSD1': 23,
#          'PLVAP': 23,
#          'ASH1L': 23,
#          'SCAF1': 23,
#          'VCPIP1': 23,
#          'MARF1': 23,
#          'MBD1': 23,
#          'ATF7': 23,
#          'TCF25': 23,
#          'ARHGAP23': 23,
#          'NOP56': 23,
#          'LOC105376790': 23,
#          'LOC102800447': 23,
#          'LOC101929162': 23,
#          'LOC105377172': 23,
#          'LOC101928336': 23,
#          'LOC101927932': 23,
#          'PAPL': 23,
#          'LOC105375266': 23,
#          'LOC101928460': 23,
#          'LOC105379379': 23,
#          'LOC101927660': 23,
#          'LOC101929595': 23,
#          'APCDD1L-AS1': 23,
#          'LOC105371577': 23,
#          'LOC105369808': 23,
#          'LOC105375037': 23,
#          'LOC101929227': 23,
#          'LOC105374716': 23,
#          'LOC105378178': 23,
#          'LOC105376036': 23,
#          'LOC105378283': 23,
#          'LOC105374817': 23,
#          'LOC105371918': 23,
#          'LOC105370512': 23,
#          'LOC105372638': 23,
#          'FLJ46066': 23,
#          'LOC400002': 23,
#          'LOC100101148': 23,
#          'LOC105375551': 23,
#          'LOC105377991': 23,
#          'LOC102724917': 23,
#          'LOC101927502': 23,
#          'LOC105374724': 23,
#          'LOC102724227': 23,
#          'LOC105378591': 23,
#          'LOC102723306': 23,
#          'FLJ35816': 23,
#          'LOC101928089': 23,
#          'LOC339468': 23,
#          'LOC105370003': 23,
#          'LOC100507557': 23,
#          'LOC101927260': 23,
#          ...})

# %%
gene_counts["KRAS"]
# Out:
# 148

# %% [markdown]
# ### Load Ambiguous Gene Symbol Set

# %%
with open("../output/ambiguous_symbol_set.txt", "r") as file:
    # read each line, strip newline characters, and convert to a set
    ambiguous_symbol_set = set(line.strip() for line in file)
ambiguous_symbol_set
# Out:
# {'MSSP',
#  'UGT1-01',
#  'PRO1',
#  'SPR',
#  'CSL',
#  'NOP9',
#  'HIS1',
#  'LRP/LR',
#  'A3GALNT',
#  'H3C10',
#  'TRC-GCA2-4',
#  'DELTA',
#  'ARP5',
#  'DEFA1',
#  'AIP1',
#  'CDC14B2',
#  'TNRC18',
#  'A3B',
#  'STAP',
#  'ZNF',
#  'MAGI1',
#  'VARS2',
#  'AGS1',
#  'GTF2IRD2',
#  'SAX2',
#  'PPT2',
#  'PIRB',
#  'CPT1',
#  'AMCD2B',
#  'HSD3',
#  'NUDT10',
#  'MGAT2',
#  'CN1',
#  'DLK',
#  'P42',
#  'INCA',
#  'LINC00545',
#  'SWS1',
#  'HL1',
#  'CILD38',
#  'KIR2DL5',
#  'PRSSL1',
#  'LINC02110',
#  'STA',
#  'WASH',
#  'TRIF',
#  'TSPEAR-AS2',
#  'H3C3',
#  'CMK',
#  'CAP',
#  'SUMO3',
#  'NPIPA7',
#  'NOR1',
#  'SPN',
#  'ADAMTS-2',
#  'TRF',
#  'ODC',
#  'GIP',
#  'CLIP4',
#  'H2BC7',
#  'DQA1',
#  'GCAP',
#  'HBSCI',
#  'ENOS',
#  'HLS',
#  'SIRH1',
#  'APOC4',
#  'LINC02036',
#  'CDA1',
#  'EIF1AP1',
#  'SCG2',
#  'P41',
#  'ALT1',
#  'MYLK-AS2',
#  'ELK2',
#  'TRNAMI2',
#  'OR11-104',
#  'NPH2',
#  'DIM1',
#  'RNU1-8',
#  'HSFY',
#  'SERRS',
#  'POP3',
#  'RAB1',
#  'S100',
#  'PK',
#  'XDH',
#  'PIT-1',
#  'HPF1',
#  'SOCS4',
#  'SPC1',
#  'DRF1',
#  'TRA-TGC3-2',
#  'M33',
#  'P33',
#  'HCST',
#  'TRH-GTG1-8',
#  'IL-20',
#  'FAM66E',
#  'SPP2',
#  'TNFRSF11B',
#  'LSH',
#  'CCZ1',
#  'SLAP',
#  'MCRIP2P1',
#  'HK1',
#  'PUMAG',
#  'SUP',
#  'LYS2',
#  'SSS1',
#  'RIP3',
#  'ARF1',
#  'EWSR2',
#  'P44',
#  'SPC7',
#  'RNASE4',
#  'TCRAV15S1',
#  'DESI2',
#  'ARP',
#  'UBTFL5',
#  'FRG',
#  'NOC4',
#  'P73',
#  'ODD',
#  'RNASEH1',
#  'GTK',
#  'MAP-2',
#  'TAL',
#  'GEM',
#  'H2-ALPHA',
#  'CAB',
#  'NBC3',
#  'NG2',
#  'ICLN',
#  'VWS1',
#  'PCPB',
#  'T6',
#  'PSCTK2',
#  'KLIP1',
#  'DAN',
#  'SCP',
#  'TRY-GTA5-5',
#  'UNR',
#  'ABP',
#  'CAT2',
#  'BPAD',
#  'HNRPA1L3',
#  'ZAC',
#  'S14',
#  'ME2',
#  'TTY6',
#  'VPP3',
#  'CYBL',
#  'D3F15S2',
#  'C11ORF5',
#  'CD205',
#  'TTTY21',
#  'GCP',
#  'PAR-4',
#  'MUHH',
#  'COX11P',
#  'SMUC',
#  'FOXO3B',
#  'ODF2',
#  'MIHC',
#  'SPK',
#  'TICAM-2',
#  'B7-H5',
#  'NRP',
#  'PCA1',
#  'OR4M2',
#  'PRO1068',
#  'GAGED2',
#  'CAB1',
#  'FADS',
#  'C17ORF106',
#  'RILP',
#  'CFHL3',
#  'SKD2',
#  'LINC02815',
#  'MTFR2P1',
#  'PLGP2',
#  'CT45-2',
#  'PTE2',
#  'CYB560',
#  'SST2',
#  'CCRL1',
#  'POLB',
#  'C1ORF175',
#  'SNF2',
#  'CDF',
#  'EDF',
#  'FAM25C',
#  'STIP-1',
#  'MOSP',
#  'CLS',
#  'ARGRS',
#  'MYNN',
#  'L8',
#  'HB-1',
#  'TCRAV17S1',
#  'KIAA0229',
#  'FRAG1',
#  'CHL',
#  'ALTMIEF1',
#  'TSPY',
#  'TSSK1B',
#  'MPS1',
#  'FRA',
#  'KIAA0700',
#  'IBD1',
#  'SIP-1',
#  'GTF2A1L',
#  'SMN-AS1',
#  'HSP70.1',
#  'GCD10',
#  'ERG3',
#  'CTH',
#  'SEP2',
#  'T2R56',
#  'IP',
#  'TEF3',
#  'ORM',
#  'XAGE1B',
#  'LINC00516',
#  'PRL1',
#  'OR19-8',
#  'MAGE1',
#  'AGT',
#  'TIH1',
#  'CA11',
#  'EEG1',
#  'TC2',
#  'BMH',
#  'P11',
#  'MMP21',
#  'HRH2',
#  'FAM90A17P',
#  'LINC00707',
#  'IMD2',
#  'ANCR',
#  'SPANX',
#  'GNT1',
#  'MCS',
#  'FIX',
#  'PCP2',
#  'MIP-1-BETA',
#  'H4C12',
#  'CT',
#  'TUBB4',
#  'FANCD',
#  'RNF35',
#  'DRG-1',
#  'MU2',
#  'CTLA1',
#  'TER',
#  'ROC1',
#  'AAAT',
#  'LAT3',
#  'LINC00086',
#  'PAR2',
#  'QARS',
#  'CDH7',
#  'PAP2',
#  'VP',
#  'TMSA',
#  'MTS',
#  'RINZF',
#  'GYPA',
#  'CTF5',
#  'P19',
#  'CNC',
#  'HBA',
#  'P38',
#  'AK6',
#  'CFTD',
#  'TRL-AAG2-3',
#  'P2Y11',
#  'POTE22',
#  'CFAG',
#  'GGTA1P',
#  'NKH',
#  'HIES2',
#  'LINC01731',
#  'SCZD9',
#  'P20',
#  'OR7E73P',
#  'TCF4',
#  'ORP1',
#  'OR1D4',
#  'WMS',
#  'VR1',
#  'HH13',
#  'BEDP',
#  'TMSL8',
#  'ERG-1',
#  'FIR',
#  'OLFR42B',
#  'LINC02254',
#  'NPIPB',
#  'SIGLECP1',
#  'RNU1-7',
#  'L10',
#  'PRH2',
#  'ZNF408',
#  'SLURP2',
#  'RU2',
#  'HSPA1',
#  'TK2',
#  'OR19-6',
#  'MT1',
#  'HPCA',
#  'MBD3',
#  '12-LOX',
#  'DIVA',
#  'GPR42',
#  'TCRAV18S1',
#  'ESP1',
#  'MRP-S28',
#  'MM1',
#  'FOXL3',
#  'FBLP1',
#  'LCA',
#  'LAP',
#  'BDA2',
#  'UGD',
#  'HNRNP-G',
#  'NPY4R',
#  'FCGR1',
#  'PISD',
#  'RBP4',
#  'DUX1',
#  'BRCC3',
#  'GSS',
#  'CTNND1',
#  'LRP',
#  'GRINL1A',
#  'TAFII105',
#  'MMDS3',
#  'INV',
#  'CKLF',
#  'OBTP',
#  'BD-4',
#  'MRP8',
#  'HPC2',
#  'BAP',
#  'SIGLECL1',
#  'DCT1',
#  'RNA18S5',
#  '9G8',
#  'U6',
#  'GT',
#  'T6BP',
#  'IL8RA',
#  'RSC8',
#  'DNM1DN10@',
#  'OCT3',
#  'ALG2',
#  'HRAS1',
#  'LINC01260',
#  'MGAT3',
#  'EMILIN3',
#  'POD1',
#  'PGR2',
#  'EMT',
#  'GPRASP3',
#  'MRP',
#  'SGK2',
#  'TRAC',
#  'BS',
#  'MTCO2',
#  'PTPN20CP',
#  'CLP',
#  'FCT3A',
#  'MINT',
#  'POLYMERASE',
#  'NP2',
#  'CHN',
#  'CMPD2',
#  'BEC1',
#  'MRPL27',
#  'UBH1',
#  'S31I125',
#  'ACAT2',
#  'L7',
#  'P26',
#  'TRS-AGA2-6',
#  'MIF',
#  'HL-2',
#  'IFNA',
#  'NFIC',
#  'C11ORF4',
#  'APM1',
#  'MBP-1',
#  'PFD',
#  'GRL',
#  'HLS2',
#  'RAD1',
#  'DELXQ22.3',
#  'BCD1',
#  'MRD63',
#  'K8',
#  'RWDD4A',
#  'TCEAL3',
#  'HIST1H2BE',
#  'NEPPK',
#  'SFN',
#  'ODC1L',
#  'DCP1',
#  'HB5',
#  'PPS',
#  'PAR1',
#  'SF3B1',
#  'BCRP2',
#  'LINC02060',
#  'FDH',
#  'NSE2',
#  'KIP1',
#  'PTB',
#  'CYP2D',
#  'HLA-H',
#  'TTL',
#  'APOC-IV',
#  'PRL3',
#  'RSRFR2',
#  'HAI',
#  'FBP',
#  'TRNP1',
#  'SLC23A1',
#  'HZF',
#  'FCRL1',
#  'MSE',
#  'RNU6-6',
#  'FAPP2',
#  'MONA',
#  'OR11-1',
#  'MRPS12',
#  'TRP-AGG2-2',
#  'NT5',
#  'RSS',
#  'FCRL2',
#  'OR6-1',
#  'ASP',
#  'TRNAG-CCC',
#  'BRPF1',
#  'FCP',
#  'C2',
#  'HOS',
#  'HP-1',
#  'SALF',
#  'RD',
#  'RHO',
#  'PDF',
#  'IL27',
#  'CYK4',
#  'HD6',
#  'PMP22',
#  'FLJ10052',
#  'COT',
#  'TVP23C',
#  'TOP',
#  'OBP',
#  'CT4.7',
#  'RPS27AP',
#  'P240',
#  'KLC2',
#  'DJ222E13.1',
#  'TRNAV22',
#  'DHS',
#  'CSN2',
#  'DRP-1',
#  'STAT5',
#  'RAP1',
#  'CARD2',
#  'BCS',
#  'SR',
#  'FOP',
#  'H3-3A',
#  'CXXC11',
#  'KCNJN1',
#  'GBF1',
#  'PRP4',
#  'C6ORF8',
#  'LPC1',
#  'FRAXE',
#  'TNDM1',
#  'CRD',
#  'SCGB1C1',
#  'MRX15',
#  'INT4',
#  'NAF1',
#  'BDP1',
#  'FPRH1',
#  'ICBP90',
#  'A3',
#  'RPA2',
#  'CART1',
#  'HLA-HA2',
#  'CD',
#  'HCCR-1',
#  'DSS',
#  'ZAC1',
#  'PK3',
#  'PC-1',
#  'CORO7',
#  'TRS4',
#  'TRH-GTG1-6',
#  'FBL4',
#  'MIEF1-MP',
#  'DBC1',
#  'KRTAP10-9',
#  'IL-25',
#  'TYR-TRNA',
#  'PTX2',
#  'CDG1DD',
#  'H3C14',
#  'TRF-GAA1-5',
#  'CAMC',
#  'PSF1',
#  'MTF1',
#  'HML',
#  'DHP',
#  'HMGB1L1',
#  'TRAP-1',
#  'TRK-TTT3-4',
#  'P7',
#  'TRQ-CTG1-2',
#  'AD3',
#  'CST',
#  'ARSC',
#  'DMRV',
#  'DOK1',
#  'ARIA',
#  'MOP',
#  'GST3',
#  'TDPX2',
#  'MRAP',
#  'KCNMB2',
#  'TRY1',
#  'EPM2A',
#  'RK',
#  'NS3TP1',
#  'PK1',
#  'SIMP',
#  'HERV-K',
#  'LRP4',
#  'DRP1',
#  'CHC',
#  'LEURS',
#  'H-PLK',
#  'ZNF474',
#  'SPTBN1-AS2',
#  'CAP3',
#  'TCRBV12S3',
#  'LAM',
#  'U3',
#  'PKD4',
#  'VMA21',
#  'CARK',
#  'RHOGAP2',
#  'BFNC',
#  'ETK',
#  'CGRP',
#  'SRM',
#  'DJ221C16.8',
#  'RPS12',
#  'SNAPA',
#  'ALS',
#  'MAD2',
#  'CDK11-P46',
#  'TXN',
#  'SIGLECP2',
#  'AMY',
#  'PAK2',
#  'ZIN',
#  'HTR',
#  'SPATA31C2',
#  'CED',
#  'BRIP1',
#  'HSP27',
#  'P32',
#  'SRGAP2',
#  'TCRBV21S1',
#  'ICE',
#  'IK',
#  'LINC01655',
#  'AG3',
#  'SK1',
#  'LST-2',
#  'PSS1',
#  'HCDH',
#  'MLL2',
#  'POM121L1',
#  'TRF-GAA1-1',
#  'GP39',
#  'CHL1',
#  'ERV1',
#  'ABP1',
#  'SWD2',
#  'VDR',
#  'OPT',
#  'VSD1',
#  'AT',
#  'SAMS',
#  'DUX4',
#  'TCRAV2S1',
#  'HARS2',
#  'THG1',
#  'OPA1',
#  'GLUT9',
#  'PPIAL4F',
#  'ART',
#  'SP17',
#  'SLA',
#  'GC1',
#  'UBP',
#  'UGT1A',
#  'EBN',
#  'CSE',
#  'C6ST',
#  'DOR',
#  'L32MT',
#  'OR11-11A',
#  'P23',
#  'FIH1',
#  'CAR',
#  'COD4',
#  'LPCAT',
#  'CIRS-7',
#  'RAF1',
#  'DDAH',
#  'UTR',
#  'TCF6L1',
#  'PTH',
#  'PSS2',
#  'PCDH22',
#  'PTHR',
#  'FKBP51',
#  'MLD',
#  'PABP2',
#  'CRAM',
#  'CST6',
#  'CYPH',
#  'EIF-5A',
#  'EIF3A',
#  'NTN4',
#  'MUM1',
#  'EIT-6',
#  'LIN10',
#  'HNP-1',
#  'CDH1',
#  'HEP',
#  'KCNA8',
#  'ALOX12-AS1',
#  'DSC3',
#  'LAP3',
#  'SPANXE',
#  'GPCR',
#  'TRW-CCA3-2',
#  'TUBA2',
#  'ASAP',
#  'TPP1',
#  'GTF2IRD2A',
#  'HOPS',
#  'SD',
#  'GPT',
#  'RING2',
#  'SPANX-E',
#  'NEM2',
#  'NPIPA1',
#  'OR11H12',
#  'TC1',
#  'AK3L1',
#  'L10A',
#  'ZNF32',
#  'ESA1',
#  'ADAMTS-4',
#  'NAC3',
#  'RASSF4',
#  'RASSF5',
#  'ANKRD30BP3',
#  'RLF',
#  'TRX2',
#  'HRH1',
#  'FH',
#  'NOL1',
#  'CT64',
#  'KOP',
#  'BFD',
#  'FADS3',
#  'DLD',
#  'GEMIN1',
#  'CSS1',
#  'COAS2',
#  'GCKR',
#  'DTL',
#  'ERF',
#  'NCMAP-DT',
#  'CRHSP24',
#  'FCGR2C',
#  'TRMT1',
#  'OCP2',
#  'TRQ-CTG1-5',
#  'CP11',
#  'PTGES3P',
#  'CYSRS',
#  'LGL2',
#  'ADRA1',
#  'IFNT1',
#  'TYRO4',
#  'CDR1NAT',
#  'H3',
#  'NIP',
#  'TNX',
#  'H3-3B',
#  'DKFZP434B204',
#  'TIM1',
#  'DDX26',
#  'NEURL3',
#  'TTG1',
#  'IP3R',
#  'NL2',
#  'NBPF9',
#  'RNR1',
#  'ESG1',
#  'CP27',
#  'SHMT',
#  'UBXD10',
#  'RAM2',
#  'DNM1DN3@',
#  'HDGF2',
#  'HSS',
#  'ISO1',
#  'KDAP',
#  'TCRAV7S1',
#  'AP3AASE',
#  'CMS1D',
#  'ELN',
#  'H1RNA',
#  'MGA',
#  'CGI-141',
#  'RFT1',
#  'DUSP23',
#  'SMA3-L',
#  'P3',
#  'GC',
#  'VMA2',
#  'BD-6',
#  'H3C8',
#  'P17',
#  'TCF-1',
#  'HDLC1',
#  'IMP-3',
#  'GUCY2B',
#  'ATF',
#  'B55',
#  'HCG1',
#  'U4',
#  'HN3',
#  'HC',
#  'HACL1',
#  'TRK',
#  'TPT',
#  'PARPL',
#  'OR912-109',
#  'REG-III',
#  'MBD1',
#  'BD-5',
#  'LAK',
#  'CPS1',
#  'RBP',
#  'RETSDR2',
#  'F10',
#  'ACHRD',
#  'LQT5',
#  'ATP1A1',
#  'RBMY1C',
#  'CDG2T',
#  'FPP',
#  'MK3',
#  'ATF1',
#  'TRS-AGA2-1',
#  'NAT3',
#  'USE1',
#  'ATX',
#  'B3GNT6',
#  'NOV',
#  'SEMG',
#  'D-X',
#  'HYPK',
#  'CNK',
#  'CEP68',
#  'RP11',
#  'GASP',
#  'GP135',
#  'KGA',
#  'RIP2',
#  'SHEP1',
#  'SCYL2',
#  'F11',
#  'PBX2',
#  'TRS-GCT4-1',
#  'RIF',
#  'DGCR6',
#  'RBP1',
#  'METTL2',
#  'TGM6',
#  'FMR2',
#  'CAMIII',
#  'PRODH2',
#  'SPEN',
#  'SPDYE9',
#  'DVL1L1',
#  'CLECSF13',
#  'CMM8',
#  'GALNT17',
#  'BTF4',
#  'IGLV',
#  'TNRC14',
#  'RTA',
#  'HST',
#  'ASE1',
#  'CPN2',
#  'CD1',
#  'POR',
#  'RALBP1',
#  'D4',
#  'U5B1',
#  'HB2',
#  'Z18',
#  'CSRP2BP',
#  'PCN',
#  'BMND12',
#  'PIG8',
#  'PLA2',
#  'SCN1',
#  'CD158B',
#  'GALNAC-T10',
#  'XAP3',
#  'MCT4',
#  'ESA',
#  'J2',
#  'TC-1',
#  'USP17',
#  'EIF2',
#  'PAS-2',
#  'TMSNB',
#  'MGC15397',
#  'DVL',
#  'SAE2',
#  'GOLGA8F',
#  'HPIP',
#  'MADA',
#  'CRT1',
#  'FRP',
#  'PHERS',
#  'TCRAV30S1',
#  'GLUD1',
#  'LTBP3',
#  'PAC1',
#  'PACT',
#  'CRP',
#  'GS',
#  'SSA',
#  'CV2',
#  'TRR-CCG1-1',
#  'GSG1',
#  'ADF',
#  'CAC',
#  'GLUR3',
#  'N2N',
#  'CT58',
#  'SEMAL',
#  'HB1',
#  'TRX-CAT1-2',
#  'PHS2',
#  'MK2',
#  'MED',
#  'PPOX',
#  'HCGB',
#  'ZNF475',
#  'PIG-U',
#  'K13',
#  'L1',
#  'TRG-GCC2-2',
#  'TRB2',
#  'C10ORF44',
#  'ADHR',
#  'CPTI-M',
#  'KIR2DS5',
#  'OR7E75P',
#  'CKB',
#  'PTC',
#  'L15',
#  'RAY',
#  'U3B2',
#  'RPL13',
#  'T2',
#  'RCK',
#  'GPIV',
#  'PSBG-11',
#  'G3PP',
#  'TCRAV19S1',
#  'SCG3',
#  'SSF-1',
#  'TCRAV24S1',
#  'DOC2',
#  'EP2',
#  'MRP6',
#  'UBC',
#  'PRG-3',
#  'T2D',
#  'NACT',
#  'NAT5',
#  'MASK',
#  'CRABP-I',
#  'TN-C',
#  'HAP1',
#  'TGS1',
#  'C11ORF48',
#  'PLGLA',
#  'CT5.2',
#  'FAME3',
#  'JP2',
#  'INFE1',
#  'NIFU',
#  'FCGR3',
#  'US2',
#  'ZNF422',
#  'GLUT6',
#  'LPP2',
#  'PRR34-AS1',
#  'TCI',
#  'MRP7',
#  'DEF6',
#  'RMP',
#  'P75',
#  'SAT2',
#  'MINERVA',
#  'AT2',
#  'FAM90A18P',
#  'RAR2',
#  'UGT1-03',
#  'CD85',
#  'HIST1H2BF',
#  'SCAR1',
#  'YMR292W',
#  'CDD',
#  'PC',
#  'ACRP',
#  'LAMP',
#  'SST1',
#  'ERIS',
#  'T1',
#  'S31III125',
#  'GAL-NAC6S',
#  'TFIIF',
#  'C16DUPP11.2',
#  'PDZK4',
#  'NEP',
#  'FHL1',
#  'PTAR',
#  'OCTD',
#  'IGNT',
#  'BHLHE38',
#  'ACTL6',
#  'HDMX',
#  'SS',
#  'NT',
#  'OCC1',
#  'YDR084C',
#  'STAG3L3',
#  'ALF',
#  'SNT2',
#  'HAP2',
#  'RPL36A',
#  'HNRNPCL3',
#  'STAG1',
#  'GPR89',
#  'GR3',
#  'STIP',
#  'FRP-2',
#  'GOLGA5',
#  'LGTN',
#  'P21',
#  'PTMA',
#  'EBS1',
#  'GUP1',
#  'CSS3',
#  'ZNF225',
#  'KLK6',
#  'SCCMS',
#  'CT4.8',
#  'MYM',
#  'H4C1',
#  'HBH',
#  'NTT',
#  'ACP1',
#  'OCT-4',
#  'TSARG1',
#  ...}

# %%
len(ambiguous_symbol_set)
# Out:
# 5069

# %% [markdown]
# ### How many of the interaction queries using genes included an ambiguous symbol?

# %%
data["ambiguous_gene_in_query"] = data.genes.apply(lambda x: x & ambiguous_symbol_set)
data_df = data[data.ambiguous_gene_in_query != set()]
data_df
# Out:
#                               time request_num  \
# 17     2023-04-03T21:41:46.386524      #112476
# 18     2023-04-03T21:41:56.047208      #112476
# 19     2023-04-03T21:41:57.140781      #112476
# 20     2023-04-03T21:42:17.482316      #112476
# 21     2023-04-03T21:42:27.478590      #112476
# ...                            ...         ...
# 23036   2023-04-16T01:17:14.363678      #37959
# 23056   2023-04-16T01:17:19.774606      #37959
# 23064   2023-04-16T01:17:35.989923      #37959
# 23065   2023-04-16T01:17:36.045976      #37959
# 23068   2023-04-16T01:17:37.637435      #37959
#
#                                        uuid method                       path  \
# 17     58e2f514-3c72-470c-9249-323d8c9bb081   POST  /api/v2/interactions.json
# 18     fc4d3f38-9a45-4a1e-8572-ca7b789b34a4   POST  /api/v2/interactions.json
# 19     88cb7915-5e7b-4807-9dfc-bdc77e8574f4   POST  /api/v2/interactions.json
# 20     44602b18-ff6b-4c05-934e-71914d0080e6   POST  /api/v2/interactions.json
# 21     6269711b-ec6b-4067-9d03-904711e64451   POST  /api/v2/interactions.json
# ...                                     ...    ...                        ...
# 23036  c83f3204-ff8a-46b9-976d-dfb0db6b9e62    GET  /api/v2/interactions.json
# 23056  924bbe55-47a8-4b48-b0e5-8d06be1d4c87    GET  /api/v2/interactions.json
# 23064  96b8aa02-0862-4b29-bba9-40934aa1caaa    GET  /api/v2/interactions.json
# 23065  385d79d5-7991-4b4b-ad6e-aeb0886c77a0    GET  /api/v2/interactions.json
# 23068  3e9c38bc-c066-46b6-a174-064702deb2a8    GET  /api/v2/interactions.json
#
#       format            controller        action  status  duration      view  \
# 17      json  ServicesV2Controller  interactions     200   9202.31   8841.23
# 18      json  ServicesV2Controller  interactions     200   9223.01   8844.45
# 19      json  ServicesV2Controller  interactions     200    213.81      1.15
# 20      json  ServicesV2Controller  interactions     200   9401.45   9043.04
# 21      json  ServicesV2Controller  interactions     200   9494.68   9129.97
# ...      ...                   ...           ...     ...       ...       ...
# 23036   json  ServicesV2Controller  interactions     200    516.33    433.78
# 23056   json  ServicesV2Controller  interactions     200     50.15     11.97
# 23064   json  ServicesV2Controller  interactions     200  15158.28  14676.73
# 23065   json  ServicesV2Controller  interactions     200     53.55     13.20
# 23068   json  ServicesV2Controller  interactions     200   1272.06   1162.75
#
#            db                                             params location  \
# 17     308.21  {'genes': 'TNF,AP1,AP2,XYZA', 'interaction_sou...      NaN
# 18     312.74  {'genes': 'TNF,AP1,AP2,XYZA', 'interaction_sou...      NaN
# 19     135.14  {'genes': 'TNF,AP1,AP2,XYZA', 'interaction_sou...      NaN
# 20     305.14  {'genes': 'TNF,AP1,AP2,XYZA', 'interaction_sou...      NaN
# 21     312.85  {'genes': 'TNF,AP1,AP2,XYZA', 'interaction_sou...      NaN
# ...       ...                                                ...      ...
# 23036   70.57        {'genes': 'RPL41P5,RPL13,PTPRR,PEBP1,MYL5'}      NaN
# 23056   26.96        {'genes': 'TUBGCP2,RBM7,KMT2B,MRPL33,LDB1'}      NaN
# 23064  439.61           {'genes': 'POLH,NPM1P2,MT-TL2,MSK9,MPI'}      NaN
# 23065   28.44        {'genes': 'CLIP1,RN7SL5P,RBMY1C,PVR,QSOX1'}      NaN
# 23068   94.18        {'genes': 'PTHLH,MTCP1,ITGAM,IDDM9,HSD3B2'}      NaN
#
#       error   type                                 genes  \
# 17      NaN  genes                 {AP1, TNF, XYZA, AP2}
# 18      NaN  genes                 {AP1, TNF, XYZA, AP2}
# 19      NaN  genes                 {AP1, TNF, XYZA, AP2}
# 20      NaN  genes                 {AP1, TNF, XYZA, AP2}
# 21      NaN  genes                 {AP1, TNF, XYZA, AP2}
# ...     ...    ...                                   ...
# 23036   NaN  genes  {MYL5, RPL41P5, RPL13, PTPRR, PEBP1}
# 23056   NaN  genes  {KMT2B, MRPL33, RBM7, LDB1, TUBGCP2}
# 23064   NaN  genes     {MPI, POLH, MSK9, MT-TL2, NPM1P2}
# 23065   NaN  genes  {RN7SL5P, QSOX1, RBMY1C, CLIP1, PVR}
# 23068   NaN  genes  {PTHLH, HSD3B2, ITGAM, IDDM9, MTCP1}
#
#       ambiguous_gene_in_query
# 17                      {AP2}
# 18                      {AP2}
# 19                      {AP2}
# 20                      {AP2}
# 21                      {AP2}
# ...                       ...
# 23036                 {RPL13}
# 23056                  {LDB1}
# 23064             {POLH, MPI}
# 23065                {RBMY1C}
# 23068                 {MTCP1}
#
# [4033 rows x 18 columns]

# %%
num_interaction_queries_with_ambig_symbols = len(data_df)
num_interaction_queries_with_ambig_symbols
# Out:
# 4033

# %% [markdown]
# ### Of the total gene terms searched, how many were ambiguous gene symbols?

# %%
total_sum = 0

for key, value in gene_counts.items():
    if key in ambiguous_symbol_set:
        total_sum += value

# %%
num_queried_gene_terms_ambig = total_sum
num_queried_gene_terms_ambig
# Out:
# 8570

# %% [markdown]
# ### Of the unique gene symbols queried, how many are ambiguous?

# %%
filtered_dict = {key: value for key, value in gene_counts.items() if key in ambiguous_symbol_set}

ambiguous_symbol_queries_df = pd.DataFrame(
    list(filtered_dict.items()), columns=["Ambiguous Symbol", "# of Queries"]
)

ambiguous_symbol_queries_df = ambiguous_symbol_queries_df.sort_values(by="# of Queries", ascending=False)

ambiguous_symbol_queries_df.to_csv("../output/ambiguous_symbol_queries.csv", index=False)

# %%
num_unique_gene_symbols_queried_ambig = len(ambiguous_symbol_queries_df)
num_unique_gene_symbols_queried_ambig
# Out:
# 1431

# %% [markdown]
# ### Summary

# %%
title = [
    "# Interaction Queries using Genes",
    "# Terms as Genes for Queries",
    "# Unique Gene Symbols Queried",
]
summary_data = {
    "": [num_interaction_queries_using_genes, num_queried_gene_terms, num_unique_gene_symbols_queried],
    "# Ambiguous Symbols": [f"{num_interaction_queries_with_ambig_symbols} ({((num_interaction_queries_with_ambig_symbols/num_interaction_queries_using_genes)*100):.2f}%)", f"{num_queried_gene_terms_ambig} ({((num_queried_gene_terms_ambig/num_queried_gene_terms)*100):.2f}%)",f"{num_unique_gene_symbols_queried_ambig} ({((num_unique_gene_symbols_queried_ambig/num_unique_gene_symbols_queried)*100):.2f}%)"],
}
summary_df = pd.DataFrame(summary_data, index=title)
summary_df
# Out:
#                                           # Ambiguous Symbols
# # Interaction Queries using Genes   23070       4033 (17.48%)
# # Terms as Genes for Queries       188832        8570 (4.54%)
# # Unique Gene Symbols Queried       43400        1431 (3.30%)
