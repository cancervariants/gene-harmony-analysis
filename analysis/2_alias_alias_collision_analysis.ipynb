# %% [markdown]
# **Table of contents**<a id='toc0_'></a>
# - [ENSG](#toc1_)
#     - [How many total unique gene records are there in Ensembl](#toc1_1_1_)
#     - [Identify alias-alias collision symbols](#toc1_1_2_)
# - [HGNC](#toc2_)
#     - [How many total unique gene records are there in HGNC](#toc2_1_1_)
#     - [Identify alias-alias collision symbols](#toc2_1_2_)
# - [NCBI Info](#toc3_)
#     - [How many total unique gene records are there in NCBI Gene](#toc3_1_1_)
#     - [Identify alias-alias collision symbols](#toc3_1_2_)
# - [Merge to create Alias-Alias Collision Table- On Primary Gene Symbol](#toc4_)
# - [Merge to create Alias-Alias Collision Table- On Alias Symbol](#toc5_)
#
# <!-- vscode-jupyter-toc-config
# 	numbering=false
# 	anchor=true
# 	flat=false
# 	minLevel=1
# 	maxLevel=6
# 	/vscode-jupyter-toc-config -->
# <!-- THIS CELL WILL BE REPLACED ON TOC UPDATE. DO NOT WRITE YOUR TEXT IN THIS CELL -->

# %%
import pandas as pd

# %%
def create_aa_collision_df(subset_genes_xxxx_df: pd.DataFrame, merged_alias_xxxx_df: pd.DataFrame, source: str, case_sensitive: bool = False) -> pd.DataFrame:
    """
    Create a DataFrame of alias-alias collision symbols.

    :param subset_genes_xxxx_df: Processed df of gene records (one alias per row, no records without aliases)
    :param merged_alias_xxxx_df: Merged alias df for post-processing enrichment
    :param source: Representation of the gene source ('HGNC', 'NCBI', 'ENSG')
    :param case_sensitive: Whether alias matching is case-sensitive
    :return: A df of genes that share an alias with another gene
    """

    # Normalize alias symbols if not case-sensitive
    if not case_sensitive:
        subset_genes_xxxx_df["alias_symbol_upper"] = subset_genes_xxxx_df["alias_symbol"].str.upper()
        alias_col = "alias_symbol_upper"
    else:
        alias_col = "alias_symbol"

    # Find alias symbols used by multiple different genes
    dup_alias = (
        subset_genes_xxxx_df.groupby(alias_col)["primary_gene_symbol"]
        .nunique()
        .reset_index()
    )
    dup_alias = dup_alias[dup_alias["primary_gene_symbol"] > 1][alias_col]

    # Filter for rows with those duplicate aliases
    aa_collision_xxxx_df = subset_genes_xxxx_df[
        subset_genes_xxxx_df[alias_col].isin(dup_alias)
    ].copy()

    # Rename column to 'collision' and clean up temp column
    aa_collision_xxxx_df = aa_collision_xxxx_df.rename(columns={"alias_symbol": "collision"})
    if not case_sensitive:
        aa_collision_xxxx_df = aa_collision_xxxx_df.drop("alias_symbol_upper", axis=1)

    # Sort and tag by source
    aa_collision_xxxx_df = aa_collision_xxxx_df.sort_values("collision")
    aa_collision_xxxx_df["source"] = str(source)

    # Save single alias collision output
    aa_collision_xxxx_df.to_csv(f'../output/single_alias_aa_collision_{source.lower()}_df.csv', index=False)

    # Prepare for merged output
    columns_map = {
        "ENSG": ["NCBI_ID", "HGNC_ID"],
        "HGNC": ["NCBI_ID", "ENSG_ID"],
        "NCBI": ["HGNC_ID", "ENSG_ID"]
    }
    cols_of_interest = columns_map.get(source, [])

    merged_alias_aa_collision_xxxx_df = aa_collision_xxxx_df.drop(columns=cols_of_interest)

    merged_alias_aa_collision_xxxx_df = pd.merge(
        merged_alias_aa_collision_xxxx_df,
        merged_alias_xxxx_df[[f"{source}_ID"] + cols_of_interest + ["alias_symbol"]],
        on=f"{source}_ID",
        how="left"
    )

    # Save merged alias output
    merged_alias_aa_collision_xxxx_df.to_csv(
        f'../output/merged_alias_aa_collision_{source.lower()}_df.csv', index=False
    )

    return merged_alias_aa_collision_xxxx_df.head()

# %% [markdown]
# # <a id='toc1_'></a>[ENSG](#toc0_)

# %%
mini_ensg_df = pd.read_csv(
    "../output/mini_ensg_df.csv")

# %%
subset_genes_ensg_df = pd.read_csv(
    "../output/subset_genes_ensg_df.csv")

# %%
merged_alias_ensg_df = pd.read_csv(
    "../output/merged_alias_ensg_df.csv")

# %% [markdown]
# ### <a id='toc1_1_1_'></a>[How many total unique gene records are there in Ensembl](#toc0_)

# %%
gene_record_set_ensg = set(mini_ensg_df['ENSG_ID'])
gene_record_count_ensg = len(gene_record_set_ensg)
gene_record_count_ensg
# Out:
# 48401

# %% [markdown]
# ADTAB is not a collision

# %%
mini_ensg_df.loc[mini_ensg_df["alias_symbol"] == "ADTAB"]
# Out:
#                ENSG_ID      NCBI_ID   HGNC_ID alias_symbol primary_gene_symbol
# 25020  ENSG00000281385  GENE ID:161  HGNC:562        ADTAB               AP2A2
# 25325  ENSG00000280759  GENE ID:161  HGNC:562        ADTAB               AP2A2
# 73733  ENSG00000183020  GENE ID:161  HGNC:562        ADTAB               AP2A2

# %% [markdown]
# A3GALNT is a collision between ABO and GBGT1 *not* ABO and ABO

# %%
a3galnt_example_df = mini_ensg_df.loc[mini_ensg_df["alias_symbol"] == "A3GALNT"]
a3galnt_example_df
# Out:
#                ENSG_ID        NCBI_ID     HGNC_ID alias_symbol  \
# 11282  ENSG00000281879     GENE ID:28     HGNC:79      A3GALNT
# 29578  ENSG00000148288  GENE ID:26301  HGNC:20460      A3GALNT
# 29711  ENSG00000175164     GENE ID:28     HGNC:79      A3GALNT
#
#       primary_gene_symbol
# 11282                 ABO
# 29578               GBGT1
# 29711                 ABO

# %% [markdown]
# ### <a id='toc1_1_2_'></a>[Identify alias-alias collision symbols](#toc0_)

# %%
create_aa_collision_df(subset_genes_ensg_df, merged_alias_ensg_df, source="ENSG")
# Out:
#            ENSG_ID collision primary_gene_symbol source        NCBI_ID  \
# 0  ENSG00000139187       2F1               KLRG1   ENSG  GENE ID:10219
# 1  ENSG00000005022       2F1             SLC25A5   ENSG    GENE ID:292
# 2  ENSG00000163220    60B8AG              S100A9   ENSG   GENE ID:6280
# 3  ENSG00000143546    60B8AG              S100A8   ENSG   GENE ID:6279
# 4  ENSG00000206832      87U6               RNU6V   ENSG            NaN
#
#       HGNC_ID                                       alias_symbol
# 0   HGNC:6380                            2F1,CLEC15A,MAFA,MAFA-L
# 1  HGNC:10991                                     2F1,ANT2,T2,T3
# 2  HGNC:10499  60B8AG,CAGB,CFAG,CGLB,LIAG,MAC387,MIF,MRP-14,M...
# 3  HGNC:10498        60B8AG,CAGA,CFAG,CGLA,MRP-8,MRP8,P8,S100-A8
# 4  HGNC:10230                                          87U6,LH87

# %%
aa_collision_ensg_df = pd.read_csv(
    "../output/single_alias_aa_collision_ensg_df.csv")

# %%
merged_alias_aa_collision_ensg_df = pd.read_csv(
    "../output/merged_alias_aa_collision_ensg_df.csv")

# %%
aa_collision_ensg_df.loc[aa_collision_ensg_df["collision"] == "ADTAB"]
# Out:
# Empty DataFrame
# Columns: [ENSG_ID, NCBI_ID, HGNC_ID, collision, primary_gene_symbol, source]
# Index: []

# %% [markdown]
# How many ambiguous symbols result from alias-alias collisions?

# %%
aa_collision_ambiguous_symbol_set_ensg = set(merged_alias_aa_collision_ensg_df["collision"])
aa_collision_ambiguous_symbol_count_ensg = len(aa_collision_ambiguous_symbol_set_ensg)
aa_collision_ambiguous_symbol_count_ensg
# Out:
# 1617

# %% [markdown]
# How many records have at least one alias-alias collision (alias that matches another record's alias gene symbol)?

# %%
aa_record_set_ensg = set(merged_alias_aa_collision_ensg_df["ENSG_ID"])
aa_record_count_ensg = len(aa_record_set_ensg)
aa_record_count_ensg
# Out:
# 3784

# %% [markdown]
# # <a id='toc2_'></a>[HGNC](#toc0_)

# %%
mini_hgnc_df = pd.read_csv(
    "../output/mini_hgnc_df.csv"
)

# %%
subset_genes_hgnc_df = pd.read_csv(
    "../output/subset_genes_hgnc_df.csv")

# %%
merged_alias_hgnc_df = pd.read_csv(
    "../output/merged_alias_hgnc_df.csv")

# %% [markdown]
# ### <a id='toc2_1_2_'></a>[Identify alias-alias collision symbols](#toc0_)

# %%
create_aa_collision_df(subset_genes_hgnc_df, merged_alias_hgnc_df, source="HGNC")
# Out:
#       HGNC_ID primary_gene_symbol collision source        NCBI_ID  \
# 0  HGNC:10991             SLC25A5       2F1   HGNC    GENE ID:292
# 1   HGNC:6380               KLRG1       2F1   HGNC  GENE ID:10219
# 2  HGNC:10499              S100A9    60B8AG   HGNC   GENE ID:6280
# 3  HGNC:10498              S100A8    60B8AG   HGNC   GENE ID:6279
# 4  HGNC:10230               RNU6V      87U6   HGNC   GENE ID:6071
#
#            ENSG_ID                                       alias_symbol
# 0  ENSG00000005022                                          2F1,T2,T3
# 1  ENSG00000139187                            2F1,CLEC15A,MAFA,MAFA-L
# 2  ENSG00000163220  60B8AG,CGLB,LIAG,MAC387,MIF,MRP-14,MRP14,NIF,P...
# 3  ENSG00000143546                  60B8AG,CGLA,MRP-8,MRP8,P8,S100-A8
# 4  ENSG00000206832                                          87U6,LH87

# %%
merged_alias_aa_collision_hgnc_df = pd.read_csv(
    "../output/merged_alias_aa_collision_hgnc_df.csv")

# %% [markdown]
# How many ambiguous symbols result from alias-alias collisions?

# %%
aa_collision_ambiguous_symbol_set_hgnc = set(merged_alias_aa_collision_hgnc_df["collision"])
aa_collision_ambiguous_symbol_count_hgnc = len(aa_collision_ambiguous_symbol_set_hgnc)
aa_collision_ambiguous_symbol_count_hgnc
# Out:
# 1458

# %% [markdown]
# How many records have at least one alias-alias collision (alias that matches another record's alias gene symbol)?

# %%
aa_record_set_hgnc = set(merged_alias_aa_collision_hgnc_df["HGNC_ID"])
aa_record_count_hgnc = len(aa_record_set_hgnc)
aa_record_count_hgnc
# Out:
# 2482

# %% [markdown]
# # <a id='toc3_'></a>[NCBI Info](#toc0_)

# %%
mini_ncbi_df = pd.read_csv(
    "../output/mini_ncbi_df.csv")

# %%
subset_genes_ncbi_df = pd.read_csv(
    "../output/subset_genes_ncbi_df.csv")

# %%
merged_alias_ncbi_df = pd.read_csv(
    "../output/merged_alias_ncbi_df.csv")

# %% [markdown]
# ### <a id='toc3_1_2_'></a>[Identify alias-alias collision symbols](#toc0_)

# %%
create_aa_collision_df(subset_genes_ncbi_df, merged_alias_ncbi_df, source="NCBI")
# Out:
#         NCBI_ID primary_gene_symbol     collision       gene_type source  \
# 0   GENE ID:657              BMPR1A      10q23del  protein-coding   NCBI
# 1  GENE ID:5728                PTEN      10q23del  protein-coding   NCBI
# 2   GENE ID:239              ALOX12        12-LOX  protein-coding   NCBI
# 3   GENE ID:246              ALOX15        12-LOX  protein-coding   NCBI
# 4  GENE ID:1645              AKR1C1  20-ALPHA-HSD  protein-coding   NCBI
#
#      HGNC_ID          ENSG_ID  \
# 0  HGNC:1076  ENSG00000107779
# 1  HGNC:9588  ENSG00000171862
# 2   HGNC:429  ENSG00000108839
# 3   HGNC:433  ENSG00000161905
# 4   HGNC:384  ENSG00000187134
#
#                                         alias_symbol
# 0     10q23del,ACVRLK3,ALK-3,ALK3,BMPR-1A,CD292,SKR5
# 1  10q23del,BZS,CWS1,DEC,GLM2,MHAM,MMAC1,PTEN1,PT...
# 2                               12-LOX,12S-LOX,LOG12
# 3                       12-LOX,15-LOX,15-LOX-1,LOG15
# 4  2-ALPHA-HSD,20-ALPHA-HSD,C9,DD1,DD1/DD2,DDH,DD...

# %%
merged_alias_aa_collision_ncbi_df = pd.read_csv(
    "../output/merged_alias_aa_collision_ncbi_df.csv")

# %% [markdown]
# How many ambiguous symbols result from alias-alias collisions?

# %%
aa_collision_ambiguous_symbol_set_ncbi = set(merged_alias_aa_collision_ncbi_df["collision"])
aa_collision_ambiguous_symbol_count_ncbi = len(aa_collision_ambiguous_symbol_set_ncbi)
aa_collision_ambiguous_symbol_count_ncbi
# Out:
# 4031

# %% [markdown]
# How many records have at least one alias-alias collision (alias that matches another record's alias gene symbol)?

# %%
aa_record_set_ncbi = set(merged_alias_aa_collision_ncbi_df["NCBI_ID"])
aa_record_count_ncbi = len(aa_record_set_ncbi)
aa_record_count_ncbi
# Out:
# 5964

# %% [markdown]
# # <a id='toc4_'></a>[Merge to create Alias-Alias Collision Table- On Primary Gene Symbol](#toc0_)

# %%
merged_aa_collision_gene_df = pd.concat(
    [
        merged_alias_aa_collision_hgnc_df[["primary_gene_symbol", "alias_symbol", "collision", "source", "ENSG_ID", "HGNC_ID", "NCBI_ID"]],
        merged_alias_aa_collision_ncbi_df[["primary_gene_symbol", "alias_symbol", "collision", "source", "ENSG_ID", "HGNC_ID", "NCBI_ID"]],
        merged_alias_aa_collision_ensg_df[["primary_gene_symbol", "alias_symbol", "collision", "source", "ENSG_ID", "HGNC_ID", "NCBI_ID"]],
    ]
)
merged_aa_collision_gene_df
# Out:
#      primary_gene_symbol                                       alias_symbol  \
# 0                SLC25A5                                          2F1,T2,T3
# 1                  KLRG1                            2F1,CLEC15A,MAFA,MAFA-L
# 2                 S100A9  60B8AG,CGLB,LIAG,MAC387,MIF,MRP-14,MRP14,NIF,P...
# 3                 S100A8                  60B8AG,CGLA,MRP-8,MRP8,P8,S100-A8
# 4                  RNU6V                                          87U6,LH87
# ...                  ...                                                ...
# 4727             SLC30A8                                         ZNT-8,ZNT8
# 4728             SLC30A1                                          ZNT1,ZRC1
# 4729            SLC30A10                DKFZP547M236,ZNT-10,ZNT10,ZNT8,ZRC1
# 4730              ZYG11A                                              ZYG11
# 4731              ZYG11B                                     FLJ13456,ZYG11
#
#      collision source          ENSG_ID     HGNC_ID         NCBI_ID
# 0          2F1   HGNC  ENSG00000005022  HGNC:10991     GENE ID:292
# 1          2F1   HGNC  ENSG00000139187   HGNC:6380   GENE ID:10219
# 2       60B8AG   HGNC  ENSG00000163220  HGNC:10499    GENE ID:6280
# 3       60B8AG   HGNC  ENSG00000143546  HGNC:10498    GENE ID:6279
# 4         87U6   HGNC  ENSG00000206832  HGNC:10230    GENE ID:6071
# ...        ...    ...              ...         ...             ...
# 4727      ZNT8   ENSG  ENSG00000164756  HGNC:20303  GENE ID:169026
# 4728      ZRC1   ENSG  ENSG00000170385  HGNC:11012    GENE ID:7779
# 4729      ZRC1   ENSG  ENSG00000196660  HGNC:25355   GENE ID:55532
# 4730     ZYG11   ENSG  ENSG00000203995  HGNC:32058  GENE ID:440590
# 4731     ZYG11   ENSG  ENSG00000162378  HGNC:25820   GENE ID:79699
#
# [16351 rows x 7 columns]

# %%
merged_aa_collision_gene_df.to_csv(
    "../output/merged_aa_collision_gene_df.csv", index=False)

# %%
merged_aa_collision_gene_df.loc[merged_aa_collision_gene_df.collision == "U3B2"]
# Out:
#      primary_gene_symbol          alias_symbol collision source  \
# 4602           SNORD3B-1  RNU3A1,U3A,U3B1,U3B2      U3B2   ENSG
# 4603           SNORD3B-2            U3-2B,U3B2      U3B2   ENSG
#
#               ENSG_ID     HGNC_ID NCBI_ID
# 4602  ENSG00000265185  HGNC:10168     NaN
# 4603  ENSG00000262074  HGNC:33190     NaN
