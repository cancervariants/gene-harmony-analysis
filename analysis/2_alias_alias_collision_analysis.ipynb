# %% [markdown]
# **Table of contents**<a id='toc0_'></a>
# - [ENSG](#toc1_)
#     - [How many total unique gene records are there in Ensembl](#toc1_1_1_)
#     - [Identify alias-alias collision symbols](#toc1_1_2_)
# - [HGNC](#toc2_)
#     - [How many total unique gene records are there in HGNC](#toc2_1_1_)
#     - [Identify alias-alias collision symbols](#toc2_1_2_)
# - [NCBI Info](#toc3_)
#     - [How many total unique gene records are there in NCBI Gene](#toc3_1_1_)
#     - [Identify alias-alias collision symbols](#toc3_1_2_)
# - [Merge to create Alias-Alias Collision Table- On Primary Gene Symbol](#toc4_)
# - [Merge to create Alias-Alias Collision Table- On Alias Symbol](#toc5_)
#
# <!-- vscode-jupyter-toc-config
# 	numbering=false
# 	anchor=true
# 	flat=false
# 	minLevel=1
# 	maxLevel=6
# 	/vscode-jupyter-toc-config -->
# <!-- THIS CELL WILL BE REPLACED ON TOC UPDATE. DO NOT WRITE YOUR TEXT IN THIS CELL -->

# %%
import pandas as pd
import numpy as np
import plotly.express as px

# %%
# def create_aa_collision_df(subset_genes_xxxx_df: pd.DataFrame, merged_alias_xxxx_df: pd.DataFrame, source: str) -> pd.DataFrame:
#     """ CASE INSENSITIVE COLLISIONS
#     Create a df of alias-alias collision symbols 

#     :param subset_genes_xxxx_df: Processed df of gene records
#     :param source: Representation of the source of the gene records
#     :return: A df of genes that share an alias with another gene
#     """

#     dup_alias = subset_genes_xxxx_df.copy()
#     dup_alias = dup_alias.dropna(subset=["alias_symbol"])
#     dup_alias["alias_symbol_upper"] = dup_alias["alias_symbol"].str.upper()

#     #Find alias_symbols that are shared by multiple different gene_symbols
#     dup_alias = (
#         dup_alias.groupby('alias_symbol_upper')['gene_symbol']
#         .nunique()
#         .reset_index()
#     )
#     #Keep only alias_symbols linked to more than one gene
#     dup_alias = dup_alias[dup_alias['gene_symbol'] > 1]['alias_symbol_upper']

#     #Filter the original df for those alias collisions
#     aa_collision_xxxx_df = subset_genes_xxxx_df.copy()
#     aa_collision_xxxx_df["alias_symbol_upper"] = aa_collision_xxxx_df["alias_symbol"].str.upper()
#     aa_collision_xxxx_df = aa_collision_xxxx_df[aa_collision_xxxx_df['alias_symbol_upper'].isin(dup_alias)]
#     aa_collision_xxxx_df = aa_collision_xxxx_df.rename(
#     columns={"alias_symbol_upper": "collision"})
#     aa_collision_xxxx_df = aa_collision_xxxx_df.drop("alias_symbol", axis=1)

#     aa_collision_xxxx_df = aa_collision_xxxx_df.sort_values("collision")

#     #Add a source tag for future merging efforts
#     aa_collision_xxxx_df["source"] = str(source)
#     aa_collision_xxxx_df.to_csv(f'../output/single_alias_aa_collision_{source.lower()}_df.csv', index=True)

#     #Create a secondary collision df that merges the alias symbols for each record
#     columns_map = {
#     'ENSG': ['NCBI_ID', 'HGNC_ID'],
#     'HGNC': ['NCBI_ID', 'ENSG_ID'],
#     'NCBI': ['HGNC_ID', 'ENSG_ID']
#     }
#     cols_of_interest = columns_map.get(source, [])

#     merged_alias_aa_collision_xxxx_df = aa_collision_xxxx_df.drop(columns=cols_of_interest)

#     merged_alias_aa_collision_xxxx_df = pd.merge(
#         merged_alias_aa_collision_xxxx_df,
#         merged_alias_xxxx_df[[f"{source}_ID"] + cols_of_interest + ['alias_symbol']],
#         on=[f"{source}_ID"],
#         how="left"
#     )
#     #Convert the df into a csv
#     merged_alias_aa_collision_xxxx_df.to_csv(f'../output/merged_alias_aa_collision_{source.lower()}_df.csv', index=True)

#     return merged_alias_aa_collision_xxxx_df.head()

# %%
def create_aa_collision_df(subset_genes_xxxx_df: pd.DataFrame, merged_alias_xxxx_df: pd.DataFrame, source: str) -> pd.DataFrame:
    """CASE SENSITIVE COLLISIONS
    Create a df of alias-alias collision symbols 

    :param subset_genes_xxxx_df: Processed df of gene records
    :param source: Representation of the source of the gene records
    :return: A df of genes that share an alias with another gene
    """
    #Find alias_symbols that are shared by multiple different gene_symbols
    dup_alias = (
        subset_genes_xxxx_df.groupby('alias_symbol')['gene_symbol']
        .nunique()
        .reset_index()
    )
    #Keep only alias_symbols linked to more than one gene
    dup_alias = dup_alias[dup_alias['gene_symbol'] > 1]['alias_symbol']

    #Filter the original df for those alias collisions
    aa_collision_xxxx_df = subset_genes_xxxx_df[subset_genes_xxxx_df['alias_symbol'].isin(dup_alias)].copy()
    aa_collision_xxxx_df = aa_collision_xxxx_df.rename(
    columns={"alias_symbol": "collision"})

    aa_collision_xxxx_df = aa_collision_xxxx_df.sort_values("collision")

    #Add a source tag for future merging efforts
    aa_collision_xxxx_df["source"] = str(source)
    aa_collision_xxxx_df.to_csv(f'../output/single_alias_aa_collision_{source.lower()}_df.csv', index=True)

    #Create a secondary collision df that merges the alias symbols for each record
    columns_map = {
    'ENSG': ['NCBI_ID', 'HGNC_ID'],
    'HGNC': ['NCBI_ID', 'ENSG_ID'],
    'NCBI': ['HGNC_ID', 'ENSG_ID']
    }
    cols_of_interest = columns_map.get(source, [])

    merged_alias_aa_collision_xxxx_df = aa_collision_xxxx_df.drop(columns=cols_of_interest)

    merged_alias_aa_collision_xxxx_df = pd.merge(
        merged_alias_aa_collision_xxxx_df,
        merged_alias_xxxx_df[[f"{source}_ID"] + cols_of_interest + ['alias_symbol']],
        on=[f"{source}_ID"],
        how="left"
    )
    #Convert the df into a csv
    merged_alias_aa_collision_xxxx_df.to_csv(f'../output/merged_alias_aa_collision_{source.lower()}_df.csv', index=True)

    return merged_alias_aa_collision_xxxx_df.head()

# %% [markdown]
# # <a id='toc1_'></a>[ENSG](#toc0_)

# %%
mini_ensg_df = pd.read_csv(
    "../output/mini_ensg_df.csv", index_col=0
)

# %%
subset_genes_ensg_df = pd.read_csv(
    "../output/subset_genes_ensg_df.csv", index_col=[0])

# %%
merged_alias_ensg_df = pd.read_csv(
    "../output/merged_alias_ensg_df.csv", index_col=[0])

# %% [markdown]
# ### <a id='toc1_1_1_'></a>[How many total unique gene records are there in Ensembl](#toc0_)

# %%
gene_record_set_ensg = set(mini_ensg_df['ENSG_ID'])
gene_record_count_ensg = len(gene_record_set_ensg)
gene_record_count_ensg
# Out:
# 48401

# %%
dup_alias = subset_genes_ensg_df.copy()
dup_alias = dup_alias.dropna(subset=["alias_symbol"])
dup_alias["alias_symbol_upper"] = dup_alias["alias_symbol"].str.upper()

#Find alias_symbols that are shared by multiple different gene_symbols
dup_alias = (
    dup_alias.groupby('alias_symbol_upper')['gene_symbol']
    .nunique()
    .reset_index()
)
#Keep only alias_symbols linked to more than one gene
dup_alias = dup_alias[dup_alias['gene_symbol'] > 1]['alias_symbol_upper']
dup_alias
# Out:
# 117         2F1
# 222      60B8AG
# 255        87U6
# 264         9G8
# 276          A1
#           ...
# 54729      ZIP4
# 54995    ZNF422
# 55250      ZNT8
# 55283      ZRC1
# 55352     ZYG11
# Name: alias_symbol_upper, Length: 1615, dtype: object

# %%
dup_alias_id = (
    subset_genes_ensg_df.groupby('alias_symbol')["ENSG_ID"]
    .nunique()
    .reset_index()
)

# %%
dup_alias_id = dup_alias_id[dup_alias_id['ENSG_ID'] > 1]

# %%
dup_alias_id.iloc[1000:1060]
# Out:
#      alias_symbol  ENSG_ID
# 8729        CIRL1        2
# 8773         CK20        2
# 8774         CK23        2
# 8788        CKB-8        2
# 8789         CKB1        9
# 8792        CKB12        2
# 8794         CKB2        7
# 8796         CKB7        3
# 8797         CKB8        2
# 8828        CKMT1        2
# 8831        CKR-1        2
# 8841         CKS1        2
# 8845     CKTSF1B1        3
# 8849        CL-11       33
# 8850         CL-2       32
# 8852        CL-39       33
# 8853        CL-42       33
# 8854        CL-43        3
# 8855        CL-49       13
# 8856         CL-5       37
# 8857         CL-6       32
# 8868         CLA1        2
# 8870        CLA20        2
# 8871        CLAMP        2
# 8872         CLAN        2
# 8880       CLAPA2        3
# 8909         CLC2        2
# 8914        CLCA3        2
# 8918       CLCNL1        7
# 8926       CLDN21        2
# 8927        CLDNL        2
# 8957     CLECSF13        2
# 8968          CLF        2
# 8971          CLG        2
# 8988        CLIM1        2
# 8993         CLIP        4
# 9011          CLM        2
# 9014         CLM7        2
# 9016         CLMF        2
# 9035          CLP        3
# 9041         CLPA        2
# 9044      CLPSMCR        2
# 9046      CLR11.1        3
# 9057      CLR19.4       10
# 9062      CLR19.9       10
# 9077         CLU1        2
# 9080         CMAH        2
# 9104         CMG1        2
# 9116         CMIR        2
# 9134       CMKRL1        2
# 9137         CML2        2
# 9147        CMPD2        2
# 9153   CMRF-35-H9        2
# 9154     CMRF-35A        2
# 9155       CMRF35        2
# 9156      CMRF35A        2
# 9157     CMRF35A4        2
# 9158      CMRF35H        2
# 9167         CMT2        2
# 9212          CN1        2

# %%
mini_ensg_df.loc[mini_ensg_df["alias_symbol"] == "ADTAB"]
# Out:
#                ENSG_ID      NCBI_ID   HGNC_ID alias_symbol gene_symbol
# 31521  ENSG00000281385  GENE ID:161  HGNC:562        ADTAB       AP2A2
# 31874  ENSG00000280759  GENE ID:161  HGNC:562        ADTAB       AP2A2
# 91841  ENSG00000183020  GENE ID:161  HGNC:562        ADTAB       AP2A2

# %%
a3galnt_example_df = mini_ensg_df.loc[mini_ensg_df["alias_symbol"] == "A3GALNT"]
a3galnt_example_df
# Out:
#                ENSG_ID        NCBI_ID     HGNC_ID alias_symbol gene_symbol
# 13817  ENSG00000281879     GENE ID:28     HGNC:79      A3GALNT         ABO
# 36875  ENSG00000148288  GENE ID:26301  HGNC:20460      A3GALNT       GBGT1
# 37023  ENSG00000175164     GENE ID:28     HGNC:79      A3GALNT         ABO

# %%
dup_alias_symbol = (
    subset_genes_ensg_df.groupby('alias_symbol')["gene_symbol"]
    .nunique()
    .reset_index()
)

# %%
#Keep only alias_symbols linked to more than one gene
dup_alias_symbol = dup_alias_symbol[dup_alias_symbol['gene_symbol'] > 1]
dup_alias_symbol
# Out:
#       alias_symbol  gene_symbol
# 117            2F1            2
# 222         60B8AG            2
# 255           87U6            2
# 264            9G8            2
# 276             A1            4
# ...            ...          ...
# 54753         ZIP4            2
# 55019       ZNF422            2
# 55274         ZNT8            2
# 55307         ZRC1            2
# 55376        ZYG11            2
#
# [1614 rows x 2 columns]

# %% [markdown]
# ### <a id='toc1_1_2_'></a>[Identify alias-alias collision symbols](#toc0_)

# %%
create_aa_collision_df(subset_genes_ensg_df, merged_alias_ensg_df, source="ENSG")
# Out:
#            ENSG_ID collision gene_symbol source        NCBI_ID     HGNC_ID  \
# 0  ENSG00000139187       2F1       KLRG1   ENSG  GENE ID:10219   HGNC:6380
# 1  ENSG00000005022       2F1     SLC25A5   ENSG    GENE ID:292  HGNC:10991
# 2  ENSG00000163220    60B8AG      S100A9   ENSG   GENE ID:6280  HGNC:10499
# 3  ENSG00000143546    60B8AG      S100A8   ENSG   GENE ID:6279  HGNC:10498
# 4  ENSG00000065135      87U6       GNAI3   ENSG   GENE ID:2773   HGNC:4387
#
#                                         alias_symbol
# 0                            2F1,CLEC15A,MAFA,MAFA-L
# 1                                     2F1,ANT2,T2,T3
# 2  60B8AG,CAGB,CFAG,CGLB,LIAG,MAC387,MIF,MRP-14,M...
# 3        60B8AG,CAGA,CFAG,CGLA,MRP-8,MRP8,P8,S100-A8
# 4                                               87U6

# %%
merged_alias_aa_collision_ensg_df = pd.read_csv(
    "../output/merged_alias_aa_collision_ensg_df.csv", index_col=[0])
merged_alias_aa_collision_ensg_df
# Out:
#               ENSG_ID collision gene_symbol source         NCBI_ID  \
# 0     ENSG00000139187       2F1       KLRG1   ENSG   GENE ID:10219
# 1     ENSG00000005022       2F1     SLC25A5   ENSG     GENE ID:292
# 2     ENSG00000163220    60B8AG      S100A9   ENSG    GENE ID:6280
# 3     ENSG00000143546    60B8AG      S100A8   ENSG    GENE ID:6279
# 4     ENSG00000065135      87U6       GNAI3   ENSG    GENE ID:2773
# ...               ...       ...         ...    ...             ...
# 4721  ENSG00000164756      ZNT8     SLC30A8   ENSG  GENE ID:169026
# 4722  ENSG00000196660      ZRC1    SLC30A10   ENSG   GENE ID:55532
# 4723  ENSG00000170385      ZRC1     SLC30A1   ENSG    GENE ID:7779
# 4724  ENSG00000162378     ZYG11      ZYG11B   ENSG   GENE ID:79699
# 4725  ENSG00000203995     ZYG11      ZYG11A   ENSG  GENE ID:440590
#
#          HGNC_ID                                       alias_symbol
# 0      HGNC:6380                            2F1,CLEC15A,MAFA,MAFA-L
# 1     HGNC:10991                                     2F1,ANT2,T2,T3
# 2     HGNC:10499  60B8AG,CAGB,CFAG,CGLB,LIAG,MAC387,MIF,MRP-14,M...
# 3     HGNC:10498        60B8AG,CAGA,CFAG,CGLA,MRP-8,MRP8,P8,S100-A8
# 4      HGNC:4387                                               87U6
# ...          ...                                                ...
# 4721  HGNC:20303                                         ZNT-8,ZNT8
# 4722  HGNC:25355                DKFZP547M236,ZNT-10,ZNT10,ZNT8,ZRC1
# 4723  HGNC:11012                                          ZNT1,ZRC1
# 4724  HGNC:25820                                     FLJ13456,ZYG11
# 4725  HGNC:32058                                              ZYG11
#
# [4726 rows x 7 columns]

# %%
merged_alias_aa_collision_ensg_df.loc[merged_alias_aa_collision_ensg_df["gene_symbol"] == "ABO"]
# Out:
#             ENSG_ID collision gene_symbol source     NCBI_ID  HGNC_ID  \
# 20  ENSG00000175164   A3GALNT         ABO   ENSG  GENE ID:28  HGNC:79
# 21  ENSG00000281879   A3GALNT         ABO   ENSG  GENE ID:28  HGNC:79
#
#        alias_symbol
# 20  A3GALNT,A3GALT1
# 21  A3GALNT,A3GALT1

# %% [markdown]
# How many ambiguous symbols result from alias-alias collisions?

# %%
aa_collision_ambiguous_symbol_set_ensg = set(merged_alias_aa_collision_ensg_df["collision"])
aa_collision_ambiguous_symbol_count_ensg = len(aa_collision_ambiguous_symbol_set_ensg)
aa_collision_ambiguous_symbol_count_ensg
# Out:
# 1614

# %% [markdown]
# How many records have at least one alias-alias collision (alias that matches another record's alias gene symbol)?

# %%
aa_record_set_ensg = set(merged_alias_aa_collision_ensg_df["ENSG_ID"])
aa_record_count_ensg = len(aa_record_set_ensg)
aa_record_count_ensg
# Out:
# 3778

# %% [markdown]
# # <a id='toc2_'></a>[HGNC](#toc0_)

# %%
mini_hgnc_df = pd.read_csv(
    "../output/mini_hgnc_df.csv"
)

# %%
subset_genes_hgnc_df = pd.read_csv(
    "../output/subset_genes_hgnc_df.csv", index_col=[0])

# %%
merged_alias_hgnc_df = pd.read_csv(
    "../output/merged_alias_hgnc_df.csv", index_col=[0])

# %% [markdown]
# ### <a id='toc2_1_2_'></a>[Identify alias-alias collision symbols](#toc0_)

# %%
create_aa_collision_df(subset_genes_hgnc_df, merged_alias_hgnc_df, source="HGNC")
# Out:
#       HGNC_ID gene_symbol collision source        NCBI_ID          ENSG_ID  \
# 0  HGNC:10991     SLC25A5       2F1   HGNC    GENE ID:292  ENSG00000005022
# 1   HGNC:6380       KLRG1       2F1   HGNC  GENE ID:10219  ENSG00000139187
# 2  HGNC:10498      S100A8    60B8AG   HGNC   GENE ID:6279  ENSG00000143546
# 3  HGNC:10499      S100A9    60B8AG   HGNC   GENE ID:6280  ENSG00000163220
# 4  HGNC:10230       RNU6V      87U6   HGNC   GENE ID:6071  ENSG00000206832
#
#                                         alias_symbol
# 0                                          2F1,T2,T3
# 1                            2F1,CLEC15A,MAFA,MAFA-L
# 2                  60B8AG,CGLA,MRP-8,MRP8,P8,S100-A8
# 3  60B8AG,CGLB,LIAG,MAC387,MIF,MRP-14,MRP14,NIF,P...
# 4                                          87U6,LH87

# %%
merged_alias_aa_collision_hgnc_df = pd.read_csv(
    "../output/merged_alias_aa_collision_hgnc_df.csv", index_col=[0])
merged_alias_aa_collision_hgnc_df
# Out:
#          HGNC_ID gene_symbol collision source         NCBI_ID  \
# 0     HGNC:10991     SLC25A5       2F1   HGNC     GENE ID:292
# 1      HGNC:6380       KLRG1       2F1   HGNC   GENE ID:10219
# 2     HGNC:10498      S100A8    60B8AG   HGNC    GENE ID:6279
# 3     HGNC:10499      S100A9    60B8AG   HGNC    GENE ID:6280
# 4     HGNC:10230       RNU6V      87U6   HGNC    GENE ID:6071
# ...          ...         ...       ...    ...             ...
# 2441  HGNC:33356     TEX28P1      pTEX   HGNC  GENE ID:728447
# 2442  HGNC:20219     PPP4R3A      smk1   HGNC   GENE ID:55671
# 2443  HGNC:33146     PPP4R3C      smk1   HGNC  GENE ID:139420
# 2444  HGNC:14681      SPATA2      tamo   HGNC    GENE ID:9825
# 2445  HGNC:28393     SPATA2L      tamo   HGNC  GENE ID:124044
#
#               ENSG_ID                                       alias_symbol
# 0     ENSG00000005022                                          2F1,T2,T3
# 1     ENSG00000139187                            2F1,CLEC15A,MAFA,MAFA-L
# 2     ENSG00000143546                  60B8AG,CGLA,MRP-8,MRP8,P8,S100-A8
# 3     ENSG00000163220  60B8AG,CGLB,LIAG,MAC387,MIF,MRP-14,MRP14,NIF,P...
# 4     ENSG00000206832                                          87U6,LH87
# ...               ...                                                ...
# 2441  ENSG00000274962                                               pTEX
# 2442  ENSG00000100796            FLFL1,FLJ20707,MSTP033,PP4R3,smk-1,smk1
# 2443  ENSG00000224960                               FLFL3P,FLJ32867,smk1
# 2444  ENSG00000158480                         KIAA0757,PD1,PPP1R145,tamo
# 2445  ENSG00000158792                                      MGC26885,tamo
#
# [2446 rows x 7 columns]

# %% [markdown]
# How many ambiguous symbols result from alias-alias collisions?

# %%
aa_collision_ambiguous_symbol_set_hgnc = set(merged_alias_aa_collision_hgnc_df["collision"])
aa_collision_ambiguous_symbol_count_hgnc = len(aa_collision_ambiguous_symbol_set_hgnc)
aa_collision_ambiguous_symbol_count_hgnc
# Out:
# 1082

# %% [markdown]
# How many records have at least one alias-alias collision (alias that matches another record's alias gene symbol)?

# %%
aa_record_set_hgnc = set(merged_alias_aa_collision_hgnc_df["HGNC_ID"])
aa_record_count_hgnc = len(aa_record_set_hgnc)
aa_record_count_hgnc
# Out:
# 2173

# %% [markdown]
# # <a id='toc3_'></a>[NCBI Info](#toc0_)

# %%
mini_ncbi_df = pd.read_csv(
    "../output/mini_ncbi_df.csv", index_col=[0]
)

# %%
subset_genes_ncbi_df = pd.read_csv(
    "../output/subset_genes_ncbi_df.csv", index_col=[0])

# %%
merged_alias_ncbi_df = pd.read_csv(
    "../output/merged_alias_ncbi_df.csv", index_col=[0])

# %% [markdown]
# ### <a id='toc3_1_2_'></a>[Identify alias-alias collision symbols](#toc0_)

# %%
create_aa_collision_df(subset_genes_ncbi_df, merged_alias_ncbi_df, source="NCBI")
# Out:
#          NCBI_ID gene_symbol collision source    HGNC_ID          ENSG_ID  \
# 0   GENE ID:5728        PTEN  10q23del   NCBI  HGNC:9588  ENSG00000171862
# 1    GENE ID:657      BMPR1A  10q23del   NCBI  HGNC:1076  ENSG00000107779
# 2    GENE ID:239      ALOX12    12-LOX   NCBI   HGNC:429  ENSG00000108839
# 3    GENE ID:246      ALOX15    12-LOX   NCBI   HGNC:433  ENSG00000161905
# 4  GENE ID:10219       KLRG1       2F1   NCBI  HGNC:6380  ENSG00000139187
#
#                                         alias_symbol
# 0  10q23del,BZS,CWS1,DEC,GLM2,MHAM,MMAC1,PTEN1,PT...
# 1     10q23del,ACVRLK3,ALK-3,ALK3,BMPR-1A,CD292,SKR5
# 2                               12-LOX,12S-LOX,LOG12
# 3                       12-LOX,15-LOX,15-LOX-1,LOG15
# 4         2F1,CLEC15A,MAFA,MAFA-2F1,MAFA-L,MAFA-LIKE

# %%
merged_alias_aa_collision_ncbi_df = pd.read_csv(
    "../output/merged_alias_aa_collision_ncbi_df.csv", index_col=[0])
merged_alias_aa_collision_ncbi_df
# Out:
#              NCBI_ID gene_symbol collision source     HGNC_ID  \
# 0       GENE ID:5728        PTEN  10q23del   NCBI   HGNC:9588
# 1        GENE ID:657      BMPR1A  10q23del   NCBI   HGNC:1076
# 2        GENE ID:239      ALOX12    12-LOX   NCBI    HGNC:429
# 3        GENE ID:246      ALOX15    12-LOX   NCBI    HGNC:433
# 4      GENE ID:10219       KLRG1       2F1   NCBI   HGNC:6380
# ...              ...         ...       ...    ...         ...
# 8173   GENE ID:57223     PPP4R3B      smk1   NCBI  HGNC:29267
# 8174  GENE ID:139420     PPP4R3C      smk1   NCBI  HGNC:33146
# 8175   GENE ID:55671     PPP4R3A      smk1   NCBI  HGNC:20219
# 8176    GENE ID:9825      SPATA2      tamo   NCBI  HGNC:14681
# 8177  GENE ID:124044     SPATA2L      tamo   NCBI  HGNC:28393
#
#               ENSG_ID                                       alias_symbol
# 0     ENSG00000171862  10q23del,BZS,CWS1,DEC,GLM2,MHAM,MMAC1,PTEN1,PT...
# 1     ENSG00000107779     10q23del,ACVRLK3,ALK-3,ALK3,BMPR-1A,CD292,SKR5
# 2     ENSG00000108839                               12-LOX,12S-LOX,LOG12
# 3     ENSG00000161905                       12-LOX,15-LOX,15-LOX-1,LOG15
# 4     ENSG00000139187         2F1,CLEC15A,MAFA,MAFA-2F1,MAFA-L,MAFA-LIKE
# ...               ...                                                ...
# 8173  ENSG00000275052                       FLFL2,PP4R3B,PSY2,SMEK2,smk1
# 8174  ENSG00000224960                        FLFL3P,PPP4R3CP,SMEK3P,smk1
# 8175  ENSG00000100796  FLFL1,KIAA2010,MSTP033,PP4R3,PP4R3A,SMEK1,smk-...
# 8176  ENSG00000158480                                  PD1,PPP1R145,tamo
# 8177  ENSG00000158792                                      C16orf76,tamo
#
# [8178 rows x 7 columns]

# %% [markdown]
# How many ambiguous symbols result from alias-alias collisions?

# %%
aa_collision_ambiguous_symbol_set_ncbi = set(merged_alias_aa_collision_ncbi_df["collision"])
aa_collision_ambiguous_symbol_count_ncbi = len(aa_collision_ambiguous_symbol_set_ncbi)
aa_collision_ambiguous_symbol_count_ncbi
# Out:
# 3412

# %% [markdown]
# How many records have at least one alias-alias collision (alias that matches another record's alias gene symbol)?

# %%
aa_record_set_ncbi = set(merged_alias_aa_collision_ncbi_df["NCBI_ID"])
aa_record_count_ncbi = len(aa_record_set_ncbi)
aa_record_count_ncbi
# Out:
# 5615

# %% [markdown]
# # <a id='toc4_'></a>[Merge to create Alias-Alias Collision Table- On Primary Gene Symbol](#toc0_)

# %%
merged_aa_collision_gene_df = pd.concat(
    [
        merged_alias_aa_collision_hgnc_df[["gene_symbol", "alias_symbol", "ENSG_ID", "collision", "source"]],
        merged_alias_aa_collision_ncbi_df[["gene_symbol", "alias_symbol", "ENSG_ID", "collision", "source"]],
        merged_alias_aa_collision_ensg_df[["gene_symbol", "alias_symbol", "ENSG_ID", "collision", "source"]],
    ]
)
merged_aa_collision_gene_df
# Out:
#      gene_symbol                                       alias_symbol  \
# 0        SLC25A5                                          2F1,T2,T3
# 1          KLRG1                            2F1,CLEC15A,MAFA,MAFA-L
# 2         S100A8                  60B8AG,CGLA,MRP-8,MRP8,P8,S100-A8
# 3         S100A9  60B8AG,CGLB,LIAG,MAC387,MIF,MRP-14,MRP14,NIF,P...
# 4          RNU6V                                          87U6,LH87
# ...          ...                                                ...
# 4721     SLC30A8                                         ZNT-8,ZNT8
# 4722    SLC30A10                DKFZP547M236,ZNT-10,ZNT10,ZNT8,ZRC1
# 4723     SLC30A1                                          ZNT1,ZRC1
# 4724      ZYG11B                                     FLJ13456,ZYG11
# 4725      ZYG11A                                              ZYG11
#
#               ENSG_ID collision source
# 0     ENSG00000005022       2F1   HGNC
# 1     ENSG00000139187       2F1   HGNC
# 2     ENSG00000143546    60B8AG   HGNC
# 3     ENSG00000163220    60B8AG   HGNC
# 4     ENSG00000206832      87U6   HGNC
# ...               ...       ...    ...
# 4721  ENSG00000164756      ZNT8   ENSG
# 4722  ENSG00000196660      ZRC1   ENSG
# 4723  ENSG00000170385      ZRC1   ENSG
# 4724  ENSG00000162378     ZYG11   ENSG
# 4725  ENSG00000203995     ZYG11   ENSG
#
# [15350 rows x 5 columns]

# %%
merged_aa_collision_gene_df.to_csv(
    "../output/merged_aa_collision_gene_df.csv", index=False
)

# %%
merged_aa_collision_gene_df.loc[merged_aa_collision_gene_df.collision == "ALP"]
# Out:
#     gene_symbol                                     alias_symbol  \
# 75       ATRNL1                            ALP,FLJ45344,KIAA0534
# 76         SLPI             ALK1,ALP,BLPI,HUSI,HUSI-I,WAP4,WFDC4
# 77        CCL27         ALP,CTACK,CTAK,ESkine,ILC,PESKY,skinkine
# 78       PDLIM3                                              ALP
# 79       ASRGL1                                ALP,ALP1,FLJ22316
# 248      ATRNL1                        ALP,bA338L11.1,bA454H24.1
# 249      ASRGL1                                   ALP,ALP1,CRASH
# 250       NAT10                                  ALP,Kre33,NET43
# 251       CCL27           ALP,CTACK,CTAK,ESKINE,ILC,PESKY,SCYA27
# 252        SLPI         ALK1,ALP,BLPI,HUSI,HUSI-I,MPI,WAP4,WFDC4
# 253        ALPP                    ALP,ALPI,IAP,PALP,PLAP,PLAP-1
# 254      PDLIM3                                              ALP
# 141      PDLIM3                                              ALP
# 142      ASRGL1                                ALP,ALP1,FLJ22316
# 143        SLPI             ALK1,ALP,BLPI,HUSI,HUSI-I,WAP4,WFDC4
# 144       CCL27  ALP,CTACK,CTAK,ESKINE,ILC,PESKY,SCYA27,SKINKINE
# 145      ATRNL1                            ALP,FLJ45344,KIAA0534
#
#              ENSG_ID collision source
# 75   ENSG00000107518       ALP   HGNC
# 76   ENSG00000124107       ALP   HGNC
# 77   ENSG00000213927       ALP   HGNC
# 78   ENSG00000154553       ALP   HGNC
# 79   ENSG00000162174       ALP   HGNC
# 248  ENSG00000107518       ALP   NCBI
# 249  ENSG00000162174       ALP   NCBI
# 250  ENSG00000135372       ALP   NCBI
# 251  ENSG00000213927       ALP   NCBI
# 252  ENSG00000124107       ALP   NCBI
# 253  ENSG00000163283       ALP   NCBI
# 254  ENSG00000154553       ALP   NCBI
# 141  ENSG00000154553       ALP   ENSG
# 142  ENSG00000162174       ALP   ENSG
# 143  ENSG00000124107       ALP   ENSG
# 144  ENSG00000213927       ALP   ENSG
# 145  ENSG00000107518       ALP   ENSG
