# %% [markdown]
# ### Import

# %%
import pandas as pd
import numpy as np
import re
from datetime import datetime

# %%
# def create_ap_collision_df(mini_xxxx_df: pd.DataFrame, source: str) -> pd.DataFrame:
#     """ CASE SENSITIVE COLLISIONS
#     Create a df of alias-primary collision symbols 

#     :param mini_xxxx_df: Processed df of gene records
#     :param source: Representation of the source of the gene records
#     :param split_on_character: Character that is used to seperate alias symbols in the mini_xxxx_df
#     :return: A df of genes that share an alias with another gene
#     """

#     #Remove placeholder gene records (those with no primary gene symbol)
#     mini_xxxx_df = mini_xxxx_df.dropna(subset=["gene_symbol"])

#     #mini_xxx_df
#     ## no LOC genes (only present in NCBI)
#     ## no records with no primary symbols (only present in ENSG)
#     ## each alias on a separate row
#     #Convert the df into a csv and save
#     mini_xxxx_df.to_csv(f'../output/mini_{source.lower()}_df.csv', index=True) 

#     #Make a new df where the alias symbols are merged together for each record
#     merged_alias_xxxx_df = (
#         mini_xxxx_df
#         .copy()
#         .fillna("")
#         .groupby(f"{source}_ID", dropna=False)
#         .agg(lambda col: ",".join(sorted(set(map(str, col)))))
#         .reset_index()
#     )

#     #merged_alias_xxxx_df
#     ##merging aliases associated with the same record (same gene record identifier) into a list
#     #Convert the df into a csv and save
#     merged_alias_xxxx_df.to_csv(f'../output/merged_alias_{source}_df.csv', index=True) 

#     #Make a set of the primary gene symbols
#     xxxx_gene_symbol_set = set(mini_xxxx_df["gene_symbol"])

#     subset_genes_xxxx_df = mini_xxxx_df.copy()

#     #Remove alias symbols that are an exact match to their respective primary gene symbol
#     subset_genes_xxxx_df['alias_symbol'] = subset_genes_xxxx_df.apply(lambda row: np.nan if row['alias_symbol'] == row['gene_symbol'] else row['alias_symbol'], axis=1)

#     #subset_genes_xxxx_df
#     ## no aliases that match the primary gene symbol
#     ## each alias on a separate row
#     #Convert the df into a csv and save
#     subset_genes_xxxx_df.to_csv(f'../output/subset_genes_{source}_df.csv', index=True) 

#     #Create df with genes that have an alias that can be found as another gene's primary gene symbol
#     ap_collision_xxxx_df = subset_genes_xxxx_df.copy()
#     ap_collision_xxxx_df = ap_collision_xxxx_df.dropna(subset=["alias_symbol"])

#     #makes list of aliases into a set
#     ap_collision_xxxx_df.loc[:, "alias_symbol"] = ap_collision_xxxx_df["alias_symbol"].apply(lambda x: {x})

#     ap_collision_xxxx_df.loc[:, "collision"] = ap_collision_xxxx_df["alias_symbol"].apply(
#         lambda x: x & xxxx_gene_symbol_set
#     )
#     ap_collision_xxxx_df = ap_collision_xxxx_df[ap_collision_xxxx_df["collision"].apply(lambda x: len(x) > 0)]
#     #changes back the set of aliases to a list, and make the set of collisions to a list
#     ap_collision_xxxx_df['collision'] = ap_collision_xxxx_df['collision'].apply(
#         lambda x: ', '.join(map(str, x)) if isinstance(x, set) else x
#     )
#     ap_collision_xxxx_df = ap_collision_xxxx_df.sort_values("collision")

#     #Add a source tag for future merging efforts
#     ap_collision_xxxx_df["source"] = str(source.upper())

#     #ap_collision_xxxx_df
#     ## only the gene records with an alias that matches another gene record's primary gene symbol
#     ## each alias on a separate row
#     #Convert the df into a csv
#     ap_collision_xxxx_df.to_csv(f'../output/single_alias_ap_collision_{source.lower()}_df.csv', index=True)

#     #Create a secondary collision df that merges the alias symbols for each record
#     columns_map = {
#         'ENSG': ['NCBI_ID', 'HGNC_ID'],
#         'HGNC': ['NCBI_ID', 'ENSG_ID'],
#         'NCBI': ['HGNC_ID', 'ENSG_ID']
#     }

#     cols_of_interest = columns_map.get(source, [])

#     merged_alias_ap_collision_xxxx_df = ap_collision_xxxx_df.drop(columns=cols_of_interest + ['alias_symbol'])

#     merged_alias_ap_collision_xxxx_df = pd.merge(
#         merged_alias_ap_collision_xxxx_df,
#         merged_alias_xxxx_df[[f"{source}_ID"] + cols_of_interest + ['alias_symbol']],
#         on=[f"{source}_ID"],
#         how="left"
#     )
#     merged_alias_ap_collision_xxxx_df = merged_alias_ap_collision_xxxx_df.drop_duplicates(subset=[f"{source}_ID"])

#     #Test to make sure all collisions are in the alias list for the record
#     test_ap_collision_xxxx_df = merged_alias_ap_collision_xxxx_df.copy()
#     test_ap_collision_xxxx_df['alias_symbol'] = test_ap_collision_xxxx_df['alias_symbol'].apply(lambda x: x if isinstance(x, list) else [x])
#     test_ap_collision_xxxx_df['collision_in_alias'] = test_ap_collision_xxxx_df.apply(lambda row: row['collision'] in test_ap_collision_xxxx_df['alias_symbol'].values, axis=1)
#     true_count = test_ap_collision_xxxx_df['collision_in_alias'].sum()

#     if true_count == 0:
#         #merged_alias_ap_collision_xxxx_df
#         ## only the gene records with an alias that matches another gene record's primary gene symbol
#         ## merging aliases associated with the same record (same gene record identifier) into a list
#         #Convert the df into a csv and save
#         merged_alias_ap_collision_xxxx_df.to_csv(f'../output/merged_alias_ap_collision_{source.lower()}_df.csv', index=True)
#         print("All collisions are present in gene alias lists.")
#     else:
#         print("Some collisions are not present in gene alias lists.")

#     return mini_xxxx_df.head()

# %%
def create_ap_collision_df(mini_xxxx_df: pd.DataFrame, source: str) -> pd.DataFrame:
    """ CASE INSENSITIVE COLLISIONS
    Create a df of alias-primary collision symbols 

    :param mini_xxxx_df: Processed df of gene records
    :param source: Representation of the source of the gene records
    :param split_on_character: Character that is used to seperate alias symbols in the mini_xxxx_df
    :return: A df of genes that share an alias with another gene
    """

    #Remove placeholder gene records (those with no primary gene symbol)
    mini_xxxx_df = mini_xxxx_df.dropna(subset=["gene_symbol"])

    #mini_xxx_df
    ## no LOC genes (only present in NCBI)
    ## no records with no primary symbols (only present in ENSG)
    ## each alias on a separate row
    #Convert the df into a csv and save
    mini_xxxx_df.to_csv(f'../output/mini_{source.lower()}_df.csv', index=True) 

    #Make a new df where the alias symbols are merged together for each record
    merged_alias_xxxx_df = (
        mini_xxxx_df
        .copy()
        .fillna("")
        .groupby(f"{source}_ID", dropna=False)
        .agg(lambda col: ",".join(sorted(set(map(str, col)))))
        .reset_index()
    )

    #merged_alias_xxxx_df
    ##merging aliases associated with the same record (same gene record identifier) into a list
    #Convert the df into a csv and save
    merged_alias_xxxx_df.to_csv(f'../output/merged_alias_{source}_df.csv', index=True) 

    #Make a set of the primary gene symbols
    xxxx_gene_symbol_set = set(mini_xxxx_df["gene_symbol"])
    uppercased_xxxx_gene_symbol_set = {s.upper() for s in xxxx_gene_symbol_set}

    
    subset_genes_xxxx_df = mini_xxxx_df.copy()

    #Remove alias symbols that are an exact match to their respective primary gene symbol
    subset_genes_xxxx_df["alias_symbol_upper"] = subset_genes_xxxx_df["alias_symbol"].str.upper()
    subset_genes_xxxx_df["gene_symbol_upper"] = subset_genes_xxxx_df["gene_symbol"].str.upper()
    subset_genes_xxxx_df['alias_symbol'] = subset_genes_xxxx_df.apply(lambda row: np.nan if row['alias_symbol_upper'] == row['gene_symbol_upper'] else row['alias_symbol'], axis=1)
    subset_genes_xxxx_df = subset_genes_xxxx_df.drop(["alias_symbol_upper","gene_symbol_upper"], axis=1)

    #subset_genes_xxxx_df
    ## no aliases that match the primary gene symbol
    ## each alias on a separate row
    #Convert the df into a csv and save
    subset_genes_xxxx_df.to_csv(f'../output/subset_genes_{source}_df.csv', index=True) 

    #Create df with genes that have an alias that can be found as another gene's primary gene symbol
    ap_collision_xxxx_df = subset_genes_xxxx_df.copy()
    ap_collision_xxxx_df = ap_collision_xxxx_df.dropna(subset=["alias_symbol"])
    ap_collision_xxxx_df["alias_symbol_upper"] = ap_collision_xxxx_df["alias_symbol"].str.upper()

    #makes list of aliases into a set
    ap_collision_xxxx_df.loc[:, "alias_symbol_upper"] = ap_collision_xxxx_df["alias_symbol_upper"].apply(lambda x: {x})

    ap_collision_xxxx_df.loc[:, "collision"] = ap_collision_xxxx_df["alias_symbol_upper"].apply(
        lambda x: x & uppercased_xxxx_gene_symbol_set
    )
    ap_collision_xxxx_df = ap_collision_xxxx_df.drop("alias_symbol_upper", axis=1)
    ap_collision_xxxx_df = ap_collision_xxxx_df[ap_collision_xxxx_df["collision"].apply(lambda x: len(x) > 0)]
    #changes back the set of aliases to a list, and make the set of collisions to a list
    ap_collision_xxxx_df['collision'] = ap_collision_xxxx_df['collision'].apply(
        lambda x: ', '.join(map(str, x)) if isinstance(x, set) else x
    )
    ap_collision_xxxx_df = ap_collision_xxxx_df.sort_values("collision")

    #Add a source tag for future merging efforts
    ap_collision_xxxx_df["source"] = str(source.upper())

    #ap_collision_xxxx_df
    ## only the gene records with an alias that matches another gene record's primary gene symbol
    ## each alias on a separate row
    #Convert the df into a csv
    ap_collision_xxxx_df.to_csv(f'../output/single_alias_ap_collision_{source.lower()}_df.csv', index=True)

    #Create a secondary collision df that merges the alias symbols for each record
    columns_map = {
        'ENSG': ['NCBI_ID', 'HGNC_ID'],
        'HGNC': ['NCBI_ID', 'ENSG_ID'],
        'NCBI': ['HGNC_ID', 'ENSG_ID']
    }

    cols_of_interest = columns_map.get(source, [])

    merged_alias_ap_collision_xxxx_df = ap_collision_xxxx_df.drop(columns=cols_of_interest + ['alias_symbol'])

    merged_alias_ap_collision_xxxx_df = pd.merge(
        merged_alias_ap_collision_xxxx_df,
        merged_alias_xxxx_df[[f"{source}_ID"] + cols_of_interest + ['alias_symbol']],
        on=[f"{source}_ID"],
        how="left"
    )
    merged_alias_ap_collision_xxxx_df = merged_alias_ap_collision_xxxx_df.drop_duplicates(subset=[f"{source}_ID"])

    #Test to make sure all collisions are in the alias list for the record
    test_ap_collision_xxxx_df = merged_alias_ap_collision_xxxx_df.copy()
    test_ap_collision_xxxx_df["alias_symbol_upper"] = test_ap_collision_xxxx_df["alias_symbol"].str.upper()   
    test_ap_collision_xxxx_df['alias_symbol_upper'] = test_ap_collision_xxxx_df['alias_symbol_upper'].apply(lambda x: x if isinstance(x, list) else [x])
    test_ap_collision_xxxx_df['collision_in_alias'] = test_ap_collision_xxxx_df.apply(lambda row: row['collision'] in test_ap_collision_xxxx_df['alias_symbol_upper'].values, axis=1)
    true_count = test_ap_collision_xxxx_df['collision_in_alias'].sum()
    test_ap_collision_xxxx_df = test_ap_collision_xxxx_df.drop("alias_symbol_upper", axis=1)

    if true_count == 0:
        #merged_alias_ap_collision_xxxx_df
        ## only the gene records with an alias that matches another gene record's primary gene symbol
        ## merging aliases associated with the same record (same gene record identifier) into a list
        #Convert the df into a csv and save
        merged_alias_ap_collision_xxxx_df.to_csv(f'../output/merged_alias_ap_collision_{source.lower()}_df.csv', index=True)
        print("All collisions are present in gene alias lists.")
    else:
        print("Some collisions are not present in gene alias lists.")

    return mini_xxxx_df.head()

# %% [markdown]
# # Ensembl

# %%
raw_ensg_df = pd.read_csv(
    "../input/ensg_biomart_gene20250625.txt", sep="\t",dtype={"NCBI gene (formerly Entrezgene) ID": pd.Int64Dtype()}
)
raw_ensg_df = raw_ensg_df.rename(
    columns={
        "HGNC ID": "HGNC_ID",
        "Gene Synonym": "alias_symbol",
        "Gene name": "gene_symbol",
        "Gene stable ID": "ENSG_ID",
        "NCBI gene (formerly Entrezgene) ID": "NCBI_ID",
    }
)
raw_ensg_df
# Out:
#                 ENSG_ID  NCBI_ID     HGNC_ID alias_symbol gene_symbol
# 0       ENSG00000210049     <NA>   HGNC:7481         MTTF       MT-TF
# 1       ENSG00000210049     <NA>   HGNC:7481         TRNF       MT-TF
# 2       ENSG00000211459     <NA>   HGNC:7470          12S     MT-RNR1
# 3       ENSG00000211459     <NA>   HGNC:7470       MOTS-C     MT-RNR1
# 4       ENSG00000211459     <NA>   HGNC:7470       MTRNR1     MT-RNR1
# ...                 ...      ...         ...          ...         ...
# 133060  ENSG00000229388     <NA>  HGNC:52502    LINC01715    TAF12-DT
# 133061  ENSG00000289291     <NA>         NaN          NaN         NaN
# 133062  ENSG00000274978    26824  HGNC:10108      RNU11-1       RNU11
# 133063  ENSG00000274978    26824  HGNC:10108          U11       RNU11
# 133064  ENSG00000296488     <NA>         NaN          NaN         NaN
#
# [133065 rows x 5 columns]

# %%
raw_ensg_df["NCBI_ID"] = raw_ensg_df["NCBI_ID"].apply(
lambda x: f"GENE ID:{int(x)}" if pd.notna(x) and x == int(x) else f"GENE ID:{x}" if pd.notna(x) else x
)

# %%
raw_ensg_df = raw_ensg_df.replace(" ", np.nan)
raw_ensg_df = raw_ensg_df.replace("", np.nan)
raw_ensg_df = raw_ensg_df.replace("-", np.nan)
raw_ensg_df = raw_ensg_df.replace("<NA>", np.nan)

# %%
raw_ensg_df.to_csv(f'../output/raw_ensg_df.csv', index=True)

# %% [markdown]
# how many gene records for the Ensembl data set before any kind of cleaning?

# %%
total_raw_gene_record_set_ensg = set(raw_ensg_df['ENSG_ID'])
total_raw_gene_record_count_ensg = len(total_raw_gene_record_set_ensg)
total_raw_gene_record_count_ensg
# Out:
# 86364

# %% [markdown]
# how many gene records have no primary gene symbol?

# %%
raw_no_primary_symbol_record_count_ensg = (
    raw_ensg_df[raw_ensg_df["gene_symbol"].isna()]
    .dropna(subset=["ENSG_ID"])
    ["ENSG_ID"]
    .nunique()
)
raw_no_primary_symbol_record_count_ensg
# Out:
# 37963

# %% [markdown]
# how many gene records that have a primary gene symbol that is a LOC placeholder?

# %%
raw_loc_record_count_ensg = (
    raw_ensg_df[raw_ensg_df["gene_symbol"].str.startswith('LOC', na=False)&
    ~raw_ensg_df['gene_symbol']
    .str.contains('-', na=False)]
    .dropna(subset=["ENSG_ID"])
    ["ENSG_ID"]
    .nunique()
)
raw_loc_record_count_ensg
# Out:
# 0

# %% [markdown]
# how many records with an @ symbol in the primary gene symbol?

# %%
at_symbol_records_ensg_df = raw_ensg_df[raw_ensg_df['gene_symbol'].str.contains('@', na=False)]
len(set(at_symbol_records_ensg_df["ENSG_ID"]))
# Out:
# 0

# %%
create_ap_collision_df(raw_ensg_df, "ENSG")
# Out:
# All collisions are present in gene alias lists.
#            ENSG_ID NCBI_ID    HGNC_ID alias_symbol gene_symbol
# 0  ENSG00000210049     NaN  HGNC:7481         MTTF       MT-TF
# 1  ENSG00000210049     NaN  HGNC:7481         TRNF       MT-TF
# 2  ENSG00000211459     NaN  HGNC:7470          12S     MT-RNR1
# 3  ENSG00000211459     NaN  HGNC:7470       MOTS-C     MT-RNR1
# 4  ENSG00000211459     NaN  HGNC:7470       MTRNR1     MT-RNR1

# %%
mini_ensg_df = pd.read_csv(
    "../output/mini_ensg_df.csv", index_col=[0])

# %%
subset_genes_ensg_df = pd.read_csv(
    "../output/subset_genes_ensg_df.csv", index_col=[0])
subset_genes_ensg_df
# Out:
#                 ENSG_ID        NCBI_ID     HGNC_ID alias_symbol gene_symbol
# 0       ENSG00000210049            NaN   HGNC:7481         MTTF       MT-TF
# 1       ENSG00000210049            NaN   HGNC:7481         TRNF       MT-TF
# 2       ENSG00000211459            NaN   HGNC:7470          12S     MT-RNR1
# 3       ENSG00000211459            NaN   HGNC:7470       MOTS-C     MT-RNR1
# 4       ENSG00000211459            NaN   HGNC:7470       MTRNR1     MT-RNR1
# ...                 ...            ...         ...          ...         ...
# 133058  ENSG00000197989  GENE ID:85028  HGNC:30062    LINC00100      SNHG12
# 133059  ENSG00000197989  GENE ID:85028  HGNC:30062     PNAS-123      SNHG12
# 133060  ENSG00000229388            NaN  HGNC:52502    LINC01715    TAF12-DT
# 133062  ENSG00000274978  GENE ID:26824  HGNC:10108      RNU11-1       RNU11
# 133063  ENSG00000274978  GENE ID:26824  HGNC:10108          U11       RNU11
#
# [95024 rows x 5 columns]

# %%
subset_genes_ensg_df.loc[subset_genes_ensg_df["gene_symbol"]== "OR6K4P"]
# Out:
#                 ENSG_ID NCBI_ID     HGNC_ID alias_symbol gene_symbol
# 133028  ENSG00000180437     NaN  HGNC:15031          NaN      OR6K4P

# %%
ap_collision_ensg_df = pd.read_csv(
    "../output/single_alias_ap_collision_ensg_df.csv", index_col=[0])
ap_collision_ensg_df
# Out:
#                ENSG_ID         NCBI_ID     HGNC_ID alias_symbol gene_symbol  \
# 24761  ENSG00000283293  GENE ID:125050  HGNC:10037          7SK       RN7SK
# 37365  ENSG00000057252    GENE ID:6646  HGNC:11177        ACAT1       SOAT1
# 17666  ENSG00000167780    GENE ID:8435  HGNC:11178        ACAT2       SOAT2
# 35063  ENSG00000004779    GENE ID:4706   HGNC:7694         ACP1     NDUFAB1
# 47647  ENSG00000220267             NaN    HGNC:141       ACTBP2      ACTBP8
# ...                ...             ...         ...          ...         ...
# 53226  ENSG00000197961    GENE ID:7675  HGNC:12904        ZNF20      ZNF121
# 35374  ENSG00000110315   GENE ID:50862  HGNC:21159       ZNF230      RNF141
# 96229  ENSG00000188801             NaN  HGNC:14003       ZNF322    ZNF322P1
# 81813  ENSG00000103994   GENE ID:64397  HGNC:12886       ZNF474      ZNF106
# 14437  ENSG00000184517  GENE ID:162239  HGNC:23328       ZNF475        ZFP1
#
#       collision source
# 24761       7SK   ENSG
# 37365     ACAT1   ENSG
# 17666     ACAT2   ENSG
# 35063      ACP1   ENSG
# 47647    ACTBP2   ENSG
# ...         ...    ...
# 53226     ZNF20   ENSG
# 35374    ZNF230   ENSG
# 96229    ZNF322   ENSG
# 81813    ZNF474   ENSG
# 14437    ZNF475   ENSG
#
# [811 rows x 7 columns]

# %%
merged_alias_ap_collision_ensg_df = pd.read_csv(
    "../output/merged_alias_ap_collision_ensg_df.csv", index_col=[0])
merged_alias_ap_collision_ensg_df
# Out:
#              ENSG_ID gene_symbol collision source         NCBI_ID     HGNC_ID  \
# 0    ENSG00000283293       RN7SK       7SK   ENSG  GENE ID:125050  HGNC:10037
# 1    ENSG00000057252       SOAT1     ACAT1   ENSG    GENE ID:6646  HGNC:11177
# 2    ENSG00000167780       SOAT2     ACAT2   ENSG    GENE ID:8435  HGNC:11178
# 3    ENSG00000004779     NDUFAB1      ACP1   ENSG    GENE ID:4706   HGNC:7694
# 4    ENSG00000220267      ACTBP8    ACTBP2   ENSG             NaN    HGNC:141
# ..               ...         ...       ...    ...             ...         ...
# 806  ENSG00000197961      ZNF121     ZNF20   ENSG    GENE ID:7675  HGNC:12904
# 807  ENSG00000110315      RNF141    ZNF230   ENSG   GENE ID:50862  HGNC:21159
# 808  ENSG00000188801    ZNF322P1    ZNF322   ENSG             NaN  HGNC:14003
# 809  ENSG00000103994      ZNF106    ZNF474   ENSG   GENE ID:64397  HGNC:12886
# 810  ENSG00000184517        ZFP1    ZNF475   ENSG  GENE ID:162239  HGNC:23328
#
#              alias_symbol
# 0                     7SK
# 1    ACAT,ACAT1,SOAT,STAT
# 2                   ACAT2
# 3    ACP,ACP1,FASN2A,SDAP
# 4                  ACTBP2
# ..                    ...
# 806   D19S204,ZHC32,ZNF20
# 807          ZFP26,ZNF230
# 808        ZNF322,ZNF322B
# 809  SH3BP3,ZFP106,ZNF474
# 810       FLJ34243,ZNF475
#
# [767 rows x 7 columns]

# %% [markdown]
# how many gene records are in the Ensembl database?

# %%
gene_record_set_ensg = set(mini_ensg_df['ENSG_ID'])
gene_record_count_ensg = len(gene_record_set_ensg)
gene_record_count_ensg
# Out:
# 48401

# %% [markdown]
# how many unique primary gene symbols are in the Ensembl data set?

# %%
primary_symbol_set_ensg = set(mini_ensg_df['gene_symbol'])
primary_symbol_count_ensg = len(primary_symbol_set_ensg)
primary_symbol_count_ensg
# Out:
# 41164

# %% [markdown]
# how many unique alias gene symbols are in the Ensembl data set?

# %%
alias_symbol_set_ensg = set(mini_ensg_df['alias_symbol'])
alias_symbol_count_ensg = len(alias_symbol_set_ensg)
alias_symbol_count_ensg
# Out:
# 55413

# %% [markdown]
# how many unique gene symbols in total are there in the Ensembl data set??

# %%
total_symbol_count_ensg = pd.concat([mini_ensg_df["gene_symbol"], mini_ensg_df["alias_symbol"]]).dropna().nunique()
total_symbol_count_ensg
# Out:
# 95941

# %% [markdown]
# how many gene records have no alias symbols?

# %%
no_alias_symbol_record_count_ensg = (
    mini_ensg_df[mini_ensg_df["alias_symbol"].isna()]
    .dropna(subset=["ENSG_ID"])
    ["ENSG_ID"]
    .nunique()
)
no_alias_symbol_record_count_ensg
# Out:
# 19363

# %%
(no_alias_symbol_record_count_ensg/gene_record_count_ensg)*100
# Out:
# 40.00537178983905

# %% [markdown]
# how many gene records have a primary gene symbol that is a C#orf?

# %%
orf_record_set_ensg = set(
    mini_ensg_df[
        mini_ensg_df["gene_symbol"].str.contains(r'^C.*ORF', case=False, na=False) &
        ~mini_ensg_df["gene_symbol"].str.contains("-", na=False)
    ]
    .dropna(subset=["ENSG_ID"])["ENSG_ID"]
)

orf_record_count_ensg = len(orf_record_set_ensg)
orf_record_count_ensg
# Out:
# 288

# %%
(orf_record_count_ensg/gene_record_count_ensg)*100
# Out:
# 0.595029028325861

# %% [markdown]
# how many gene records that have a primary gene symbol that is a FAM placeholder?

# %%
fam_record_set_ensg = set(
    mini_ensg_df[
        mini_ensg_df["gene_symbol"].str.startswith("FAM", na=False) &
        ~mini_ensg_df["gene_symbol"].str.contains("-", na=False)
    ]
    .dropna(subset=["ENSG_ID"])["ENSG_ID"]
)

fam_record_count_ensg = len(fam_record_set_ensg)
fam_record_count_ensg
# Out:
# 430

# %%
(fam_record_count_ensg/gene_record_count_ensg)*100
# Out:
# 0.8884113964587508

# %%
fam_record_set_ensg_df = mini_ensg_df[mini_ensg_df['ENSG_ID'].isin(fam_record_set_ensg)].copy()
fam_record_set_ensg_df['fam_family'] = fam_record_set_ensg_df['gene_symbol'].str.extract(r'^FAM(\d+)')
unique_families_count_ensg = fam_record_set_ensg_df['fam_family'].unique()
print("Number of unique FAM families in ENSG:", len(unique_families_count_ensg))
# Out:
# Number of unique FAM families in ENSG: 106

# %% [markdown]
# how many gene records that have a primary gene symbol that is a KIAA placeholder?

# %%
kiaa_record_set_ensg = set(
    mini_ensg_df[
        mini_ensg_df["gene_symbol"].str.startswith("KIAA", na=False) &
        ~mini_ensg_df["gene_symbol"].str.contains("-", na=False)
    ]
    .dropna(subset=["ENSG_ID"])["ENSG_ID"]
)

kiaa_record_count_ensg = len(kiaa_record_set_ensg)
kiaa_record_count_ensg
# Out:
# 33

# %%
(kiaa_record_count_ensg/gene_record_count_ensg)*100
# Out:
# 0.06818040949567158

# %% [markdown]
# which gene records share a primary symbol with other gene records?

# %%
# groupby name and return a boolean of whether each has more than 1 unique ENSG ID
multi_primary = mini_ensg_df.groupby(["gene_symbol"]).ENSG_ID.nunique().gt(1)

num_rows = mini_ensg_df[mini_ensg_df.gene_symbol.isin(multi_primary[multi_primary].index)].shape[0]
print(num_rows)

# use loc to only see those values that have `True` in `multi_primary`:
mini_ensg_df.loc[mini_ensg_df.gene_symbol.isin(multi_primary[multi_primary].index)].sort_values(by='gene_symbol').iloc[6000:6060]
# Out:
# 25007
#                 ENSG_ID         NCBI_ID     HGNC_ID alias_symbol gene_symbol
# 92891   ENSG00000138641    GENE ID:8916   HGNC:4876     KIAA0032       HERC3
# 92878   ENSG00000287542    GENE ID:8916         NaN          NaN       HERC3
# 52117   ENSG00000273529  GENE ID:388585  HGNC:19764      BHLHB38        HES5
# 14696   ENSG00000197921  GENE ID:388585  HGNC:19764      BHLHB38        HES5
# 4416    ENSG00000280680   GENE ID:55733  HGNC:18270       MART-2        HHAT
# 4421    ENSG00000280680   GENE ID:55733  HGNC:18270          SKN        HHAT
# 4418    ENSG00000280680   GENE ID:55733  HGNC:18270         RASP        HHAT
# 4417    ENSG00000280680   GENE ID:55733  HGNC:18270        MART2        HHAT
# 43282   ENSG00000054392   GENE ID:55733  HGNC:18270        MART2        HHAT
# 43285   ENSG00000054392   GENE ID:55733  HGNC:18270          SKI        HHAT
# 4415    ENSG00000280680   GENE ID:55733  HGNC:18270         GUP2        HHAT
# 4414    ENSG00000280680   GENE ID:55733  HGNC:18270     FLJ10724        HHAT
# 4419    ENSG00000280680   GENE ID:55733  HGNC:18270          SIT        HHAT
# 43284   ENSG00000054392   GENE ID:55733  HGNC:18270          SIT        HHAT
# 43283   ENSG00000054392   GENE ID:55733  HGNC:18270         RASP        HHAT
# 43281   ENSG00000054392   GENE ID:55733  HGNC:18270       MART-2        HHAT
# 43280   ENSG00000054392   GENE ID:55733  HGNC:18270         GUP2        HHAT
# 43279   ENSG00000054392   GENE ID:55733  HGNC:18270     FLJ10724        HHAT
# 43286   ENSG00000054392   GENE ID:55733  HGNC:18270          SKN        HHAT
# 4420    ENSG00000280680   GENE ID:55733  HGNC:18270          SKI        HHAT
# 72820   ENSG00000235657    GENE ID:3105   HGNC:4931          NaN       HLA-A
# 68794   ENSG00000224320    GENE ID:3105   HGNC:4931          NaN       HLA-A
# 66867   ENSG00000227715    GENE ID:3105   HGNC:4931          NaN       HLA-A
# 76339   ENSG00000231834    GENE ID:3105   HGNC:4931          NaN       HLA-A
# 101068  ENSG00000206503    GENE ID:3105   HGNC:4931          NaN       HLA-A
# 67552   ENSG00000206505    GENE ID:3105   HGNC:4931          NaN       HLA-A
# 79893   ENSG00000223980    GENE ID:3105   HGNC:4931          NaN       HLA-A
# 66597   ENSG00000229215    GENE ID:3105   HGNC:4931          NaN       HLA-A
# 79909   ENSG00000224608    GENE ID:3106   HGNC:4932           AS       HLA-B
# 71168   ENSG00000234745    GENE ID:3106   HGNC:4932           AS       HLA-B
# 66216   ENSG00000206450    GENE ID:3106   HGNC:4932           AS       HLA-B
# 70494   ENSG00000232126    GENE ID:3106   HGNC:4932           AS       HLA-B
# 79186   ENSG00000223532    GENE ID:3106   HGNC:4932           AS       HLA-B
# 81469   ENSG00000228964    GENE ID:3106   HGNC:4932           AS       HLA-B
# 62689   ENSG00000204525    GENE ID:3107   HGNC:4933       D6S204       HLA-C
# 78388   ENSG00000228299    GENE ID:3107   HGNC:4933       PSORS1       HLA-C
# 78387   ENSG00000228299    GENE ID:3107   HGNC:4933      HLA-JY3       HLA-C
# 78774   ENSG00000233841    GENE ID:3107   HGNC:4933       PSORS1       HLA-C
# 76516   ENSG00000206452    GENE ID:3107   HGNC:4933      HLA-JY3       HLA-C
# 78386   ENSG00000228299    GENE ID:3107   HGNC:4933       D6S204       HLA-C
# 78773   ENSG00000233841    GENE ID:3107   HGNC:4933      HLA-JY3       HLA-C
# 70213   ENSG00000225691    GENE ID:3107   HGNC:4933       PSORS1       HLA-C
# 80918   ENSG00000206435    GENE ID:3107   HGNC:4933       PSORS1       HLA-C
# 76515   ENSG00000206452    GENE ID:3107   HGNC:4933       D6S204       HLA-C
# 80917   ENSG00000206435    GENE ID:3107   HGNC:4933      HLA-JY3       HLA-C
# 81311   ENSG00000237022    GENE ID:3107   HGNC:4933       PSORS1       HLA-C
# 81310   ENSG00000237022    GENE ID:3107   HGNC:4933      HLA-JY3       HLA-C
# 70211   ENSG00000225691    GENE ID:3107   HGNC:4933       D6S204       HLA-C
# 76517   ENSG00000206452    GENE ID:3107   HGNC:4933       PSORS1       HLA-C
# 80916   ENSG00000206435    GENE ID:3107   HGNC:4933       D6S204       HLA-C
# 62691   ENSG00000204525    GENE ID:3107   HGNC:4933       PSORS1       HLA-C
# 70212   ENSG00000225691    GENE ID:3107   HGNC:4933      HLA-JY3       HLA-C
# 62690   ENSG00000204525    GENE ID:3107   HGNC:4933      HLA-JY3       HLA-C
# 81309   ENSG00000237022    GENE ID:3107   HGNC:4933       D6S204       HLA-C
# 78772   ENSG00000233841    GENE ID:3107   HGNC:4933       D6S204       HLA-C
# 76137   ENSG00000242685    GENE ID:3108   HGNC:4934      D6S222E     HLA-DMA
# 75324   ENSG00000243189    GENE ID:3108   HGNC:4934      D6S222E     HLA-DMA
# 83537   ENSG00000243215    GENE ID:3108   HGNC:4934      D6S222E     HLA-DMA
# 74916   ENSG00000243719    GENE ID:3108   HGNC:4934      D6S222E     HLA-DMA
# 75325   ENSG00000243189    GENE ID:3108   HGNC:4934        RING6     HLA-DMA

# %% [markdown]
# How many ambiguous symbols result from alias-primary collisions?

# %%
ap_collision_ambiguous_symbol_set_ensg = set(merged_alias_ap_collision_ensg_df["collision"])
ap_collision_ambiguous_symbol_count_ensg = len(ap_collision_ambiguous_symbol_set_ensg)
ap_collision_ambiguous_symbol_count_ensg
# Out:
# 606

# %% [markdown]
# How many records have at least one alias-primary collision (alias that matches another record's primary gene symbol)?

# %%
ap_record_set_ensg = set(merged_alias_ap_collision_ensg_df["ENSG_ID"])
ap_record_count_ensg = len(ap_record_set_ensg)
ap_record_count_ensg
# Out:
# 767

# %% [markdown]
# 1. Why is the alias-gene collision set not the same length as the set of primary symbols with collisions ?
# 2. Why is the length of the alias-gene collison set shorter?
#  - A gene record with an alias-primary collision has an alias that matches a different gene's primary gene symbol.
#  - Multiple gene records can share a single alias (alias-alias collision)
#  - If that shared alias is an alias-primary collision, then there will be more unique gene symbols in the set of primary symbols with collisions than the set of alias-primary collisions.

# %% [markdown]
# # HGNC

# %% [markdown]
# ## Set up table

# %%
hgnc_file_path = "../input/hgnc_biomart_gene20250625.txt"

raw_hgnc_df = pd.read_csv(
    hgnc_file_path, sep="\t"
)

# Rename columns
raw_hgnc_df = raw_hgnc_df.rename(
    columns={
        "HGNC ID": "HGNC_ID",
        "Approved symbol": "gene_symbol",
        "Ensembl gene ID": "ENSG_ID",
    }
)

#structure and labeling in HGNC download files changed between 2024 amd 2025
if "Alias symbol" in raw_hgnc_df.columns:
    raw_hgnc_df = raw_hgnc_df.rename(columns={"Alias symbol": "alias_symbol"})
elif "Alias symbols" in raw_hgnc_df.columns:
    raw_hgnc_df = raw_hgnc_df.rename(columns={"Alias symbols": "alias_symbol"})
else:
    raw_hgnc_df["alias_symbol"] = pd.NA

if "NCBI gene ID" in raw_hgnc_df.columns:
    raw_hgnc_df = raw_hgnc_df.rename(columns={"NCBI gene ID": "NCBI_ID"})
elif "NCBI Gene ID" in raw_hgnc_df.columns:
    raw_hgnc_df = raw_hgnc_df.rename(columns={"NCBI Gene ID": "NCBI_ID"})
else:
    raw_hgnc_df["NCBI_ID"] = pd.NA   

raw_hgnc_df["NCBI_ID"] = raw_hgnc_df["NCBI_ID"].astype(pd.Int64Dtype())

# Extract date from filename and check if it is before June 25, 2025
match = re.search(r'(\d{8})', hgnc_file_path)
file_date = datetime.strptime(match.group(1), "%Y%m%d") if match else None
cutoff_date = datetime.strptime("20250625", "%Y%m%d")

# Apply list-splitting logic for newer files
if file_date and file_date >= cutoff_date:
    raw_hgnc_df['alias_symbol'] = (
        raw_hgnc_df['alias_symbol']
        .fillna('')
        .str.split(',')
        .apply(lambda x: [a.strip() for a in x if a.strip()])
    )
    raw_hgnc_df = raw_hgnc_df.explode('alias_symbol')

raw_hgnc_df
# Out:
#           HGNC_ID gene_symbol alias_symbol  NCBI_ID          ENSG_ID
# 0        HGNC:100       ASIC1        BNaC2       41  ENSG00000110881
# 0        HGNC:100       ASIC1       hBNaC2       41  ENSG00000110881
# 1      HGNC:10000        RGS4          NaN     5999  ENSG00000117152
# 2      HGNC:10001        RGS5          NaN     8490  ENSG00000143248
# 3      HGNC:10002        RGS6          NaN     9628  ENSG00000182732
# ...           ...         ...          ...      ...              ...
# 44232   HGNC:9997       RGS16        RGS-r     6004  ENSG00000143333
# 44233   HGNC:9998        RGS2          NaN     5997  ENSG00000116741
# 44234   HGNC:9999        RGS3         C2PA     5998  ENSG00000138835
# 44234   HGNC:9999        RGS3     FLJ20370     5998  ENSG00000138835
# 44234   HGNC:9999        RGS3     PDZ-RGS3     5998  ENSG00000138835
#
# [66207 rows x 5 columns]

# %%
raw_hgnc_df["NCBI_ID"] = raw_hgnc_df["NCBI_ID"].apply(
lambda x: f"GENE ID:{int(x)}" if pd.notna(x) and x == int(x) else f"GENE ID:{x}" if pd.notna(x) else x
)

# %%
raw_hgnc_df = raw_hgnc_df.replace(" ", np.nan)
raw_hgnc_df = raw_hgnc_df.replace("", np.nan)
raw_hgnc_df = raw_hgnc_df.replace("-", np.nan)

# %%
raw_hgnc_df.to_csv(f'../output/raw_hgnc_df.csv', index=True)

# %% [markdown]
# how many gene records for the HGNC data set before any kind of cleaning?

# %%
total_raw_gene_record_set_hgnc = set(raw_hgnc_df['HGNC_ID'])
total_raw_gene_record_count_hgnc = len(total_raw_gene_record_set_hgnc)
total_raw_gene_record_count_hgnc
# Out:
# 44235

# %% [markdown]
# how many gene records have no primary gene symbol?

# %%
raw_no_primary_symbol_record_count_hgnc = (
    raw_hgnc_df[raw_hgnc_df["gene_symbol"].isna()]
    .dropna(subset=["HGNC_ID"])
    ["HGNC_ID"]
    .nunique()
)
raw_no_primary_symbol_record_count_hgnc
# Out:
# 0

# %% [markdown]
# how many gene records that have a primary gene symbol that is a LOC placeholder?

# %%
raw_loc_record_count_hgnc = (
    raw_hgnc_df[raw_hgnc_df["gene_symbol"].str.startswith('LOC', na=False)&
    ~raw_hgnc_df['gene_symbol']
    .str.contains('-', na=False)]
    .dropna(subset=["HGNC_ID"])
    ["HGNC_ID"]
    .nunique()
)
raw_loc_record_count_hgnc
# Out:
# 0

# %% [markdown]
# how many records with an @ symbol in the primary gene symbol?

# %%
at_symbol_records_hgnc_df = raw_hgnc_df[raw_hgnc_df['gene_symbol'].str.contains('@', na=False)]
len(set(at_symbol_records_hgnc_df["HGNC_ID"]))
# Out:
# 7

# %%
no_at_hgnc_df = raw_hgnc_df[~raw_hgnc_df['HGNC_ID'].isin(at_symbol_records_hgnc_df['HGNC_ID'])]

# %%
create_ap_collision_df(no_at_hgnc_df, "HGNC")
# Out:
# All collisions are present in gene alias lists.
#       HGNC_ID gene_symbol alias_symbol       NCBI_ID          ENSG_ID
# 0    HGNC:100       ASIC1        BNaC2    GENE ID:41  ENSG00000110881
# 0    HGNC:100       ASIC1       hBNaC2    GENE ID:41  ENSG00000110881
# 1  HGNC:10000        RGS4          NaN  GENE ID:5999  ENSG00000117152
# 2  HGNC:10001        RGS5          NaN  GENE ID:8490  ENSG00000143248
# 3  HGNC:10002        RGS6          NaN  GENE ID:9628  ENSG00000182732

# %%
mini_hgnc_df = pd.read_csv(
    "../output/mini_hgnc_df.csv", index_col=[0])

# %%
subset_genes_hgnc_df = pd.read_csv(
    "../output/subset_genes_hgnc_df.csv", index_col=[0])
subset_genes_hgnc_df
# Out:
#           HGNC_ID gene_symbol alias_symbol       NCBI_ID          ENSG_ID
# 0        HGNC:100       ASIC1        BNaC2    GENE ID:41  ENSG00000110881
# 0        HGNC:100       ASIC1       hBNaC2    GENE ID:41  ENSG00000110881
# 1      HGNC:10000        RGS4          NaN  GENE ID:5999  ENSG00000117152
# 2      HGNC:10001        RGS5          NaN  GENE ID:8490  ENSG00000143248
# 3      HGNC:10002        RGS6          NaN  GENE ID:9628  ENSG00000182732
# ...           ...         ...          ...           ...              ...
# 44232   HGNC:9997       RGS16        RGS-r  GENE ID:6004  ENSG00000143333
# 44233   HGNC:9998        RGS2          NaN  GENE ID:5997  ENSG00000116741
# 44234   HGNC:9999        RGS3         C2PA  GENE ID:5998  ENSG00000138835
# 44234   HGNC:9999        RGS3     FLJ20370  GENE ID:5998  ENSG00000138835
# 44234   HGNC:9999        RGS3     PDZ-RGS3  GENE ID:5998  ENSG00000138835
#
# [66199 rows x 5 columns]

# %%
merged_alias_ap_collision_hgnc_df = pd.read_csv(
    "../output/merged_alias_ap_collision_hgnc_df.csv", index_col=[0])
merged_alias_ap_collision_hgnc_df
# Out:
#         HGNC_ID gene_symbol collision source         NCBI_ID          ENSG_ID  \
# 0    HGNC:14947    PPP1R12C     AAVS1   HGNC   GENE ID:54776  ENSG00000125503
# 1    HGNC:11177       SOAT1     ACAT1   HGNC    GENE ID:6646  ENSG00000057252
# 2    HGNC:11178       SOAT2     ACAT2   HGNC    GENE ID:8435  ENSG00000167780
# 3     HGNC:1612       CCRL2     ACKR5   HGNC    GENE ID:9034  ENSG00000121797
# 4     HGNC:7694     NDUFAB1      ACP1   HGNC    GENE ID:4706  ENSG00000004779
# ..          ...         ...       ...    ...             ...              ...
# 555   HGNC:3147       ECEL1       XCE   HGNC    GENE ID:9427  ENSG00000171551
# 556  HGNC:12904      ZNF121     ZNF20   HGNC    GENE ID:7675  ENSG00000197961
# 557  HGNC:21159      RNF141    ZNF230   HGNC   GENE ID:50862  ENSG00000110315
# 558  HGNC:12886      ZNF106    ZNF474   HGNC   GENE ID:64397  ENSG00000103994
# 559  HGNC:23328        ZFP1    ZNF475   HGNC  GENE ID:162239  ENSG00000184517
#
#                           alias_symbol
# 0    AAVS1,DKFZP434D0412,MBS85,p84,p85
# 1                           ACAT,ACAT1
# 2                                ACAT2
# 3         ACKR5,CKRX,CRAM-A,CRAM-B,HCR
# 4                 ACP,ACP1,FASN2A,SDAP
# ..                                 ...
# 555                           DINE,XCE
# 556                        ZHC32,ZNF20
# 557                       ZFP26,ZNF230
# 558                      SH3BP3,ZNF474
# 559                    FLJ34243,ZNF475
#
# [546 rows x 7 columns]

# %% [markdown]
# how many gene records are in the HGNC database?

# %%
gene_record_set_hgnc = set(mini_hgnc_df['HGNC_ID'])
gene_record_count_hgnc = len(gene_record_set_hgnc)
gene_record_count_hgnc
# Out:
# 44228

# %% [markdown]
# how many unique primary gene symbols are in the HGNC data set?

# %%
primary_symbol_set_hgnc = set(mini_hgnc_df['gene_symbol'])
primary_symbol_count_hgnc = len(primary_symbol_set_hgnc)
primary_symbol_count_hgnc
# Out:
# 44228

# %% [markdown]
# how many unique alias gene symbols are in the HGNC data set?

# %%
alias_symbol_set_hgnc = set(mini_hgnc_df['alias_symbol'])
alias_symbol_count_hgnc = len(alias_symbol_set_hgnc)
alias_symbol_count_hgnc
# Out:
# 43072

# %% [markdown]
# how many unique gene symbols in total are there in the HGNC data set??

# %%
total_symbol_count_hgnc = len(set(mini_hgnc_df['gene_symbol']) | set(mini_hgnc_df['alias_symbol']))
total_symbol_count_hgnc
# Out:
# 86832

# %% [markdown]
# how many gene records have no alias symbols?

# %%
no_alias_symbol_record_count_hgnc = (
    mini_hgnc_df[mini_hgnc_df["alias_symbol"].isna()]
    .dropna(subset=["HGNC_ID"])
    ["HGNC_ID"]
    .nunique()
)
no_alias_symbol_record_count_hgnc
# Out:
# 21764

# %%
(no_alias_symbol_record_count_hgnc/gene_record_count_ensg)*100
# Out:
# 44.96601309890291

# %% [markdown]
# how many gene records have a primary gene symbol that is a C#orf?

# %%
orf_record_set_hgnc = set(
    mini_hgnc_df[
        mini_hgnc_df["gene_symbol"].str.contains(r'^C.*ORF', case=False, na=False) &
        ~mini_hgnc_df["gene_symbol"].str.contains("-", na=False)
    ]
    .dropna(subset=["HGNC_ID"])["HGNC_ID"]
)

orf_record_count_hgnc = len(orf_record_set_hgnc)
orf_record_count_hgnc
# Out:
# 246

# %%
(orf_record_count_hgnc/gene_record_count_ensg)*100
# Out:
# 0.5082539616950063

# %% [markdown]
# how many gene records that have a primary gene symbol that is a FAM placeholder?

# %%
fam_record_set_hgnc = set(
    mini_hgnc_df[mini_hgnc_df["gene_symbol"].str.startswith('FAM', na=False)&
    ~mini_hgnc_df['gene_symbol']
    .str.contains('-', na=False)]
    .dropna(subset=["HGNC_ID"])
    ["HGNC_ID"]
)
fam_record_count_hgnc = len(fam_record_set_hgnc)
fam_record_count_hgnc
# Out:
# 371

# %%
(fam_record_count_hgnc/gene_record_count_ensg)*100
# Out:
# 0.7665130885725502

# %%
fam_record_set_hgnc_df = mini_hgnc_df[mini_hgnc_df['HGNC_ID'].isin(fam_record_set_hgnc)].copy()
fam_record_set_hgnc_df['fam_family'] = fam_record_set_hgnc_df['gene_symbol'].str.extract(r'^FAM(\d+)')
unique_families_count_hgnc = fam_record_set_hgnc_df['fam_family'].unique()
print("Number of unique FAM families in HGNC:", len(unique_families_count_hgnc))
# Out:
# Number of unique FAM families in HGNC: 107

# %% [markdown]
# how many gene records that have a primary gene symbol that is a KIAA placeholder?

# %%
kiaa_record_set_hgnc = set(
    mini_hgnc_df[mini_hgnc_df["gene_symbol"].str.startswith('KIAA', na=False)&
    ~mini_hgnc_df['gene_symbol']
    .str.contains('-', na=False)]
    .dropna(subset=["HGNC_ID"])
    ["HGNC_ID"]
)
kiaa_record_count_hgnc = len(kiaa_record_set_hgnc)
kiaa_record_count_hgnc
# Out:
# 32

# %%
(kiaa_record_count_hgnc/gene_record_count_ensg)*100
# Out:
# 0.06611433648065122

# %% [markdown]
# which gene records share a primary symbol with other gene records?

# %%
# groupby name and return a boolean of whether each has more than 1 unique Country
multi_primary = mini_hgnc_df.groupby(["gene_symbol"]).HGNC_ID.nunique().gt(1)

num_rows = mini_hgnc_df[mini_hgnc_df.gene_symbol.isin(multi_primary[multi_primary].index)].shape[0]
print(num_rows)

# use loc to only see those values that have `True` in `multi_country`:
multi_record_same_symbol_df = mini_hgnc_df.loc[mini_hgnc_df.gene_symbol.isin(multi_primary[multi_primary].index)].sort_values(by='gene_symbol')
multi_record_same_symbol_df.head(60)
# Out:
# 0
# Empty DataFrame
# Columns: [HGNC_ID, gene_symbol, alias_symbol, NCBI_ID, ENSG_ID]
# Index: []

# %% [markdown]
# How many ambiguous symbols result from alias-primary collisions?

# %%
ap_collision_ambiguous_symbol_set_hgnc = set(
    merged_alias_ap_collision_hgnc_df["collision"]
)
ap_collision_ambiguous_symbol_count_hgnc = len(ap_collision_ambiguous_symbol_set_hgnc)
ap_collision_ambiguous_symbol_count_hgnc
# Out:
# 492

# %% [markdown]
# How many records have at least one alias-primary collision (alias that matches another record's primary gene symbol)?

# %%
ap_record_set_hgnc = set(merged_alias_ap_collision_hgnc_df["HGNC_ID"])
ap_record_count_hgnc = len(ap_record_set_hgnc)
ap_record_count_hgnc
# Out:
# 546

# %% [markdown]
# # NCBI Gene

# %%
ncbi_file_path = "../input/Homo_sapiens.gene_info20250625"

raw_ncbi_df = pd.read_csv(ncbi_file_path, sep="\t")
# Drop all columns besides ENSG_ID, gene_symbol, and alias_symbol
raw_ncbi_df = raw_ncbi_df[
["GeneID", "Symbol", "Synonyms", "dbXrefs"]
]
raw_ncbi_df = raw_ncbi_df.rename(
    columns={"GeneID": "NCBI_ID", "Symbol": "gene_symbol", "Synonyms": "alias_symbol"})

# %% [markdown]
# Split dbXrefs into individual columns

# %%
raw_ncbi_df = raw_ncbi_df.assign(
    MIM=np.nan,
    HGNC_ID=np.nan,
    ENSG_ID=np.nan,
    AllianceGenome=np.nan,
    MIRbase=np.nan,
    IMGTgene_db=np.nan,
    dash=np.nan,
    unknown=np.nan,
)

# %%
index_pos = 0

print(len(raw_ncbi_df))
while index_pos < len(raw_ncbi_df):
    xrefs = raw_ncbi_df["dbXrefs"][index_pos].split("|")

    for xref in xrefs:
        xref = xref.lower()
        if xref.startswith("mim:"):
            xref = xref.replace("mim:", "")
            raw_ncbi_df["MIM"][index_pos] = xref
        elif xref.startswith("hgnc:hgnc:"):
            xref = xref.replace("hgnc:hgnc:", "")
            raw_ncbi_df["HGNC_ID"][index_pos] = xref
        elif xref.startswith("ensembl:"):
            xref = xref.replace("ensembl:", "")
            raw_ncbi_df["ENSG_ID"][index_pos] = xref
        elif xref.startswith("alliancegenome:"):
            xref = xref.replace("alliancegenome:", "")
            raw_ncbi_df["AllianceGenome"][index_pos] = xref
        elif xref.startswith("mirbase"):
            xref = xref.replace("mirbase:", "")
            raw_ncbi_df["MIRbase"][index_pos] = xref
        elif xref.startswith("imgt/gene-db:"):
            xref = xref.replace("imgt/gene-db:", "")
            raw_ncbi_df["IMGTgene_db"][index_pos] = xref
        elif xref.startswith("-"):
            raw_ncbi_df["dash"][index_pos] = xref
        else:
            raw_ncbi_df["unknown"][index_pos] = xref

    index_pos += 1
    pass

print(index_pos)
# Out:
# 193580
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_12104/3928680218.py:11: FutureWarning:
#
# ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_12104/3928680218.py:11: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_12104/3928680218.py:11: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '138670' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_12104/3928680218.py:14: FutureWarning:
#
# ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_12104/3928680218.py:14: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_12104/3928680218.py:14: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '5' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_12104/3928680218.py:17: FutureWarning:
#
# ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_12104/3928680218.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_12104/3928680218.py:17: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'ensg00000121410' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_12104/3928680218.py:20: FutureWarning:
#
# ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_12104/3928680218.py:20: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_12104/3928680218.py:20: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'hgnc:5' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_12104/3928680218.py:26: FutureWarning:
#
# ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_12104/3928680218.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_12104/3928680218.py:26: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'cd1d' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_12104/3928680218.py:28: FutureWarning:
#
# ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_12104/3928680218.py:28: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_12104/3928680218.py:28: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_12104/3928680218.py:23: FutureWarning:
#
# ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_12104/3928680218.py:23: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_12104/3928680218.py:23: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'mi0000060' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
# 193580

# %%
raw_ncbi_df["ENSG_ID"] = raw_ncbi_df["ENSG_ID"].str.replace("ensg", "ENSG", 1)

# %%
raw_ncbi_df = raw_ncbi_df.drop(
    [
        "AllianceGenome",
        "MIRbase",
        "IMGTgene_db",
        "dash",
        "unknown",
        "dbXrefs",
        "MIM",
    ],
    axis=1,
)

# %%
# Extract date from filename and check if it is before June 25, 2025
match = re.search(r'(\d{8})', ncbi_file_path)
file_date = datetime.strptime(match.group(1), "%Y%m%d") if match else None
cutoff_date = datetime.strptime("20250625", "%Y%m%d")

# Apply list-splitting logic for newer files
if file_date and file_date >= cutoff_date:
    raw_ncbi_df['alias_symbol'] = (
        raw_ncbi_df['alias_symbol']
        .fillna('')
        .str.split('|')
        .apply(lambda x: [a.strip() for a in x if a.strip()])
    )
    raw_ncbi_df = raw_ncbi_df.explode('alias_symbol')
raw_ncbi_df
# Out:
#         NCBI_ID gene_symbol alias_symbol HGNC_ID          ENSG_ID
# 0             1        A1BG          A1B       5  ENSG00000121410
# 0             1        A1BG          ABG       5  ENSG00000121410
# 0             1        A1BG          GAB       5  ENSG00000121410
# 0             1        A1BG     HYST2477       5  ENSG00000121410
# 1             2         A2M         A2MD       7  ENSG00000175899
# ...         ...         ...          ...     ...              ...
# 193575  8923215        trnD            -     NaN              NaN
# 193576  8923216        trnP            -     NaN              NaN
# 193577  8923217        trnA            -     NaN              NaN
# 193578  8923218        COX1            -     NaN              NaN
# 193579  8923219    16S rRNA            -     NaN              NaN
#
# [240508 rows x 5 columns]

# %%
raw_ncbi_df["NCBI_ID"] = raw_ncbi_df["NCBI_ID"].apply(
lambda x: f"GENE ID:{int(x)}" if pd.notna(x) and x == int(x) else f"GENE ID:{x}" if pd.notna(x) else x
)

# %%
raw_ncbi_df["HGNC_ID"] = raw_ncbi_df["HGNC_ID"].apply(
lambda x: f"HGNC:{int(x)}" if pd.notna(x) and x == int(x) else f"HGNC:{x}" if pd.notna(x) else x
)

# %%
raw_ncbi_df = raw_ncbi_df.replace(" ", np.nan)
raw_ncbi_df = raw_ncbi_df.replace("", np.nan)
raw_ncbi_df = raw_ncbi_df.replace("-", np.nan)

# %%
raw_ncbi_df.to_csv(f'../output/raw_ncbi_df.csv', index=True)

# %% [markdown]
# how many gene records for the NCBI data set before any kind of cleaning?

# %%
total_raw_gene_record_set_ncbi = set(raw_ncbi_df['NCBI_ID'])
total_raw_gene_record_count_ncbi = len(total_raw_gene_record_set_ncbi)
total_raw_gene_record_count_ncbi
# Out:
# 193580

# %% [markdown]
# how many gene records have the "phenotype only" property?

# %%
# This file (ncbi_records_w_property_pheno_only_20250630.txt) was generated through the NCBI Gene web page by 
# searching for these parameters "phenotype only [Properties] AND "Homo sapiens"[porgn:__txid9606]"
ncbi_pheno_records_df = pd.read_csv("../input/ncbi_records_w_property_pheno_only_20250630.txt", sep="\t")

ncbi_pheno_records_df = ncbi_pheno_records_df.rename(
    columns={"GeneID": "NCBI_ID", "Symbol": "gene_symbol", "Aliases": "alias_symbol"})

ncbi_pheno_records_df["NCBI_ID"] = ncbi_pheno_records_df["NCBI_ID"].apply(
lambda x: f"GENE ID:{int(x)}" if pd.notna(x) and x == int(x) else f"GENE ID:{x}" if pd.notna(x) else x
)

# %%
ncbi_pheno_records_df.loc[ncbi_pheno_records_df["gene_symbol"].str.startswith('LOC', na=False)]
# Out:
#       tax_id      Org_name         NCBI_ID  CurrentID Status gene_symbol  \
# 170     9606  Homo sapiens    GENE ID:7795          0   live     LOC7795
# 1096    9606  Homo sapiens  GENE ID:619539          0   live   LOC619539
#
#      alias_symbol                           description  \
# 170         MEMO1  Methylation modifier for class I HLA
# 1096          NaN     lentiginosis, inherited patterned
#
#                      other_designations  map_location chromosome  \
# 170                                 NaN    1p36.1-p35          1
# 1096  familial generalized lentiginosis  4q21.1-q22.3          4
#
#       genomic_nucleotide_accession.version  \
# 170                                    NaN
# 1096                                   NaN
#
#       start_position_on_the_genomic_accession  \
# 170                                       NaN
# 1096                                      NaN
#
#       end_position_on_the_genomic_accession  orientation  exon_count  \
# 170                                     NaN          NaN         NaN
# 1096                                    NaN          NaN         NaN
#
#           OMIM  Unnamed: 17
# 170   601201.0          NaN
# 1096  151001.0          NaN

# %%
# need to drop them
no_pheno_ncbi_df = raw_ncbi_df[~raw_ncbi_df['NCBI_ID'].isin(ncbi_pheno_records_df['NCBI_ID'])]

# %% [markdown]
# how many gene records have no primary gene symbol?

# %%
raw_no_primary_symbol_record_count_ncbi = (
    raw_ncbi_df[raw_ncbi_df["gene_symbol"].isna()]
    .dropna(subset=["NCBI_ID"])
    ["NCBI_ID"]
    .nunique()
)
raw_no_primary_symbol_record_count_ncbi
# Out:
# 0

# %%
(raw_no_primary_symbol_record_count_ncbi/total_raw_gene_record_count_ncbi)*100
# Out:
# 0.0

# %% [markdown]
# how many gene records that have a primary gene symbol that is a LOC placeholder?

# %%
raw_loc_record_count_ncbi = (
    raw_ncbi_df[raw_ncbi_df["gene_symbol"].str.startswith('LOC', na=False)&
    ~raw_ncbi_df['gene_symbol']
    .str.contains('-', na=False)]
    .dropna(subset=["NCBI_ID"])
    ["NCBI_ID"]
    .nunique()
)
raw_loc_record_count_ncbi
# Out:
# 147700

# %%
no_pheno_loc_ncbi_df = no_pheno_ncbi_df[~no_pheno_ncbi_df['gene_symbol'].str.startswith('LOC', na=False)]

# %%
len(set(no_pheno_loc_ncbi_df["NCBI_ID"]))
# Out:
# 44712

# %% [markdown]
# how many gene records are sub species records: "homo sapiens ssp denisova"[Organism]

# %%
ncbi_denisova_records_df = pd.read_csv("../input/ncbi_denisova_20250630.txt", sep="\t")

ncbi_denisova_records_df = ncbi_denisova_records_df.rename(
    columns={"GeneID": "NCBI_ID", "Symbol": "gene_symbol", "Aliases": "alias_symbol"})

ncbi_denisova_records_df["NCBI_ID"] = ncbi_denisova_records_df["NCBI_ID"].apply(
lambda x: f"GENE ID:{int(x)}" if pd.notna(x) and x == int(x) else f"GENE ID:{x}" if pd.notna(x) else x
)

# %%
len(set(ncbi_denisova_records_df["NCBI_ID"]))
# Out:
# 36

# %%
no_pheno_loc_denisova_ncbi_df = no_pheno_loc_ncbi_df[~no_pheno_loc_ncbi_df['NCBI_ID'].isin(ncbi_denisova_records_df['NCBI_ID'])]

# %%
len(set(no_pheno_loc_denisova_ncbi_df["NCBI_ID"]))
# Out:
# 44676

# %% [markdown]
# Drop sub species records: "homo sapiens neanderthalensis"[Organism]

# %%
ncbi_neanderthalensis_records_df = pd.read_csv("../input/ncbi_neanderthalensis_20250630.txt", sep="\t")

ncbi_neanderthalensis_records_df = ncbi_neanderthalensis_records_df.rename(
    columns={"GeneID": "NCBI_ID", "Symbol": "gene_symbol", "Aliases": "alias_symbol"})

ncbi_neanderthalensis_records_df["NCBI_ID"] = ncbi_neanderthalensis_records_df["NCBI_ID"].apply(
lambda x: f"GENE ID:{int(x)}" if pd.notna(x) and x == int(x) else f"GENE ID:{x}" if pd.notna(x) else x
)

# %%
len(set(ncbi_neanderthalensis_records_df["NCBI_ID"]))
# Out:
# 37

# %%
no_pheno_loc_denisova_neanderthalis_ncbi_df = no_pheno_loc_denisova_ncbi_df[~no_pheno_loc_denisova_ncbi_df['NCBI_ID'].isin(ncbi_neanderthalensis_records_df['NCBI_ID'])]

# %% [markdown]
# how many records with an @ symbol in the primary gene symbol?

# %%
at_symbol_records_ncbi_df = no_pheno_loc_denisova_neanderthalis_ncbi_df[no_pheno_loc_denisova_neanderthalis_ncbi_df['gene_symbol'].str.contains('@', na=False)]
len(set(at_symbol_records_ncbi_df["NCBI_ID"]))
# Out:
# 11

# %%
len(set(no_pheno_loc_denisova_neanderthalis_ncbi_df["NCBI_ID"]))
# Out:
# 44639

# %%
no_pheno_loc_denisova_neanderthalis_at_ncbi_df = no_pheno_loc_denisova_neanderthalis_ncbi_df[~no_pheno_loc_denisova_neanderthalis_ncbi_df['NCBI_ID'].isin(at_symbol_records_ncbi_df['NCBI_ID'])]

# %%
len(set(no_pheno_loc_denisova_neanderthalis_at_ncbi_df["NCBI_ID"]))
# Out:
# 44628

# %%
create_ap_collision_df(no_pheno_loc_denisova_neanderthalis_at_ncbi_df, "NCBI")
# Out:
# All collisions are present in gene alias lists.
#      NCBI_ID gene_symbol alias_symbol HGNC_ID          ENSG_ID
# 0  GENE ID:1        A1BG          A1B  HGNC:5  ENSG00000121410
# 0  GENE ID:1        A1BG          ABG  HGNC:5  ENSG00000121410
# 0  GENE ID:1        A1BG          GAB  HGNC:5  ENSG00000121410
# 0  GENE ID:1        A1BG     HYST2477  HGNC:5  ENSG00000121410
# 1  GENE ID:2         A2M         A2MD  HGNC:7  ENSG00000175899

# %%
mini_ncbi_df = pd.read_csv(
    "../output/mini_ncbi_df.csv", index_col=[0])

# %%
subset_genes_ncbi_df = pd.read_csv(
    "../output/subset_genes_ncbi_df.csv", index_col=[0])
subset_genes_ncbi_df
# Out:
#                   NCBI_ID gene_symbol alias_symbol     HGNC_ID  \
# 0               GENE ID:1        A1BG          A1B      HGNC:5
# 0               GENE ID:1        A1BG          ABG      HGNC:5
# 0               GENE ID:1        A1BG          GAB      HGNC:5
# 0               GENE ID:1        A1BG     HYST2477      HGNC:5
# 1               GENE ID:2         A2M         A2MD      HGNC:7
# ...                   ...         ...          ...         ...
# 193502  GENE ID:141732005   ADCY2-AS1          NaN  HGNC:40064
# 193503  GENE ID:141732006    NSG2-AS1          NaN  HGNC:41074
# 193504  GENE ID:141732007    ST18-AS1          NaN  HGNC:58430
# 193505  GENE ID:141732008  MICAL2-AS1          NaN  HGNC:58437
# 193506  GENE ID:141732009  TRIM41-AS1          NaN  HGNC:40863
#
#                 ENSG_ID
# 0       ENSG00000121410
# 0       ENSG00000121410
# 0       ENSG00000121410
# 0       ENSG00000121410
# 1       ENSG00000175899
# ...                 ...
# 193502              NaN
# 193503              NaN
# 193504              NaN
# 193505              NaN
# 193506              NaN
#
# [91355 rows x 5 columns]

# %%
merged_alias_ap_collision_ncbi_df = pd.read_csv(
    "../output/merged_alias_ap_collision_ncbi_df.csv", index_col=[0])
merged_alias_ap_collision_ncbi_df
# Out:
#              NCBI_ID gene_symbol collision source     HGNC_ID  \
# 0       GENE ID:3494       IGHA2       A2M   NCBI   HGNC:5479
# 1      GENE ID:54776    PPP1R12C     AAVS1   NCBI  HGNC:14947
# 2       GENE ID:6646       SOAT1     ACAT1   NCBI  HGNC:11177
# 3       GENE ID:8435       SOAT2     ACAT2   NCBI  HGNC:11178
# 4       GENE ID:9034       CCRL2     ACKR5   NCBI   HGNC:1612
# ...              ...         ...       ...    ...         ...
# 2031   GENE ID:29903     CCDC106    ZNF581   NCBI  HGNC:30181
# 2032  GENE ID:146540      ZNF785    ZNF688   NCBI  HGNC:26496
# 2033   GENE ID:57829         ZP4       ZP1   NCBI  HGNC:15770
# 2035   GENE ID:55663      ZNF446   ZSCAN30   NCBI  HGNC:21036
# 2036  GENE ID:342357     ZKSCAN2   ZSCAN31   NCBI  HGNC:25677
#
#               ENSG_ID                       alias_symbol
# 0     ENSG00000211890                                A2M
# 1     ENSG00000125503          AAVS1,LENG3,MBS85,p84,p85
# 2     ENSG00000057252  ACACT,ACAT,ACAT-1,ACAT1,SOAT,STAT
# 3     ENSG00000167780                 ACACT2,ACAT2,ARGP2
# 4     ENSG00000121797  ACKR5,CKRX,CRAM,CRAM-A,CRAM-B,HCR
# ...               ...                                ...
# 2031  ENSG00000173581                    HSU79303,ZNF581
# 2032  ENSG00000197162                             ZNF688
# 2033  ENSG00000116996         ZBP,ZP1,ZP1B,ZPB,ZPB2,Zp-4
# 2035  ENSG00000083838           ZKSCAN20,ZSCAN30,ZSCAN52
# 2036  ENSG00000155592             ZNF694,ZSCAN31,ZSCAN34
#
# [1613 rows x 7 columns]

# %% [markdown]
# how many gene records are in the NCBI database?

# %%
gene_record_set_ncbi = set(mini_ncbi_df['NCBI_ID'])
gene_record_count_ncbi = len(gene_record_set_ncbi)
gene_record_count_ncbi
# Out:
# 44628

# %% [markdown]
# how many unique primary gene symbols are in the NCBI data set?

# %%
primary_symbol_set_ncbi = set(mini_ncbi_df['gene_symbol'])
primary_symbol_count_ncbi = len(primary_symbol_set_ncbi)
primary_symbol_count_ncbi
# Out:
# 44530

# %% [markdown]
# how many unique alias gene symbols are in the NCBI data set?

# %%
alias_symbol_set_ncbi = set(mini_ncbi_df['alias_symbol'])
alias_symbol_count_ncbi = len(alias_symbol_set_ncbi)
alias_symbol_count_ncbi
# Out:
# 69210

# %% [markdown]
# how many unique gene symbols in total are there in the NCBI data set??

# %%
total_symbol_count_ncbi = pd.concat([mini_ncbi_df["gene_symbol"], mini_ncbi_df["alias_symbol"]]).dropna().nunique()
total_symbol_count_ncbi
# Out:
# 112266

# %% [markdown]
# how many gene records have no alias symbols?

# %%
no_alias_symbol_record_count_ncbi = (
    mini_ncbi_df[mini_ncbi_df["alias_symbol"].isna()]
    .dropna(subset=["NCBI_ID"])
    ["NCBI_ID"]
    .nunique()
)
no_alias_symbol_record_count_ncbi
# Out:
# 17380

# %%
(no_alias_symbol_record_count_ncbi/gene_record_count_ncbi)*100
# Out:
# 38.94416061665322

# %% [markdown]
# how many gene records have a primary gene symbol that is a C#orf?

# %%
orf_record_set_ncbi = set(mini_ncbi_df[
    mini_ncbi_df['gene_symbol']
    .str.contains(r'^C.*ORF', case=False, na=False) &
    ~mini_ncbi_df['gene_symbol']
    .str.contains('-', na=False)
])
orf_record_count_ncbi = len(orf_record_set_ncbi)
orf_record_count_ncbi
# Out:
# 5

# %%
(orf_record_count_ncbi/gene_record_count_ncbi)*100
# Out:
# 0.011203728600878373

# %% [markdown]
# how many gene records that have a primary gene symbol that is a FAM placeholder?

# %%
fam_record_set_ncbi = set(
    mini_ncbi_df[mini_ncbi_df["gene_symbol"].str.startswith('FAM', na=False)&
    ~mini_ncbi_df['gene_symbol']
    .str.contains('-', na=False)]
    .dropna(subset=["NCBI_ID"])
    ["NCBI_ID"]
)
fam_record_count_ncbi = len(fam_record_set_ncbi)
fam_record_count_ncbi
# Out:
# 371

# %%
(fam_record_count_ncbi/gene_record_count_ncbi)*100
# Out:
# 0.8313166621851753

# %%
fam_record_set_ncbi_df = mini_ncbi_df[mini_ncbi_df['NCBI_ID'].isin(fam_record_set_ncbi)].copy()
fam_record_set_ncbi_df['fam_family'] = fam_record_set_ncbi_df['gene_symbol'].str.extract(r'^FAM(\d+)')
unique_families_count_ncbi = fam_record_set_ncbi_df['fam_family'].unique()
print("Number of unique FAM families in NCBI:", len(unique_families_count_ncbi))
# Out:
# Number of unique FAM families in NCBI: 107

# %% [markdown]
# how many gene records that have a primary gene symbol that is a KIAA placeholder?

# %%
kiaa_record_set_ncbi = set(
    mini_ncbi_df[mini_ncbi_df["gene_symbol"].str.startswith('KIAA', na=False)&
    ~mini_ncbi_df['gene_symbol']
    .str.contains('-', na=False)]
    .dropna(subset=["NCBI_ID"])
    ["NCBI_ID"]
)
kiaa_record_count_ncbi = len(kiaa_record_set_ncbi)
kiaa_record_count_ncbi
# Out:
# 33

# %%
(kiaa_record_count_ncbi/gene_record_count_ncbi)*100
# Out:
# 0.07394460876579727

# %% [markdown]
# which gene records share a primary symbol with other gene records?

# %%
# groupby name and return a boolean of whether each has more than 1 unique Country
multi_primary = mini_ncbi_df.groupby(["gene_symbol"]).NCBI_ID.nunique().gt(1)

num_rows = mini_ncbi_df[mini_ncbi_df.gene_symbol.isin(multi_primary[multi_primary].index)].shape[0]
print(num_rows)

# use loc to only see those values that have `True` in `multi_country`:
multi_record_same_symbol_df = mini_ncbi_df.loc[mini_ncbi_df.gene_symbol.isin(multi_primary[multi_primary].index)].sort_values(by='gene_symbol')
multi_record_same_symbol_df.head(60)
# Out:
# 110
#                  NCBI_ID gene_symbol alias_symbol     HGNC_ID ENSG_ID
# 3550        GENE ID:4549        RNR1       MTRNR1   HGNC:7470     NaN
# 4762        GENE ID:6052        RNR1          NaN  HGNC:10082     NaN
# 3551        GENE ID:4550        RNR2       MTRNR2   HGNC:7471     NaN
# 4763        GENE ID:6053        RNR2          NaN  HGNC:10083     NaN
# 65892  GENE ID:124901565   TRNAA-AGC          NaN         NaN     NaN
# 65891  GENE ID:124901564   TRNAA-AGC          NaN         NaN     NaN
# 65890  GENE ID:124901563   TRNAA-AGC          NaN         NaN     NaN
# 65889  GENE ID:124901562   TRNAA-AGC          NaN         NaN     NaN
# 70782  GENE ID:124906586   TRNAA-AGC          NaN         NaN     NaN
# 65888  GENE ID:124901561   TRNAA-AGC          NaN         NaN     NaN
# 70114  GENE ID:124905878   TRNAD-GUC          NaN         NaN     NaN
# 70102  GENE ID:124905866   TRNAD-GUC          NaN         NaN     NaN
# 70099  GENE ID:124905863   TRNAD-GUC          NaN         NaN     NaN
# 70108  GENE ID:124905872   TRNAD-GUC          NaN         NaN     NaN
# 70096  GENE ID:124905860   TRNAD-GUC          NaN         NaN     NaN
# 70093  GENE ID:124905857   TRNAD-GUC          NaN         NaN     NaN
# 70111  GENE ID:124905875   TRNAD-GUC          NaN         NaN     NaN
# 70090  GENE ID:124905854   TRNAD-GUC          NaN         NaN     NaN
# 70117  GENE ID:124905881   TRNAD-GUC          NaN         NaN     NaN
# 70120  GENE ID:124905884   TRNAD-GUC          NaN         NaN     NaN
# 70123  GENE ID:124905887   TRNAD-GUC          NaN         NaN     NaN
# 70105  GENE ID:124905869   TRNAD-GUC          NaN         NaN     NaN
# 70126  GENE ID:124905890   TRNAD-GUC          NaN         NaN     NaN
# 70138  GENE ID:124905902   TRNAD-GUC          NaN         NaN     NaN
# 70132  GENE ID:124905896   TRNAD-GUC          NaN         NaN     NaN
# 70135  GENE ID:124905899   TRNAD-GUC          NaN         NaN     NaN
# 70129  GENE ID:124905893   TRNAD-GUC          NaN         NaN     NaN
# 70103  GENE ID:124905867   TRNAE-CUC          NaN         NaN     NaN
# 70106  GENE ID:124905870   TRNAE-CUC          NaN         NaN     NaN
# 70100  GENE ID:124905864   TRNAE-CUC          NaN         NaN     NaN
# 70139  GENE ID:124905903   TRNAE-CUC          NaN         NaN     NaN
# 70121  GENE ID:124905885   TRNAE-CUC          NaN         NaN     NaN
# 70097  GENE ID:124905861   TRNAE-CUC          NaN         NaN     NaN
# 70136  GENE ID:124905900   TRNAE-CUC          NaN         NaN     NaN
# 70109  GENE ID:124905873   TRNAE-CUC          NaN         NaN     NaN
# 70124  GENE ID:124905888   TRNAE-CUC          NaN         NaN     NaN
# 70133  GENE ID:124905897   TRNAE-CUC          NaN         NaN     NaN
# 70091  GENE ID:124905855   TRNAE-CUC          NaN         NaN     NaN
# 70127  GENE ID:124905891   TRNAE-CUC          NaN         NaN     NaN
# 70112  GENE ID:124905876   TRNAE-CUC          NaN         NaN     NaN
# 70115  GENE ID:124905879   TRNAE-CUC          NaN         NaN     NaN
# 70130  GENE ID:124905894   TRNAE-CUC          NaN         NaN     NaN
# 70094  GENE ID:124905858   TRNAE-CUC          NaN         NaN     NaN
# 70118  GENE ID:124905882   TRNAE-CUC          NaN         NaN     NaN
# 70144  GENE ID:124905908   TRNAE-UUC          NaN         NaN     NaN
# 54286  GENE ID:107987368   TRNAE-UUC          NaN         NaN     NaN
# 69857  GENE ID:124905580   TRNAE-UUC          NaN         NaN     NaN
# 69860  GENE ID:124905583   TRNAE-UUC          NaN         NaN     NaN
# 69861  GENE ID:124905584   TRNAE-UUC          NaN         NaN     NaN
# 69863  GENE ID:124905586   TRNAE-UUC          NaN         NaN     NaN
# 69858  GENE ID:124905581   TRNAG-CCC          NaN         NaN     NaN
# 69855  GENE ID:124905578   TRNAG-CCC          NaN         NaN     NaN
# 69865  GENE ID:124905588   TRNAG-CCC          NaN         NaN     NaN
# 70143  GENE ID:124905907   TRNAG-GCC          NaN         NaN     NaN
# 70146  GENE ID:124905910   TRNAG-GCC          NaN         NaN     NaN
# 70083  GENE ID:124905847   TRNAG-GCC          NaN         NaN     NaN
# 70148  GENE ID:124905912   TRNAG-GCC          NaN         NaN     NaN
# 70150  GENE ID:124905914   TRNAG-GCC          NaN         NaN     NaN
# 70085  GENE ID:124905849   TRNAG-GCC          NaN         NaN     NaN
# 70152  GENE ID:124905916   TRNAG-GCC          NaN         NaN     NaN

# %%
multi_record_same_symbol_df.iloc[60:110]
# Out:
#                  NCBI_ID gene_symbol alias_symbol HGNC_ID ENSG_ID
# 70154  GENE ID:124905918   TRNAG-GCC          NaN     NaN     NaN
# 70157  GENE ID:124905921   TRNAG-GCC          NaN     NaN     NaN
# 70159  GENE ID:124905923   TRNAG-GCC          NaN     NaN     NaN
# 70089  GENE ID:124905853   TRNAG-GCC          NaN     NaN     NaN
# 70161  GENE ID:124905925   TRNAG-GCC          NaN     NaN     NaN
# 70163  GENE ID:124905927   TRNAG-GCC          NaN     NaN     NaN
# 70165  GENE ID:124905929   TRNAG-GCC          NaN     NaN     NaN
# 70167  GENE ID:124905931   TRNAG-GCC          NaN     NaN     NaN
# 70169  GENE ID:124905933   TRNAG-GCC          NaN     NaN     NaN
# 70087  GENE ID:124905851   TRNAG-GCC          NaN     NaN     NaN
# 70134  GENE ID:124905898   TRNAG-UCC          NaN     NaN     NaN
# 70140  GENE ID:124905904   TRNAG-UCC          NaN     NaN     NaN
# 70104  GENE ID:124905868   TRNAG-UCC          NaN     NaN     NaN
# 70101  GENE ID:124905865   TRNAG-UCC          NaN     NaN     NaN
# 70137  GENE ID:124905901   TRNAG-UCC          NaN     NaN     NaN
# 70131  GENE ID:124905895   TRNAG-UCC          NaN     NaN     NaN
# 70107  GENE ID:124905871   TRNAG-UCC          NaN     NaN     NaN
# 70098  GENE ID:124905862   TRNAG-UCC          NaN     NaN     NaN
# 70095  GENE ID:124905859   TRNAG-UCC          NaN     NaN     NaN
# 70110  GENE ID:124905874   TRNAG-UCC          NaN     NaN     NaN
# 70092  GENE ID:124905856   TRNAG-UCC          NaN     NaN     NaN
# 70113  GENE ID:124905877   TRNAG-UCC          NaN     NaN     NaN
# 70116  GENE ID:124905880   TRNAG-UCC          NaN     NaN     NaN
# 70122  GENE ID:124905886   TRNAG-UCC          NaN     NaN     NaN
# 70119  GENE ID:124905883   TRNAG-UCC          NaN     NaN     NaN
# 70128  GENE ID:124905892   TRNAG-UCC          NaN     NaN     NaN
# 70125  GENE ID:124905889   TRNAG-UCC          NaN     NaN     NaN
# 70142  GENE ID:124905906   TRNAL-CAG          NaN     NaN     NaN
# 70168  GENE ID:124905932   TRNAL-CAG          NaN     NaN     NaN
# 70166  GENE ID:124905930   TRNAL-CAG          NaN     NaN     NaN
# 70164  GENE ID:124905928   TRNAL-CAG          NaN     NaN     NaN
# 70162  GENE ID:124905926   TRNAL-CAG          NaN     NaN     NaN
# 70160  GENE ID:124905924   TRNAL-CAG          NaN     NaN     NaN
# 70145  GENE ID:124905909   TRNAL-CAG          NaN     NaN     NaN
# 70158  GENE ID:124905922   TRNAL-CAG          NaN     NaN     NaN
# 70153  GENE ID:124905917   TRNAL-CAG          NaN     NaN     NaN
# 70156  GENE ID:124905920   TRNAL-CAG          NaN     NaN     NaN
# 70088  GENE ID:124905852   TRNAL-CAG          NaN     NaN     NaN
# 70151  GENE ID:124905915   TRNAL-CAG          NaN     NaN     NaN
# 70086  GENE ID:124905850   TRNAL-CAG          NaN     NaN     NaN
# 70149  GENE ID:124905913   TRNAL-CAG          NaN     NaN     NaN
# 70084  GENE ID:124905848   TRNAL-CAG          NaN     NaN     NaN
# 70147  GENE ID:124905911   TRNAL-CAG          NaN     NaN     NaN
# 70170  GENE ID:124905934   TRNAL-CAG          NaN     NaN     NaN
# 69859  GENE ID:124905582   TRNAN-GUU          NaN     NaN     NaN
# 69864  GENE ID:124905587   TRNAN-GUU          NaN     NaN     NaN
# 69862  GENE ID:124905585   TRNAN-GUU          NaN     NaN     NaN
# 69856  GENE ID:124905579   TRNAN-GUU          NaN     NaN     NaN
# 53230  GENE ID:107985614   TRNAV-CAC          NaN     NaN     NaN
# 53231  GENE ID:107985615   TRNAV-CAC          NaN     NaN     NaN

# %% [markdown]
# How many ambiguous symbols result from alias-primary collisions?

# %%
ap_collision_ambiguous_symbol_set_ncbi = set(
    merged_alias_ap_collision_ncbi_df["collision"]
)
ap_collision_ambiguous_symbol_count_ncbi = len(ap_collision_ambiguous_symbol_set_ncbi)
ap_collision_ambiguous_symbol_count_ncbi
# Out:
# 1394

# %% [markdown]
# How many records have at least one alias-primary collision (alias that matches another record's primary gene symbol)?

# %%
ap_record_set_ncbi = set(merged_alias_ap_collision_ncbi_df["NCBI_ID"])
ap_record_count_ncbi = len(ap_record_set_ncbi)
ap_record_count_ncbi
# Out:
# 1613

# %% [markdown]
# # Merge 3 sets together

# %%
merged_alias_primary_collisions_df = pd.concat(
    [
        merged_alias_ap_collision_hgnc_df[
            ["gene_symbol", "alias_symbol", "collision", "source", "ENSG_ID", "HGNC_ID", "NCBI_ID"]
        ],
        merged_alias_ap_collision_ncbi_df[
            ["gene_symbol", "alias_symbol", "collision", "source", "ENSG_ID", "HGNC_ID", "NCBI_ID"]
        ],
        merged_alias_ap_collision_ensg_df[
            ["gene_symbol", "alias_symbol", "collision", "source", "ENSG_ID", "HGNC_ID", "NCBI_ID"]
        ],
    ]
)
merged_alias_primary_collisions_df
# Out:
#     gene_symbol                       alias_symbol collision source  \
# 0      PPP1R12C  AAVS1,DKFZP434D0412,MBS85,p84,p85     AAVS1   HGNC
# 1         SOAT1                         ACAT,ACAT1     ACAT1   HGNC
# 2         SOAT2                              ACAT2     ACAT2   HGNC
# 3         CCRL2       ACKR5,CKRX,CRAM-A,CRAM-B,HCR     ACKR5   HGNC
# 4       NDUFAB1               ACP,ACP1,FASN2A,SDAP      ACP1   HGNC
# ..          ...                                ...       ...    ...
# 806      ZNF121                D19S204,ZHC32,ZNF20     ZNF20   ENSG
# 807      RNF141                       ZFP26,ZNF230    ZNF230   ENSG
# 808    ZNF322P1                     ZNF322,ZNF322B    ZNF322   ENSG
# 809      ZNF106               SH3BP3,ZFP106,ZNF474    ZNF474   ENSG
# 810        ZFP1                    FLJ34243,ZNF475    ZNF475   ENSG
#
#              ENSG_ID     HGNC_ID         NCBI_ID
# 0    ENSG00000125503  HGNC:14947   GENE ID:54776
# 1    ENSG00000057252  HGNC:11177    GENE ID:6646
# 2    ENSG00000167780  HGNC:11178    GENE ID:8435
# 3    ENSG00000121797   HGNC:1612    GENE ID:9034
# 4    ENSG00000004779   HGNC:7694    GENE ID:4706
# ..               ...         ...             ...
# 806  ENSG00000197961  HGNC:12904    GENE ID:7675
# 807  ENSG00000110315  HGNC:21159   GENE ID:50862
# 808  ENSG00000188801  HGNC:14003             NaN
# 809  ENSG00000103994  HGNC:12886   GENE ID:64397
# 810  ENSG00000184517  HGNC:23328  GENE ID:162239
#
# [2926 rows x 7 columns]

# %%
merged_alias_primary_collisions_df.loc[
    merged_alias_primary_collisions_df["collision"] == "KRAS"
]
# Out:
#     gene_symbol                          alias_symbol collision source  \
# 963        NRAS  ALPS4,CMNS,KRAS,N-ras,NCMS,NRAS1,NS6      KRAS   NCBI
#
#              ENSG_ID    HGNC_ID       NCBI_ID
# 963  ENSG00000213281  HGNC:7989  GENE ID:4893

# %% [markdown]
# # Convert to csv

# %%
merged_alias_primary_collisions_df.to_csv(
    "../output/merged_alias_primary_collisions_df.csv", index=False
)

# %%
common_ap_collision_ambiguous_symbol_set = (
    ap_collision_ambiguous_symbol_set_ncbi
    & ap_collision_ambiguous_symbol_set_hgnc
    & ap_collision_ambiguous_symbol_set_ensg
)
common_ap_collision_ambiguous_symbol_set
# Out:
# {'ACAT1',
#  'ACAT2',
#  'ACP1',
#  'ACTBP2',
#  'ADA2',
#  'ADRA1A',
#  'AGT',
#  'AIP',
#  'ALB',
#  'AMN',
#  'APC2',
#  'AR',
#  'ARC',
#  'ARG1',
#  'ARHGAP10',
#  'ARL1',
#  'ARSB',
#  'ASIP',
#  'ATF1',
#  'ATR',
#  'AVP',
#  'B3GNT8',
#  'BACH1',
#  'BAP1',
#  'BCAM',
#  'BCRP1',
#  'BCRP2',
#  'BDP1',
#  'BNC1',
#  'BRAP',
#  'BRCC3',
#  'BRI3',
#  'BST1',
#  'BTF3',
#  'C6',
#  'C7',
#  'CA11',
#  'CABP1',
#  'CAD',
#  'CAMP',
#  'CAP1',
#  'CAP2',
#  'CAPS',
#  'CAPS2',
#  'CARF',
#  'CAST',
#  'CBLC',
#  'CCR10',
#  'CCR4',
#  'CDH1',
#  'CDH20',
#  'CDH7',
#  'CDKN1A',
#  'CDS1',
#  'CES2',
#  'CHD5',
#  'CHL1',
#  'CHP1',
#  'CIC',
#  'CKLF',
#  'CLC',
#  'CLCP1',
#  'CLIP4',
#  'CNP',
#  'CNR1',
#  'CNR2',
#  'COP1',
#  'CPA3',
#  'CPA6',
#  'CPD',
#  'CPN1',
#  'CPN2',
#  'CPS1',
#  'CREB3',
#  'CRIP1',
#  'CRP',
#  'CSN2',
#  'CSN3',
#  'CSNK2A1',
#  'CST6',
#  'CSTP1',
#  'CTAGE4',
#  'CTH',
#  'DAO',
#  'DAP',
#  'DAP3',
#  'DBI',
#  'DBP',
#  'DEF6',
#  'DIO1',
#  'DLC1',
#  'DMC1',
#  'DMP1',
#  'DOK1',
#  'DRC3',
#  'DRG1',
#  'DRP2',
#  'DSC1',
#  'DUSP1',
#  'DUSP23',
#  'DUSP26',
#  'EAF2',
#  'EBP',
#  'ECD',
#  'EIF2A',
#  'ELF1',
#  'ELK1',
#  'ELN',
#  'EMB',
#  'EPO',
#  'F11',
#  'F3',
#  'FAAH',
#  'FABP5',
#  'FADS6',
#  'FAH',
#  'FAS',
#  'FBP2',
#  'FBXO31',
#  'FCRL2',
#  'FEM1A',
#  'FEZ1',
#  'FGF2',
#  'FLG',
#  'FLI1',
#  'FZD3',
#  'GAB1',
#  'GAL',
#  'GAL3ST2',
#  'GALNT15',
#  'GALNT17',
#  'GAR1',
#  'GCK',
#  'GCKR',
#  'GCOM1',
#  'GDA',
#  'GEM',
#  'GIP',
#  'GK2',
#  'GLA',
#  'GLS',
#  'GLUD1',
#  'GLUD2',
#  'GOT1',
#  'GPI',
#  'GPT',
#  'GPX6',
#  'GRIN1',
#  'GRIP1',
#  'GRP',
#  'GSG1',
#  'HAP1',
#  'HAS1',
#  'HBM',
#  'HCP5',
#  'HCRTR2',
#  'HCST',
#  'HDC',
#  'HES1',
#  'HGF',
#  'HK1',
#  'HK2',
#  'HK3',
#  'HLA-H',
#  'HLF',
#  'HP',
#  'HPCA',
#  'HPF1',
#  'HRG',
#  'HRH1',
#  'HSD17B7',
#  'HTRA3',
#  'IFNA13',
#  'IK',
#  'IL25',
#  'IMP3',
#  'IMP4',
#  'IQCH',
#  'ISY1',
#  'KLF14',
#  'KLHL6',
#  'KLK7',
#  'KRTAP5-1',
#  'KRTAP5-11',
#  'KRTAP5-2',
#  'KRTAP5-3',
#  'KRTAP5-8',
#  'KRTAP5-9',
#  'KSR2',
#  'LAMA3',
#  'LAT',
#  'LAT2',
#  'LBH',
#  'LCP1',
#  'LDB1',
#  'LIG1',
#  'LIPA',
#  'LNP1',
#  'LRP1',
#  'LRP2BP',
#  'LRP4',
#  'MADD',
#  'MAFA',
#  'MAK',
#  'MAL',
#  'MAP1A',
#  'MAP2',
#  'MAS1',
#  'MAST1',
#  'MBP',
#  'ME1',
#  'ME2',
#  'ME3',
#  'MED1',
#  'MED24',
#  'MED25',
#  'MET',
#  'MGA',
#  'MGAT1',
#  'MGAT2',
#  'MGAT3',
#  'MIA2',
#  'MIF',
#  'MIP',
#  'MLC1',
#  'MLN',
#  'MOS',
#  'MPDZ',
#  'MPP1',
#  'MPP2',
#  'MPP4',
#  'MPP7',
#  'MRPL27',
#  'MRPS28',
#  'MRPS35',
#  'MS4A10',
#  'MS4A7',
#  'MS4A8',
#  'MSL1',
#  'MST1',
#  'MTCP1',
#  'MTF1',
#  'MYH14',
#  'MYNN',
#  'MYO1C',
#  'MYT1',
#  'NAF1',
#  'NANOGP2',
#  'NANOGP3',
#  'NANOGP4',
#  'NAPA',
#  'NAPB',
#  'NARF',
#  'NAT1',
#  'NAT2',
#  'NBN',
#  'NET1',
#  'NGB',
#  'NLK',
#  'NMB',
#  'NME1',
#  'NMI',
#  'NOP9',
#  'NOS1',
#  'NOS2',
#  'NOS3',
#  'NPR2',
#  'NPR3',
#  'NRAP',
#  'NRF1',
#  'NRP2',
#  'NSL1',
#  'NTN4',
#  'ODC1',
#  'OPA1',
#  'ORC1',
#  'OSM',
#  'OSR1',
#  'OXR1',
#  'PAK1',
#  'PAK3',
#  'PAK5',
#  'PAM',
#  'PAN2',
#  'PAN3',
#  'PC',
#  'PCM1',
#  'PDF',
#  'PDK1',
#  'PDP1',
#  'PDX1',
#  'PGAM1',
#  'PGP',
#  'PGS1',
#  'PIGF',
#  'PIM1',
#  'PISD',
#  'PKD2',
#  'PLAC8',
#  'PMP22',
#  'PMS2P13',
#  'PNP',
#  'POLK',
#  'POLQ',
#  'POMP',
#  'POP1',
#  'POP4',
#  'POR',
#  'PPAT',
#  'PPOX',
#  'PRB1',
#  'PRDX6',
#  'PREP',
#  'PRG2',
#  'PRG3',
#  'PRR4',
#  'PRX',
#  'PSAP',
#  'PSG1',
#  'PTH2',
#  'PTPRO',
#  'PVALB',
#  'RAC1',
#  'RAC3',
#  'RAD1',
#  'RAE1',
#  'RAF1',
#  'RAI1',
#  'RASSF4',
#  'RAX',
#  'RBM5-AS1',
#  'RBP1',
#  'RBP2',
#  'RBP3',
#  'REN',
#  'RFC1',
#  'RGP1',
#  'RGR',
#  'RGS13',
#  'RHEB',
#  'RHO',
#  'RIF1',
#  'RILP',
#  'RLF',
#  'RNASE9',
#  'ROR1',
#  'RP1',
#  'RP2',
#  'RPA1',
#  'RPA2',
#  'RPF1',
#  'RPL10',
#  'RPL13',
#  'RPL17',
#  'RPL23',
#  'RPL24',
#  'RPN1',
#  'RPN2',
#  'RPS12',
#  'RRP1',
#  'RS1',
#  'S100A16',
#  'SAG',
#  'SAP130',
#  'SAT2',
#  'SCAF1',
#  'SCP2',
#  'SCYL1',
#  'SCYL2',
#  'SCYL3',
#  'SDS',
#  'SELP',
#  'SF1',
#  'SF3B1',
#  'SFN',
#  'SI',
#  'SIT1',
#  'SKP2',
#  'SLA',
#  'SLIT1',
#  'SLIT3',
#  'SLK',
#  'SMAD1',
#  'SMAP2',
#  'SMO',
#  'SMS',
#  'SNORA58B',
#  'SNORD115-48',
#  'SNURF',
#  'SNX30',
#  'SP110',
#  'SPATA8',
#  'SPN',
#  'SPP1',
#  'SPP2',
#  'SPR',
#  'SRA1',
#  'SRM',
#  'ST7',
#  'STAG1',
#  'STAR',
#  'STK3',
#  'STRAP',
#  'TAF4B',
#  'TAP1',
#  'TAP2',
#  'TEN1',
#  'TEP1',
#  'TF',
#  'THY1-AS1',
#  'TIFA',
#  'TKT',
#  'TNFRSF11B',
#  'TNNC1',
#  'TPH2',
#  'TPO',
#  'TPP1',
#  'TPRKB',
#  'TRAP1',
#  'TRAV11',
#  'TSN',
#  'TTF1',
#  'UCN2',
#  'UGT2B11',
#  'USE1',
#  'USP10',
#  'USP16',
#  'USP21',
#  'VIP',
#  'WBP1',
#  'ZNF20',
#  'ZNF230',
#  'ZNF474',
#  'ZNF475'}

# %%
len(common_ap_collision_ambiguous_symbol_set)
# Out:
# 434
