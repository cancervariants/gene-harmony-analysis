# %% [markdown]
# **Table of contents**<a id='toc0_'></a>
# - [Gene Symbol Capture Data Generation](#toc1_)
#     - [CAPTURED: annotated with a relationship type, relationship being between the symbol and the gene concept](#toc1_1_1_)
#   - [Download gene records from ENSG, HGNC, and NCBI](#toc1_2_)
#       - [This subset file was created in the alias-primary collision analysis notebook by the following modifications:](#toc1_2_1_1_)
#   - [Combine data from all sources](#toc1_3_)
#   - [Group the associated data by primary gene symbol- alias symbol pairs](#toc1_4_)
#       - [This will ensure that there are no duplicate primary gene symbol- alias symbol pairs as well as preserving in which sources these pairs occur](#toc1_4_1_1_)
# - [Ortholog Capture](#toc2_)
#   - [Download an Ensembl Biomart export file with the Gene Name and the Ortholog Gene Name](#toc2_1_)
#   - [Make all of the gene symbols all caps](#toc2_2_)
#   - [Match aliases to orthologs!](#toc2_3_)
#     - [Drosophila melanogaster](#toc2_3_1_)
#     - [Mouse](#toc2_3_2_)
#     - [(1)Abingdon island giant tortoise](#toc2_3_3_)
#     - [(1)African ostrich](#toc2_3_4_)
#     - [(1)Algerian mouse](#toc2_3_5_)
#     - [(2)Alpaca](#toc2_3_6_)
#     - [(2)Alpine marmot](#toc2_3_7_)
#     - [(2)Amazon molly](#toc2_3_8_)
#     - [(2)American bison](#toc2_3_9_)
#     - [(2)American black bear](#toc2_3_10_)
#     - [(3)American Mink](#toc2_3_11_)
#     - [(3)Arabian camel](#toc2_3_12_)
#     - [(3)Arctic ground squirrel](#toc2_3_13_)
#     - [(3)Argentine black and white tegu](#toc2_3_14_)
#     - [(3)Armadillo](#toc2_3_15_)
#     - [(3)Asian bonytongue](#toc2_3_16_)
#     - [(4)Atlantic Cod](#toc2_3_17_)
#     - [(4)Atlantic herring](#toc2_3_18_)
#     - [(4)Atlantic salmon](#toc2_3_19_)
#     - [(4)Australian saltwater crocodile](#toc2_3_20_)
#     - [(4)Ballan wrasse](#toc2_3_21_)
#     - [(5)Barramundi perch](#toc2_3_22_)
#     - [(5)Beluga whale](#toc2_3_23_)
#     - [(5)Bicolor damselfish](#toc2_3_24_)
#     - [(5)Black snub-nosed monkey](#toc2_3_25_)
#     - [(5)Blue whale](#toc2_3_26_)
#     - [(6) Blue-ringed sea krait](#toc2_3_27_)
#     - [(6) Burton's mouthbrooder](#toc2_3_28_)
#     - [(6) C.intestinalis](#toc2_3_29_)
#     - [(6) C.savignyi](#toc2_3_30_)
#     - [(6) Caenorhabditis elegans (Nematode, N2)](#toc2_3_31_)
#     - [(7) Cat](#toc2_3_32_)
#     - [(7) Chacoan peccary](#toc2_3_33_)
#     - [(7) Channel bull blenny](#toc2_3_34_)
#     - [(7) Channel catfish](#toc2_3_35_)
#     - [(7) Chicken](#toc2_3_36_)
#     - [(8) Chimpanzee](#toc2_3_37_)
#     - [(8) Chinese hamster CHOK1GS](#toc2_3_38_)
#     - [(8) Chinese medaka](#toc2_3_39_)
#     - [(8) Chinese softshell turtle](#toc2_3_40_)
#     - [(8) Chinook salmon](#toc2_3_41_)
#     - [(9) Climbing perch](#toc2_3_42_)
#     - [(9) Clown anemone fish](#toc2_3_43_)
#     - [(9) Coelacanth](#toc2_3_44_)
#     - [(9) Coho salmon](#toc2_3_45_)
#     - [(9) Collared flycatcher](#toc2_3_46_)
#     - [(10) Common canary](#toc2_3_47_)
#     - [(10) Common carp](#toc2_3_48_)
#     - [(10) Commonwall lizard](#toc2_3_49_)
#     - [(10) Common wombat](#toc2_3_50_)
#     - [(10) Coquerel's sifaka](#toc2_3_51_)
#   - [Convert ortholog_analysis_dfs to csv for use in other notebooks](#toc2_4_)
# - [HGNC Previous Symbol Capture](#toc3_)
#   - [Download the HGNC custom download including the gene symbol, ID, and previous symbols](#toc3_1_)
#   - [Remove all genes with no previous symbols](#toc3_2_)
#   - [Explode the previous symbols so that it is only one symbol per row](#toc3_3_)
#   - [Make all of the gene symbols all caps](#toc3_4_)
#   - [Match aliases to previous symbols!](#toc3_5_)
# - [FLJ Clone Name Capture](#toc4_)
#   - [Download the FLJ database file including FLJ IDs](#toc4_1_)
# - [Gene Family Symbol Capture](#toc5_)
# - [Disorder/Disease Symbol Capture](#toc6_)
#
# <!-- vscode-jupyter-toc-config
# 	numbering=false
# 	anchor=true
# 	flat=false
# 	minLevel=1
# 	maxLevel=6
# 	/vscode-jupyter-toc-config -->
# <!-- THIS CELL WILL BE REPLACED ON TOC UPDATE. DO NOT WRITE YOUR TEXT IN THIS CELL -->

# %% [markdown]
# # <a id='toc1_'></a>[Gene Symbol Capture Data Generation](#toc0_)

# %% [markdown]
# ### <a id='toc1_1_1_'></a>[Annotating the relationship between a gene symbol and a gene concept using a descriptive database](#toc0_)

# %% [markdown]
# Expect a new table for each type of relationship. Orthologs are a special case where a group of species has its own table. The subsets created after establishing a relationship, are only the symbols that are TRUE for that relationship.

# %%
import pandas as pd
import numpy as np
import re

# %%
def remove_nan_from_set(s):
    """Remove null instances from set
    
    :param s: selected set
    :return: set with no null values
    """
    return {x for x in s if pd.notna(x)}

# %%
def read_subset_genes_csv(location):
    """Create a df of primary gene symbol- alias symbol pairs

    :param location: file location
    return: a df of gene records
    """
    
    subset_genes_xxxx_df = pd.read_csv(
        location, index_col=[0],dtype={"NCBI_ID": str,"HGNC_ID":str})
    subset_genes_xxxx_df['primary_gene_symbol'] = subset_genes_xxxx_df['gene_symbol'].str.upper()
    subset_genes_xxxx_df.drop(["gene_symbol"], axis=1, inplace=True)
    subset_genes_xxxx_df['alias_symbol'] = subset_genes_xxxx_df['alias_symbol'].str.upper()
    return subset_genes_xxxx_df

# %%
def convert_all_columns_to_uppercase(df):
    """Convert gene symbols to all-caps. Diffferent species have differing capitalization requirements and this will standardize.

    :param df: DataFrame containing gene symbols of unknown capitalizations
    :return: a DataFrame with all gene symbols all-caps
    """
    for column in df.columns:
        if df[column].dtype == 'object':  # Check if the column type is object
            df[column] = df[column].str.upper()

    return df

# %%
def combine_rows(series):
    """Combine duplicate rows.

    :param series: a Pandas Series containing values from a DataFrame column.
                    this Series may contain NaN values, and the function will
                    return the first non-null value, or None if all values are NaN.
    :return: combined value from the Series, or None if the Series is empty or contains only NaNs.
    """
    return series.ffill().bfill().drop_duplicates().values[0] if not series.dropna().empty else None

# %%
def make_col_ortholog_match(recording_df, source_df, animal= str):
    """Check for ortholog matches in the primary gene symbol- alias symbol pairs. 
    Adds a T/F column for each pair. T if the alias is an ortholog from the specified animal and F if not

    :param recording_df: df that contains the primary gene symbol- alias symbol pairs
    :param source_df: df that contains the orthologs and their associated human genes
    :param animal: the animal from with the orthologs are being checked
    return: the number of primary gene symbol- alias symbol pairs where the alias is an ortholog from the specified animal
    """
    df = recording_df.copy()
    df[f'{animal} Match'] = df.apply(lambda row: 
                            any((source_df['Gene name'] == row['primary_gene_symbol']) 
                                & 
                                (source_df[f'{animal} gene name'] == row['alias_symbol'])), axis=1)
    print(f"Added column: {animal} Match")
    return df

# %%
def match_alias_to_ortholog(og_recording_df, source_df):
    """Apply the make_col_ortholog_match function to all animal columns in the DataFrame.

    :param og_recording_df: DataFrame containing the primary gene symbol- alias symbol pairs
    :param source_df: DataFrame containing the orthologs and their associated human genes
    :return: a DataFrame with all match columns added
    """
    source_df = source_df.dropna(subset=['Gene name'])

    source_df = convert_all_columns_to_uppercase(source_df)
    
    source_df = source_df.groupby('Gene name', as_index=False).agg(combine_rows)

    recording_df = og_recording_df.copy()
    recording_df.columns = recording_df.columns.str.strip().str.replace(r'\s+', ' ', regex=True)
    source_df.columns = source_df.columns.str.strip().str.replace(r'\s+', ' ', regex=True)

    animal_columns = [col for col in source_df.columns if 'gene name' in col and col != 'Gene name']
    
    true_counts = {}

    for animal in animal_columns:
        # Extract the animal name
        animal_name = animal.replace(' gene name', '')
        recording_df = make_col_ortholog_match(recording_df, source_df, animal_name)

        true_count = recording_df[f'{animal_name} Match'].sum()
        true_counts[animal_name] = true_count
    return recording_df, true_counts

# %% [markdown]
# ## <a id='toc1_2_'></a>[Download gene records from ENSG, HGNC, and NCBI](#toc0_)

# %% [markdown]
# #### <a id='toc1_2_1_1_'></a>[This subset file was created in the alias-primary collision analysis notebook by the following modifications:](#toc0_)
#  - Gene records with no aliases were removed.
#  - Primary gene symbol- alias symbol pairs where the alias was an exact match to the primary symbol were removed.
#  - Primary gene symbol- alias symbol pairs that were duplicated were removed.

# %%
subset_genes_ensg_df = read_subset_genes_csv("../output/subset_genes_ensg_df.csv")
subset_genes_hgnc_df = read_subset_genes_csv("../output/subset_genes_hgnc_df.csv")
subset_genes_ncbi_df = read_subset_genes_csv("../output/subset_genes_ncbi_df.csv")

# %% [markdown]
# ## <a id='toc1_3_'></a>[Combine data from all sources](#toc0_)

# %%
subset_genes_df = pd.concat([subset_genes_ensg_df, subset_genes_hgnc_df, subset_genes_ncbi_df], axis=0)
subset_genes_df
# Out:
#                 ENSG_ID alias_symbol HGNC_ID    NCBI_ID primary_gene_symbol
# 0       ENSG00000210049         MTTF    7481        NaN               MT-TF
# 1       ENSG00000210049         TRNF    7481        NaN               MT-TF
# 2       ENSG00000211459          12S    7470        NaN             MT-RNR1
# 3       ENSG00000211459       MOTS-C    7470        NaN             MT-RNR1
# 4       ENSG00000211459       MTRNR1    7470        NaN             MT-RNR1
# ...                 ...          ...     ...        ...                 ...
# 190961              NaN         GLTC   56861  131840634               GLTC1
# 193342              NaN        ARBAG   40248  132532400          GABRA6-AS1
# 193377              NaN         ARGI   56890  133395150             LNCARGI
# 193378              NaN         MP31   55481  133834869               MLDHR
# 193378              NaN      PTENURF   55481  133834869               MLDHR
#
# [175646 rows x 5 columns]

# %% [markdown]
# ## <a id='toc1_4_'></a>[Group the associated data by primary gene symbol- alias symbol pairs](#toc0_)

# %% [markdown]
# #### <a id='toc1_4_1_1_'></a>[This will ensure that there are no duplicate primary gene symbol- alias symbol pairs as well as preserving in which sources these pairs occur](#toc0_)

# %%
subset_genes_df = subset_genes_df.rename(columns={'gene_symbol': 'primary_gene_symbol'})

# %%
subset_genes_df = subset_genes_df.groupby(['primary_gene_symbol',"alias_symbol"], as_index=False).agg({
    "HGNC_ID": lambda x: set(x),
    'ENSG_ID': lambda x: set(x),
    'NCBI_ID': lambda x: set(x),
})
subset_genes_df
# Out:
#       primary_gene_symbol  alias_symbol  HGNC_ID            ENSG_ID  \
# 0              A-GAMMA3'E     A-GAMMA-E    {nan}              {nan}
# 1                    A1BG           A1B      {5}  {ENSG00000121410}
# 2                    A1BG           ABG      {5}  {ENSG00000121410}
# 3                    A1BG           GAB      {5}  {ENSG00000121410}
# 4                    A1BG      HYST2477      {5}  {ENSG00000121410}
# ...                   ...           ...      ...                ...
# 86546               ZZEF1      FLJ10821  {29027}  {ENSG00000074755}
# 86547               ZZEF1      KIAA0399  {29027}  {ENSG00000074755}
# 86548               ZZEF1          ZZZ4  {29027}  {ENSG00000074755}
# 86549                ZZZ3         ATAC1  {24523}  {ENSG00000036549}
# 86550                ZZZ3  DKFZP564I052  {24523}  {ENSG00000036549}
#
#            NCBI_ID
# 0      {109951028}
# 1              {1}
# 2              {1}
# 3              {1}
# 4              {1}
# ...            ...
# 86546      {23140}
# 86547      {23140}
# 86548      {23140}
# 86549      {26009}
# 86550      {26009}
#
# [86551 rows x 5 columns]

# %%
subset_genes_df['NCBI_ID'] = subset_genes_df['NCBI_ID'].apply(remove_nan_from_set)
subset_genes_df['ENSG_ID'] = subset_genes_df['ENSG_ID'].apply(remove_nan_from_set)
subset_genes_df['HGNC_ID'] = subset_genes_df['HGNC_ID'].apply(remove_nan_from_set)

# %%
subset_genes_df.loc[subset_genes_df["primary_gene_symbol"]=="BICDL3P"]
# Out:
#      primary_gene_symbol alias_symbol  HGNC_ID            ENSG_ID   NCBI_ID
# 6181             BICDL3P   ABHD11-AS1  {18289}  {ENSG00000225969}        {}
# 6182             BICDL3P    LINC00035  {18289}  {ENSG00000225969}        {}
# 6183             BICDL3P   NCRNA00035  {18289}  {ENSG00000225969}  {171022}
# 6184             BICDL3P      WBSCR26  {18289}  {ENSG00000225969}        {}

# %%
subset_genes_df.to_hdf(
    "../output/subset_genes_df.h5", key='df', mode='w'
)
# Out:
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_36862/735503889.py:1: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block0_values] [items->Index(['primary_gene_symbol', 'alias_symbol', 'HGNC_ID', 'ENSG_ID', 'NCBI_ID'], dtype='object')]
#
#   subset_genes_df.to_hdf(

# %%
subset_genes_df.to_csv(
    "../output/subset_genes_df.csv", index=True
)

# %% [markdown]
# # <a id='toc2_'></a>[Ortholog Capture](#toc0_)

# %% [markdown]
# ## <a id='toc2_1_'></a>[Download an Ensembl Biomart export file with the Gene Name and the Ortholog Gene Name](#toc0_)

# %%
mur_dros_ortho_df = pd.read_csv(
    "../input/ensg_mart_export_dros_murin_ortho.txt", sep=",", index_col=[0])
mur_dros_ortho_df
# Out:
#                 Drosophila melanogaster (Fruit fly) gene name  \
# Gene stable ID
# ENSG00000210049                                           NaN
# ENSG00000211459                                           NaN
# ENSG00000210077                                           NaN
# ENSG00000210082                                           NaN
# ENSG00000209082                                           NaN
# ...                                                       ...
# ENSG00000232679                                           NaN
# ENSG00000200033                                           NaN
# ENSG00000228437                                           NaN
# ENSG00000229463                                           NaN
# ENSG00000229291                                           NaN
#
#                 Drosophila melanogaster (Fruit fly) gene stable ID  \
# Gene stable ID
# ENSG00000210049                                                NaN
# ENSG00000211459                                                NaN
# ENSG00000210077                                                NaN
# ENSG00000210082                                                NaN
# ENSG00000209082                                                NaN
# ...                                                            ...
# ENSG00000232679                                                NaN
# ENSG00000200033                                                NaN
# ENSG00000228437                                                NaN
# ENSG00000229463                                                NaN
# ENSG00000229291                                                NaN
#
#                 Mouse gene stable ID Mouse gene name  Gene name
# Gene stable ID
# ENSG00000210049                  NaN             NaN      MT-TF
# ENSG00000211459                  NaN             NaN    MT-RNR1
# ENSG00000210077                  NaN             NaN      MT-TV
# ENSG00000210082                  NaN             NaN    MT-RNR2
# ENSG00000209082                  NaN             NaN     MT-TL1
# ...                              ...             ...        ...
# ENSG00000232679                  NaN             NaN  LINC01705
# ENSG00000200033   ENSMUSG00000088001         Gm22883  RNU6-403P
# ENSG00000228437                  NaN             NaN  LINC02474
# ENSG00000229463                  NaN             NaN   LYST-AS1
# ENSG00000229291                  NaN             NaN  LINC02768
#
# [91822 rows x 5 columns]

# %% [markdown]
# ## <a id='toc2_2_'></a>[Make all of the gene symbols all caps](#toc0_)

# %% [markdown]
# Different species follow different gene nomenclature conventions. <br>
# For example, mouse genes have the first letter capitalized but the rest lowercase.<br>
# They need to be all caps for matching

# %%
mur_dros_ortho_df = convert_all_columns_to_uppercase(mur_dros_ortho_df)

# %% [markdown]
# ## <a id='toc2_3_'></a>[Match aliases to orthologs!](#toc0_)

# %% [markdown]
# ### <a id='toc2_3_1_'></a>[Drosophila melanogaster](#toc0_)

# %%
fruitfly_df = make_col_ortholog_match(subset_genes_df, mur_dros_ortho_df,"Drosophila melanogaster (Fruit fly)")
print(len(fruitfly_df))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 fruitfly_df = make_col_ortholog_match(subset_genes_df, mur_dros_ortho_df,"Drosophila melanogaster (Fruit fly)")
#       2 print(len(fruitfly_df))
#
# Cell In[6], line 11, in make_col_ortholog_match(recording_df, source_df, animal)
#       2 """Check for ortholog matches in the primary gene symbol- alias symbol pairs.
#       3 Adds a T/F column for each pair. T if the alias is an ortholog from the specified animal and F if not
#       4
#    (...)      8 return: the number of primary gene symbol- alias symbol pairs where the alias is an ortholog from the specified animal
#       9 """
#      10 df = recording_df.copy()
# ---> 11 df[f'{animal} Match'] = df.apply(lambda row:
#      12                         any((source_df['Gene name'] == row['primary_gene_symbol'])
#      13                             &
#      14                             (source_df[f'{animal} gene name'] == row['alias_symbol'])), axis=1)
#      15 print(f"Added column: {animal} Match")
#      16 return df
#
# File ~/Desktop/gene-harmony-analysis/.venv/lib/python3.11/site-packages/pandas/core/frame.py:10374, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10360 from pandas.core.apply import frame_apply
#   10362 op = frame_apply(
#   10363     self,
#   10364     func=func,
#    (...)  10372     kwargs=kwargs,
#   10373 )
# > 10374 return op.apply().__finalize__(self, method="apply")
#
# File ~/Desktop/gene-harmony-analysis/.venv/lib/python3.11/site-packages/pandas/core/apply.py:916, in FrameApply.apply(self)
#     913 elif self.raw:
#     914     return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
# --> 916 return self.apply_standard()
#
# File ~/Desktop/gene-harmony-analysis/.venv/lib/python3.11/site-packages/pandas/core/apply.py:1063, in FrameApply.apply_standard(self)
#    1061 def apply_standard(self):
#    1062     if self.engine == "python":
# -> 1063         results, res_index = self.apply_series_generator()
#    1064     else:
#    1065         results, res_index = self.apply_series_numba()
#
# File ~/Desktop/gene-harmony-analysis/.venv/lib/python3.11/site-packages/pandas/core/apply.py:1081, in FrameApply.apply_series_generator(self)
#    1078 with option_context("mode.chained_assignment", None):
#    1079     for i, v in enumerate(series_gen):
#    1080         # ignore SettingWithCopy here in case the user mutates
# -> 1081         results[i] = self.func(v, *self.args, **self.kwargs)
#    1082         if isinstance(results[i], ABCSeries):
#    1083             # If we have a view on v, we need to make a copy because
#    1084             #  series_generator will swap out the underlying data
#    1085             results[i] = results[i].copy(deep=False)
#
# Cell In[6], line 12, in make_col_ortholog_match.<locals>.<lambda>(row)
#       2 """Check for ortholog matches in the primary gene symbol- alias symbol pairs.
#       3 Adds a T/F column for each pair. T if the alias is an ortholog from the specified animal and F if not
#       4
#    (...)      8 return: the number of primary gene symbol- alias symbol pairs where the alias is an ortholog from the specified animal
#       9 """
#      10 df = recording_df.copy()
#      11 df[f'{animal} Match'] = df.apply(lambda row:
# ---> 12                         any((source_df['Gene name'] == row['primary_gene_symbol'])
#      13                             &
#      14                             (source_df[f'{animal} gene name'] == row['alias_symbol'])), axis=1)
#      15 print(f"Added column: {animal} Match")
#      16 return df
#
# File ~/Desktop/gene-harmony-analysis/.venv/lib/python3.11/site-packages/pandas/core/ops/common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File ~/Desktop/gene-harmony-analysis/.venv/lib/python3.11/site-packages/pandas/core/arraylike.py:40, in OpsMixin.__eq__(self, other)
#      38 @unpack_zerodim_and_defer("__eq__")
#      39 def __eq__(self, other):
# ---> 40     return self._cmp_method(other, operator.eq)
#
# File ~/Desktop/gene-harmony-analysis/.venv/lib/python3.11/site-packages/pandas/core/series.py:6119, in Series._cmp_method(self, other, op)
#    6116 lvalues = self._values
#    6117 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
# -> 6119 res_values = ops.comparison_op(lvalues, rvalues, op)
#    6121 return self._construct_result(res_values, name=res_name)
#
# File ~/Desktop/gene-harmony-analysis/.venv/lib/python3.11/site-packages/pandas/core/ops/array_ops.py:344, in comparison_op(left, right, op)
#     341     return invalid_comparison(lvalues, rvalues, op)
#     343 elif lvalues.dtype == object or isinstance(rvalues, str):
# --> 344     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     346 else:
#     347     res_values = _na_arithmetic_op(lvalues, rvalues, op, is_cmp=True)
#
# File ~/Desktop/gene-harmony-analysis/.venv/lib/python3.11/site-packages/pandas/core/ops/array_ops.py:129, in comp_method_OBJECT_ARRAY(op, x, y)
#     127     result = libops.vec_compare(x.ravel(), y.ravel(), op)
#     128 else:
# --> 129     result = libops.scalar_compare(x.ravel(), y, op)
#     130 return result.reshape(x.shape)
#
# KeyboardInterrupt:

# %% [markdown]
# ### <a id='toc2_3_2_'></a>[Mouse](#toc0_)

# %%
mouse_df = make_col_ortholog_match(subset_genes_df, mur_dros_ortho_df,"Mouse")
print(len(mouse_df))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 mouse_df = make_col_ortholog_match(subset_genes_df, mur_dros_ortho_df,"Mouse")
#       2 print(len(mouse_df))
#
# Cell In[6], line 11, in make_col_ortholog_match(recording_df, source_df, animal)
#       2 """Check for ortholog matches in the primary gene symbol- alias symbol pairs.
#       3 Adds a T/F column for each pair. T if the alias is an ortholog from the specified animal and F if not
#       4
#    (...)      8 return: the number of primary gene symbol- alias symbol pairs where the alias is an ortholog from the specified animal
#       9 """
#      10 df = recording_df.copy()
# ---> 11 df[f'{animal} Match'] = df.apply(lambda row:
#      12                         any((source_df['Gene name'] == row['primary_gene_symbol'])
#      13                             &
#      14                             (source_df[f'{animal} gene name'] == row['alias_symbol'])), axis=1)
#      15 print(f"Added column: {animal} Match")
#      16 return df
#
# File ~/Desktop/gene-harmony-analysis/.venv/lib/python3.11/site-packages/pandas/core/frame.py:10374, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10360 from pandas.core.apply import frame_apply
#   10362 op = frame_apply(
#   10363     self,
#   10364     func=func,
#    (...)  10372     kwargs=kwargs,
#   10373 )
# > 10374 return op.apply().__finalize__(self, method="apply")
#
# File ~/Desktop/gene-harmony-analysis/.venv/lib/python3.11/site-packages/pandas/core/apply.py:916, in FrameApply.apply(self)
#     913 elif self.raw:
#     914     return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
# --> 916 return self.apply_standard()
#
# File ~/Desktop/gene-harmony-analysis/.venv/lib/python3.11/site-packages/pandas/core/apply.py:1063, in FrameApply.apply_standard(self)
#    1061 def apply_standard(self):
#    1062     if self.engine == "python":
# -> 1063         results, res_index = self.apply_series_generator()
#    1064     else:
#    1065         results, res_index = self.apply_series_numba()
#
# File ~/Desktop/gene-harmony-analysis/.venv/lib/python3.11/site-packages/pandas/core/apply.py:1081, in FrameApply.apply_series_generator(self)
#    1078 with option_context("mode.chained_assignment", None):
#    1079     for i, v in enumerate(series_gen):
#    1080         # ignore SettingWithCopy here in case the user mutates
# -> 1081         results[i] = self.func(v, *self.args, **self.kwargs)
#    1082         if isinstance(results[i], ABCSeries):
#    1083             # If we have a view on v, we need to make a copy because
#    1084             #  series_generator will swap out the underlying data
#    1085             results[i] = results[i].copy(deep=False)
#
# Cell In[6], line 14, in make_col_ortholog_match.<locals>.<lambda>(row)
#       2 """Check for ortholog matches in the primary gene symbol- alias symbol pairs.
#       3 Adds a T/F column for each pair. T if the alias is an ortholog from the specified animal and F if not
#       4
#    (...)      8 return: the number of primary gene symbol- alias symbol pairs where the alias is an ortholog from the specified animal
#       9 """
#      10 df = recording_df.copy()
#      11 df[f'{animal} Match'] = df.apply(lambda row:
#      12                         any((source_df['Gene name'] == row['primary_gene_symbol'])
#      13                             &
# ---> 14                             (source_df[f'{animal} gene name'] == row['alias_symbol'])), axis=1)
#      15 print(f"Added column: {animal} Match")
#      16 return df
#
# File ~/Desktop/gene-harmony-analysis/.venv/lib/python3.11/site-packages/pandas/core/ops/common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File ~/Desktop/gene-harmony-analysis/.venv/lib/python3.11/site-packages/pandas/core/arraylike.py:40, in OpsMixin.__eq__(self, other)
#      38 @unpack_zerodim_and_defer("__eq__")
#      39 def __eq__(self, other):
# ---> 40     return self._cmp_method(other, operator.eq)
#
# File ~/Desktop/gene-harmony-analysis/.venv/lib/python3.11/site-packages/pandas/core/series.py:6119, in Series._cmp_method(self, other, op)
#    6116 lvalues = self._values
#    6117 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
# -> 6119 res_values = ops.comparison_op(lvalues, rvalues, op)
#    6121 return self._construct_result(res_values, name=res_name)
#
# File ~/Desktop/gene-harmony-analysis/.venv/lib/python3.11/site-packages/pandas/core/ops/array_ops.py:344, in comparison_op(left, right, op)
#     341     return invalid_comparison(lvalues, rvalues, op)
#     343 elif lvalues.dtype == object or isinstance(rvalues, str):
# --> 344     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     346 else:
#     347     res_values = _na_arithmetic_op(lvalues, rvalues, op, is_cmp=True)
#
# File ~/Desktop/gene-harmony-analysis/.venv/lib/python3.11/site-packages/pandas/core/ops/array_ops.py:129, in comp_method_OBJECT_ARRAY(op, x, y)
#     127     result = libops.vec_compare(x.ravel(), y.ravel(), op)
#     128 else:
# --> 129     result = libops.scalar_compare(x.ravel(), y, op)
#     130 return result.reshape(x.shape)
#
# KeyboardInterrupt:

# %%
mouse_df
# Out:
#       primary_gene_symbol  alias_symbol  HGNC_ID            ENSG_ID  \
# 0              A-GAMMA3'E     A-GAMMA-E       {}                 {}
# 1                    A1BG           A1B      {5}  {ENSG00000121410}
# 2                    A1BG           ABG      {5}  {ENSG00000121410}
# 3                    A1BG           GAB      {5}  {ENSG00000121410}
# 4                    A1BG      HYST2477      {5}  {ENSG00000121410}
# ...                   ...           ...      ...                ...
# 86546               ZZEF1      FLJ10821  {29027}  {ENSG00000074755}
# 86547               ZZEF1      KIAA0399  {29027}  {ENSG00000074755}
# 86548               ZZEF1          ZZZ4  {29027}  {ENSG00000074755}
# 86549                ZZZ3         ATAC1  {24523}  {ENSG00000036549}
# 86550                ZZZ3  DKFZP564I052  {24523}  {ENSG00000036549}
#
#            NCBI_ID              source  Mouse Match
# 0      {109951028}              {NCBI}        False
# 1              {1}              {NCBI}        False
# 2              {1}              {NCBI}        False
# 3              {1}              {NCBI}        False
# 4              {1}              {NCBI}        False
# ...            ...                 ...          ...
# 86546      {23140}        {ENSG, HGNC}        False
# 86547      {23140}        {ENSG, HGNC}        False
# 86548      {23140}  {NCBI, ENSG, HGNC}        False
# 86549      {26009}  {NCBI, ENSG, HGNC}        False
# 86550      {26009}        {ENSG, HGNC}        False
#
# [86551 rows x 7 columns]

# %% [markdown]
# ### <a id='toc2_3_3_'></a>[(1)Abingdon island giant tortoise](#toc0_)
# ### <a id='toc2_3_4_'></a>[(1)African ostrich](#toc0_)
# ### <a id='toc2_3_5_'></a>[(1)Algerian mouse](#toc0_)

# %%
ortholog_set_1_df = pd.read_csv(
    "../input/ortholog_set_1_df.txt", sep=",")

# %%
ortholog_analysis_1_df, ortholog_analysis_1_counts = match_alias_to_ortholog(subset_genes_df, ortholog_set_1_df)
print(ortholog_analysis_1_counts)
# Out:
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_6161/3502168503.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].str.upper()
# Added column: Abingdon island giant tortoise Match
# Added column: African ostrich Match
# Added column: Algerian mouse Match
# {'Abingdon island giant tortoise': np.int64(1), 'African ostrich': np.int64(1), 'Algerian mouse': np.int64(162)}

# %%
ortholog_analysis_1_df.head()
# Out:
#   primary_gene_symbol alias_symbol HGNC_ID            ENSG_ID      NCBI_ID  \
# 0          A-GAMMA3'E    A-GAMMA-E      {}                 {}  {109951028}
# 1                A1BG          A1B     {5}  {ENSG00000121410}          {1}
# 2                A1BG          ABG     {5}  {ENSG00000121410}          {1}
# 3                A1BG          GAB     {5}  {ENSG00000121410}          {1}
# 4                A1BG     HYST2477     {5}  {ENSG00000121410}          {1}
#
#    Abingdon island giant tortoise Match  African ostrich Match  \
# 0                                 False                  False
# 1                                 False                  False
# 2                                 False                  False
# 3                                 False                  False
# 4                                 False                  False
#
#    Algerian mouse Match
# 0                 False
# 1                 False
# 2                 False
# 3                 False
# 4                 False

# %% [markdown]
# ### <a id='toc2_3_6_'></a>[(2)Alpaca](#toc0_)
# ### <a id='toc2_3_7_'></a>[(2)Alpine marmot](#toc0_)
# ### <a id='toc2_3_8_'></a>[(2)Amazon molly](#toc0_)
# ### <a id='toc2_3_9_'></a>[(2)American bison](#toc0_)
# ### <a id='toc2_3_10_'></a>[(2)American black bear](#toc0_)

# %%
ortholog_set_2_df = pd.read_csv(
    "../input/ortholog_set_2_df.txt", sep=",")

# %%
ortholog_analysis_2_df, ortholog_analysis_2_counts = match_alias_to_ortholog(subset_genes_df, ortholog_set_2_df)
print(ortholog_analysis_2_counts)
# Out:
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_6161/3502168503.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].str.upper()
# Added column: Alpaca Match
# Added column: Alpine marmot Match
# Added column: Amazon molly Match
# Added column: American bison Match
# Added column: American black bear Match
# {'Alpaca': np.int64(13), 'Alpine marmot': np.int64(6), 'Amazon molly': np.int64(96), 'American bison': np.int64(277), 'American black bear': np.int64(1)}

# %%
ortholog_analysis_2_df.head()
# Out:
#   primary_gene_symbol alias_symbol HGNC_ID            ENSG_ID      NCBI_ID  \
# 0          A-GAMMA3'E    A-GAMMA-E      {}                 {}  {109951028}
# 1                A1BG          A1B     {5}  {ENSG00000121410}          {1}
# 2                A1BG          ABG     {5}  {ENSG00000121410}          {1}
# 3                A1BG          GAB     {5}  {ENSG00000121410}          {1}
# 4                A1BG     HYST2477     {5}  {ENSG00000121410}          {1}
#
#    Alpaca Match  Alpine marmot Match  Amazon molly Match  \
# 0         False                False               False
# 1         False                False               False
# 2         False                False               False
# 3         False                False               False
# 4         False                False               False
#
#    American bison Match  American black bear Match
# 0                 False                      False
# 1                 False                      False
# 2                 False                      False
# 3                 False                      False
# 4                 False                      False

# %% [markdown]
# ### <a id='toc2_3_11_'></a>[(3)American Mink](#toc0_)
# ### <a id='toc2_3_12_'></a>[(3)Arabian camel](#toc0_)
# ### <a id='toc2_3_13_'></a>[(3)Arctic ground squirrel](#toc0_)
# ### <a id='toc2_3_14_'></a>[(3)Argentine black and white tegu](#toc0_)
# ### <a id='toc2_3_15_'></a>[(3)Armadillo](#toc0_)
# ### <a id='toc2_3_16_'></a>[(3)Asian bonytongue](#toc0_)

# %%
ortholog_set_3_df = pd.read_csv(
    "../input/ortholog_set_3_df.txt", sep=",")
# Out:
#          Gene stable ID    Gene name American mink gene name  \
# 0       ENSG00000210049        MT-TF                     NaN
# 1       ENSG00000211459      MT-RNR1                     NaN
# 2       ENSG00000210077        MT-TV                     NaN
# 3       ENSG00000210082      MT-RNR2                     NaN
# 4       ENSG00000209082       MT-TL1                     NaN
# ...                 ...          ...                     ...
# 139603  ENSG00000235358     SCMH1-DT                     NaN
# 139604  ENSG00000228067    LINC01740                     NaN
# 139605  ENSG00000293271  SLC44A3-AS1                     NaN
# 139606  ENSG00000310526       WASH7P                     NaN
# 139607  ENSG00000241860          NaN                     NaN
#
#        Arabian camel gene name Arctic ground squirrel gene name  \
# 0                          NaN                              NaN
# 1                          NaN                              NaN
# 2                          NaN                              NaN
# 3                          NaN                              NaN
# 4                          NaN                              NaN
# ...                        ...                              ...
# 139603                     NaN                              NaN
# 139604                     NaN                              NaN
# 139605                     NaN                              NaN
# 139606                     NaN                              NaN
# 139607                     NaN                              NaN
#
#        Argentine black and white tegu gene name Armadillo gene name  \
# 0                                           NaN                 NaN
# 1                                           NaN                 NaN
# 2                                           NaN                 NaN
# 3                                           NaN                 NaN
# 4                                           NaN                 NaN
# ...                                         ...                 ...
# 139603                                      NaN                 NaN
# 139604                                      NaN                 NaN
# 139605                                      NaN                 NaN
# 139606                                      NaN                 NaN
# 139607                                      NaN                 NaN
#
#        Asian bonytongue gene name
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
# ...                           ...
# 139603                        NaN
# 139604                        NaN
# 139605                        NaN
# 139606                        NaN
# 139607                        NaN
#
# [139608 rows x 8 columns]

# %%
ortholog_analysis_3_df, ortholog_analysis_3_counts = match_alias_to_ortholog(subset_genes_df, ortholog_set_3_df)
print(ortholog_analysis_3_counts)
# Out:
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_6161/3502168503.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].str.upper()
# Added column: American mink Match
# Added column: Arabian camel Match
# Added column: Arctic ground squirrel Match
# Added column: Argentine black and white tegu Match
# Added column: Armadillo Match
# Added column: Asian bonytongue Match
# {'American mink': np.int64(15), 'Arabian camel': np.int64(32), 'Arctic ground squirrel': np.int64(2), 'Argentine black and white tegu': np.int64(4), 'Armadillo': np.int64(28), 'Asian bonytongue': np.int64(96)}

# %%
ortholog_analysis_3_df.head()
# Out:
#   primary_gene_symbol alias_symbol HGNC_ID            ENSG_ID      NCBI_ID  \
# 0          A-GAMMA3'E    A-GAMMA-E      {}                 {}  {109951028}
# 1                A1BG          A1B     {5}  {ENSG00000121410}          {1}
# 2                A1BG          ABG     {5}  {ENSG00000121410}          {1}
# 3                A1BG          GAB     {5}  {ENSG00000121410}          {1}
# 4                A1BG     HYST2477     {5}  {ENSG00000121410}          {1}
#
#    American mink Match  Arabian camel Match  Arctic ground squirrel Match  \
# 0                False                False                         False
# 1                False                False                         False
# 2                False                False                         False
# 3                False                False                         False
# 4                False                False                         False
#
#    Argentine black and white tegu Match  Armadillo Match  \
# 0                                 False            False
# 1                                 False            False
# 2                                 False            False
# 3                                 False            False
# 4                                 False            False
#
#    Asian bonytongue Match
# 0                   False
# 1                   False
# 2                   False
# 3                   False
# 4                   False

# %% [markdown]
# ### <a id='toc2_3_17_'></a>[(4)Atlantic Cod](#toc0_)
# ### <a id='toc2_3_18_'></a>[(4)Atlantic herring](#toc0_)
# ### <a id='toc2_3_19_'></a>[(4)Atlantic salmon](#toc0_)
# ### <a id='toc2_3_20_'></a>[(4)Australian saltwater crocodile](#toc0_)
# ### <a id='toc2_3_21_'></a>[(4)Ballan wrasse](#toc0_)

# %%
ortholog_set_4_df = pd.read_csv(
    "../input/ortholog_set_4_df.txt", sep=",")
ortholog_set_4_df.head()
# Out:
#      Gene stable ID  Gene name Atlantic cod gene name  \
# 0   ENSG00000263418    5S_rRNA                    NaN
# 1   ENSG00000265816    5S_rRNA                    NaN
# 2   ENSG00000266035    5S_rRNA                    NaN
# 3   ENSG00000266615    5S_rRNA                    NaN
# 4   ENSG00000266653    5S_rRNA                    NaN
# 5   ENSG00000266726    5S_rRNA                    NaN
# 6   ENSG00000273928    5S_rRNA                    NaN
# 7   ENSG00000275780    5S_rRNA                    NaN
# 8   ENSG00000275999    5S_rRNA                    NaN
# 9   ENSG00000276861    5S_rRNA                    NaN
# 10  ENSG00000277395    5S_rRNA                    NaN
# 11  ENSG00000277411    5S_rRNA                    NaN
# 12  ENSG00000277488    5S_rRNA                    NaN
# 13  ENSG00000277584    5S_rRNA                    NaN
# 14  ENSG00000278457    5S_rRNA                    NaN
# 15  ENSG00000278779    5S_rRNA                    NaN
# 16  ENSG00000283454    5S_rRNA                    NaN
# 17  ENSG00000285609    5S_rRNA                    NaN
# 18  ENSG00000285626    5S_rRNA                    NaN
# 19  ENSG00000285674    5S_rRNA                    NaN
# 20  ENSG00000285776    5S_rRNA                    NaN
# 21  ENSG00000285912    5S_rRNA                    NaN
# 22  ENSG00000288601    5S_rRNA                    NaN
# 23  ENSG00000273730  5_8S_rRNA                    NaN
# 24  ENSG00000275757  5_8S_rRNA                    NaN
# 25  ENSG00000275877  5_8S_rRNA                    NaN
# 26  ENSG00000276871  5_8S_rRNA                    NaN
# 27  ENSG00000277739  5_8S_rRNA                    NaN
# 28  ENSG00000278294  5_8S_rRNA                    NaN
# 29  ENSG00000283274  5_8S_rRNA                    NaN
# 30  ENSG00000283291  5_8S_rRNA                    NaN
# 31  ENSG00000283568  5_8S_rRNA                    NaN
# 32  ENSG00000202198        7SK                    NaN
# 33  ENSG00000264415        7SK                    NaN
# 34  ENSG00000265255        7SK                    NaN
# 35  ENSG00000265633        7SK                    NaN
# 36  ENSG00000265903        7SK                    NaN
# 37  ENSG00000266263        7SK                    NaN
# 38  ENSG00000271394        7SK                    NaN
# 39  ENSG00000273591        7SK                    NaN
# 40  ENSG00000274262        7SK                    NaN
# 41  ENSG00000274303        7SK                    NaN
# 42  ENSG00000275933        7SK                    NaN
# 43  ENSG00000276626        7SK                    NaN
# 44  ENSG00000277313        7SK                    NaN
# 45  ENSG00000291974        7SK                    NaN
# 46  ENSG00000121410       A1BG                    NaN
# 47  ENSG00000268895   A1BG-AS1                    NaN
# 48  ENSG00000148584       A1CF                    NaN
# 49  ENSG00000148584       A1CF                    NaN
#
#    Atlantic herring  gene name Atlantic salmon gene name  \
# 0                          NaN                       NaN
# 1                          NaN                       NaN
# 2                          NaN                       NaN
# 3                          NaN                       NaN
# 4                          NaN                       NaN
# 5                          NaN                       NaN
# 6                          NaN                       NaN
# 7                          NaN                       NaN
# 8                          NaN                       NaN
# 9                          NaN                       NaN
# 10                         NaN                       NaN
# 11                         NaN                       NaN
# 12                         NaN                       NaN
# 13                         NaN                       NaN
# 14                         NaN                       NaN
# 15                         NaN                       NaN
# 16                         NaN                       NaN
# 17                         NaN                       NaN
# 18                         NaN                       NaN
# 19                         NaN                       NaN
# 20                         NaN                       NaN
# 21                         NaN                       NaN
# 22                         NaN                       NaN
# 23                         NaN                       NaN
# 24                         NaN                       NaN
# 25                         NaN                       NaN
# 26                         NaN                       NaN
# 27                         NaN                       NaN
# 28                         NaN                       NaN
# 29                         NaN                       NaN
# 30                         NaN                       NaN
# 31                         NaN                       NaN
# 32                         NaN                       NaN
# 33                         NaN                       NaN
# 34                         NaN                       NaN
# 35                         NaN                       NaN
# 36                         NaN                       NaN
# 37                         NaN                       NaN
# 38                         NaN                       NaN
# 39                         NaN                       NaN
# 40                         NaN                       NaN
# 41                         NaN                       NaN
# 42                         NaN                       NaN
# 43                         NaN                       NaN
# 44                         NaN                       NaN
# 45                         NaN                       NaN
# 46                         NaN                       NaN
# 47                         NaN                       NaN
# 48                        A1CF                      A1CF
# 49                        A1CF                      a1cf
#
#    Australian saltwater crocodile gene name Ballan wrasse gene name
# 0                                       NaN                     NaN
# 1                                       NaN                     NaN
# 2                                       NaN                     NaN
# 3                                       NaN                     NaN
# 4                                       NaN                     NaN
# 5                                       NaN                     NaN
# 6                                       NaN                     NaN
# 7                                       NaN                     NaN
# 8                                       NaN                     NaN
# 9                                       NaN                     NaN
# 10                                      NaN                     NaN
# 11                                      NaN                     NaN
# 12                                      NaN                     NaN
# 13                                      NaN                     NaN
# 14                                      NaN                     NaN
# 15                                      NaN                     NaN
# 16                                      NaN                     NaN
# 17                                      NaN                     NaN
# 18                                      NaN                     NaN
# 19                                      NaN                     NaN
# 20                                      NaN                     NaN
# 21                                      NaN                     NaN
# 22                                      NaN                     NaN
# 23                                      NaN                     NaN
# 24                                      NaN                     NaN
# 25                                      NaN                     NaN
# 26                                      NaN                     NaN
# 27                                      NaN                     NaN
# 28                                      NaN                     NaN
# 29                                      NaN                     NaN
# 30                                      NaN                     NaN
# 31                                5_8S_rRNA                     NaN
# 32                                      7SK                     NaN
# 33                                      NaN                     NaN
# 34                                      NaN                     NaN
# 35                                      NaN                     NaN
# 36                                      NaN                     NaN
# 37                                      NaN                     NaN
# 38                                      NaN                     NaN
# 39                                      NaN                     NaN
# 40                                      NaN                     NaN
# 41                                      NaN                     NaN
# 42                                      NaN                     NaN
# 43                                      NaN                     NaN
# 44                                      NaN                     NaN
# 45                                      NaN                     NaN
# 46                                      NaN                     NaN
# 47                                      NaN                     NaN
# 48                                     A1CF                    A1CF
# 49                                     A1CF                    A1CF

# %%
ortholog_set_4_df = ortholog_set_4_df.groupby('Gene name', as_index=False).agg(combine_rows)

# %%
ortholog_analysis_4_df, ortholog_analysis_4_counts = match_alias_to_ortholog(subset_genes_df, ortholog_set_4_df)
print(ortholog_analysis_4_counts)
# Out:
# Added column: Atlantic cod Match
# Added column: Atlantic herring Match
# Added column: Atlantic salmon Match
# Added column: Australian saltwater crocodile Match
# Added column: Ballan wrasse Match
# {'Atlantic cod': np.int64(57), 'Atlantic herring': np.int64(211), 'Atlantic salmon': np.int64(167), 'Australian saltwater crocodile': np.int64(16), 'Ballan wrasse': np.int64(97)}

# %%
ortholog_analysis_4_df.head()
# Out:
#   primary_gene_symbol alias_symbol HGNC_ID            ENSG_ID      NCBI_ID  \
# 0          A-GAMMA3'E    A-GAMMA-E      {}                 {}  {109951028}
# 1                A1BG          A1B     {5}  {ENSG00000121410}          {1}
# 2                A1BG          ABG     {5}  {ENSG00000121410}          {1}
# 3                A1BG          GAB     {5}  {ENSG00000121410}          {1}
# 4                A1BG     HYST2477     {5}  {ENSG00000121410}          {1}
#
#    Atlantic cod Match  Atlantic herring Match  Atlantic salmon Match  \
# 0               False                   False                  False
# 1               False                   False                  False
# 2               False                   False                  False
# 3               False                   False                  False
# 4               False                   False                  False
#
#    Australian saltwater crocodile Match  Ballan wrasse Match
# 0                                 False                False
# 1                                 False                False
# 2                                 False                False
# 3                                 False                False
# 4                                 False                False

# %% [markdown]
# ### <a id='toc2_3_22_'></a>[(5)Barramundi perch](#toc0_)
# ### <a id='toc2_3_23_'></a>[(5)Beluga whale](#toc0_)
# ### <a id='toc2_3_24_'></a>[(5)Bicolor damselfish](#toc0_)
# ### <a id='toc2_3_25_'></a>[(5)Black snub-nosed monkey](#toc0_)
# ### <a id='toc2_3_26_'></a>[(5)Blue whale](#toc0_)

# %%
ortholog_set_5_df = pd.read_csv(
    "../input/ortholog_set_5_df.txt", sep=",")

# %%
ortholog_analysis_5_df, ortholog_analysis_5_counts = match_alias_to_ortholog(subset_genes_df, ortholog_set_5_df)
print(ortholog_analysis_5_counts)
# Out:
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_6161/3502168503.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].str.upper()
# Added column: Blue whale Match
# Added column: Black snub-nosed monkey Match
# Added column: Bicolor damselfish Match
# Added column: Beluga whale Match
# Added column: Barramundi perch Match
# {'Blue whale': np.int64(8), 'Black snub-nosed monkey': np.int64(14), 'Bicolor damselfish': np.int64(93), 'Beluga whale': np.int64(28), 'Barramundi perch': np.int64(93)}

# %%
ortholog_analysis_5_df.head()
# Out:
#   primary_gene_symbol alias_symbol HGNC_ID            ENSG_ID      NCBI_ID  \
# 0          A-GAMMA3'E    A-GAMMA-E      {}                 {}  {109951028}
# 1                A1BG          A1B     {5}  {ENSG00000121410}          {1}
# 2                A1BG          ABG     {5}  {ENSG00000121410}          {1}
# 3                A1BG          GAB     {5}  {ENSG00000121410}          {1}
# 4                A1BG     HYST2477     {5}  {ENSG00000121410}          {1}
#
#    Blue whale Match  Black snub-nosed monkey Match  Bicolor damselfish Match  \
# 0             False                          False                     False
# 1             False                          False                     False
# 2             False                          False                     False
# 3             False                          False                     False
# 4             False                          False                     False
#
#    Beluga whale Match  Barramundi perch Match
# 0               False                   False
# 1               False                   False
# 2               False                   False
# 3               False                   False
# 4               False                   False

# %% [markdown]
# ### <a id='toc2_3_27_'></a>[(6) Blue-ringed sea krait](#toc0_)
# ### <a id='toc2_3_28_'></a>[(6) Burton's mouthbrooder](#toc0_)
# ### <a id='toc2_3_29_'></a>[(6) C.intestinalis](#toc0_)
# ### <a id='toc2_3_30_'></a>[(6) C.savignyi](#toc0_)
# ### <a id='toc2_3_31_'></a>[(6) Caenorhabditis elegans (Nematode, N2)](#toc0_)

# %%
ortholog_set_6_df = pd.read_csv(
    "../input/ortholog_set_6_df.txt", sep=",")

# %%
ortholog_analysis_6_df, ortholog_analysis_6_counts = match_alias_to_ortholog(subset_genes_df, ortholog_set_6_df)
print(ortholog_analysis_6_counts)
# Out:
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_6161/3502168503.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].str.upper()
# Added column: Caenorhabditis elegans (Nematode, N2) Match
# Added column: C.savignyi Match
# Added column: C.intestinalis Match
# Added column: Burton's mouthbrooder Match
# Added column: Blue-ringed sea krait Match
# {'Caenorhabditis elegans (Nematode, N2)': np.int64(101), 'C.savignyi': np.int64(9), 'C.intestinalis': np.int64(34), "Burton's mouthbrooder": np.int64(88), 'Blue-ringed sea krait': np.int64(2)}

# %%
ortholog_analysis_6_df.head()
# Out:
#   primary_gene_symbol alias_symbol HGNC_ID            ENSG_ID      NCBI_ID  \
# 0          A-GAMMA3'E    A-GAMMA-E      {}                 {}  {109951028}
# 1                A1BG          A1B     {5}  {ENSG00000121410}          {1}
# 2                A1BG          ABG     {5}  {ENSG00000121410}          {1}
# 3                A1BG          GAB     {5}  {ENSG00000121410}          {1}
# 4                A1BG     HYST2477     {5}  {ENSG00000121410}          {1}
#
#    Caenorhabditis elegans (Nematode, N2) Match  C.savignyi Match  \
# 0                                        False             False
# 1                                        False             False
# 2                                        False             False
# 3                                        False             False
# 4                                        False             False
#
#    C.intestinalis Match  Burton's mouthbrooder Match  \
# 0                 False                        False
# 1                 False                        False
# 2                 False                        False
# 3                 False                        False
# 4                 False                        False
#
#    Blue-ringed sea krait Match
# 0                        False
# 1                        False
# 2                        False
# 3                        False
# 4                        False

# %% [markdown]
# ### <a id='toc2_3_32_'></a>[(7) Cat](#toc0_)
# ### <a id='toc2_3_33_'></a>[(7) Chacoan peccary](#toc0_)
# ### <a id='toc2_3_34_'></a>[(7) Channel bull blenny](#toc0_)
# ### <a id='toc2_3_35_'></a>[(7) Channel catfish](#toc0_)
# ### <a id='toc2_3_36_'></a>[(7) Chicken](#toc0_)

# %%
ortholog_set_7_df = pd.read_csv(
    "../input/ortholog_set_7_df.txt", sep=",")

# %%
ortholog_analysis_7_df, ortholog_analysis_7_counts = match_alias_to_ortholog(subset_genes_df, ortholog_set_7_df)
print(ortholog_analysis_7_counts)
# Out:
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_6161/3502168503.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].str.upper()
# Added column: Chicken Match
# Added column: Channel catfish Match
# Added column: Channel bull blenny Match
# Added column: Chacoan peccary Match
# Added column: Cat Match
# {'Chicken': np.int64(154), 'Channel catfish': np.int64(172), 'Channel bull blenny': np.int64(129), 'Chacoan peccary': np.int64(10), 'Cat': np.int64(30)}

# %%
ortholog_analysis_7_df.head()
# Out:
#   primary_gene_symbol alias_symbol HGNC_ID            ENSG_ID      NCBI_ID  \
# 0          A-GAMMA3'E    A-GAMMA-E      {}                 {}  {109951028}
# 1                A1BG          A1B     {5}  {ENSG00000121410}          {1}
# 2                A1BG          ABG     {5}  {ENSG00000121410}          {1}
# 3                A1BG          GAB     {5}  {ENSG00000121410}          {1}
# 4                A1BG     HYST2477     {5}  {ENSG00000121410}          {1}
#
#    Chicken Match  Channel catfish Match  Channel bull blenny Match  \
# 0          False                  False                      False
# 1          False                  False                      False
# 2          False                  False                      False
# 3          False                  False                      False
# 4          False                  False                      False
#
#    Chacoan peccary Match  Cat Match
# 0                  False      False
# 1                  False      False
# 2                  False      False
# 3                  False      False
# 4                  False      False

# %% [markdown]
# ### <a id='toc2_3_37_'></a>[(8) Chimpanzee](#toc0_)
# ### <a id='toc2_3_38_'></a>[(8) Chinese hamster CHOK1GS](#toc0_)
# ### <a id='toc2_3_39_'></a>[(8) Chinese medaka](#toc0_)
# ### <a id='toc2_3_40_'></a>[(8) Chinese softshell turtle](#toc0_)
# ### <a id='toc2_3_41_'></a>[(8) Chinook salmon](#toc0_)

# %%
ortholog_set_8_df = pd.read_csv(
    "../input/ortholog_set_8_df.txt", sep=",")

# %%
ortholog_analysis_8_df, ortholog_analysis_8_counts = match_alias_to_ortholog(subset_genes_df, ortholog_set_8_df)
print(ortholog_analysis_8_counts)
# Out:
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_6161/3502168503.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].str.upper()
# Added column: Chinook salmon Match
# Added column: Chinese softshell turtle Match
# Added column: Chinese medaka Match
# Added column: Chinese hamster CHOK1GS Match
# Added column: Chimpanzee Match
# {'Chinook salmon': np.int64(210), 'Chinese softshell turtle': np.int64(2), 'Chinese medaka': np.int64(85), 'Chinese hamster CHOK1GS': np.int64(180), 'Chimpanzee': np.int64(44)}

# %%
ortholog_analysis_8_df.head()
# Out:
#   primary_gene_symbol alias_symbol HGNC_ID            ENSG_ID      NCBI_ID  \
# 0          A-GAMMA3'E    A-GAMMA-E      {}                 {}  {109951028}
# 1                A1BG          A1B     {5}  {ENSG00000121410}          {1}
# 2                A1BG          ABG     {5}  {ENSG00000121410}          {1}
# 3                A1BG          GAB     {5}  {ENSG00000121410}          {1}
# 4                A1BG     HYST2477     {5}  {ENSG00000121410}          {1}
#
#    Chinook salmon Match  Chinese softshell turtle Match  Chinese medaka Match  \
# 0                 False                           False                 False
# 1                 False                           False                 False
# 2                 False                           False                 False
# 3                 False                           False                 False
# 4                 False                           False                 False
#
#    Chinese hamster CHOK1GS Match  Chimpanzee Match
# 0                          False             False
# 1                          False             False
# 2                          False             False
# 3                          False             False
# 4                          False             False

# %% [markdown]
# ### <a id='toc2_3_42_'></a>[(9) Climbing perch](#toc0_)
# ### <a id='toc2_3_43_'></a>[(9) Clown anemone fish](#toc0_)
# ### <a id='toc2_3_44_'></a>[(9) Coelacanth](#toc0_)
# ### <a id='toc2_3_45_'></a>[(9) Coho salmon](#toc0_)
# ### <a id='toc2_3_46_'></a>[(9) Collared flycatcher](#toc0_)

# %%
ortholog_set_9_df = pd.read_csv(
    "../input/ortholog_set_9_df.txt", sep=",")

# %%
ortholog_analysis_9_df, ortholog_analysis_9_counts = match_alias_to_ortholog(subset_genes_df, ortholog_set_9_df)
print(ortholog_analysis_9_counts)
# Out:
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_6161/3502168503.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].str.upper()
# Added column: Climbing perch Match
# Added column: Clown anemonefish Match
# Added column: Coelacanth Match
# Added column: Coho salmon Match
# Added column: Collared flycatcher Match
# {'Climbing perch': np.int64(198), 'Clown anemonefish': np.int64(203), 'Coelacanth': np.int64(35), 'Coho salmon': np.int64(84), 'Collared flycatcher': np.int64(13)}

# %%
ortholog_analysis_9_df.head()
# Out:
#   primary_gene_symbol alias_symbol HGNC_ID            ENSG_ID      NCBI_ID  \
# 0          A-GAMMA3'E    A-GAMMA-E      {}                 {}  {109951028}
# 1                A1BG          A1B     {5}  {ENSG00000121410}          {1}
# 2                A1BG          ABG     {5}  {ENSG00000121410}          {1}
# 3                A1BG          GAB     {5}  {ENSG00000121410}          {1}
# 4                A1BG     HYST2477     {5}  {ENSG00000121410}          {1}
#
#    Climbing perch Match  Clown anemonefish Match  Coelacanth Match  \
# 0                 False                    False             False
# 1                 False                    False             False
# 2                 False                    False             False
# 3                 False                    False             False
# 4                 False                    False             False
#
#    Coho salmon Match  Collared flycatcher Match
# 0              False                      False
# 1              False                      False
# 2              False                      False
# 3              False                      False
# 4              False                      False

# %% [markdown]
# ### <a id='toc2_3_47_'></a>[(10) Common canary](#toc0_)
# ### <a id='toc2_3_48_'></a>[(10) Common carp](#toc0_)
# ### <a id='toc2_3_49_'></a>[(10) Commonwall lizard](#toc0_)
# ### <a id='toc2_3_50_'></a>[(10) Common wombat](#toc0_)
# ### <a id='toc2_3_51_'></a>[(10) Coquerel's sifaka](#toc0_)

# %%
ortholog_set_10_df = pd.read_csv(
    "../input/ortholog_set_10_df.txt", sep=",")

# %%
ortholog_analysis_10_df, ortholog_analysis_10_counts = match_alias_to_ortholog(subset_genes_df, ortholog_set_10_df)
print(ortholog_analysis_10_counts)
# Out:
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_6161/3502168503.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].str.upper()
# Added column: Common canary Match
# Added column: Common carp Match
# Added column: Common wall lizard Match
# Added column: Common wombat Match
# Added column: Coquerel's sifaka Match
# {'Common canary': np.int64(6), 'Common carp': np.int64(103), 'Common wall lizard': np.int64(10), 'Common wombat': np.int64(17), "Coquerel's sifaka": np.int64(14)}

# %%
ortholog_analysis_10_df.head()
# Out:
#   primary_gene_symbol alias_symbol HGNC_ID            ENSG_ID      NCBI_ID  \
# 0          A-GAMMA3'E    A-GAMMA-E      {}                 {}  {109951028}
# 1                A1BG          A1B     {5}  {ENSG00000121410}          {1}
# 2                A1BG          ABG     {5}  {ENSG00000121410}          {1}
# 3                A1BG          GAB     {5}  {ENSG00000121410}          {1}
# 4                A1BG     HYST2477     {5}  {ENSG00000121410}          {1}
#
#    Common canary Match  Common carp Match  Common wall lizard Match  \
# 0                False              False                     False
# 1                False              False                     False
# 2                False              False                     False
# 3                False              False                     False
# 4                False              False                     False
#
#    Common wombat Match  Coquerel's sifaka Match
# 0                False                    False
# 1                False                    False
# 2                False                    False
# 3                False                    False
# 4                False                    False

# %% [markdown]
# ## <a id='toc2_4_'></a>[Convert ortholog_analysis_dfs to csv for use in other notebooks](#toc0_)

# %%
ortholog_analysis_dfs_dict = {
    key: value for key, value in globals().items()
    if key.startswith('ortholog_analysis')  
    and key.endswith('_df')                
    and isinstance(value, pd.DataFrame)    
}

ortholog_analysis_dfs_dict
# Out:
# {'ortholog_analysis_1_df':       primary_gene_symbol  alias_symbol  HGNC_ID            ENSG_ID  \
#  0              A-GAMMA3'E     A-GAMMA-E       {}                 {}
#  1                    A1BG           A1B      {5}  {ENSG00000121410}
#  2                    A1BG           ABG      {5}  {ENSG00000121410}
#  3                    A1BG           GAB      {5}  {ENSG00000121410}
#  4                    A1BG      HYST2477      {5}  {ENSG00000121410}
#  ...                   ...           ...      ...                ...
#  86546               ZZEF1      FLJ10821  {29027}  {ENSG00000074755}
#  86547               ZZEF1      KIAA0399  {29027}  {ENSG00000074755}
#  86548               ZZEF1          ZZZ4  {29027}  {ENSG00000074755}
#  86549                ZZZ3         ATAC1  {24523}  {ENSG00000036549}
#  86550                ZZZ3  DKFZP564I052  {24523}  {ENSG00000036549}
#
#             NCBI_ID  Abingdon island giant tortoise Match  \
#  0      {109951028}                                 False
#  1              {1}                                 False
#  2              {1}                                 False
#  3              {1}                                 False
#  4              {1}                                 False
#  ...            ...                                   ...
#  86546      {23140}                                 False
#  86547      {23140}                                 False
#  86548      {23140}                                 False
#  86549      {26009}                                 False
#  86550      {26009}                                 False
#
#         African ostrich Match  Algerian mouse Match
#  0                      False                 False
#  1                      False                 False
#  2                      False                 False
#  3                      False                 False
#  4                      False                 False
#  ...                      ...                   ...
#  86546                  False                 False
#  86547                  False                 False
#  86548                  False                 False
#  86549                  False                 False
#  86550                  False                 False
#
#  [86551 rows x 8 columns],
#  'ortholog_analysis_2_df':       primary_gene_symbol  alias_symbol  HGNC_ID            ENSG_ID  \
#  0              A-GAMMA3'E     A-GAMMA-E       {}                 {}
#  1                    A1BG           A1B      {5}  {ENSG00000121410}
#  2                    A1BG           ABG      {5}  {ENSG00000121410}
#  3                    A1BG           GAB      {5}  {ENSG00000121410}
#  4                    A1BG      HYST2477      {5}  {ENSG00000121410}
#  ...                   ...           ...      ...                ...
#  86546               ZZEF1      FLJ10821  {29027}  {ENSG00000074755}
#  86547               ZZEF1      KIAA0399  {29027}  {ENSG00000074755}
#  86548               ZZEF1          ZZZ4  {29027}  {ENSG00000074755}
#  86549                ZZZ3         ATAC1  {24523}  {ENSG00000036549}
#  86550                ZZZ3  DKFZP564I052  {24523}  {ENSG00000036549}
#
#             NCBI_ID  Alpaca Match  Alpine marmot Match  Amazon molly Match  \
#  0      {109951028}         False                False               False
#  1              {1}         False                False               False
#  2              {1}         False                False               False
#  3              {1}         False                False               False
#  4              {1}         False                False               False
#  ...            ...           ...                  ...                 ...
#  86546      {23140}         False                False               False
#  86547      {23140}         False                False               False
#  86548      {23140}         False                False               False
#  86549      {26009}         False                False               False
#  86550      {26009}         False                False               False
#
#         American bison Match  American black bear Match
#  0                     False                      False
#  1                     False                      False
#  2                     False                      False
#  3                     False                      False
#  4                     False                      False
#  ...                     ...                        ...
#  86546                 False                      False
#  86547                 False                      False
#  86548                 False                      False
#  86549                 False                      False
#  86550                 False                      False
#
#  [86551 rows x 10 columns],
#  'ortholog_analysis_3_df':       primary_gene_symbol  alias_symbol  HGNC_ID            ENSG_ID  \
#  0              A-GAMMA3'E     A-GAMMA-E       {}                 {}
#  1                    A1BG           A1B      {5}  {ENSG00000121410}
#  2                    A1BG           ABG      {5}  {ENSG00000121410}
#  3                    A1BG           GAB      {5}  {ENSG00000121410}
#  4                    A1BG      HYST2477      {5}  {ENSG00000121410}
#  ...                   ...           ...      ...                ...
#  86546               ZZEF1      FLJ10821  {29027}  {ENSG00000074755}
#  86547               ZZEF1      KIAA0399  {29027}  {ENSG00000074755}
#  86548               ZZEF1          ZZZ4  {29027}  {ENSG00000074755}
#  86549                ZZZ3         ATAC1  {24523}  {ENSG00000036549}
#  86550                ZZZ3  DKFZP564I052  {24523}  {ENSG00000036549}
#
#             NCBI_ID  American mink Match  Arabian camel Match  \
#  0      {109951028}                False                False
#  1              {1}                False                False
#  2              {1}                False                False
#  3              {1}                False                False
#  4              {1}                False                False
#  ...            ...                  ...                  ...
#  86546      {23140}                False                False
#  86547      {23140}                False                False
#  86548      {23140}                False                False
#  86549      {26009}                False                False
#  86550      {26009}                False                False
#
#         Arctic ground squirrel Match  Argentine black and white tegu Match  \
#  0                             False                                 False
#  1                             False                                 False
#  2                             False                                 False
#  3                             False                                 False
#  4                             False                                 False
#  ...                             ...                                   ...
#  86546                         False                                 False
#  86547                         False                                 False
#  86548                         False                                 False
#  86549                         False                                 False
#  86550                         False                                 False
#
#         Armadillo Match  Asian bonytongue Match
#  0                False                   False
#  1                False                   False
#  2                False                   False
#  3                False                   False
#  4                False                   False
#  ...                ...                     ...
#  86546            False                   False
#  86547            False                   False
#  86548            False                   False
#  86549            False                   False
#  86550            False                   False
#
#  [86551 rows x 11 columns],
#  'ortholog_analysis_4_df':       primary_gene_symbol  alias_symbol  HGNC_ID            ENSG_ID  \
#  0              A-GAMMA3'E     A-GAMMA-E       {}                 {}
#  1                    A1BG           A1B      {5}  {ENSG00000121410}
#  2                    A1BG           ABG      {5}  {ENSG00000121410}
#  3                    A1BG           GAB      {5}  {ENSG00000121410}
#  4                    A1BG      HYST2477      {5}  {ENSG00000121410}
#  ...                   ...           ...      ...                ...
#  86546               ZZEF1      FLJ10821  {29027}  {ENSG00000074755}
#  86547               ZZEF1      KIAA0399  {29027}  {ENSG00000074755}
#  86548               ZZEF1          ZZZ4  {29027}  {ENSG00000074755}
#  86549                ZZZ3         ATAC1  {24523}  {ENSG00000036549}
#  86550                ZZZ3  DKFZP564I052  {24523}  {ENSG00000036549}
#
#             NCBI_ID  Atlantic cod Match  Atlantic herring Match  \
#  0      {109951028}               False                   False
#  1              {1}               False                   False
#  2              {1}               False                   False
#  3              {1}               False                   False
#  4              {1}               False                   False
#  ...            ...                 ...                     ...
#  86546      {23140}               False                   False
#  86547      {23140}               False                   False
#  86548      {23140}               False                   False
#  86549      {26009}               False                   False
#  86550      {26009}               False                   False
#
#         Atlantic salmon Match  Australian saltwater crocodile Match  \
#  0                      False                                 False
#  1                      False                                 False
#  2                      False                                 False
#  3                      False                                 False
#  4                      False                                 False
#  ...                      ...                                   ...
#  86546                  False                                 False
#  86547                  False                                 False
#  86548                  False                                 False
#  86549                  False                                 False
#  86550                  False                                 False
#
#         Ballan wrasse Match
#  0                    False
#  1                    False
#  2                    False
#  3                    False
#  4                    False
#  ...                    ...
#  86546                False
#  86547                False
#  86548                False
#  86549                False
#  86550                False
#
#  [86551 rows x 10 columns],
#  'ortholog_analysis_5_df':       primary_gene_symbol  alias_symbol  HGNC_ID            ENSG_ID  \
#  0              A-GAMMA3'E     A-GAMMA-E       {}                 {}
#  1                    A1BG           A1B      {5}  {ENSG00000121410}
#  2                    A1BG           ABG      {5}  {ENSG00000121410}
#  3                    A1BG           GAB      {5}  {ENSG00000121410}
#  4                    A1BG      HYST2477      {5}  {ENSG00000121410}
#  ...                   ...           ...      ...                ...
#  86546               ZZEF1      FLJ10821  {29027}  {ENSG00000074755}
#  86547               ZZEF1      KIAA0399  {29027}  {ENSG00000074755}
#  86548               ZZEF1          ZZZ4  {29027}  {ENSG00000074755}
#  86549                ZZZ3         ATAC1  {24523}  {ENSG00000036549}
#  86550                ZZZ3  DKFZP564I052  {24523}  {ENSG00000036549}
#
#             NCBI_ID  Blue whale Match  Black snub-nosed monkey Match  \
#  0      {109951028}             False                          False
#  1              {1}             False                          False
#  2              {1}             False                          False
#  3              {1}             False                          False
#  4              {1}             False                          False
#  ...            ...               ...                            ...
#  86546      {23140}             False                          False
#  86547      {23140}             False                          False
#  86548      {23140}             False                          False
#  86549      {26009}             False                          False
#  86550      {26009}             False                          False
#
#         Bicolor damselfish Match  Beluga whale Match  Barramundi perch Match
#  0                         False               False                   False
#  1                         False               False                   False
#  2                         False               False                   False
#  3                         False               False                   False
#  4                         False               False                   False
#  ...                         ...                 ...                     ...
#  86546                     False               False                   False
#  86547                     False               False                   False
#  86548                     False               False                   False
#  86549                     False               False                   False
#  86550                     False               False                   False
#
#  [86551 rows x 10 columns],
#  'ortholog_analysis_6_df':       primary_gene_symbol  alias_symbol  HGNC_ID            ENSG_ID  \
#  0              A-GAMMA3'E     A-GAMMA-E       {}                 {}
#  1                    A1BG           A1B      {5}  {ENSG00000121410}
#  2                    A1BG           ABG      {5}  {ENSG00000121410}
#  3                    A1BG           GAB      {5}  {ENSG00000121410}
#  4                    A1BG      HYST2477      {5}  {ENSG00000121410}
#  ...                   ...           ...      ...                ...
#  86546               ZZEF1      FLJ10821  {29027}  {ENSG00000074755}
#  86547               ZZEF1      KIAA0399  {29027}  {ENSG00000074755}
#  86548               ZZEF1          ZZZ4  {29027}  {ENSG00000074755}
#  86549                ZZZ3         ATAC1  {24523}  {ENSG00000036549}
#  86550                ZZZ3  DKFZP564I052  {24523}  {ENSG00000036549}
#
#             NCBI_ID  Caenorhabditis elegans (Nematode, N2) Match  \
#  0      {109951028}                                        False
#  1              {1}                                        False
#  2              {1}                                        False
#  3              {1}                                        False
#  4              {1}                                        False
#  ...            ...                                          ...
#  86546      {23140}                                        False
#  86547      {23140}                                        False
#  86548      {23140}                                        False
#  86549      {26009}                                        False
#  86550      {26009}                                        False
#
#         C.savignyi Match  C.intestinalis Match  Burton's mouthbrooder Match  \
#  0                 False                 False                        False
#  1                 False                 False                        False
#  2                 False                 False                        False
#  3                 False                 False                        False
#  4                 False                 False                        False
#  ...                 ...                   ...                          ...
#  86546             False                 False                        False
#  86547             False                 False                        False
#  86548             False                 False                        False
#  86549             False                 False                        False
#  86550             False                 False                        False
#
#         Blue-ringed sea krait Match
#  0                            False
#  1                            False
#  2                            False
#  3                            False
#  4                            False
#  ...                            ...
#  86546                        False
#  86547                        False
#  86548                        False
#  86549                        False
#  86550                        False
#
#  [86551 rows x 10 columns],
#  'ortholog_analysis_7_df':       primary_gene_symbol  alias_symbol  HGNC_ID            ENSG_ID  \
#  0              A-GAMMA3'E     A-GAMMA-E       {}                 {}
#  1                    A1BG           A1B      {5}  {ENSG00000121410}
#  2                    A1BG           ABG      {5}  {ENSG00000121410}
#  3                    A1BG           GAB      {5}  {ENSG00000121410}
#  4                    A1BG      HYST2477      {5}  {ENSG00000121410}
#  ...                   ...           ...      ...                ...
#  86546               ZZEF1      FLJ10821  {29027}  {ENSG00000074755}
#  86547               ZZEF1      KIAA0399  {29027}  {ENSG00000074755}
#  86548               ZZEF1          ZZZ4  {29027}  {ENSG00000074755}
#  86549                ZZZ3         ATAC1  {24523}  {ENSG00000036549}
#  86550                ZZZ3  DKFZP564I052  {24523}  {ENSG00000036549}
#
#             NCBI_ID  Chicken Match  Channel catfish Match  \
#  0      {109951028}          False                  False
#  1              {1}          False                  False
#  2              {1}          False                  False
#  3              {1}          False                  False
#  4              {1}          False                  False
#  ...            ...            ...                    ...
#  86546      {23140}          False                  False
#  86547      {23140}          False                  False
#  86548      {23140}          False                  False
#  86549      {26009}          False                  False
#  86550      {26009}          False                  False
#
#         Channel bull blenny Match  Chacoan peccary Match  Cat Match
#  0                          False                  False      False
#  1                          False                  False      False
#  2                          False                  False      False
#  3                          False                  False      False
#  4                          False                  False      False
#  ...                          ...                    ...        ...
#  86546                      False                  False      False
#  86547                      False                  False      False
#  86548                      False                  False      False
#  86549                      False                  False      False
#  86550                      False                  False      False
#
#  [86551 rows x 10 columns],
#  'ortholog_analysis_8_df':       primary_gene_symbol  alias_symbol  HGNC_ID            ENSG_ID  \
#  0              A-GAMMA3'E     A-GAMMA-E       {}                 {}
#  1                    A1BG           A1B      {5}  {ENSG00000121410}
#  2                    A1BG           ABG      {5}  {ENSG00000121410}
#  3                    A1BG           GAB      {5}  {ENSG00000121410}
#  4                    A1BG      HYST2477      {5}  {ENSG00000121410}
#  ...                   ...           ...      ...                ...
#  86546               ZZEF1      FLJ10821  {29027}  {ENSG00000074755}
#  86547               ZZEF1      KIAA0399  {29027}  {ENSG00000074755}
#  86548               ZZEF1          ZZZ4  {29027}  {ENSG00000074755}
#  86549                ZZZ3         ATAC1  {24523}  {ENSG00000036549}
#  86550                ZZZ3  DKFZP564I052  {24523}  {ENSG00000036549}
#
#             NCBI_ID  Chinook salmon Match  Chinese softshell turtle Match  \
#  0      {109951028}                 False                           False
#  1              {1}                 False                           False
#  2              {1}                 False                           False
#  3              {1}                 False                           False
#  4              {1}                 False                           False
#  ...            ...                   ...                             ...
#  86546      {23140}                 False                           False
#  86547      {23140}                 False                           False
#  86548      {23140}                 False                           False
#  86549      {26009}                 False                           False
#  86550      {26009}                 False                           False
#
#         Chinese medaka Match  Chinese hamster CHOK1GS Match  Chimpanzee Match
#  0                     False                          False             False
#  1                     False                          False             False
#  2                     False                          False             False
#  3                     False                          False             False
#  4                     False                          False             False
#  ...                     ...                            ...               ...
#  86546                 False                          False             False
#  86547                 False                          False             False
#  86548                 False                          False             False
#  86549                 False                          False             False
#  86550                 False                          False             False
#
#  [86551 rows x 10 columns],
#  'ortholog_analysis_9_df':       primary_gene_symbol  alias_symbol  HGNC_ID            ENSG_ID  \
#  0              A-GAMMA3'E     A-GAMMA-E       {}                 {}
#  1                    A1BG           A1B      {5}  {ENSG00000121410}
#  2                    A1BG           ABG      {5}  {ENSG00000121410}
#  3                    A1BG           GAB      {5}  {ENSG00000121410}
#  4                    A1BG      HYST2477      {5}  {ENSG00000121410}
#  ...                   ...           ...      ...                ...
#  86546               ZZEF1      FLJ10821  {29027}  {ENSG00000074755}
#  86547               ZZEF1      KIAA0399  {29027}  {ENSG00000074755}
#  86548               ZZEF1          ZZZ4  {29027}  {ENSG00000074755}
#  86549                ZZZ3         ATAC1  {24523}  {ENSG00000036549}
#  86550                ZZZ3  DKFZP564I052  {24523}  {ENSG00000036549}
#
#             NCBI_ID  Climbing perch Match  Clown anemonefish Match  \
#  0      {109951028}                 False                    False
#  1              {1}                 False                    False
#  2              {1}                 False                    False
#  3              {1}                 False                    False
#  4              {1}                 False                    False
#  ...            ...                   ...                      ...
#  86546      {23140}                 False                    False
#  86547      {23140}                 False                    False
#  86548      {23140}                 False                    False
#  86549      {26009}                 False                    False
#  86550      {26009}                 False                    False
#
#         Coelacanth Match  Coho salmon Match  Collared flycatcher Match
#  0                 False              False                      False
#  1                 False              False                      False
#  2                 False              False                      False
#  3                 False              False                      False
#  4                 False              False                      False
#  ...                 ...                ...                        ...
#  86546             False              False                      False
#  86547             False              False                      False
#  86548             False              False                      False
#  86549             False              False                      False
#  86550             False              False                      False
#
#  [86551 rows x 10 columns],
#  'ortholog_analysis_10_df':       primary_gene_symbol  alias_symbol  HGNC_ID            ENSG_ID  \
#  0              A-GAMMA3'E     A-GAMMA-E       {}                 {}
#  1                    A1BG           A1B      {5}  {ENSG00000121410}
#  2                    A1BG           ABG      {5}  {ENSG00000121410}
#  3                    A1BG           GAB      {5}  {ENSG00000121410}
#  4                    A1BG      HYST2477      {5}  {ENSG00000121410}
#  ...                   ...           ...      ...                ...
#  86546               ZZEF1      FLJ10821  {29027}  {ENSG00000074755}
#  86547               ZZEF1      KIAA0399  {29027}  {ENSG00000074755}
#  86548               ZZEF1          ZZZ4  {29027}  {ENSG00000074755}
#  86549                ZZZ3         ATAC1  {24523}  {ENSG00000036549}
#  86550                ZZZ3  DKFZP564I052  {24523}  {ENSG00000036549}
#
#             NCBI_ID  Common canary Match  Common carp Match  \
#  0      {109951028}                False              False
#  1              {1}                False              False
#  2              {1}                False              False
#  3              {1}                False              False
#  4              {1}                False              False
#  ...            ...                  ...                ...
#  86546      {23140}                False              False
#  86547      {23140}                False              False
#  86548      {23140}                False              False
#  86549      {26009}                False              False
#  86550      {26009}                False              False
#
#         Common wall lizard Match  Common wombat Match  Coquerel's sifaka Match
#  0                         False                False                    False
#  1                         False                False                    False
#  2                         False                False                    False
#  3                         False                False                    False
#  4                         False                False                    False
#  ...                         ...                  ...                      ...
#  86546                     False                False                    False
#  86547                     False                False                    False
#  86548                     False                False                    False
#  86549                     False                False                    False
#  86550                     False                False                    False
#
#  [86551 rows x 10 columns]}

# %%
output_dir = "../output/"

for name, df in ortholog_analysis_dfs_dict.items():
    file_path = f"{output_dir}{name}.csv"
    
    df.to_csv(file_path, index=True)
    print(f"Saved: {file_path}")
# Out:
# Saved: output/ortholog_analysis_1_df.csv
# Saved: output/ortholog_analysis_2_df.csv
# Saved: output/ortholog_analysis_3_df.csv
# Saved: output/ortholog_analysis_4_df.csv
# Saved: output/ortholog_analysis_5_df.csv
# Saved: output/ortholog_analysis_6_df.csv
# Saved: output/ortholog_analysis_7_df.csv
# Saved: output/ortholog_analysis_8_df.csv
# Saved: output/ortholog_analysis_9_df.csv
# Saved: output/ortholog_analysis_10_df.csv

# %% [markdown]
# # <a id='toc3_'></a>[HGNC Previous Symbol Capture](#toc0_)

# %% [markdown]
# ## <a id='toc3_1_'></a>[Download the HGNC custom download including the gene symbol, ID, and previous symbols](#toc0_)

# %%
hgnc_previous_symbols_df = pd.read_csv(
    "../input/HGNC_previous_symbols20241010.txt", sep="\t")
hgnc_previous_symbols_df
# Out:
#           HGNC ID Approved symbol             Previous symbols
# 0          HGNC:5            A1BG                          NaN
# 1      HGNC:37133        A1BG-AS1  NCRNA00181, A1BGAS, A1BG-AS
# 2      HGNC:24086            A1CF                          NaN
# 3          HGNC:6           A1S9T                          NaN
# 4          HGNC:7             A2M                          NaN
# ...           ...             ...                          ...
# 49077  HGNC:25820          ZYG11B                        ZYG11
# 49078  HGNC:13200             ZYX                          NaN
# 49079  HGNC:51695           ZYXP1                          NaN
# 49080  HGNC:29027           ZZEF1                          NaN
# 49081  HGNC:24523            ZZZ3                          NaN
#
# [49082 rows x 3 columns]

# %% [markdown]
# ## <a id='toc3_2_'></a>[Remove all genes with no previous symbols](#toc0_)

# %%
hgnc_previous_symbols_df = hgnc_previous_symbols_df.dropna(subset=["Previous symbols"])
hgnc_previous_symbols_df
# Out:
#           HGNC ID Approved symbol             Previous symbols
# 1      HGNC:37133        A1BG-AS1  NCRNA00181, A1BGAS, A1BG-AS
# 6      HGNC:23336           A2ML1                       CPAMD9
# 9          HGNC:8           A2MP1                         A2MP
# 12     HGNC:30005         A3GALT2                     A3GALT2P
# 13     HGNC:18149          A4GALT                           P1
# ...           ...             ...                          ...
# 49063  HGNC:23528          ZSWIM8                     KIAA0913
# 49065  HGNC:34495          ZSWIM9                     C19orf68
# 49066  HGNC:21224            ZUP1              C6orf113, ZUFSP
# 49071  HGNC:13197            ZWS1                          ZWS
# 49077  HGNC:25820          ZYG11B                        ZYG11
#
# [13067 rows x 3 columns]

# %% [markdown]
# ## <a id='toc3_3_'></a>[Explode the previous symbols so that it is only one symbol per row](#toc0_)

# %%
hgnc_previous_symbols_df["previous_symbol"] = hgnc_previous_symbols_df['Previous symbols'].str.split(',').apply(lambda x: [s.strip() for s in x])
hgnc_previous_symbols_df = hgnc_previous_symbols_df.explode('previous_symbol')
hgnc_previous_symbols_df = hgnc_previous_symbols_df.drop(columns=['Previous symbols'])
hgnc_previous_symbols_df
# Out:
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_6161/994957772.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hgnc_previous_symbols_df["previous_symbol"] = hgnc_previous_symbols_df['Previous symbols'].str.split(',').apply(lambda x: [s.strip() for s in x])
#           HGNC ID Approved symbol previous_symbol
# 1      HGNC:37133        A1BG-AS1      NCRNA00181
# 1      HGNC:37133        A1BG-AS1          A1BGAS
# 1      HGNC:37133        A1BG-AS1         A1BG-AS
# 6      HGNC:23336           A2ML1          CPAMD9
# 9          HGNC:8           A2MP1            A2MP
# ...           ...             ...             ...
# 49065  HGNC:34495          ZSWIM9        C19orf68
# 49066  HGNC:21224            ZUP1        C6orf113
# 49066  HGNC:21224            ZUP1           ZUFSP
# 49071  HGNC:13197            ZWS1             ZWS
# 49077  HGNC:25820          ZYG11B           ZYG11
#
# [16274 rows x 3 columns]

# %%
hgnc_previous_symbols_df.to_hdf(
    "../output/hgnc_previous_symbols_df.h5", key='df', mode='w'
)
# Out:
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_6161/762854523.py:1: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block0_values] [items->Index(['HGNC ID', 'Approved symbol', 'previous_symbol'], dtype='object')]
#
#   hgnc_previous_symbols_df.to_hdf(

# %% [markdown]
# ## <a id='toc3_4_'></a>[Make all of the gene symbols all caps](#toc0_)

# %% [markdown]
# Different species follow different gene nomenclature conventions. <br>
# For example, mouse genes have the first letter capitalized but the rest lowercase.<br>
# They need to be all caps for matching

# %%
hgnc_previous_symbols_df["Approved symbol"] = hgnc_previous_symbols_df["Approved symbol"].str.upper()
hgnc_previous_symbols_df["previous_symbol"] = hgnc_previous_symbols_df["previous_symbol"].str.upper()

# %% [markdown]
# ## <a id='toc3_5_'></a>[Match aliases to previous symbols!](#toc0_)

# %%
previous_symbol_analysis_df = subset_genes_df.copy()
previous_symbol_analysis_df
# Out:
#       primary_gene_symbol  alias_symbol  HGNC_ID            ENSG_ID  \
# 0              A-GAMMA3'E     A-GAMMA-E       {}                 {}
# 1                    A1BG           A1B      {5}  {ENSG00000121410}
# 2                    A1BG           ABG      {5}  {ENSG00000121410}
# 3                    A1BG           GAB      {5}  {ENSG00000121410}
# 4                    A1BG      HYST2477      {5}  {ENSG00000121410}
# ...                   ...           ...      ...                ...
# 86546               ZZEF1      FLJ10821  {29027}  {ENSG00000074755}
# 86547               ZZEF1      KIAA0399  {29027}  {ENSG00000074755}
# 86548               ZZEF1          ZZZ4  {29027}  {ENSG00000074755}
# 86549                ZZZ3         ATAC1  {24523}  {ENSG00000036549}
# 86550                ZZZ3  DKFZP564I052  {24523}  {ENSG00000036549}
#
#            NCBI_ID
# 0      {109951028}
# 1              {1}
# 2              {1}
# 3              {1}
# 4              {1}
# ...            ...
# 86546      {23140}
# 86547      {23140}
# 86548      {23140}
# 86549      {26009}
# 86550      {26009}
#
# [86551 rows x 5 columns]

# %%
previous_symbol_analysis_df["Previous Symbol Match"] = previous_symbol_analysis_df.apply(lambda row: 
                        any((hgnc_previous_symbols_df['Approved symbol'] == row['primary_gene_symbol']) 
                            & 
                            (hgnc_previous_symbols_df["previous_symbol"] == row['alias_symbol'])), axis=1)
previous_symbol_match_subset_genes_df = previous_symbol_analysis_df[previous_symbol_analysis_df["Previous Symbol Match"]]
previous_symbol_match_subset_genes_df
# Out:
#       primary_gene_symbol alias_symbol  HGNC_ID  \
# 5                A1BG-AS1      A1BG-AS  {37133}
# 6                A1BG-AS1       A1BGAS  {37133}
# 8                A1BG-AS1   NCRNA00181  {37133}
# 18                  A2ML1       CPAMD9  {23336}
# 22                  A2MP1         A2MP      {8}
# ...                   ...          ...      ...
# 86516              ZSWIM8     KIAA0913  {23528}
# 86517              ZSWIM9     C19ORF68  {34495}
# 86519                ZUP1     C6ORF113  {21224}
# 86522                ZUP1        ZUFSP  {21224}
# 86543              ZYG11B        ZYG11  {25820}
#
#                                   ENSG_ID   NCBI_ID  Previous Symbol Match
# 5                       {ENSG00000268895}  {503538}                   True
# 6                       {ENSG00000268895}  {503538}                   True
# 8                       {ENSG00000268895}  {503538}                   True
# 18                      {ENSG00000166535}  {144568}                   True
# 22     {ENSG00000291190, ENSG00000256069}       {3}                   True
# ...                                   ...       ...                    ...
# 86516                   {ENSG00000214655}   {23053}                   True
# 86517                   {ENSG00000185453}  {374920}                   True
# 86519                   {ENSG00000153975}  {221302}                   True
# 86522                   {ENSG00000153975}  {221302}                   True
# 86543                   {ENSG00000162378}   {79699}                   True
#
# [15585 rows x 6 columns]

# %%
previous_symbol_match_subset_genes_df.head(20)
# Out:
#     primary_gene_symbol alias_symbol  HGNC_ID  \
# 5              A1BG-AS1      A1BG-AS  {37133}
# 6              A1BG-AS1       A1BGAS  {37133}
# 8              A1BG-AS1   NCRNA00181  {37133}
# 18                A2ML1       CPAMD9  {23336}
# 22                A2MP1         A2MP      {8}
# 23              A3GALT2     A3GALT2P  {30005}
# 30               A4GALT           P1  {18149}
# 47               AACSP1        AACSL  {18226}
# 63                AAMDC     C11ORF67  {30205}
# 70                 AAR2      C20ORF4  {15886}
# 72                 AARD      C8ORF85  {33842}
# 74                AARS1         AARS     {20}
# 81              AARS1P1       AARSP1  {49894}
# 82                AARS2        AARSL  {21022}
# 123               ABCA1         ABC1     {29}
# 126               ABCA1       HDLDT1     {29}
# 130             ABCA11P       ABCA11     {31}
# 136              ABCA12        ICR2B  {14637}
# 140             ABCA15P     CRYM-AS1  {34405}
# 142             ABCA15P   NCRNA00169  {34405}
#
#                                 ENSG_ID      NCBI_ID  Previous Symbol Match
# 5                     {ENSG00000268895}     {503538}                   True
# 6                     {ENSG00000268895}     {503538}                   True
# 8                     {ENSG00000268895}     {503538}                   True
# 18                    {ENSG00000166535}     {144568}                   True
# 22   {ENSG00000291190, ENSG00000256069}          {3}                   True
# 23                    {ENSG00000184389}     {127550}                   True
# 30                    {ENSG00000128274}      {53947}                   True
# 47   {ENSG00000291019, ENSG00000250420}     {729522}                   True
# 63                    {ENSG00000087884}      {28971}                   True
# 70                    {ENSG00000131043}      {25980}                   True
# 72                    {ENSG00000205002}     {441376}                   True
# 74                    {ENSG00000090861}         {16}                   True
# 81                    {ENSG00000249038}  {106480683}                   True
# 82                    {ENSG00000124608}      {57505}                   True
# 123                   {ENSG00000165029}         {19}                   True
# 126                   {ENSG00000165029}         {19}                   True
# 130  {ENSG00000293360, ENSG00000251595}      {79963}                   True
# 136                   {ENSG00000144452}      {26154}                   True
# 140                   {ENSG00000189149}           {}                   True
# 142                   {ENSG00000189149}           {}                   True

# %%
previous_symbol_match_subset_genes_df.loc[previous_symbol_match_subset_genes_df["alias_symbol"] == "FWP007"]
# Out:
# Empty DataFrame
# Columns: [primary_gene_symbol, alias_symbol, HGNC_ID, ENSG_ID, NCBI_ID, Previous Symbol Match]
# Index: []

# %%
previous_symbol_match_subset_genes_df.to_hdf(
    "output/previous_symbol_match_subset_genes_df.h5", key='df', mode='w'
)
# Out:
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_6161/3081668469.py:1: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block0_values] [items->Index(['primary_gene_symbol', 'alias_symbol', 'HGNC_ID', 'ENSG_ID', 'NCBI_ID'], dtype='object')]
#
#   previous_symbol_match_subset_genes_df.to_hdf(

# %%
previous_symbol_analysis_df.to_hdf(
    "../output/previous_symbol_analysis_df.h5", key='df', mode='w'
)
# Out:
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_6161/2450742260.py:1: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block0_values] [items->Index(['primary_gene_symbol', 'alias_symbol', 'HGNC_ID', 'ENSG_ID', 'NCBI_ID'], dtype='object')]
#
#   previous_symbol_analysis_df.to_hdf(

# %% [markdown]
# # <a id='toc4_'></a>[FLJ Clone Name Capture](#toc0_)

# %% [markdown]
# ## <a id='toc4_1_'></a>[Download the FLJ database file including FLJ IDs](#toc0_)
# - https://flj.lifesciencedb.jp/top/sys_info/02_about_database/accession_no/download_v032.html
# - https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2780955/
# - https://www.ncbi.nlm.nih.gov/nuccore/AK027222?report=GenBank

# %%
with open("../input/Conversion_table_FLJ(1).txt", 'r') as file:
    for i, line in enumerate(file):
        print(f"Line {i}: {line.strip()}")
# Out:
# Line 0: Conversion table of Accession No/ FLJ ID/ Clone ID/ Sequence ID/ Another Sequence ID
# Line 1: (Data by Extracting System of Accurate ORFs)
# Line 2:
# Line 3: Accesion No	FLJ ID	Clone ID	Sequence ID	Another Sequence ID
# Line 4: AK075326	PSEC0001(FLJ91001)	NT2RM1000066	C-NT2RM1000066
# Line 5: AK172724	PSEC0002(FLJ91002)	NT2RM1000295	C-NT2RM1000295
# Line 6: AK075327	PSEC0003(FLJ91003)	NT2RM1000361	C-NT2RM1000361
# Line 7: AK075328	PSEC0004(FLJ91004)	NT2RM1000558	C-NT2RM1000558
# Line 8: AK075329	PSEC0005(FLJ91005)	NT2RM1000566	C-NT2RM1000566
# Line 9: AK075330	PSEC0006(FLJ91006)	NT2RM1000630	C-NT2RM1000630
# Line 10: AK075331	PSEC0007(FLJ91007)	NT2RM1000634	C-NT2RM1000634
# Line 11: AK075332	PSEC0008(FLJ91008)	NT2RM1000726	C-NT2RM1000726
# Line 12: AK075333	PSEC0009(FLJ91009)	NT2RM1000731	C-NT2RM1000731
# Line 13: AK075334	PSEC0011(FLJ91010)	NT2RM1000779	C-NT2RM1000779
# Line 14: AK075335	PSEC0012(FLJ91011)	NT2RM1000853	C-NT2RM1000853
# Line 15: AK075336	PSEC0013(FLJ91012)	NT2RM1000960	C-NT2RM1000960
# Line 16: AK075337	PSEC0015(FLJ91013)	NT2RM1001028	C-NT2RM1001028
# Line 17: AK075338	PSEC0016(FLJ91014)	NT2RM1001076	C-NT2RM1001076
# Line 18: AK075339	PSEC0017(FLJ91015)	NT2RM1001103	C-NT2RM1001103
# Line 19: AK172725	PSEC0018(FLJ91016)	NT2RP1000042	C-NT2RP1000042
# Line 20: AK075340	PSEC0019(FLJ91017)	NT2RP1000125	C-NT2RP1000125
# Line 21: AK075341	PSEC0020(FLJ91018)	NT2RP1000255	C-NT2RP1000255
# Line 22: AK075342	PSEC0021(FLJ91019)	NT2RP1000279	C-NT2RP1000279
# Line 23: AK075343	PSEC0022(FLJ91020)	NT2RP1000349	C-NT2RP1000349
# Line 24: AK172726	PSEC0023(FLJ91021)	NT2RP1000386	C-NT2RP1000386
# Line 25: AK075344	PSEC0024(FLJ91022)	NT2RP1000407	C-NT2RP1000407
# Line 128: AK075440	PSEC0131(FLJ91125)	PLACE1004322	C-PLACE1004322
# Line 129: AK172733	PSEC0132(FLJ91126)	PLACE1004427	C-PLACE1004427
# Line 130: AK075441	PSEC0133(FLJ91127)	PLACE1004507	C-PLACE1004507
# Line 131: AK075442	PSEC0134(FLJ91128)	PLACE1004757	C-PLACE1004757
# Line 132: AK075443	PSEC0135(FLJ91129)	PLACE1004850	C-PLACE1004850
# Line 133: AK075444	PSEC0136(FLJ91130)	PLACE1004904	C-PLACE1004904
# Line 134: AK075445	PSEC0137(FLJ91131)	PLACE1005047	C-PLACE1005047
# Line 135: AK075446	PSEC0138(FLJ91132)	PLACE1005659	C-PLACE1005659
# Line 136: AK075447	PSEC0139(FLJ91133)	PLACE1005760	C-PLACE1005760
# Line 137: AK075448	PSEC0140(FLJ91134)	PLACE1005783	C-PLACE1005783
# Line 138: AK075449	PSEC0141(FLJ91135)	PLACE1005913	C-PLACE1005913
# Line 139: AK075450	PSEC0142(FLJ91136)	PLACE1006269	C-PLACE1006269
# Line 140: AK075451	PSEC0143(FLJ91137)	PLACE1006472	C-PLACE1006472
# Line 141: AK075452	PSEC0144(FLJ91138)	PLACE1006610	C-PLACE1006610
# Line 142: AK075453	PSEC0145(FLJ91139)	PLACE1006711	C-PLACE1006711
# Line 143: AB038269	PSEC0146(FLJ91140)	PLACE1006979	C-PLACE1006979
# Line 144: AK075454	PSEC0147(FLJ91141)	PLACE1007190	C-PLACE1007190
# Line 145: AK075455	PSEC0148(FLJ91142)	PLACE1007202	C-PLACE1007202
# Line 146: AK075456	PSEC0149(FLJ91143)	PLACE1007338	C-PLACE1007338
# Line 147: AK075457	PSEC0150(FLJ91144)	PLACE1007635	C-PLACE1007635
# Line 148: AK075458	PSEC0151(FLJ91145)	PLACE1007878	C-PLACE1007878
# Line 149: AK075459	PSEC0152(FLJ91146)	PLACE1007885	C-PLACE1007885
# Line 150: AK075460	PSEC0153(FLJ91147)	PLACE1007950	C-PLACE1007950
# Line 151: AB056476	PSEC0154(FLJ91148)	PLACE1008092	C-PLACE1008092
# Line 152: AK075462	PSEC0155(FLJ91149)	PLACE1008105	C-PLACE1008105
# Line 153: AK075463	PSEC0156(FLJ91150)	PLACE1008107	C-PLACE1008107
# Line 154: AK075464	PSEC0157(FLJ91151)	PLACE1008238	C-PLACE1008238
# Line 155: AK075465	PSEC0158(FLJ91152)	PLACE1008738	C-PLACE1008738
# Line 156: AK075466	PSEC0159(FLJ91153)	PLACE1008994	C-PLACE1008994
# Line 157: AK172734	PSEC0160(FLJ91154)	PLACE1009236	C-PLACE1009236
# Line 158: AK075467	PSEC0161(FLJ91155)	PLACE1009580	C-PLACE1009580
# Line 159: AK075468	PSEC0162(FLJ91156)	PLACE1009772	C-PLACE1009772
# Line 160: AK075469	PSEC0163(FLJ91157)	PLACE1010330	C-PLACE1010330
# Line 161: AK075470	PSEC0164(FLJ91158)	PLACE1010482	C-PLACE1010482
# Line 162: AK075471	PSEC0165(FLJ91159)	PLACE1010978	C-PLACE1010978
# Line 163: AB056477	PSEC0166(FLJ91160)	PLACE1011019	C-PLACE1011019
# Line 164: AK075473	PSEC0167(FLJ91161)	PLACE1011134	C-PLACE1011134
# Line 165: AK075474	PSEC0168(FLJ91162)	PLACE1011146	C-PLACE1011146
# Line 166: AK075475	PSEC0169(FLJ91163)	PLACE1011360	C-PLACE1011360
# Line 167: AK075476	PSEC0170(FLJ91164)	PLACE1011386	C-PLACE1011386
# Line 168: AK075477	PSEC0171(FLJ91165)	PLACE1011514	C-PLACE1011514
# Line 169: AK075478	PSEC0172(FLJ91166)	PLACE1011835	C-PLACE1011835
# Line 170: AK075479	PSEC0173(FLJ91167)	NT2RP2000428	C-NT2RP2000428
# Line 171: AK075480	PSEC0174(FLJ91168)	NT2RP2002760	C-NT2RP2002760
# Line 172: AK075481	PSEC0175(FLJ91169)	OVARC1000169	C-OVARC1000169
# Line 173: AK075482	PSEC0176(FLJ91170)	OVARC1000254	C-OVARC1000254
# Line 174: AK075483	PSEC0177(FLJ91171)	OVARC1000287	C-OVARC1000287
# Line 175: AK075484	PSEC0178(FLJ91172)	OVARC1000636	C-OVARC1000636
# Line 176: AK075485	PSEC0179(FLJ91173)	OVARC1001209	C-OVARC1001209
# Line 177: AK075486	PSEC0180(FLJ91174)	OVARC1001359	C-OVARC1001359
# Line 178: AK075487	PSEC0181(FLJ91175)	OVARC1001499	C-OVARC1001499
# Line 179: AK075488	PSEC0182(FLJ91176)	OVARC1001636	C-OVARC1001636
# Line 180: AK075489	PSEC0183(FLJ91177)	OVARC1001849	C-OVARC1001849
# Line 181: AK172735	PSEC0184(FLJ91178)	OVARC1001983	C-OVARC1001983
# Line 182: AK075490	PSEC0185(FLJ91179)	OVARC1002091	C-OVARC1002091
# Line 183: AK075491	PSEC0186(FLJ91180)	OVARC1002093	C-OVARC1002093
# Line 184: AK075492	PSEC0187(FLJ91181)	HEMBA1000034	C-HEMBA1000034
# Line 185: AK172736	PSEC0188(FLJ91182)	HEMBA1000154	C-HEMBA1000154
# Line 186: AK172737	PSEC0189(FLJ91183)	HEMBA1000269	C-HEMBA1000269
# Line 187: AK075493	PSEC0190(FLJ91184)	HEMBA1000296	C-HEMBA1000296
# Line 188: AK075494	PSEC0191(FLJ91185)	HEMBA1000446	C-HEMBA1000446
# Line 189: AK075495	PSEC0192(FLJ91186)	HEMBA1000675	C-HEMBA1000675
# Line 190: AK075496	PSEC0193(FLJ91187)	HEMBA1000760	C-HEMBA1000760
# Line 191: AK172738	PSEC0194(FLJ91188)	HEMBA1001279	C-HEMBA1001279
# Line 192: AK075497	PSEC0195(FLJ91189)	HEMBA1001322	C-HEMBA1001322
# Line 193: AK075498	PSEC0196(FLJ91190)	HEMBA1001414	C-HEMBA1001414
# Line 194: AK075499	PSEC0197(FLJ91191)	HEMBA1001490	C-HEMBA1001490
# Line 195: AK075500	PSEC0198(FLJ91192)	HEMBA1001552	C-HEMBA1001552
# Line 196: AK075501	PSEC0199(FLJ91193)	HEMBA1001680	C-HEMBA1001680
# Line 197: AK075502	PSEC0200(FLJ91194)	HEMBA1001879	C-HEMBA1001879
# Line 198: AK075503	PSEC0201(FLJ91195)	HEMBA1002107	C-HEMBA1002107
# Line 199: AK075504	PSEC0202(FLJ91196)	HEMBA1002307	C-HEMBA1002307
# Line 200: AK075505	PSEC0203(FLJ91197)	HEMBA1002441	C-HEMBA1002441
# Line 201: AK075506	PSEC0204(FLJ91198)	HEMBA1002706	C-HEMBA1002706
# Line 202: AK075507	PSEC0205(FLJ91199)	HEMBA1002715	C-HEMBA1002715
# Line 203: AK075508	PSEC0206(FLJ91200)	HEMBA1002913	C-HEMBA1002913
# Line 204: AK075509	PSEC0207(FLJ91201)	HEMBA1002981	C-HEMBA1002981
# Line 205: AK075510	PSEC0208(FLJ91202)	HEMBA1003252	C-HEMBA1003252
# Line 206: AK075511	PSEC0209(FLJ91203)	HEMBA1003280	C-HEMBA1003280
# Line 207: AK075512	PSEC0210(FLJ91204)	HEMBA1003702	C-HEMBA1003702
# Line 208: AK075513	PSEC0211(FLJ91205)	HEMBA1003728	C-HEMBA1003728
# Line 209: AK075514	PSEC0212(FLJ91206)	HEMBA1003764	C-HEMBA1003764
# Line 210: AK075515	PSEC0213(FLJ91207)	HEMBA1004078	C-HEMBA1004078
# Line 211: AK075516	PSEC0214(FLJ91208)	HEMBA1004100	C-HEMBA1004100
# Line 212: AK075517	PSEC0215(FLJ91209)	HEMBA1004149	C-HEMBA1004149
# Line 213: AK075518	PSEC0216(FLJ91210)	HEMBA1004633	C-HEMBA1004633
# Line 214: AK075519	PSEC0217(FLJ91211)	HEMBA1004833	C-HEMBA1004833
# Line 215: AK075520	PSEC0218(FLJ91212)	HEMBA1005096	C-HEMBA1005096
# Line 216: AK075521	PSEC0219(FLJ91213)	HEMBA1005229	C-HEMBA1005229
# Line 217: AK075522	PSEC0220(FLJ91214)	HEMBA1005301	C-HEMBA1005301
# Line 218: AK172739	PSEC0221(FLJ91215)	HEMBA1005305	C-HEMBA1005305
# Line 219: AK075523	PSEC0222(FLJ91216)	HEMBA1005452	C-HEMBA1005452
# Line 220: AK075524	PSEC0223(FLJ91217)	HEMBA1005628	C-HEMBA1005628
# Line 221: AK075525	PSEC0224(FLJ91218)	HEMBA1005703	C-HEMBA1005703
# Line 222: AK075526	PSEC0225(FLJ91219)	HEMBA1005766	C-HEMBA1005766
# Line 223: AK075527	PSEC0226(FLJ91220)	HEMBA1005833	C-HEMBA1005833
# Line 224: AK075528	PSEC0227(FLJ91221)	HEMBA1006019	C-HEMBA1006019
# Line 225: AK075529	PSEC0228(FLJ91222)	HEMBA1006099	C-HEMBA1006099
# Line 226: AK075530	PSEC0229(FLJ91223)	HEMBA1006273	C-HEMBA1006273
# Line 227: AK075531	PSEC0230(FLJ91224)	HEMBA1006391	C-HEMBA1006391
# Line 228: AK075532	PSEC0231(FLJ91225)	HEMBA1006418	C-HEMBA1006418
# Line 229: AK075533	PSEC0232(FLJ91226)	HEMBA1006549	C-HEMBA1006549
# Line 230: AK075534	PSEC0233(FLJ91227)	HEMBA1006813	C-HEMBA1006813
# Line 265: AK074484	FLJ90003	BNGH41000091	C-BNGH41000091
# Line 266: AK074485	FLJ90004	HEMBA1000006	C-HEMBA1000006
# Line 267: AK074486	FLJ90005	HEMBA1000084	C-HEMBA1000084
# Line 268: AK074487	FLJ90006	HEMBA1000121	C-HEMBA1000121
# Line 269: AK074488	FLJ90007	HEMBA1000128	C-HEMBA1000128
# Line 270: AK074489	FLJ90008	HEMBA1000275	C-HEMBA1000275
# Line 271: AK074490	FLJ90009	HEMBA1000300	C-HEMBA1000300
# Line 272: AK074491	FLJ90010	HEMBA1000349	C-HEMBA1000349
# Line 273: AK074492	FLJ90011	HEMBA1000443	C-HEMBA1000443
# Line 274: AK074493	FLJ90012	HEMBA1000462	C-HEMBA1000462
# Line 275: AK074494	FLJ90013	HEMBA1000477	C-HEMBA1000477
# Line 276: AK074495	FLJ90014	HEMBA1000590	C-HEMBA1000590
# Line 277: AK074496	FLJ90015	HEMBA1000634	C-HEMBA1000634
# Line 278: AK074497	FLJ90016	HEMBA1000671	C-HEMBA1000671
# Line 279: AK074498	FLJ90017	HEMBA1000713	C-HEMBA1000713
# Line 280: AK074499	FLJ90018	HEMBA1000732	C-HEMBA1000732
# Line 281: AK074500	FLJ90019	HEMBA1000745	C-HEMBA1000745
# Line 282: AK074502	FLJ90021	HEMBA1000875	C-HEMBA1000875
# Line 283: AK074503	FLJ90022	HEMBA1000907	C-HEMBA1000907
# Line 284: AK074504	FLJ90023	HEMBA1000940	C-HEMBA1000940
# Line 285: AK074505	FLJ90024	HEMBA1000962	C-HEMBA1000962
# Line 286: AK074507	FLJ90026	HEMBA1001221	C-HEMBA1001221
# Line 287: AK074508	FLJ90027	HEMBA1001228	C-HEMBA1001228
# Line 288: AK074509	FLJ90028	HEMBA1001272	C-HEMBA1001272
# Line 289: AK074510	FLJ90029	HEMBA1001296	C-HEMBA1001296
# Line 290: AK074511	FLJ90030	HEMBA1001297	C-HEMBA1001297
# Line 291: AK074512	FLJ90031	HEMBA1001390	C-HEMBA1001390
# Line 292: AK074513	FLJ90032	HEMBA1001563	C-HEMBA1001563
# Line 293: AK074514	FLJ90033	HEMBA1001621	C-HEMBA1001621
# Line 294: AK074515	FLJ90034	HEMBA1001794	C-HEMBA1001794
# Line 295: AK074516	FLJ90035	HEMBA1001878	C-HEMBA1001878
# Line 296: AK074518	FLJ90037	HEMBA1002048	C-HEMBA1002048
# Line 297: AK074519	FLJ90038	HEMBA1002131	C-HEMBA1002131
# Line 298: AK074520	FLJ90039	HEMBA1002163	C-HEMBA1002163
# Line 299: AK074521	FLJ90040	HEMBA1002164	C-HEMBA1002164
# Line 300: AK074522	FLJ90041	HEMBA1002167	C-HEMBA1002167
# Line 301: AK074523	FLJ90042	HEMBA1002178	C-HEMBA1002178
# Line 302: AK074524	FLJ90043	HEMBA1002179	C-HEMBA1002179
# Line 303: AK074525	FLJ90044	HEMBA1002195	C-HEMBA1002195
# Line 304: AK074526	FLJ90045	HEMBA1002227	C-HEMBA1002227
# Line 305: AK074527	FLJ90046	HEMBA1002239	C-HEMBA1002239
# Line 794: AK075017	FLJ90536	OVARC1000105	C-OVARC1000105
# Line 795: AK075018	FLJ90537	OVARC1000137	C-OVARC1000137
# Line 796: AK075019	FLJ90538	OVARC1000208	C-OVARC1000208
# Line 797: AK075020	FLJ90539	OVARC1000255	C-OVARC1000255
# Line 798: AK075021	FLJ90540	OVARC1000275	C-OVARC1000275
# Line 799: AK075022	FLJ90541	OVARC1000298	C-OVARC1000298
# Line 800: AK075023	FLJ90542	OVARC1000307	C-OVARC1000307
# Line 801: AK075024	FLJ90543	OVARC1000313	C-OVARC1000313
# Line 802: AK075025	FLJ90544	OVARC1000331	C-OVARC1000331
# Line 803: AK075026	FLJ90545	OVARC1000410	C-OVARC1000410
# Line 804: AK075027	FLJ90546	OVARC1000439	C-OVARC1000439
# Line 805: AK075028	FLJ90547	OVARC1000467	C-OVARC1000467
# Line 806: AK075029	FLJ90548	OVARC1000529	C-OVARC1000529
# Line 807: AK075030	FLJ90549	OVARC1000553	C-OVARC1000553
# Line 808: AK075031	FLJ90550	OVARC1000775	C-OVARC1000775
# Line 809: AK075032	FLJ90551	OVARC1000779	C-OVARC1000779
# Line 810: AK075033	FLJ90552	OVARC1000811	C-OVARC1000811
# Line 811: AK075034	FLJ90553	OVARC1000853	C-OVARC1000853
# ...
# Line 30035: AK128860	FLJ46668	TRACH3007995	C-TRACH3007995
# Line 30036: AK128861	FLJ46674	TRACH3009148	C-TRACH3009148
# Line 30037: AK128862	FLJ46697	TRACH3013558	C-TRACH3013558
# Line 30038: AK131567	FLJ16820	TRACH3019290	C-TRACH3019290
# Line 30039: AK130850	FLJ27340	TST00132	C-TST00132
# Line 30040: AK130851	FLJ27341	TST02567	C-TST02567
# Line 30041: AK130852	FLJ27342	TST02993	C-TST02993
# Line 30042: AK130853	FLJ27343	TST03371	C-TST03371
# Line 30043: AK130854	FLJ27344	TST03461	C-TST03461
# Line 30044: AK130855	FLJ27345	TST03943	C-TST03943
# Line 30045: AK130856	FLJ27346	TST03947	C-TST03947
# Line 30046: AK130859	FLJ27349	TST04829	C-TST04829
# Line 30047: AK130860	FLJ27350	TST04882	C-TST04882
# Line 30048: AK130861	FLJ27351	TST05050	C-TST05050
# Line 30049: AK130862	FLJ27352	TST05165	C-TST05165
# Line 30050: AK130863	FLJ27353	TST05348	C-TST05348
# Line 30051: AK130864	FLJ27354	TST05713	C-TST05713
# Line 30052: AK130865	FLJ27355	TST05837	C-TST05837
# Line 30053: AK130866	FLJ27356	TST05949	C-TST05949
# Line 30054: AK130867	FLJ27357	TST06157	C-TST06157
# Line 30055: AK128863	FLJ46820	TSTOM2001571	C-TSTOM2001571
# Line 30056: AK128864	FLJ46830	UTERU2020226	C-UTERU2020226
# Line 30057: AK128865	FLJ46831	UTERU2022955	C-UTERU2022955
# Line 30058: AK128866	FLJ46832	UTERU2023941	C-UTERU2023941
# Line 30059: AK128867	FLJ46838	UTERU2035926	C-UTERU2035926
# Line 30060: AK128868	FLJ46846	UTERU3004635	C-UTERU3004635
# Line 30106: AK130976	FLJ27466	ADG01776	C-ADG01776
# Line 30107: AK130977	FLJ27467	ADG06160	C-ADG06160
# Line 30108: AK130978	FLJ27468	ADG08728	C-ADG08728
# Line 30109: AK130979	FLJ27469	CBL06308	C-CBL06308
# Line 30110: AK130980	FLJ27470	CBL07949	C-CBL07949
# Line 30111: AK130981	FLJ27471	DMC00410	C-DMC00410
# Line 30112: AK130982	FLJ27472	DMC06411	C-DMC06411
# Line 30113: AK130983	FLJ27473	DMC06528	C-DMC06528
# Line 30114: AK130984	FLJ27474	DMC07009	C-DMC07009
# Line 30115: AK130985	FLJ27475	DMC07108	C-DMC07108
# Line 30116: AK130986	FLJ27476	DMC08379	C-DMC08379
# Line 30117: AK130987	FLJ27477	DMC09313	C-DMC09313
# Line 30118: AK130988	FLJ27478	LVR00105	C-LVR00105
# Line 30119: AK130989	FLJ27479	LVR01187	C-LVR01187
# Line 30120: AK130990	FLJ27480	LVR01643	C-LVR01643
# Line 30121: AK130991	FLJ27481	PCD01382	C-PCD01382
# Line 30122: AK130992	FLJ27482	PCD04339	C-PCD04339
# Line 30123: AK130993	FLJ27483	PCD08351	C-PCD08351
# Line 30124: AK130994	FLJ27484	PNC02551	C-PNC02551
# Line 30125: AK130995	FLJ27485	PRS07088	C-PRS07088
# Line 30126: AK130996	FLJ27486	RCT02754	C-RCT02754
# Line 30127: AK130997	FLJ27487	RCT03859	C-RCT03859
# Line 30128: AK130998	FLJ27488	RCT04380	C-RCT04380
# Line 30129: AK130999	FLJ27489	STM01672	C-STM01672
# Line 30130: AK131000	FLJ27490	STM01825	C-STM01825
# Line 30131: AK131001	FLJ27491	STM02744	C-STM02744
# Line 30132: AK131002	FLJ27492	SYN03530	C-SYN03530
# Line 30133: AK131003	FLJ27493	TST03808	C-TST03808
# Line 30134: AK131004	FLJ27494	TST03877	C-TST03877
# Line 30135: AK131005	FLJ27495	TST03995	C-TST03995
# Line 30136: AK131006	FLJ27496	TST04138	C-TST04138
# Line 30137: AK131007	FLJ27497	TST05436	C-TST05436
# Line 30138: AK131008	FLJ27498	TST05526	C-TST05526
# Line 30139: AK131009	FLJ27499	TST06025	C-TST06025
# Line 30140: AK131010	FLJ27500	TST06265	C-TST06265
# Line 30141: AK131011	FLJ27501	TST06374	C-TST06374
# Line 30142: AK131012	FLJ27502	TST06617	C-TST06617
# Line 30143: AK131013	FLJ27503	TST06682	C-TST06682
# Line 30144: AK131014	FLJ27504	TST07195	C-TST07195
# Line 30145: AK131015	FLJ27505	TST07618	C-TST07618
# Line 30146: AK131016	FLJ27506	TST07655	C-TST07655
# Line 30147: AK131017	FLJ27507	TST07684	C-TST07684
# Line 30148: AK131018	FLJ27508	TST08061	C-TST08061
# Line 30149: AK131019	FLJ27509	TST08220	C-TST08220
# Line 30150: AK131020	FLJ27510	TST08253	C-TST08253
# Line 30151: AK131021	FLJ27511	TST08407	C-TST08407
# Line 30152: AK131022	FLJ27512	TST08465	C-TST08465
# Line 30153: AK131023	FLJ27513	TST08509	C-TST08509
# Line 30154: AK131024	FLJ27514	TST08513	C-TST08513
# Line 30198: AK024210	FLJ14148	MAMMA1002987	C-MAMMA1002987
# Line 30199: AK001500	FLJ10638	NT2RP2005690	C-NT2RP2005690
# Line 30200: AK001626	FLJ10764	NT2RP4000109	C-NT2RP4000109
# Line 30201: AK001716	FLJ10854	NT2RP4001507	C-NT2RP4001507
# Line 30202: AK056511	FLJ31949	NT2RP7007114	C-NT2RP7007114
# Line 30203: AK023300	FLJ13238	OVARC1000440	C-OVARC1000440
# Line 30204: AK001987	FLJ11125	PLACE1006195	C-PLACE1006195
# Line 30205: AK023639	FLJ13577	PLACE1008748	C-PLACE1008748
# Line 30206: AK002153	FLJ11291	PLACE1009659	C-PLACE1009659
# Line 30207: AK002203	FLJ11341	PLACE1010786	C-PLACE1010786
# Line 30208: AK055316	FLJ30754	FEBRA2000438	C-FEBRA2000438
# Line 30209: AK055371	FLJ30809	FEBRA2001438	C-FEBRA2001438
# Line 30210: AK056509	FLJ31947	NT2RP7006995	C-NT2RP7006995
# Line 30211: AK057443	FLJ32881	TESTI2004153	C-TESTI2004153
# Line 30212: AK095659	FLJ38340	FCBBF3027903	C-FCBBF3027903
# Line 30213: AK001521	FLJ10659	NT2RP2006071	C-NT2RP2006071
# Line 30214: AK027701	FLJ14795	NT2RP4001219	C-NT2RP4001219
# Line 30215: AK056586	FLJ32024	NTONG1000182	C-NTONG1000182
# Line 30216: AK057356	FLJ32794	TESTI2002423	C-TESTI2002423
# Line 30217: AK057360	FLJ32798	TESTI2002498	C-TESTI2002498
# Line 30218: AK058072	FLJ25343	TST01040	C-TST01040
# Line 30219: AK054697	FLJ30135	BRACE2000061	C-BRACE2000061
# Line 30220: AK024723	FLJ21070	CAS01707	C-CAS01707
# Line 30221: AK025242	FLJ21589	COL06960	C-COL06960
# Line 30222: AK027342	FLJ14436	HEMBA1007112	C-HEMBA1007112
# Line 30223: AK024134	FLJ14072	HEMBB1001665	C-HEMBB1001665
# Line 30224: AK172793	FLJ23954	HEP10825	C-HEP10825
# Line 30225: AK026344	FLJ22691	HSI11182	C-HSI11182
# Line 30226: AK022336	FLJ12274	MAMMA1001679	C-MAMMA1001679
# Line 30227: AK001693	FLJ10831	NT2RP4001148	C-NT2RP4001148
# Line 30228: AK056593	FLJ32031	NTONG2000107	C-NTONG2000107
# Line 30229: AK075070	FLJ90589	PLACE1000986	C-PLACE1000986
# Line 30230: AK023599	FLJ13537	PLACE1006534	C-PLACE1006534
# Line 30231: AK075176	FLJ90695	PLACE1006786	C-PLACE1006786
# Line 30232: AK092515	FLJ35196	PLACE6017701	C-PLACE6017701
# Line 30233: AK057081	FLJ32519	SMINT1000131	C-SMINT1000131
# Line 30234: AK092799	FLJ35480	SMINT2007932	C-SMINT2007932
# Line 30235: AK000009	FLJ20002	ADKA01577	C-ADKA01577
# Line 30236: AK074206	FLJ23626	ADSU00926	C-ADSU00926
# Line 30237: AK124391	FLJ42400	ASTRO2003581	C-ASTRO2003581
# Line 30238: AK123020	FLJ41024	BRACE2001353	C-BRACE2001353
# Line 30325: AK057825	FLJ25096	CBR00778	C-CBR00778
# Line 30326: AK000479	FLJ20472	KAT07023	C-KAT07023
# Line 30327: AK125921	FLJ43933	TESTI4013685	C-TESTI4013685
# Line 30328: AK125959	FLJ43971	TESTI4017901	C-TESTI4017901
# Line 30329: AK000594	FLJ20587	KAT09116	C-KAT09116

# %%
clone_symbols_df = pd.read_csv(
    "../input/Conversion_table_FLJ(1).txt", 
    sep="\t", 
    skiprows=3
)
clone_symbols_df
# Out:
#       Accesion No              FLJ ID      Clone ID     Sequence ID  \
# 0        AK075326  PSEC0001(FLJ91001)  NT2RM1000066  C-NT2RM1000066
# 1        AK172724  PSEC0002(FLJ91002)  NT2RM1000295  C-NT2RM1000295
# 2        AK075327  PSEC0003(FLJ91003)  NT2RM1000361  C-NT2RM1000361
# 3        AK075328  PSEC0004(FLJ91004)  NT2RM1000558  C-NT2RM1000558
# 4        AK075329  PSEC0005(FLJ91005)  NT2RM1000566  C-NT2RM1000566
# ...           ...                 ...           ...             ...
# 30321    AK057825            FLJ25096      CBR00778      C-CBR00778
# 30322    AK000479            FLJ20472      KAT07023      C-KAT07023
# 30323    AK125921            FLJ43933  TESTI4013685  C-TESTI4013685
# 30324    AK125959            FLJ43971  TESTI4017901  C-TESTI4017901
# 30325    AK000594            FLJ20587      KAT09116      C-KAT09116
#
#        Another Sequence ID
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# ...                    ...
# 30321                  NaN
# 30322                  NaN
# 30323                  NaN
# 30324                  NaN
# 30325                  NaN
#
# [30326 rows x 5 columns]

# %% [markdown]
# Extract values from the FLJ column so that there is only one ID per row

# %%
extracted_ids = clone_symbols_df['FLJ ID'].str.extract(r'([^()]+)\((.+?)\)')

result_rows = []

for index, row in clone_symbols_df.iterrows():
    flj_id = row['FLJ ID']
    if pd.notnull(extracted_ids.iloc[index, 0]):
        result_rows.append({'Accesion No': row['Accesion No'], 'ID': extracted_ids.iloc[index, 0]})  
        result_rows.append({'Accesion No': row['Accesion No'], 'ID': extracted_ids.iloc[index, 1]})  
    else:
        result_rows.append({'Accesion No': row['Accesion No'], 'ID': flj_id})

result_df = pd.DataFrame(result_rows)
result_df
# Out:
#       Accesion No        ID
# 0        AK075326  PSEC0001
# 1        AK075326  FLJ91001
# 2        AK172724  PSEC0002
# 3        AK172724  FLJ91002
# 4        AK075327  PSEC0003
# ...           ...       ...
# 30581    AK057825  FLJ25096
# 30582    AK000479  FLJ20472
# 30583    AK125921  FLJ43933
# 30584    AK125959  FLJ43971
# 30585    AK000594  FLJ20587
#
# [30586 rows x 2 columns]

# %%
result_df["ID"] = result_df["ID"].str.strip()

# %%
result_df.to_hdf(
    "../output/flj_clone_symbols_df.h5", key='df', mode='w'
)

# %%
clone_symbol_analysis_df = subset_genes_df.copy()
clone_symbol_analysis_df["Clone Symbol Match"] = clone_symbol_analysis_df['alias_symbol'].isin(result_df['ID'])

clone_symbol_match_subset_genes_df = clone_symbol_analysis_df[clone_symbol_analysis_df["Clone Symbol Match"]]
clone_symbol_match_subset_genes_df.head(20)
# Out:
#     primary_gene_symbol alias_symbol  HGNC_ID            ENSG_ID   NCBI_ID  \
# 7              A1BG-AS1     FLJ23569  {37133}  {ENSG00000268895}  {503538}
# 19                A2ML1     FLJ25179  {23336}  {ENSG00000166535}  {144568}
# 45                 AACS     FLJ12389  {21298}  {ENSG00000081760}   {65985}
# 56                AAGAB     FLJ11506  {25662}  {ENSG00000103591}   {79719}
# 65                AAMDC     FLJ21035  {30205}  {ENSG00000087884}   {28971}
# 132             ABCA11P     FLJ14297     {31}  {ENSG00000251595}   {79963}
# 138              ABCA13     FLJ33876  {14638}  {ENSG00000179869}  {154664}
# 139              ABCA13     FLJ33951  {14638}  {ENSG00000179869}  {154664}
# 141             ABCA15P     FLJ41766  {34405}  {ENSG00000189149}  {400508}
# 348               ABHD1     FLJ36128  {17553}  {ENSG00000143994}   {84696}
# 350              ABHD10     FLJ11342  {25656}  {ENSG00000144827}   {55347}
# 369              ABHD13     FLJ14906  {20293}  {ENSG00000139826}   {84945}
# 409              ABHD18     FLJ21106  {26111}  {ENSG00000164074}   {80167}
# 415               ABHD4     FLJ12816  {20154}  {ENSG00000100439}   {63874}
# 420               ABHD8     FLJ11743  {23759}  {ENSG00000127220}   {79575}
# 448             ABITRAM     FLJ20457   {1364}  {ENSG00000119328}   {54942}
# 483            ABRAXAS1     FLJ13614  {25829}  {ENSG00000163322}   {84142}
# 501               ABTB3     FLJ33957  {23844}  {ENSG00000151136}  {121551}
# 526              ACAD11     FLJ12592  {30211}  {ENSG00000240303}   {84129}
# 569               ACBD4     FLJ13322  {23337}  {ENSG00000181513}   {79777}
#
#      Clone Symbol Match
# 7                  True
# 19                 True
# 45                 True
# 56                 True
# 65                 True
# 132                True
# 138                True
# 139                True
# 141                True
# 348                True
# 350                True
# 369                True
# 409                True
# 415                True
# 420                True
# 448                True
# 483                True
# 501                True
# 526                True
# 569                True

# %%
clone_symbol_analysis_df
# Out:
#       primary_gene_symbol  alias_symbol  HGNC_ID            ENSG_ID  \
# 0              A-GAMMA3'E     A-GAMMA-E       {}                 {}
# 1                    A1BG           A1B      {5}  {ENSG00000121410}
# 2                    A1BG           ABG      {5}  {ENSG00000121410}
# 3                    A1BG           GAB      {5}  {ENSG00000121410}
# 4                    A1BG      HYST2477      {5}  {ENSG00000121410}
# ...                   ...           ...      ...                ...
# 86546               ZZEF1      FLJ10821  {29027}  {ENSG00000074755}
# 86547               ZZEF1      KIAA0399  {29027}  {ENSG00000074755}
# 86548               ZZEF1          ZZZ4  {29027}  {ENSG00000074755}
# 86549                ZZZ3         ATAC1  {24523}  {ENSG00000036549}
# 86550                ZZZ3  DKFZP564I052  {24523}  {ENSG00000036549}
#
#            NCBI_ID  Clone Symbol Match
# 0      {109951028}               False
# 1              {1}               False
# 2              {1}               False
# 3              {1}               False
# 4              {1}               False
# ...            ...                 ...
# 86546      {23140}                True
# 86547      {23140}               False
# 86548      {23140}               False
# 86549      {26009}               False
# 86550      {26009}               False
#
# [86551 rows x 6 columns]

# %%
clone_symbol_analysis_df.to_hdf(
    "../output/clone_symbol_analysis_df.h5", key='df', mode='w'
)
# Out:
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_6161/1000915458.py:1: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block0_values] [items->Index(['primary_gene_symbol', 'alias_symbol', 'HGNC_ID', 'ENSG_ID', 'NCBI_ID'], dtype='object')]
#
#   clone_symbol_analysis_df.to_hdf(

# %%
clone_symbol_match_subset_genes_df.to_hdf(
    "../output/clone_symbol_match_subset_genes_df.h5", key='df', mode='w'
)
# Out:
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_6161/3262910723.py:1: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block0_values] [items->Index(['primary_gene_symbol', 'alias_symbol', 'HGNC_ID', 'ENSG_ID', 'NCBI_ID'], dtype='object')]
#
#   clone_symbol_match_subset_genes_df.to_hdf(

# %% [markdown]
# # <a id='toc5_'></a>[Gene Family Symbol Capture](#toc0_)

# %% [markdown]
# Gene Group ID and abbreviation reference from HGNC: https://storage.googleapis.com/public-download-files/hgnc/csv/csv/genefamily_db_tables/family.csv or family.csv from https://www.genenames.org/download/gene-groups/#!/#tocAnchor-1-1

# %%
hgnc_genefamilies_df = pd.read_csv(
    "../input/hgnc_genefamily.csv", sep=",")
hgnc_genefamilies_df
# Out:
#         id abbreviation                                          name  \
# 0        3         FSCN                                 Fascin family
# 1        4         ABHD                 Abhydrolase domain containing
# 2        6        ZYG11             ZYG11 cell cycle regulator family
# 3        8           ZP                  Zona pellucida glycoproteins
# 4       10          VNN                                  Vanin family
# ...    ...          ...                                           ...
# 1810  3338          NaN                                  WICH complex
# 1811  3339          NaN                                  NoRC complex
# 1812  3340          NaN                                   RSF complex
# 1813  3341          NaN  ATP-dependent chromatin remodeling complexes
# 1814  3342          NaN                        Zinc fingers CHHC-type
#
#      external_note          pubmed_ids  \
# 0              NaN            21618240
# 1              NaN            23328280
# 2              NaN                 NaN
# 3              NaN            15760956
# 4              NaN            22155241
# ...            ...                 ...
# 1810           NaN            21326359
# 1811           NaN                 NaN
# 1812           NaN                 NaN
# 1813           NaN            19355820
# 1814           NaN  18703587, 19217400
#
#                                            desc_comment  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3     There are four major zona pellucida glycoprote...
# 4                                                   NaN
# ...                                                 ...
# 1810  Chromatin remodeling complex required for main...
# 1811  NoRC remodels nucleosomes at the rDNA promoter...
# 1812  A nucleosome remodeling complex that participa...
# 1813                                                NaN
# 1814  The CHHC U11-48K-type zinc finger contains fou...
#
#                          desc_label  \
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3      Zona pellucida glycoproteins
# 4                               NaN
# ...                             ...
# 1810                   WICH complex
# 1811                   NoRC complex
# 1812                    RSF complex
# 1813                            NaN
# 1814  U11-48K-like CHHC zinc finger
#
#                                             desc_source desc_go typical_gene
# 0                                                   NaN     NaN        FSCN1
# 1                                                   NaN     NaN        ABHD1
# 2                                                   NaN     NaN          NaN
# 3     Wikipedia|https://en.wikipedia.org/wiki/Zona p...     NaN          ZP1
# 4                                                   NaN     NaN         VNN1
# ...                                                 ...     ...          ...
# 1810  Complex portal|https://www.ebi.ac.uk/complexpo...     NaN          NaN
# 1811  Complex Portal|https://www.ebi.ac.uk/complexpo...     NaN          NaN
# 1812  Complex Portal|https://www.ebi.ac.uk/complexpo...     NaN          NaN
# 1813                                                NaN     NaN          NaN
# 1814  InterPro|https://www.ebi.ac.uk/interpro/entry/...     NaN       TRMT13
#
# [1815 rows x 10 columns]

# %%
hgnc_genefamilies_df = hgnc_genefamilies_df[["id","abbreviation"]]
hgnc_genefamilies_df.rename(columns={'id': 'Gene group ID'}, inplace=True)
# Out:
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_6161/4212134290.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hgnc_genefamilies_df.rename(columns={'id': 'Gene group ID'}, inplace=True)

# %% [markdown]
# Gene and Primary gene symbol and Group ID reference from HGNC: https://storage.googleapis.com/public-download-files/hgnc/csv/csv/genefamily_db_tables/gene_has_family.csv or gene_has_family.csv from https://www.genenames.org/download/gene-groups/#!/#tocAnchor-1-1 or HGNC Custom Downloads and selcet these three fields

# %%
hgnc_gene_groupid_df = pd.read_csv(
    "input/hgnc_id_symbol_genegroupid.txt", sep="\t")
hgnc_gene_groupid_df
# Out:
#           HGNC ID Approved symbol Gene group ID
# 0          HGNC:5            A1BG           594
# 1      HGNC:37133        A1BG-AS1          1987
# 2      HGNC:24086            A1CF           725
# 3          HGNC:6           A1S9T           NaN
# 4          HGNC:7             A2M          2148
# ...           ...             ...           ...
# 49078  HGNC:25820          ZYG11B        6|1492
# 49079  HGNC:13200             ZYX     1402|1691
# 49080  HGNC:51695           ZYXP1           NaN
# 49081  HGNC:29027           ZZEF1        91|863
# 49082  HGNC:24523            ZZZ3   91|532|1058
#
# [49083 rows x 3 columns]

# %%
hgnc_gene_groupid_df['HGNC ID'] = hgnc_gene_groupid_df['HGNC ID'].str.replace('^HGNC:', '', regex=True)
hgnc_gene_groupid_df['Gene group ID'] = hgnc_gene_groupid_df['Gene group ID'].str.split('|')
hgnc_gene_groupid_df = hgnc_gene_groupid_df.explode('Gene group ID')

# %%
hgnc_gene_groupid_df = hgnc_gene_groupid_df.dropna(subset=['Gene group ID'])
hgnc_gene_groupid_df['Gene group ID'] = hgnc_gene_groupid_df['Gene group ID'].astype(int)

# %%
hgnc_gene_group_root_df = hgnc_gene_groupid_df.merge(hgnc_genefamilies_df, on='Gene group ID', how='left')
hgnc_gene_group_root_df
# Out:
#       HGNC ID Approved symbol  Gene group ID abbreviation
# 0           5            A1BG            594          NaN
# 1       37133        A1BG-AS1           1987          NaN
# 2       24086            A1CF            725          RBM
# 3           7             A2M           2148          NaN
# 4       27057         A2M-AS1           1987          NaN
# ...       ...             ...            ...          ...
# 31399   29027           ZZEF1             91          ZZZ
# 31400   29027           ZZEF1            863          NaN
# 31401   24523            ZZZ3             91          ZZZ
# 31402   24523            ZZZ3            532          NaN
# 31403   24523            ZZZ3           1058         ATAC
#
# [31404 rows x 4 columns]

# %%
hgnc_gene_group_root_df["HGNC ID"] = hgnc_gene_group_root_df["HGNC ID"].apply(
    lambda x: f"HGNC:{int(x)}" if pd.notna(x) and x == int(x) else f"HGNC:{x}" if pd.notna(x) else x
)

# %%
hgnc_gene_group_root_df = hgnc_gene_group_root_df.dropna(subset=['abbreviation'])

# %%
hgnc_gene_group_root_df["abbreviation"] = hgnc_gene_group_root_df["abbreviation"].str.upper()
hgnc_gene_group_root_df["Approved symbol"] = hgnc_gene_group_root_df["Approved symbol"].str.upper()
# Out:
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_6161/3423886471.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hgnc_gene_group_root_df["abbreviation"] = hgnc_gene_group_root_df["abbreviation"].str.upper()
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_6161/3423886471.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hgnc_gene_group_root_df["Approved symbol"] = hgnc_gene_group_root_df["Approved symbol"].str.upper()

# %%
hgnc_gene_group_root_df.to_hdf(
    "../output/hgnc_gene_group_root_df.h5", key='df', mode='w'
)

# %%
gene_group_analysis_df = subset_genes_df.copy()

# %% [markdown]
# Add the 'Prefix Gene Group Symbol Match' column with True/False

# %%
gene_group_analysis_df["Prefix Gene Group Symbol Match"] = gene_group_analysis_df.apply(
    lambda row: any(
        row['alias_symbol'].startswith(abbreviation)  # Check if alias_symbol starts with abbreviation
        for abbreviation in hgnc_gene_group_root_df.loc[
            hgnc_gene_group_root_df['Approved symbol'] == row['primary_gene_symbol'], 
            'abbreviation'
        ]  # Loop through all abbreviations for the gene_symbol
    ), axis=1
)

# %% [markdown]
# Add the 'Matching Abbreviation' column with the actual abbreviation (or None if no match)

# %%
gene_group_analysis_df["Matching Abbreviation"] = gene_group_analysis_df.apply(
    lambda row: next((
        abbreviation for abbreviation in hgnc_gene_group_root_df.loc[
            hgnc_gene_group_root_df['Approved symbol'] == row['primary_gene_symbol'], 
            'abbreviation'
        ] 
        if row['alias_symbol'].startswith(abbreviation)  # Check if alias_symbol starts with abbreviation
    ),  ""), axis=1
)

# %%
gene_group_prefix_match_subset_genes_df = gene_group_analysis_df[gene_group_analysis_df["Prefix Gene Group Symbol Match"]]
gene_group_analysis_df
# Out:
#       primary_gene_symbol  alias_symbol  HGNC_ID            ENSG_ID  \
# 0              A-GAMMA3'E     A-GAMMA-E       {}                 {}
# 1                    A1BG           A1B      {5}  {ENSG00000121410}
# 2                    A1BG           ABG      {5}  {ENSG00000121410}
# 3                    A1BG           GAB      {5}  {ENSG00000121410}
# 4                    A1BG      HYST2477      {5}  {ENSG00000121410}
# ...                   ...           ...      ...                ...
# 86546               ZZEF1      FLJ10821  {29027}  {ENSG00000074755}
# 86547               ZZEF1      KIAA0399  {29027}  {ENSG00000074755}
# 86548               ZZEF1          ZZZ4  {29027}  {ENSG00000074755}
# 86549                ZZZ3         ATAC1  {24523}  {ENSG00000036549}
# 86550                ZZZ3  DKFZP564I052  {24523}  {ENSG00000036549}
#
#            NCBI_ID  Prefix Gene Group Symbol Match Matching Abbreviation
# 0      {109951028}                           False
# 1              {1}                           False
# 2              {1}                           False
# 3              {1}                           False
# 4              {1}                           False
# ...            ...                             ...                   ...
# 86546      {23140}                           False
# 86547      {23140}                           False
# 86548      {23140}                            True                   ZZZ
# 86549      {26009}                            True                  ATAC
# 86550      {26009}                           False
#
# [86551 rows x 7 columns]

# %%
gene_group_prefix_match_subset_genes_df.to_hdf(
    "../output/gene_group_prefix_match_subset_genes_df.h5", key='df', mode='w'
)
# Out:
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_6161/2065329530.py:1: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block1_values] [items->Index(['primary_gene_symbol', 'alias_symbol', 'HGNC_ID', 'ENSG_ID', 'NCBI_ID',
#        'Matching Abbreviation'],
#       dtype='object')]
#
#   gene_group_prefix_match_subset_genes_df.to_hdf(

# %%
gene_group_analysis_df.to_hdf(
    "../output/gene_group_analysis_df.h5", key='df', mode='w'
)
# Out:
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_6161/1135911867.py:1: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block1_values] [items->Index(['primary_gene_symbol', 'alias_symbol', 'HGNC_ID', 'ENSG_ID', 'NCBI_ID',
#        'Matching Abbreviation'],
#       dtype='object')]
#
#   gene_group_analysis_df.to_hdf(

# %% [markdown]
# # <a id='toc6_'></a>[Disorder/Disease Symbol Capture](#toc0_)

# %% [markdown]
# OMIM downloads: https://omim.org/downloads/

# %%
mim2gene_df = pd.read_csv(
    "../input/mim2gene.txt", 
    sep="\t", 
    comment="#",
    names=["gene_MIM_number", "MIM Entry Type", "Entrez Gene ID (NCBI)", "Approved Gene Symbol (HGNC)", "Ensembl Gene ID (Ensembl)"],
    dtype={"Entrez Gene ID (NCBI)": "Int64"}
    )

mim2gene_df.drop(columns=['MIM Entry Type'], inplace=True)

mim2gene_df
# Out:
#        gene_MIM_number  Entrez Gene ID (NCBI) Approved Gene Symbol (HGNC)  \
# 0               100050                   <NA>                         NaN
# 1               100070              100329167                         NaN
# 2               100100                   <NA>                         NaN
# 3               100200                   <NA>                         NaN
# 4               100300                   <NA>                         NaN
# ...                ...                    ...                         ...
# 28979           621039                   <NA>                         NaN
# 28980           621040                   <NA>                         NaN
# 28981           621041                   <NA>                         NaN
# 28982           621042                   <NA>                         NaN
# 28983           621043                   <NA>                         NaN
#
#       Ensembl Gene ID (Ensembl)
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# ...                         ...
# 28979                       NaN
# 28980                       NaN
# 28981                       NaN
# 28982                       NaN
# 28983                       NaN
#
# [28984 rows x 4 columns]

# %%
mim2gene_df["Entrez Gene ID (NCBI)"] = mim2gene_df["Entrez Gene ID (NCBI)"].apply(
    lambda x: f"GENE ID:{int(x)}" if pd.notna(x) and x == int(x) else f"GENE ID:{x}" if pd.notna(x) else x
)

# %%
mim2gene_df.loc[mim2gene_df["Approved Gene Symbol (HGNC)"]=="A2ML1"]
# Out:
#        gene_MIM_number Entrez Gene ID (NCBI) Approved Gene Symbol (HGNC)  \
# 18573           610627        GENE ID:144568                       A2ML1
#
#       Ensembl Gene ID (Ensembl)
# 18573           ENSG00000166535

# %%
mimTitles_df = pd.read_csv(
    "../input/mimTitles.txt", 
    sep="\t", 
    comment="#",
    names=["Prefix", "phenotype_MIM_number", "phenotype_preferred_title_symbol", "phenotype_alternative_titles_symbols", "phenotype__included_titles_symbols"]
    )
mimTitles_df.head()
# Out:
#         Prefix  phenotype_MIM_number  \
# 0          NaN                100050
# 1      Percent                100070
# 2  Number Sign                100100
# 3          NaN                100200
# 4  Number Sign                100300
#
#                phenotype_preferred_title_symbol  \
# 0          AARSKOG SYNDROME, AUTOSOMAL DOMINANT
# 1  AORTIC ANEURYSM, FAMILIAL ABDOMINAL, 1; AAA1
# 2                     PRUNE BELLY SYNDROME; PBS
# 3                                ABDUCENS PALSY
# 4                 ADAMS-OLIVER SYNDROME 1; AOS1
#
#                 phenotype_alternative_titles_symbols  \
# 0                                                NaN
# 1  ANEURYSM, ABDOMINAL AORTIC; AAA;; ABDOMINAL AO...
# 2  ABDOMINAL MUSCLES, ABSENCE OF, WITH URINARY TR...
# 3                                                NaN
# 4  AOS;; ABSENCE DEFECT OF LIMBS, SCALP, AND SKUL...
#
#                   phenotype__included_titles_symbols
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  APLASIA CUTIS CONGENITA, CONGENITAL HEART DEFE...

# %%
mimTitles_df[mimTitles_df['phenotype__included_titles_symbols'].str.contains("INCLUDED", na=False)]
# Out:
#             Prefix  phenotype_MIM_number  \
# 4      Number Sign                100300
# 8             Plus                100650
# 30     Number Sign                101200
# 31     Number Sign                101400
# 32     Number Sign                101600
# ...            ...                   ...
# 25884  Number Sign                618057
# 25974  Number Sign                618147
# 26086     Asterisk                618259
# 26186     Asterisk                618359
# 26233  Number Sign                618406
#
#                         phenotype_preferred_title_symbol  \
# 4                          ADAMS-OLIVER SYNDROME 1; AOS1
# 8                 ALDEHYDE DEHYDROGENASE 2 FAMILY; ALDH2
# 30                                        APERT SYNDROME
# 31                         SAETHRE-CHOTZEN SYNDROME; SCS
# 32                                     PFEIFFER SYNDROME
# ...                                                  ...
# 25884             DRUG METABOLISM, ALTERED, CES1-RELATED
# 25974  INTELLECTUAL DEVELOPMENTAL DISORDER WITH HYPER...
# 26086      LONG INTERGENIC NONCODING RNA 1565; LINC01565
# 26186                    ZINC FINGER PROTEIN 197; ZNF197
# 26233  BODY MASS INDEX QUANTITATIVE TRAIT LOCUS 20; B...
#
#                     phenotype_alternative_titles_symbols  \
# 4      AOS;; ABSENCE DEFECT OF LIMBS, SCALP, AND SKUL...
# 8      ALDEHYDE DEHYDROGENASE 2;; ALDH, LIVER MITOCHO...
# 30           ACROCEPHALOSYNDACTYLY, TYPE I; ACS1;; ACS I
# 31     ACROCEPHALOSYNDACTYLY, TYPE III; ACS3;; ACS II...
# 32     ACROCEPHALOSYNDACTYLY, TYPE V; ACS5;; ACS V;; ...
# ...                                                  ...
# 25884                                                NaN
# 25974                                                NaN
# 26086                                 lincRNA 1565;; GR6
# 26186                      ZINC FINGER PROTEIN 20; ZNF20
# 26233  OBESITY;; MELANOCORTIN 4 RECEPTOR DEFICIENCY;;...
#
#                       phenotype__included_titles_symbols
# 4      APLASIA CUTIS CONGENITA, CONGENITAL HEART DEFE...
# 8      SUBLINGUAL NITROGLYCERIN, SUSCEPTIBILITY TO PO...
# 30     APERT-CROUZON DISEASE, INCLUDED;; ACROCEPHALOS...
# 31     SAETHRE-CHOTZEN SYNDROME WITH EYELID ANOMALIES...
# 32     CRANIOFACIAL-SKELETAL-DERMATOLOGIC DYSPLASIA, ...
# ...                                                  ...
# 25884  CARBOXYLESTERASE 1 DEFICIENCY, INCLUDED;; MONO...
# 25974       CHROMOSOME 14q32 DELETION SYNDROME, INCLUDED
# 26086                     GR6/EVI1 FUSION GENE, INCLUDED
# 26186  VHL-ASSOCIATED KRAB-A DOMAIN-CONTAINING PROTEI...
# 26233                   OBESITY, RESISTANCE TO, INCLUDED
#
# [1337 rows x 5 columns]

# %%
# remove all asterisks(*) and carets(^). gene(*) and entry(^) records removed

# %%
mimTitles_df = mimTitles_df[mimTitles_df['Prefix'] != "Asterisk"]

# %%
mimTitles_df = mimTitles_df[mimTitles_df['Prefix'] != "Caret"]

# %%
df = mimTitles_df.copy()
df_preffered = df[['Prefix', 'phenotype_MIM_number', 'phenotype_preferred_title_symbol']].copy()
df_preffered['titles_symbols'] = df_preffered['phenotype_preferred_title_symbol']
df_preffered
# Out:
#             Prefix  phenotype_MIM_number  \
# 0              NaN                100050
# 1          Percent                100070
# 2      Number Sign                100100
# 3              NaN                100200
# 4      Number Sign                100300
# ...            ...                   ...
# 26266  Number Sign                618440
# 26269  Number Sign                618443
# 26274  Number Sign                618449
# 26276  Number Sign                618451
# 26278  Number Sign                618453
#
#                         phenotype_preferred_title_symbol  \
# 0                   AARSKOG SYNDROME, AUTOSOMAL DOMINANT
# 1           AORTIC ANEURYSM, FAMILIAL ABDOMINAL, 1; AAA1
# 2                              PRUNE BELLY SYNDROME; PBS
# 3                                         ABDUCENS PALSY
# 4                          ADAMS-OLIVER SYNDROME 1; AOS1
# ...                                                  ...
# 26266                 OCULOSKELETODENTAL SYNDROME; OCSKD
# 26269  NEURODEVELOPMENTAL DISORDER WITH OR WITHOUT VA...
# 26274            CILIARY DYSKINESIA, PRIMARY, 41; CILD41
# 26276  NEURODEGENERATION, EARLY-ONSET, WITH CHOREOATH...
# 26278  INTELLECTUAL DEVELOPMENTAL DISORDER WITH SHORT...
#
#                                           titles_symbols
# 0                   AARSKOG SYNDROME, AUTOSOMAL DOMINANT
# 1           AORTIC ANEURYSM, FAMILIAL ABDOMINAL, 1; AAA1
# 2                              PRUNE BELLY SYNDROME; PBS
# 3                                         ABDUCENS PALSY
# 4                          ADAMS-OLIVER SYNDROME 1; AOS1
# ...                                                  ...
# 26266                 OCULOSKELETODENTAL SYNDROME; OCSKD
# 26269  NEURODEVELOPMENTAL DISORDER WITH OR WITHOUT VA...
# 26274            CILIARY DYSKINESIA, PRIMARY, 41; CILD41
# 26276  NEURODEGENERATION, EARLY-ONSET, WITH CHOREOATH...
# 26278  INTELLECTUAL DEVELOPMENTAL DISORDER WITH SHORT...
#
# [8916 rows x 4 columns]

# %%
df = mimTitles_df.copy()
df_alt = df[['Prefix', 'phenotype_MIM_number', 'phenotype_alternative_titles_symbols']].copy()
df_alt['titles_symbols'] = df_alt['phenotype_alternative_titles_symbols']
df_alt
# Out:
#             Prefix  phenotype_MIM_number  \
# 0              NaN                100050
# 1          Percent                100070
# 2      Number Sign                100100
# 3              NaN                100200
# 4      Number Sign                100300
# ...            ...                   ...
# 26266  Number Sign                618440
# 26269  Number Sign                618443
# 26274  Number Sign                618449
# 26276  Number Sign                618451
# 26278  Number Sign                618453
#
#                     phenotype_alternative_titles_symbols  \
# 0                                                    NaN
# 1      ANEURYSM, ABDOMINAL AORTIC; AAA;; ABDOMINAL AO...
# 2      ABDOMINAL MUSCLES, ABSENCE OF, WITH URINARY TR...
# 3                                                    NaN
# 4      AOS;; ABSENCE DEFECT OF LIMBS, SCALP, AND SKUL...
# ...                                                  ...
# 26266  CATARACTS, EARLY-ONSET, WITH SKELETAL AND DENT...
# 26269                                                NaN
# 26274                                                NaN
# 26276                                                NaN
# 26278                                                NaN
#
#                                           titles_symbols
# 0                                                    NaN
# 1      ANEURYSM, ABDOMINAL AORTIC; AAA;; ABDOMINAL AO...
# 2      ABDOMINAL MUSCLES, ABSENCE OF, WITH URINARY TR...
# 3                                                    NaN
# 4      AOS;; ABSENCE DEFECT OF LIMBS, SCALP, AND SKUL...
# ...                                                  ...
# 26266  CATARACTS, EARLY-ONSET, WITH SKELETAL AND DENT...
# 26269                                                NaN
# 26274                                                NaN
# 26276                                                NaN
# 26278                                                NaN
#
# [8916 rows x 4 columns]

# %%
df = mimTitles_df.copy()
df_inc = df[['Prefix', 'phenotype_MIM_number', 'phenotype__included_titles_symbols']].copy()
df_inc['titles_symbols'] = df_inc['phenotype__included_titles_symbols']
df_inc
# Out:
#             Prefix  phenotype_MIM_number  \
# 0              NaN                100050
# 1          Percent                100070
# 2      Number Sign                100100
# 3              NaN                100200
# 4      Number Sign                100300
# ...            ...                   ...
# 26266  Number Sign                618440
# 26269  Number Sign                618443
# 26274  Number Sign                618449
# 26276  Number Sign                618451
# 26278  Number Sign                618453
#
#                       phenotype__included_titles_symbols  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4      APLASIA CUTIS CONGENITA, CONGENITAL HEART DEFE...
# ...                                                  ...
# 26266                                                NaN
# 26269                                                NaN
# 26274                                                NaN
# 26276                                                NaN
# 26278                                                NaN
#
#                                           titles_symbols
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4      APLASIA CUTIS CONGENITA, CONGENITAL HEART DEFE...
# ...                                                  ...
# 26266                                                NaN
# 26269                                                NaN
# 26274                                                NaN
# 26276                                                NaN
# 26278                                                NaN
#
# [8916 rows x 4 columns]

# %%
df_combined = pd.concat([df_preffered, df_alt, df_inc], ignore_index=True)
df_combined.drop(["phenotype_preferred_title_symbol","phenotype_alternative_titles_symbols", "phenotype__included_titles_symbols"], axis=1, inplace=True)
df_combined
# Out:
#             Prefix  phenotype_MIM_number  \
# 0              NaN                100050
# 1          Percent                100070
# 2      Number Sign                100100
# 3              NaN                100200
# 4      Number Sign                100300
# ...            ...                   ...
# 26743  Number Sign                618440
# 26744  Number Sign                618443
# 26745  Number Sign                618449
# 26746  Number Sign                618451
# 26747  Number Sign                618453
#
#                                      titles_symbols
# 0              AARSKOG SYNDROME, AUTOSOMAL DOMINANT
# 1      AORTIC ANEURYSM, FAMILIAL ABDOMINAL, 1; AAA1
# 2                         PRUNE BELLY SYNDROME; PBS
# 3                                    ABDUCENS PALSY
# 4                     ADAMS-OLIVER SYNDROME 1; AOS1
# ...                                             ...
# 26743                                           NaN
# 26744                                           NaN
# 26745                                           NaN
# 26746                                           NaN
# 26747                                           NaN
#
# [26748 rows x 3 columns]

# %%
df_combined.dropna(subset=['titles_symbols'], inplace=True)
df_combined
# Out:
#             Prefix  phenotype_MIM_number  \
# 0              NaN                100050
# 1          Percent                100070
# 2      Number Sign                100100
# 3              NaN                100200
# 4      Number Sign                100300
# ...            ...                   ...
# 26442      Percent                617955
# 26449  Number Sign                617966
# 26496  Number Sign                618057
# 26548  Number Sign                618147
# 26721  Number Sign                618406
#
#                                           titles_symbols
# 0                   AARSKOG SYNDROME, AUTOSOMAL DOMINANT
# 1           AORTIC ANEURYSM, FAMILIAL ABDOMINAL, 1; AAA1
# 2                              PRUNE BELLY SYNDROME; PBS
# 3                                         ABDUCENS PALSY
# 4                          ADAMS-OLIVER SYNDROME 1; AOS1
# ...                                                  ...
# 26442  FETAL HYDANTOIN SYNDROME, INCLUDED; FHS, INCLUDED
# 26449                   EZETIMIBE, RESPONSE TO, INCLUDED
# 26496  CARBOXYLESTERASE 1 DEFICIENCY, INCLUDED;; MONO...
# 26548       CHROMOSOME 14q32 DELETION SYNDROME, INCLUDED
# 26721                   OBESITY, RESISTANCE TO, INCLUDED
#
# [13988 rows x 3 columns]

# %% [markdown]
# split title and symbol

# %%
def split_name_symbol_pairs(value):
    pairs = value.split(';;')

    result = []
    for pair in pairs:
        parts = pair.strip().split(';')
        if len(parts) == 2:
            result.append(parts)
    return result

# %%
split_data = df_combined['titles_symbols'].apply(split_name_symbol_pairs)
split_data
# Out:
# 0                                                       []
# 1        [[AORTIC ANEURYSM, FAMILIAL ABDOMINAL, 1,  AAA1]]
# 2                           [[PRUNE BELLY SYNDROME,  PBS]]
# 3                                                       []
# 4                       [[ADAMS-OLIVER SYNDROME 1,  AOS1]]
#                                ...
# 26442    [[FETAL HYDANTOIN SYNDROME, INCLUDED,  FHS, IN...
# 26449                                                   []
# 26496                                                   []
# 26548                                                   []
# 26721                                                   []
# Name: titles_symbols, Length: 13988, dtype: object

# %%
df_reset = df_combined.reset_index(drop=True)
split_data_reset = split_data.reset_index(drop=True)

# %% [markdown]
# put titles and symbols into different columns

# %%
expanded_rows = []

for row, titles_symbols in zip(df_reset.iterrows(), split_data_reset):
    _, row_data = row  # Unpack the row from iterrows()
    col1_value = row_data['Prefix']
    col2_value = row_data['phenotype_MIM_number']
    
    # Ensure split_data contains lists of name-symbol pairs
    for title_symbol in titles_symbols:
        title = title_symbol[0].strip()
        symbol = title_symbol[1].strip()
        # Append the expanded row (duplicating col1 and col2)
        expanded_rows.append([col1_value, col2_value, title, symbol])

# %%
expanded_df = pd.DataFrame(expanded_rows, columns=['Prefix', 'phenotype_MIM_number', 'pheno_title', 'pheno_symbol'])
expanded_df
# Out:
#            Prefix  phenotype_MIM_number  \
# 0         Percent                100070
# 1     Number Sign                100100
# 2     Number Sign                100300
# 3            Plus                100650
# 4     Number Sign                100800
# ...           ...                   ...
# 7922  Number Sign                616553
# 7923  Number Sign                617047
# 7924  Number Sign                617347
# 7925  Number Sign                617562
# 7926      Percent                617955
#
#                                             pheno_title      pheno_symbol
# 0                AORTIC ANEURYSM, FAMILIAL ABDOMINAL, 1              AAA1
# 1                                  PRUNE BELLY SYNDROME               PBS
# 2                               ADAMS-OLIVER SYNDROME 1              AOS1
# 3                       ALDEHYDE DEHYDROGENASE 2 FAMILY             ALDH2
# 4                                        ACHONDROPLASIA               ACH
# ...                                                 ...               ...
# 7922  DYSKERATOSIS CONGENITA, AUTOSOMAL RECESSIVE 7,...   DKCB7, INCLUDED
# 7923  CARDIOMYOPATHY, FAMILIAL RESTRICTIVE, 5, INCLUDED    RCM5, INCLUDED
# 7924  LOW DENSITY LIPOPROTEIN CHOLESTEROL LEVEL QUAN...  LDLCQ5, INCLUDED
# 7925                      JOUBERT SYNDROME 29, INCLUDED  JBTS29, INCLUDED
# 7926                 FETAL HYDANTOIN SYNDROME, INCLUDED     FHS, INCLUDED
#
# [7927 rows x 4 columns]

# %% [markdown]
# In pheno-symbols, there are vlaues that are not just symbols

# %%
comma_df = expanded_df[expanded_df["pheno_symbol"].str.contains(",")]
comma_df
# Out:
#            Prefix  phenotype_MIM_number  \
# 5985  Number Sign                106210
# 6084  Number Sign                122000
# 6125  Number Sign                129500
# 6127  Number Sign                130000
# 6128  Number Sign                130010
# ...           ...                   ...
# 7922  Number Sign                616553
# 7923  Number Sign                617047
# 7924  Number Sign                617347
# 7925  Number Sign                617562
# 7926      Percent                617955
#
#                                             pheno_title      pheno_symbol
# 5985                              ANIRIDIA II, FORMERLY     AN2, FORMERLY
# 6084  CORNEAL ENDOTHELIAL DYSTROPHY 1, AUTOSOMAL DOM...   CHED1, FORMERLY
# 6125        ECTODERMAL DYSPLASIA, HIDROTIC, 2, FORMERLY    HED2, FORMERLY
# 6127           EHLERS-DANLOS SYNDROME, TYPE I, FORMERLY    EDS1, FORMERLY
# 6128          EHLERS-DANLOS SYNDROME, TYPE II, FORMERLY    EDS2, FORMERLY
# ...                                                 ...               ...
# 7922  DYSKERATOSIS CONGENITA, AUTOSOMAL RECESSIVE 7,...   DKCB7, INCLUDED
# 7923  CARDIOMYOPATHY, FAMILIAL RESTRICTIVE, 5, INCLUDED    RCM5, INCLUDED
# 7924  LOW DENSITY LIPOPROTEIN CHOLESTEROL LEVEL QUAN...  LDLCQ5, INCLUDED
# 7925                      JOUBERT SYNDROME 29, INCLUDED  JBTS29, INCLUDED
# 7926                 FETAL HYDANTOIN SYNDROME, INCLUDED     FHS, INCLUDED
#
# [441 rows x 4 columns]

# %% [markdown]
# the vocab present that is not a symbol in DIGENIC, INCLUDED, FORMERLY, ICHTHYOSIS, CONGENITAL, WITH TRICHOTHIODYSTROPHY (identified via manual review)

# %% [markdown]
# always occur after a comma (excpet ICHTHYOSIS)

# %%
comma_df[comma_df["pheno_symbol"].str.contains("DIGENIC")]
# Out:
#            Prefix  phenotype_MIM_number  \
# 7368  Number Sign                611818
# 7684  Number Sign                192500
# 7795  Number Sign                603830
# 7796  Number Sign                603830
# 7876  Number Sign                613688
# 7877  Number Sign                613688
# 7878  Number Sign                613688
# 7879  Number Sign                613688
# 7880  Number Sign                613693
# 7881  Number Sign                613695
#
#                                   pheno_title               pheno_symbol
# 7368  LONG QT SYNDROME 2/9, DIGENIC, INCLUDED  LQT2/9, DIGENIC, INCLUDED
# 7684  LONG QT SYNDROME 1/2, DIGENIC, INCLUDED  LQT1/2, DIGENIC, INCLUDED
# 7795  LONG QT SYNDROME 2/3, DIGENIC, INCLUDED  LQT2/3, DIGENIC, INCLUDED
# 7796  LONG QT SYNDROME 3/6, DIGENIC, INCLUDED  LQT3/6, DIGENIC, INCLUDED
# 7876  LONG QT SYNDROME 1/2, DIGENIC, INCLUDED  LQT1/2, DIGENIC, INCLUDED
# 7877  LONG QT SYNDROME 2/3, DIGENIC, INCLUDED  LQT2/3, DIGENIC, INCLUDED
# 7878  LONG QT SYNDROME 2/5, DIGENIC, INCLUDED  LQT2/5, DIGENIC, INCLUDED
# 7879  LONG QT SYNDROME 2/9, DIGENIC, INCLUDED  LQT2/9, DIGENIC, INCLUDED
# 7880  LONG QT SYNDROME 3/6, DIGENIC, INCLUDED  LQT3/6, DIGENIC, INCLUDED
# 7881  LONG QT SYNDROME 2/5, DIGENIC, INCLUDED  LQT2/5, DIGENIC, INCLUDED

# %% [markdown]
# Remove comman and all vocabulary after in the pheno_symbol column

# %%
expanded_df['pheno_symbol'] = expanded_df['pheno_symbol'].str.split(',').str[0]

# %%
cleaned_mimTitles_df = expanded_df.copy()

# %%
cleaned_mimTitles_df[cleaned_mimTitles_df['pheno_symbol'].str.contains("A2M", na=False)]
# Out:
#      Prefix  phenotype_MIM_number                       pheno_title  \
# 3983    NaN                614036  ALPHA-2-MACROGLOBULIN DEFICIENCY
#
#      pheno_symbol
# 3983         A2MD

# %%
cleaned_mimTitles_df.loc[cleaned_mimTitles_df["pheno_symbol"]=="A2MD"]
# Out:
#      Prefix  phenotype_MIM_number                       pheno_title  \
# 3983    NaN                614036  ALPHA-2-MACROGLOBULIN DEFICIENCY
#
#      pheno_symbol
# 3983         A2MD

# %%
cleaned_mimTitles_df.loc[cleaned_mimTitles_df["phenotype_MIM_number"]==166760]
# Out:
#           Prefix  phenotype_MIM_number                      pheno_title  \
# 600  Number Sign                166760  OTITIS MEDIA, SUSCEPTIBILITY TO
#
#     pheno_symbol
# 600          OMS

# %%
cleaned_mimTitles_df.loc[cleaned_mimTitles_df["pheno_symbol"]=="OMS"]
# Out:
#           Prefix  phenotype_MIM_number                      pheno_title  \
# 600  Number Sign                166760  OTITIS MEDIA, SUSCEPTIBILITY TO
#
#     pheno_symbol
# 600          OMS

# %%
morbidmap_df = pd.read_csv(
    "../input/morbidmap.txt", 
    sep="\t", 
    comment="#",
    names=["Phenotype", "gene_symbols", "gene_MIM_number", "gene_cyto_location"]
    )
morbidmap_df.head(50)
# Out:
#                                             Phenotype  \
# 0        17,20-lyase deficiency, isolated, 202110 (3)
# 1   17-alpha-hydroxylase/17,20-lyase deficiency, 2...
# 2      2-aminoadipic 2-oxoadipic aciduria, 204750 (3)
# 3               2-methylbutyrylglycinuria, 610006 (3)
# 4                          3-M syndrome 1, 273750 (3)
# 5                          3-M syndrome 2, 612921 (3)
# 6                          3-M syndrome 3, 614205 (3)
# 7   3-Methylcrotonyl-CoA carboxylase 1 deficiency,...
# 8   3-Methylcrotonyl-CoA carboxylase 2 deficiency,...
# 9   3-hydroxyacyl-CoA dehydrogenase deficiency, 23...
# 10  3-hydroxyisobutryl-CoA hydrolase deficiency, 2...
# 11  3-methylglutaconic aciduria with deafness, enc...
# 12    3-methylglutaconic aciduria, type I, 250950 (3)
# 13  3-methylglutaconic aciduria, type III, 258501 (3)
# 14   3-methylglutaconic aciduria, type IX, 617698 (3)
# 15    3-methylglutaconic aciduria, type V, 610198 (3)
# 16  3-methylglutaconic aciduria, type VII, with ca...
# 17  3-methylglutaconic aciduria, type VIII, 617248...
# 18                         3MC syndrome 1, 257920 (3)
# 19                         3MC syndrome 2, 265050 (3)
# 20                         3MC syndrome 3, 248340 (3)
# 21                                   3p- syndrome (4)
# 22                  46, XX sex reversal 4, 617480 (3)
# 23                    46XX sex reversal 1, 400045 (3)
# 24                            46XX sex reversal 2 (4)
# 25                            46XX sex reversal 3 (4)
# 26  46XY partial gonadal dysgenesis, with minifasc...
# 27                    46XY sex reversal 1, 400044 (3)
# 28                           46XY sex reversal 10 (4)
# 29  46XY sex reversal 2, dosage-sensitive, 300018 (3)
# 30                    46XY sex reversal 3, 612965 (3)
# 31                            46XY sex reversal 4 (4)
# 32                    46XY sex reversal 6, 613762 (3)
# 33                    46XY sex reversal 7, 233420 (3)
# 34                    46XY sex reversal 8, 614279 (3)
# 35                    46XY sex reversal 9, 616067 (3)
# 36                5-fluorouracil toxicity, 274270 (3)
# 37              5-oxoprolinase deficiency, 260005 (3)
# 38  ?2,4-dienoyl-CoA reductase deficiency, 616034 (3)
# 39                   ?46XY sex reversal 5, 613080 (3)
# 40                      ?ACAT2 deficiency, 614055 (1)
# 41             ?Abruzzo-Erickson syndrome, 302905 (3)
# 42  ?Acromesomelic dysplasia, Hunter-Thompson type...
# 43  ?Advanced sleep phase syndrome, familial, 3, 6...
# 44                  ?Agammaglobulinemia 5, 613506 (3)
# 45  ?Agammaglobulinemia 7, autosomal recessive, 61...
# 46         ?Al-Gazali-Bakalinova syndrome, 607131 (3)
# 47  ?Alopecia, neurologic defects, and endocrinopa...
# 48  ?Amelogenesis imperfecta, type IE, X-linked 2 (2)
# 49    ?Amelogenesis imperfecta, type IIIB, 617607 (3)
#
#                                          gene_symbols  gene_MIM_number  \
# 0                             CYP17A1, CYP17, P450C17           609300
# 1                             CYP17A1, CYP17, P450C17           609300
# 2                     DHTKD1, KIAA1630, AMOXAD, CMT2Q           614984
# 3                                       ACADSB, SBCAD           600301
# 4                                           CUL7, 3M1           609577
# 5                                OBSL1, KIAA0657, 3M2           610991
# 6                                          CCDC8, 3M3           614145
# 7                                         MCCC1, MCCA           609010
# 8                                         MCCC2, MCCB           609014
# 9                                 HADHSC, SCHAD, HHF4           601609
# 10                                              HIBCH           610690
# 11                                     SERAC1, MEGDEL           614725
# 12                                                AUH           600529
# 13                                         OPA3, MGA3           606580
# 14                               TIMM50, TIM50, MGCA9           607381
# 15                                     DNAJC19, TIM14           608977
# 16                         CLPB, SKD3, MEGCANN, MGCA7           616254
# 17                  HTRA2, OMI, PARK13, PRSS25, MGCA8           606441
# 18                                 MASP1, CRARF, 3MC1           600521
# 19                                COLEC11, CLK1, 3MC2           612502
# 20                                COLEC10, CLL1, 3MC3           607620
# 21                          DEL3pterp25, C3DELpterp25           613792
# 22  NR5A1, FTZF1, FTZ1, SF1, AD4BP, POF7, SRXY3, S...           184757
# 23                        SRY, TDF, TDY, SRXX1, SRXY1           480000
# 24                                  SRXX2, DUP17q24.3           278850
# 25                                              SRXX3           300833
# 26                                  DHH, SRXY7, GDXYM           605423
# 27                        SRY, TDF, TDY, SRXX1, SRXY1           480000
# 28                                             SRXY10           616425
# 29                       NR0B1, DAX1, AHC, AHX, SRXY2           300473
# 30  NR5A1, FTZF1, FTZ1, SF1, AD4BP, POF7, SRXY3, S...           184757
# 31                       DEL9p24.3, C9DELp24.3, SRXY4           154230
# 32                         MAP3K1, MEKK1, MEKK, SRXY6           600982
# 33                                  DHH, SRXY7, GDXYM           605423
# 34                    AKR1C2, DDH2, DD2, HAKRD, SRXY8           600450
# 35                           ZFPM2, FOG2, DIH3, SRXY9           603693
# 36                                          DPYD, DPD           612779
# 37                                      OPLAH, OPLAHD           614243
# 38                              NADK2, C5orf33, DECRD           615787
# 39                                   CBX2, M33, SRXY5           602770
# 40                                              ACAT2           100678
# 41                                  TBX22, CPX, ABERS           300307
# 42              GDF5, CDMP1, SYNS2, OS5, BDA1C, SYM1B           601146
# 43                                       PER3, FASPS3           603427
# 44                             LRRC8A, KIAA1437, AGM5           608360
# 45                   PIK3R1, GRB1, AGM7, SHORT, IMD36           171833
# 46                     KIF7, HLS2, ACLS, JBTS12, AGBK           611254
# 47                                        RBM28, ANES           612074
# 48                                        AI1E2, AIH3           301201
# 49                                         AMTN, AI3B           610912
#
#    gene_cyto_location
# 0            10q24.32
# 1            10q24.32
# 2               10p14
# 3            10q26.13
# 4              6p21.1
# 5                2q35
# 6            19q13.32
# 7              3q27.1
# 8              5q13.2
# 9                4q25
# 10             2q32.2
# 11             6q25.3
# 12            9q22.31
# 13           19q13.32
# 14            19q13.2
# 15            3q26.33
# 16            11q13.4
# 17             2p13.1
# 18             3q27.3
# 19             2p25.3
# 20            8q24.12
# 21          3pter-p25
# 22             9q33.3
# 23             Yp11.2
# 24      17q24.3-q25.1
# 25             Xq26.3
# 26           12q13.12
# 27             Yp11.2
# 28              17q24
# 29             Xp21.2
# 30             9q33.3
# 31             9p24.3
# 32             5q11.2
# 33           12q13.12
# 34            10p15.1
# 35             8q23.1
# 36             1p21.3
# 37             8q24.3
# 38             5p13.2
# 39            17q25.3
# 40             6q25.3
# 41             Xq21.1
# 42           20q11.22
# 43            1p36.23
# 44            9q34.11
# 45             5q13.1
# 46            15q26.1
# 47             7q32.1
# 48           Xq22-q28
# 49             4q13.3

# %%
morbidmap_df[morbidmap_df['gene_symbols'].str.contains("OMS", na=False)]
# Out:
#                                               Phenotype  \
# 514            Abdominal obesity-metabolic syndrome (2)
# 515          Abdominal obesity-metabolic syndrome 1 (2)
# 516   Abdominal obesity-metabolic syndrome 3, 615812...
# 5687                       Stromme syndrome, 243605 (3)
# 7130              {Otitis media, susceptibility to} (2)
#
#                gene_symbols  gene_MIM_number gene_cyto_location
# 514                   AOMS2           605572              17p12
# 515             AOMS1, SYNX           605552               3q27
# 516     DYRK1B, MIRK, AOMS3           604556            19q13.2
# 5687  CENPF, CILD31, STROMS           600236               1q41
# 7130                    OMS           166760            10q26.3

# %%
morbidmap_df[morbidmap_df['gene_symbols'].str.contains("A2ML1", na=False)]
# Out:
# Empty DataFrame
# Columns: [Phenotype, gene_symbols, gene_MIM_number, gene_cyto_location]
# Index: []

# %%
morbidmap_df[morbidmap_df["gene_MIM_number"] == 610627]
# Out:
# Empty DataFrame
# Columns: [Phenotype, gene_symbols, gene_MIM_number, gene_cyto_location]
# Index: []

# %%
def split_phenotype_on_last_comma(phenotype):
    parts = phenotype.rsplit(',', 1)
    return parts[0], parts[1] if len(parts) > 1 else ''


morbidmap_df[['phenotype', 'MIM_number/phenotype_mapping_key']] = morbidmap_df['Phenotype'].apply(lambda x: pd.Series(split_phenotype_on_last_comma(x)))


morbidmap_df.drop(columns=['Phenotype'], inplace=True)

# %%
morbidmap_df
# Out:
#                              gene_symbols  gene_MIM_number gene_cyto_location  \
# 0                 CYP17A1, CYP17, P450C17           609300           10q24.32
# 1                 CYP17A1, CYP17, P450C17           609300           10q24.32
# 2         DHTKD1, KIAA1630, AMOXAD, CMT2Q           614984              10p14
# 3                           ACADSB, SBCAD           600301           10q26.13
# 4                               CUL7, 3M1           609577             6p21.1
# ...                                   ...              ...                ...
# 7408         CCR5, CMKBR5, CCCKR5, IDDM22           601373            3p21.31
# 7409        REST, NRSF, WT6, GINGF5, HGF5           600571               4q12
# 7410                    POU6F2, WTSL, WT5           609062             7p14.1
# 7411  NOD2, CARD15, IBD1, CD, YAOS, BLAUS           605956            16q12.1
# 7412                   CCND1, PRAD1, BCL1           168461            11q13.3
#
#                                         phenotype  \
# 0                17,20-lyase deficiency, isolated
# 1     17-alpha-hydroxylase/17,20-lyase deficiency
# 2              2-aminoadipic 2-oxoadipic aciduria
# 3                       2-methylbutyrylglycinuria
# 4                                  3-M syndrome 1
# ...                                           ...
# 7408         {West nile virus, susceptibility to}
# 7409           {Wilms tumor 6, susceptibility to}
# 7410               {Wilms tumor susceptibility-5}
# 7411                               {Yao syndrome}
# 7412    {von Hippel-Lindau syndrome, modifier of}
#
#      MIM_number/phenotype_mapping_key
# 0                          202110 (3)
# 1                          202110 (3)
# 2                          204750 (3)
# 3                          610006 (3)
# 4                          273750 (3)
# ...                               ...
# 7408                       610379 (3)
# 7409                       616806 (3)
# 7410                       601583 (3)
# 7411                       617321 (3)
# 7412                       193300 (3)
#
# [7413 rows x 5 columns]

# %%
morbidmap_df.loc[morbidmap_df["gene_MIM_number"]==166760]
# Out:
#      gene_symbols  gene_MIM_number gene_cyto_location      phenotype  \
# 7130          OMS           166760            10q26.3  {Otitis media
#
#      MIM_number/phenotype_mapping_key
# 7130           susceptibility to} (2)

# %%
morbidmap_df[morbidmap_df['gene_symbols'].str.contains("OMS", na=False)]
# Out:
#                gene_symbols  gene_MIM_number gene_cyto_location  \
# 514                   AOMS2           605572              17p12
# 515             AOMS1, SYNX           605552               3q27
# 516     DYRK1B, MIRK, AOMS3           604556            19q13.2
# 5687  CENPF, CILD31, STROMS           600236               1q41
# 7130                    OMS           166760            10q26.3
#
#                                        phenotype  \
# 514     Abdominal obesity-metabolic syndrome (2)
# 515   Abdominal obesity-metabolic syndrome 1 (2)
# 516       Abdominal obesity-metabolic syndrome 3
# 5687                            Stromme syndrome
# 7130                               {Otitis media
#
#      MIM_number/phenotype_mapping_key
# 514
# 515
# 516                        615812 (3)
# 5687                       243605 (3)
# 7130           susceptibility to} (2)

# %%
morbidmap_df[morbidmap_df["gene_MIM_number"] == 610627]
# Out:
# Empty DataFrame
# Columns: [gene_symbols, gene_MIM_number, gene_cyto_location, phenotype, MIM_number/phenotype_mapping_key]
# Index: []

# %%
def split_phenotype_description(description):
    match = re.match(r"(.*?)(\s*\(\d+\))?$", description)
    if match:
        return match.group(1).strip(), match.group(2).strip() if match.group(2) else ''
    else:
        return description, ''


morbidmap_df[['phenotype_MIM_number', 'phenotype_mapping_key']] = morbidmap_df['MIM_number/phenotype_mapping_key'].apply(
    lambda x: pd.Series(split_phenotype_description(x))
)
morbidmap_df.drop(columns=['MIM_number/phenotype_mapping_key', 'gene_cyto_location','phenotype','phenotype_mapping_key', 'gene_symbols'], inplace=True)

# %%
morbidmap_df
# Out:
#       gene_MIM_number phenotype_MIM_number
# 0              609300               202110
# 1              609300               202110
# 2              614984               204750
# 3              600301               610006
# 4              609577               273750
# ...               ...                  ...
# 7408           601373               610379
# 7409           600571               616806
# 7410           609062               601583
# 7411           605956               617321
# 7412           168461               193300
#
# [7413 rows x 2 columns]

# %%
morbidmap_df.loc[morbidmap_df["gene_MIM_number"] == "166760"]
# Out:
# Empty DataFrame
# Columns: [gene_MIM_number, phenotype_MIM_number]
# Index: []

# %%
cleaned_mimTitles_df['phenotype_MIM_number'] = cleaned_mimTitles_df['phenotype_MIM_number'].astype(str)

# %%
morbidmap_and_mimTitles_df = pd.merge(morbidmap_df, cleaned_mimTitles_df, on='phenotype_MIM_number', how='left')

# %%
morbidmap_and_mimTitles_df
# Out:
#       gene_MIM_number phenotype_MIM_number       Prefix  \
# 0              609300               202110          NaN
# 1              609300               202110          NaN
# 2              614984               204750  Number Sign
# 3              600301               610006  Number Sign
# 4              609577               273750  Number Sign
# ...               ...                  ...          ...
# 9357           600571               616806  Number Sign
# 9358           609062               601583  Number Sign
# 9359           609062               601583  Number Sign
# 9360           605956               617321  Number Sign
# 9361           168461               193300  Number Sign
#
#                                             pheno_title pheno_symbol
# 0                                                   NaN          NaN
# 1                                                   NaN          NaN
# 2                    2-AMINOADIPIC 2-OXOADIPIC ACIDURIA       AMOXAD
# 3     SHORT/BRANCHED-CHAIN ACYL-CoA DEHYDROGENASE DE...       SBCADD
# 4                                    THREE M SYNDROME 1          3M1
# ...                                                 ...          ...
# 9357                                      WILMS TUMOR 6          WT6
# 9358                                      WILMS TUMOR 5          WT5
# 9359                     WILMS TUMOR, SUSCEPTIBILITY TO         WTSL
# 9360                                       YAO SYNDROME         YAOS
# 9361                         VON HIPPEL-LINDAU SYNDROME          VHL
#
# [9362 rows x 5 columns]

# %%
morbidmap_and_mimTitles_df.loc[morbidmap_and_mimTitles_df["phenotype_MIM_number"] == "166760"]
# Out:
# Empty DataFrame
# Columns: [gene_MIM_number, phenotype_MIM_number, Prefix, pheno_title, pheno_symbol]
# Index: []

# %%
morbidmap_and_mimTitles_df.loc[morbidmap_and_mimTitles_df["pheno_symbol"]=="A2MD"]
# Out:
#      gene_MIM_number phenotype_MIM_number Prefix  \
# 744           103950               614036    NaN
#
#                           pheno_title pheno_symbol
# 744  ALPHA-2-MACROGLOBULIN DEFICIENCY         A2MD

# %%
mim2gene_and_morbidmap_and_mimTitles_df = pd.merge(morbidmap_and_mimTitles_df, mim2gene_df, on='gene_MIM_number', how='left')

# %%
mim2gene_and_morbidmap_and_mimTitles_df
# Out:
#       gene_MIM_number phenotype_MIM_number       Prefix  \
# 0              609300               202110          NaN
# 1              609300               202110          NaN
# 2              614984               204750  Number Sign
# 3              600301               610006  Number Sign
# 4              609577               273750  Number Sign
# ...               ...                  ...          ...
# 9357           600571               616806  Number Sign
# 9358           609062               601583  Number Sign
# 9359           609062               601583  Number Sign
# 9360           605956               617321  Number Sign
# 9361           168461               193300  Number Sign
#
#                                             pheno_title pheno_symbol  \
# 0                                                   NaN          NaN
# 1                                                   NaN          NaN
# 2                    2-AMINOADIPIC 2-OXOADIPIC ACIDURIA       AMOXAD
# 3     SHORT/BRANCHED-CHAIN ACYL-CoA DEHYDROGENASE DE...       SBCADD
# 4                                    THREE M SYNDROME 1          3M1
# ...                                                 ...          ...
# 9357                                      WILMS TUMOR 6          WT6
# 9358                                      WILMS TUMOR 5          WT5
# 9359                     WILMS TUMOR, SUSCEPTIBILITY TO         WTSL
# 9360                                       YAO SYNDROME         YAOS
# 9361                         VON HIPPEL-LINDAU SYNDROME          VHL
#
#      Entrez Gene ID (NCBI) Approved Gene Symbol (HGNC)  \
# 0             GENE ID:1586                     CYP17A1
# 1             GENE ID:1586                     CYP17A1
# 2            GENE ID:55526                      DHTKD1
# 3               GENE ID:36                      ACADSB
# 4             GENE ID:9820                        CUL7
# ...                    ...                         ...
# 9357          GENE ID:5978                        REST
# 9358         GENE ID:11281                      POU6F2
# 9359         GENE ID:11281                      POU6F2
# 9360         GENE ID:64127                        NOD2
# 9361           GENE ID:595                       CCND1
#
#      Ensembl Gene ID (Ensembl)
# 0              ENSG00000148795
# 1              ENSG00000148795
# 2              ENSG00000181192
# 3              ENSG00000196177
# 4              ENSG00000044090
# ...                        ...
# 9357           ENSG00000084093
# 9358           ENSG00000106536
# 9359           ENSG00000106536
# 9360           ENSG00000167207
# 9361           ENSG00000110092
#
# [9362 rows x 8 columns]

# %%
mim2gene_and_morbidmap_and_mimTitles_df.loc[mim2gene_and_morbidmap_and_mimTitles_df["pheno_symbol"]=="A2MD"]
# Out:
#      gene_MIM_number phenotype_MIM_number Prefix  \
# 744           103950               614036    NaN
#
#                           pheno_title pheno_symbol Entrez Gene ID (NCBI)  \
# 744  ALPHA-2-MACROGLOBULIN DEFICIENCY         A2MD             GENE ID:2
#
#     Approved Gene Symbol (HGNC) Ensembl Gene ID (Ensembl)
# 744                         A2M           ENSG00000175899

# %%
mim2gene_and_morbidmap_and_mimTitles_df.dropna(subset=['pheno_symbol'], inplace=True)

# %%
gene2disease_df = mim2gene_and_morbidmap_and_mimTitles_df.copy()

# %%
gene2disease_df.to_hdf(
    "output/gene2disease_df.h5", key='df', mode='w'
)
# Out:
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_6161/2802543088.py:1: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block1_values] [items->Index(['phenotype_MIM_number', 'Prefix', 'pheno_title', 'pheno_symbol',
#        'Entrez Gene ID (NCBI)', 'Approved Gene Symbol (HGNC)',
#        'Ensembl Gene ID (Ensembl)'],
#       dtype='object')]
#
#   gene2disease_df.to_hdf(

# %%
disease_analysis_df = subset_genes_df.copy()
disease_analysis_df
# Out:
#       primary_gene_symbol  alias_symbol  HGNC_ID            ENSG_ID  \
# 0              A-GAMMA3'E     A-GAMMA-E       {}                 {}
# 1                    A1BG           A1B      {5}  {ENSG00000121410}
# 2                    A1BG           ABG      {5}  {ENSG00000121410}
# 3                    A1BG           GAB      {5}  {ENSG00000121410}
# 4                    A1BG      HYST2477      {5}  {ENSG00000121410}
# ...                   ...           ...      ...                ...
# 86546               ZZEF1      FLJ10821  {29027}  {ENSG00000074755}
# 86547               ZZEF1      KIAA0399  {29027}  {ENSG00000074755}
# 86548               ZZEF1          ZZZ4  {29027}  {ENSG00000074755}
# 86549                ZZZ3         ATAC1  {24523}  {ENSG00000036549}
# 86550                ZZZ3  DKFZP564I052  {24523}  {ENSG00000036549}
#
#            NCBI_ID
# 0      {109951028}
# 1              {1}
# 2              {1}
# 3              {1}
# 4              {1}
# ...            ...
# 86546      {23140}
# 86547      {23140}
# 86548      {23140}
# 86549      {26009}
# 86550      {26009}
#
# [86551 rows x 5 columns]

# %%
print(gene2disease_df.dtypes)
# Out:
# gene_MIM_number                 int64
# phenotype_MIM_number           object
# Prefix                         object
# pheno_title                    object
# pheno_symbol                   object
# Entrez Gene ID (NCBI)          object
# Approved Gene Symbol (HGNC)    object
# Ensembl Gene ID (Ensembl)      object
# dtype: object

# %%
print(disease_analysis_df.dtypes)
# Out:
# primary_gene_symbol    object
# alias_symbol           object
# HGNC_ID                object
# ENSG_ID                object
# NCBI_ID                object
# dtype: object

# %%
disease_analysis_df["Prefix Disease Symbol Match"] = disease_analysis_df.apply(
    lambda row: any(
        row['alias_symbol'].startswith(phenotype_symbol)  # Check if alias_symbol starts with phenotype symbol
        for phenotype_symbol in gene2disease_df.loc[
            gene2disease_df['Approved Gene Symbol (HGNC)'] == row['primary_gene_symbol'], 
            'pheno_symbol'
        ]  # Loop through all abbreviations for the gene_symbol
    ), axis=1
)
disease_analysis_df
# Out:
#       primary_gene_symbol  alias_symbol  HGNC_ID            ENSG_ID  \
# 0              A-GAMMA3'E     A-GAMMA-E       {}                 {}
# 1                    A1BG           A1B      {5}  {ENSG00000121410}
# 2                    A1BG           ABG      {5}  {ENSG00000121410}
# 3                    A1BG           GAB      {5}  {ENSG00000121410}
# 4                    A1BG      HYST2477      {5}  {ENSG00000121410}
# ...                   ...           ...      ...                ...
# 86546               ZZEF1      FLJ10821  {29027}  {ENSG00000074755}
# 86547               ZZEF1      KIAA0399  {29027}  {ENSG00000074755}
# 86548               ZZEF1          ZZZ4  {29027}  {ENSG00000074755}
# 86549                ZZZ3         ATAC1  {24523}  {ENSG00000036549}
# 86550                ZZZ3  DKFZP564I052  {24523}  {ENSG00000036549}
#
#            NCBI_ID  Prefix Disease Symbol Match
# 0      {109951028}                        False
# 1              {1}                        False
# 2              {1}                        False
# 3              {1}                        False
# 4              {1}                        False
# ...            ...                          ...
# 86546      {23140}                        False
# 86547      {23140}                        False
# 86548      {23140}                        False
# 86549      {26009}                        False
# 86550      {26009}                        False
#
# [86551 rows x 6 columns]

# %% [markdown]
# Add the 'Matching Phenotype Symbol' column with the actual symbol (or None if no match)

# %%
disease_analysis_df["Matching Phenotype Symbol"] = disease_analysis_df.apply(
    lambda row: next((
        symbol for symbol in gene2disease_df.loc[
            gene2disease_df['Approved Gene Symbol (HGNC)'] == row['primary_gene_symbol'], 
            'pheno_symbol'
        ] 
        if row['alias_symbol'].startswith(symbol)  # Check if alias_symbol starts with abbreviation
    ),  ""), axis=1
)
disease_analysis_df
# Out:
#       primary_gene_symbol  alias_symbol  HGNC_ID            ENSG_ID  \
# 0              A-GAMMA3'E     A-GAMMA-E       {}                 {}
# 1                    A1BG           A1B      {5}  {ENSG00000121410}
# 2                    A1BG           ABG      {5}  {ENSG00000121410}
# 3                    A1BG           GAB      {5}  {ENSG00000121410}
# 4                    A1BG      HYST2477      {5}  {ENSG00000121410}
# ...                   ...           ...      ...                ...
# 86546               ZZEF1      FLJ10821  {29027}  {ENSG00000074755}
# 86547               ZZEF1      KIAA0399  {29027}  {ENSG00000074755}
# 86548               ZZEF1          ZZZ4  {29027}  {ENSG00000074755}
# 86549                ZZZ3         ATAC1  {24523}  {ENSG00000036549}
# 86550                ZZZ3  DKFZP564I052  {24523}  {ENSG00000036549}
#
#            NCBI_ID  Prefix Disease Symbol Match Matching Phenotype Symbol
# 0      {109951028}                        False
# 1              {1}                        False
# 2              {1}                        False
# 3              {1}                        False
# 4              {1}                        False
# ...            ...                          ...                       ...
# 86546      {23140}                        False
# 86547      {23140}                        False
# 86548      {23140}                        False
# 86549      {26009}                        False
# 86550      {26009}                        False
#
# [86551 rows x 7 columns]

# %%
disease_analysis_df["Prefix Disease Symbol Match"].value_counts()
# Out:
# Prefix Disease Symbol Match
# False    81968
# True      4583
# Name: count, dtype: int64

# %%
disease_analysis_df.loc[disease_analysis_df["alias_symbol"]=="A2MD"]
# Out:
#    primary_gene_symbol alias_symbol HGNC_ID            ENSG_ID NCBI_ID  \
# 14                 A2M         A2MD     {7}  {ENSG00000175899}     {2}
#
#     Prefix Disease Symbol Match Matching Phenotype Symbol
# 14                         True                      A2MD

# %%
disease_analysis_df.loc[disease_analysis_df["Prefix Disease Symbol Match"]]
# Out:
#       primary_gene_symbol alias_symbol  HGNC_ID            ENSG_ID  NCBI_ID  \
# 14                    A2M         A2MD      {7}  {ENSG00000175899}      {2}
# 39                   AAAS        AAASB  {13666}  {ENSG00000094914}   {8086}
# 59                  AAGAB        PPKP1  {25662}  {ENSG00000103591}  {79719}
# 60                  AAGAB       PPKP1A  {25662}  {ENSG00000103591}  {79719}
# 76                  AARS1        CMT2N     {20}  {ENSG00000090861}     {16}
# ...                   ...          ...      ...                ...      ...
# 86136              ZNF711        MRX97  {13128}  {ENSG00000147180}   {7552}
# 86347              ZNHIT3         PEHO  {12309}  {ENSG00000273611}   {9326}
# 86372                 ZP1        OOMD1  {13187}  {ENSG00000149506}  {22917}
# 86379                 ZP3        OOMD3  {13189}  {ENSG00000188372}   {7784}
# 86509              ZSWIM6         AFND  {29316}  {ENSG00000130449}  {57688}
#
#        Prefix Disease Symbol Match Matching Phenotype Symbol
# 14                            True                      A2MD
# 39                            True                      AAAS
# 59                            True                     PPKP1
# 60                            True                    PPKP1A
# 76                            True                     CMT2N
# ...                            ...                       ...
# 86136                         True                     MRX97
# 86347                         True                      PEHO
# 86372                         True                     OOMD1
# 86379                         True                     OOMD3
# 86509                         True                      AFND
#
# [4583 rows x 7 columns]

# %%
disease_prefix_match_subset_genes_df = disease_analysis_df[disease_analysis_df["Prefix Disease Symbol Match"]]

# %%
disease_prefix_match_subset_genes_df.to_hdf(
    "../output/disease_prefix_match_subset_genes_df.h5", key='df', mode='w'
)
# Out:
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_6161/3276897619.py:1: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block1_values] [items->Index(['primary_gene_symbol', 'alias_symbol', 'HGNC_ID', 'ENSG_ID', 'NCBI_ID',
#        'Matching Phenotype Symbol'],
#       dtype='object')]
#
#   disease_prefix_match_subset_genes_df.to_hdf(

# %%
disease_analysis_df.to_hdf(
    "../output/disease_analysis_df.h5", key='df', mode='w'
)
# Out:
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_6161/1897148281.py:1: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block1_values] [items->Index(['primary_gene_symbol', 'alias_symbol', 'HGNC_ID', 'ENSG_ID', 'NCBI_ID',
#        'Matching Phenotype Symbol'],
#       dtype='object')]
#
#   disease_analysis_df.to_hdf(
