# %% [markdown]
# **Table of contents**<a id='toc0_'></a>
# - [Gene Symbol Capture Data Generation](#toc1_)
#     - [Annotating the relationship between a gene symbol and a gene concept using a descriptive database](#toc1_1_1_)
#   - [Download gene records from ENSG, HGNC, and NCBI](#toc1_2_)
#       - [This subset file was created in the alias-primary collision analysis notebook by the following modifications:](#toc1_2_1_1_)
# - [Ortholog Capture](#toc2_)
#   - [Download an Ensembl Biomart export file with the Gene Name and the Ortholog Gene Name](#toc2_1_)
#   - [Match aliases to orthologs!](#toc2_2_)
#   - [SGD Ortholog Symbol](#toc2_3_)
# - [Previous Symbol Capture](#toc3_)
#   - [Download the HGNC custom download including the gene symbol, ID, and previous symbols](#toc3_1_)
#   - [Remove all genes with no previous symbols](#toc3_2_)
#   - [Explode the previous symbols so that it is only one symbol per row](#toc3_3_)
#   - [Match aliases to previous symbols!](#toc3_4_)
# - [Clone Name Capture](#toc4_)
#   - [Download the FLJ database file including FLJ IDs](#toc4_1_)
# - [Gene Family Symbol Capture](#toc5_)
# - [Disorder/Disease Symbol Capture](#toc6_)
# - [Placeholder Symbol Capture](#toc7_)
# - [Protein Mass Symbol Capture](#toc8_)
# - [Gene Neighbors](#toc9_)
#       - [Right neighbors](#toc9_1_1_1_)
#       - [Left Neighbors](#toc9_1_1_2_)
#       - [Overlapping Genes](#toc9_1_1_3_)
#       - [Combine all neighbor data](#toc9_1_1_4_)
# - [Gene Group](#toc10_)
# - [Gene Interactions](#toc11_)
# - [Gene Identifiers](#toc12_)
#   - [Ensembl linked Gene Identifiers](#toc12_1_)
#   - [HGNC](#toc12_2_)
#   - [NCBI](#toc12_3_)
#   - [Combine all three sources](#toc12_4_)
# - [Withdrawn MGI Symbol Capture](#toc13_)
# - [LLM Prediction: Alternate Abbreviation Symbol](#toc14_)
#
# <!-- vscode-jupyter-toc-config
# 	numbering=false
# 	anchor=true
# 	flat=false
# 	minLevel=1
# 	maxLevel=6
# 	/vscode-jupyter-toc-config -->
# <!-- THIS CELL WILL BE REPLACED ON TOC UPDATE. DO NOT WRITE YOUR TEXT IN THIS CELL -->

# %% [markdown]
# # <a id='toc1_'></a>[Gene Symbol Capture Data Generation](#toc0_)

# %% [markdown]
# ### <a id='toc1_1_1_'></a>[Annotating the relationship between a gene symbol and a gene concept using a descriptive database](#toc0_)

# %% [markdown]
# Expect a new table for each type of relationship. Orthologs are a special case where a group of species has its own table. The subsets created after establishing a relationship, are only the symbols that are TRUE for that relationship.

# %%
import sys
from pathlib import Path
import pandas as pd
import numpy as np
import re
from pybiomart import Server
from tqdm import tqdm
import json
import os
tqdm.pandas()
from collections import deque
import requests
from io import StringIO
import nest_asyncio
nest_asyncio.apply()
import time
from requests.exceptions import RequestException
import nltk
from nltk.corpus import words
import ast

from automatic_alternate_abbreviation_annotation.alt_abbrev_llm_functions import *

# %%
def remove_nan_from_set(s):
    """Remove null instances from set
    
    :param s: selected set
    :return: set with no null values
    """
    return {x for x in s if pd.notna(x)}

# %%
def combine_rows(series):
    """Combine duplicate rows.

    :param series: a Pandas Series containing values from a DataFrame column.
                    this Series may contain NaN values, and the function will
                    return the first non-null value, or None if all values are NaN.
    :return: combined value from the Series, or None if the Series is empty or contains only NaNs.
    """
    return series.ffill().bfill().drop_duplicates().values[0] if not series.dropna().empty else None

# %%
def read_subset_genes_csv(location):
    """Create a df of primary gene symbol- alias symbol pairs

    :param location: file location
    return: a df of gene records
    """
    
    subset_genes_xxxx_df = pd.read_csv(
        location, dtype={"NCBI_ID": str,"HGNC_ID":str})
    return subset_genes_xxxx_df

# %%
def make_col_ortholog_match(recording_df, source_df, animal= str):
    """Check for ortholog matches in the primary gene symbol- alias symbol pairs. 
    Adds a T/F column for each pair. T if the alias is an ortholog from the specified animal and F if not

    :param recording_df: df that contains the primary gene symbol- alias symbol pairs
    :param source_df: df that contains the orthologs and their associated human genes
    :param animal: the animal from with the orthologs are being checked
    return: the number of primary gene symbol- alias symbol pairs where the alias is an ortholog from the specified animal
    """

    source_df["Gene name upper"] = source_df["Gene name"].str.upper()
    source_df[f'{animal} gene name upper'] = source_df[f'{animal} gene name'].str.upper()
    
    # Build a set of (gene, ortholog) pairs for this animal
    ortholog_pairs = set(zip(source_df['Gene name upper'], source_df[f'{animal} gene name upper']))
    source_df = source_df.drop(['Gene name upper', f'{animal} gene name upper'], axis=1)

    # Match using vectorized lookup
    df = recording_df.copy()
    df["primary_gene_symbol_upper"] = df["primary_gene_symbol"].str.upper()
    df["alias_symbol_upper"] = df["alias_symbol"].str.upper()
    df[f'{animal} Match'] = df.apply(
        lambda row: (row['primary_gene_symbol_upper'], row['alias_symbol_upper'],) in ortholog_pairs,
        axis=1
    )
    df = df.drop(['primary_gene_symbol_upper', 'alias_symbol_upper'], axis=1)
    print(f"Added column: {animal} Match")
    return df

# %%
def match_alias_to_ortholog(og_recording_df, source_df):
    """Apply the make_col_ortholog_match function to all animal columns in the DataFrame.

    :param og_recording_df: DataFrame containing the primary gene symbol- alias symbol pairs
    :param source_df: DataFrame containing the orthologs and their associated human genes
    :return: a DataFrame with all match columns added
    """
    source_df = source_df.groupby('Gene name', as_index=False).agg(combine_rows)

    recording_df = og_recording_df.copy()
    recording_df.columns = recording_df.columns.str.strip().str.replace(r'\s+', ' ', regex=True)
    source_df.columns = source_df.columns.str.strip().str.replace(r'\s+', ' ', regex=True)

    animal_columns = [col for col in source_df.columns if 'gene name' in col and col != 'Gene name']
    
    true_counts = {}

    for animal in animal_columns:
        # Extract the animal name
        animal_name = animal.replace(' gene name', '')

        # Keep only rows with values in both columns
        source_df = source_df.dropna(subset= animal)

        recording_df = make_col_ortholog_match(recording_df, source_df, animal_name)

        true_count = recording_df[f'{animal_name} Match'].sum()
        true_counts[animal_name] = true_count
    return recording_df, true_counts

# %% [markdown]
# ## <a id='toc1_2_'></a>[Download gene records from ENSG, HGNC, and NCBI](#toc0_)

# %% [markdown]
# #### <a id='toc1_2_1_1_'></a>[This subset file was created in the alias-primary collision analysis notebook by the following modifications:](#toc0_)
#  - Primary gene symbol- alias symbol pairs where the alias was an exact match to the primary symbol were removed.
#  - Primary gene symbol- alias symbol pairs that were duplicated were removed.

# %%
databases = ['ensg','hgnc','ncbi']
dfs = [
    read_subset_genes_csv(f'../output/subset_genes_{db}_df.csv')
    for db in databases
]

subset_genes_df = pd.concat(dfs, axis=0, ignore_index=True)

# %%
subset_genes_df = subset_genes_df.groupby(
    ["primary_gene_symbol", "alias_symbol"],
    as_index=False
).agg({
    "HGNC_ID": lambda x: set(x.dropna()),
    "ENSG_ID": lambda x: set(x.dropna()),
    "NCBI_ID": lambda x: set(x.dropna()),
})

# %%
subset_genes_df['NCBI_ID'] = subset_genes_df['NCBI_ID'].apply(remove_nan_from_set)
subset_genes_df['ENSG_ID'] = subset_genes_df['ENSG_ID'].apply(remove_nan_from_set)
subset_genes_df['HGNC_ID'] = subset_genes_df['HGNC_ID'].apply(remove_nan_from_set)

# %%
subset_genes_df.to_hdf("../output/subset_genes_df.h5", key='df', mode='w')
subset_genes_df.to_csv("../output/subset_genes_df.csv", index=True)
# Out:
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_36639/1256166966.py:1: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block0_values] [items->Index(['primary_gene_symbol', 'alias_symbol', 'HGNC_ID', 'ENSG_ID', 'NCBI_ID'], dtype='object')]
#
#   subset_genes_df.to_hdf("../output/subset_genes_df.h5", key='df', mode='w')

# %% [markdown]
# # <a id='toc2_'></a>[Ortholog Capture](#toc0_)

# %% [markdown]
# ## <a id='toc2_1_'></a>[Download an Ensembl Biomart export file with the Gene Name and the Ortholog Gene Name](#toc0_)

# %%
server = Server(host='http://www.ensembl.org')
dataset = server.marts['ENSEMBL_MART_ENSEMBL'].datasets['hsapiens_gene_ensembl']

homologs = []
for key in dataset.attributes.keys():
    if '_homolog_associated_gene_name' in key:
        homologs.append(key)
print(f'{len(homologs)} found!')

for homolog in tqdm(homologs):
    attributes = ['ensembl_gene_id', 'external_gene_name', homolog]
    df = dataset.query(attributes=attributes)
    df.to_csv(f'../input/orthologs/{homolog}.csv')

# %% [markdown]
# ## <a id='toc2_2_'></a>[Match aliases to orthologs!](#toc0_)

# %%
#can comment out after run
BATCH_SIZE = 5

files = sorted([file for file in os.listdir('../input/orthologs/') if file.endswith('.csv')])

for i in tqdm(range(0, len(files), BATCH_SIZE)):
    batch_files = files[i:i + BATCH_SIZE]
    
    batch_df = pd.concat(
        [pd.read_csv(f'../input/orthologs/{file}') for file in batch_files],
        ignore_index=True
    )
    
    analysis, counts = match_alias_to_ortholog(subset_genes_df, batch_df)
    
    batch_number = i // BATCH_SIZE
    analysis.to_csv(f'../output/orthologs/analysis_{batch_number}.csv')

    counts_serialized = {k: int(v) for k, v in counts.items()} # Required to serialize numpy to int, otherwise cannot save to json
    with open(f'../output/orthologs/counts_{batch_number}.json', 'w') as f:
        json.dump(counts_serialized, f, indent=2)

# %% [markdown]
# ## <a id='toc2_3_'></a>[SGD Ortholog Symbol](#toc0_)
# Not all of the yeast orthologs are present in the Ensembl database. The Saccharomyces Genome Database was identified to potentially fill in the gap through manual annotation of the alias symbols LYS5 (correlates to HGNC:14235) and BFR2 (HGNC:19235)

# %% [markdown]
# In the Download tab on the SGD site: http://sgd-archive.yeastgenome.org / curation / chromosomal_feature / dbxref.tab

# %%
sgd_dbref_df = pd.read_csv(
    "../input/dbxref20251213.tab", 
    sep="\t", 
    header=None)

# %%
#from the dbxref.README
sgd_dbref_df.columns = [
    "DBXREF ID", 
    "DBXREF ID source", 
    "DBXREF ID type", 
    "S. cerevisiae feature name", 
    "SGDID",
    "gene_symbol"
]

# %% [markdown]
# isolate the rows that point the yeast gene to a HGNC xref

# %%
hgnc_sgd_dbref_df = sgd_dbref_df[sgd_dbref_df["DBXREF ID"].fillna('').str.startswith("HGNC:")]

# %%
ncbi_previous_symbols_df.replace('-', np.nan, inplace=True)
ncbi_previous_symbols_df = ncbi_previous_symbols_df.dropna(subset=["GeneID"])
ncbi_previous_symbols_df['GeneID'] = 'GENE ID:' + ncbi_previous_symbols_df['GeneID'].astype(str)
ncbi_previous_symbols_df

# %%
## <a id='toc3_3_'></a>[Explode the previous symbols so that it is only one symbol per row](#toc0_)

# %%
hgnc_previous_symbols_df["previous_symbol"] = hgnc_previous_symbols_df['Previous symbols'].str.split(',').apply(lambda x: [s.strip() for s in x])
hgnc_previous_symbols_df = hgnc_previous_symbols_df.explode('previous_symbol')
hgnc_previous_symbols_df = hgnc_previous_symbols_df.drop(columns=['Previous symbols'])
hgnc_previous_symbols_df

# %%
hgnc_previous_symbols_df.to_hdf(
    "../output/hgnc_previous_symbols_df.h5", key='df', mode='w'
)
# Out:
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_69763/2567776836.py:1: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block0_values] [items->Index(['HGNC ID', 'Approved symbol', 'previous_symbol'], dtype='object')]
#
#   hgnc_previous_symbols_df.to_hdf(

# %%
## <a id='toc3_4_'></a>[Match aliases to previous symbols!](#toc0_)

# %%
previous_symbol_analysis_df = subset_genes_df.copy()
previous_symbol_analysis_df

# %%
def match_alias_to_previous_symbol(
    analysis_df: pd.DataFrame,
    sources: list[tuple[pd.DataFrame, str, str, str, str]],
) -> pd.DataFrame:
    """
    Identify previous symbol matches across one or more reference sources.

    :param analysis_df: DataFrame containing alias symbols and identifier columns.
    :param sources: List of tuples containing
        (reference_df, analysis_id_col, reference_id_col,
        reference_symbol_col, source_name).
    :return: DataFrame containing the columns
        ``Previous Symbol Match`` and ``Previous Symbol Source``.
    """
    # Precompute lookup sets once for each source
    source_lookup = []
    for (
        reference_df,
        analysis_id_col,
        reference_id_col,
        reference_symbol_col,
        source_name,
    ) in sources:
        reference_pairs = set(
            zip(
                reference_df[reference_id_col].str.upper(),
                reference_df[reference_symbol_col].str.upper(),
            )
        )

        source_lookup.append(
            (
                analysis_id_col,
                reference_pairs,
                source_name,
            )
        )

    matches = []
    source_labels = []

    for _, row in tqdm(
        analysis_df.iterrows(),
        total=len(analysis_df),
        desc="Matching previous symbols",
    ):
        alias = row["alias_symbol"]

        if pd.isna(alias):
            matches.append(False)
            source_labels.append(pd.NA)
            continue

        alias = alias.upper()
        row_sources = []

        for analysis_id_col, reference_pairs, source_name in source_lookup:
            ids = row[analysis_id_col]

            if isinstance(ids, (list, set)):
                if any(
                    (gene_id.upper(), alias) in reference_pairs
                    for gene_id in ids
                    if isinstance(gene_id, str)
                ):
                    row_sources.append(source_name)

        matches.append(bool(row_sources))
        source_labels.append(", ".join(row_sources) if row_sources else pd.NA)

    return pd.DataFrame(
        {
            "Previous Symbol Match": matches,
            "Previous Symbol Source": source_labels,
        },
        index=analysis_df.index,
    )

# %%
previous_symbol_analysis_df[
    ["Previous Symbol Match", "Previous Symbol Source"]
] = match_alias_to_previous_symbol(
    previous_symbol_analysis_df,
    [
        (
            hgnc_previous_symbols_df,
            "HGNC_ID",
            "HGNC ID",
            "previous_symbol",
            "HGNC",
        ),
        (
            ncbi_previous_symbols_df,
            "NCBI_ID",
            "GeneID",
            "Discontinued_Symbol",
            "NCBI",
        ),
    ],
)

# %%
previous_symbol_analysis_df

# %%
# Filter to matched rows
previous_symbol_match_subset_genes_df = previous_symbol_analysis_df[previous_symbol_analysis_df["Previous Symbol Match"]].copy()

# %%
ncbi_previous_symbols_df = pd.read_csv(
    "../input/ncbi_gene_history20251006", sep="\t")
ncbi_previous_symbols_df

# %%
previous_symbol_match_subset_genes_df.head(20)

# %%
previous_symbol_match_subset_genes_df.to_hdf(
    "../output/previous_symbol_match_subset_genes_df.h5", key='df', mode='w'
)

# %%
previous_symbol_analysis_df.to_hdf(
    "../output/previous_symbol_analysis_df.h5", key='df', mode='w'
)

# %% [markdown]
# # <a id='toc4_'></a>[Clone Name Capture](#toc0_)

# %% [markdown]
# ## <a id='toc4_1_'></a>[Download the FLJ database file including FLJ IDs](#toc0_)
# - https://flj.lifesciencedb.jp/top/sys_info/02_about_database/accession_no/download_v032.html
# - https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2780955/
# - https://www.ncbi.nlm.nih.gov/nuccore/AK027222?report=GenBank

# %%
with open("../input/Conversion_table_FLJ.txt", 'r') as file:
    for i, line in enumerate(file):
        print(f"Line {i}: {line.strip()}")

# %%
raw_flj_clone_symbols_df = pd.read_csv(
    "../input/Conversion_table_FLJ.txt", 
    sep="\t", 
    skiprows=3
)
raw_flj_clone_symbols_df

# %% [markdown]
# ## <a id='toc3_4_'></a>[Match aliases to previous symbols!](#toc0_)

# %%
previous_symbol_analysis_df = subset_genes_df.copy()
previous_symbol_analysis_df

# %%
flj_extracted_ids = raw_flj_clone_symbols_df['FLJ ID'].str.extract(r'([^()]+)\((.+?)\)')

result_rows = []

for index, row in raw_flj_clone_symbols_df.iterrows():
    flj_id = row['FLJ ID']
    if pd.notnull(flj_extracted_ids.iloc[index, 0]):
        result_rows.append({'Accesion No': row['Accesion No'], 'ID': flj_extracted_ids.iloc[index, 0]})  
        result_rows.append({'Accesion No': row['Accesion No'], 'ID': flj_extracted_ids.iloc[index, 1]})  
    else:
        result_rows.append({'Accesion No': row['Accesion No'], 'ID': flj_id})

flj_clone_symbols_df = pd.DataFrame(result_rows)
flj_clone_symbols_df

# %%
flj_clone_symbols_df["ID"] = flj_clone_symbols_df["ID"].str.strip()

# %%
flj_clone_symbols_df.to_hdf(
    "../output/flj_clone_symbols_df.h5", key='df', mode='w'
)

# %%
flj_clone_symbol_analysis_df = subset_genes_df.copy()

# Convert both ID and Accession No columns to uppercase strings
combined_flj_clone_ids = pd.concat([
    flj_clone_symbols_df['ID'].dropna().astype(str).str.upper(),
    flj_clone_symbols_df['Accesion No'].dropna().astype(str).str.upper()
])

combined_flj_clone_id_set = set(combined_flj_clone_ids)

flj_clone_symbol_analysis_df["Clone Symbol Match"] = flj_clone_symbol_analysis_df['alias_symbol'].str.upper().isin(combined_flj_clone_id_set)


flj_clone_symbol_match_subset_genes_df = flj_clone_symbol_analysis_df[flj_clone_symbol_analysis_df["Clone Symbol Match"]]
flj_clone_symbol_match_subset_genes_df.head(20)

# %%
flj_clone_symbol_analysis_df.to_hdf(
    "../output/flj_clone_symbol_analysis_df.h5", key='df', mode='w'
)

# %%
previous_symbol_match_subset_genes_df.head(20)

# %%
previous_symbol_match_subset_genes_df.to_hdf(
    "../output/previous_symbol_match_subset_genes_df.h5", key='df', mode='w'
)

# %%
previous_symbol_analysis_df.to_hdf(
    "../output/previous_symbol_analysis_df.h5", key='df', mode='w'
)

# %% [markdown]
# # <a id='toc4_'></a>[Clone Name Capture](#toc0_)

# %% [markdown]
# ## <a id='toc4_1_'></a>[Download the FLJ database file including FLJ IDs](#toc0_)
# - https://flj.lifesciencedb.jp/top/sys_info/02_about_database/accession_no/download_v032.html
# - https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2780955/
# - https://www.ncbi.nlm.nih.gov/nuccore/AK027222?report=GenBank

# %%
with open("../input/Conversion_table_FLJ.txt", 'r') as file:
    for i, line in enumerate(file):
        print(f"Line {i}: {line.strip()}")

# %%
raw_flj_clone_symbols_df = pd.read_csv(
    "../input/Conversion_table_FLJ.txt", 
    sep="\t", 
    skiprows=3
)
raw_flj_clone_symbols_df

# %% [markdown]
# Extract values from the FLJ column so that there is only one ID per row

# %%
flj_extracted_ids = raw_flj_clone_symbols_df['FLJ ID'].str.extract(r'([^()]+)\((.+?)\)')

result_rows = []

for index, row in raw_flj_clone_symbols_df.iterrows():
    flj_id = row['FLJ ID']
    if pd.notnull(flj_extracted_ids.iloc[index, 0]):
        result_rows.append({'Accesion No': row['Accesion No'], 'ID': flj_extracted_ids.iloc[index, 0]})  
        result_rows.append({'Accesion No': row['Accesion No'], 'ID': flj_extracted_ids.iloc[index, 1]})  
    else:
        result_rows.append({'Accesion No': row['Accesion No'], 'ID': flj_id})

flj_clone_symbols_df = pd.DataFrame(result_rows)
flj_clone_symbols_df

# %%
flj_clone_symbols_df["ID"] = flj_clone_symbols_df["ID"].str.strip()

# %%
flj_clone_symbols_df.to_hdf(
    "../output/flj_clone_symbols_df.h5", key='df', mode='w'
)

# %%
flj_clone_symbol_analysis_df = subset_genes_df.copy()

# Convert both ID and Accession No columns to uppercase strings
combined_flj_clone_ids = pd.concat([
    flj_clone_symbols_df['ID'].dropna().astype(str).str.upper(),
    flj_clone_symbols_df['Accesion No'].dropna().astype(str).str.upper()
])

combined_flj_clone_id_set = set(combined_flj_clone_ids)

flj_clone_symbol_analysis_df["Clone Symbol Match"] = flj_clone_symbol_analysis_df['alias_symbol'].str.upper().isin(combined_flj_clone_id_set)


flj_clone_symbol_match_subset_genes_df = flj_clone_symbol_analysis_df[flj_clone_symbol_analysis_df["Clone Symbol Match"]]
flj_clone_symbol_match_subset_genes_df.head(20)

# %%
flj_clone_symbol_analysis_df.to_hdf(
    "../output/flj_clone_symbol_analysis_df.h5", key='df', mode='w'
)

# %%
flj_clone_symbol_match_subset_genes_df.to_hdf(
    "../output/flj_clone_symbol_match_subset_genes_df.h5", key='df', mode='w'
)

# %% [markdown]
# # <a id='toc5_'></a>[Gene Family Symbol Capture](#toc0_)

# %% [markdown]
# Gene Group ID and abbreviation reference from HGNC: https://storage.googleapis.com/public-download-files/hgnc/csv/csv/genefamily_db_tables/family.csv or family.csv from https://www.genenames.org/download/gene-groups/#!/#tocAnchor-1-1

# %%
hgnc_genefamilies_df = pd.read_csv(
    "../input/hgnc_genefamily.csv", sep=",")

# %%
hgnc_genefamily_hierarchy_df = pd.read_csv(
    "../input/hgnc_genefamily_hierarchy.csv")

# %%
hgnc_genefamily_hierarchy_df['child_fam_id'] = hgnc_genefamily_hierarchy_df['child_fam_id'].astype(str)
hgnc_genefamily_hierarchy_df['parent_fam_id'] = hgnc_genefamily_hierarchy_df['parent_fam_id'].astype(str)

# %%
hgnc_genefamilies_df = hgnc_genefamilies_df[["id","abbreviation"]]
hgnc_genefamilies_df.rename(columns={'id': 'Gene group ID'}, inplace=True)

# %% [markdown]
# Gene and Primary gene symbol and Group ID reference from HGNC: https://storage.googleapis.com/public-download-files/hgnc/csv/csv/genefamily_db_tables/gene_has_family.csv or gene_has_family.csv from https://www.genenames.org/download/gene-groups/#!/#tocAnchor-1-1 or HGNC Custom Downloads and selcet these three fields

# %%
hgnc_gene_groupid_df = pd.read_csv(
    "../input/hgnc_id_symbol_genegroupid.txt", sep="\t")

# %%
hgnc_gene_groupid_df['HGNC ID'] = hgnc_gene_groupid_df['HGNC ID'].str.replace('^HGNC:', '', regex=True)
hgnc_gene_groupid_df['Gene group ID'] = hgnc_gene_groupid_df['Gene group ID'].str.split('|')
hgnc_gene_groupid_df = hgnc_gene_groupid_df.explode('Gene group ID')

# %%
def expand_gene_groups(gene_df, hierarchy_df):
    """Expand the gene group IDs to include parent and grandparent gene group IDs

    :param gene_df: the df with the HGNC ID, Approved Symbol, and the most childest Gene goup ID information
    :param hierarchy_df: the df with the information about the parent gene group ID and associated child group IDs
    :return: a new df that includes new rows with the same base information but the parent and grand parent IDs in the Gene Group ID column
    """
    # Build a mapping of child to list of parents
    child_to_parents = hierarchy_df.groupby("child_fam_id")["parent_fam_id"].apply(list).to_dict()
    
    expanded_rows = []

    # Queue: list of tuples (base information: HGNC ID, Approved symbol, current group ID)
    queue = deque()
    seen = set()

    # Seed queue with original rows
    for _, row in gene_df.iterrows():
        hgnc_id = row["HGNC ID"]
        approved_symbol = row["Approved symbol"]
        group_id = row["Gene group ID"]
        queue.append((hgnc_id, approved_symbol, group_id))
        seen.add((hgnc_id, group_id))  # seen by HGNC ID + group ID
        expanded_rows.append({
            "HGNC ID": hgnc_id,
            "Approved symbol": approved_symbol,
            "Gene group ID": group_id
        })

    # Walk the hierarchy upward
    while queue:
        hgnc_id, symbol, group_id = queue.popleft()

        parent_ids = child_to_parents.get(group_id, [])
        for parent_id in parent_ids:
            key = (hgnc_id, parent_id)
            if key not in seen:
                seen.add(key)
                queue.append((hgnc_id, symbol, parent_id))
                expanded_rows.append({
                    "HGNC ID": hgnc_id,
                    "Approved symbol": symbol,
                    "Gene group ID": parent_id
                })

    return pd.DataFrame(expanded_rows)

# %%
expanded_hgnc_gene_groupid_df = expand_gene_groups(hgnc_gene_groupid_df, hgnc_genefamily_hierarchy_df)

# %%
expanded_hgnc_gene_groupid_df = expanded_hgnc_gene_groupid_df.dropna(subset=['Gene group ID'])
expanded_hgnc_gene_groupid_df['Gene group ID'] = expanded_hgnc_gene_groupid_df['Gene group ID'].astype(int)

# %%
hgnc_gene_group_root_df = expanded_hgnc_gene_groupid_df.merge(hgnc_genefamilies_df, on='Gene group ID', how='left')
hgnc_gene_group_root_df

# %%
hgnc_gene_group_root_df["HGNC ID"] = hgnc_gene_group_root_df["HGNC ID"].apply(
    lambda x: f"HGNC:{int(x)}" if pd.notna(x) and x == int(x) else f"HGNC:{x}" if pd.notna(x) else x
)

# %% [markdown]
# Edge case example: an example of a gene who's most childest gene group did not have a root symbol but the parent gene group symbol was a match to the gene symbol prefix (PCDH1)

# %%
hgnc_gene_groupid_df.loc[hgnc_gene_groupid_df["Approved symbol"] == "PCDH1"]

# %%
hgnc_gene_group_root_df.loc[hgnc_gene_group_root_df["Approved symbol"] == "PCDH1"]

# %%
hgnc_gene_group_root_df = hgnc_gene_group_root_df.dropna(subset=['abbreviation'])

# %%
hgnc_gene_group_root_df.to_hdf(
    "../output/hgnc_gene_group_root_df.h5", key='df', mode='w'
)

# %%
gene_group_analysis_df = subset_genes_df.copy()

# %% [markdown]
# Add the 'Prefix Gene Group Symbol Match' column with True/False

# %%
# Create a dictionary mapping Approved symbol → list of abbreviations
hgnc_gene_group_root_df["Approved symbol upper"] = hgnc_gene_group_root_df['Approved symbol'].str.upper()
hgnc_gene_group_root_df["abbreviation upper"] =  hgnc_gene_group_root_df['abbreviation'].str.upper()

abbrev_map = (
    hgnc_gene_group_root_df
    .dropna(subset=['Approved symbol upper', 'abbreviation upper'])  # remove rows with missing values
    .groupby('Approved symbol upper')['abbreviation upper']
    .apply(list)
    .to_dict()
)
hgnc_gene_group_root_df = hgnc_gene_group_root_df.drop(['Approved symbol upper', "abbreviation upper"], axis=1)

def has_prefix_gene_group_match(row):
    alias = row['alias_symbol_upper']
    primary_gene_symbol = row['primary_gene_symbol_upper']
    
    # Skip if alias is not a valid string
    if not isinstance(alias, str):
        return False

    # Get abbreviations list for this gene symbol
    abbreviations = abbrev_map.get(primary_gene_symbol, [])
    
    # Check if alias starts with any abbreviation
    return any(alias.startswith(abbrev) for abbrev in abbreviations)

gene_group_analysis_df["alias_symbol_upper"] = gene_group_analysis_df['alias_symbol'].str.upper()
gene_group_analysis_df["primary_gene_symbol_upper"] =  gene_group_analysis_df['primary_gene_symbol'].str.upper()

gene_group_analysis_df["Prefix Gene Group Symbol Match"] = gene_group_analysis_df.progress_apply(
    has_prefix_gene_group_match, axis=1
)
gene_group_analysis_df = gene_group_analysis_df.drop(['alias_symbol_upper', "primary_gene_symbol_upper"], axis=1)

# %% [markdown]
# Add the 'Matching Abbreviation' column with the actual abbreviation (or None if no match)

# %%
hgnc_gene_group_root_df["Approved symbol upper"] = hgnc_gene_group_root_df['Approved symbol'].str.upper()
hgnc_gene_group_root_df["abbreviation upper"] =  hgnc_gene_group_root_df['abbreviation'].str.upper()

abbrev_map = (
    hgnc_gene_group_root_df
    .dropna(subset=['Approved symbol upper', 'abbreviation upper'])
    .groupby('Approved symbol upper')['abbreviation upper']
    .apply(list)
    .to_dict()
)
hgnc_gene_group_root_df = hgnc_gene_group_root_df.drop(['Approved symbol upper', "abbreviation upper"], axis=1)

def get_matching_abbreviation(row):
    alias = row['alias_symbol_upper']
    primary_gene_symbol = row['primary_gene_symbol_upper']
    
    if not isinstance(alias, str):
        return ""
    
    abbreviations = abbrev_map.get(primary_gene_symbol, [])
    
    for abbrev in abbreviations:
        if alias.startswith(abbrev):
            return abbrev
    
    return ""
gene_group_analysis_df["alias_symbol_upper"] = gene_group_analysis_df['alias_symbol'].str.upper()
gene_group_analysis_df["primary_gene_symbol_upper"] =  gene_group_analysis_df['primary_gene_symbol'].str.upper()

gene_group_analysis_df["Matching Abbreviation"] = gene_group_analysis_df.progress_apply(
    get_matching_abbreviation, axis=1
)

gene_group_analysis_df = gene_group_analysis_df.drop(['alias_symbol_upper', "primary_gene_symbol_upper"], axis=1)

# %%
gene_group_prefix_match_subset_genes_df = gene_group_analysis_df[gene_group_analysis_df["Prefix Gene Group Symbol Match"]]
gene_group_analysis_df

# %%
gene_group_prefix_match_subset_genes_df.to_hdf(
    "../output/gene_group_prefix_match_subset_genes_df.h5", key='df', mode='w'
)

# %%
gene_group_analysis_df.to_hdf(
    "../output/gene_group_analysis_df.h5", key='df', mode='w'
)

# %% [markdown]
# # <a id='toc6_'></a>[Disorder/Disease Symbol Capture](#toc0_)

# %% [markdown]
# OMIM downloads: https://omim.org/downloads/

# %%
mim2gene_df_old = pd.read_csv(
    "../input/mim2gene.txt", 
    sep="\t", 
    comment="#",
    names=["gene_MIM_number", "MIM Entry Type", "Entrez Gene ID (NCBI)", "Approved Gene Symbol (HGNC)", "Ensembl Gene ID (Ensembl)"],
    dtype={"Entrez Gene ID (NCBI)": "Int64"}
    )

mim2gene_df_old.drop(columns=['MIM Entry Type'], inplace=True)

mim2gene_df_old

# %%
mim2gene_df_new = pd.read_csv(
    "../input/mim2gene04292025.txt", 
    sep="\t", 
    comment="#",
    names=["gene_MIM_number", "MIM Entry Type", "Entrez Gene ID (NCBI)", "Approved Gene Symbol (HGNC)", "Ensembl Gene ID (Ensembl)"],
    dtype={"Entrez Gene ID (NCBI)": "Int64"}
    )

mim2gene_df_new.drop(columns=['MIM Entry Type'], inplace=True)

mim2gene_df_new

# %%
mim2gene_df = pd.concat([mim2gene_df_old, mim2gene_df_new], ignore_index=True)
mim2gene_df = mim2gene_df.drop_duplicates()

# %%
mim2gene_df["Entrez Gene ID (NCBI)"] = mim2gene_df["Entrez Gene ID (NCBI)"].apply(
    lambda x: f"GENE ID:{int(x)}" if pd.notna(x) and x == int(x) else f"GENE ID:{x}" if pd.notna(x) else x
)

# %%
mim2gene_df.loc[mim2gene_df["Approved Gene Symbol (HGNC)"]=="A2ML1"]

# %%
mimTitles_df_old = pd.read_csv(
    "../input/mimTitles.txt", 
    sep="\t", 
    comment="#",
    names=["Prefix", "phenotype_MIM_number", "phenotype_preferred_title_symbol", "phenotype_alternative_titles_symbols", "phenotype__included_titles_symbols"]
    )
mimTitles_df_old.head()

# %%
mimTitles_df_new = pd.read_csv(
    "../input/mimTitles04292025.txt", 
    sep="\t", 
    comment="#",
    names=["Prefix", "phenotype_MIM_number", "phenotype_preferred_title_symbol", "phenotype_alternative_titles_symbols", "phenotype__included_titles_symbols"]
    )
mimTitles_df_new.head()

# %%
mimTitles_df = pd.concat([mimTitles_df_old, mimTitles_df_new], ignore_index=True)
mimTitles_df = mimTitles_df.drop_duplicates()

# %%
mimTitles_df[mimTitles_df['phenotype__included_titles_symbols'].str.contains("INCLUDED", na=False)]

# %%
# remove all asterisks(*) and carets(^). gene(*) and entry(^) records removed

# %%
mimTitles_df = mimTitles_df[mimTitles_df['Prefix'] != "Asterisk"]

# %%
mimTitles_df = mimTitles_df[mimTitles_df['Prefix'] != "Caret"]

# %%
df = mimTitles_df.copy()
df_preffered = df[['Prefix', 'phenotype_MIM_number', 'phenotype_preferred_title_symbol']].copy()
df_preffered['titles_symbols'] = df_preffered['phenotype_preferred_title_symbol']
df_preffered

# %%
df = mimTitles_df.copy()
df_alt = df[['Prefix', 'phenotype_MIM_number', 'phenotype_alternative_titles_symbols']].copy()
df_alt['titles_symbols'] = df_alt['phenotype_alternative_titles_symbols']
df_alt

# %%
df = mimTitles_df.copy()
df_inc = df[['Prefix', 'phenotype_MIM_number', 'phenotype__included_titles_symbols']].copy()
df_inc['titles_symbols'] = df_inc['phenotype__included_titles_symbols']
df_inc

# %%
df_combined = pd.concat([df_preffered, df_alt, df_inc], ignore_index=True)
df_combined.drop(["phenotype_preferred_title_symbol","phenotype_alternative_titles_symbols", "phenotype__included_titles_symbols"], axis=1, inplace=True)
df_combined

# %%
df_combined.dropna(subset=['titles_symbols'], inplace=True)
df_combined

# %% [markdown]
# split title and symbol

# %%
def split_name_symbol_pairs(value):
    pairs = value.split(';;')

    result = []
    for pair in pairs:
        parts = pair.strip().split(';')
        if len(parts) == 2:
            result.append(parts)
    return result

# %%
split_data = df_combined['titles_symbols'].apply(split_name_symbol_pairs)
split_data

# %%
df_reset = df_combined.reset_index(drop=True)
split_data_reset = split_data.reset_index(drop=True)

# %% [markdown]
# put titles and symbols into different columns

# %%
expanded_rows = []

for row, titles_symbols in zip(df_reset.iterrows(), split_data_reset):
    _, row_data = row  # Unpack the row from iterrows()
    col1_value = row_data['Prefix']
    col2_value = row_data['phenotype_MIM_number']
    
    # Ensure split_data contains lists of name-symbol pairs
    for title_symbol in titles_symbols:
        title = title_symbol[0].strip()
        symbol = title_symbol[1].strip()
        # Append the expanded row (duplicating col1 and col2)
        expanded_rows.append([col1_value, col2_value, title, symbol])

# %%
expanded_df = pd.DataFrame(expanded_rows, columns=['Prefix', 'phenotype_MIM_number', 'pheno_title', 'pheno_symbol'])
expanded_df

# %% [markdown]
# In pheno-symbols, there are values that are not just symbols

# %%
comma_df = expanded_df[expanded_df["pheno_symbol"].str.contains(",")]
comma_df

# %% [markdown]
# the vocab present that is not a symbol in DIGENIC, INCLUDED, FORMERLY, ICHTHYOSIS, CONGENITAL, WITH TRICHOTHIODYSTROPHY (identified via manual review)

# %% [markdown]
# always occur after a comma (excpet ICHTHYOSIS)

# %%
comma_df[comma_df["pheno_symbol"].str.contains("DIGENIC")]

# %% [markdown]
# Remove comman and all vocabulary after in the pheno_symbol column

# %%
expanded_df['pheno_symbol'] = expanded_df['pheno_symbol'].str.split(',').str[0]

# %%
cleaned_mimTitles_df = expanded_df.copy()

# %%
cleaned_mimTitles_df[cleaned_mimTitles_df['pheno_symbol'].str.contains("A2M", na=False)]

# %%
cleaned_mimTitles_df.loc[cleaned_mimTitles_df["pheno_symbol"]=="A2MD"]

# %%
cleaned_mimTitles_df.loc[cleaned_mimTitles_df["phenotype_MIM_number"]==166760]

# %%
cleaned_mimTitles_df.loc[cleaned_mimTitles_df["pheno_symbol"]=="OMS"]

# %%
morbidmap_df_old = pd.read_csv(
    "../input/morbidmap.txt", 
    sep="\t", 
    comment="#",
    names=["Phenotype", "gene_symbols", "gene_MIM_number", "gene_cyto_location"]
    )

# %%
morbidmap_df_new = pd.read_csv(
    "../input/morbidmap04292025.txt", 
    sep="\t", 
    comment="#",
    names=["Phenotype", "gene_symbols", "gene_MIM_number", "gene_cyto_location"]
    )

# %%
morbidmap_df = pd.concat([morbidmap_df_old, morbidmap_df_new], ignore_index=True)
morbidmap_df = morbidmap_df.drop_duplicates()

# %%
morbidmap_df[morbidmap_df['gene_symbols'].str.contains("A2M", na=False)]

# %%
morbidmap_df[morbidmap_df['gene_symbols'].str.contains("A2ML1", na=False)]

# %%
morbidmap_df[morbidmap_df["gene_MIM_number"] == 610627]

# %%
def split_phenotype_on_last_comma(phenotype):
    parts = phenotype.rsplit(',', 1)
    return parts[0], parts[1] if len(parts) > 1 else ''


morbidmap_df[['phenotype', 'MIM_number/phenotype_mapping_key']] = morbidmap_df['Phenotype'].apply(lambda x: pd.Series(split_phenotype_on_last_comma(x)))


morbidmap_df.drop(columns=['Phenotype'], inplace=True)

# %%
morbidmap_df

# %%
morbidmap_df.loc[morbidmap_df["gene_MIM_number"]==610627]

# %%
morbidmap_df[morbidmap_df['gene_symbols'].str.contains("OMS", na=False)]

# %%
morbidmap_df[morbidmap_df["gene_MIM_number"] == 610627]

# %%
def split_phenotype_description(description):
    match = re.match(r"(.*?)(\s*\(\d+\))?$", description)
    if match:
        return match.group(1).strip(), match.group(2).strip() if match.group(2) else ''
    else:
        return description, ''


morbidmap_df[['phenotype_MIM_number', 'phenotype_mapping_key']] = morbidmap_df['MIM_number/phenotype_mapping_key'].apply(
    lambda x: pd.Series(split_phenotype_description(x))
)
morbidmap_df.drop(columns=['MIM_number/phenotype_mapping_key', 'gene_cyto_location','phenotype','phenotype_mapping_key', 'gene_symbols'], inplace=True)

# %%
morbidmap_df

# %%
morbidmap_df.loc[morbidmap_df["gene_MIM_number"] == 610627]

# %%
cleaned_mimTitles_df['phenotype_MIM_number'] = cleaned_mimTitles_df['phenotype_MIM_number'].astype(str)

# %%
morbidmap_df.loc[morbidmap_df["phenotype_MIM_number"]=="614036"]

# %%
cleaned_mimTitles_df.loc[cleaned_mimTitles_df["pheno_symbol"]=="A2MD"]

# %%
morbidmap_and_mimTitles_df = pd.merge(morbidmap_df, cleaned_mimTitles_df, on='phenotype_MIM_number', how='left')

# %%
morbidmap_and_mimTitles_df

# %%
morbidmap_and_mimTitles_df.loc[morbidmap_and_mimTitles_df["phenotype_MIM_number"] == "166760"]

# %%
morbidmap_and_mimTitles_df.loc[morbidmap_and_mimTitles_df["pheno_symbol"]=="A2MD"]

# %%
mim2gene_and_morbidmap_and_mimTitles_df = pd.merge(morbidmap_and_mimTitles_df, mim2gene_df, on='gene_MIM_number', how='left')

# %%
mim2gene_and_morbidmap_and_mimTitles_df

# %%
mim2gene_and_morbidmap_and_mimTitles_df.loc[mim2gene_and_morbidmap_and_mimTitles_df["pheno_symbol"]=="A2MD"]

# %%
mim2gene_and_morbidmap_and_mimTitles_df.loc[mim2gene_and_morbidmap_and_mimTitles_df["pheno_symbol"]=="OMS"]

# %%
mim2gene_and_morbidmap_and_mimTitles_df.dropna(subset=['pheno_symbol'], inplace=True)

# %%
gene2disease_df = mim2gene_and_morbidmap_and_mimTitles_df.copy()

# %%
gene2disease_df.to_hdf(
    "../output/gene2disease_df.h5", key='df', mode='w'
)

# %%
disease_analysis_df = subset_genes_df.copy()
disease_analysis_df

# %%
print(gene2disease_df.dtypes)

# %%
print(disease_analysis_df.dtypes)

# %%
gene2disease_df['Approved Gene Symbol (HGNC)'] = gene2disease_df['Approved Gene Symbol (HGNC)'].str.upper()
gene2disease_df['pheno_symbol'] = gene2disease_df['pheno_symbol'].str.upper()

# %%
gene2disease_df["Approved Gene Symbol (HGNC) upper"] = gene2disease_df['Approved Gene Symbol (HGNC)'].str.upper()
gene2disease_df["pheno_symbol_upper"] =  gene2disease_df['pheno_symbol'].str.upper()

pheno_map = (
    gene2disease_df
    .dropna(subset=['Approved Gene Symbol (HGNC) upper', 'pheno_symbol_upper'])
    .groupby('Approved Gene Symbol (HGNC) upper')['pheno_symbol_upper']
    .apply(list)
    .to_dict()
)

gene2disease_df = gene2disease_df.drop(['Approved Gene Symbol (HGNC) upper', "pheno_symbol_upper"], axis=1)

def check_prefix_disease_match(row):
    alias = row['alias_symbol_upper']
    primary_gene_symbol = row['primary_gene_symbol_upper']

    if not isinstance(alias, str):
        return False

    phenotypes = pheno_map.get(primary_gene_symbol, [])

    return any(alias.startswith(pheno) for pheno in phenotypes)

disease_analysis_df["alias_symbol_upper"] = disease_analysis_df['alias_symbol'].str.upper()
disease_analysis_df["primary_gene_symbol_upper"] =  disease_analysis_df['primary_gene_symbol'].str.upper()

disease_analysis_df["Prefix Disease Symbol Match"] = disease_analysis_df.progress_apply(
    check_prefix_disease_match, axis=1)

def get_matching_phenotype_symbol_fast(row):
    alias = row['alias_symbol_upper']
    primary_gene_symbol = row['primary_gene_symbol_upper']

    if not isinstance(alias, str):
        return ""

    phenotypes = pheno_map.get(primary_gene_symbol, [])
    return next((symbol for symbol in phenotypes if alias.startswith(symbol)), "")

disease_analysis_df["Matching Phenotype Symbol"] = disease_analysis_df.progress_apply(
    get_matching_phenotype_symbol_fast, axis=1
)
disease_analysis_df = disease_analysis_df.drop(['alias_symbol_upper', "primary_gene_symbol_upper"], axis=1)

# %%
disease_analysis_df["Prefix Disease Symbol Match"].value_counts()

# %%
disease_analysis_df.loc[disease_analysis_df["alias_symbol"]=="A2MD"]

# %%
disease_analysis_df.loc[disease_analysis_df["alias_symbol"]=="OMS"]

# %%
disease_analysis_df.loc[disease_analysis_df["primary_gene_symbol"]=="BBS2"]

# %%
disease_analysis_df.loc[disease_analysis_df["Prefix Disease Symbol Match"]]

# %%
disease_prefix_match_subset_genes_df = disease_analysis_df[disease_analysis_df["Prefix Disease Symbol Match"]]

# %%
disease_prefix_match_subset_genes_df.to_hdf(
    "../output/disease_prefix_match_subset_genes_df.h5", key='df', mode='w'
)

# %%
disease_analysis_df.to_hdf(
    "../output/disease_analysis_df.h5", key='df', mode='w'
)

# %%
disease_analysis_df = pd.read_hdf("../output/disease_analysis_df.h5", key='df')

# %% [markdown]
# # <a id='toc7_'></a>[Placeholder Symbol Capture](#toc0_)

# %% [markdown]
# "we defined a gene as “unknown” if its official gene symbol (according to NCBI Entrez and HUGO) matched naming conventions of an EST (e.g., “KIAA”, “LOC”, “MGC”, “FLJ”, or “DKFZp” followed by digits)." - https://pmc.ncbi.nlm.nih.gov/articles/PMC4707969/

# %%
placeholder_analysis_df = subset_genes_df.copy()

# %%
loc_match = placeholder_analysis_df['alias_symbol'].str.match(r'^LOC\d+$', na=False)
kiaa_match = placeholder_analysis_df['alias_symbol'].str.startswith('KIAA', na=False)
dkfz_match = placeholder_analysis_df['alias_symbol'].str.startswith('DKFZ', na=False)
mgc_match = placeholder_analysis_df['alias_symbol'].str.match(r'^MGC:?\d{3,}$', na=False)
orf_match = placeholder_analysis_df['alias_symbol'].str.contains(r'^C.*ORF', case=False, na=False)
fam_match = placeholder_analysis_df['alias_symbol'].str.match(r'^FAM\d[A-Z0-9]*$', na=False)

no_dash = ~placeholder_analysis_df['alias_symbol'].str.contains("-", na=False)

placeholder_analysis_df["Placeholder Symbol Match"] = (
    ((loc_match | kiaa_match | dkfz_match | mgc_match | orf_match | fam_match) & no_dash)
)

# %%
conditions = [
    loc_match & no_dash,
    kiaa_match & no_dash,
    dkfz_match & no_dash,
    mgc_match & no_dash,
    orf_match & no_dash,
    fam_match & no_dash 
]

reasons = [
    'LOC placeholder symbol',
    'KIAA clone symbol',
    "DKFZ clone symbol",
    "MGC symbol",
    'C-ORF symbol',
    'FAM symbol'
]
placeholder_analysis_df['Placeholder Symbol Match Type'] = np.select(
    conditions, reasons, default=None
)

# %%
placeholder_match_subset_genes_df = placeholder_analysis_df.loc[placeholder_analysis_df["Placeholder Symbol Match"]]

# %%
placeholder_match_subset_genes_df.to_hdf(
    "../output/placeholder_match_subset_genes_df.h5", key='df', mode='w'
)

# %%
placeholder_analysis_df.to_hdf(
    "../output/placeholder_analysis_df.h5", key='df', mode='w'
)

# %% [markdown]
# # <a id='toc8_'></a>[Protein Mass Symbol Capture](#toc0_)

# %%
ens_uniprot_id_df = pd.read_csv(
    "../input/ens_uniprot_id20250827.txt", 
    sep=",")

# %% [markdown]
# ENS

# %%
# Original list of IDs
ens_uniprot_id_list = ens_uniprot_id_df["UniProtKB/Swiss-Prot ID"].dropna().unique().tolist()

# Split into chunks of 20
chunk_size = 20
ens_uniprot_id_chunks = [ens_uniprot_id_list[i:i + chunk_size] for i in range(0, len(ens_uniprot_id_list), chunk_size)]

# %%
def get_uniprot_data(uniprot_ids, fields=None):
    """
    """
    if fields is None:
        fields = ["accession", "mass"]

    base_url = "https://rest.uniprot.org/uniprotkb/search"
    query = " OR ".join(f"accession:{uid}" for uid in uniprot_ids)
    field_str = ",".join(fields)

    params = {
        "query": query,
        "fields": field_str,
        "format": "tsv",
        "size": len(uniprot_ids)
    }

    response = requests.get(base_url, params=params)
    if response.status_code == 200:
        df = pd.read_csv(StringIO(response.text), sep="\t")
        return df
    else:
        print(f"Failed chunk with status {response.status_code}")
        return pd.DataFrame()  # Return empty DataFrame on failure

# %%
# 2. Run each chunk through the function and collect results
all_dataframes = []

for idx, chunk in enumerate(ens_uniprot_id_chunks):
    print(f"Processing chunk {idx + 1}/{len(ens_uniprot_id_chunks)}...")
    df_chunk = get_uniprot_data(chunk)
    if df_chunk is not None and not df_chunk.empty:
        all_dataframes.append(df_chunk)

# 3. Combine all results into one DataFrame
ens_uniprot_id_chunks_combined_df = pd.concat(all_dataframes, ignore_index=True)

# 4. Inspect the final result
print("Combined UniProt data shape:", ens_uniprot_id_chunks_combined_df.shape)
print(ens_uniprot_id_chunks_combined_df.head())

# %%
ens_uniprot_id_chunks_combined_df.rename(columns={'Entry': 'UniProtKB/Swiss-Prot ID'}, inplace=True)

ens_uniprot_id_mass_merged_df = pd.merge(ens_uniprot_id_df, ens_uniprot_id_chunks_combined_df, on='UniProtKB/Swiss-Prot ID', how='inner')

# %%
protein_mass_analysis_df = subset_genes_df.copy()

# %%
def digit_prefix_matches_with_alias(row, df2,uniprot_associated_gene_id_col, subset_df_database_id_col):
    """
    """
    val1 = row[uniprot_associated_gene_id_col]
    val2_df1 = str(row['Mass'])
    matching_rows = df2[df2[subset_df_database_id_col].apply(lambda s: val1 in s)]
    pattern = re.compile(r'^[Pp](\d{1,3})')

    for _, r2 in matching_rows.iterrows():
        alias = str(r2['alias_symbol'])
        m = pattern.match(alias)
        if m:
            digits = m.group(1)
            if val2_df1.startswith(digits):
                # Return True and the matched alias_symbol
                return True, alias

    # No match found
    return False, None

# %% [markdown]
# #TODO: Add tqdm for cell below, 3 min run time

# %%
ens_uniprot_id_mass_merged_df[['Protein Mass Symbol Match', 'Matched Alias Symbol']] = (
    ens_uniprot_id_mass_merged_df
    .apply(lambda row: digit_prefix_matches_with_alias(row, protein_mass_analysis_df, 'Gene stable ID', 'ENSG_ID'), axis=1, result_type='expand')
)

# %%
ens_uniprot_id_mass_merged_df.loc[ens_uniprot_id_mass_merged_df["Gene stable ID"] == "ENSG00000103591"]

# %%
true_ens_uniprot_id_mass_merged_df = ens_uniprot_id_mass_merged_df[ens_uniprot_id_mass_merged_df["Protein Mass Symbol Match"]]

# %%
def alias_match_for_row(row, source_df, subset_df_database_id_col, uniprot_associated_gene_id_col):
    """
    Check if the 'alias_symbol' in protein_mass_analysis_df matches 'Matched Alias Symbol' in merged_df,
    ignoring case, and if any corresponding 'Gene stable ID' exists in the ENSG_ID set.
    """
    alias_symbol_raw = row['alias_symbol']
    if pd.isna(alias_symbol_raw):
        return False  # or np.nan if you prefer to keep missing info

    alias_symbol = alias_symbol_raw.casefold()  # Normalize to lowercase
    ens_set = row[subset_df_database_id_col]  # Set of IDs

    # Make sure ens_set is a set or list
    if not isinstance(ens_set, (set, list)):
        return False

    # Case-insensitive filter on merged_df
    matched_rows = source_df[source_df['Matched Alias Symbol'].str.casefold() == alias_symbol]

    # Check if any matching 'Gene stable ID' is in ens_set
    for _, r2 in matched_rows.iterrows():
        if r2[uniprot_associated_gene_id_col] in ens_set:
            return True

    return False

# %%
protein_mass_analysis_df['Protein Mass Alias Match ENS'] = protein_mass_analysis_df.apply(lambda row: alias_match_for_row(row, true_ens_uniprot_id_mass_merged_df,'ENSG_ID', 'Gene stable ID'), axis=1)

# %%
protein_mass_analysis_df.loc[protein_mass_analysis_df["primary_gene_symbol"] == "AAGAB"]

# %% [markdown]
# hgnc

# %%
hgnc_uniprot_id_df = pd.read_csv(
    "../input/hgnc_uniprot_id20250827.txt",
    sep="\t")
hgnc_uniprot_id_df

# %%
hgnc_uniprot_id_df = hgnc_uniprot_id_df.dropna(subset=['UniProt ID(supplied by UniProt)'])

# %%
hgnc_uniprot_id_df.loc[hgnc_uniprot_id_df["HGNC ID"] == "HGNC:377"]

# %%
hgnc_uniprot_id_df['UniProt ID(supplied by UniProt)_split'] = hgnc_uniprot_id_df['UniProt ID(supplied by UniProt)'].str.split(',')
hgnc_uniprot_id_df = hgnc_uniprot_id_df.explode('UniProt ID(supplied by UniProt)_split').reset_index(drop=True)
hgnc_uniprot_id_df = hgnc_uniprot_id_df.drop('UniProt ID(supplied by UniProt)', axis=1)

# %%
hgnc_uniprot_id_df.loc[hgnc_uniprot_id_df["HGNC ID"] == "HGNC:377"]

# %%
# Original list of IDs
hgnc_uniprot_id_list = hgnc_uniprot_id_df["UniProt ID(supplied by UniProt)_split"].dropna().unique().tolist()

hgnc_uniprot_id_chunks = [hgnc_uniprot_id_list[i:i + chunk_size] for i in range(0, len(hgnc_uniprot_id_list), chunk_size)]

# %%
# 2. Run each chunk through the function and collect results
all_dataframes = []

for idx, chunk in enumerate(hgnc_uniprot_id_chunks):
    print(f"Processing chunk {idx + 1}/{len(hgnc_uniprot_id_chunks)}...")
    df_chunk = get_uniprot_data(chunk)
    if df_chunk is not None and not df_chunk.empty:
        all_dataframes.append(df_chunk)

# 3. Combine all results into one DataFrame
hgnc_uniprot_id_chunks_combined_df = pd.concat(all_dataframes, ignore_index=True)

# 4. Inspect the final result
print("Combined UniProt data shape:", hgnc_uniprot_id_chunks_combined_df.shape)
print(hgnc_uniprot_id_chunks_combined_df.head())

# %%
hgnc_uniprot_id_chunks_combined_df.rename(columns={'Entry': 'UniProt ID(supplied by UniProt)_split'}, inplace=True)

hgnc_uniprot_id_mass_merged_df = pd.merge(hgnc_uniprot_id_df, hgnc_uniprot_id_chunks_combined_df, on='UniProt ID(supplied by UniProt)_split', how='inner')

# %% [markdown]
# #TODO: Add tqdm to cell below, 3 min run time

# %%
hgnc_uniprot_id_mass_merged_df[['Protein Mass Symbol Match', 'Matched Alias Symbol']] = (
    hgnc_uniprot_id_mass_merged_df
    .apply(lambda row: digit_prefix_matches_with_alias(row, protein_mass_analysis_df, 'HGNC ID', 'HGNC_ID'), axis=1, result_type='expand')
)

# %%
hgnc_uniprot_id_mass_merged_df.loc[hgnc_uniprot_id_mass_merged_df["HGNC ID"] == "HGNC:25662"]

# %%
true_hgnc_uniprot_id_mass_merged_df = hgnc_uniprot_id_mass_merged_df[hgnc_uniprot_id_mass_merged_df["Protein Mass Symbol Match"]]

# %%
protein_mass_analysis_df['Protein Mass Alias Match HGNC'] = protein_mass_analysis_df.apply(lambda row: alias_match_for_row(row, true_hgnc_uniprot_id_mass_merged_df,'HGNC_ID', "HGNC ID"), axis=1)

# %%
protein_mass_analysis_df.loc[protein_mass_analysis_df["primary_gene_symbol"] == "AAGAB"]

# %%
protein_mass_analysis_df['Protein Mass Symbol Match'] = protein_mass_analysis_df['Protein Mass Alias Match ENS'] | protein_mass_analysis_df['Protein Mass Alias Match HGNC']
protein_mass_analysis_df = protein_mass_analysis_df.drop(columns=['Protein Mass Alias Match ENS','Protein Mass Alias Match HGNC'])

# %%
protein_mass_match_subset_genes_df = protein_mass_analysis_df.loc[protein_mass_analysis_df["Protein Mass Symbol Match"]]

# %%
protein_mass_match_subset_genes_df

# %%
protein_mass_match_subset_genes_df.to_hdf(
    "../output/protein_mass_match_subset_genes_df.h5", key='df', mode='w'
)

# %%
protein_mass_analysis_df.to_hdf(
    "../output/protein_mass_analysis_df.h5", key='df', mode='w'
)

# %% [markdown]
# # <a id='toc9_'></a>[Gene Neighbors](#toc0_)

# %%
# can comment out after first run (~2 min run)
raw_ncbi_neighbors_df = pd.read_csv(
    "../input/gene_neighbors20251007", sep="\t")
raw_ncbi_neighbors_df

# %%
# can comment out after first run (~1 min run)
raw_ncbi_neighbors_df = raw_ncbi_neighbors_df.replace('-', np.nan)

# %%
#spilt the df into three: genes on left, genes on right, and overlapping genes
ncbi_right_neighbors_df = raw_ncbi_neighbors_df[['GeneID', 'GeneIDs_on_right']]
ncbi_right_neighbors_df = ncbi_right_neighbors_df.dropna(subset=['GeneIDs_on_right'])

ncbi_left_neighbors_df = raw_ncbi_neighbors_df[['GeneID', 'GeneIDs_on_left']]
ncbi_left_neighbors_df = ncbi_left_neighbors_df.dropna(subset=['GeneIDs_on_left'])

ncbi_overlapping_neighbors_df = raw_ncbi_neighbors_df[['GeneID', 'overlapping_GeneIDs']]
ncbi_overlapping_neighbors_df = ncbi_overlapping_neighbors_df.dropna(subset=['overlapping_GeneIDs'])

# %%
def optimized_split_and_explode(df, col):
    has_pipe = df[col].str.contains('\|', na=False)
    df_to_explode = df[has_pipe].copy()
    df_to_explode[col] = df_to_explode[col].str.split('|')
    exploded = df_to_explode.explode(col)

    # Add back rows that didn't need exploding
    df_no_pipe = df[~has_pipe]
    return pd.concat([df_no_pipe, exploded], ignore_index=True)

# %%
ncbi_gene_neighbor_symbol_analysis_df = subset_genes_df.copy()
ncbi_gene_neighbor_symbol_analysis_df['NCBI_ID'] = ncbi_gene_neighbor_symbol_analysis_df['NCBI_ID'].apply(lambda x: list(map(str, x)) if isinstance(x, set) else [])
ncbi_gene_neighbor_symbol_analysis_df = ncbi_gene_neighbor_symbol_analysis_df.explode('NCBI_ID').reset_index(drop=True)
ncbi_gene_neighbor_symbol_analysis_df = ncbi_gene_neighbor_symbol_analysis_df.dropna(subset=['alias_symbol','NCBI_ID'])
ncbi_gene_neighbor_symbol_analysis_df['NCBI_ID'] = ncbi_gene_neighbor_symbol_analysis_df['NCBI_ID'].str.removeprefix('GENE ID:')
ncbi_gene_neighbor_symbol_analysis_df

# %% [markdown]
# #### <a id='toc9_1_1_1_'></a>[Right neighbors](#toc0_)

# %%
# comment out after first run (~6 min run time)
ncbi_right_neighbors_df = optimized_split_and_explode(ncbi_right_neighbors_df, 'GeneIDs_on_right')

# %%
ncbi_right_neighbors_df = ncbi_right_neighbors_df.rename(columns={'GeneID': 'NCBI_ID'})
ncbi_right_neighbors_df

# %%
ncbi_right_neighbors_df = ncbi_right_neighbors_df.astype(str)

# %%
# comment out after the first run (~8.5 min run)
ncbi_right_neighbors_with_aliases_df = ncbi_right_neighbors_df.merge(
    ncbi_gene_neighbor_symbol_analysis_df[['NCBI_ID', 'alias_symbol']],
    left_on='NCBI_ID',
    right_on='NCBI_ID',
    how='left'
)
ncbi_right_neighbors_with_aliases_df = ncbi_right_neighbors_with_aliases_df.dropna(subset=['alias_symbol'])
ncbi_right_neighbors_with_aliases_df

# %%
ncbi_right_neighbors_with_aliases_and_symbols_df = ncbi_right_neighbors_with_aliases_df.merge(
    ncbi_gene_neighbor_symbol_analysis_df[['NCBI_ID', 'primary_gene_symbol']],
    left_on='GeneIDs_on_right',
    right_on='NCBI_ID',
    how='left',
    suffixes=('', '_associated')
)
ncbi_right_neighbors_with_aliases_and_symbols_df

# %%
ncbi_right_neighbors_with_aliases_and_symbols_df['Right Neighbor Gene Symbol Match'] = (
    ncbi_right_neighbors_with_aliases_and_symbols_df['alias_symbol'] == ncbi_right_neighbors_with_aliases_and_symbols_df['primary_gene_symbol']
)

# %%
ncbi_right_neighbors_with_aliases_and_symbols_df['Right Neighbor Gene Symbol Match Value'] = (
    ncbi_right_neighbors_with_aliases_and_symbols_df.apply(lambda row: f"Gene ID:{row['NCBI_ID']}'s alias,{row['alias_symbol']}, is also the primary gene symbol of Gene ID:{row['GeneIDs_on_right']}", axis=1)
)
ncbi_right_neighbors_with_aliases_and_symbols_df_match = ncbi_right_neighbors_with_aliases_and_symbols_df.loc[ncbi_right_neighbors_with_aliases_and_symbols_df['Right Neighbor Gene Symbol Match']]

# %% [markdown]
# #### <a id='toc9_1_1_2_'></a>[Left Neighbors](#toc0_)

# %%
#comment out after first run (~9 min run time)
ncbi_left_neighbors_df = optimized_split_and_explode(ncbi_left_neighbors_df, 'GeneIDs_on_left')

# %%
ncbi_left_neighbors_df = ncbi_left_neighbors_df.rename(columns={'GeneID': 'NCBI_ID'})
ncbi_left_neighbors_df

# %%
ncbi_left_neighbors_df = ncbi_left_neighbors_df.astype(str)

# %%
ncbi_left_neighbors_with_aliases_df = ncbi_left_neighbors_df.merge(
    ncbi_gene_neighbor_symbol_analysis_df[['NCBI_ID', 'alias_symbol']],
    left_on='NCBI_ID',
    right_on='NCBI_ID',
    how='left'
)
ncbi_left_neighbors_with_aliases_df = ncbi_left_neighbors_with_aliases_df.dropna(subset=['alias_symbol'])
ncbi_left_neighbors_with_aliases_df

# %%
ncbi_left_neighbors_with_aliases_and_symbols_df = ncbi_left_neighbors_with_aliases_df.merge(
    ncbi_gene_neighbor_symbol_analysis_df[['NCBI_ID', 'primary_gene_symbol']],
    left_on='GeneIDs_on_left',
    right_on='NCBI_ID',
    how='left',
    suffixes=('', '_associated')
)
ncbi_left_neighbors_with_aliases_and_symbols_df

# %%
ncbi_left_neighbors_with_aliases_and_symbols_df['Left Neighbor Gene Symbol Match'] = (
    ncbi_left_neighbors_with_aliases_and_symbols_df['alias_symbol'] == ncbi_left_neighbors_with_aliases_and_symbols_df['primary_gene_symbol']
)

# %%
ncbi_left_neighbors_with_aliases_and_symbols_df['Left Neighbor Gene Symbol Match Value'] = (
    ncbi_left_neighbors_with_aliases_and_symbols_df.apply(lambda row: f"Gene ID:{row['NCBI_ID']}'s alias,{row['alias_symbol']}, is also the primary gene symbol of Gene ID:{row['GeneIDs_on_left']}", axis=1)
)
ncbi_left_neighbors_with_aliases_and_symbols_df_match = ncbi_left_neighbors_with_aliases_and_symbols_df.loc[ncbi_left_neighbors_with_aliases_and_symbols_df['Left Neighbor Gene Symbol Match']]
ncbi_left_neighbors_with_aliases_and_symbols_df_match

# %% [markdown]
# #### <a id='toc9_1_1_3_'></a>[Overlapping Genes](#toc0_)

# %%
ncbi_overlapping_neighbors_df = optimized_split_and_explode(ncbi_overlapping_neighbors_df, 'overlapping_GeneIDs')

# %%
ncbi_overlapping_neighbors_df = ncbi_overlapping_neighbors_df.rename(columns={'GeneID': 'NCBI_ID'})
ncbi_overlapping_neighbors_df

# %%
ncbi_overlapping_neighbors_df = ncbi_overlapping_neighbors_df.astype(str)

# %%
ncbi_overlapping_neighbors_with_aliases_df = ncbi_overlapping_neighbors_df.merge(
    ncbi_gene_neighbor_symbol_analysis_df[['NCBI_ID', 'alias_symbol']],
    left_on='NCBI_ID',
    right_on='NCBI_ID',
    how='left'
)
ncbi_overlapping_neighbors_with_aliases_df = ncbi_overlapping_neighbors_with_aliases_df.dropna(subset=['alias_symbol'])
ncbi_overlapping_neighbors_with_aliases_df

# %%
ncbi_overlapping_neighbors_with_aliases_and_symbols_df = ncbi_overlapping_neighbors_with_aliases_df.merge(
    ncbi_gene_neighbor_symbol_analysis_df[['NCBI_ID', 'primary_gene_symbol']],
    left_on='overlapping_GeneIDs',
    right_on='NCBI_ID',
    how='left',
    suffixes=('', '_associated')
)
ncbi_overlapping_neighbors_with_aliases_and_symbols_df

# %%
ncbi_overlapping_neighbors_with_aliases_and_symbols_df['Overlap Gene Symbol Match'] = (
    ncbi_overlapping_neighbors_with_aliases_and_symbols_df['alias_symbol'] == ncbi_overlapping_neighbors_with_aliases_and_symbols_df['primary_gene_symbol']
)

# %%
ncbi_overlapping_neighbors_with_aliases_and_symbols_df['Overlap Gene Symbol Match Value'] = (
    ncbi_overlapping_neighbors_with_aliases_and_symbols_df.apply(lambda row: f"Gene ID:{row['NCBI_ID']}'s alias,{row['alias_symbol']}, is also the primary gene symbol of Gene ID:{row['overlapping_GeneIDs']}", axis=1)
)
ncbi_overlapping_neighbors_with_aliases_and_symbols_df_match = ncbi_overlapping_neighbors_with_aliases_and_symbols_df.loc[ncbi_overlapping_neighbors_with_aliases_and_symbols_df['Overlap Gene Symbol Match']]
ncbi_overlapping_neighbors_with_aliases_and_symbols_df_match

# %% [markdown]
# #### <a id='toc9_1_1_4_'></a>[Combine all neighbor data](#toc0_)

# %%
ncbi_right_neighbors_with_aliases_and_symbols_df_match['neighbor_gene_type'] = 'Right Gene Neighbor'
ncbi_right_neighbors_df_match = ncbi_right_neighbors_with_aliases_and_symbols_df_match.rename(columns={
    'GeneIDs_on_right': 'neighbor_NCBI_ID',
    'primary_gene_symbol': 'neighbor_primary_gene_symbol',
    'Right Neighbor Gene Symbol Match':'Neighbor Gene Symbol Match'
})[['NCBI_ID', 'neighbor_NCBI_ID','alias_symbol','neighbor_primary_gene_symbol','Neighbor Gene Symbol Match','neighbor_gene_type']]

# %%
ncbi_left_neighbors_with_aliases_and_symbols_df_match['neighbor_gene_type'] = 'Left Gene Neighbor'
ncbi_left_neighbors_df_match = ncbi_left_neighbors_with_aliases_and_symbols_df_match.rename(columns={
    'GeneIDs_on_left': 'neighbor_NCBI_ID',
    'primary_gene_symbol': 'neighbor_primary_gene_symbol',
    'Left Neighbor Gene Symbol Match':'Neighbor Gene Symbol Match'
})[['NCBI_ID', 'neighbor_NCBI_ID','alias_symbol','neighbor_primary_gene_symbol','Neighbor Gene Symbol Match','neighbor_gene_type']]

# %%
ncbi_overlapping_neighbors_with_aliases_and_symbols_df_match['neighbor_gene_type'] = 'Overlap Gene Neighbor'
ncbi_overlapping_neighbors_df_match = ncbi_overlapping_neighbors_with_aliases_and_symbols_df_match.rename(columns={
    'overlapping_GeneIDs': 'neighbor_NCBI_ID',
    'primary_gene_symbol': 'neighbor_primary_gene_symbol',
    'Overlap Gene Symbol Match':'Neighbor Gene Symbol Match'
})[['NCBI_ID', 'neighbor_NCBI_ID','alias_symbol','neighbor_primary_gene_symbol','Neighbor Gene Symbol Match','neighbor_gene_type']]

# %%
ncbi_neighbors_df_match = pd.concat([ncbi_right_neighbors_df_match, ncbi_left_neighbors_df_match, ncbi_overlapping_neighbors_df_match], ignore_index=True)
ncbi_neighbors_df_match

# %%
ncbi_gene_neighbor_symbol_analysis_df = ncbi_gene_neighbor_symbol_analysis_df.merge(
    ncbi_neighbors_df_match[['NCBI_ID', 'alias_symbol', 'Neighbor Gene Symbol Match', 'neighbor_gene_type']],
    on=['NCBI_ID', 'alias_symbol'],
    how='left'
)

# %%
ncbi_gene_neighbor_symbol_analysis_df['NCBI_ID'] = 'GENE ID:' + ncbi_gene_neighbor_symbol_analysis_df['NCBI_ID'].astype(str)
ncbi_gene_neighbor_symbol_analysis_df['NCBI_ID'] = ncbi_gene_neighbor_symbol_analysis_df['NCBI_ID'].apply(
        lambda x: set(x.split(',')) if isinstance(x, str) and x else set() if x == '' else x
    )
ncbi_gene_neighbor_symbol_analysis_df

# %%
ncbi_gene_neighbor_symbol_analysis_df = ncbi_gene_neighbor_symbol_analysis_df[ncbi_gene_neighbor_symbol_analysis_df["Neighbor Gene Symbol Match"].fillna(False)]
ncbi_gene_neighbor_match_subset_genes_df = ncbi_gene_neighbor_symbol_analysis_df.loc[ncbi_gene_neighbor_symbol_analysis_df["Neighbor Gene Symbol Match"]]
ncbi_gene_neighbor_match_subset_genes_df

# %%
ncbi_gene_neighbor_symbol_analysis_df.to_hdf(
    "../output/ncbi_gene_neighbor_symbol_analysis_df.h5", key='df', mode='w'
)

# %%
ncbi_gene_neighbor_match_subset_genes_df.to_hdf(
    "../output/ncbi_gene_neighbor_match_subset_genes_df.h5", key='df', mode='w'
)

# %% [markdown]
# # <a id='toc10_'></a>[Gene Group](#toc0_)

# %%
raw_ncbi_gene_group_df = pd.read_csv(
    "../input/gene_group20251007",
    sep="\t",
    usecols=["GeneID", "relationship","Other_GeneID"]  # replace with actual column names
)
raw_ncbi_gene_group_df

# %%
ncbi_gene_group_df = raw_ncbi_gene_group_df.replace('-', np.nan)

# %%
ncbi_gene_group_df = ncbi_gene_group_df.dropna(subset=['Other_GeneID'])

# %% [markdown]
# Make the NCBI ID not a set and remove the prefix

# %%
ncbi_gene_group_symbol_analysis_df = subset_genes_df.copy()
ncbi_gene_group_symbol_analysis_df['NCBI_ID'] = ncbi_gene_group_symbol_analysis_df['NCBI_ID'].apply(lambda x: list(map(str, x)) if isinstance(x, set) else [])
ncbi_gene_group_symbol_analysis_df = ncbi_gene_group_symbol_analysis_df.explode('NCBI_ID').reset_index(drop=True)
ncbi_gene_group_symbol_analysis_df = ncbi_gene_group_symbol_analysis_df.dropna(subset=['alias_symbol','NCBI_ID'])
ncbi_gene_group_symbol_analysis_df['NCBI_ID'] = ncbi_gene_group_symbol_analysis_df['NCBI_ID'].str.removeprefix('GENE ID:')
ncbi_gene_group_symbol_analysis_df

# %%
ncbi_gene_group_df = ncbi_gene_group_df.rename(columns={'GeneID': 'NCBI_ID'})
ncbi_gene_group_df

# %%
cols_to_clean = ['NCBI_ID', 'Other_GeneID']
ncbi_gene_group_df[cols_to_clean] = ncbi_gene_group_df[cols_to_clean].astype(str).apply(lambda col: col.str.strip())
ncbi_gene_group_symbol_analysis_df['NCBI_ID'] = ncbi_gene_group_symbol_analysis_df['NCBI_ID'].astype(str).str.strip()

# %%
ncbi_gene_group_df.loc[ncbi_gene_group_df["NCBI_ID"] == "442334"]

# %% [markdown]
# Add aliases of the gene in NCBI ID to ncbi_gene_group_df

# %%
# comment out after the first run (~8.5 min run)
ncbi_gene_group_with_aliases_df = ncbi_gene_group_df.merge(
    ncbi_gene_group_symbol_analysis_df[['NCBI_ID', 'alias_symbol']],
    left_on='NCBI_ID',
    right_on='NCBI_ID',
    how='left'
)
ncbi_gene_group_with_aliases_df = ncbi_gene_group_with_aliases_df.dropna(subset=['alias_symbol'])
ncbi_gene_group_with_aliases_df

# %% [markdown]
# Add the primary gene symbol of the gene in Other GeneID

# %%
ncbi_gene_group_with_aliases_and_symbols_df = ncbi_gene_group_with_aliases_df.merge(
    ncbi_gene_group_symbol_analysis_df[['NCBI_ID', 'primary_gene_symbol']],
    left_on='Other_GeneID',
    right_on='NCBI_ID',
    how='left',
    suffixes=('', '_associated')
)
ncbi_gene_group_with_aliases_and_symbols_df

# %% [markdown]
# When is the related gene symbol(other_geneid/primary_gene_symbol) featured as an alias(alias_symbol) to the first gene(NCBI_ID)?

# %%
ncbi_gene_group_with_aliases_and_symbols_df['Gene Group Gene Symbol Match'] = (
    ncbi_gene_group_with_aliases_and_symbols_df['alias_symbol'] == ncbi_gene_group_with_aliases_and_symbols_df['primary_gene_symbol']
)

# %%
ncbi_gene_group_with_aliases_and_symbols_df['Gene Group Gene Symbol Match'].value_counts()

# %%
ncbi_gene_group_symbol_analysis_df = ncbi_gene_group_symbol_analysis_df.merge(
    ncbi_gene_group_with_aliases_and_symbols_df[['NCBI_ID', 'alias_symbol', 'Gene Group Gene Symbol Match', 'relationship']],
    on=['NCBI_ID', 'alias_symbol'],
    how='left'
)

# %%
ncbi_gene_group_symbol_analysis_df['NCBI_ID'] = ncbi_gene_group_symbol_analysis_df['NCBI_ID'].apply(
        lambda x: set(x.split(',')) if isinstance(x, str) and x else set() if x == '' else x
    )
ncbi_gene_group_symbol_analysis_df

# %%
ncbi_gene_group_symbol_analysis_df = ncbi_gene_group_symbol_analysis_df[ncbi_gene_group_symbol_analysis_df["Gene Group Gene Symbol Match"].fillna(False)]
ncbi_gene_group_symbol_analysis_df.loc[ncbi_gene_group_symbol_analysis_df['Gene Group Gene Symbol Match'] == False, 'relationship'] = np.nan
ncbi_gene_group_symbol_match_subset_genes_df = ncbi_gene_group_symbol_analysis_df.loc[ncbi_gene_group_symbol_analysis_df["Gene Group Gene Symbol Match"]]
ncbi_gene_group_symbol_match_subset_genes_df

# %%
ncbi_gene_group_symbol_analysis_df.to_hdf(
    "../output/ncbi_gene_group_symbol_analysis_df.h5", key='df', mode='w'
)

# %%
ncbi_gene_group_symbol_match_subset_genes_df.to_hdf(
    "../output/ncbi_gene_group_symbol_match_subset_genes_df.h5", key='df', mode='w'
)

# %% [markdown]
# # <a id='toc11_'></a>[Gene Interactions](#toc0_)

# %%
raw_ncbi_interactions_df = pd.read_csv(
    "../input/interactions20251007",
    sep="\t",
    usecols=["gene_id", "name","keyphrase","interactant_id"]  # replace with actual column names
)
raw_ncbi_interactions_df

# %%
ncbi_interactions_df = raw_ncbi_interactions_df.replace('-', np.nan)

# %%
ncbi_interactions_df = ncbi_interactions_df.dropna(subset=['interactant_id'])

# %%
ncbi_gene_interaction_symbol_analysis_df = subset_genes_df.copy()
ncbi_gene_interaction_symbol_analysis_df['NCBI_ID'] = ncbi_gene_interaction_symbol_analysis_df['NCBI_ID'].apply(lambda x: list(map(str, x)) if isinstance(x, set) else [])
ncbi_gene_interaction_symbol_analysis_df = ncbi_gene_interaction_symbol_analysis_df.explode('NCBI_ID').reset_index(drop=True)
ncbi_gene_interaction_symbol_analysis_df = ncbi_gene_interaction_symbol_analysis_df.dropna(subset=['alias_symbol','NCBI_ID'])
ncbi_gene_interaction_symbol_analysis_df['NCBI_ID'] = ncbi_gene_interaction_symbol_analysis_df['NCBI_ID'].str.removeprefix('GENE ID:')
ncbi_gene_interaction_symbol_analysis_df

# %%
ncbi_interactions_df = ncbi_interactions_df.rename(columns={'gene_id': 'NCBI_ID'})
ncbi_interactions_df

# %%
cols_to_clean = ['NCBI_ID', 'interactant_id']
ncbi_interactions_df[cols_to_clean] = ncbi_interactions_df[cols_to_clean].astype(str).apply(lambda col: col.str.strip())
ncbi_gene_interaction_symbol_analysis_df['NCBI_ID'] = ncbi_gene_interaction_symbol_analysis_df['NCBI_ID'].astype(str).str.strip()

# %%
ncbi_interactions_with_aliases_df = ncbi_interactions_df.merge(
    ncbi_gene_interaction_symbol_analysis_df[['NCBI_ID', 'alias_symbol']],
    left_on='NCBI_ID',
    right_on='NCBI_ID',
    how='left'
)
ncbi_interactions_with_aliases_df = ncbi_interactions_with_aliases_df.dropna(subset=['alias_symbol'])
ncbi_interactions_with_aliases_df

# %%
ncbi_interactions_with_aliases_and_symbols_df = ncbi_interactions_with_aliases_df.merge(
    ncbi_gene_interaction_symbol_analysis_df[['NCBI_ID', 'primary_gene_symbol']],
    left_on='interactant_id',
    right_on='NCBI_ID',
    how='left',
    suffixes=('', '_associated')
)
ncbi_interactions_with_aliases_and_symbols_df

# %%
ncbi_interactions_with_aliases_and_symbols_df['Gene Interaction Gene Symbol Match'] = (
    ncbi_interactions_with_aliases_and_symbols_df['alias_symbol'] == ncbi_interactions_with_aliases_and_symbols_df['primary_gene_symbol']
)

# %%
ncbi_interactions_with_aliases_and_symbols_df['Gene Interaction Gene Symbol Match'].value_counts()

# %%
ncbi_gene_interaction_symbol_analysis_df = ncbi_gene_interaction_symbol_analysis_df.merge(
    ncbi_interactions_with_aliases_and_symbols_df[['NCBI_ID', 'alias_symbol', 'Gene Interaction Gene Symbol Match']],
    on=['NCBI_ID', 'alias_symbol'],
    how='left'
)

# %%
ncbi_gene_interaction_symbol_analysis_df['NCBI_ID'] = ncbi_gene_interaction_symbol_analysis_df['NCBI_ID'].apply(
        lambda x: set(x.split(',')) if isinstance(x, str) and x else set() if x == '' else x
    )
ncbi_gene_interaction_symbol_analysis_df

# %%
ncbi_gene_interaction_symbol_analysis_df = ncbi_gene_interaction_symbol_analysis_df[ncbi_gene_interaction_symbol_analysis_df["Gene Interaction Gene Symbol Match"].fillna(False)]
ncbi_gene_interaction_symbol_match_subset_genes_df = ncbi_gene_interaction_symbol_analysis_df.loc[ncbi_gene_interaction_symbol_analysis_df["Gene Interaction Gene Symbol Match"]]
ncbi_gene_interaction_symbol_match_subset_genes_df

# %%
ncbi_gene_interaction_symbol_analysis_df.to_hdf(
    "../output/ncbi_gene_interaction_symbol_analysis_df.h5", key='df', mode='w'
)

# %%
ncbi_gene_interaction_symbol_match_subset_genes_df.to_hdf(
    "../output/ncbi_gene_interaction_symbol_match_subset_genes_df.h5", key='df', mode='w'
)

# %% [markdown]
# # <a id='toc12_'></a>[Gene Identifiers](#toc0_)

# %% [markdown]
# ## <a id='toc12_1_'></a>[Ensembl linked Gene Identifiers](#toc0_)

# %%
ens_gene_id_symbol_analysis_df = subset_genes_df.copy()

# %%
def get_attributes_for_ensembl_id(ensembl_id= str, attributes= list, dataset=None):
    """
    Query Ensembl BioMart for the given a SINGLE Ensembl gene ID and return attribute values.
    
    :param ensembl_id: The Ensembl gene ID (e.g., 'ENSG00000141510')
    :param attributes: List of attribute keys (e.g., ['external_gene_name', 'hgnc_symbol'])
    :param dataset (pybiomart.dataset.Dataset, optional): Pass a pre-initialized dataset object to reuse connection.
    return: dict {attribute_key: [values]} for each attribute
    """
    if dataset is None:
        server = Server(host='http://www.ensembl.org')
        dataset = server.marts['ENSEMBL_MART_ENSEMBL'].datasets['hsapiens_gene_ensembl']

    # Get attribute key → display name mapping
    display_names = {attr.name: attr.display_name for attr in dataset.attributes.values()}

    result_dict = {}

    for attr in attributes:
        display_name = display_names.get(attr, attr)  # fallback to key if not found

        try:
            query_result = dataset.query(
                attributes=['ensembl_gene_id', attr],
                filters={'link_ensembl_gene_id': ensembl_id}
            )

            if display_name in query_result.columns:
                values = query_result[display_name].dropna().unique().tolist()
                result_dict[attr] = values
            else:
                result_dict[attr] = []
        except Exception as e:
            print(f"Error querying attribute '{attr}' for Ensembl ID {ensembl_id}: {e}")
            result_dict[attr] = []

    return result_dict

# %%
def safe_query(dataset, attributes, filters, retries=3, wait=5):
    """
    Query a BioMart dataset with retry logic for handling connection-related errors.

    :param dataset: pybiomart.Dataset object to query.
    :param attributes: List of attribute keys to retrieve (e.g., ['ensembl_gene_id', 'hgnc_symbol']).
    :param filters: Dictionary of filters to apply to the query (e.g., {'link_ensembl_gene_id': ['ENSG00000141510']}).
    :param retries: Number of times to retry the query if a connection error occurs (default is 3).
    :param wait: Base number of seconds to wait between retries; wait time increases linearly with each attempt (default is 5).
    
    :return: pandas.DataFrame containing the query results.
    
    :raises: Last encountered exception if all retry attempts fail.
    """

    for attempt in range(1, retries + 1):
        try:
            return dataset.query(attributes=attributes, filters=filters)
        except (ConnectionResetError, ConnectionAbortedError, RequestException, TimeoutError) as e:
            print(f"Connection error on attempt {attempt}/{retries}: {e}")
            if attempt == retries:
                raise
            else:
                time.sleep(wait * attempt)  # exponential backoff
        except Exception as e:
            print(f"Unexpected error on attempt {attempt}/{retries}: {e}")
            if attempt == retries:
                raise
            else:
                time.sleep(wait * attempt)

# %%
def get_attributes_for_ensembl_ids(ensembl_ids, attributes, dataset=None):
    """
    Query Ensembl BioMart for MULTIPLE Ensembl gene IDs and return attribute values.

    :param ensembl_ids: Set or list of Ensembl gene IDs (e.g., {'ENSG00000141510', 'ENSG00000155657'}).
    :param attributes: List of attribute keys to retrieve (e.g., ['external_gene_name', 'hgnc_symbol']).
    :param dataset: (pybiomart.dataset.Dataset, optional) Pass a pre-initialized dataset object to reuse the connection.

    :return: dict in the form {ensembl_id: {attribute_key: [values]}} 
             where each value is a list of unique non-null entries returned from BioMart.
    """
    if dataset is None:
        server = Server(host='http://www.ensembl.org')
        dataset = server.marts['ENSEMBL_MART_ENSEMBL'].datasets['hsapiens_gene_ensembl']

    display_names = {attr.name: attr.display_name for attr in dataset.attributes.values()}

    result = {ensembl_id: {attr: [] for attr in attributes} for ensembl_id in ensembl_ids}

    for attr in attributes:
        display_name = display_names.get(attr, attr)

        try:
            query_result = safe_query(
                dataset,
                attributes=['ensembl_gene_id', attr],
                filters={'link_ensembl_gene_id': list(ensembl_ids)}
            )

            if display_name in query_result.columns and 'Gene stable ID' in query_result.columns:
                grouped = query_result.dropna().groupby('Gene stable ID')[display_name]

                for ensembl_id, values in grouped:
                    if ensembl_id in result:
                        result[ensembl_id][attr] = list(values.dropna().unique())
        except Exception as e:
            print(f"Error querying attribute '{attr}': {e}")
            # All Ensembl IDs already default to [] for this attribute

    return result

# %%
def batch_query_ensembl(ids, attributes, dataset, batch_size=400):
    """
    Query Ensembl BioMart in batches to avoid exceeding URL length or server limits.

    :param ids: Iterable of Ensembl gene IDs (e.g., list or set of 'ENSG...' strings).
    :param attributes: List of attribute keys to retrieve (e.g., ['external_gene_name', 'hgnc_symbol']).
    :param dataset: (pybiomart.dataset.Dataset) A pre-initialized dataset object for querying BioMart.
    :param batch_size: Number of Ensembl IDs to include per batch (default is 400).

    :return: dict in the form {ensembl_id: {attribute_key: [values]}} with results merged across all batches.
    """
    results = {}
    for i in tqdm(range(0, len(ids), batch_size), desc="Batch querying BioMart"):
        batch = list(ids)[i:i+batch_size]
        try:
            batch_results = get_attributes_for_ensembl_ids(batch, attributes, dataset=dataset)
            results.update(batch_results)
        except Exception as e:
            print(f"Error querying batch {i//batch_size+1}: {e}")
    return results

# %%
def match_alias_to_ensembl_attributes(df, id_column, alias_column, attributes, dataset=None):
    """
    Match alias values in a DataFrame to Ensembl attribute values using BioMart.

    For each row, checks whether the alias value appears in any of the specified Ensembl attributes
    for any of the associated Ensembl gene IDs. Stops at the first match found (attribute-level or ID-level)
    and returns match details.

    :param df: pandas.DataFrame with columns for Ensembl IDs and alias values.
    :param id_column: Name of the column in `df` containing a set or list of Ensembl gene IDs per row.
    :param alias_column: Name of the column in `df` containing the alias string to match.
    :param attributes: List of attribute keys to query from Ensembl (e.g., ['external_gene_name', 'hgnc_symbol']).
    :param dataset: (pybiomart.dataset.Dataset, optional) Reuse a pre-initialized dataset if provided.

    :return: pandas.DataFrame with additional columns:
        - 'match_found': Boolean indicating if alias matched any attribute value.
        - 'matching_value': The alias value that matched (or None).
        - 'matching_attribute': Display name of the attribute that matched (or None).
    """
    if dataset is None:
        server = Server(host='http://www.ensembl.org')
        dataset = server.marts['ENSEMBL_MART_ENSEMBL'].datasets['hsapiens_gene_ensembl']

    # Map internal attribute keys to display names
    display_name_map = {attr.name: attr.display_name for attr in dataset.attributes.values()}

    all_ids = set().union(*df[id_column])
    attribute_results = batch_query_ensembl(all_ids, attributes, dataset)

    match_flags = []
    match_values = []
    match_attributes = []

    for _, row in tqdm(df.iterrows(), total=len(df), desc="Matching rows"):        
        alias = row[alias_column]
        id_set = row[id_column]

        match_found = False
        matched_value = None
        matched_attr_display = None

        for eid in id_set:
            attr_data = attribute_results.get(eid, {})
            for attr_key, values in attr_data.items():
                if pd.isna(alias):
                    continue  # skip if alias is missing

                alias_lower = str(alias).lower()

                for attr_key, values in attr_data.items():
                    # Filter out NaN and lowercase values for comparison
                    filtered_values = [str(v).lower() for v in values if pd.notna(v)]
                    
                    if alias_lower in filtered_values:
                        match_found = True
                        matched_value = alias  # keep original alias casing
                        matched_attr_display = display_name_map.get(attr_key, attr_key)
                        break
            if match_found:
                break

        match_flags.append(match_found)
        match_values.append(matched_value)
        match_attributes.append(matched_attr_display)

    df = df.copy()
    df['Gene Identifier Match'] = match_flags
    df['matching_value'] = match_values
    df['matching_attribute'] = match_attributes

    return df

# %%
attributes_of_interest = ['protein_id', 'mirbase_id', 'mirbase_accession', 'entrezgene_accession', 'pdb', 'hgnc_trans_name', 'uniprot_gn_id', 'agilent_gpl19072', 'prints']

# %%
ens_gene_id_symbol_analysis_df = match_alias_to_ensembl_attributes(ens_gene_id_symbol_analysis_df, id_column='ENSG_ID', alias_column='alias_symbol', attributes=attributes_of_interest)
ens_gene_id_symbol_analysis_df["Gene Identifier Match"].value_counts()

# %%
ens_gene_id_symbol_analysis_df["matching_attribute"].value_counts()

# %% [markdown]
# Add match = True if alias has associated source prefix

# %%
def match_alias_to_gene_identifier_by_prefix(row, boolean_match_col, alias_symbol_col, source_of_id_col, prefix, suffix_condition=None):
    """Check and update match status and source information based on alias prefix.

    If the boolean match column is already True, returns existing values.
    If the alias symbol starts with the given prefix, sets match to True and
    sets the source column to a descriptive prefix string.

    :param row: a single row from a DataFrame (Series)
    :param boolean_match_col: name of the column that holds the True/False match status
    :param alias_symbol_col: name of the column containing the alias symbol
    :param source_of_id_col: name of the column where the source label should be added
    :param prefix: string prefix to match against the alias symbol
    :param suffix_condition: function to apply to the suffix after prefix (optional)
    :return: tuple (updated match boolean, updated source string)
    """
    if row[boolean_match_col]:
        return row[boolean_match_col], row[source_of_id_col]
    
    value = row.get(alias_symbol_col)
    
    if isinstance(value, str) and value.upper().startswith(prefix.upper()):
        suffix = value[len(prefix):]
        
        if suffix_condition is None or suffix_condition(suffix):
            return True, f'{prefix} prefix'

    return False, row[source_of_id_col]

# %%
ens_gene_id_symbol_analysis_df[["Gene Identifier Match", "matching_attribute"]] = ens_gene_id_symbol_analysis_df.apply(
    lambda row: match_alias_to_gene_identifier_by_prefix(
        row,
        "Gene Identifier Match",
        "alias_symbol",
        "matching_attribute",
        "hsa-mir"
    ),
    axis=1,
    result_type='expand'
)
ens_gene_id_symbol_analysis_df

# %%
ens_gene_id_symbol_analysis_df["Gene Identifier Match"].value_counts()

# %%
ens_gene_id_symbol_analysis_df.loc[ens_gene_id_symbol_analysis_df["alias_symbol"].fillna("").str.match(r"^PR\d{5}$")]

# %%
ens_gene_id_symbol_analysis_df.loc[ens_gene_id_symbol_analysis_df["alias_symbol"].fillna("").str.match(r"^PRO\d{4}$")]

# %% [markdown]
# ## <a id='toc12_2_'></a>[HGNC](#toc0_)

# %%
raw_hgnc_associated_ids_df = pd.read_csv(
    "../input/hgnc_associated_ids20250926.txt", sep="\t")
raw_hgnc_associated_ids_df

# %%
unique_id_col = raw_hgnc_associated_ids_df.columns[0]

# %%
records = []

# %% [markdown]
# Condense all identifiers into one column (associated_id) and add a separate column to identify the source of the identifier (source)

# %%
for _, row in raw_hgnc_associated_ids_df.iterrows():
    uid = row[unique_id_col]
    for col in raw_hgnc_associated_ids_df.columns[1:]:
        val = row[col]
        if pd.isna(val) or val == '':
            continue
        # Split comma-separated values and strip whitespace
        values = [v.strip() for v in str(val).split(',')]
        for v in values:
            records.append({unique_id_col: uid, 'associated_id': v, 'source': col})

# %%
hgnc_associated_ids_df = pd.DataFrame(records)

# %%
hgnc_associated_ids_df = hgnc_associated_ids_df[[unique_id_col, 'associated_id', 'source']].reset_index(drop=True)
hgnc_associated_ids_df = hgnc_associated_ids_df[hgnc_associated_ids_df['associated_id'].notna() & (hgnc_associated_ids_df['associated_id'].str.strip() != '')]
hgnc_associated_ids_df

# %%
hgnc_associated_ids_df.loc[hgnc_associated_ids_df["HGNC ID"] == "HGNC:7"]

# %%
hgnc_associated_ids_df.loc[hgnc_associated_ids_df["source"] == "Accession numbers"]

# %%
hgnc_associated_ids_df.loc[hgnc_associated_ids_df["associated_id"].str.startswith("AC008")]

# %% [markdown]
# Split out the HGNC ID sets so that they are one per row and just a string

# %%
hgnc_gene_id_symbol_analysis_df = subset_genes_df.copy()
hgnc_gene_id_symbol_analysis_df['HGNC_ID'] = hgnc_gene_id_symbol_analysis_df['HGNC_ID'].apply(lambda x: list(map(str, x)) if isinstance(x, set) else [])
hgnc_gene_id_symbol_analysis_df = hgnc_gene_id_symbol_analysis_df.explode('HGNC_ID').reset_index(drop=True)
hgnc_gene_id_symbol_analysis_df

# %% [markdown]
# Example of a gene record that has an OTTHUM prefix alias that is not captured in the Vega IDs curated by HGNC

# %%
hgnc_gene_id_symbol_analysis_df.loc[hgnc_gene_id_symbol_analysis_df["HGNC_ID"] == "HGNC:26764"]

# %%
hgnc_associated_ids_df.loc[hgnc_associated_ids_df["HGNC ID"] == "HGNC:26764"]

# %%
def match_alias_to_hgnc_associated_ids(analysis_df, associated_id_df):
    # Make copies to avoid modifying originals
    analysis_df = analysis_df.copy()
    associated_id_df = associated_id_df.copy()

    # Ensure strings and strip spaces
    analysis_df['HGNC_ID'] = analysis_df['HGNC_ID'].astype(str).str.strip()
    analysis_df['alias_symbol'] = analysis_df['alias_symbol'].astype(str).str.strip()
    associated_id_df['HGNC ID'] = associated_id_df['HGNC ID'].astype(str).str.strip()
    associated_id_df['associated_id'] = associated_id_df['associated_id'].astype(str).str.strip()
    associated_id_df['source'] = associated_id_df['source'].astype(str).str.strip()

    analysis_df['alias_symbol_upper'] = analysis_df['alias_symbol'].str.upper()
    associated_id_df['associated_id_upper'] = associated_id_df['associated_id'].str.upper()

    # Merge on HGNC_ID and alias_symbol matching associated_id
    merged = analysis_df.merge(
        associated_id_df,
        how='left',
        left_on=['HGNC_ID', 'alias_symbol_upper'],
        right_on=['HGNC ID', 'associated_id_upper']
    )

    # Gene Identifier Match = True if a match occurred
    merged['Gene Identifier Match'] = merged['associated_id'].notna()

    # Rename to match expected output columns
    merged = merged.rename(columns={'source': 'associated_source'})

    # Drop merge helper column
    merged = merged.drop(columns=['HGNC ID', 'alias_symbol_upper', 'associated_id_upper'], errors='ignore')

    return merged

# %%
hgnc_gene_id_symbol_analysis_df = match_alias_to_hgnc_associated_ids(hgnc_gene_id_symbol_analysis_df, hgnc_associated_ids_df)
hgnc_gene_id_symbol_analysis_df = hgnc_gene_id_symbol_analysis_df[hgnc_gene_id_symbol_analysis_df['alias_symbol'].notna() & (hgnc_gene_id_symbol_analysis_df['alias_symbol'].str.strip() != '<NA>')]
hgnc_gene_id_symbol_analysis_df['Gene Identifier Match'].value_counts()

# %%
vega_id_df = hgnc_associated_ids_df.loc[hgnc_associated_ids_df["source"] == "Vega IDs"]
vega_id_set = set(vega_id_df['associated_id'].dropna())
len(vega_id_set)

# %% [markdown]
# Are there any Vega IDs that are used for multiple gene records? Yes

# %%
vega_id_df.loc[vega_id_df['associated_id'].duplicated(keep=False)]

# %% [markdown]
# Are there any collisions between the OTTHUM prefix aliases? No

# %%
records_with_OTTHUM_prefix_alias_df = hgnc_gene_id_symbol_analysis_df.loc[hgnc_gene_id_symbol_analysis_df["alias_symbol"].str.startswith("OTTHUM")]

# %%
records_with_OTTHUM_prefix_alias_df.loc[records_with_OTTHUM_prefix_alias_df["alias_symbol"].duplicated(keep=False)]

# %% [markdown]
# how many aliases are OTTHUM prefix aliases?

# %%
OTTHUM_prefix_alias_set = set(records_with_OTTHUM_prefix_alias_df['alias_symbol'].dropna())
len(OTTHUM_prefix_alias_set)

# %% [markdown]
# how many records have a OTTHUM prefix alias?

# %%
hgnc_ids_w_OTTHUM_alias = set(records_with_OTTHUM_prefix_alias_df['HGNC_ID'].dropna())
len(hgnc_ids_w_OTTHUM_alias)

# %% [markdown]
# Are there gene records with more than one OTTHUM prefix aliases?

# %%
records_with_OTTHUM_prefix_alias_df[records_with_OTTHUM_prefix_alias_df['HGNC_ID'].duplicated(keep=False)]

# %% [markdown]
# how many records does HGNC map to Vega IDs?

# %%
hgnc_ids_w_vega_id = set(vega_id_df['HGNC ID'].dropna())
len(hgnc_ids_w_vega_id)

# %% [markdown]
# how many of the OTTHUM prefix aliases are captured using the HGNC Vega ID mappings?

# %%
hgnc_vega_match_df = records_with_OTTHUM_prefix_alias_df.loc[records_with_OTTHUM_prefix_alias_df['associated_source'] == "Vega IDs"]
hgnc_vega_match_set = set(hgnc_vega_match_df['alias_symbol'].dropna())
len(hgnc_vega_match_set)

# %%
hgnc_id_vega_match_set = set(hgnc_vega_match_df['HGNC_ID'].dropna())
len(hgnc_id_vega_match_set)

# %%
OTTH_aliases_not_captured_set = OTTHUM_prefix_alias_set - hgnc_vega_match_set
len(OTTH_aliases_not_captured_set)

# %% [markdown]
# How many records contain an OTTHUM prefix alias AND a mapped Vega ID?

# %%
records_with_OTTHUM_prefix_alias_df.loc[records_with_OTTHUM_prefix_alias_df['HGNC_ID'].isin(hgnc_ids_w_vega_id), 'HGNC_ID'].nunique()

# %% [markdown]
# For records containing an OTTHUM prefix alias AND a mapped Vega ID, how many have mismatches between the alias and the Vega ID?

# %%
records_with_OTTHUM_prefix_alias_df.loc[
    (records_with_OTTHUM_prefix_alias_df['HGNC_ID'].isin(hgnc_ids_w_vega_id)) &
    (~records_with_OTTHUM_prefix_alias_df['Gene Identifier Match']),
    'HGNC_ID'
].nunique()

# %%
records_with_OTTHUM_prefix_alias_df.loc[
    (records_with_OTTHUM_prefix_alias_df['HGNC_ID'].isin(hgnc_ids_w_vega_id)) &
    (~records_with_OTTHUM_prefix_alias_df['Gene Identifier Match'])]

# %% [markdown]
# Add match = True if alias has associated source prefix

# %%
suffix_condition = lambda s: len(s) >= 6 and s[0].isalpha() and s[1:].isdigit() and len(s[1:]) >= 5

# %%
hgnc_gene_id_symbol_analysis_df[["Gene Identifier Match", "associated_source"]] = hgnc_gene_id_symbol_analysis_df.apply(
    lambda row: match_alias_to_gene_identifier_by_prefix(
        row,
        "Gene Identifier Match",
        "alias_symbol",
        "associated_source",
        "OTTHUM",
        suffix_condition
    ),
    axis=1,
    result_type='expand'
)
hgnc_gene_id_symbol_analysis_df

# %%
hgnc_gene_id_symbol_analysis_df.loc[hgnc_gene_id_symbol_analysis_df["associated_source"] == "OTTHUM prefix"]

# %%
CCDS_NR_suffix_condition = lambda s: sum(c.isdigit() for c in s) >= 5 and all(c.isdigit() or c == '.' for c in s)

# %%
hgnc_gene_id_symbol_analysis_df[["Gene Identifier Match", "associated_source"]] = hgnc_gene_id_symbol_analysis_df.apply(
    lambda row: match_alias_to_gene_identifier_by_prefix(
        row,
        "Gene Identifier Match",
        "alias_symbol",
        "associated_source",
        "NR_",
        CCDS_NR_suffix_condition
    ),
    axis=1,
    result_type='expand'
)
hgnc_gene_id_symbol_analysis_df

# %%
hgnc_gene_id_symbol_analysis_df[["Gene Identifier Match", "associated_source"]] = hgnc_gene_id_symbol_analysis_df.apply(
    lambda row: match_alias_to_gene_identifier_by_prefix(
        row,
        "Gene Identifier Match",
        "alias_symbol",
        "associated_source",
        "CCDS",
        CCDS_NR_suffix_condition
    ),
    axis=1,
    result_type='expand'
)
hgnc_gene_id_symbol_analysis_df

# %%
hgnc_gene_id_symbol_analysis_df.loc[hgnc_gene_id_symbol_analysis_df["associated_source"] == "NR_ prefix"]

# %%
hgnc_gene_id_symbol_analysis_df.loc[hgnc_gene_id_symbol_analysis_df["associated_source"] == "CCDS prefix"]

# %%
hgnc_gene_id_symbol_analysis_df["associated_source"].value_counts()

# %% [markdown]
# ## <a id='toc12_3_'></a>[NCBI](#toc0_)

# %%
raw_ncbi_gene_info_df = pd.read_csv(
    "../input/Homo_sapiens.gene_info20250625",
    sep="\t",
    usecols=["GeneID", "dbXrefs"]  # replace with actual column names
)
raw_ncbi_gene_info_df

# %%
ncbi_gene_info_df = raw_ncbi_gene_info_df.copy()
ncbi_gene_info_df['dbXrefs'] = raw_ncbi_gene_info_df['dbXrefs'].str.split('|')
ncbi_gene_info_df = ncbi_gene_info_df.explode('dbXrefs')
ncbi_gene_info_df

# %%
ncbi_gene_info_df = ncbi_gene_info_df.replace('-', np.nan)
ncbi_gene_info_df = ncbi_gene_info_df.dropna()
ncbi_gene_info_df

# %%
counts = ncbi_gene_info_df['dbXrefs'].str[:15].value_counts()
print(counts)

# %%
imgt_gene_db_df = ncbi_gene_info_df.loc[ncbi_gene_info_df["dbXrefs"].str.startswith("IMGT/GENE-DB:")]
imgt_gene_db_df['dbXrefs'] = imgt_gene_db_df['dbXrefs'].str.removeprefix('IMGT/GENE-DB:')
imgt_gene_db_df = imgt_gene_db_df.rename(columns={'dbXrefs': 'IMGT/GENE-DB ID'})
imgt_gene_db_df

# %%
raw_ncbi_gene2vega_Vega_protein_identifier_df = pd.read_csv(
    "../input/gene2vega20251007",
    sep="\t",
    usecols=["GeneID", "Vega_protein_identifier"]  # replace with actual column names
)
raw_ncbi_gene2vega_Vega_protein_identifier_df

# %%
ncbi_gene2vega_Vega_protein_identifier_df = raw_ncbi_gene2vega_Vega_protein_identifier_df.replace('-', np.nan)

# %%
ncbi_gene2vega_Vega_protein_identifier_df = ncbi_gene2vega_Vega_protein_identifier_df.dropna(subset=['Vega_protein_identifier'])

# %%
raw_ncbi_gene2vega_Vega_rna_identifier_df = pd.read_csv(
    "../input/gene2vega20251007",
    sep="\t",
    usecols=["GeneID", "Vega_rna_identifier"]  # replace with actual column names
)
raw_ncbi_gene2vega_Vega_rna_identifier_df

# %%
ncbi_gene2vega_Vega_rna_identifier_df = raw_ncbi_gene2vega_Vega_rna_identifier_df.replace('-', np.nan)

# %%
ncbi_gene2vega_Vega_rna_identifier_df = ncbi_gene2vega_Vega_rna_identifier_df.dropna(subset=['Vega_rna_identifier'])

# %%
raw_ncbi_gene2vega_Vega_gene_identifier_df = pd.read_csv(
    "../input/gene2vega20251007",
    sep="\t",
    usecols=["GeneID", "Vega_gene_identifier"]  # replace with actual column names
)
raw_ncbi_gene2vega_Vega_gene_identifier_df

# %%
ncbi_gene2vega_Vega_gene_identifier_df = raw_ncbi_gene2vega_Vega_gene_identifier_df.replace('-', np.nan)

# %%
ncbi_gene2vega_Vega_gene_identifier_df = ncbi_gene2vega_Vega_gene_identifier_df.dropna(subset=['Vega_gene_identifier'])

# %%
raw_ncbi_gene2ensembl_Ensembl_gene_identifier_df = pd.read_csv(
    "../input/gene2ensembl20251007",
    sep="\t",
    usecols=["GeneID", "Ensembl_gene_identifier"]  # replace with actual column names
)
raw_ncbi_gene2ensembl_Ensembl_gene_identifier_df

# %%
ncbi_gene2ensembl_Ensembl_gene_identifier_df = raw_ncbi_gene2ensembl_Ensembl_gene_identifier_df.replace('-', np.nan)

# %%
ncbi_gene2ensembl_Ensembl_gene_identifier_df = ncbi_gene2ensembl_Ensembl_gene_identifier_df.dropna(subset=['Ensembl_gene_identifier'])

# %%
raw_ncbi_gene2accession_genomic_nucleotide_accession_df = pd.read_csv(
    "../input/gene2accession20251007",
    sep="\t",
    usecols=["GeneID", "genomic_nucleotide_accession.version"]
)
raw_ncbi_gene2accession_genomic_nucleotide_accession_df

# %%
ncbi_gene2accession_genomic_nucleotide_accession_df = raw_ncbi_gene2accession_genomic_nucleotide_accession_df.replace('-', np.nan)

# %%
ncbi_gene2accession_genomic_nucleotide_accession_df = ncbi_gene2accession_genomic_nucleotide_accession_df.dropna(subset=['genomic_nucleotide_accession.version'])

# %%
ncbi_gene_id_symbol_analysis_df = subset_genes_df.copy()
ncbi_gene_id_symbol_analysis_df['NCBI_ID'] = ncbi_gene_id_symbol_analysis_df['NCBI_ID'].apply(lambda x: list(map(str, x)) if isinstance(x, set) else [])
ncbi_gene_id_symbol_analysis_df = ncbi_gene_id_symbol_analysis_df.explode('NCBI_ID').reset_index(drop=True)
ncbi_gene_id_symbol_analysis_df['NCBI_ID'] = ncbi_gene_id_symbol_analysis_df['NCBI_ID'].str.removeprefix('GENE ID:')

# %%
def match_alias_to_ncbi_associated_ids(analysis_df, associated_id_df, associated_id_col):
    # Ensure all values are strings and stripped
    analysis_df = analysis_df.copy()
    associated_id_df = associated_id_df.copy()

    analysis_df['NCBI_ID'] = analysis_df['NCBI_ID'].astype(str).str.strip()
    analysis_df['alias_symbol'] = analysis_df['alias_symbol'].astype(str).str.strip()
    associated_id_df['GeneID'] = associated_id_df['GeneID'].astype(str).str.strip()
    associated_id_df[associated_id_col] = associated_id_df[associated_id_col].astype(str).str.strip()

    # Rename for merge
    temp = associated_id_df.rename(columns={associated_id_col: f'{associated_id_col}_id'})

    # Perform the merge
    merged = analysis_df.merge(
        temp[['GeneID', f'{associated_id_col}_id']],
        left_on=['NCBI_ID', 'alias_symbol'],
        right_on=['GeneID', f'{associated_id_col}_id'],
        how='left'
    )

    # Determine match
    merged[f'{associated_id_col} Match'] = merged['GeneID'].notna()

    return merged.drop(columns=['GeneID'], errors='ignore')

# %% [markdown]
# for some reason the kernel crashes right here if I try to run the whole nb but it i just run this section then it works fine?

# %%
ncbi_gene_id_symbol_analysis_gene2accession_genomic_nucleotide_accession_df = match_alias_to_ncbi_associated_ids(ncbi_gene_id_symbol_analysis_df, ncbi_gene2accession_genomic_nucleotide_accession_df,"genomic_nucleotide_accession.version")
ncbi_gene_id_symbol_analysis_gene2accession_genomic_nucleotide_accession_df = ncbi_gene_id_symbol_analysis_gene2accession_genomic_nucleotide_accession_df[ncbi_gene_id_symbol_analysis_gene2accession_genomic_nucleotide_accession_df['alias_symbol'].notna() & (ncbi_gene_id_symbol_analysis_gene2accession_genomic_nucleotide_accession_df['alias_symbol'].str.strip() != '<NA>')]
ncbi_gene_id_symbol_analysis_gene2accession_genomic_nucleotide_accession_df['genomic_nucleotide_accession.version Match'].value_counts()

# %%
ncbi_gene_id_symbol_analysis_gene2ensembl_Ensembl_gene_identifier_df = match_alias_to_ncbi_associated_ids(ncbi_gene_id_symbol_analysis_df, ncbi_gene2ensembl_Ensembl_gene_identifier_df,"Ensembl_gene_identifier")
ncbi_gene_id_symbol_analysis_gene2ensembl_Ensembl_gene_identifier_df = ncbi_gene_id_symbol_analysis_gene2ensembl_Ensembl_gene_identifier_df[ncbi_gene_id_symbol_analysis_gene2ensembl_Ensembl_gene_identifier_df['alias_symbol'].notna() & (ncbi_gene_id_symbol_analysis_gene2ensembl_Ensembl_gene_identifier_df['alias_symbol'].str.strip() != '<NA>')]
ncbi_gene_id_symbol_analysis_gene2ensembl_Ensembl_gene_identifier_df['Ensembl_gene_identifier Match'].value_counts()

# %%
ncbi_gene_id_symbol_analysis_gene2vega_Vega_gene_identifier_df = match_alias_to_ncbi_associated_ids(ncbi_gene_id_symbol_analysis_df, ncbi_gene2vega_Vega_gene_identifier_df,"Vega_gene_identifier")
ncbi_gene_id_symbol_analysis_gene2vega_Vega_gene_identifier_df = ncbi_gene_id_symbol_analysis_gene2vega_Vega_gene_identifier_df[ncbi_gene_id_symbol_analysis_gene2vega_Vega_gene_identifier_df['alias_symbol'].notna() & (ncbi_gene_id_symbol_analysis_gene2vega_Vega_gene_identifier_df['alias_symbol'].str.strip() != '<NA>')]
ncbi_gene_id_symbol_analysis_gene2vega_Vega_gene_identifier_df['Vega_gene_identifier Match'].value_counts()

# %%
ncbi_gene_id_symbol_analysis_gene2vega_Vega_rna_identifier_df = match_alias_to_ncbi_associated_ids(ncbi_gene_id_symbol_analysis_df, ncbi_gene2vega_Vega_rna_identifier_df,"Vega_rna_identifier")
ncbi_gene_id_symbol_analysis_gene2vega_Vega_rna_identifier_df = ncbi_gene_id_symbol_analysis_gene2vega_Vega_rna_identifier_df[ncbi_gene_id_symbol_analysis_gene2vega_Vega_rna_identifier_df['alias_symbol'].notna() & (ncbi_gene_id_symbol_analysis_gene2vega_Vega_rna_identifier_df['alias_symbol'].str.strip() != '<NA>')]
ncbi_gene_id_symbol_analysis_gene2vega_Vega_rna_identifier_df['Vega_rna_identifier Match'].value_counts()

# %%
ncbi_gene_id_symbol_analysis_gene2vega_Vega_protein_identifier_df = match_alias_to_ncbi_associated_ids(ncbi_gene_id_symbol_analysis_df, ncbi_gene2vega_Vega_protein_identifier_df,"Vega_protein_identifier")
ncbi_gene_id_symbol_analysis_gene2vega_Vega_protein_identifier_df = ncbi_gene_id_symbol_analysis_gene2vega_Vega_protein_identifier_df[ncbi_gene_id_symbol_analysis_gene2vega_Vega_protein_identifier_df['alias_symbol'].notna() & (ncbi_gene_id_symbol_analysis_gene2vega_Vega_protein_identifier_df['alias_symbol'].str.strip() != '<NA>')]
ncbi_gene_id_symbol_analysis_gene2vega_Vega_protein_identifier_df['Vega_protein_identifier Match'].value_counts()

# %%
ncbi_gene_id_symbol_analysis_imgt_gene_db_df = match_alias_to_ncbi_associated_ids(ncbi_gene_id_symbol_analysis_df, imgt_gene_db_df,"IMGT/GENE-DB ID")
ncbi_gene_id_symbol_analysis_imgt_gene_db_df = ncbi_gene_id_symbol_analysis_imgt_gene_db_df[ncbi_gene_id_symbol_analysis_imgt_gene_db_df['alias_symbol'].notna() & (ncbi_gene_id_symbol_analysis_imgt_gene_db_df['alias_symbol'].str.strip() != '<NA>')]
ncbi_gene_id_symbol_analysis_imgt_gene_db_df['IMGT/GENE-DB ID Match'].value_counts()

# %%
ncbi_gene_id_symbol_analysis_gene2accession_genomic_nucleotide_accession_df_match = ncbi_gene_id_symbol_analysis_gene2accession_genomic_nucleotide_accession_df.loc[ncbi_gene_id_symbol_analysis_gene2accession_genomic_nucleotide_accession_df['genomic_nucleotide_accession.version Match']]
ncbi_gene_id_symbol_analysis_gene2accession_genomic_nucleotide_accession_df_match['source'] = 'Genomic Nucleotide Accession'
ncbi_gene_id_symbol_analysis_gene2accession_genomic_nucleotide_accession_df_match = ncbi_gene_id_symbol_analysis_gene2accession_genomic_nucleotide_accession_df_match.rename(columns={
    'genomic_nucleotide_accession.version_id': 'Gene Identifier',
    'genomic_nucleotide_accession.version Match':'Gene Identifier Match'
})[['primary_gene_symbol', 'alias_symbol','HGNC_ID','ENSG_ID','NCBI_ID','Gene Identifier','Gene Identifier Match','source']]

# %%
ncbi_gene_id_symbol_analysis_gene2ensembl_Ensembl_gene_identifier_df_match = ncbi_gene_id_symbol_analysis_gene2ensembl_Ensembl_gene_identifier_df.loc[ncbi_gene_id_symbol_analysis_gene2ensembl_Ensembl_gene_identifier_df['Ensembl_gene_identifier Match']]
ncbi_gene_id_symbol_analysis_gene2ensembl_Ensembl_gene_identifier_df_match['source'] = 'Ensembl Gene Identifier'
ncbi_gene_id_symbol_analysis_gene2ensembl_Ensembl_gene_identifier_df_match = ncbi_gene_id_symbol_analysis_gene2ensembl_Ensembl_gene_identifier_df_match.rename(columns={
    'Ensembl_gene_identifier_id': 'Gene Identifier',
    'Ensembl_gene_identifier Match':'Gene Identifier Match'
})[['primary_gene_symbol', 'alias_symbol','HGNC_ID','ENSG_ID','NCBI_ID','Gene Identifier','Gene Identifier Match','source']]

# %%
ncbi_gene_id_symbol_analysis_gene2vega_Vega_gene_identifier_df_match = ncbi_gene_id_symbol_analysis_gene2vega_Vega_gene_identifier_df.loc[ncbi_gene_id_symbol_analysis_gene2vega_Vega_gene_identifier_df['Vega_gene_identifier Match']]
ncbi_gene_id_symbol_analysis_gene2vega_Vega_gene_identifier_df_match['source'] = 'Vega Gene Identifier'
ncbi_gene_id_symbol_analysis_gene2vega_Vega_gene_identifier_df_match = ncbi_gene_id_symbol_analysis_gene2vega_Vega_gene_identifier_df_match.rename(columns={
    'Vega_gene_identifier_id': 'Gene Identifier',
    'Vega_gene_identifier Match':'Gene Identifier Match'
})[['primary_gene_symbol', 'alias_symbol','HGNC_ID','ENSG_ID','NCBI_ID','Gene Identifier','Gene Identifier Match','source']]

# %%
ncbi_gene_id_symbol_analysis_gene2vega_Vega_rna_identifier_df_match = ncbi_gene_id_symbol_analysis_gene2vega_Vega_rna_identifier_df.loc[ncbi_gene_id_symbol_analysis_gene2vega_Vega_rna_identifier_df['Vega_rna_identifier Match']]
ncbi_gene_id_symbol_analysis_gene2vega_Vega_rna_identifier_df_match['source'] = 'Vega RNA Identifier'
ncbi_gene_id_symbol_analysis_gene2vega_Vega_rna_identifier_df_match = ncbi_gene_id_symbol_analysis_gene2vega_Vega_rna_identifier_df_match.rename(columns={
    'Vega_rna_identifier_id': 'Gene Identifier',
    'Vega_rna_identifier Match':'Gene Identifier Match'
})[['primary_gene_symbol', 'alias_symbol','HGNC_ID','ENSG_ID','NCBI_ID','Gene Identifier','Gene Identifier Match','source']]

# %%
ncbi_gene_id_symbol_analysis_gene2vega_Vega_protein_identifier_df_match = ncbi_gene_id_symbol_analysis_gene2vega_Vega_protein_identifier_df.loc[ncbi_gene_id_symbol_analysis_gene2vega_Vega_protein_identifier_df['Vega_protein_identifier Match']]
ncbi_gene_id_symbol_analysis_gene2vega_Vega_protein_identifier_df_match['source'] = 'Vega Protein Identifier'
ncbi_gene_id_symbol_analysis_gene2vega_Vega_protein_identifier_df_match = ncbi_gene_id_symbol_analysis_gene2vega_Vega_protein_identifier_df_match.rename(columns={
    'Vega_protein_identifier_id': 'Gene Identifier',
    'Vega_protein_identifier Match':'Gene Identifier Match'
})[['primary_gene_symbol', 'alias_symbol','HGNC_ID','ENSG_ID','NCBI_ID','Gene Identifier','Gene Identifier Match','source']]

# %%
ncbi_gene_id_symbol_analysis_imgt_gene_db_df_match = ncbi_gene_id_symbol_analysis_imgt_gene_db_df.loc[ncbi_gene_id_symbol_analysis_imgt_gene_db_df['IMGT/GENE-DB ID Match']]
ncbi_gene_id_symbol_analysis_imgt_gene_db_df_match['source'] = 'IMGT/GENE-DB Identifier'
ncbi_gene_id_symbol_analysis_imgt_gene_db_df_match = ncbi_gene_id_symbol_analysis_imgt_gene_db_df_match.rename(columns={
    'IMGT/GENE-DB ID_id': 'Gene Identifier',
    'IMGT/GENE-DB ID Match':'Gene Identifier Match'
})[['primary_gene_symbol', 'alias_symbol','HGNC_ID','ENSG_ID','NCBI_ID','Gene Identifier','Gene Identifier Match','source']]

# %%
matched_ncbi_gene_id_symbol_analysis_df = pd.concat([ncbi_gene_id_symbol_analysis_gene2accession_genomic_nucleotide_accession_df_match, ncbi_gene_id_symbol_analysis_gene2ensembl_Ensembl_gene_identifier_df_match, ncbi_gene_id_symbol_analysis_gene2vega_Vega_gene_identifier_df_match,ncbi_gene_id_symbol_analysis_gene2vega_Vega_rna_identifier_df_match,ncbi_gene_id_symbol_analysis_gene2vega_Vega_protein_identifier_df_match,ncbi_gene_id_symbol_analysis_imgt_gene_db_df_match], ignore_index=True)
matched_ncbi_gene_id_symbol_analysis_df

# %%
ncbi_gene_id_symbol_analysis_df = ncbi_gene_id_symbol_analysis_df.merge(
    matched_ncbi_gene_id_symbol_analysis_df[['NCBI_ID', 'alias_symbol', 'Gene Identifier Match', 'source']],
    on=['NCBI_ID', 'alias_symbol'],
    how='left'
)

# %%
ncbi_gene_id_symbol_analysis_df['NCBI_ID'] = 'GENE ID:' + ncbi_gene_id_symbol_analysis_df['NCBI_ID'].astype(str)
ncbi_gene_id_symbol_analysis_df['NCBI_ID'] = ncbi_gene_id_symbol_analysis_df['NCBI_ID'].apply(
        lambda x: set(x.split(',')) if isinstance(x, str) and x else set() if x == '' else x
    )
ncbi_gene_id_symbol_analysis_df = ncbi_gene_id_symbol_analysis_df[ncbi_gene_id_symbol_analysis_df["Gene Identifier Match"].fillna(False)]
ncbi_gene_id_symbol_match_subset_genes_df = ncbi_gene_id_symbol_analysis_df.loc[ncbi_gene_id_symbol_analysis_df["Gene Identifier Match"]]

# %%
ncbi_gene_id_symbol_analysis_df.to_hdf(
    "../output/ncbi_gene_id_symbol_analysis_df.h5", key='df', mode='w'
)

# %%
ncbi_gene_id_symbol_match_subset_genes_df.to_hdf(
    "../output/ncbi_gene_id_symbol_match_subset_genes_df.h5", key='df', mode='w'
)

# %% [markdown]
# ## <a id='toc12_4_'></a>[Combine all three sources](#toc0_)

# %%
ensg_cols_to_convert = ["ENSG_ID", "HGNC_ID", "NCBI_ID"]

hgnc_cols_to_convert = ["ENSG_ID", "NCBI_ID"]

for col in ensg_cols_to_convert:
    ens_gene_id_symbol_analysis_df[col] = ens_gene_id_symbol_analysis_df[col].apply(
        lambda x: ','.join(sorted(x)) if isinstance(x, (set, tuple)) else str(x)
    )

for col in hgnc_cols_to_convert:
    hgnc_gene_id_symbol_analysis_df[col] = hgnc_gene_id_symbol_analysis_df[col].apply(
        lambda x: ','.join(sorted(x)) if isinstance(x, (set, tuple)) else str(x)
    )

for col in ensg_cols_to_convert:
    ncbi_gene_id_symbol_analysis_df[col] = ncbi_gene_id_symbol_analysis_df[col].apply(
        lambda x: ','.join(sorted(x)) if isinstance(x, (set, tuple)) else str(x)
    )

# %%
merge_keys = ens_gene_id_symbol_analysis_df.columns[:5].tolist()

# Merge the two dataframes on the first 5 columns
merged_df = pd.merge(ens_gene_id_symbol_analysis_df, hgnc_gene_id_symbol_analysis_df, on=merge_keys, suffixes=('_1', '_2'))
merged_df = pd.merge(
    merged_df,
    ncbi_gene_id_symbol_analysis_df,
    on=merge_keys,
    how='outer',
    suffixes=('', '_3') 
)
def combine_rows(row):
    a1, a2, a3 = row.get('Gene Identifier Match_1'), row.get('Gene Identifier Match_2'), row.get('Gene Identifier Match_3')
    b1, b2, b3 = row.get('matching_attribute'), row.get('associated_source'), row.get('associated_source_3')

    combined = []
    match = False

    for a, b in [(a1, b1), (a2, b2), (a3, b3)]:
        if a:
            match = True
            if isinstance(b, list):
                combined.extend(b)
            elif b and b != '<NA>':
                combined.append(b)

    if not combined:
        return (False, pd.NA)

    return (match, list(set(combined)))

# %%
# Apply logic row-wise
merged_df[['Gene Identifier Match', 'Identifier Match Source']] = merged_df.apply(combine_rows, axis=1, result_type='expand')

# Optional: Drop old A/B columns and keep only combined ones
gene_id_analysis_df = merged_df[merge_keys + ['Gene Identifier Match', 'Identifier Match Source']]

# %%
gene_id_analysis_df[ensg_cols_to_convert] = gene_id_analysis_df[ensg_cols_to_convert].applymap(
    lambda x: set(x.split(',')) if isinstance(x, str) and x else set() if x == '' else x
)

# %%
gene_id_analysis_df

# %%
gene_id_analysis_df["Gene Identifier Match"].value_counts()

# %%
gene_id_analysis_df.to_hdf(
    "../output/gene_id_analysis_df.h5", key='df', mode='w'
)

# %%
gene_id_match_subset_genes_df = gene_id_analysis_df.loc[gene_id_analysis_df["Gene Identifier Match"]]

# %%
gene_id_match_subset_genes_df.to_hdf(
    "../output/gene_id_match_subset_genes_df.h5", key='df', mode='w'
)

# %% [markdown]
# # <a id='toc15_'></a>[Withdrawn Ortholog](#toc0_)

# %%
mgi_withdrawn_symbol_analysis_df = subset_genes_df.copy()
# mgi_withdrawn_symbol_analysis_df['MGI Withdrawn Symbol Match'] = None
# mgi_withdrawn_symbol_analysis_df['MGI Withdrawn Symbol'] = None
mgi_withdrawn_symbol_analysis_df = mgi_withdrawn_symbol_analysis_df.dropna(subset=['alias_symbol'])

# %% [markdown]
# - https://www.informatics.jax.org/
# - Downloads
# -  MGI_EntrezGene.rpt

# %%
column_names = ["MGI Marker Accession ID",
                "Marker Symbol",
                "Status",
                "Marker Name",
                "cM Position",
                "Chromosome",
                "Type (Gene, DNA Segment, Other Genome Feature, Complex/Cluster/Region, microRNA)", 
                "Secondary Accession IDs (|-delimited)",
                "Entrez Gene ID",
                "Synonyms (|-delimited)",
                "Feature Types (|-delimited)",
                "Genome Coordinate Start",
                "Genome Coordinate End"	"Strand",
                "BioTypes(|-delimited)"]
dtype_dict = {'Entrez Gene ID': str}

mgi_entrez_df = pd.read_csv(
    "../input/MGI_EntrezGene.rpt.txt",
    sep="\t",
    header=None, 
    names=column_names,
    index_col=False,
    dtype=dtype_dict,
    usecols=["Marker Symbol", "Status", "Marker Name","Entrez Gene ID"]
)

# %%
mgi_entrez_df.loc[mgi_entrez_df["Marker Name"].str.contains("Asp")]
# Out:
#         Marker Symbol Status  \
# 154              nur7      W
# 155              Acy2      W
# 33439          Cited2      O
# 35571         Calmbp1      W
# 36081          Cited1      O
# 36889          Adprt2      W
# 42238          Cited4      O
# 46369   4631401G09Rik      W
# 46370        AA986886      W
# 46806          Kdelr2      O
# 46860   3110001L23Rik      W
# 46861        AI848629      W
# 46863   2310005F16Rik      W
# 46864        AW561901      W
# 48968   2300003P22Rik      W
# 49584          Kdelr1      O
# 50030   0610012D14Rik      W
# 50874        AB039977      W
# 56846   2900006N09Rik      W
# 68530        Nudc-ps1      O
# 69271   A530050D06Rik      W
# 69735          Kdelr3      O
# 83786   A830007L07Rik      W
# 197739         Asprl1      O
# 197740         Asprl2      O
# 197741         Asprl3      O
# 197742         Asprl4      O
#
#                                               Marker Name Entrez Gene ID
# ...

# %%
mgi_entrez_df.loc[mgi_entrez_df["Marker Symbol"] == "asp"]
# Out:
#     Marker Symbol Status         Marker Name Entrez Gene ID
# 523           asp      W  withdrawn, = asp-2            NaN

# %%
mgi_entrez_df.loc[mgi_entrez_df["Marker Symbol"] == "Calmbp1"]
# Out:
#       Marker Symbol Status        Marker Name Entrez Gene ID
# 35571       Calmbp1      W  withdrawn, = Aspm            NaN

# %%
def match_alias_to_mgi_withdrawn_symbols(analysis_df, mgi_df):
    """
    Match alias symbols to withdrawn MGI symbols and verify that the
    corresponding primary gene symbol is referenced in the MGI marker name.

    :param analysis_df: DataFrame containing at least the columns
        ``alias_symbol`` and ``primary_gene_symbol``.
    :param mgi_df: MGI marker DataFrame containing the columns
        ``Marker Symbol``, ``Marker Name``, and ``Status``.
    :return: A copy of ``analysis_df`` with the following additional columns:
        - ``MGI Withdrawn Symbol``: Matching withdrawn MGI symbol, if found.
        - ``Marker Name``: Name associated with the withdrawn MGI symbol.
        - ``MGI Withdrawn Symbol Match``: Boolean indicating whether both the
          withdrawn symbol matched the alias symbol and the primary gene symbol
          was found within the marker name.
    """
    # Copy inputs to avoid modifying original data
    analysis_df = analysis_df.copy()
    mgi_df = mgi_df.copy()

    # Standardize and strip strings
    analysis_df["alias_symbol"] = (
        analysis_df["alias_symbol"].astype(str).str.strip().str.upper()
    )
    analysis_df["primary_gene_symbol"] = (
        analysis_df["primary_gene_symbol"].astype(str).str.strip().str.upper()
    )

    mgi_df["Marker Symbol"] = (
        mgi_df["Marker Symbol"].astype(str).str.strip().str.upper()
    )
    mgi_df["Marker Name"] = mgi_df["Marker Name"].astype(str).str.strip()
    mgi_df["Status"] = mgi_df["Status"].astype(str).str.strip()

    # Filter to withdrawn symbols
    withdrawn_mgi_df = mgi_df[mgi_df["Status"] == "W"]

    # Rename for clarity before merge
    temp = withdrawn_mgi_df.rename(
        columns={"Marker Symbol": "MGI Withdrawn Symbol"}
    )

    # Perform left merge on alias symbol
    merged = analysis_df.merge(
        temp[["MGI Withdrawn Symbol", "Marker Name"]],
        left_on="alias_symbol",
        right_on="MGI Withdrawn Symbol",
        how="left",
    )

    # Match only if the primary gene symbol appears in the Marker Name
    primary_in_marker_name = merged.apply(
        lambda row: (
            pd.notna(row["Marker Name"])
            and row["primary_gene_symbol"] in row["Marker Name"].upper()
        ),
        axis=1,
    )

    # Final match indicator
    merged["MGI Withdrawn Symbol Match"] = (
        merged["MGI Withdrawn Symbol"].notna()
        & primary_in_marker_name
    )

    return merged

# %%
mgi_withdrawn_symbol_analysis_df = match_alias_to_mgi_withdrawn_symbols(mgi_withdrawn_symbol_analysis_df, mgi_entrez_df)
mgi_withdrawn_symbol_analysis_df
# Out:
#       primary_gene_symbol  alias_symbol       HGNC_ID            ENSG_ID  \
# 0              A-GAMMA3'E     A-GAMMA-E            {}                 {}
# 1                    A1BG           A1B      {HGNC:5}  {ENSG00000121410}
# 2                    A1BG           ABG      {HGNC:5}  {ENSG00000121410}
# 3                    A1BG           GAB      {HGNC:5}  {ENSG00000121410}
# 4                    A1BG      HYST2477      {HGNC:5}  {ENSG00000121410}
# ...                   ...           ...           ...                ...
# 98618               ZZEF1      FLJ10821  {HGNC:29027}  {ENSG00000074755}
# 98619               ZZEF1      KIAA0399  {HGNC:29027}  {ENSG00000074755}
# 98620               ZZEF1          ZZZ4  {HGNC:29027}  {ENSG00000074755}
# 98621                ZZZ3         ATAC1  {HGNC:24523}  {ENSG00000036549}
# 98622                ZZZ3  DKFZP564I052  {HGNC:24523}  {ENSG00000036549}
#
#                    NCBI_ID MGI Withdrawn Symbol Marker Name  \
# ...

# %%
mgi_withdrawn_symbol_analysis_df["MGI Withdrawn Symbol Match"].value_counts()
# Out:
# MGI Withdrawn Symbol Match
# False    94171
# True      4452
# Name: count, dtype: int64

# %%
mgi_withdrawn_symbol_analysis_df.loc[mgi_withdrawn_symbol_analysis_df["alias_symbol"] == "CALMBP1"]
# Out:
#      primary_gene_symbol alias_symbol       HGNC_ID            ENSG_ID  \
# 5022                ASPM      CALMBP1  {HGNC:19048}  {ENSG00000066279}
# 5023                ASPM      CALMBP1  {HGNC:19048}  {ENSG00000066279}
#
#                NCBI_ID MGI Withdrawn Symbol        Marker Name  \
# 5022  {GENE ID:259266}              CALMBP1  withdrawn, = Aspm
# 5023  {GENE ID:259266}              CALMBP1  withdrawn, = Aspm
#
#       MGI Withdrawn Symbol Match
# 5022                        True
# 5023                        True

# %%
mgi_withdrawn_symbol_match_subset_genes_df = mgi_withdrawn_symbol_analysis_df[mgi_withdrawn_symbol_analysis_df["MGI Withdrawn Symbol Match"]]

# %%
mgi_withdrawn_symbol_analysis_df.to_hdf(
    "../output/mgi_withdrawn_symbol_analysis_df.h5", key='df', mode='w'
)
# Out:
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_36639/2907572110.py:1: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block1_values] [items->Index(['primary_gene_symbol', 'alias_symbol', 'HGNC_ID', 'ENSG_ID', 'NCBI_ID',
#        'MGI Withdrawn Symbol', 'Marker Name'],
#       dtype='object')]
#
#   mgi_withdrawn_symbol_analysis_df.to_hdf(

# %%
mgi_withdrawn_symbol_match_subset_genes_df.to_hdf(
    "../output/mgi_withdrawn_symbol_match_subset_genes_df.h5", key='df', mode='w'
)
# Out:
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_36639/3438113495.py:1: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block1_values] [items->Index(['primary_gene_symbol', 'alias_symbol', 'HGNC_ID', 'ENSG_ID', 'NCBI_ID',
#        'MGI Withdrawn Symbol', 'Marker Name'],
#       dtype='object')]
#
#   mgi_withdrawn_symbol_match_subset_genes_df.to_hdf(

# %% [markdown]
# # <a id='toc14_'></a>[LLM Prediction: Alternate Abbreviation Symbol](#toc0_)

# %%
subset_genes_df = pl.read_csv("../output/subset_genes_df.csv")

# %%
def parse_hgnc(x):
    return list(ast.literal_eval(x)) if x else []

# %%
df_w_names = subset_genes_df.with_columns(
    pl.col("HGNC_ID").map_elements(
        parse_hgnc,
        return_dtype=pl.List(pl.Utf8)
    ).alias("HGNC_list")
)

# %%
flj_clone_symbol_match_subset_genes_df = pd.read_hdf("../output/flj_clone_symbol_match_subset_genes_df.h5", key="df")
flj_clone_symbol_match_subset_genes_df = pl.from_pandas(flj_clone_symbol_match_subset_genes_df)

# %%
gene_id_match_subset_genes_df = pd.read_hdf("../output/gene_id_match_subset_genes_df.h5", key="df")
gene_id_match_subset_genes_df = pl.from_pandas(gene_id_match_subset_genes_df)

# %%
filtered_df_w_names = df_w_names.join(
    pl.concat([
        flj_clone_symbol_match_subset_genes_df.select(["primary_gene_symbol", "alias_symbol"]),
        gene_id_match_subset_genes_df.select(["primary_gene_symbol", "alias_symbol"])
    ]).unique(),
    on=["primary_gene_symbol", "alias_symbol"],
    how="anti"
)

# %%
hgnc = (
    pl.scan_csv(
        "../input/hgnc_complete_set20260703.txt",
        separator="\t",
    )
    .select(["hgnc_id", "name"])
    .collect()
)

df_w_names = (
    df_w_names
    .with_columns(
        pl.when(pl.col("HGNC_list").list.len() == 1)
        .then(pl.col("HGNC_list").list.first())
        .otherwise(None)
        .alias("hgnc_id")
    )
    .join(hgnc, on="hgnc_id", how="left")
    .rename({"name": "gene_name"})
    .drop(["HGNC_list", "hgnc_id"])
)

# %%
df_w_names = df_w_names.filter(pl.col("gene_name").is_not_null())

# %%
df_w_names.write_csv("../output/df_w_names.csv")

# %%
df_w_names = pl.read_csv("../output/df_w_names.csv")

# %%
df_w_names = df_w_names.with_columns(
        pl.lit(None).alias("captured_category_list")
    )

# %%
df_w_names = df_w_names.rename({"alias_symbol": "gene_symbol"})

# %%
# alt_abbrev_symbol_analysis_df = annotate_alt_abbrev(df_w_names, 0.0, "v1")
# Out:
#   0%|          | 0/98316 [00:00<?, ?it/s]

# %%
# alt_abbrev_symbol_analysis_df = alt_abbrev_symbol_analysis_df.drop("captured_category_list")

# %%
alt_abbrev_symbol_analysis_df
# Out:
# shape: (98_316, 9)
# ┌───────┬────────────┬────────────┬────────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │       ┆ primary_ge ┆ gene_symbo ┆ HGNC_ID    ┆ … ┆ NCBI_ID   ┆ gene_name ┆ Alternate ┆ skip_reas │
# │ ---   ┆ ne_symbol  ┆ l          ┆ ---        ┆   ┆ ---       ┆ ---       ┆ Abbreviat ┆ on        │
# │ i64   ┆ ---        ┆ ---        ┆ str        ┆   ┆ str       ┆ str       ┆ ion       ┆ ---       │
# │       ┆ str        ┆ str        ┆            ┆   ┆           ┆           ┆ Symbol    ┆ str       │
# │       ┆            ┆            ┆            ┆   ┆           ┆           ┆ ---       ┆           │
# │       ┆            ┆            ┆            ┆   ┆           ┆           ┆ bool      ┆           │
# ╞═══════╪════════════╪════════════╪════════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 1     ┆ A1BG       ┆ A1B        ┆ {'HGNC:5'} ┆ … ┆ {'GENE    ┆ alpha-1-B ┆ true      ┆ null      │
# ...

# %%
# alt_abbrev_symbol_analysis_df.to_pandas().to_hdf(
#     "../output/alt_abbrev_symbol_analysis_df.h5",
#     key="df",
#     mode="w"
# )
# Out:
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_36639/1099267105.py:1: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block1_values] [items->Index(['primary_gene_symbol', 'gene_symbol', 'HGNC_ID', 'ENSG_ID', 'NCBI_ID',
#        'gene_name', 'Alternate Abbreviation Symbol', 'skip_reason'],
#       dtype='object')]
#
#   alt_abbrev_symbol_analysis_df.to_pandas().to_hdf(

# %%
alt_abbrev_symbol_analysis_df = pl.from_pandas(
    pd.read_hdf(
        "../output/alt_abbrev_symbol_analysis_df.h5",
        key="df",
    )
)

alt_abbrev_symbol_analysis_df
# Out:
# shape: (98_316, 9)
# ┌──────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ column_0 ┆ primary_g ┆ gene_symb ┆ HGNC_ID   ┆ … ┆ NCBI_ID   ┆ gene_name ┆ Alternate ┆ skip_reas │
# │ ---      ┆ ene_symbo ┆ ol        ┆ ---       ┆   ┆ ---       ┆ ---       ┆ Abbreviat ┆ on        │
# │ i64      ┆ l         ┆ ---       ┆ str       ┆   ┆ str       ┆ str       ┆ ion       ┆ ---       │
# │          ┆ ---       ┆ str       ┆           ┆   ┆           ┆           ┆ Symbol    ┆ str       │
# │          ┆ str       ┆           ┆           ┆   ┆           ┆           ┆ ---       ┆           │
# │          ┆           ┆           ┆           ┆   ┆           ┆           ┆ bool      ┆           │
# ╞══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 1        ┆ A1BG      ┆ A1B       ┆ {'HGNC:5' ┆ … ┆ {'GENE    ┆ alpha-1-B ┆ true      ┆ null      │
# ...

# %%
alt_abbrev_symbol_analysis_df = alt_abbrev_symbol_analysis_df.rename({"gene_symbol": "alias_symbol"})

# %%
alt_abbrev_symbol_match_subset_genes_df = alt_abbrev_symbol_analysis_df.filter(
    pl.col("Alternate Abbreviation Symbol") == True
)
alt_abbrev_symbol_match_subset_genes_df
# Out:
# shape: (21_586, 9)
# ┌──────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ column_0 ┆ primary_g ┆ alias_sym ┆ HGNC_ID   ┆ … ┆ NCBI_ID   ┆ gene_name ┆ Alternate ┆ skip_reas │
# │ ---      ┆ ene_symbo ┆ bol       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ Abbreviat ┆ on        │
# │ i64      ┆ l         ┆ ---       ┆ str       ┆   ┆ str       ┆ str       ┆ ion       ┆ ---       │
# │          ┆ ---       ┆ str       ┆           ┆   ┆           ┆           ┆ Symbol    ┆ str       │
# │          ┆ str       ┆           ┆           ┆   ┆           ┆           ┆ ---       ┆           │
# │          ┆           ┆           ┆           ┆   ┆           ┆           ┆ bool      ┆           │
# ╞══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 1        ┆ A1BG      ┆ A1B       ┆ {'HGNC:5' ┆ … ┆ {'GENE    ┆ alpha-1-B ┆ true      ┆ null      │
# ...

# %%
alt_abbrev_symbol_match_subset_genes_df.to_pandas().to_hdf(
    "../output/alt_abbrev_symbol_match_subset_genes_df.h5",
    key="df",
    mode="w"
)
# Out:
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_36639/173325440.py:1: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block1_values] [items->Index(['primary_gene_symbol', 'alias_symbol', 'HGNC_ID', 'ENSG_ID', 'NCBI_ID',
#        'gene_name', 'skip_reason'],
#       dtype='object')]
#
#   alt_abbrev_symbol_match_subset_genes_df.to_pandas().to_hdf(
