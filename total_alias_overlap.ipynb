# %% [markdown]
# **Table of contents**<a id='toc0_'></a>
# - [ENSG](#toc1_)
#     - [Drop all columns besides ENSG_ID, gene_symbol, and alias_symbol](#toc1_1_1_)
#     - [How many total unique gene records are there](#toc1_1_2_)
#     - [Drop rows with NAN in alias_symbol](#toc1_1_3_)
#     - [Make each row in alias_symbol a set:](#toc1_1_4_)
#     - [Explode the alias sets so that it is one per row](#toc1_1_5_)
#     - [How many total unique aliases are there](#toc1_1_6_)
#     - [Pull out all the rows that have an alias symbol that can be found elsewhere](#toc1_1_7_)
#     - [Sort alias symbols alphabetically](#toc1_1_8_)
#     - [Number of records with an alias that is shared](#toc1_1_9_)
#     - [Count the number of times each multi-use alias is used](#toc1_1_10_)
#       - [Save as csv](#toc1_1_10_1_)
#     - [Put columns in different order to ephasize alias symbols instead of gene records](#toc1_1_11_)
#     - [Merge rows with matching alias symbols](#toc1_1_12_)
# - [HGNC](#toc2_)
#     - [Drop all columns besides ENSG_ID, gene_symbol, and alias_symbol](#toc2_1_1_)
#     - [How many total unique gene records are there](#toc2_1_2_)
#     - [Drop rows with NAN in alias_symbol](#toc2_1_3_)
#     - [Make each row in alias_symbol a set:](#toc2_1_4_)
#     - [Explode the alias sets so that it is one per row](#toc2_1_5_)
#     - [How many total unique aliases are there](#toc2_1_6_)
#     - [Pull out all the rows that have an alias symbol that can be found elsewhere](#toc2_1_7_)
#     - [Sort alias symbols alphabetically](#toc2_1_8_)
#     - [Number of records with an alias that is shared](#toc2_1_9_)
#     - [Count the number of times each multi-use alias is used](#toc2_1_10_)
#       - [Save as csv](#toc2_1_10_1_)
#     - [Put columns in different order to ephasize alias symbols instead of gene records](#toc2_1_11_)
#     - [Merge rows with matching alias symbols](#toc2_1_12_)
# - [NCBI Info](#toc3_)
#     - [Drop all columns besides ENSG_ID, gene_symbol, and alias_symbol](#toc3_1_1_)
#     - [How many total unique gene records are there](#toc3_1_2_)
#     - [Drop rows with - in alias_symbol](#toc3_1_3_)
#     - [Make each row in alias_symbol a set:](#toc3_1_4_)
#     - [Explode the alias sets so that it is one per row](#toc3_1_5_)
#     - [How many unique aliases are there](#toc3_1_6_)
#     - [Pull out all the rows that have an alias symbol that can be found elsewhere](#toc3_1_7_)
#     - [Sort alias symbols alphabetically](#toc3_1_8_)
#     - [Number of records with an alias that is shared](#toc3_1_9_)
#     - [Count the number of times each multi-use alias is used](#toc3_1_10_)
#     - [Put columns in different order to ephasize alias symbols instead of gene records](#toc3_1_11_)
#     - [Merge rows with matching alias symbols](#toc3_1_12_)
# - [Merge to create Alias Overlap Table 1 - Gene Symbol](#toc4_)
# - [Merge to create Alias Overlap Table 2 - Alias Symbol](#toc5_)
#
# <!-- vscode-jupyter-toc-config
# 	numbering=false
# 	anchor=true
# 	flat=false
# 	minLevel=1
# 	maxLevel=6
# 	/vscode-jupyter-toc-config -->
# <!-- THIS CELL WILL BE REPLACED ON TOC UPDATE. DO NOT WRITE YOUR TEXT IN THIS CELL -->

# %%
import pandas as pd
import numpy as np
import plotly.express as px
#new_alias-alias_collision_records

# %% [markdown]
# # <a id='toc1_'></a>[ENSG](#toc0_)

# %%
mini_ensg_df = pd.read_csv('Downloaded_files/mini_ensg_df.csv', dtype={'HGNC_ID': pd.Int64Dtype(), 'NCBI_ID': pd.Int64Dtype()})
mini_ensg_df
# Out:
#                ENSG_ID gene_symbol  HGNC_ID    NCBI_ID  \
# 0      ENSG00000000003      TSPAN6    11858       7105
# 1      ENSG00000000005        TNMD    17757      64102
# 2      ENSG00000000419        DPM1     3005       8813
# 3      ENSG00000000457       SCYL3    19285      57147
# 4      ENSG00000000460       FIRRM    25565      55732
# ...                ...         ...      ...        ...
# 75829  ENSG00000293596         NaN     <NA>  105372654
# 75830  ENSG00000293597   LINC00970    48730  101978719
# 75831  ENSG00000293599         NaN     <NA>       <NA>
# 75832  ENSG00000293600         NaN     <NA>  131768270
# 75833  ENSG00000293604       ORAI1    25896      84876
#
#                                    alias_symbol
# 0                         T245, TM4SF6, TSPAN-6
# 1          BRICD4, CHM1L, MYODULIN, TEM, TENDIN
# 2                                   CDGIE, MPDS
# 3                                 PACE-1, PACE1
# 4      APOLO1, C1ORF112, FLIP, FLJ10706, MEICA1
# ...                                         ...
# 75829                                       NaN
# 75830                                       NaN
# 75831                                       NaN
# 75832                                       NaN
# 75833                CRACM1, FLJ14466, TMEM142A
#
# [75834 rows x 5 columns]

# %% [markdown]
# ### <a id='toc1_1_2_'></a>[How many total unique gene records are there](#toc0_)

# %% [markdown]
# By ENSG ID

# %%
ensg_gene_id_set = set(mini_ensg_df['ENSG_ID'])
len(ensg_gene_id_set)
# Out:
# 70611

# %% [markdown]
# By gene symbol

# %%
ensg_gene_symbol_set = set(mini_ensg_df['gene_symbol'])
len(ensg_gene_symbol_set)
# Out:
# 41068

# %% [markdown]
# ### <a id='toc1_1_3_'></a>[Drop genes with no aliases](#toc0_)

# %%
mini_ensg_df = mini_ensg_df[mini_ensg_df["alias_symbol"].str.contains("NaN") == False]
mini_ensg_df
# Out:
#                ENSG_ID gene_symbol  HGNC_ID  NCBI_ID  \
# 0      ENSG00000000003      TSPAN6    11858     7105
# 1      ENSG00000000005        TNMD    17757    64102
# 2      ENSG00000000419        DPM1     3005     8813
# 3      ENSG00000000457       SCYL3    19285    57147
# 4      ENSG00000000460       FIRRM    25565    55732
# ...                ...         ...      ...      ...
# 75796  ENSG00000293549       HCG22     <NA>   285834
# 75798  ENSG00000293551    PRAMEF22    34393   653606
# 75801  ENSG00000293555    FAM169BP    26835   283777
# 75828  ENSG00000293595   SLC25A3P1    26869   163742
# 75833  ENSG00000293604       ORAI1    25896    84876
#
#                                    alias_symbol
# 0                         T245, TM4SF6, TSPAN-6
# 1          BRICD4, CHM1L, MYODULIN, TEM, TENDIN
# 2                                   CDGIE, MPDS
# 3                                 PACE-1, PACE1
# 4      APOLO1, C1ORF112, FLIP, FLJ10706, MEICA1
# ...                                         ...
# 75796                                   PBMUCL2
# 75798                                  PRAMEF3L
# 75801              FAM169B, FLJ39743, KIAA0888L
# 75828                                  FLJ40434
# 75833                CRACM1, FLJ14466, TMEM142A
#
# [31851 rows x 5 columns]

# %% [markdown]
# ### <a id='toc1_1_4_'></a>[Make each row in alias_symbol a set:](#toc0_)
#     covert to a list
#     make a set

# %%
mini_ensg_df['alias_symbol'] = mini_ensg_df['alias_symbol'].astype(str)
mini_ensg_df['alias_symbol'] = [x.split(',') for x in mini_ensg_df.alias_symbol]
mini_ensg_df['alias_symbol']=np.where(mini_ensg_df.alias_symbol=='','',mini_ensg_df.alias_symbol.map(set))
mini_ensg_df.head(1)
# Out:
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_73154/1602162191.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mini_ensg_df['alias_symbol'] = mini_ensg_df['alias_symbol'].astype(str)
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_73154/1602162191.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mini_ensg_df['alias_symbol'] = [x.split(',') for x in mini_ensg_df.alias_symbol]
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_73154/1602162191.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mini_ensg_df['alias_symbol']=np.where(mini_ensg_df.alias_symbol=='','',mini_ensg_df.alias_symbol.map(set))
#            ENSG_ID gene_symbol  HGNC_ID  NCBI_ID               alias_symbol
# 0  ENSG00000000003      TSPAN6    11858     7105  { TSPAN-6, T245,  TM4SF6}

# %% [markdown]
# ### <a id='toc1_1_5_'></a>[Explode the alias sets so that it is one per row](#toc0_)

# %%
mini_ensg_df = mini_ensg_df.explode('alias_symbol')
mini_ensg_df
# Out:
#                ENSG_ID gene_symbol  HGNC_ID  NCBI_ID alias_symbol
# 0      ENSG00000000003      TSPAN6    11858     7105      TSPAN-6
# 0      ENSG00000000003      TSPAN6    11858     7105         T245
# 0      ENSG00000000003      TSPAN6    11858     7105       TM4SF6
# 1      ENSG00000000005        TNMD    17757    64102       BRICD4
# 1      ENSG00000000005        TNMD    17757    64102        CHM1L
# ...                ...         ...      ...      ...          ...
# 75801  ENSG00000293555    FAM169BP    26835   283777     FLJ39743
# 75828  ENSG00000293595   SLC25A3P1    26869   163742     FLJ40434
# 75833  ENSG00000293604       ORAI1    25896    84876     TMEM142A
# 75833  ENSG00000293604       ORAI1    25896    84876       CRACM1
# 75833  ENSG00000293604       ORAI1    25896    84876     FLJ14466
#
# [73134 rows x 5 columns]

# %%
mini_ensg_df.loc[mini_ensg_df['alias_symbol'] == "CFM1" ]
# Out:
#                ENSG_ID gene_symbol  HGNC_ID  NCBI_ID alias_symbol
# 15693  ENSG00000183688       RFLNB    28705   359845         CFM1
# 66337  ENSG00000283979       RFLNB    28705   359845         CFM1

# %% [markdown]
# ### <a id='toc3_1_6_'></a>[How many unique aliases are there](#toc0_)

# %%
ensg_alias_symbol_set = set(mini_ensg_df['alias_symbol'])
ensg_alias_len = len(ensg_alias_symbol_set)
ensg_alias_len
# Out:
# 55938

# %% [markdown]
# ### Remove the duplicate instances of a primary gene symbol- alias pair

# %% [markdown]
# Example:

# %%
mini_ensg_df.loc[mini_ensg_df['gene_symbol'] == "RFLNB" ]
# Out:
#                ENSG_ID gene_symbol  HGNC_ID  NCBI_ID alias_symbol
# 15693  ENSG00000183688       RFLNB    28705   359845     MGC45871
# 15693  ENSG00000183688       RFLNB    28705   359845      FAM101B
# 15693  ENSG00000183688       RFLNB    28705   359845     REFILINB
# 15693  ENSG00000183688       RFLNB    28705   359845         CFM1
# 66337  ENSG00000283979       RFLNB    28705   359845     MGC45871
# 66337  ENSG00000283979       RFLNB    28705   359845      FAM101B
# 66337  ENSG00000283979       RFLNB    28705   359845     REFILINB
# 66337  ENSG00000283979       RFLNB    28705   359845         CFM1

# %%
mini_ensg_df = mini_ensg_df.drop_duplicates(subset=['gene_symbol', 'alias_symbol'], keep='first')

# %%
mini_ensg_df.loc[mini_ensg_df['gene_symbol'] == "RFLNB" ]
# Out:
#                ENSG_ID gene_symbol  HGNC_ID  NCBI_ID alias_symbol
# 15693  ENSG00000183688       RFLNB    28705   359845     MGC45871
# 15693  ENSG00000183688       RFLNB    28705   359845      FAM101B
# 15693  ENSG00000183688       RFLNB    28705   359845     REFILINB
# 15693  ENSG00000183688       RFLNB    28705   359845         CFM1

# %% [markdown]
# ### <a id='toc3_1_7_'></a>[Pull out all the rows that have an alias symbol that can be found elsewhere](#toc0_)

# %%
mini_ensg_df['alias_duplicates'] = mini_ensg_df.duplicated(subset= 'alias_symbol', keep=False)
aa_collision_ensg_df = mini_ensg_df[mini_ensg_df['alias_duplicates'] == True]
aa_collision_ensg_df = aa_collision_ensg_df.drop(['alias_duplicates'], axis=1)
aa_collision_ensg_df.head(5)
# Out:
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_73154/2021707324.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mini_ensg_df['alias_duplicates'] = mini_ensg_df.duplicated(subset= 'alias_symbol', keep=False)
#             ENSG_ID gene_symbol  HGNC_ID  NCBI_ID alias_symbol
# 4   ENSG00000000460       FIRRM    25565    55732         FLIP
# 8   ENSG00000001084        GCLC     4311     2729          GCS
# 12  ENSG00000001497       LAS1L    25726    81887         LAS1
# 13  ENSG00000001561       ENPP4     3359    22875      AP3AASE
# 15  ENSG00000001626        CFTR     1884     1080    DJ760C5.1

# %% [markdown]
# ### <a id='toc3_1_8_'></a>[Sort alias symbols alphabetically](#toc0_)

# %%
aa_collision_ensg_df = aa_collision_ensg_df.sort_values('alias_symbol')
aa_collision_ensg_df
# Out:
#                ENSG_ID gene_symbol  HGNC_ID  NCBI_ID alias_symbol
# 58193  ENSG00000275176       ACACA       84       31         ACC1
# 8000   ENSG00000140379      BCL2A1      991      597         ACC1
# 8000   ENSG00000140379      BCL2A1      991      597         ACC2
# 1354   ENSG00000076555       ACACB       85       32         ACC2
# 2085   ENSG00000097021       ACOT7    24157    11332          ACT
# ...                ...         ...      ...      ...          ...
# 24134  ENSG00000213339       QTRT1    23797    81890          TGT
# 6615   ENSG00000132388      UBE2G1    12482     7326         UBC7
# 15955  ENSG00000184787      UBE2G2    12483     7327         UBC7
# 11780  ENSG00000165828       PRAP1    23304   118471          UPA
# 5350   ENSG00000122861        PLAU     9052     5328          UPA
#
# [2573 rows x 5 columns]

# %%
#ensg_CD158b_alias_count_df.to_csv('../hgnc_CD158b_alias_count_df.csv')

# %% [markdown]
# ### <a id='toc3_1_9_'></a>[Number of records with an alias that is shared](#toc0_)

# %%
ensg_alias_alias_collision_primary_symbol_set = set(aa_collision_ensg_df['gene_symbol'])
len(ensg_alias_alias_collision_primary_symbol_set)
# Out:
# 2224

# %%
aa_collision_ensg_df['source'] = 'ENSG'
aa_collision_ensg_df
# Out:
#                ENSG_ID gene_symbol  HGNC_ID  NCBI_ID alias_symbol source
# 58193  ENSG00000275176       ACACA       84       31         ACC1   ENSG
# 8000   ENSG00000140379      BCL2A1      991      597         ACC1   ENSG
# 8000   ENSG00000140379      BCL2A1      991      597         ACC2   ENSG
# 1354   ENSG00000076555       ACACB       85       32         ACC2   ENSG
# 2085   ENSG00000097021       ACOT7    24157    11332          ACT   ENSG
# ...                ...         ...      ...      ...          ...    ...
# 24134  ENSG00000213339       QTRT1    23797    81890          TGT   ENSG
# 6615   ENSG00000132388      UBE2G1    12482     7326         UBC7   ENSG
# 15955  ENSG00000184787      UBE2G2    12483     7327         UBC7   ENSG
# 11780  ENSG00000165828       PRAP1    23304   118471          UPA   ENSG
# 5350   ENSG00000122861        PLAU     9052     5328          UPA   ENSG
#
# [2573 rows x 6 columns]

# %%
aa_collision_ensg_df.loc[aa_collision_ensg_df['alias_symbol'] == "RN5S3" ]
# Out:
# Empty DataFrame
# Columns: [ENSG_ID, gene_symbol, HGNC_ID, NCBI_ID, alias_symbol, source]
# Index: []

# %% [markdown]
# ### <a id='toc3_1_10_'></a>[Count the number of times each multi-use alias is used](#toc0_)

# %%
aa_collision_ensg_count_df = aa_collision_ensg_df.pivot_table(index = ['alias_symbol'], aggfunc ='size')
aa_collision_ensg_count_df = aa_collision_ensg_count_df.reset_index()
aa_collision_ensg_count_df.rename(columns={0:'num_gene_records'}, inplace=True )
aa_collision_ensg_count_df = aa_collision_ensg_count_df.sort_values('num_gene_records', ascending=False)
aa_collision_ensg_count_df.head(5)
# Out:
#      alias_symbol  num_gene_records
# 1091          MT1                10
# 1060         HOX1                10
# 1061         HOX2                 9
# 411           P40                 9
# 392           P18                 8

# %%
ensg_alias_alias_collision_set = set(aa_collision_ensg_count_df['alias_symbol'])
len(ensg_alias_alias_collision_set)
# Out:
# 1149

# %%
aa_collision_ensg_count_df.to_csv('../aa_collision_ensg_count_df.csv', index=True)

# %%
aa_collision_ensg_distribution_df = aa_collision_ensg_count_df.pivot_table(index = ['num_gene_records'], aggfunc ='size')
aa_collision_ensg_distribution_df = aa_collision_ensg_distribution_df.reset_index()
aa_collision_ensg_distribution_df.rename(columns={0:'num_alias_symbol'}, inplace=True )
aa_collision_ensg_distribution_df['percent_alias_symbol'] = ((aa_collision_ensg_distribution_df['num_alias_symbol'] / ensg_alias_len) * 100)
aa_collision_ensg_distribution_df.head()
# Out:
#    num_gene_records  num_alias_symbol  percent_alias_symbol
# 0                 2               980              1.751940
# 1                 3               117              0.209160
# 2                 4                31              0.055418
# 3                 5                 5              0.008938
# 4                 6                10              0.017877

# %%
ensg_alias_count_histogram_df = aa_collision_ensg_distribution_df.drop('num_alias_symbol', axis=1)
ensg_alias_count_histogram_df.head()
# Out:
#    num_gene_records  percent_alias_symbol
# 0                 2              1.751940
# 1                 3              0.209160
# 2                 4              0.055418
# 3                 5              0.008938
# 4                 6              0.017877

# %%
#px.bar(ensg_alias_count_histogram_df, x='num_gene_records', y='percent_alias_symbol')

# %%
aa_collision_ensg_distribution_df.to_csv('../aa_collision_ensg_distribution_df.csv', index=True)

# %% [markdown]
# #### <a id='toc1_1_10_1_'></a>[Save as csv](#toc0_)

# %%
#mini_ensg_df_explode.to_csv('../ensg_alias_overlap.csv', index=False)

# %% [markdown]
# ### <a id='toc1_1_11_'></a>[Put columns in different order to ephasize alias symbols instead of gene records](#toc0_)

# %%
aa_collision_ensg_df
# Out:
#                ENSG_ID gene_symbol  HGNC_ID  NCBI_ID alias_symbol source
# 58193  ENSG00000275176       ACACA       84       31         ACC1   ENSG
# 8000   ENSG00000140379      BCL2A1      991      597         ACC1   ENSG
# 8000   ENSG00000140379      BCL2A1      991      597         ACC2   ENSG
# 1354   ENSG00000076555       ACACB       85       32         ACC2   ENSG
# 2085   ENSG00000097021       ACOT7    24157    11332          ACT   ENSG
# ...                ...         ...      ...      ...          ...    ...
# 24134  ENSG00000213339       QTRT1    23797    81890          TGT   ENSG
# 6615   ENSG00000132388      UBE2G1    12482     7326         UBC7   ENSG
# 15955  ENSG00000184787      UBE2G2    12483     7327         UBC7   ENSG
# 11780  ENSG00000165828       PRAP1    23304   118471          UPA   ENSG
# 5350   ENSG00000122861        PLAU     9052     5328          UPA   ENSG
#
# [2573 rows x 6 columns]

# %%
aa_collision_ensg_df_2 = aa_collision_ensg_df[['alias_symbol', 'ENSG_ID', 'gene_symbol', 'source']]
aa_collision_ensg_df_2
# Out:
#       alias_symbol          ENSG_ID gene_symbol source
# 58193         ACC1  ENSG00000275176       ACACA   ENSG
# 8000          ACC1  ENSG00000140379      BCL2A1   ENSG
# 8000          ACC2  ENSG00000140379      BCL2A1   ENSG
# 1354          ACC2  ENSG00000076555       ACACB   ENSG
# 2085           ACT  ENSG00000097021       ACOT7   ENSG
# ...            ...              ...         ...    ...
# 24134          TGT  ENSG00000213339       QTRT1   ENSG
# 6615          UBC7  ENSG00000132388      UBE2G1   ENSG
# 15955         UBC7  ENSG00000184787      UBE2G2   ENSG
# 11780          UPA  ENSG00000165828       PRAP1   ENSG
# 5350           UPA  ENSG00000122861        PLAU   ENSG
#
# [2573 rows x 4 columns]

# %% [markdown]
# ### <a id='toc1_1_12_'></a>[Merge rows with matching alias symbols](#toc0_)

# %%
aa_collision_ensg_df_2 = aa_collision_ensg_df_2.drop_duplicates(subset = ["alias_symbol", "gene_symbol"], keep = 'first')

# %%
aa_collision_ensg_df_2 = aa_collision_ensg_df_2.applymap(str)
aa_collision_ensg_df_2
# Out:
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_73154/2500633515.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   aa_collision_ensg_df_2 = aa_collision_ensg_df_2.applymap(str)
#       alias_symbol          ENSG_ID gene_symbol source
# 58193         ACC1  ENSG00000275176       ACACA   ENSG
# 8000          ACC1  ENSG00000140379      BCL2A1   ENSG
# 8000          ACC2  ENSG00000140379      BCL2A1   ENSG
# 1354          ACC2  ENSG00000076555       ACACB   ENSG
# 2085           ACT  ENSG00000097021       ACOT7   ENSG
# ...            ...              ...         ...    ...
# 24134          TGT  ENSG00000213339       QTRT1   ENSG
# 6615          UBC7  ENSG00000132388      UBE2G1   ENSG
# 15955         UBC7  ENSG00000184787      UBE2G2   ENSG
# 11780          UPA  ENSG00000165828       PRAP1   ENSG
# 5350           UPA  ENSG00000122861        PLAU   ENSG
#
# [2573 rows x 4 columns]

# %%
aa_collision_ensg_df_2 = aa_collision_ensg_df_2.groupby('alias_symbol').agg({'ENSG_ID': ', '.join, 
                             'gene_symbol': ', '.join, 
                             'source':'first' }).reset_index()
aa_collision_ensg_df_2
# Out:
#      alias_symbol                           ENSG_ID       gene_symbol source
# 0            ACC1  ENSG00000275176, ENSG00000140379     ACACA, BCL2A1   ENSG
# 1            ACC2  ENSG00000140379, ENSG00000076555     BCL2A1, ACACB   ENSG
# 2             ACT  ENSG00000097021, ENSG00000196136   ACOT7, SERPINA3   ENSG
# 3          AGPAT9  ENSG00000153395, ENSG00000138678     LPCAT1, GPAT3   ENSG
# 4            AIP1  ENSG00000136848, ENSG00000187391     DAB2IP, MAGI2   ENSG
# ...           ...                               ...               ...    ...
# 1144    TCRBV15S1  ENSG00000276819, ENSG00000211750  TRBV15, TRBV24-1   ENSG
# 1145      TCRGV5P  ENSG00000228668, ENSG00000226212     TRGV5P, TRGV6   ENSG
# 1146          TGT  ENSG00000101557, ENSG00000213339      USP14, QTRT1   ENSG
# 1147         UBC7  ENSG00000132388, ENSG00000184787    UBE2G1, UBE2G2   ENSG
# 1148          UPA  ENSG00000165828, ENSG00000122861       PRAP1, PLAU   ENSG
#
# [1149 rows x 4 columns]

# %% [markdown]
# # <a id='toc2_'></a>[HGNC](#toc0_)

# %%
mini_hgnc_df = pd.read_csv('Downloaded_files/mini_hgnc_df.csv', dtype={'HGNC_ID': pd.Int64Dtype(), 'NCBI_ID': pd.Int64Dtype()})
mini_hgnc_df
# Out:
#                ENSG_ID gene_symbol  HGNC_ID    NCBI_ID  \
# 0      ENSG00000000003      TSPAN6    11858       7105
# 1      ENSG00000000005        TNMD    17757      64102
# 2      ENSG00000000419        DPM1     3005       8813
# 3      ENSG00000000457       SCYL3    19285      57147
# 4      ENSG00000000460       FIRRM    25565      55732
# ...                ...         ...      ...        ...
# 45641              NaN       ZNF97    13173       <NA>
# 45642              NaN       ZNFP1    13181       <NA>
# 45643              NaN       ZPAXP    51635  105373450
# 45644              NaN         ZRK    13193       <NA>
# 45645              NaN     ZWINTAS    13196       <NA>
#
#                                alias_symbol
# 0                             T245, TSPAN-6
# 1      myodulin, ChM1L, tendin, TEM, BRICD4
# 2                               MPDS, CDGIE
# 3                             PACE-1, PACE1
# 4            FLJ10706, Apolo1, FLIP, MEICA1
# ...                                     ...
# 45641                                   NaN
# 45642                                   NaN
# 45643                                 ZPX1P
# 45644                                   NaN
# 45645            MPP5, MPHOSPH5, NCRNA00018
#
# [45646 rows x 5 columns]

# %% [markdown]
# ### <a id='toc2_1_2_'></a>[How many total unique gene records are there](#toc0_)

# %% [markdown]
# By HGNC ID

# %%
hgnc_gene_id_set = set(mini_hgnc_df['HGNC_ID'])
len(hgnc_gene_id_set)
# Out:
# 45646

# %% [markdown]
# By gene symbol

# %%
hgnc_gene_symbol_set = set(mini_hgnc_df['gene_symbol'])
len(hgnc_gene_symbol_set)
# Out:
# 45646

# %% [markdown]
# ### <a id='toc2_1_3_'></a>[Drop genes with no aliases](#toc0_)

# %%
mini_hgnc_df = mini_hgnc_df[mini_hgnc_df["alias_symbol"].str.contains("NaN") == False]
mini_hgnc_df
# Out:
#                ENSG_ID gene_symbol  HGNC_ID    NCBI_ID  \
# 0      ENSG00000000003      TSPAN6    11858       7105
# 1      ENSG00000000005        TNMD    17757      64102
# 2      ENSG00000000419        DPM1     3005       8813
# 3      ENSG00000000457       SCYL3    19285      57147
# 4      ENSG00000000460       FIRRM    25565      55732
# ...                ...         ...      ...        ...
# 45632              NaN     ZNF78L2    13152       <NA>
# 45636              NaN       ZNF88    13163       <NA>
# 45638              NaN       ZNF94    13170       <NA>
# 45643              NaN       ZPAXP    51635  105373450
# 45645              NaN     ZWINTAS    13196       <NA>
#
#                                alias_symbol
# 0                             T245, TSPAN-6
# 1      myodulin, ChM1L, tendin, TEM, BRICD4
# 2                               MPDS, CDGIE
# 3                             PACE-1, PACE1
# 4            FLJ10706, Apolo1, FLIP, MEICA1
# ...                                     ...
# 45632                                   pT3
# 45636                                  HPF8
# 45638                                F11465
# 45643                                 ZPX1P
# 45645            MPP5, MPHOSPH5, NCRNA00018
#
# [22647 rows x 5 columns]

# %% [markdown]
# ### <a id='toc2_1_4_'></a>[Make each row in alias_symbol a set:](#toc0_)
#     covert to a list
#     make a set

# %%
mini_hgnc_df['alias_symbol'] = mini_hgnc_df['alias_symbol'].astype(str)
mini_hgnc_df['alias_symbol'] = [x.split(',') for x in mini_hgnc_df.alias_symbol]
mini_hgnc_df['alias_symbol']=np.where(mini_hgnc_df.alias_symbol=='','',mini_hgnc_df.alias_symbol.map(set))
mini_hgnc_df
# Out:
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_73154/1236743559.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mini_hgnc_df['alias_symbol'] = mini_hgnc_df['alias_symbol'].astype(str)
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_73154/1236743559.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mini_hgnc_df['alias_symbol'] = [x.split(',') for x in mini_hgnc_df.alias_symbol]
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_73154/1236743559.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mini_hgnc_df['alias_symbol']=np.where(mini_hgnc_df.alias_symbol=='','',mini_hgnc_df.alias_symbol.map(set))
#                ENSG_ID gene_symbol  HGNC_ID    NCBI_ID  \
# 0      ENSG00000000003      TSPAN6    11858       7105
# 1      ENSG00000000005        TNMD    17757      64102
# 2      ENSG00000000419        DPM1     3005       8813
# 3      ENSG00000000457       SCYL3    19285      57147
# 4      ENSG00000000460       FIRRM    25565      55732
# ...                ...         ...      ...        ...
# 45632              NaN     ZNF78L2    13152       <NA>
# 45636              NaN       ZNF88    13163       <NA>
# 45638              NaN       ZNF94    13170       <NA>
# 45643              NaN       ZPAXP    51635  105373450
# 45645              NaN     ZWINTAS    13196       <NA>
#
#                                      alias_symbol
# 0                                {T245,  TSPAN-6}
# 1      {myodulin,  ChM1L,  BRICD4,  TEM,  tendin}
# 2                                  {MPDS,  CDGIE}
# 3                                {PACE-1,  PACE1}
# 4             { Apolo1,  MEICA1,  FLIP, FLJ10706}
# ...                                           ...
# 45632                                       {pT3}
# 45636                                      {HPF8}
# 45638                                    {F11465}
# 45643                                     {ZPX1P}
# 45645              { NCRNA00018, MPP5,  MPHOSPH5}
#
# [22647 rows x 5 columns]

# %% [markdown]
# ### <a id='toc2_1_5_'></a>[Explode the alias sets so that it is one per row](#toc0_)

# %%
mini_hgnc_df = mini_hgnc_df.explode('alias_symbol')
mini_hgnc_df
# Out:
#                ENSG_ID gene_symbol  HGNC_ID    NCBI_ID alias_symbol
# 0      ENSG00000000003      TSPAN6    11858       7105         T245
# 0      ENSG00000000003      TSPAN6    11858       7105      TSPAN-6
# 1      ENSG00000000005        TNMD    17757      64102     myodulin
# 1      ENSG00000000005        TNMD    17757      64102        ChM1L
# 1      ENSG00000000005        TNMD    17757      64102       BRICD4
# ...                ...         ...      ...        ...          ...
# 45638              NaN       ZNF94    13170       <NA>       F11465
# 45643              NaN       ZPAXP    51635  105373450        ZPX1P
# 45645              NaN     ZWINTAS    13196       <NA>   NCRNA00018
# 45645              NaN     ZWINTAS    13196       <NA>         MPP5
# 45645              NaN     ZWINTAS    13196       <NA>     MPHOSPH5
#
# [44584 rows x 5 columns]

# %% [markdown]
# ### <a id='toc2_1_6_'></a>[How many total unique aliases are there](#toc0_)

# %%
hgnc_alias_symbol_set = set(mini_hgnc_df['alias_symbol'])
hgnc_alias_len = len(hgnc_alias_symbol_set)
hgnc_alias_len
# Out:
# 43770

# %% [markdown]
# ### Remove the duplicate instances of a primary gene symbol- alias pair

# %%
mini_hgnc_df = mini_hgnc_df.drop_duplicates(subset=['gene_symbol', 'alias_symbol'], keep='first')
mini_hgnc_df
# Out:
#                ENSG_ID gene_symbol  HGNC_ID    NCBI_ID alias_symbol
# 0      ENSG00000000003      TSPAN6    11858       7105         T245
# 0      ENSG00000000003      TSPAN6    11858       7105      TSPAN-6
# 1      ENSG00000000005        TNMD    17757      64102     myodulin
# 1      ENSG00000000005        TNMD    17757      64102        ChM1L
# 1      ENSG00000000005        TNMD    17757      64102       BRICD4
# ...                ...         ...      ...        ...          ...
# 45638              NaN       ZNF94    13170       <NA>       F11465
# 45643              NaN       ZPAXP    51635  105373450        ZPX1P
# 45645              NaN     ZWINTAS    13196       <NA>   NCRNA00018
# 45645              NaN     ZWINTAS    13196       <NA>         MPP5
# 45645              NaN     ZWINTAS    13196       <NA>     MPHOSPH5
#
# [44584 rows x 5 columns]

# %% [markdown]
# ### <a id='toc2_1_7_'></a>[Pull out all the rows that have an alias symbol that can be found elsewhere](#toc0_)

# %%
mini_hgnc_df['alias_duplicates'] = mini_hgnc_df.duplicated(subset= 'alias_symbol', keep=False)
aa_collision_hgnc_df = mini_hgnc_df[mini_hgnc_df['alias_duplicates'] == True]
aa_collision_hgnc_df = aa_collision_hgnc_df.drop(['alias_duplicates'], axis=1)
aa_collision_hgnc_df.head(5)
# Out:
#             ENSG_ID gene_symbol  HGNC_ID  NCBI_ID alias_symbol
# 4   ENSG00000000460       FIRRM    25565    55732         FLIP
# 8   ENSG00000001084        GCLC     4311     2729          GCS
# 13  ENSG00000001561       ENPP4     3359    22875      AP3Aase
# 22  ENSG00000002549        LAP3    18449    51056          LAP
# 39  ENSG00000003402       CFLAR     1876     8837         FLIP

# %% [markdown]
# ### <a id='toc2_1_8_'></a>[Sort alias symbols alphabetically](#toc0_)

# %%
aa_collision_hgnc_df = aa_collision_hgnc_df.sort_values('alias_symbol')
aa_collision_hgnc_df
# Out:
#                ENSG_ID gene_symbol  HGNC_ID  NCBI_ID alias_symbol
# 7761   ENSG00000139187       KLRG1     6380    10219          2F1
# 75     ENSG00000005022     SLC25A5    10991      292          2F1
# 10916  ENSG00000163220      S100A9    10499     6280       60B8AG
# 8398   ENSG00000143546      S100A8    10498     6279       60B8AG
# 10424  ENSG00000160226     CFAP410     1260      755           A2
# ...                ...         ...      ...      ...          ...
# 10537  ENSG00000161011      SQSTM1    11280     8878          p62
# 17080  ENSG00000196787      H2AC11     4737     8969       pH2A/f
# 28269  ENSG00000234816      H2AC5P     4728    10341       pH2A/f
# 39337  ENSG00000274962     TEX28P1    33356   728447         pTEX
# 39717  ENSG00000277008     TEX28P2    33357   653363         pTEX
#
# [1487 rows x 5 columns]

# %% [markdown]
# ### <a id='toc2_1_9_'></a>[Number of records with an alias that is shared](#toc0_)

# %%
hgnc_alias_alias_collision_primary_symbol_set = set(aa_collision_hgnc_df['gene_symbol'])
len(hgnc_alias_alias_collision_primary_symbol_set)
# Out:
# 1356

# %%
aa_collision_hgnc_df['source'] = 'HGNC'
aa_collision_hgnc_df
# Out:
#                ENSG_ID gene_symbol  HGNC_ID  NCBI_ID alias_symbol source
# 7761   ENSG00000139187       KLRG1     6380    10219          2F1   HGNC
# 75     ENSG00000005022     SLC25A5    10991      292          2F1   HGNC
# 10916  ENSG00000163220      S100A9    10499     6280       60B8AG   HGNC
# 8398   ENSG00000143546      S100A8    10498     6279       60B8AG   HGNC
# 10424  ENSG00000160226     CFAP410     1260      755           A2   HGNC
# ...                ...         ...      ...      ...          ...    ...
# 10537  ENSG00000161011      SQSTM1    11280     8878          p62   HGNC
# 17080  ENSG00000196787      H2AC11     4737     8969       pH2A/f   HGNC
# 28269  ENSG00000234816      H2AC5P     4728    10341       pH2A/f   HGNC
# 39337  ENSG00000274962     TEX28P1    33356   728447         pTEX   HGNC
# 39717  ENSG00000277008     TEX28P2    33357   653363         pTEX   HGNC
#
# [1487 rows x 6 columns]

# %% [markdown]
# ### <a id='toc2_1_10_'></a>[Count the number of times each multi-use alias is used](#toc0_)

# %%
aa_collision_hgnc_count_df = aa_collision_hgnc_df.pivot_table(index = ['alias_symbol'], aggfunc ='size')
aa_collision_hgnc_count_df = aa_collision_hgnc_count_df.reset_index()
aa_collision_hgnc_count_df.rename(columns={0:'num_gene_records'}, inplace=True )
aa_collision_hgnc_count_df = aa_collision_hgnc_count_df.sort_values('num_gene_records', ascending=False)
aa_collision_hgnc_count_df.head(5)
# Out:
#     alias_symbol  num_gene_records
# 639           U3                 8
# 642           U4                 6
# 189          MYM                 6
# 446         F379                 6
# 638           U2                 5

# %%
hgnc_alias_alias_collision_set = set(aa_collision_hgnc_count_df['alias_symbol'])
len(hgnc_alias_alias_collision_set)
# Out:
# 673

# %%
aa_collision_hgnc_count_df.to_csv('../aa_collision_hgnc_count_df.csv', index=True)

# %%
hgnc_alias_count_distribution_df = aa_collision_hgnc_count_df.pivot_table(index = ['num_gene_records'], aggfunc ='size')
hgnc_alias_count_distribution_df = hgnc_alias_count_distribution_df.reset_index()
hgnc_alias_count_distribution_df.rename(columns={0:'num_alias_symbol'}, inplace=True )
hgnc_alias_count_distribution_df['percent_alias_symbol'] = ((hgnc_alias_count_distribution_df['num_alias_symbol'] / hgnc_alias_len) * 100)
hgnc_alias_count_distribution_df
# Out:
#    num_gene_records  num_alias_symbol  percent_alias_symbol
# 0                 2               574              1.311401
# 1                 3                70              0.159927
# 2                 4                22              0.050263
# 3                 5                 3              0.006854
# 4                 6                 3              0.006854
# 5                 8                 1              0.002285

# %%
hgnc_alias_count_distribution_df = hgnc_alias_count_distribution_df.drop('num_alias_symbol', axis=1)
hgnc_alias_count_distribution_df
# Out:
#    num_gene_records  percent_alias_symbol
# 0                 2              1.311401
# 1                 3              0.159927
# 2                 4              0.050263
# 3                 5              0.006854
# 4                 6              0.006854
# 5                 8              0.002285

# %%
#px.bar(hgnc_alias_count_histogram_df, x='num_gene_records', y='percent_alias_symbol')

# %% [markdown]
# #### <a id='toc2_1_10_1_'></a>[Save as csv](#toc0_)

# %%
#mini_hgnc_df_explode.to_csv('../hgnc_alias_overlap.csv', index=False)

# %% [markdown]
# ### <a id='toc2_1_11_'></a>[Put columns in different order to ephasize alias symbols instead of gene records](#toc0_)

# %%
aa_collision_hgnc_df_2 = aa_collision_hgnc_df.drop_duplicates(subset = ["alias_symbol", "gene_symbol"], keep = 'first')

# %%
aa_collision_hgnc_df_2 = aa_collision_hgnc_df_2[['alias_symbol', 'ENSG_ID', 'gene_symbol', 'source']]
aa_collision_hgnc_df_2
# Out:
#       alias_symbol          ENSG_ID gene_symbol source
# 7761           2F1  ENSG00000139187       KLRG1   HGNC
# 75             2F1  ENSG00000005022     SLC25A5   HGNC
# 10916       60B8AG  ENSG00000163220      S100A9   HGNC
# 8398        60B8AG  ENSG00000143546      S100A8   HGNC
# 10424           A2  ENSG00000160226     CFAP410   HGNC
# ...            ...              ...         ...    ...
# 10537          p62  ENSG00000161011      SQSTM1   HGNC
# 17080       pH2A/f  ENSG00000196787      H2AC11   HGNC
# 28269       pH2A/f  ENSG00000234816      H2AC5P   HGNC
# 39337         pTEX  ENSG00000274962     TEX28P1   HGNC
# 39717         pTEX  ENSG00000277008     TEX28P2   HGNC
#
# [1487 rows x 4 columns]

# %% [markdown]
# ### <a id='toc2_1_12_'></a>[Merge rows with matching alias symbols](#toc0_)

# %%
aa_collision_hgnc_df_2 = aa_collision_hgnc_df_2.applymap(str)
aa_collision_hgnc_df_2
# Out:
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_73154/3240441429.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   aa_collision_hgnc_df_2 = aa_collision_hgnc_df_2.applymap(str)
#       alias_symbol          ENSG_ID gene_symbol source
# 7761           2F1  ENSG00000139187       KLRG1   HGNC
# 75             2F1  ENSG00000005022     SLC25A5   HGNC
# 10916       60B8AG  ENSG00000163220      S100A9   HGNC
# 8398        60B8AG  ENSG00000143546      S100A8   HGNC
# 10424           A2  ENSG00000160226     CFAP410   HGNC
# ...            ...              ...         ...    ...
# 10537          p62  ENSG00000161011      SQSTM1   HGNC
# 17080       pH2A/f  ENSG00000196787      H2AC11   HGNC
# 28269       pH2A/f  ENSG00000234816      H2AC5P   HGNC
# 39337         pTEX  ENSG00000274962     TEX28P1   HGNC
# 39717         pTEX  ENSG00000277008     TEX28P2   HGNC
#
# [1487 rows x 4 columns]

# %%
aa_collision_hgnc_df_2 = aa_collision_hgnc_df_2.groupby('alias_symbol').agg({'ENSG_ID': ', '.join, 
                             'gene_symbol': ', '.join, 
                             'source':'first' }).reset_index()
aa_collision_hgnc_df_2
# Out:
#     alias_symbol                                            ENSG_ID  \
# 0            2F1                   ENSG00000139187, ENSG00000005022
# 1         60B8AG                   ENSG00000163220, ENSG00000143546
# 2             A2  ENSG00000160226, ENSG00000108823, ENSG00000149735
# 3           ACC2                   ENSG00000076555, ENSG00000140379
# 4           ACS2                   ENSG00000197142, ENSG00000164398
# ..           ...                                                ...
# 668          p55  ENSG00000197170, ENSG00000075618, ENSG00000117...
# 669          p56                   ENSG00000123106, ENSG00000227211
# 670          p62                   ENSG00000213024, ENSG00000161011
# 671       pH2A/f                   ENSG00000196787, ENSG00000234816
# 672         pTEX                   ENSG00000274962, ENSG00000277008
#
#                       gene_symbol source
# 0                  KLRG1, SLC25A5   HGNC
# 1                  S100A9, S100A8   HGNC
# 2            CFAP410, SGCA, GPHA2   HGNC
# 3                   ACACB, BCL2A1   HGNC
# 4                    ACSL5, ACSL6   HGNC
# ..                            ...    ...
# 668  PSMD12, FSCN1, PIK3R3, H3P44   HGNC
# 669                 CCDC91, H3P45   HGNC
# 670                 NUP62, SQSTM1   HGNC
# 671                H2AC11, H2AC5P   HGNC
# 672              TEX28P1, TEX28P2   HGNC
#
# [673 rows x 4 columns]

# %%
#mini_hgnc_df_2.to_csv('../hgnc_alias_overlap_2.csv', index=False)

# %% [markdown]
# # <a id='toc3_'></a>[NCBI Info](#toc0_)

# %%
mini_ncbi_df = pd.read_csv('Downloaded_files/mini_ncbi_df.csv', dtype={'HGNC_ID': pd.Int64Dtype(), 'NCBI_ID': pd.Int64Dtype()})
mini_ncbi_df
# Out:
#         NCBI_ID gene_symbol               alias_symbol  HGNC_ID  \
# 0             1        A1BG       A1B|ABG|GAB|HYST2477        5
# 1             2         A2M  A2MD|CPAMD5|FWP007|S863-7        7
# 2             3       A2MP1                       A2MP        8
# 3             9        NAT1       AAC1|MNAT|NAT-1|NATI     7645
# 4            10        NAT2            AAC2|NAT-2|PNAT     7646
# ...         ...         ...                        ...      ...
# 193451  8923215        trnD                          -     <NA>
# 193452  8923216        trnP                          -     <NA>
# 193453  8923217        trnA                          -     <NA>
# 193454  8923218        COX1                          -     <NA>
# 193455  8923219    16S rRNA                          -     <NA>
#
#                 ENSG_ID
# 0       ENSG00000121410
# 1       ENSG00000175899
# 2       ENSG00000291190
# 3       ENSG00000171428
# 4       ENSG00000156006
# ...                 ...
# 193451              NaN
# 193452              NaN
# 193453              NaN
# 193454              NaN
# 193455              NaN
#
# [193456 rows x 5 columns]

# %% [markdown]
# ### <a id='toc3_1_2_'></a>[How many total unique gene records are there](#toc0_)

# %% [markdown]
# By ENSG ID

# %%
ncbi_gene_id_set = set(mini_ncbi_df['ENSG_ID'])
len(ncbi_gene_id_set)
# Out:
# 36803

# %% [markdown]
# By gene symbol

# %%
ncbi_gene_symbol_set = set(mini_ncbi_df['gene_symbol'])
len(ncbi_gene_symbol_set)
# Out:
# 193303

# %% [markdown]
# ### <a id='toc3_1_3_'></a>[Drop genes with no aliases](#toc0_)

# %%
mini_ncbi_df = mini_ncbi_df.replace("-", np.nan)
mini_ncbi_df
# Out:
#         NCBI_ID gene_symbol               alias_symbol  HGNC_ID  \
# 0             1        A1BG       A1B|ABG|GAB|HYST2477        5
# 1             2         A2M  A2MD|CPAMD5|FWP007|S863-7        7
# 2             3       A2MP1                       A2MP        8
# 3             9        NAT1       AAC1|MNAT|NAT-1|NATI     7645
# 4            10        NAT2            AAC2|NAT-2|PNAT     7646
# ...         ...         ...                        ...      ...
# 193451  8923215        trnD                        NaN     <NA>
# 193452  8923216        trnP                        NaN     <NA>
# 193453  8923217        trnA                        NaN     <NA>
# 193454  8923218        COX1                        NaN     <NA>
# 193455  8923219    16S rRNA                        NaN     <NA>
#
#                 ENSG_ID
# 0       ENSG00000121410
# 1       ENSG00000175899
# 2       ENSG00000291190
# 3       ENSG00000171428
# 4       ENSG00000156006
# ...                 ...
# 193451              NaN
# 193452              NaN
# 193453              NaN
# 193454              NaN
# 193455              NaN
#
# [193456 rows x 5 columns]

# %%
mini_ncbi_df = mini_ncbi_df.dropna(subset=['alias_symbol'])
mini_ncbi_df
# Out:
#           NCBI_ID   gene_symbol               alias_symbol  HGNC_ID  \
# 0               1          A1BG       A1B|ABG|GAB|HYST2477        5
# 1               2           A2M  A2MD|CPAMD5|FWP007|S863-7        7
# 2               3         A2MP1                       A2MP        8
# 3               9          NAT1       AAC1|MNAT|NAT-1|NATI     7645
# 4              10          NAT2            AAC2|NAT-2|PNAT     7646
# ...           ...           ...                        ...      ...
# 190958  131696449  LOC131696449             PKD1P1-NPIPA5L     <NA>
# 190961  131840634         GLTC1                       GLTC    56861
# 193342  132532400    GABRA6-AS1                      ARBAG    40248
# 193377  133395150       LNCARGI                       ARGI    56890
# 193378  133834869         MLDHR               MP31|PTENURF    55481
#
#                 ENSG_ID
# 0       ENSG00000121410
# 1       ENSG00000175899
# 2       ENSG00000291190
# 3       ENSG00000171428
# 4       ENSG00000156006
# ...                 ...
# 190958              NaN
# 190961              NaN
# 193342              NaN
# 193377              NaN
# 193378              NaN
#
# [27582 rows x 5 columns]

# %% [markdown]
# ### <a id='toc3_1_4_'></a>[Make each row in alias_symbol a set:](#toc0_)
#     covert to a list
#     make a set

# %%
mini_ncbi_df['alias_symbol'] = mini_ncbi_df['alias_symbol'].astype(str)
mini_ncbi_df['alias_symbol'] = [x.split('|') for x in mini_ncbi_df.alias_symbol]
mini_ncbi_df['alias_symbol']=np.where(mini_ncbi_df.alias_symbol=='','',mini_ncbi_df.alias_symbol.map(set))
mini_ncbi_df.head(1)
# Out:
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_73154/2736731455.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mini_ncbi_df['alias_symbol'] = mini_ncbi_df['alias_symbol'].astype(str)
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_73154/2736731455.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mini_ncbi_df['alias_symbol'] = [x.split('|') for x in mini_ncbi_df.alias_symbol]
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_73154/2736731455.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mini_ncbi_df['alias_symbol']=np.where(mini_ncbi_df.alias_symbol=='','',mini_ncbi_df.alias_symbol.map(set))
#    NCBI_ID gene_symbol               alias_symbol  HGNC_ID          ENSG_ID
# 0        1        A1BG  {A1B, HYST2477, ABG, GAB}        5  ENSG00000121410

# %% [markdown]
# ### <a id='toc3_1_5_'></a>[Explode the alias sets so that it is one per row](#toc0_)

# %%
mini_ncbi_df = mini_ncbi_df.explode(column="alias_symbol")
mini_ncbi_df.head(5)
# Out:
#    NCBI_ID gene_symbol alias_symbol  HGNC_ID          ENSG_ID
# 0        1        A1BG          A1B        5  ENSG00000121410
# 0        1        A1BG     HYST2477        5  ENSG00000121410
# 0        1        A1BG          ABG        5  ENSG00000121410
# 0        1        A1BG          GAB        5  ENSG00000121410
# 1        2         A2M         A2MD        7  ENSG00000175899

# %%
#ncbi_CD158b_alias_count_df.to_csv('../ncbi_CD158b_alias_count_df.csv')

# %% [markdown]
# ### <a id='toc3_1_6_'></a>[How many unique aliases are there](#toc0_)

# %%
ncbi_alias_symbol_set = set(mini_ncbi_df['alias_symbol'])
ncbi_alias_len = len(ncbi_alias_symbol_set)
ncbi_alias_len
# Out:
# 69157

# %% [markdown]
# ### Remove the duplicate instances of a primary gene symbol- alias pair

# %%
mini_ncbi_df = mini_ncbi_df.drop_duplicates(subset=['gene_symbol', 'alias_symbol'], keep='first')
mini_ncbi_df
# Out:
#           NCBI_ID gene_symbol alias_symbol  HGNC_ID          ENSG_ID
# 0               1        A1BG          A1B        5  ENSG00000121410
# 0               1        A1BG     HYST2477        5  ENSG00000121410
# 0               1        A1BG          ABG        5  ENSG00000121410
# 0               1        A1BG          GAB        5  ENSG00000121410
# 1               2         A2M         A2MD        7  ENSG00000175899
# ...           ...         ...          ...      ...              ...
# 190961  131840634       GLTC1         GLTC    56861              NaN
# 193342  132532400  GABRA6-AS1        ARBAG    40248              NaN
# 193377  133395150     LNCARGI         ARGI    56890              NaN
# 193378  133834869       MLDHR         MP31    55481              NaN
# 193378  133834869       MLDHR      PTENURF    55481              NaN
#
# [74053 rows x 5 columns]

# %% [markdown]
# ### <a id='toc3_1_7_'></a>[Pull out all the rows that have an alias symbol that can be found elsewhere](#toc0_)

# %%
mini_ncbi_df['alias_duplicates'] = mini_ncbi_df.duplicated(subset= 'alias_symbol', keep=False)
mini_ncbi_df = mini_ncbi_df[mini_ncbi_df['alias_duplicates'] == True]
mini_ncbi_df = mini_ncbi_df.drop(['alias_duplicates'], axis=1)
mini_ncbi_df.head(5)
# Out:
#    NCBI_ID gene_symbol alias_symbol  HGNC_ID          ENSG_ID
# 0        1        A1BG          A1B        5  ENSG00000121410
# 3        9        NAT1        NAT-1     7645  ENSG00000171428
# 3        9        NAT1         AAC1     7645  ENSG00000171428
# 4       10        NAT2         AAC2     7646  ENSG00000156006
# 6       12    SERPINA3          ACT       16  ENSG00000196136

# %% [markdown]
# ### <a id='toc3_1_8_'></a>[Sort alias symbols alphabetically](#toc0_)

# %%
mini_ncbi_df = mini_ncbi_df.sort_values('alias_symbol')
mini_ncbi_df.head(5)
# Out:
#       NCBI_ID gene_symbol alias_symbol  HGNC_ID          ENSG_ID
# 537       657      BMPR1A     10q23del     1076  ENSG00000107779
# 4525     5728        PTEN     10q23del     9588  ENSG00000171862
# 199       239      ALOX12       12-LOX      429  ENSG00000108839
# 205       246      ALOX15       12-LOX      433  ENSG00000161905
# 7974    10219       KLRG1          2F1     6380  ENSG00000139187

# %% [markdown]
# ### <a id='toc3_1_9_'></a>[Number of records with an alias that is shared](#toc0_)

# %%
ncbi_alias_alias_collision_primary_symbol_set = set(mini_ncbi_df['gene_symbol'])
len(ncbi_alias_alias_collision_primary_symbol_set)
# Out:
# 5732

# %%
mini_ncbi_df['source'] = 'NCBI Info'
mini_ncbi_df
# Out:
#        NCBI_ID gene_symbol alias_symbol  HGNC_ID          ENSG_ID     source
# 537        657      BMPR1A     10q23del     1076  ENSG00000107779  NCBI Info
# 4525      5728        PTEN     10q23del     9588  ENSG00000171862  NCBI Info
# 199        239      ALOX12       12-LOX      429  ENSG00000108839  NCBI Info
# 205        246      ALOX15       12-LOX      433  ENSG00000161905  NCBI Info
# 7974     10219       KLRG1          2F1     6380  ENSG00000139187  NCBI Info
# ...        ...         ...          ...      ...              ...        ...
# 18172   139420     PPP4R3C         smk1    33146  ENSG00000224960  NCBI Info
# 12905    55671     PPP4R3A         smk1    20219  ENSG00000100796  NCBI Info
# 13522    57223     PPP4R3B         smk1    29267  ENSG00000275052  NCBI Info
# 7631      9825      SPATA2         tamo    14681  ENSG00000158480  NCBI Info
# 17516   124044     SPATA2L         tamo    28393  ENSG00000158792  NCBI Info
#
# [8372 rows x 6 columns]

# %% [markdown]
# ### <a id='toc3_1_10_'></a>[Count the number of times each multi-use alias is used](#toc0_)

# %%
ncbi_dup_alias_count_df = mini_ncbi_df.pivot_table(index = ['alias_symbol'], aggfunc ='size')
ncbi_dup_alias_count_df
# Out:
# alias_symbol
# 10q23del       2
# 12-LOX         2
# 2F1            2
# 3-alpha-HSD    2
# 35DAG          2
#               ..
# polymerase     3
# psiSSX8        2
# rpL7a          2
# smk1           3
# tamo           2
# Length: 3476, dtype: int64

# %%
ncbi_dup_alias_count_df.to_csv('../ncbi_alias_overlap_count.csv', index=True)

# %%
ncbi_dup_alias_count_df = ncbi_dup_alias_count_df.reset_index()
ncbi_dup_alias_count_df
# Out:
#      alias_symbol  0
# 0        10q23del  2
# 1          12-LOX  2
# 2             2F1  2
# 3     3-alpha-HSD  2
# 4           35DAG  2
# ...           ... ..
# 3471   polymerase  3
# 3472      psiSSX8  2
# 3473        rpL7a  2
# 3474         smk1  3
# 3475         tamo  2
#
# [3476 rows x 2 columns]

# %%
ncbi_dup_alias_count_df.rename(columns={0:'num_gene_records'}, inplace=True )
ncbi_dup_alias_count_df
# Out:
#      alias_symbol  num_gene_records
# 0        10q23del                 2
# 1          12-LOX                 2
# 2             2F1                 2
# 3     3-alpha-HSD                 2
# 4           35DAG                 2
# ...           ...               ...
# 3471   polymerase                 3
# 3472      psiSSX8                 2
# 3473        rpL7a                 2
# 3474         smk1                 3
# 3475         tamo                 2
#
# [3476 rows x 2 columns]

# %%
ncbi_dup_alias_count_df = ncbi_dup_alias_count_df.sort_values('num_gene_records', ascending=False)
ncbi_dup_alias_count_df.head(30)
# Out:
#      alias_symbol  num_gene_records
# 3305           VH                36
# 1303        H4-16                14
# 1306        H4C12                13
# 1305        H4C11                13
# 1316         H4C8                13
# 1317         H4C9                13
# 1312         H4C3                13
# 1310        H4C16                13
# 1304         H4C1                13
# 1315         H4C6                13
# 1309        H4C15                13
# 1314         H4C5                13
# 1308        H4C14                13
# 1307        H4C13                13
# 1313         H4C4                13
# 1311         H4C2                13
# 1992          MT1                12
# 1211         GPCR                11
# 1463         HOX1                10
# 2496           PR                10
# 1289        H3C10                 9
# 1290        H3C11                 9
# 1288         H3C1                 9
# 3277         UGT1                 9
# 3269        UDPGT                 9
# 1300         H3C8                 9
# 1299         H3C7                 9
# 1298         H3C6                 9
# 1465         HOX2                 9
# 1297         H3C4                 9

# %%
ncbi_alias_alias_collision_set = set(ncbi_dup_alias_count_df['alias_symbol'])
len(ncbi_alias_alias_collision_set)
# Out:
# 3476

# %%
ncbi_dup_alias_count_df.to_csv('../ncbi_dup_alias_count_df.csv', index=True)

# %%
ncbi_alias_count_histogram_df = ncbi_dup_alias_count_df.pivot_table(index = ['num_gene_records'], aggfunc ='size')
ncbi_alias_count_histogram_df
# Out:
# num_gene_records
# 2     2786
# 3      413
# 4      140
# 5       54
# 6       23
# 7       17
# 8        8
# 9       15
# 10       2
# 11       1
# 12       1
# 13      14
# 14       1
# 36       1
# dtype: int64

# %%
ncbi_alias_count_histogram_df = ncbi_alias_count_histogram_df.reset_index()
ncbi_alias_count_histogram_df
# Out:
#     num_gene_records     0
# 0                  2  2786
# 1                  3   413
# 2                  4   140
# 3                  5    54
# 4                  6    23
# 5                  7    17
# 6                  8     8
# 7                  9    15
# 8                 10     2
# 9                 11     1
# 10                12     1
# 11                13    14
# 12                14     1
# 13                36     1

# %%
ncbi_alias_count_histogram_df.rename(columns={0:'num_alias_symbol'}, inplace=True )
ncbi_alias_count_histogram_df
# Out:
#     num_gene_records  num_alias_symbol
# 0                  2              2786
# 1                  3               413
# 2                  4               140
# 3                  5                54
# 4                  6                23
# 5                  7                17
# 6                  8                 8
# 7                  9                15
# 8                 10                 2
# 9                 11                 1
# 10                12                 1
# 11                13                14
# 12                14                 1
# 13                36                 1

# %%
ncbi_alias_count_histogram_df['percent_alias_symbol'] = ((ncbi_alias_count_histogram_df['num_alias_symbol'] / ncbi_alias_len) * 100)
ncbi_alias_count_histogram_df
# Out:
#     num_gene_records  num_alias_symbol  percent_alias_symbol
# 0                  2              2786              4.028515
# 1                  3               413              0.597192
# 2                  4               140              0.202438
# 3                  5                54              0.078083
# 4                  6                23              0.033258
# 5                  7                17              0.024582
# 6                  8                 8              0.011568
# 7                  9                15              0.021690
# 8                 10                 2              0.002892
# 9                 11                 1              0.001446
# 10                12                 1              0.001446
# 11                13                14              0.020244
# 12                14                 1              0.001446
# 13                36                 1              0.001446

# %%
ncbi_alias_count_histogram_df = ncbi_alias_count_histogram_df.drop('num_alias_symbol', axis=1)
ncbi_alias_count_histogram_df
# Out:
#     num_gene_records  percent_alias_symbol
# 0                  2              4.028515
# 1                  3              0.597192
# 2                  4              0.202438
# 3                  5              0.078083
# 4                  6              0.033258
# 5                  7              0.024582
# 6                  8              0.011568
# 7                  9              0.021690
# 8                 10              0.002892
# 9                 11              0.001446
# 10                12              0.001446
# 11                13              0.020244
# 12                14              0.001446
# 13                36              0.001446

# %%
# px.bar(ncbi_alias_count_histogram_df, x='num_gene_records', y='percent_alias_symbol')

# %% [markdown]
# ### <a id='toc3_1_11_'></a>[Put columns in different order to ephasize alias symbols instead of gene records](#toc0_)

# %%
mini_ncbi_df_2 = mini_ncbi_df.drop_duplicates(subset = ["alias_symbol", "gene_symbol"], keep = 'first')

# %%
mini_ncbi_df_2 = mini_ncbi_df[['alias_symbol', 'ENSG_ID', 'gene_symbol', 'source']]
mini_ncbi_df_2
# Out:
#       alias_symbol          ENSG_ID gene_symbol     source
# 537       10q23del  ENSG00000107779      BMPR1A  NCBI Info
# 4525      10q23del  ENSG00000171862        PTEN  NCBI Info
# 199         12-LOX  ENSG00000108839      ALOX12  NCBI Info
# 205         12-LOX  ENSG00000161905      ALOX15  NCBI Info
# 7974           2F1  ENSG00000139187       KLRG1  NCBI Info
# ...            ...              ...         ...        ...
# 18172         smk1  ENSG00000224960     PPP4R3C  NCBI Info
# 12905         smk1  ENSG00000100796     PPP4R3A  NCBI Info
# 13522         smk1  ENSG00000275052     PPP4R3B  NCBI Info
# 7631          tamo  ENSG00000158480      SPATA2  NCBI Info
# 17516         tamo  ENSG00000158792     SPATA2L  NCBI Info
#
# [8372 rows x 4 columns]

# %% [markdown]
# ### <a id='toc3_1_12_'></a>[Merge rows with matching alias symbols](#toc0_)

# %%
mini_ncbi_df_2 = mini_ncbi_df_2.applymap(str)
mini_ncbi_df_2
# Out:
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_73154/792032257.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   mini_ncbi_df_2 = mini_ncbi_df_2.applymap(str)
#       alias_symbol          ENSG_ID gene_symbol     source
# 537       10q23del  ENSG00000107779      BMPR1A  NCBI Info
# 4525      10q23del  ENSG00000171862        PTEN  NCBI Info
# 199         12-LOX  ENSG00000108839      ALOX12  NCBI Info
# 205         12-LOX  ENSG00000161905      ALOX15  NCBI Info
# 7974           2F1  ENSG00000139187       KLRG1  NCBI Info
# ...            ...              ...         ...        ...
# 18172         smk1  ENSG00000224960     PPP4R3C  NCBI Info
# 12905         smk1  ENSG00000100796     PPP4R3A  NCBI Info
# 13522         smk1  ENSG00000275052     PPP4R3B  NCBI Info
# 7631          tamo  ENSG00000158480      SPATA2  NCBI Info
# 17516         tamo  ENSG00000158792     SPATA2L  NCBI Info
#
# [8372 rows x 4 columns]

# %%
mini_ncbi_df_2['ENSG_ID'] = mini_ncbi_df_2['ENSG_ID'].str.replace('NAN','nan')
mini_ncbi_df_2
# Out:
#       alias_symbol          ENSG_ID gene_symbol     source
# 537       10q23del  ENSG00000107779      BMPR1A  NCBI Info
# 4525      10q23del  ENSG00000171862        PTEN  NCBI Info
# 199         12-LOX  ENSG00000108839      ALOX12  NCBI Info
# 205         12-LOX  ENSG00000161905      ALOX15  NCBI Info
# 7974           2F1  ENSG00000139187       KLRG1  NCBI Info
# ...            ...              ...         ...        ...
# 18172         smk1  ENSG00000224960     PPP4R3C  NCBI Info
# 12905         smk1  ENSG00000100796     PPP4R3A  NCBI Info
# 13522         smk1  ENSG00000275052     PPP4R3B  NCBI Info
# 7631          tamo  ENSG00000158480      SPATA2  NCBI Info
# 17516         tamo  ENSG00000158792     SPATA2L  NCBI Info
#
# [8372 rows x 4 columns]

# %%
mini_ncbi_df_2 = mini_ncbi_df_2.groupby('alias_symbol').agg({'ENSG_ID': ', '.join, 
                             'gene_symbol': ', '.join, 
                             'source':'first' }).reset_index()
mini_ncbi_df_2
# Out:
#      alias_symbol                                            ENSG_ID  \
# 0        10q23del                   ENSG00000107779, ENSG00000171862
# 1          12-LOX                   ENSG00000108839, ENSG00000161905
# 2             2F1                   ENSG00000139187, ENSG00000005022
# 3     3-alpha-HSD                   ENSG00000198610, ENSG00000073737
# 4           35DAG                   ENSG00000102683, ENSG00000170624
# ...           ...                                                ...
# 3471   polymerase                                      nan, nan, nan
# 3472      psiSSX8                               ENSG00000241207, nan
# 3473        rpL7a                   ENSG00000213272, ENSG00000240522
# 3474         smk1  ENSG00000224960, ENSG00000100796, ENSG00000275052
# 3475         tamo                   ENSG00000158480, ENSG00000158792
#
#                     gene_symbol     source
# 0                  BMPR1A, PTEN  NCBI Info
# 1                ALOX12, ALOX15  NCBI Info
# 2                KLRG1, SLC25A5  NCBI Info
# 3                 AKR1C4, DHRS9  NCBI Info
# 4                    SGCG, SGCD  NCBI Info
# ...                         ...        ...
# 3471   ERVK-11, ERVK-19, ERVK-9  NCBI Info
# 3472              SSX18P, SSXP8  NCBI Info
# 3473          RPL7AP9, RPL7AP10  NCBI Info
# 3474  PPP4R3C, PPP4R3A, PPP4R3B  NCBI Info
# 3475            SPATA2, SPATA2L  NCBI Info
#
# [3476 rows x 4 columns]

# %% [markdown]
# # <a id='toc4_'></a>[Merge to create Alias Overlap Table 1 - Gene Symbol](#toc0_)

# %%
# merged_alias_overlap_df_1 = pd.concat([mini_hgnc_df[['gene_symbol', 'ENSG_ID', 'alias_symbol', 'source']],mini_ncbi_df[['gene_symbol', 'ENSG_ID', 'alias_symbol', 'source']], mini_ensg_df[['gene_symbol', 'ENSG_ID', 'alias_symbol', 'source']]])
# merged_alias_overlap_df_1

# %%
# merged_alias_overlap_df_1.to_csv('../merged_alias_overlap_df_1.csv', index=False)

# %%
# merged_alias_overlap_df_1.loc[merged_alias_overlap_df_1.gene_symbol == 'HSP90AA1']

# %%
# merged_alias_overlap_df_1.loc[merged_alias_overlap_df_1.alias_symbol == 'Hsp90' ]

# %%
# merged_alias_overlap_df_1['source'].value_counts()

# %% [markdown]
# # <a id='toc5_'></a>[Merge to create Alias Overlap Table 2 - Alias Symbol](#toc0_)

# %%
merged_alias_overlap_df_2 = pd.concat([aa_collision_hgnc_df_2[['alias_symbol', 'gene_symbol', 'ENSG_ID', 'source']],mini_ncbi_df_2[['alias_symbol', 'gene_symbol', 'ENSG_ID', 'source']], aa_collision_ensg_df_2[['alias_symbol', 'gene_symbol', 'ENSG_ID', 'source']]])
merged_alias_overlap_df_2
# Out:
#      alias_symbol           gene_symbol  \
# 0             2F1        KLRG1, SLC25A5
# 1          60B8AG        S100A9, S100A8
# 2              A2  CFAP410, SGCA, GPHA2
# 3            ACC2         ACACB, BCL2A1
# 4            ACS2          ACSL5, ACSL6
# ...           ...                   ...
# 1144    TCRBV15S1      TRBV15, TRBV24-1
# 1145      TCRGV5P         TRGV5P, TRGV6
# 1146          TGT          USP14, QTRT1
# 1147         UBC7        UBE2G1, UBE2G2
# 1148          UPA           PRAP1, PLAU
#
#                                                 ENSG_ID source
# 0                      ENSG00000139187, ENSG00000005022   HGNC
# 1                      ENSG00000163220, ENSG00000143546   HGNC
# 2     ENSG00000160226, ENSG00000108823, ENSG00000149735   HGNC
# 3                      ENSG00000076555, ENSG00000140379   HGNC
# 4                      ENSG00000197142, ENSG00000164398   HGNC
# ...                                                 ...    ...
# 1144                   ENSG00000276819, ENSG00000211750   ENSG
# 1145                   ENSG00000228668, ENSG00000226212   ENSG
# 1146                   ENSG00000101557, ENSG00000213339   ENSG
# 1147                   ENSG00000132388, ENSG00000184787   ENSG
# 1148                   ENSG00000165828, ENSG00000122861   ENSG
#
# [5298 rows x 4 columns]

# %%
merged_alias_overlap_df_2.loc[merged_alias_overlap_df_2['alias_symbol'] == "ASP" ]
# Out:
#     alias_symbol                                        gene_symbol  \
# 394          ASP                           ROPN1L, ASPA, ATG5, ASIP
# 222          ASP  A1CF, ATG5, ASPM, TMPRSS11D, ROPN1L, ASIP, ASP...
# 864          ASP                            ROPN1L, ASPM, TMPRSS11D
#
#                                                ENSG_ID     source
# 394  ENSG00000145491, ENSG00000108381, ENSG00000057...       HGNC
# 222  ENSG00000148584, ENSG00000057663, ENSG00000066...  NCBI Info
# 864  ENSG00000145491, ENSG00000066279, ENSG00000153802       ENSG

# %%
merged_alias_overlap_df_2['gene_symbol'] = merged_alias_overlap_df_2['gene_symbol'].str.split(",")
merged_alias_overlap_df_2
# Out:
#      alias_symbol               gene_symbol  \
# 0             2F1         [KLRG1,  SLC25A5]
# 1          60B8AG         [S100A9,  S100A8]
# 2              A2  [CFAP410,  SGCA,  GPHA2]
# 3            ACC2          [ACACB,  BCL2A1]
# 4            ACS2           [ACSL5,  ACSL6]
# ...           ...                       ...
# 1144    TCRBV15S1       [TRBV15,  TRBV24-1]
# 1145      TCRGV5P          [TRGV5P,  TRGV6]
# 1146          TGT           [USP14,  QTRT1]
# 1147         UBC7         [UBE2G1,  UBE2G2]
# 1148          UPA            [PRAP1,  PLAU]
#
#                                                 ENSG_ID source
# 0                      ENSG00000139187, ENSG00000005022   HGNC
# 1                      ENSG00000163220, ENSG00000143546   HGNC
# 2     ENSG00000160226, ENSG00000108823, ENSG00000149735   HGNC
# 3                      ENSG00000076555, ENSG00000140379   HGNC
# 4                      ENSG00000197142, ENSG00000164398   HGNC
# ...                                                 ...    ...
# 1144                   ENSG00000276819, ENSG00000211750   ENSG
# 1145                   ENSG00000228668, ENSG00000226212   ENSG
# 1146                   ENSG00000101557, ENSG00000213339   ENSG
# 1147                   ENSG00000132388, ENSG00000184787   ENSG
# 1148                   ENSG00000165828, ENSG00000122861   ENSG
#
# [5298 rows x 4 columns]

# %%
merged_alias_overlap_df_2['gene_symbol_count'] = [len(c) for c in merged_alias_overlap_df_2['gene_symbol']]
merged_alias_overlap_df_2
# Out:
#      alias_symbol               gene_symbol  \
# 0             2F1         [KLRG1,  SLC25A5]
# 1          60B8AG         [S100A9,  S100A8]
# 2              A2  [CFAP410,  SGCA,  GPHA2]
# 3            ACC2          [ACACB,  BCL2A1]
# 4            ACS2           [ACSL5,  ACSL6]
# ...           ...                       ...
# 1144    TCRBV15S1       [TRBV15,  TRBV24-1]
# 1145      TCRGV5P          [TRGV5P,  TRGV6]
# 1146          TGT           [USP14,  QTRT1]
# 1147         UBC7         [UBE2G1,  UBE2G2]
# 1148          UPA            [PRAP1,  PLAU]
#
#                                                 ENSG_ID source  \
# 0                      ENSG00000139187, ENSG00000005022   HGNC
# 1                      ENSG00000163220, ENSG00000143546   HGNC
# 2     ENSG00000160226, ENSG00000108823, ENSG00000149735   HGNC
# 3                      ENSG00000076555, ENSG00000140379   HGNC
# 4                      ENSG00000197142, ENSG00000164398   HGNC
# ...                                                 ...    ...
# 1144                   ENSG00000276819, ENSG00000211750   ENSG
# 1145                   ENSG00000228668, ENSG00000226212   ENSG
# 1146                   ENSG00000101557, ENSG00000213339   ENSG
# 1147                   ENSG00000132388, ENSG00000184787   ENSG
# 1148                   ENSG00000165828, ENSG00000122861   ENSG
#
#       gene_symbol_count
# 0                     2
# 1                     2
# 2                     3
# 3                     2
# 4                     2
# ...                 ...
# 1144                  2
# 1145                  2
# 1146                  2
# 1147                  2
# 1148                  2
#
# [5298 rows x 5 columns]

# %%
merged_alias_overlap_df_2 = merged_alias_overlap_df_2.sort_values(by='gene_symbol_count', ascending= False)
merged_alias_overlap_df_2
# Out:
#      alias_symbol                                        gene_symbol  \
# 3305           VH  [IGHV4-34,  IGHV3-43,  IGHV4-59,  IGHV4-61,  I...
# 1303        H4-16  [H4C9,  H4C14,  H4C13,  H4C5,  H4C16,  H4C2,  ...
# 1317         H4C9  [H4C1,  H4C2,  H4C6,  H4C4,  H4C8,  H4C15,  H4...
# 1304         H4C1  [H4C2,  H4C12,  H4C9,  H4C8,  H4C11,  H4C14,  ...
# 1305        H4C11  [H4C13,  H4C1,  H4C2,  H4C9,  H4C8,  H4C4,  H4...
# ...           ...                                                ...
# 1240         GST3                                    [CHST4,  GSTP1]
# 1238         GST1                                    [GSTM1,  GSPT1]
# 1237          GST                                  [GSTK1,  SLCO6A1]
# 1236          GSP                                      [GNAS,  GSM1]
# 1148          UPA                                     [PRAP1,  PLAU]
#
#                                                 ENSG_ID     source  \
# 3305  ENSG00000211956, ENSG00000232216, ENSG00000224...  NCBI Info
# 1303  ENSG00000276180, ENSG00000270882, ENSG00000275...  NCBI Info
# 1317  ENSG00000278637, ENSG00000278705, ENSG00000274...  NCBI Info
# 1304  ENSG00000278705, ENSG00000273542, ENSG00000276...  NCBI Info
# 1305  ENSG00000275126, ENSG00000278637, ENSG00000278...  NCBI Info
# ...                                                 ...        ...
# 1240                   ENSG00000140835, ENSG00000084207  NCBI Info
# 1238                   ENSG00000134184, ENSG00000103342  NCBI Info
# 1237                   ENSG00000197448, ENSG00000205359  NCBI Info
# 1236                               ENSG00000087460, nan  NCBI Info
# 1148                   ENSG00000165828, ENSG00000122861       ENSG
#
#       gene_symbol_count
# 3305                 36
# 1303                 14
# 1317                 13
# 1304                 13
# 1305                 13
# ...                 ...
# 1240                  2
# 1238                  2
# 1237                  2
# 1236                  2
# 1148                  2
#
# [5298 rows x 5 columns]

# %%
merged_alias_overlap_df_2.loc[merged_alias_overlap_df_2['alias_symbol'] == "CFM1" ]
# Out:
# Empty DataFrame
# Columns: [alias_symbol, gene_symbol, ENSG_ID, source, gene_symbol_count]
# Index: []

# %%
merged_alias_overlap_df_2['gene_symbol_count'].value_counts()
# Out:
# gene_symbol_count
# 2     4340
# 3      600
# 4      193
# 5       62
# 6       36
# 7       18
# 9       17
# 13      14
# 8       10
# 10       4
# 36       1
# 14       1
# 12       1
# 11       1
# Name: count, dtype: int64

# %%
merged_alias_overlap_df_2.to_csv('merged_alias_overlap_df_2.csv', index=True)

# %%
aa_collision_set = set(merged_alias_overlap_df_2['alias_symbol'].tolist())

# %%
common_aa_collisions = ensg_alias_alias_collision_primary_symbol_set & hgnc_alias_alias_collision_primary_symbol_set & ncbi_alias_alias_collision_primary_symbol_set
common_aa_collisions
# Out:
# {'A1CF',
#  'ABCC2',
#  'ABCC6',
#  'ABCC8',
#  'ABHD14B',
#  'ABL1',
#  'ACACB',
#  'ACKR1',
#  'ACOD1',
#  'ACOT7',
#  'ACOT8',
#  'ACP2',
#  'ACP6',
#  'ACSL5',
#  'ACSL6',
#  'ACTR2',
#  'ACTR3',
#  'ACTR3B',
#  'ACTR3C',
#  'ACTRT1',
#  'ADAM10',
#  'AGAP13P',
#  'AGER',
#  'AGFG1',
#  'AGTR1',
#  'AHI1',
#  'AHSA1',
#  'AIFM2',
#  'AIMP1',
#  'AIMP2',
#  'AKR1A1',
#  'AKR1B1',
#  'AKR1C4',
#  'ALDH9A1',
#  'ALK',
#  'ALPG',
#  'ALPI',
#  'ALPP',
#  'AMBP',
#  'AMPD1',
#  'AMT',
#  'ANAPC1',
#  'ANAPC10',
#  'ANGPTL1',
#  'ANGPTL2',
#  'ANGPTL4',
#  'ANKRD1',
#  'ANKS4B',
#  'ANPEP',
#  'ANXA2',
#  'ANXA2P3',
#  'AP1M2',
#  'AP2M1',
#  'AP3B1',
#  'AP3M2',
#  'AP4S1',
#  'APEX1',
#  'APOBEC2',
#  'APOBEC3A',
#  'APPBP2',
#  'ARFRP1',
#  'ARHGEF2',
#  'ARHGEF28',
#  'ARHGEF5',
#  'ARID2',
#  'ARL6IP1',
#  'ARMH1',
#  'ARSF',
#  'ASAP1',
#  'ASAP2',
#  'ASCC1',
#  'ASIP',
#  'ASPA',
#  'ASPM',
#  'ASRGL1',
#  'ATF7IP',
#  'ATG5',
#  'ATN1',
#  'ATP2C1',
#  'ATP6V0A1',
#  'ATP6V0A2',
#  'ATP6V0A4',
#  'ATP6V0D1',
#  'ATP6V1B1',
#  'ATP6V1B2',
#  'ATP6V1G1',
#  'ATP6V1G3',
#  'ATP8A2',
#  'ATRAID',
#  'ATRNL1',
#  'AURKA',
#  'AZI2',
#  'AZIN1',
#  'AZIN2',
#  'B3GNT2',
#  'B4GAT1',
#  'B9D1',
#  'BBS9',
#  'BCL2A1',
#  'BLOC1S5',
#  'BMAL1',
#  'BPIFA2',
#  'BRCA1',
#  'BRCA2',
#  'BRD4',
#  'BRD8',
#  'BRI3BP',
#  'BRMS1L',
#  'BVES',
#  'C10orf62',
#  'C12orf75',
#  'C17orf49',
#  'C4A',
#  'C4B',
#  'CACNA1C',
#  'CACYBP',
#  'CALM2',
#  'CALML3',
#  'CAP1',
#  'CARD8',
#  'CAV2',
#  'CBX4',
#  'CBX8',
#  'CCDC26',
#  'CCDC6',
#  'CCDC91',
#  'CCHCR1',
#  'CCL16',
#  'CCL18',
#  'CCL2',
#  'CCL27',
#  'CCN1',
#  'CCR1',
#  'CCRL2',
#  'CD200R1',
#  'CD300LF',
#  'CD40',
#  'CD40LG',
#  'CD47',
#  'CD5',
#  'CD55',
#  'CD79B',
#  'CDK11A',
#  'CDK11B',
#  'CDK2AP1',
#  'CDK2AP2',
#  'CDK5R1',
#  'CDK5R2',
#  'CDK7',
#  'CDKN1A',
#  'CDKN2A',
#  'CDKN2B',
#  'CDKN2C',
#  'CDKN2D',
#  'CDT1',
#  'CENPC',
#  'CENPJ',
#  'CENPU',
#  'CES1',
#  'CFAP100',
#  'CFDP1',
#  'CFLAR',
#  'CHAF1A',
#  'CHAF1B',
#  'CHD1L',
#  'CHP1',
#  'CHST1',
#  'CHST2',
#  'CHST3',
#  'CIB1',
#  'CISD2',
#  'CISH',
#  'CLEC11A',
#  'CLIC4',
#  'CLIP1',
#  'CLIP2',
#  'CLNS1A',
#  'CLNS1AP1',
#  'CMC4',
#  'CMKLR1',
#  'COASY',
#  'COL18A1',
#  'COL9A2',
#  'COMP',
#  'COPS2',
#  'COTL1',
#  'CPOX',
#  'CREBBP',
#  'CRIP2',
#  'CRIPTO',
#  'CRISP1',
#  'CRNKL1',
#  'CRYGEP',
#  'CRYL1',
#  'CSDE1',
#  'CSH2',
#  'CSPG4',
#  'CSRP2',
#  'CSRP3',
#  'CST12P',
#  'CTAG1A',
#  'CTAG1B',
#  'CTDSP1',
#  'CTF1',
#  'CTNND1',
#  'CUL9',
#  'CUX1',
#  'CXADR',
#  'CXADRP1',
#  'CXCL14',
#  'CXCL8',
#  'CXCR1',
#  'CYCSP24',
#  'CYCSP38',
#  'CYCSP51',
#  'CYP2A13',
#  'CYP2A6',
#  'DAB2IP',
#  'DCTN4',
#  'DDT',
#  'DDX27',
#  'DDX3X',
#  'DEFB4A',
#  'DENR',
#  'DEPP1',
#  'DESI1',
#  'DFFB',
#  'DGKB',
#  'DGKE',
#  'DIAPH2',
#  'DIAPH3',
#  'DIRAS1',
#  'DKK3',
#  'DLAT',
#  'DNAAF3',
#  'DNAH5',
#  'DNAI1',
#  'DNAJC3',
#  'DOCK3',
#  'DOLK',
#  'DONSON',
#  'DSTYK',
#  'DTL',
#  'DUOXA1',
#  'DYNC1H1',
#  'EBNA1BP2',
#  'EBP',
#  'ECI2',
#  'EDA',
#  'EDARADD',
#  'EFS',
#  'EIF1',
#  'EIF2B1',
#  'EIF2B3',
#  'EIF2B4',
#  'EIF2B5',
#  'EIF4G2',
#  'ELMO1',
#  'ELMO2',
#  'ELMO3',
#  'ELOB',
#  'ELOC',
#  'EML5',
#  'ENOPH1',
#  'ENPP1',
#  'EPRS1',
#  'ERCC6L',
#  'ERCC6L2',
#  'EREG',
#  'ERGIC2',
#  'ESR1',
#  'EVA1C',
#  'EXOSC7',
#  'F2R',
#  'FAM111B',
#  'FAM138A',
#  'FAM138B',
#  'FAM138C',
#  'FAM138D',
#  'FAM138E',
#  'FAM138F',
#  'FAM72A',
#  'FANCD2',
#  'FBLIM1',
#  'FBXL4',
#  'FBXL5',
#  'FBXL7',
#  'FCGR2A',
#  'FCGR2B',
#  'FCGR3A',
#  'FCGR3B',
#  'FHL5',
#  'FIRRM',
#  'FKBP1B',
#  'FKBP2',
#  'FKBP5',
#  'FLNA',
#  'FLNB',
#  'FLNC',
#  'FLOT2',
#  'FOLH1',
#  'FOS',
#  'FOSB',
#  'FSCN1',
#  'FSTL1',
#  'FUBP1',
#  'GCA',
#  'GCG',
#  'GCLC',
#  'GEMIN4',
#  'GFER',
#  'GINS2',
#  'GIPC1',
#  'GJB6',
#  'GLDC',
#  'GLI3',
#  'GLS',
#  'GLUD1',
#  'GMCL2',
#  'GNAI3',
#  'GNL3',
#  'GOLT1A',
#  'GOLT1B',
#  'GOPC',
#  'GOSR1',
#  'GPAT3',
#  'GPHA2',
#  'GPSM3',
#  'GPX4',
#  'GRPR',
#  'GSTM1',
#  'GSTO1',
#  'GTF2E1',
#  'GTF2E2',
#  'GTF2F1',
#  'GTF2F2',
#  'GTF2F2P1',
#  'GTF2H1',
#  'GTF2H2',
#  'GTF2H3',
#  'GTF2H4',
#  'GTF2H5',
#  'GUCA1A',
#  'GYPB',
#  'GYPC',
#  'H2AB2',
#  'H2AB3',
#  'H2AC11',
#  'H2AC17',
#  'H2AC5P',
#  'H2AC8',
#  'H3C14',
#  'H3C3',
#  'H3C6',
#  'H3C9P',
#  'H3P11',
#  'H3P16',
#  'H3P17',
#  'H3P19',
#  'H3P23',
#  'H3P24',
#  'H3P30',
#  'H3P37',
#  'H3P38',
#  'H3P41',
#  'H3P42',
#  'H3P44',
#  'H3P45',
#  'H3P5',
#  'HACD1',
#  'HADHA',
#  'HAP1',
#  'HAVCR1',
#  'HCAR2',
#  'HCLS1',
#  'HCRTR2',
#  'HDAC2',
#  'HDAC3',
#  'HDAC8',
#  'HDLBP',
#  'HEATR5B',
#  'HEBP1',
#  'HHIP',
#  'HHLA2',
#  'HIP1',
#  'HIVEP1',
#  'HM13',
#  'HMGCL',
#  'HOOK2',
#  'HPCAL1',
#  'HSD17B1',
#  'HSD17B8',
#  'HTR1B',
#  'IAPP',
#  'ICAM1',
#  'ICE2',
#  'IFI44',
#  'IFTAP',
#  'IGF2BP1',
#  'IGF2BP2',
#  'IGHD5-12',
#  'IGKJ1',
#  'IGKJ2',
#  'IGKV1-12',
#  'IL12A',
#  'IL12B',
#  'IL17B',
#  'IL17F',
#  'IL1RL1',
#  'IL1RN',
#  'IL21',
#  'IL22',
#  'IL27',
#  'IL36A',
#  'IL36B',
#  'IL36RN',
#  'IL37',
#  'IL5',
#  'IL9',
#  'IMMP2L',
#  'ING1',
#  'INPP5K',
#  'ITFG1',
#  'ITGAL',
#  'ITGB2',
#  'JUN',
#  'KANK2',
#  'KAT5',
#  'KCNA3',
#  'KCNJ3',
#  'KCNJ5',
#  'KCNK1',
#  'KDM2A',
#  'KHDRBS1',
#  'KIAA1549L',
#  'KIF20B',
#  'KIF2A',
#  'KIFAP3',
#  'KLF6',
#  'KLHL1',
#  'KLK3',
#  'KLRG1',
#  'KMT2B',
#  'KMT2D',
#  'KPNB1',
#  'KRT12',
#  'KRT7',
#  'KTN1',
#  'LAMP3',
#  'LAMTOR1',
#  'LAMTOR2',
#  'LAMTOR3',
#  'LANCL1',
#  'LAP3',
#  'LETMD1',
#  'LGALS1',
#  'LGALS7',
#  'LGALS7B',
#  'LHCGR',
#  'LHX1',
#  'LILRB1',
#  'LILRB3',
#  'LINC00261',
#  'LINC00670',
#  'LINC02577',
#  'LIPC',
#  'LIPF',
#  'LLGL2',
#  'LMNA',
#  'LNPEP',
#  'LNPK',
#  'LPCAT1',
#  'LRATD2',
#  'LRIT1',
#  'LRP1',
#  'LRP10',
#  'LSAMP',
#  'LY6G6D',
#  'LY6G6F-LY6G6D',
#  'MAFK',
#  'MAGEC3',
#  'MAGI2',
#  'MAGT1',
#  'MANF',
#  'MAP3K10',
#  'MAPKAP1',
#  'MAPKAPK3',
#  'MAPRE1',
#  'MARCKSL1',
#  'MBOAT7',
#  'MCAT',
#  'MCF2L',
#  'MED1',
#  'MED10',
#  'MEIS2',
#  'MEIS3',
#  'MEIS3P1',
#  'METTL8',
#  'MIA',
#  'MIF',
#  'MINDY3',
#  'MIOS',
#  'MIP',
#  'MLH1',
#  'MLXIPL',
#  'MMEL1',
#  'MMP23A',
#  'MMP23B',
#  'MNAT1',
#  'MORF4L1P1',
#  'MPHOSPH10',
#  'MPZ',
#  'MRO',
#  'MRPL28',
#  'MRPS30',
#  'MS4A1',
#  'MSC-AS1',
#  'MSH2',
#  'MSH3',
#  'MSMB',
#  'MSX2',
#  'MT3',
#  'MTUS1',
#  'MTUS2',
#  'MUC1',
#  'MYBBP1A',
#  'MYL4',
#  'MYOZ1',
#  'NAA20',
#  'NAGLU',
#  'NAP1L1',
#  'NAPSA',
#  'NBAS',
#  'NCKIPSD',
#  'NCOA6',
#  'NDRG1',
#  'NDUFA3',
#  'NDUFB6',
#  'NDUFB7',
#  'NECTIN2',
#  'NELFE',
#  'NFKB2',
#  'NHLH2',
#  'NLRC4',
#  'NMBR',
#  'NONO',
#  'NOP2',
#  'NPEPPS',
#  'NPR2',
#  'NPR3',
#  'NR1I2',
#  'NR2E3',
#  'NRBP1',
#  'NRG4',
#  'NRP1',
#  'NRSN1',
#  'NSFL1C',
#  'NSG1',
#  'NSMCE2',
#  'NT5C',
#  'NT5C3A',
#  'NTRK1',
#  'NUP42',
#  'NUP62',
#  'NUPR1',
#  'NUPR2',
#  'NUSAP1',
#  'NXF1',
#  'NXT1',
#  'OLFM4',
#  'OPRPN',
#  'OR2A7',
#  'OR2A9P',
#  'OR7A1P',
#  'OR7A2P',
#  'OR7E4P',
#  'OR7E8P',
#  'OSBPL1A',
#  'OXSM',
#  'P2RY4',
#  'P4HB',
#  'PABPC1',
#  'PABPC1P3',
#  'PABPC3',
#  'PADI1',
#  'PAG1',
#  'PAM',
#  'PAMR1',
#  'PANK2',
#  'PAPPA',
#  'PARP1',
#  'PAX6',
#  'PBK',
#  'PBX2',
#  'PCNT',
#  'PCSK1',
#  'PCSK1N',
#  'PCSK4',
#  'PCYOX1',
#  'PDAP1',
#  'PDCD1',
#  'PDCD6IP',
#  'PDE7A',
#  'PDIA2',
#  'PDIA3',
#  'PDLIM3',
#  'PDZK1',
#  'PEX7',
#  'PFDN4',
#  'PHB2',
#  'PHETA1',
#  'PHF1',
#  'PHYH',
#  'PIAS1',
#  'PIK3R1',
#  'PIK3R3',
#  'PITRM1',
#  'PITX1',
#  'PITX2',
#  'PKD1',
#  'PKD2',
#  'PKN1',
#  'PKN2',
#  'PLAAT4',
#  'PLCL1',
#  'PLIN3',
#  'PLPPR3',
#  'PLPPR5',
#  'PLXNB1',
#  'PNRC1',
#  'POF1B',
#  'POLD4',
#  'POLE3',
#  'POLE4',
#  'POLR2E',
#  'POLR3E',
#  'POMC',
#  'POPDC2',
#  'POPDC3',
#  'POTEI',
#  'POTEJ',
#  'POTEM',
#  'POU2F1',
#  'POU2F2',
#  'POU5F1',
#  'PPBP',
#  'PPP1R12C',
#  'PPP1R13B',
#  'PPP1R14C',
#  'PPP1R14D',
#  'PPP4R3A',
#  'PPP4R3C',
#  'PPP5C',
#  'PPP6R2',
#  'PPP6R3',
#  'PRDX5',
#  'PRF1',
#  'PRODH',
#  'PROK1',
#  'PRPF38B',
#  'PRRC2A',
#  'PSEN1',
#  'PSIP1',
#  'PSMA2',
#  'PSMB6',
#  'PSMC2',
#  'PSMC3',
#  'PSMC5',
#  'PSMC6',
#  'PSMD10',
#  'PSMD12',
#  'PSMD3',
#  'PSMD7',
#  'PSMD9',
#  'PSMG1',
#  'PSPN',
#  'PTENP1',
#  'PTF1A',
#  'PTGDR',
#  'PTGFR',
#  'PTHLH',
#  'PTP4A1',
#  'PTP4A3',
#  'PTPRA',
#  'PTPRCAP',
#  'PTPRU',
#  'PTRH2',
#  'PTTG1',
#  'PUM3',
#  'PWAR1',
#  'PXDN',
#  'PXDNL',
#  'PYDC1',
#  'PYDC2',
#  'QTRT1',
#  'RAB14',
#  'RAB27A',
#  'RAB5IF',
#  'RAD23B',
#  'RALBP1',
#  'RAMAC',
#  'RASA1',
#  'RBCK1',
#  'RBM14',
#  'RBMS1',
#  'REG1A',
#  'REG3A',
#  'RERE',
#  'RET',
#  'RFC1',
#  'RFC4',
#  'RHOF',
#  'RIDA',
#  'RIGI',
#  'RIPK1',
#  'RIPK2',
#  'RLN3',
#  'RMDN1',
#  'RMND1',
#  'RMND5A',
#  'RMND5B',
#  'RNASEH2A',
#  'RNF2',
#  'RNF34',
#  'RNF5',
#  'RNPC3',
#  'RNU2-2P',
#  'RNU2-3P',
#  'RNU2-4P',
#  'RNU4-4P',
#  'RNU4-5P',
#  'RNU4-6P',
#  'RNU4-7P',
#  'RNU4-8P',
#  'RNU6-1',
#  'RNU6-50P',
#  'RNU6V',
#  'ROBO3',
#  'ROPN1L',
#  'RP1',
#  'RPAIN',
#  'RPL10',
#  'RPL19',
#  'RPL29',
#  'RPL29P31',
#  'RPLP0',
#  'RPLP1',
#  'RPP14',
#  'RPS12',
#  'RPS14',
#  'RPSA',
#  'S100A4',
#  'S100A8',
#  'S100A9',
#  'SBNO1',
#  'SBNO2',
#  'SCN1A',
#  'SCYL1',
#  'SDHA',
#  'SDS',
#  'SEC14L2',
#  'SECTM1',
#  'SEPTIN6',
#  'SEPTIN8',
#  'SERPINB6',
#  'SERPINE2',
#  'SF3B6',
#  'SHOX',
#  'SIK3',
#  'SIL1',
#  'SKIC2',
#  'SKP1',
#  'SKP1P1',
#  'SLA',
#  'SLBP',
#  'SLC16A1',
#  'SLC16A2',
#  'SLC16A3',
#  'SLC16A6',
#  'SLC16A8',
#  'SLC22A1',
#  'SLC22A2',
#  'SLC22A3',
#  'SLC25A19',
#  'SLC25A24',
#  'SLC25A3',
#  'SLC25A4',
#  'SLC25A5',
#  'SLC30A10',
#  'SLC30A8',
#  'SLC35G1',
#  'SLC36A1',
#  'SLC38A3',
#  'SLC38A4',
#  'SLC39A7',
#  'SLC46A1',
#  'SLC4A7',
#  'SLC4A8',
#  'SLC52A1',
#  'SLC52A2',
#  'SLC6A8',
#  'SLPI',
#  'SLU7',
#  'SMARCA1',
#  'SMARCA2',
#  'SMARCA4',
#  'SMARCA5',
#  'SMARCC1',
#  'SMARCC2',
#  'SMARCD1',
#  'SMARCD2',
#  'SMARCD3',
#  'SMN1',
#  'SMN2',
#  'SMR3B',
#  'SMYD1',
#  'SNCA',
#  'SNORA59A',
#  'SNORA59B',
#  'SNORA73A',
#  'SNORD13',
#  'SNORD13P1',
#  'SNORD13P3',
#  'SNORD3A',
#  'SNORD3B-1',
#  'SNORD3B-2',
#  'SNORD3P1',
#  'SNRPN',
#  'SNX24',
#  'SNX25',
#  'SOD2',
#  'SORBS1',
#  'SORL1',
#  'SPAG11A',
#  'SPAG11B',
#  'SPAG9',
#  'SPATA2',
#  'SPATA2L',
#  'SPCS3',
#  'SPEF1',
#  'SPG7',
#  'SPHKAP',
#  'SPINK5',
#  'SPPL3',
#  'SQSTM1',
#  'SRP68P2',
#  'SRP68P3',
#  'SRR',
#  'SRSF1',
#  'SRSF11',
#  'SRSF7',
#  'STING1',
#  'STK19',
#  'STK38',
#  'STMN1',
#  'SUB1',
#  'SYCP1',
#  'SYMPK',
#  'TAAR5',
#  'TACR1',
#  'TAF1',
#  'TAF1B',
#  'TAF1C',
#  'TAL1',
#  'TAOK3',
#  'TAP2',
#  'TAS1R1',
#  'TAS1R2',
#  'TAS2R13',
#  'TAS2R14',
#  'TBXAS1',
#  'TCF3',
#  'TCP11',
#  'TERC',
#  'TERF1',
#  'TFAMP1',
#  'TFAMP2',
#  'TFAP2C',
#  'TFDP1',
#  'TFF1',
#  'TFPI2',
#  'THNSL1',
#  'THNSL2',
#  'THRSP',
#  'TIMELESS',
#  'TLE1',
#  'TLE2',
#  'TLN1',
#  'TLN2',
#  'TMEM132A',
#  'TMEM158',
#  'TMPRSS11D',
#  'TNFRSF11B',
#  'TNFRSF14',
#  'TNFRSF1B',
#  'TNFRSF25',
#  'TNNI2',
#  'TNPO1',
#  'TNXA',
#  'TNXB',
#  'TOB1',
#  'TOB2',
#  'TOR1AIP1',
#  'TP53INP1',
#  'TP63',
#  'TPM3',
#  'TPPP2',
#  'TPTE',
#  'TRAF3',
#  'TRAM1',
#  'TRAPPC2',
#  'TRAPPC9',
#  'TRAV25',
#  'TRAV26-2',
#  'TRAV31',
#  'TRAV35',
#  'TRAV4',
#  'TRAV40',
#  'TRBV11-1',
#  'TRBV14',
#  'TRBV2',
#  'TRBV20-1',
#  'TRBV21-1',
#  'TRBV27',
#  'TRGJ1',
#  'TRGJ2',
#  'TRGV5P',
#  'TRGV6',
#  'TRIB1',
#  'TRIB3',
#  'TRIP4',
#  'TSACC',
#  'TSC1',
#  'TSHZ1',
#  'TSHZ2',
#  'TSPY1',
#  'TSPY3',
#  'TTK',
#  'TTTY11',
#  'TTTY12',
#  'TUSC2',
#  'TXNRD2',
#  'UBE2A',
#  'UBE2B',
#  'UBE2G1',
#  'UBE2G2',
#  'UBE4A',
#  'UBE4B',
#  'UBXN1',
#  'UCN2',
#  'UGCG',
#  'UGDH',
#  'UHRF2',
#  'ULK4P1',
#  'ULK4P2',
#  'ULK4P3',
#  'UNC119',
#  'UNC50',
#  'UPK3B',
#  'UQCRB',
#  'UQCRFS1',
#  'UQCRQ',
#  'USO1',
#  'USP14',
#  'USP39',
#  'UTRN',
#  'UTS2B',
#  'UXS1',
#  'VCP',
#  'VPS45',
#  'VSIR',
#  'WDR1',
#  'WDR77',
#  'YIPF3',
#  'YTHDF2',
#  'YTHDF2P1',
#  'YWHAQ',
#  'YY1',
#  'ZBTB18',
#  'ZFP36',
#  'ZFP36L1',
#  'ZGLP1',
#  'ZMPSTE24',
#  'ZMYM1',
#  'ZMYM2',
#  'ZMYM3',
#  'ZMYM4',
#  'ZMYM6',
#  'ZNF197',
#  'ZNF382',
#  'ZNF513',
#  'ZNF585A',
#  'ZNF585B',
#  'ZNRD2',
#  'ZRSR2'}

# %%
len(common_aa_collisions)
# Out:
# 995

# %% [markdown]
# # DGIdb ambiguous query

# %%
merged_alias_primary_collisions_df = pd.read_csv("merged_alias_gene_intersections.csv", na_values=['', 'NULL'], keep_default_na= False)
merged_alias_primary_collisions_df
# Out:
#      gene_symbol      alias_symbol intersect_point source
# 0          SOAT2             ACAT2           ACAT2   HGNC
# 1         ACTBP8            ACTBP2          ACTBP2   HGNC
# 2          APPL1              APPL            APPL   HGNC
# 3         AKR1B1                AR              AR   HGNC
# 4        B3GNTL1            B3GNT8          B3GNT8   HGNC
# ...          ...               ...             ...    ...
# 2021       USP21      USP23, USP16           USP16   ENSG
# 2022       USP25             USP21           USP21   ENSG
# 2023     VDAC1P5     VDAC5P, VDAC3           VDAC3   ENSG
# 2024      XBP1P1       XBPP1, XBP1            XBP1   ENSG
# 2025    ZNF322P1   ZNF322B, ZNF322          ZNF322   ENSG
#
# [2026 rows x 4 columns]

# %%
ag_collision_set = set(merged_alias_primary_collisions_df["intersect_point"])

# %%
dgidb_gene_df = pd.read_csv("dgidb_genes_JUNE.tsv", sep='\t', na_values=['', 'NULL'], keep_default_na= False)
dgidb_gene_df
# Out:
#       gene_claim_name    nomenclature  concept_id gene_name source_db_name  \
# 0              NGFIBA  NCBI Gene Name         NaN       NaN       BaderLab
# 1              NGFIBB  NCBI Gene Name         NaN       NaN       BaderLab
# 2                 DAX  NCBI Gene Name         NaN       NaN       BaderLab
# 3            REV-ERBA  NCBI Gene Name         NaN       NaN       BaderLab
# 4               COUP2  NCBI Gene Name         NaN       NaN       BaderLab
# ...               ...             ...         ...       ...            ...
# 80229             KIT     Gene Symbol   hgnc:6342       KIT       Oncomine
# 80230            HES1       Gene Name   hgnc:5192      HES1            NCI
# 80231            IRF1     Gene Symbol   hgnc:6116      IRF1         Tempus
# 80232           SHFM1       Gene Name  hgnc:10845      SEM1            DTC
# 80233         NEUROD1       Gene Name   hgnc:7762   NEUROD1            NCI
#
#       source_db_version
# 0                Feb-14
# 1                Feb-14
# 2                Feb-14
# 3                Feb-14
# 4                Feb-14
# ...                 ...
# 80229                v3
# 80230         14-Sep-17
# 80231         11-Nov-18
# 80232            9/2/20
# 80233         14-Sep-17
#
# [80234 rows x 6 columns]

# %%
dgidb_gene_df.query('gene_name != gene_claim_name')
# Out:
#                gene_claim_name     nomenclature  concept_id gene_name  \
# 0                       NGFIBA   NCBI Gene Name         NaN       NaN
# 1                       NGFIBB   NCBI Gene Name         NaN       NaN
# 2                          DAX   NCBI Gene Name         NaN       NaN
# 3                     REV-ERBA   NCBI Gene Name         NaN       NaN
# 4                        COUP2   NCBI Gene Name         NaN       NaN
# ...                        ...              ...         ...       ...
# 79999                    SEPT5      Gene Symbol   hgnc:9164   SEPTIN5
# 80014  ENSEMBL:ENSG00000185821  Ensembl Gene ID  hgnc:31305    OR6C76
# 80053                    SEPT5      Gene Symbol   hgnc:9164   SEPTIN5
# 80166                    SEPT6      Gene Symbol  hgnc:15848   SEPTIN6
# 80232                    SHFM1        Gene Name  hgnc:10845      SEM1
#
#                    source_db_name source_db_version
# 0                        BaderLab            Feb-14
# 1                        BaderLab            Feb-14
# 2                        BaderLab            Feb-14
# 3                        BaderLab            Feb-14
# 4                        BaderLab            Feb-14
# ...                           ...               ...
# 79999          FoundationOneGenes            9/3/20
# 80014                  RussLampel         26-Jul-11
# 80053  CarisMolecularIntelligence            9/4/20
# 80166  CarisMolecularIntelligence            9/4/20
# 80232                         DTC            9/2/20
#
# [16052 rows x 6 columns]

# %% [markdown]
# claims without a symbol/name/identifier
#  (there shouldn't be any hooray)

# %%
no_claim_symbols_df = dgidb_gene_df[dgidb_gene_df['gene_claim_name'].isnull()]
no_claim_symbols_df
# Out:
# Empty DataFrame
# Columns: [gene_claim_name, nomenclature, concept_id, gene_name, source_db_name, source_db_version]
# Index: []

# %% [markdown]
# un normalized

# %%
no_name_symbols_df = dgidb_gene_df[dgidb_gene_df['gene_name'].isnull()]
no_name_symbols_df
# Out:
#           gene_claim_name    nomenclature concept_id gene_name source_db_name  \
# 0                  NGFIBA  NCBI Gene Name        NaN       NaN       BaderLab
# 1                  NGFIBB  NCBI Gene Name        NaN       NaN       BaderLab
# 2                     DAX  NCBI Gene Name        NaN       NaN       BaderLab
# 3                REV-ERBA  NCBI Gene Name        NaN       NaN       BaderLab
# 4                   COUP2  NCBI Gene Name        NaN       NaN       BaderLab
# ...                   ...             ...        ...       ...            ...
# 29008  URS00006E35E8_9606     Gene Symbol        NaN       NaN             GO
# 29009  URS0000EA3BA1_9606     Gene Symbol        NaN       NaN             GO
# 29198   TRYPTASE_B2_HUMAN     Gene Symbol        NaN       NaN             GO
# 29199   TRYPTASE_B1_HUMAN     Gene Symbol        NaN       NaN             GO
# 29389           HERVK_113     Gene Symbol        NaN       NaN         Pharos
#
#       source_db_version
# 0                Feb-14
# 1                Feb-14
# 2                Feb-14
# 3                Feb-14
# 4                Feb-14
# ...                 ...
# 29008         10-Apr-24
# 29009         10-Apr-24
# 29198         10-Apr-24
# 29199         10-Apr-24
# 29389         10-Apr-24
#
# [2144 rows x 6 columns]

# %%
dgidb_name_set = set(dgidb_gene_df['gene_name'])
len(dgidb_name_set)
# Out:
# 12001

# %%
dgidb_gene_claim_name_set = set(dgidb_gene_df['gene_claim_name'])
len(dgidb_gene_claim_name_set)
# Out:
# 26739

# %%
hgnc_ensg_gene_symbol_set = hgnc_gene_symbol_set.union(ensg_gene_symbol_set)

# %%
hgnc_ensg_ncbi_gene_symbol_set = hgnc_ensg_gene_symbol_set.union(ncbi_gene_symbol_set)

# %%
hgnc_ensg_alias_symbol_set = hgnc_alias_symbol_set.union(ensg_alias_symbol_set)

# %%
hgnc_ensg_ncbi_alias_symbol_set = hgnc_ensg_alias_symbol_set.union(ncbi_alias_symbol_set)

# %%
print(len(aa_collision_set.intersection(ag_collision_set)))
# Out:
# 161

# %%
ambiguous_symbol_set = aa_collision_set.union(ag_collision_set)
print(len(ambiguous_symbol_set))
# Out:
# 5865

# %%
ambiguous_symbol_set = set(item.strip() for item in ambiguous_symbol_set)

print(len(ambiguous_symbol_set))
# Out:
# 5050

# %%
ambiguous_symbol_set
# Out:
# {'TF',
#  'MYO1C',
#  'CPAD',
#  'CYPH',
#  'PRAP',
#  'TRMT1',
#  'LPCAT4',
#  'GPRASP3',
#  'APC, PC',
#  'PBS',
#  'H2B/s',
#  'CEACAM3',
#  'GCP2',
#  'SR',
#  'H2BC10, H2BC4, H2BC6, H2BC7',
#  'HRES-1',
#  'CMT2B2',
#  'DAGK5',
#  'HSD17',
#  'FRAXE',
#  'PWCR',
#  'KCNJN1',
#  'SPC3',
#  'SKD2',
#  'rpL7a',
#  'PRR23D2',
#  'PP',
#  'U7',
#  'HLA-DQB1',
#  'MFT',
#  'CCA1',
#  'FAM90A16P',
#  'FABP5P1',
#  'P65',
#  'p23',
#  'HCA3',
#  'GCCD2',
#  'H2BC4, H2BC6, H2BC7, H2BC8',
#  'DSC1, DSC2',
#  'NET4',
#  'ZNT8',
#  'RK',
#  'CLS',
#  'p67',
#  'DHX40P1, TBC1D3P1',
#  'FAM25C',
#  'CAB',
#  'FAM28A',
#  'TSPY',
#  'HRH1',
#  'ZIP2',
#  'U3a',
#  'OFC2',
#  'M6A',
#  'LIP1',
#  'TK2',
#  'SCNM1',
#  'MAGEE1',
#  'TTY11',
#  'CRP1',
#  'EPO',
#  'UBH1',
#  'TER',
#  'NIPA2',
#  'NET2',
#  'HZF3',
#  'H4C8',
#  'CHC',
#  'HE',
#  'AG1',
#  'ACF',
#  'GGF2',
#  '464.2',
#  'RAX',
#  'SMG',
#  'RCK',
#  'FRMPD2',
#  'CXorf51B',
#  'p33',
#  'USE1',
#  'PRX',
#  'H4',
#  'DOC-1',
#  'HBK',
#  'SAST',
#  'FADS3',
#  'MCP2',
#  'TIP',
#  'H2B/g',
#  'STAG3L1, STAG3L3',
#  'S31III125',
#  'NBPF',
#  'OR7-21',
#  'MRXSMP',
#  'SRC1',
#  'CIP1',
#  'eIF-2gA',
#  'SYT11',
#  'U13',
#  'C10orf77',
#  'DP1',
#  'SCP3',
#  'MOB1',
#  'MYP4',
#  'UFM1P1',
#  'WASF4',
#  'ARP2',
#  'SRGAP3',
#  'BTR',
#  'AN',
#  'TMEFF1',
#  'CRYAA',
#  'GM2AP',
#  'IMPDH1',
#  'K7',
#  'G3PP',
#  'OLFRA06',
#  'FLJ20375',
#  'CSN3',
#  'TCRBV12S2',
#  'P120',
#  'HYPF',
#  'TRN2',
#  'CRIP',
#  'ODF2',
#  'MRP-L15',
#  'TLL',
#  'SCC1',
#  'SLC23A2',
#  'THY1-AS1',
#  'p57',
#  'AP3Aase',
#  'FSSV',
#  'GRIN1',
#  'LECD',
#  'MCRIP2P1',
#  'TP53TG3E, TP53TG3F',
#  'PGAM-B',
#  'P220',
#  'p34',
#  'TTC30B',
#  'GIF',
#  'DC7',
#  'GALNT4',
#  'GGT',
#  'CED-12',
#  'SPP2',
#  'IF',
#  'RPEL1',
#  'MRD4',
#  'PEO',
#  'C2, SNRPC',
#  'ZNF2',
#  'UOG1',
#  'P2RY11, PPAN',
#  'BAT1',
#  'LGS',
#  'AGS2',
#  'UGT1A',
#  'CAPS',
#  'ERK',
#  'FOXL3',
#  'KOX5',
#  'RPP2',
#  'PTA',
#  'LCA10',
#  'ECK',
#  'HAS',
#  'ARG',
#  'RPL10',
#  'EVR1',
#  'CBBM',
#  'CD20',
#  'ACN',
#  'TRYP2',
#  'TRH-GTG1-6',
#  'EIG7',
#  'CTHM',
#  'CYP2D6',
#  'STK7',
#  'p60',
#  'CRL1',
#  'IGHD1B',
#  'TRD-GTC2-8',
#  'PTE2',
#  'MIFR',
#  'MRX88',
#  'HBP',
#  'CSNK2A1',
#  'p19',
#  'M-PST',
#  'CLP1',
#  'COAS3',
#  'OR912-108',
#  'DESI2',
#  'DGPT',
#  'MIR1291',
#  'TS',
#  'CFC',
#  'TCEB1P26',
#  'RNU1P2',
#  'PIT-1',
#  'HPS',
#  'LAG1',
#  'H3-3B',
#  'PRG2, PXN',
#  'MVP',
#  'ACAT2',
#  'TRR-ACG1-3',
#  'KIAA0705',
#  'LP',
#  'H4C13',
#  'MBD3',
#  'ADAM18',
#  'TRR-ACG1-2',
#  'TCRAV18S1',
#  'PSD',
#  'CLCP1',
#  'NIRF',
#  'CDH16',
#  'PASK',
#  'SRK',
#  'S7',
#  'RASSF4',
#  'NS',
#  'H2AC19',
#  'IMP3',
#  'HOD',
#  'C15orf38',
#  'DEFB136',
#  'EP',
#  'FAME2',
#  'ACTBL1',
#  'C7orf70',
#  'PM5',
#  'TAK1',
#  'CCL4L',
#  'EPP',
#  'MTF',
#  'TRX-CAT1-6',
#  'DBC1',
#  'FTX',
#  'FLJ10052',
#  'MLN',
#  'YRRM2',
#  'TRF',
#  'SL1',
#  'TMP21',
#  'p18',
#  'C1orf175',
#  'LONP',
#  'INPP5F',
#  'NRAP',
#  'MRP7',
#  'GP1BB',
#  'OBTP',
#  'PRR',
#  'DR4',
#  'HSP70-1',
#  'APG1',
#  'AIP1',
#  'SGT2',
#  'H4C1, H4C11, H4C12, H4C14, H4C15, H4C16, H4C2, H4C3, H4C4, H4C5, H4C6, H4C8, H4C9',
#  'ESG1',
#  'PCTAIRE',
#  'AIS',
#  'PKR2',
#  'ST1A3/ST1A4',
#  'p110',
#  'OR11-22',
#  'CLK-1',
#  'TRFP',
#  'EMILIN3',
#  'LAT1',
#  'FIP1',
#  'MTMR8',
#  'CAR',
#  'HCP1',
#  'M-FABP',
#  'FAD',
#  'HRS',
#  'TRF-GAA1-6',
#  'MAS1',
#  'PCP2',
#  'TAP1',
#  'RPA1',
#  'GFAT',
#  'OPG',
#  'CTR1',
#  'ATDC',
#  'CLAC',
#  'GALNT7',
#  'ULG5',
#  'MTTP',
#  'IPS-1',
#  'G6PT',
#  'LPLAT',
#  'CT1.2',
#  'L19',
#  'ALDH7',
#  'MIP-1-beta',
#  'HBP-3',
#  'DP2',
#  'TPSB2',
#  'ATR1',
#  'DAGK6',
#  'PSGGA',
#  'TRP2',
#  'H-REV107',
#  'SWS1',
#  'H1',
#  'RGP1, RGPD2',
#  'BHD',
#  'GUP1',
#  'FB',
#  'oda6',
#  'RNU1-7',
#  'C10orf2',
#  'GLUT8',
#  'FAST',
#  'LPSAT',
#  'GLS',
#  'ATP5A',
#  'RAB1',
#  'OR9G1',
#  'NPIPA8',
#  'F379',
#  'QPC',
#  'L2',
#  'RN28S1',
#  'GOLGA5',
#  'PRR23D1',
#  'TFIIA',
#  'CAT2',
#  'MMP21',
#  'POP2',
#  'AMD',
#  'MN',
#  'TSG',
#  'SSB2',
#  'KOX31',
#  'HET',
#  'STAG3L2',
#  'BTF2',
#  'NSP2',
#  'SOAT',
#  'SRA',
#  'GAT3',
#  'TRY1',
#  'GAR1',
#  'MYZAP',
#  'B5',
#  'PRPH',
#  'PUM',
#  'EBS4',
#  'L22',
#  'CLL1',
#  'RIF1',
#  'CYP2G2P',
#  'NLF1',
#  'USP17',
#  'WAGR',
#  'CT6.1',
#  'FCGR2C',
#  'MRX95',
#  'SLEB6',
#  'BEX1',
#  'SLK',
#  'HSR1',
#  'BCS1',
#  'SMA3',
#  'TTY9',
#  'GJA10',
#  'RFP2',
#  'RIS1',
#  'RNASE4',
#  'TAMO',
#  'TRP-AGG2-8',
#  'BCL5',
#  'H2BFK',
#  'SUR2',
#  'HNRNP-G',
#  'MASA',
#  'RPL17',
#  'SLA',
#  'PHLP3',
#  'DVL1L1',
#  'CLK1',
#  'CTNND1',
#  'FA',
#  'GTK',
#  'HCCA2',
#  'CD98',
#  'Sno',
#  'DCP1',
#  'SPANXC',
#  'CXorf2',
#  'IL-23',
#  'GP110',
#  'RPP20',
#  'SDH1',
#  'H3C12',
#  'RIP-1',
#  'BD-3',
#  'OCTD',
#  'B9',
#  'P67',
#  'POR',
#  'TRI-AAT5-1',
#  'TEL2',
#  'DEC1',
#  'OCIF',
#  'TVP23C',
#  'UBC4',
#  'HLA-DRB',
#  'ICR',
#  'DSH',
#  'CSRP2BP',
#  'HDGF-2',
#  'PNUTL3',
#  'KRTAP18-9',
#  'IFN-alpha-REC',
#  'CABP1',
#  'PACT',
#  'DEFB109',
#  'ANKRD33',
#  'PAT1',
#  'LINC00470',
#  'HLS',
#  'FAS',
#  'HSTF1',
#  'CLA20',
#  'NRP1',
#  'XCE',
#  'MIR17HG',
#  'DDH2',
#  'ICBP90',
#  'APC7',
#  'H2-ALPHA',
#  'TICAM-2',
#  'TSP1',
#  'GLCT1',
#  'RhoGAP2',
#  'ODC',
#  'DGCR6',
#  'SULT1C2',
#  'TAF4B',
#  'SEMAL',
#  'NECC1',
#  'OR11-11a',
#  'CAK',
#  'DDC8',
#  'VWS1',
#  'HH1',
#  'APM-1',
#  'GAGE2',
#  'MTP',
#  'BBP',
#  'TRNAQ49P',
#  'SP3',
#  'MIR499A',
#  'ABP1',
#  'DA2B',
#  'FAM138F',
#  'EBS1',
#  'ODC1',
#  'FRA10A',
#  'BTF4',
#  'RPL29P3',
#  'RNASEH1, RNH1',
#  'TCRAV25S1',
#  'RNU1',
#  'p21',
#  'FGF2',
#  'ACS3',
#  'BTF3',
#  'INT1',
#  'P-PST',
#  'GP',
#  'ARC34',
#  'GPR58',
#  'B4',
#  'TRP-TGG3-1',
#  'LYPLAL1-AS1',
#  'ST7',
#  'BCAM',
#  'ETL1',
#  'TEN1',
#  'TRV-CAC5-1',
#  'PRR20A, PRR20B, PRR20D, PRR20E',
#  'FBL4',
#  'NOTCH2NL',
#  'FBL7',
#  'HPCA',
#  'RFMN',
#  'BOP',
#  'DGCR',
#  'SP17',
#  'NDPP1',
#  'MIFR-1',
#  'MCM2',
#  'FOP',
#  'MAGE2',
#  'ES31',
#  'SLC24A2',
#  'DTR',
#  'CBS',
#  'PS1',
#  'RBP',
#  'RP2',
#  'HEPIS',
#  'MCM',
#  'B3GNT1',
#  'PAMP',
#  'ZNF230',
#  'GC1',
#  'AT1',
#  'SYN',
#  'TPH2',
#  'NSP',
#  'TL-PST',
#  'SARS',
#  'PSM',
#  'SMUC',
#  'ART',
#  'C17DUPp13.3',
#  'NBIA4',
#  'PAR-1',
#  'SET7',
#  'KRTHB1',
#  'PAN2',
#  'KAP2.3',
#  'FBL5',
#  'TCEB3L2',
#  'LAP1',
#  'CHMP4A',
#  'HSST2',
#  'BIP',
#  'VDR',
#  'ZSCAN31',
#  'EJM',
#  'CHP',
#  'CHMP4B',
#  'IMD28',
#  'CANP',
#  'AD1',
#  'EDH17B2',
#  'M-ABC2',
#  'TMED10',
#  'HH',
#  'FGQTL2',
#  'C9',
#  'SSAO',
#  'CYK4',
#  'UGT-1C',
#  'BCS',
#  'HARP',
#  'PSCTK2',
#  'TUBB4',
#  'CSRP',
#  'NET3',
#  'FGQTL3, GK',
#  'ICIS',
#  'RNH1',
#  'MOX2',
#  'SYD1',
#  'FCG1',
#  'GLUT10',
#  'p220',
#  'MMP-25',
#  'FRAXA',
#  'PACER',
#  'PHS2',
#  'POST',
#  'SPH2',
#  'LACS2',
#  'BPAD',
#  'DIFF6',
#  'STAG3L2, STAG3L3',
#  'TNRC18',
#  'RT6',
#  'GCP-1',
#  'HGF',
#  'HBD3',
#  'EWSR2',
#  'MEP',
#  'env',
#  'p63',
#  'MIP-2A',
#  'WT2',
#  'TBC1D3C, TBC1D3D',
#  'PKB',
#  'CPT1-M',
#  'SNORA58B',
#  'NIF',
#  'AGS1',
#  'SAP130',
#  'PSBG-11',
#  'CT45A2, CT45A8',
#  'OR11-11A',
#  'CTLA1',
#  'LEU1',
#  'CPSQ3',
#  'ALDC',
#  'SEMAF',
#  'FABP5',
#  'TRS-AGA2-6',
#  'TCI',
#  'CRA',
#  'POLR1C',
#  'VWS2',
#  'CT45-5',
#  'PRH1',
#  'RNU12',
#  'MRPL22',
#  'RITA',
#  'SST2',
#  'PE',
#  'RAI1',
#  'CPX2',
#  'DA1',
#  'CA11',
#  'DSC1',
#  'BA548K23.1',
#  'MPD3',
#  'DELTA',
#  'MIR198',
#  'POTEB',
#  'HCRTR2',
#  'hBD-4',
#  'BETA2',
#  'HH13',
#  'RNR1',
#  'p45',
#  'TCEB1L',
#  'TRY4',
#  'LIG3',
#  'CAK1',
#  'RTA',
#  'HCI',
#  'CDH3',
#  'H2A/q',
#  'KLIP1',
#  'LIMS3L',
#  'CYP2D7AP',
#  'K8',
#  'TRL-AAG2-1, TRNP1',
#  'DBM',
#  'P27',
#  'IL8RA',
#  'PYPAF7',
#  'SPO',
#  'GJE1',
#  'HCF2',
#  'ARL17A',
#  'TDGF2',
#  'PAD',
#  'RAY',
#  'MT-A70',
#  'PC3',
#  'E2-1',
#  'SM25H2',
#  'PAD1',
#  'R2',
#  'PSG10',
#  'PL',
#  'ASPS',
#  'MEGT1',
#  'SMS',
#  'SIL',
#  'HLA-DPB1',
#  'PGI',
#  'C11orf3',
#  'HN1L',
#  'IDD',
#  'TLP',
#  'GSG1',
#  'ATP1A1',
#  'AU',
#  'RASSF3',
#  'OR7E68P',
#  'ALK1',
#  'RNA18SP',
#  'PSF1',
#  'LNP1',
#  'P37',
#  'INT3',
#  'PAFAH',
#  'IFI-4',
#  'PLCE',
#  'S100',
#  'ATF1',
#  'COX11',
#  'HB1',
#  'FADS2',
#  'INPP5E',
#  'UGT1E',
#  'TP53TG3C',
#  'SCKL4',
#  'ISO1',
#  'SAX2',
#  'G2',
#  'CD25',
#  'RCA1',
#  'T2D',
#  'CCZ1',
#  'ALS2CR3',
#  'DNM1DN8@',
#  'SMIT2',
#  'p48',
#  'ESO1',
#  'OLF4p',
#  '67LR',
#  'FAM47E',
#  'PCL',
#  'SRBC',
#  'HTT',
#  'TFIIIB90',
#  'DFNA2',
#  'COQ8',
#  'EEF1AL',
#  'KIR2DS5',
#  'DUSP13',
#  'OR1D4',
#  'BXDC3',
#  'ADCY3',
#  'RIP',
#  'RGP3',
#  'ARIA',
#  'S4',
#  'HCP5',
#  'HRAS1',
#  'dJ388M5',
#  'IQCH',
#  'SCA8',
#  'BD-5',
#  'RGR',
#  'RIG1',
#  'TSH2',
#  'ADPRTL3',
#  'CRD',
#  'SAE2',
#  'IL-7',
#  'GLM1',
#  'HBAB',
#  'RAB4B',
#  'TCRAV22S1',
#  'TRAC',
#  'PTPA',
#  'PED',
#  'U3b1',
#  'STA',
#  'DIP1',
#  'PPD',
#  'HHM',
#  'SAA2',
#  'TRF2',
#  'THM',
#  'WSS',
#  'Rsc6p',
#  'FSP1',
#  'CT1',
#  'SFPQ',
#  'H3C1',
#  'LAK',
#  'TFP',
#  'D3',
#  'H4C3',
#  'AMP',
#  'ACTL6',
#  'PIG3',
#  'OR7E75P',
#  'FHC',
#  'U1P2A',
#  'OB1',
#  'CKR-1',
#  'CDK11-p46',
#  'ADAMTS-2',
#  'RNU6-6',
#  'TRAC1',
#  'ZNF264',
#  'ACS',
#  'ighv',
#  'P34',
#  'GASP-1',
#  'TRD-GTC2-11',
#  'RER',
#  'JP1',
#  'FZD3',
#  'FPS',
#  'NEUROPSIN',
#  'NOP',
#  'GLUR3',
#  'L14',
#  'FHL5',
#  'KSP37',
#  'CSD',
#  'GTF2IRD2A',
#  'OR4F18',
#  'NME1',
#  'S11',
#  'CD16A',
#  'EVA',
#  'SOSS-B1',
#  'LRP10',
#  'L5',
#  'BRIGHT',
#  'NP',
#  'HAS1',
#  'RNF35',
#  'MED24',
#  'U3b2',
#  'PKNOX2-AS1',
#  'P200',
#  'MLD',
#  'CDS1',
#  'CDC25',
#  'SAX3',
#  'RGP4',
#  'BRF-1',
#  'ELOA3',
#  'KMT3G',
#  'BIS',
#  '35DAG',
#  'NRP2',
#  'ADORA2',
#  'VMA10',
#  'GAGE7B',
#  'UNQ192',
#  'BD-6',
#  'RING2',
#  'F3',
#  'ATX',
#  'SHP1',
#  'TCRAV11S1',
#  'P5',
#  'BCH',
#  'P56',
#  'TTY6',
#  'PGII',
#  'CT45A5, CT45A7',
#  'CREB2',
#  'SMAP',
#  'AP47B',
#  'PHKD',
#  'LAP',
#  'TC-1',
#  'SCP1',
#  'GLP-1',
#  'KRTAP2-3',
#  'FIH1',
#  'PLA2L',
#  'FJHN',
#  'ADC',
#  'DIVA',
#  'MGAT1',
#  'VP',
#  'MyD88-4',
#  'P160',
#  'TIM1',
#  'NLS1',
#  'HLA-HA2',
#  'OFD1P2',
#  'MMP23A',
#  'TARG1',
#  'TRP-AGG2-2',
#  'SMRP',
#  'S14',
#  'CP11',
#  'DRP-1',
#  'CD34',
#  'LCP1',
#  'NBP1',
#  'L31',
#  'SIGLECP1',
#  'H2AC15',
#  'FCGR3B',
#  'IGHV3-3',
#  'CRN',
#  'KCR1',
#  'KS',
#  'ZNF32',
#  'EIF2',
#  'CIC',
#  'AT744.2',
#  'LILRA6',
#  'GBP',
#  'PTPRZ',
#  'PRIP',
#  'KS1',
#  'KRTAP5-6',
#  'FCT3A',
#  'PDK1, PDPK2P',
#  'TRNP1, TRP-AGG2-3',
#  'SMF',
#  'BRWD2',
#  'ST1A4',
#  'PRR20C',
#  'SMAD1',
#  'RP58',
#  'CPA6',
#  'ABC1',
#  'FAE',
#  'STAG3L1, STAG3L2',
#  'UGT-1A',
#  'PFM1',
#  'P48',
#  'RSC6P',
#  'C82',
#  'GRINL1A',
#  'CAP',
#  'CSS3',
#  'CTSO1',
#  'MRG1',
#  'ETL4',
#  'CLMF',
#  'PRR20A, PRR20B, PRR20C, PRR20E',
#  'CIA',
#  'NEU',
#  'BB2',
#  'D6S230E',
#  'PEPP1',
#  'FLJ10883',
#  'CALML2',
#  'NY-ESO-1',
#  'STV1',
#  'AAC2',
#  'PTPU2',
#  'MTS',
#  'NK3',
#  'DESI1',
#  'TRIP1',
#  'CXorf11',
#  'VATB',
#  'TRAP-1',
#  'ZFP91',
#  'OA3',
#  'AOS1',
#  'DEFB4',
#  'PCA1',
#  'S8',
#  'NAP1L',
#  'KOX2',
#  'DUX1',
#  'RLP1',
#  'ASNSD1',
#  'GCCD3',
#  'HSPA1',
#  'AGPAT8',
#  'NAPA',
#  'NAT3',
#  'PIGU',
#  'IAP',
#  'CSA',
#  'C11orf52',
#  'Oct-3',
#  'HL1',
#  'IGEL',
#  'CPP',
#  'TRH-GTG1-8',
#  'MSP',
#  'CT4.4',
#  'TCRAV1S2',
#  'PEX1',
#  'MIHC',
#  'POTE2BETA',
#  'BCD1',
#  'AT3',
#  'POLK',
#  'SCZD9',
#  'MRX2',
#  'U14',
#  'HCAP',
#  'HC3',
#  'HSDJ0798C17',
#  'LGALS7',
#  'CDH7',
#  'AIDA',
#  'PAC1',
#  'PAN3',
#  'ARP8',
#  'HAP40',
#  'CT134',
#  'DFNB26',
#  'NAT1',
#  'G18',
#  'PIG4',
#  'MUHH',
#  'HP-1',
#  'FBL2',
#  'PCL1',
#  'TTTY9',
#  'FAM25A, FAM25C, FAM25G',
#  'ORC1',
#  'CDR',
#  'DFNA3',
#  'REX1',
#  'PP17',
#  'TRH-GTG1-7',
#  'TCRAV32S1',
#  ...}

# %%
with open('ambiguous_symbol_set.txt', 'w') as file:
    for item in ambiguous_symbol_set:
        file.write(f"{item.strip()}\n")

# %%
with open('ambiguous_symbol_set.txt', 'r') as file:
    # Read each line, strip newline characters, and convert to a set
    ambiguous_symbol_set = set(line for line in file)
len(ambiguous_symbol_set)
# Out:
# 5050

# %% [markdown]
# # May or may not be nonesense

# %%
name_ensg_notmatch = dgidb_name_set.difference(ensg_gene_symbol_set)
len(name_ensg_notmatch)
# Out:
# 298

# %%
gene_claim_name_ensg_notmatch = dgidb_gene_claim_name_set.difference(ensg_gene_symbol_set)
len(gene_claim_name_ensg_notmatch)
# Out:
# 15029

# %%
cleaned_gene_claim_name_ensg_notmatch = [x for x in gene_claim_name_ensg_notmatch if str(x) != 'NaN']
len(cleaned_gene_claim_name_ensg_notmatch)
# Out:
# 15029

# %%
name_hgnc_notmatch = dgidb_name_set.difference(hgnc_gene_symbol_set)
len(name_hgnc_notmatch)
# Out:
# 25

# %%
name_hngc_notmatch_aacollision = name_hgnc_notmatch.intersection(hgnc_alias_alias_collision_set)
len(name_hngc_notmatch_aacollision)
# Out:
# 0

# %%
cleaned_name_hgnc_notmatch = [x for x in name_hgnc_notmatch if str(x) != 'NaN']
len(cleaned_name_hgnc_notmatch)
# Out:
# 25

# %%
gene_claim_name_hgnc_notmatch = dgidb_gene_claim_name_set.difference(hgnc_gene_symbol_set)
len(gene_claim_name_hgnc_notmatch)
# Out:
# 14755

# %%
name_ncbi_notmatch = dgidb_name_set.difference(ncbi_gene_symbol_set)
len(name_ncbi_notmatch)
# Out:
# 97

# %%
name_ncbi_notmatch_aacollision = name_ncbi_notmatch.intersection(ncbi_alias_alias_collision_set)
len(name_ncbi_notmatch_aacollision)
# Out:
# 2

# %%
name_ncbi_hgnc_notmatch = name_ncbi_notmatch.difference(hgnc_gene_symbol_set)
len(name_ncbi_hgnc_notmatch)
# Out:
# 9

# %%
name_ncbi_hgnc_ensg_notmatch = name_ncbi_hgnc_notmatch.difference(ensg_gene_symbol_set)
len(name_ncbi_hgnc_ensg_notmatch)
# Out:
# 8

# %%
gene_claim_name_ncbi_notmatch = dgidb_gene_claim_name_set.difference(ncbi_gene_symbol_set)
len(gene_claim_name_ncbi_notmatch)
# Out:
# 14828

# %%
gene_claim_name_ncbi_hngc_notmatch = gene_claim_name_ncbi_notmatch.difference(hgnc_gene_symbol_set)
len(gene_claim_name_ncbi_hngc_notmatch)
# Out:
# 14738

# %%
gene_claim_name_ncbi_hngc_ensg_notmatch = gene_claim_name_ncbi_hngc_notmatch.difference(ensg_gene_symbol_set)
len(gene_claim_name_ncbi_hngc_ensg_notmatch)
# Out:
# 14735

# %%
name_hgnc_match = dgidb_name_set.intersection(hgnc_gene_symbol_set)
len(name_hgnc_match)
# Out:
# 11976

# %%
name_hgnc_match_aacollision = name_hgnc_match.intersection(hgnc_alias_alias_collision_set)
len(name_hgnc_match_aacollision)
# Out:
# 8

# %%
name_ensg_match = dgidb_name_set.intersection(ensg_gene_symbol_set)
len(name_ensg_match)
# Out:
# 11703

# %%
name_ncbi_match = dgidb_name_set.intersection(ncbi_gene_symbol_set)
len(name_ncbi_match)
# Out:
# 11904

# %%
name_ncbi_match_aacollision = name_ncbi_match.intersection(ncbi_alias_alias_collision_set)
len(name_ncbi_match_aacollision)
# Out:
# 124

# %%
name_ncbi_ensg_match = name_ncbi_match.intersection(ensg_gene_symbol_set)
len(name_ncbi_ensg_match)
# Out:
# 11685

# %%
name_ncbi_ensg_hgnc_match = name_ncbi_ensg_match.intersection(hgnc_gene_symbol_set)
len(name_ncbi_ensg_hgnc_match)
# Out:
# 11684

# %%
gene_claim_name_hgnc_match = dgidb_gene_claim_name_set.intersection(hgnc_gene_symbol_set)
len(gene_claim_name_hgnc_match)
# Out:
# 11984

# %%
gene_claim_name_ensg_match = dgidb_gene_claim_name_set.intersection(ensg_gene_symbol_set)
len(gene_claim_name_ensg_match)
# Out:
# 11710

# %%
gene_claim_name_ensg_aacollision_match = dgidb_gene_claim_name_set.intersection(ensg_alias_alias_collision_set)
len(gene_claim_name_ensg_aacollision_match)
# Out:
# 23

# %%
gene_claim_name_hgnc_aacollision_match = dgidb_gene_claim_name_set.intersection(hgnc_alias_alias_collision_set)
len(gene_claim_name_hgnc_aacollision_match)
# Out:
# 21

# %%
gene_claim_name_ncbi_aacollision_match = dgidb_gene_claim_name_set.intersection(ncbi_alias_alias_collision_set)
len(gene_claim_name_ncbi_aacollision_match)
# Out:
# 221

# %%
name_ensg_aacollision_match = dgidb_name_set.intersection(ensg_alias_alias_collision_set)
len(name_ensg_aacollision_match)
# Out:
# 9

# %%
name_hgnc_aacollision_match = dgidb_name_set.intersection(hgnc_alias_alias_collision_set)
len(name_hgnc_aacollision_match)
# Out:
# 8

# %%
name_ncbi_aacollision_match = dgidb_name_set.intersection(ncbi_alias_alias_collision_set)
len(name_ncbi_aacollision_match)
# Out:
# 126

# %%
gene_claim_name_hgnc_notmatch = dgidb_gene_claim_name_set.difference(hgnc_gene_symbol_set)
len(gene_claim_name_hgnc_notmatch)
# Out:
# 14755

# %%
gene_claim_name_hgnc_notmatch_aacollision = gene_claim_name_hgnc_notmatch.intersection(hgnc_alias_alias_collision_set)
len(gene_claim_name_hgnc_notmatch_aacollision)
# Out:
# 13

# %%
gene_claim_name_ensg_notmatch = dgidb_gene_claim_name_set.difference(ensg_gene_symbol_set)
len(gene_claim_name_ensg_notmatch)
# Out:
# 15029

# %%
gene_claim_name_ncbi_notmatch = dgidb_gene_claim_name_set.difference(ncbi_gene_symbol_set)
len(gene_claim_name_ncbi_notmatch)
# Out:
# 14828

# %%
gene_claim_name_ncbi_notmatch_aacollision = gene_claim_name_ncbi_notmatch.intersection(ncbi_alias_alias_collision_set)
len(gene_claim_name_ncbi_notmatch_aacollision)
# Out:
# 97

# %%
gene_claim_name_hgnc_match = dgidb_gene_claim_name_set.intersection(hgnc_gene_symbol_set)
len(gene_claim_name_hgnc_match)
# Out:
# 11984

# %%
gene_claim_name_hgnc_match_aacollision = gene_claim_name_hgnc_match.intersection(hgnc_alias_alias_collision_set)
len(gene_claim_name_hgnc_match_aacollision)
# Out:
# 8

# %%
gene_claim_name_ncbi_match = dgidb_gene_claim_name_set.intersection(ncbi_gene_symbol_set)
len(gene_claim_name_ncbi_match)
# Out:
# 11911

# %%
gene_claim_name_ncbi_match_aacollision = gene_claim_name_ncbi_match.intersection(ncbi_alias_alias_collision_set)
len(gene_claim_name_ncbi_match_aacollision)
# Out:
# 124

# %%
name_ensg_match_aacollision = name_ensg_match.intersection(ensg_alias_alias_collision_set)
len(name_ensg_match_aacollision)
# Out:
# 8

# %%
len(gene_claim_name_ncbi_hngc_ensg_notmatch)
# Out:
# 14735

# %%
len(name_ncbi_hgnc_ensg_notmatch)
# Out:
# 8

# %%
len(dgidb_name_set)
# Out:
# 12001

# %%
len(dgidb_gene_claim_name_set)
# Out:
# 26739

# %%
name_ensg_notmatch_aacollision = name_ensg_notmatch.intersection(ensg_alias_alias_collision_set)
len(name_ensg_notmatch_aacollision)
# Out:
# 1

# %%
gene_claim_name_ensg_match_aacollision = gene_claim_name_ensg_match.intersection(ensg_alias_alias_collision_set)
len(gene_claim_name_ensg_match_aacollision)
# Out:
# 8

# %%
gene_claim_name_ensg_notmatch_aacollision = gene_claim_name_ensg_notmatch.intersection(ensg_alias_alias_collision_set)
len(gene_claim_name_ensg_notmatch_aacollision)
# Out:
# 15

# %%
gene_claim_name_ncbi_notmatch_aacollision = gene_claim_name_ncbi_notmatch.intersection(ncbi_alias_alias_collision_set)
len(gene_claim_name_ncbi_notmatch_aacollision)
# Out:
# 97

# %%
gene_claim_name_ncbi_match_aacollision = gene_claim_name_ncbi_match.intersection(ncbi_alias_alias_collision_set)
len(gene_claim_name_ncbi_match_aacollision)
# Out:
# 124

# %%
gene_claim_name_hgnc_match_aacollision = gene_claim_name_hgnc_match.intersection(hgnc_alias_alias_collision_set)
len(gene_claim_name_hgnc_match_aacollision)
# Out:
# 8

# %%
gene_claim_name_hgnc_notmatch_aacollision = gene_claim_name_hgnc_notmatch.intersection(hgnc_alias_alias_collision_set)
len(gene_claim_name_hgnc_notmatch_aacollision)
# Out:
# 13

# %% [markdown]
# # Pull out instances of claim symbols that match to a primary gene symbol and the corresponding group symbols not matching to a primary gene symbol. Check for patterns of modes of error

# %%
dgidb_gene_df['claim_primary_status'] = dgidb_gene_df['gene_claim_name'].isin(hgnc_ensg_ncbi_gene_symbol_set)
dgidb_gene_df
# Out:
#       gene_claim_name    nomenclature  concept_id gene_name source_db_name  \
# 0              NGFIBA  NCBI Gene Name         NaN       NaN       BaderLab
# 1              NGFIBB  NCBI Gene Name         NaN       NaN       BaderLab
# 2                 DAX  NCBI Gene Name         NaN       NaN       BaderLab
# 3            REV-ERBA  NCBI Gene Name         NaN       NaN       BaderLab
# 4               COUP2  NCBI Gene Name         NaN       NaN       BaderLab
# ...               ...             ...         ...       ...            ...
# 80229             KIT     Gene Symbol   hgnc:6342       KIT       Oncomine
# 80230            HES1       Gene Name   hgnc:5192      HES1            NCI
# 80231            IRF1     Gene Symbol   hgnc:6116      IRF1         Tempus
# 80232           SHFM1       Gene Name  hgnc:10845      SEM1            DTC
# 80233         NEUROD1       Gene Name   hgnc:7762   NEUROD1            NCI
#
#       source_db_version  claim_primary_status
# 0                Feb-14                 False
# 1                Feb-14                 False
# 2                Feb-14                 False
# 3                Feb-14                 False
# 4                Feb-14                 False
# ...                 ...                   ...
# 80229                v3                  True
# 80230         14-Sep-17                  True
# 80231         11-Nov-18                  True
# 80232            9/2/20                 False
# 80233         14-Sep-17                  True
#
# [80234 rows x 7 columns]

# %%
dgidb_gene_df['claim_primary_status'].value_counts()
# Out:
# claim_primary_status
# True     64209
# False    16025
# Name: count, dtype: int64

# %%
dgidb_gene_df['name_primary_status'] = dgidb_gene_df['gene_name'].astype(str).isin(hgnc_ensg_ncbi_gene_symbol_set)
dgidb_gene_df
# Out:
#       gene_claim_name    nomenclature  concept_id gene_name source_db_name  \
# 0              NGFIBA  NCBI Gene Name         NaN       NaN       BaderLab
# 1              NGFIBB  NCBI Gene Name         NaN       NaN       BaderLab
# 2                 DAX  NCBI Gene Name         NaN       NaN       BaderLab
# 3            REV-ERBA  NCBI Gene Name         NaN       NaN       BaderLab
# 4               COUP2  NCBI Gene Name         NaN       NaN       BaderLab
# ...               ...             ...         ...       ...            ...
# 80229             KIT     Gene Symbol   hgnc:6342       KIT       Oncomine
# 80230            HES1       Gene Name   hgnc:5192      HES1            NCI
# 80231            IRF1     Gene Symbol   hgnc:6116      IRF1         Tempus
# 80232           SHFM1       Gene Name  hgnc:10845      SEM1            DTC
# 80233         NEUROD1       Gene Name   hgnc:7762   NEUROD1            NCI
#
#       source_db_version  claim_primary_status  name_primary_status
# 0                Feb-14                 False                False
# 1                Feb-14                 False                False
# 2                Feb-14                 False                False
# 3                Feb-14                 False                False
# 4                Feb-14                 False                False
# ...                 ...                   ...                  ...
# 80229                v3                  True                 True
# 80230         14-Sep-17                  True                 True
# 80231         11-Nov-18                  True                 True
# 80232            9/2/20                 False                 True
# 80233         14-Sep-17                  True                 True
#
# [80234 rows x 8 columns]

# %%
dgidb_gene_df['name_primary_status'].value_counts()
# Out:
# name_primary_status
# True     78074
# False     2160
# Name: count, dtype: int64

# %%
not_primary_group_name_df =  dgidb_gene_df.loc[~dgidb_gene_df['name_primary_status']]
not_primary_group_name_df
# Out:
#       gene_claim_name    nomenclature       concept_id gene_name  \
# 0              NGFIBA  NCBI Gene Name              NaN       NaN
# 1              NGFIBB  NCBI Gene Name              NaN       NaN
# 2                 DAX  NCBI Gene Name              NaN       NaN
# 3            REV-ERBA  NCBI Gene Name              NaN       NaN
# 4               COUP2  NCBI Gene Name              NaN       NaN
# ...               ...             ...              ...       ...
# 57108   NCBIGENE:2614    NCBI Gene ID    ncbigene:2614  GAPDHL17
# 57552          CYB5P1     Gene Symbol    ncbigene:1529    CYB5P1
# 66195             OA1     Gene Symbol  ncbigene:474285       OA1
# 66196             OA1     Gene Symbol  ncbigene:474285       OA1
# 74562          ATP5A2     Gene Symbol     ncbigene:499    ATP5A2
#
#             source_db_name source_db_version  claim_primary_status  \
# 0                 BaderLab            Feb-14                 False
# 1                 BaderLab            Feb-14                 False
# 2                 BaderLab            Feb-14                 False
# 3                 BaderLab            Feb-14                 False
# 4                 BaderLab            Feb-14                 False
# ...                    ...               ...                   ...
# 57108  GuideToPharmacology            2024.1                 False
# 57552                 NCBI          20240410                 False
# 66195                 NCBI          20240410                 False
# 66196                dGene         27-Jun-13                 False
# 74562                 NCBI          20240410                 False
#
#        name_primary_status
# 0                    False
# 1                    False
# 2                    False
# 3                    False
# 4                    False
# ...                    ...
# 57108                False
# 57552                False
# 66195                False
# 66196                False
# 74562                False
#
# [2160 rows x 8 columns]

# %%
not_primary_group_name_df['name_alias_status'] = dgidb_gene_df['gene_name'].isin(hgnc_ensg_ncbi_alias_symbol_set)
not_primary_group_name_df
# Out:
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_73154/2466900690.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   not_primary_group_name_df['name_alias_status'] = dgidb_gene_df['gene_name'].isin(hgnc_ensg_ncbi_alias_symbol_set)
#       gene_claim_name    nomenclature       concept_id gene_name  \
# 0              NGFIBA  NCBI Gene Name              NaN       NaN
# 1              NGFIBB  NCBI Gene Name              NaN       NaN
# 2                 DAX  NCBI Gene Name              NaN       NaN
# 3            REV-ERBA  NCBI Gene Name              NaN       NaN
# 4               COUP2  NCBI Gene Name              NaN       NaN
# ...               ...             ...              ...       ...
# 57108   NCBIGENE:2614    NCBI Gene ID    ncbigene:2614  GAPDHL17
# 57552          CYB5P1     Gene Symbol    ncbigene:1529    CYB5P1
# 66195             OA1     Gene Symbol  ncbigene:474285       OA1
# 66196             OA1     Gene Symbol  ncbigene:474285       OA1
# 74562          ATP5A2     Gene Symbol     ncbigene:499    ATP5A2
#
#             source_db_name source_db_version  claim_primary_status  \
# 0                 BaderLab            Feb-14                 False
# 1                 BaderLab            Feb-14                 False
# 2                 BaderLab            Feb-14                 False
# 3                 BaderLab            Feb-14                 False
# 4                 BaderLab            Feb-14                 False
# ...                    ...               ...                   ...
# 57108  GuideToPharmacology            2024.1                 False
# 57552                 NCBI          20240410                 False
# 66195                 NCBI          20240410                 False
# 66196                dGene         27-Jun-13                 False
# 74562                 NCBI          20240410                 False
#
#        name_primary_status  name_alias_status
# 0                    False              False
# 1                    False              False
# 2                    False              False
# 3                    False              False
# 4                    False              False
# ...                    ...                ...
# 57108                False              False
# 57552                False              False
# 66195                False               True
# 66196                False               True
# 74562                False              False
#
# [2160 rows x 9 columns]

# %%
not_primary_group_name_df['name_alias_status'].value_counts()
# Out:
# name_alias_status
# False    2154
# True        6
# Name: count, dtype: int64

# %%
print("Calmbp1" in hgnc_ensg_ncbi_alias_symbol_set)
# Out:
# True

# %%
not_primary_group_name_df['claim_alias_status'] = dgidb_gene_df['gene_claim_name'].isin(hgnc_ensg_ncbi_alias_symbol_set)
not_primary_group_name_df
# Out:
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_73154/1565248528.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   not_primary_group_name_df['claim_alias_status'] = dgidb_gene_df['gene_claim_name'].isin(hgnc_ensg_ncbi_alias_symbol_set)
#       gene_claim_name    nomenclature       concept_id gene_name  \
# 0              NGFIBA  NCBI Gene Name              NaN       NaN
# 1              NGFIBB  NCBI Gene Name              NaN       NaN
# 2                 DAX  NCBI Gene Name              NaN       NaN
# 3            REV-ERBA  NCBI Gene Name              NaN       NaN
# 4               COUP2  NCBI Gene Name              NaN       NaN
# ...               ...             ...              ...       ...
# 57108   NCBIGENE:2614    NCBI Gene ID    ncbigene:2614  GAPDHL17
# 57552          CYB5P1     Gene Symbol    ncbigene:1529    CYB5P1
# 66195             OA1     Gene Symbol  ncbigene:474285       OA1
# 66196             OA1     Gene Symbol  ncbigene:474285       OA1
# 74562          ATP5A2     Gene Symbol     ncbigene:499    ATP5A2
#
#             source_db_name source_db_version  claim_primary_status  \
# 0                 BaderLab            Feb-14                 False
# 1                 BaderLab            Feb-14                 False
# 2                 BaderLab            Feb-14                 False
# 3                 BaderLab            Feb-14                 False
# 4                 BaderLab            Feb-14                 False
# ...                    ...               ...                   ...
# 57108  GuideToPharmacology            2024.1                 False
# 57552                 NCBI          20240410                 False
# 66195                 NCBI          20240410                 False
# 66196                dGene         27-Jun-13                 False
# 74562                 NCBI          20240410                 False
#
#        name_primary_status  name_alias_status  claim_alias_status
# 0                    False              False               False
# 1                    False              False               False
# 2                    False              False               False
# 3                    False              False               False
# 4                    False              False               False
# ...                    ...                ...                 ...
# 57108                False              False               False
# 57552                False              False               False
# 66195                False               True                True
# 66196                False               True                True
# 74562                False              False               False
#
# [2160 rows x 10 columns]

# %%
alias_not_primary_group_name_df = not_primary_group_name_df.loc[not_primary_group_name_df['name_alias_status']]
alias_not_primary_group_name_df
# Out:
#       gene_claim_name nomenclature          concept_id gene_name  \
# 3251           USP17L  Gene Symbol  ncbigene:100862847    USP17L
# 23020           ACTIN    Gene Name     ncbigene:389036       ACT
# 38737          USP17L  Gene Symbol  ncbigene:100862847    USP17L
# 55006             ACT  Gene Symbol     ncbigene:389036       ACT
# 66195             OA1  Gene Symbol     ncbigene:474285       OA1
# 66196             OA1  Gene Symbol     ncbigene:474285       OA1
#
#       source_db_name source_db_version  claim_primary_status  \
# 3251           dGene         27-Jun-13                 False
# 23020            TTD        2020.06.01                 False
# 38737           NCBI          20240410                 False
# 55006           NCBI          20240410                 False
# 66195           NCBI          20240410                 False
# 66196          dGene         27-Jun-13                 False
#
#        name_primary_status  name_alias_status  claim_alias_status
# 3251                 False               True                True
# 23020                False               True               False
# 38737                False               True                True
# 55006                False               True                True
# 66195                False               True                True
# 66196                False               True                True

# %%
not_primary_group_name_df['name_null_status'] = dgidb_gene_df['gene_name'].isnull()
not_primary_group_name_df
# Out:
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_73154/743224626.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   not_primary_group_name_df['name_null_status'] = dgidb_gene_df['gene_name'].isnull()
#       gene_claim_name    nomenclature       concept_id gene_name  \
# 0              NGFIBA  NCBI Gene Name              NaN       NaN
# 1              NGFIBB  NCBI Gene Name              NaN       NaN
# 2                 DAX  NCBI Gene Name              NaN       NaN
# 3            REV-ERBA  NCBI Gene Name              NaN       NaN
# 4               COUP2  NCBI Gene Name              NaN       NaN
# ...               ...             ...              ...       ...
# 57108   NCBIGENE:2614    NCBI Gene ID    ncbigene:2614  GAPDHL17
# 57552          CYB5P1     Gene Symbol    ncbigene:1529    CYB5P1
# 66195             OA1     Gene Symbol  ncbigene:474285       OA1
# 66196             OA1     Gene Symbol  ncbigene:474285       OA1
# 74562          ATP5A2     Gene Symbol     ncbigene:499    ATP5A2
#
#             source_db_name source_db_version  claim_primary_status  \
# 0                 BaderLab            Feb-14                 False
# 1                 BaderLab            Feb-14                 False
# 2                 BaderLab            Feb-14                 False
# 3                 BaderLab            Feb-14                 False
# 4                 BaderLab            Feb-14                 False
# ...                    ...               ...                   ...
# 57108  GuideToPharmacology            2024.1                 False
# 57552                 NCBI          20240410                 False
# 66195                 NCBI          20240410                 False
# 66196                dGene         27-Jun-13                 False
# 74562                 NCBI          20240410                 False
#
#        name_primary_status  name_alias_status  claim_alias_status  \
# 0                    False              False               False
# 1                    False              False               False
# 2                    False              False               False
# 3                    False              False               False
# 4                    False              False               False
# ...                    ...                ...                 ...
# 57108                False              False               False
# 57552                False              False               False
# 66195                False               True                True
# 66196                False               True                True
# 74562                False              False               False
#
#        name_null_status
# 0                  True
# 1                  True
# 2                  True
# 3                  True
# 4                  True
# ...                 ...
# 57108             False
# 57552             False
# 66195             False
# 66196             False
# 74562             False
#
# [2160 rows x 11 columns]

# %%
not_primary_group_name_df['name_null_status'].value_counts()
# Out:
# name_null_status
# True     2144
# False      16
# Name: count, dtype: int64

# %%
null_not_primary_group_name_df = not_primary_group_name_df.loc[not_primary_group_name_df['name_null_status']]
null_not_primary_group_name_df
# Out:
#           gene_claim_name    nomenclature concept_id gene_name source_db_name  \
# 0                  NGFIBA  NCBI Gene Name        NaN       NaN       BaderLab
# 1                  NGFIBB  NCBI Gene Name        NaN       NaN       BaderLab
# 2                     DAX  NCBI Gene Name        NaN       NaN       BaderLab
# 3                REV-ERBA  NCBI Gene Name        NaN       NaN       BaderLab
# 4                   COUP2  NCBI Gene Name        NaN       NaN       BaderLab
# ...                   ...             ...        ...       ...            ...
# 29008  URS00006E35E8_9606     Gene Symbol        NaN       NaN             GO
# 29009  URS0000EA3BA1_9606     Gene Symbol        NaN       NaN             GO
# 29198   TRYPTASE_B2_HUMAN     Gene Symbol        NaN       NaN             GO
# 29199   TRYPTASE_B1_HUMAN     Gene Symbol        NaN       NaN             GO
# 29389           HERVK_113     Gene Symbol        NaN       NaN         Pharos
#
#       source_db_version  claim_primary_status  name_primary_status  \
# 0                Feb-14                 False                False
# 1                Feb-14                 False                False
# 2                Feb-14                 False                False
# 3                Feb-14                 False                False
# 4                Feb-14                 False                False
# ...                 ...                   ...                  ...
# 29008         10-Apr-24                 False                False
# 29009         10-Apr-24                 False                False
# 29198         10-Apr-24                 False                False
# 29199         10-Apr-24                 False                False
# 29389         10-Apr-24                 False                False
#
#        name_alias_status  claim_alias_status  name_null_status
# 0                  False               False              True
# 1                  False               False              True
# 2                  False               False              True
# 3                  False               False              True
# 4                  False               False              True
# ...                  ...                 ...               ...
# 29008              False               False              True
# 29009              False               False              True
# 29198              False               False              True
# 29199              False               False              True
# 29389              False               False              True
#
# [2144 rows x 11 columns]

# %%
null_not_primary_group_name_df['gene_claim_name'].value_counts()
# Out:
# gene_claim_name
# ATPF                 2
# RPSK                 2
# RPSE                 2
# RPSD                 2
# RPSC                 2
#                     ..
# YCEI                 1
# CEFE                 1
# NFSB                 1
# LIGA                 1
# TRYPTASE_B1_HUMAN    1
# Name: count, Length: 2053, dtype: int64

# %%
null_not_primary_group_name_df.loc[null_not_primary_group_name_df['claim_alias_status']]
# Out:
# Empty DataFrame
# Columns: [gene_claim_name, nomenclature, concept_id, gene_name, source_db_name, source_db_version, claim_primary_status, name_primary_status, name_alias_status, claim_alias_status, name_null_status]
# Index: []

# %%
other_not_primary_group_name_df = not_primary_group_name_df.loc[~not_primary_group_name_df['name_alias_status'] & ~not_primary_group_name_df['name_null_status']]
other_not_primary_group_name_df
# Out:
#              gene_claim_name  nomenclature       concept_id gene_name  \
# 22269  MELANOCORTIN RECEPTOR     Gene Name  ncbigene:359995       mCR
# 25653           NCBIGENE:697  NCBI Gene ID     ncbigene:697     BTNL1
# 26457          NCBIGENE:1529  NCBI Gene ID    ncbigene:1529    CYB5P1
# 26608           NCBIGENE:499  NCBI Gene ID     ncbigene:499    ATP5A2
# 54783                    mCR   Gene Symbol  ncbigene:359995       mCR
# 56710                  BTNL1   Gene Symbol     ncbigene:697     BTNL1
# 57107               GAPDHL17   Gene Symbol    ncbigene:2614  GAPDHL17
# 57108          NCBIGENE:2614  NCBI Gene ID    ncbigene:2614  GAPDHL17
# 57552                 CYB5P1   Gene Symbol    ncbigene:1529    CYB5P1
# 74562                 ATP5A2   Gene Symbol     ncbigene:499    ATP5A2
#
#             source_db_name source_db_version  claim_primary_status  \
# 22269                  TTD        2020.06.01                 False
# 25653  GuideToPharmacology            2024.1                 False
# 26457  GuideToPharmacology            2024.1                 False
# 26608  GuideToPharmacology            2024.1                 False
# 54783                 NCBI          20240410                 False
# 56710                 NCBI          20240410                 False
# 57107                 NCBI          20240410                 False
# 57108  GuideToPharmacology            2024.1                 False
# 57552                 NCBI          20240410                 False
# 74562                 NCBI          20240410                 False
#
#        name_primary_status  name_alias_status  claim_alias_status  \
# 22269                False              False               False
# 25653                False              False               False
# 26457                False              False               False
# 26608                False              False               False
# 54783                False              False               False
# 56710                False              False               False
# 57107                False              False               False
# 57108                False              False               False
# 57552                False              False               False
# 74562                False              False               False
#
#        name_null_status
# 22269             False
# 25653             False
# 26457             False
# 26608             False
# 54783             False
# 56710             False
# 57107             False
# 57108             False
# 57552             False
# 74562             False

# %%
claim_true_name_false_df = dgidb_gene_df.loc[dgidb_gene_df['claim_primary_status'] & ~dgidb_gene_df['name_primary_status']]
claim_true_name_false_df
# Out:
# Empty DataFrame
# Columns: [gene_claim_name, nomenclature, concept_id, gene_name, source_db_name, source_db_version, claim_primary_status, name_primary_status]
# Index: []

# %%
len(claim_true_name_false_df)
# Out:
# 0

# %% [markdown]
# # Creating a yaml file for each collision

# %%
# merged_alias_overlap_df_2

# %%
# data = {}

# for row in merged_alias_overlap_df_2.itertuples():
#     print(row)
#     break

# %%
# import yaml
# import os

# folder_path = 'new_alias-alias_collision_records'
# os.makedirs(folder_path, exist_ok=True)

# data = []

# for row in merged_alias_overlap_df_2.itertuples():
    
#     collision_record = {
#         "collision_symbol": row.alias_symbol,
#     }

#     collision_group = []

#     len_gene_symbols = len(row.gene_symbol)
#     ensg_ids = [r.strip() for r in row.ENSG_ID.split(",")]
#     len_ensg_ids = len(ensg_ids)

#     # if len_gene_symbols != len_ensg_ids:
#     #     print(row)
#     for i in range(0, len_gene_symbols):
#         collision_group_item = {
#             "gene_symbol": row.gene_symbol[i],
#             "ensg_id": ensg_ids[i].upper()
#         }
#         collision_group.append(collision_group_item)

#     collision_record["collision_group"] = collision_group
#     data.append(collision_record)

#     file_path = os.path.join(folder_path, f"{(row.alias_symbol.replace('/', '_'))}_collision_record.yaml")

#     with open(file_path, "w") as wf:
#         yaml.dump(collision_record, wf, default_flow_style=False)

# data
