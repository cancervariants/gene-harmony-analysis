# %% [markdown]
# **Table of contents**<a id='toc0_'></a>
# - [ENSG](#toc1_)
#     - [Drop all columns besides ENSG_ID, gene_symbol, and alias_symbol](#toc1_1_1_)
#     - [How many total unique gene records are there](#toc1_1_2_)
#     - [Drop rows with NAN in alias_symbol](#toc1_1_3_)
#     - [Make each row in alias_symbol a set:](#toc1_1_4_)
#     - [Explode the alias sets so that it is one per row](#toc1_1_5_)
#     - [How many total unique aliases are there](#toc1_1_6_)
#     - [Pull out all the rows that have an alias symbol that can be found elsewhere](#toc1_1_7_)
#     - [Sort alias symbols alphabetically](#toc1_1_8_)
#     - [Number of records with an alias that is shared](#toc1_1_9_)
#     - [Count the number of times each multi-use alias is used](#toc1_1_10_)
#       - [Save as csv](#toc1_1_10_1_)
#     - [Put columns in different order to ephasize alias symbols instead of gene records](#toc1_1_11_)
#     - [Merge rows with matching alias symbols](#toc1_1_12_)
# - [HGNC](#toc2_)
#     - [Drop all columns besides ENSG_ID, gene_symbol, and alias_symbol](#toc2_1_1_)
#     - [How many total unique gene records are there](#toc2_1_2_)
#     - [Drop rows with NAN in alias_symbol](#toc2_1_3_)
#     - [Make each row in alias_symbol a set:](#toc2_1_4_)
#     - [Explode the alias sets so that it is one per row](#toc2_1_5_)
#     - [How many total unique aliases are there](#toc2_1_6_)
#     - [Pull out all the rows that have an alias symbol that can be found elsewhere](#toc2_1_7_)
#     - [Sort alias symbols alphabetically](#toc2_1_8_)
#     - [Number of records with an alias that is shared](#toc2_1_9_)
#     - [Count the number of times each multi-use alias is used](#toc2_1_10_)
#       - [Save as csv](#toc2_1_10_1_)
#     - [Put columns in different order to ephasize alias symbols instead of gene records](#toc2_1_11_)
#     - [Merge rows with matching alias symbols](#toc2_1_12_)
# - [NCBI Info](#toc3_)
#     - [Drop all columns besides ENSG_ID, gene_symbol, and alias_symbol](#toc3_1_1_)
#     - [How many total unique gene records are there](#toc3_1_2_)
#     - [Drop rows with - in alias_symbol](#toc3_1_3_)
#     - [Make each row in alias_symbol a set:](#toc3_1_4_)
#     - [Explode the alias sets so that it is one per row](#toc3_1_5_)
#     - [How many unique aliases are there](#toc3_1_6_)
#     - [Pull out all the rows that have an alias symbol that can be found elsewhere](#toc3_1_7_)
#     - [Sort alias symbols alphabetically](#toc3_1_8_)
#     - [Number of records with an alias that is shared](#toc3_1_9_)
#     - [Count the number of times each multi-use alias is used](#toc3_1_10_)
#     - [Put columns in different order to ephasize alias symbols instead of gene records](#toc3_1_11_)
#     - [Merge rows with matching alias symbols](#toc3_1_12_)
# - [Merge to create Alias Overlap Table 1 - Gene Symbol](#toc4_)
# - [Merge to create Alias Overlap Table 2 - Alias Symbol](#toc5_)
#
# <!-- vscode-jupyter-toc-config
# 	numbering=false
# 	anchor=true
# 	flat=false
# 	minLevel=1
# 	maxLevel=6
# 	/vscode-jupyter-toc-config -->
# <!-- THIS CELL WILL BE REPLACED ON TOC UPDATE. DO NOT WRITE YOUR TEXT IN THIS CELL -->

# %%
import pandas as pd
import numpy as np
import plotly.express as px

# %% [markdown]
# # <a id='toc1_'></a>[ENSG](#toc0_)

# %%
mini_ensg_df = pd.read_csv("ensg_alias_df.csv")

# %% [markdown]
# Note: duplicate gene symbols can have different ENSG ids

# %%
duplicateENSG_ID2 = mini_ensg_df[mini_ensg_df.duplicated('ensg_id', keep=False)]
duplicateENSG_ID2
# Out:
#        Unnamed: 0       gene_type   ref_id  \
# 38           1366            rRNA   495150
# 39           1367            rRNA   495150
# 40           1368            rRNA   495150
# 55           1386  protein_coding  2874124
# 56           1387  protein_coding  2874124
# ...           ...             ...      ...
# 52151       76329           snRNA  2949399
# 52152       76330           snRNA  2949399
# 52153       76331           snRNA  2949399
# 52196       76395  protein_coding  2919059
# 52197       76396  protein_coding  2919059
#
#                                                gene_name          ensg_id  \
# 38          5.8S ribosomal RNA [Source:RFAM;Acc:RF00002]  ENSG00000278294
# 39          5.8S ribosomal RNA [Source:RFAM;Acc:RF00002]  ENSG00000278294
# 40          5.8S ribosomal RNA [Source:RFAM;Acc:RF00002]  ENSG00000278294
# 55     killer cell immunoglobulin like receptor, two ...  ENSG00000276779
# 56     killer cell immunoglobulin like receptor, two ...  ENSG00000276779
# ...                                                  ...              ...
# 52151  RNA, variant U1 small nuclear 29 [Source:HGNC ...  ENSG00000273768
# 52152  RNA, variant U1 small nuclear 29 [Source:HGNC ...  ENSG00000273768
# 52153  RNA, variant U1 small nuclear 29 [Source:HGNC ...  ENSG00000273768
# 52196  phosphodiesterase 4D interacting protein [Sour...  ENSG00000178104
# 52197  phosphodiesterase 4D interacting protein [Sour...  ENSG00000178104
#
#                          gene_synonyms gene_symbol  entrez_id
# 38                                 NaN   5_8S_rRNA  124907156
# 39                                 NaN   5_8S_rRNA  124907485
# 40                                 NaN   5_8S_rRNA  124908250
# 55               103AS, 15.212, CD158D     KIR2DL4       3805
# 56               103AS, 15.212, CD158D     KIR2DL4  124900568
# ...                                ...         ...        ...
# 52151                              NaN    RNVU1-29  124905574
# 52152                              NaN    RNVU1-29  124905808
# 52153                              NaN    RNVU1-29  124905809
# 52196  CMYA2, KIAA0454, KIAA0477, MMGL     PDE4DIP       9659
# 52197  CMYA2, KIAA0454, KIAA0477, MMGL     PDE4DIP  124904395
#
# [5990 rows x 8 columns]

# %%
duplicateENSG_ID2.to_csv('../ensg_duplicateENSG_ID2.csv', index=True)

# %% [markdown]
# ### <a id='toc1_1_1_'></a>[Drop all columns besides ENSG_ID, gene_symbol, and alias_symbol](#toc0_)

# %%
mini_ensg_df = mini_ensg_df.drop(['gene_type', 'ref_id', 'gene_name', 'Unnamed: 0'], axis=1)
mini_ensg_df = mini_ensg_df.rename(columns = {'gene_synonyms':'alias_symbol', 'ensg_id':'ENSG_ID' })
mini_ensg_df
# Out:
#                ENSG_ID         alias_symbol gene_symbol  entrez_id
# 0      ENSG00000210049           MTTF, trnF       MT-TF          0
# 1      ENSG00000211459  12S, MOTS-c, MTRNR1     MT-RNR1          0
# 2      ENSG00000210077           MTTV, trnV       MT-TV          0
# 3      ENSG00000210082      16S, HN, MTRNR2     MT-RNR2          0
# 4      ENSG00000209082         MTTL1, TRNL1      MT-TL1          0
# ...                ...                  ...         ...        ...
# 52224  ENSG00000206764                  NaN   RNU6-152P          0
# 52225  ENSG00000231684                  NaN      EIF1P3          0
# 52226  ENSG00000264470         hsa-mir-4794     MIR4794  100616338
# 52227  ENSG00000162437   FLJ10770, KIAA1579      RAVER2      55225
# 52228  ENSG00000122432                 SP-2      SPATA1  100505741
#
# [52229 rows x 4 columns]

# %% [markdown]
# Note: duplicate ENSG ids can have different entrez ids

# %%
duplicateENSG_ID = mini_ensg_df[mini_ensg_df.duplicated('ENSG_ID', keep=False)]
duplicateENSG_ID
# Out:
#                ENSG_ID                     alias_symbol gene_symbol  entrez_id
# 38     ENSG00000278294                              NaN   5_8S_rRNA  124907156
# 39     ENSG00000278294                              NaN   5_8S_rRNA  124907485
# 40     ENSG00000278294                              NaN   5_8S_rRNA  124908250
# 55     ENSG00000276779            103AS, 15.212, CD158D     KIR2DL4       3805
# 56     ENSG00000276779            103AS, 15.212, CD158D     KIR2DL4  124900568
# ...                ...                              ...         ...        ...
# 52151  ENSG00000273768                              NaN    RNVU1-29  124905574
# 52152  ENSG00000273768                              NaN    RNVU1-29  124905808
# 52153  ENSG00000273768                              NaN    RNVU1-29  124905809
# 52196  ENSG00000178104  CMYA2, KIAA0454, KIAA0477, MMGL     PDE4DIP       9659
# 52197  ENSG00000178104  CMYA2, KIAA0454, KIAA0477, MMGL     PDE4DIP  124904395
#
# [5990 rows x 4 columns]

# %%
duplicateENSG_ID.to_csv('../ensg_duplicateENSG_ID.csv', index=True)

# %% [markdown]
# ### <a id='toc1_1_2_'></a>[How many total unique gene records are there](#toc0_)

# %% [markdown]
# By ENSG ID

# %%
ensg_gene_id_set = set(mini_ensg_df['ENSG_ID'])
len(ensg_gene_id_set)
# Out:
# 46806

# %% [markdown]
# By gene symbol

# %%
ensg_gene_symbol_set = set(mini_ensg_df['gene_symbol'])
len(ensg_gene_symbol_set)
# Out:
# 40353

# %% [markdown]
# Using IGHV as an example:

# %%
type(mini_ensg_df.gene_symbol[0])
# Out:
# str

# %%
# ensg_IGHV_alias_df = mini_ensg_df.loc[mini_ensg_df['gene_symbol'].str.contains("IGHV", case=False)]

# %%
ensg_IGHV_alias_df = mini_ensg_df[mini_ensg_df['gene_symbol'].str.contains('IGHV')]

# %%
ensg_IGHV_alias_df.to_csv('../hgnc_IGHV_alias_df.csv')

# %% [markdown]
# ### <a id='toc1_1_3_'></a>[Drop genes with no aliases](#toc0_)

# %%
mini_ensg_df = mini_ensg_df[mini_ensg_df["alias_symbol"].str.contains("NaN") == False]
mini_ensg_df
# Out:
#                ENSG_ID                  alias_symbol gene_symbol  entrez_id
# 0      ENSG00000210049                    MTTF, trnF       MT-TF          0
# 1      ENSG00000211459           12S, MOTS-c, MTRNR1     MT-RNR1          0
# 2      ENSG00000210077                    MTTV, trnV       MT-TV          0
# 3      ENSG00000210082               16S, HN, MTRNR2     MT-RNR2          0
# 4      ENSG00000209082                  MTTL1, TRNL1      MT-TL1          0
# ...                ...                           ...         ...        ...
# 52220  ENSG00000198216  BII, CACH6, CACNL1A6, Cav2.3     CACNA1E        777
# 52221  ENSG00000179930                      FLJ46813      ZNF648     127665
# 52226  ENSG00000264470                  hsa-mir-4794     MIR4794  100616338
# 52227  ENSG00000162437            FLJ10770, KIAA1579      RAVER2      55225
# 52228  ENSG00000122432                          SP-2      SPATA1  100505741
#
# [31260 rows x 4 columns]

# %% [markdown]
# ### <a id='toc1_1_4_'></a>[Make each row in alias_symbol a set:](#toc0_)
#     covert to a list
#     make a set

# %%
mini_ensg_df['alias_symbol'] = mini_ensg_df['alias_symbol'].astype(str)
mini_ensg_df['alias_symbol'] = [x.split(',') for x in mini_ensg_df.alias_symbol]
mini_ensg_df['alias_symbol']=np.where(mini_ensg_df.alias_symbol=='','',mini_ensg_df.alias_symbol.map(set))
mini_ensg_df.head(1)
# Out:
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_14988/1602162191.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mini_ensg_df['alias_symbol'] = mini_ensg_df['alias_symbol'].astype(str)
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_14988/1602162191.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mini_ensg_df['alias_symbol'] = [x.split(',') for x in mini_ensg_df.alias_symbol]
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_14988/1602162191.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mini_ensg_df['alias_symbol']=np.where(mini_ensg_df.alias_symbol=='','',mini_ensg_df.alias_symbol.map(set))
#            ENSG_ID   alias_symbol gene_symbol  entrez_id
# 0  ENSG00000210049  {MTTF,  trnF}       MT-TF          0

# %% [markdown]
# ### <a id='toc1_1_5_'></a>[Explode the alias sets so that it is one per row](#toc0_)

# %%
mini_ensg_df = mini_ensg_df.explode('alias_symbol')
mini_ensg_df
# Out:
#                ENSG_ID  alias_symbol gene_symbol  entrez_id
# 0      ENSG00000210049          MTTF       MT-TF          0
# 0      ENSG00000210049          trnF       MT-TF          0
# 1      ENSG00000211459           12S     MT-RNR1          0
# 1      ENSG00000211459        MOTS-c     MT-RNR1          0
# 1      ENSG00000211459        MTRNR1     MT-RNR1          0
# ...                ...           ...         ...        ...
# 52221  ENSG00000179930      FLJ46813      ZNF648     127665
# 52226  ENSG00000264470  hsa-mir-4794     MIR4794  100616338
# 52227  ENSG00000162437      FLJ10770      RAVER2      55225
# 52227  ENSG00000162437      KIAA1579      RAVER2      55225
# 52228  ENSG00000122432          SP-2      SPATA1  100505741
#
# [70498 rows x 4 columns]

# %% [markdown]
# ### <a id='toc3_1_6_'></a>[How many unique aliases are there](#toc0_)

# %%
ensg_alias_symbol_set = set(mini_ensg_df['alias_symbol'])
ensg_alias_len = len(ensg_alias_symbol_set)
ensg_alias_len
# Out:
# 54926

# %% [markdown]
# ### <a id='toc3_1_7_'></a>[Pull out all the rows that have an alias symbol that can be found elsewhere](#toc0_)

# %%
mini_ensg_df['alias_duplicates'] = mini_ensg_df.duplicated(subset= 'alias_symbol', keep=False)
mini_ensg_df = mini_ensg_df[mini_ensg_df['alias_duplicates'] == True]
mini_ensg_df = mini_ensg_df.drop(['alias_duplicates'], axis=1)
mini_ensg_df.head(5)
# Out:
#             ENSG_ID alias_symbol gene_symbol  entrez_id
# 5   ENSG00000198888          ND1      MT-ND1       4535
# 43  ENSG00000281486        G2SYN       SNTG2      54221
# 43  ENSG00000281486         SYN5       SNTG2      54221
# 44  ENSG00000262826      C1orf60       INTS3      65123
# 44  ENSG00000262826         INT3       INTS3      65123

# %% [markdown]
# ### <a id='toc3_1_8_'></a>[Sort alias symbols alphabetically](#toc0_)

# %%
mini_ensg_df = mini_ensg_df.sort_values('alias_symbol')
mini_ensg_df
# Out:
#                ENSG_ID alias_symbol gene_symbol  entrez_id
# 672    ENSG00000277362       15.212     KIR2DL4  124900568
# 8516   ENSG00000284365       15.212     KIR2DL4  124900568
# 8515   ENSG00000284365       15.212     KIR2DL4       3805
# 8349   ENSG00000284206       15.212     KIR2DL4  124900568
# 8348   ENSG00000284206       15.212     KIR2DL4       3805
# ...                ...          ...         ...        ...
# 23567  ENSG00000227211          p56       H3P45          0
# 7724   ENSG00000283997    promethin       LDAF1      57146
# 37151  ENSG00000011638    promethin       LDAF1      57146
# 27797  ENSG00000100181    psiTPTE22      TPTEP1          0
# 27801  ENSG00000290418    psiTPTE22      TPTEP1     387590
#
# [20879 rows x 4 columns]

# %%
#ensg_CD158b_alias_count_df.to_csv('../hgnc_CD158b_alias_count_df.csv')

# %% [markdown]
# ### <a id='toc3_1_9_'></a>[Number of records with an alias that is shared](#toc0_)

# %%
ensg_gene_symbol_set_wsharedalias = set(mini_ensg_df['gene_symbol'])
len(ensg_gene_symbol_set_wsharedalias)
# Out:
# 3680

# %%
mini_ensg_df['source'] = 'ENSG'
mini_ensg_df
# Out:
#                ENSG_ID alias_symbol gene_symbol  entrez_id source
# 672    ENSG00000277362       15.212     KIR2DL4  124900568   ENSG
# 8516   ENSG00000284365       15.212     KIR2DL4  124900568   ENSG
# 8515   ENSG00000284365       15.212     KIR2DL4       3805   ENSG
# 8349   ENSG00000284206       15.212     KIR2DL4  124900568   ENSG
# 8348   ENSG00000284206       15.212     KIR2DL4       3805   ENSG
# ...                ...          ...         ...        ...    ...
# 23567  ENSG00000227211          p56       H3P45          0   ENSG
# 7724   ENSG00000283997    promethin       LDAF1      57146   ENSG
# 37151  ENSG00000011638    promethin       LDAF1      57146   ENSG
# 27797  ENSG00000100181    psiTPTE22      TPTEP1          0   ENSG
# 27801  ENSG00000290418    psiTPTE22      TPTEP1     387590   ENSG
#
# [20879 rows x 5 columns]

# %%
mini_ensg_df.loc[mini_ensg_df['alias_symbol'] == "RN5S3" ]
# Out:
#                ENSG_ID alias_symbol gene_symbol  entrez_id source
# 9998   ENSG00000285168        RN5S3      RNA5S3  124905833   ENSG
# 9983   ENSG00000285168        RN5S3      RNA5S3  124905818   ENSG
# 9982   ENSG00000285168        RN5S3      RNA5S3  124905817   ENSG
# 9981   ENSG00000285168        RN5S3      RNA5S3  124905816   ENSG
# 9980   ENSG00000285168        RN5S3      RNA5S3  124905815   ENSG
# ...                ...          ...         ...        ...    ...
# 43674  ENSG00000199337        RN5S3      RNA5S3  124905767   ENSG
# 43673  ENSG00000199337        RN5S3      RNA5S3  124905766   ENSG
# 43672  ENSG00000199337        RN5S3      RNA5S3  124905765   ENSG
# 43671  ENSG00000199337        RN5S3      RNA5S3  124905764   ENSG
# 43682  ENSG00000199337        RN5S3      RNA5S3  124905775   ENSG
#
# [218 rows x 5 columns]

# %% [markdown]
# ### <a id='toc3_1_10_'></a>[Count the number of times each multi-use alias is used](#toc0_)

# %%
ensg_dup_alias_count_df = mini_ensg_df.pivot_table(index = ['alias_symbol'], aggfunc ='size')
ensg_dup_alias_count_df
# Out:
# alias_symbol
#  15.212      82
#  5T4-AG       2
#  A1AT         2
#  A3GALT1      2
#  AAP          2
#              ..
# p42           2
# p55           2
# p56           2
# promethin     2
# psiTPTE22     2
# Length: 5307, dtype: int64

# %%
ensg_dup_alias_count_df = ensg_dup_alias_count_df.reset_index()
ensg_dup_alias_count_df
# Out:
#      alias_symbol   0
# 0          15.212  82
# 1          5T4-AG   2
# 2            A1AT   2
# 3         A3GALT1   2
# 4             AAP   2
# ...           ...  ..
# 5302          p42   2
# 5303          p55   2
# 5304          p56   2
# 5305    promethin   2
# 5306    psiTPTE22   2
#
# [5307 rows x 2 columns]

# %%
ensg_dup_alias_count_df.rename(columns={0:'num_gene_records'}, inplace=True )
ensg_dup_alias_count_df
# Out:
#      alias_symbol  num_gene_records
# 0          15.212                82
# 1          5T4-AG                 2
# 2            A1AT                 2
# 3         A3GALT1                 2
# 4             AAP                 2
# ...           ...               ...
# 5302          p42                 2
# 5303          p55                 2
# 5304          p56                 2
# 5305    promethin                 2
# 5306    psiTPTE22                 2
#
# [5307 rows x 2 columns]

# %%
ensg_dup_alias_count_df = ensg_dup_alias_count_df.sort_values('num_gene_records', ascending=False)
ensg_dup_alias_count_df.head(30)
# Out:
#      alias_symbol  num_gene_records
# 4853        RN5S3               218
# 4849        RN5S2               216
# 4844       RN5S16               216
# 4845       RN5S17               216
# 4835        RN5S1               216
# 4865     RNA5-8N2               211
# 4837       RN5S11               108
# 4839       RN5S12               108
# 4840       RN5S13               108
# 4842       RN5S14               108
# 4843       RN5S15               108
# 4858        RN5S4               108
# 4860        RN5S5               108
# 4861        RN5S6               108
# 4862        RN5S7               108
# 4863        RN5S8               108
# 4836       RN5S10               108
# 138        CD158D                82
# 0          15.212                82
# 3137        103AS                82
# 3776         CT78                53
# 2986         cl-5                43
# 3628       CD158K                43
# 3053        nkat4                43
# 3054       nkat4a                43
# 3055       nkat4b                43
# 1101        KIRC1                42
# 1099        KIR44                42
# 1097      KIR3DL7                42
# 3629       CD158Z                42

# %%
ensg_alias_alias_collision_set = set(ensg_dup_alias_count_df['alias_symbol'])
len(ensg_alias_alias_collision_set)
# Out:
# 5307

# %%
ensg_dup_alias_count_df.to_csv('../ensg_dup_alias_count_df.csv', index=True)

# %%
ensg_alias_count_histogram_df = ensg_dup_alias_count_df.pivot_table(index = ['num_gene_records'], aggfunc ='size')
ensg_alias_count_histogram_df
# Out:
# num_gene_records
# 2      3738
# 3       394
# 4       173
# 5       112
# 6       160
# 7       278
# 8       258
# 9        17
# 10       50
# 11        6
# 12        4
# 13       11
# 14        8
# 15        5
# 16       15
# 18        1
# 21        2
# 25        4
# 26        1
# 28        1
# 30        4
# 31        6
# 32       10
# 33        9
# 35        8
# 41        2
# 42        4
# 43        5
# 53        1
# 82        3
# 108      11
# 211       1
# 216       4
# 218       1
# dtype: int64

# %%
ensg_alias_count_histogram_df = ensg_alias_count_histogram_df.reset_index()
ensg_alias_count_histogram_df
# Out:
#     num_gene_records     0
# 0                  2  3738
# 1                  3   394
# 2                  4   173
# 3                  5   112
# 4                  6   160
# 5                  7   278
# 6                  8   258
# 7                  9    17
# 8                 10    50
# 9                 11     6
# 10                12     4
# 11                13    11
# 12                14     8
# 13                15     5
# 14                16    15
# 15                18     1
# 16                21     2
# 17                25     4
# 18                26     1
# 19                28     1
# 20                30     4
# 21                31     6
# 22                32    10
# 23                33     9
# 24                35     8
# 25                41     2
# 26                42     4
# 27                43     5
# 28                53     1
# 29                82     3
# 30               108    11
# 31               211     1
# 32               216     4
# 33               218     1

# %%
ensg_alias_count_histogram_df.rename(columns={0:'num_alias_symbol'}, inplace=True )
ensg_alias_count_histogram_df
# Out:
#     num_gene_records  num_alias_symbol
# 0                  2              3738
# 1                  3               394
# 2                  4               173
# 3                  5               112
# 4                  6               160
# 5                  7               278
# 6                  8               258
# 7                  9                17
# 8                 10                50
# 9                 11                 6
# 10                12                 4
# 11                13                11
# 12                14                 8
# 13                15                 5
# 14                16                15
# 15                18                 1
# 16                21                 2
# 17                25                 4
# 18                26                 1
# 19                28                 1
# 20                30                 4
# 21                31                 6
# 22                32                10
# 23                33                 9
# 24                35                 8
# 25                41                 2
# 26                42                 4
# 27                43                 5
# 28                53                 1
# 29                82                 3
# 30               108                11
# 31               211                 1
# 32               216                 4
# 33               218                 1

# %%
ensg_alias_count_histogram_df['percent_alias_symbol'] = ((ensg_alias_count_histogram_df['num_alias_symbol'] / ensg_alias_len) * 100)
ensg_alias_count_histogram_df
# Out:
#     num_gene_records  num_alias_symbol  percent_alias_symbol
# 0                  2              3738              6.805520
# 1                  3               394              0.717329
# 2                  4               173              0.314969
# 3                  5               112              0.203911
# 4                  6               160              0.291301
# 5                  7               278              0.506136
# 6                  8               258              0.469723
# 7                  9                17              0.030951
# 8                 10                50              0.091032
# 9                 11                 6              0.010924
# 10                12                 4              0.007283
# 11                13                11              0.020027
# 12                14                 8              0.014565
# 13                15                 5              0.009103
# 14                16                15              0.027309
# 15                18                 1              0.001821
# 16                21                 2              0.003641
# 17                25                 4              0.007283
# 18                26                 1              0.001821
# 19                28                 1              0.001821
# 20                30                 4              0.007283
# 21                31                 6              0.010924
# 22                32                10              0.018206
# 23                33                 9              0.016386
# 24                35                 8              0.014565
# 25                41                 2              0.003641
# 26                42                 4              0.007283
# 27                43                 5              0.009103
# 28                53                 1              0.001821
# 29                82                 3              0.005462
# 30               108                11              0.020027
# 31               211                 1              0.001821
# 32               216                 4              0.007283
# 33               218                 1              0.001821

# %%
ensg_alias_count_histogram_df = ensg_alias_count_histogram_df.drop('num_alias_symbol', axis=1)
ensg_alias_count_histogram_df
# Out:
#     num_gene_records  percent_alias_symbol
# 0                  2              6.805520
# 1                  3              0.717329
# 2                  4              0.314969
# 3                  5              0.203911
# 4                  6              0.291301
# 5                  7              0.506136
# 6                  8              0.469723
# 7                  9              0.030951
# 8                 10              0.091032
# 9                 11              0.010924
# 10                12              0.007283
# 11                13              0.020027
# 12                14              0.014565
# 13                15              0.009103
# 14                16              0.027309
# 15                18              0.001821
# 16                21              0.003641
# 17                25              0.007283
# 18                26              0.001821
# 19                28              0.001821
# 20                30              0.007283
# 21                31              0.010924
# 22                32              0.018206
# 23                33              0.016386
# 24                35              0.014565
# 25                41              0.003641
# 26                42              0.007283
# 27                43              0.009103
# 28                53              0.001821
# 29                82              0.005462
# 30               108              0.020027
# 31               211              0.001821
# 32               216              0.007283
# 33               218              0.001821

# %%
#px.bar(ensg_alias_count_histogram_df, x='num_gene_records', y='percent_alias_symbol')

# %%
ensg_dup_alias_count_df.to_csv('../ensg_alias_overlap_count.csv', index=True)

# %% [markdown]
# #### <a id='toc1_1_10_1_'></a>[Save as csv](#toc0_)

# %%
#mini_ensg_df_explode.to_csv('../ensg_alias_overlap.csv', index=False)

# %% [markdown]
# ### <a id='toc1_1_11_'></a>[Put columns in different order to ephasize alias symbols instead of gene records](#toc0_)

# %%
mini_ensg_df
# Out:
#                ENSG_ID alias_symbol gene_symbol  entrez_id source
# 672    ENSG00000277362       15.212     KIR2DL4  124900568   ENSG
# 8516   ENSG00000284365       15.212     KIR2DL4  124900568   ENSG
# 8515   ENSG00000284365       15.212     KIR2DL4       3805   ENSG
# 8349   ENSG00000284206       15.212     KIR2DL4  124900568   ENSG
# 8348   ENSG00000284206       15.212     KIR2DL4       3805   ENSG
# ...                ...          ...         ...        ...    ...
# 23567  ENSG00000227211          p56       H3P45          0   ENSG
# 7724   ENSG00000283997    promethin       LDAF1      57146   ENSG
# 37151  ENSG00000011638    promethin       LDAF1      57146   ENSG
# 27797  ENSG00000100181    psiTPTE22      TPTEP1          0   ENSG
# 27801  ENSG00000290418    psiTPTE22      TPTEP1     387590   ENSG
#
# [20879 rows x 5 columns]

# %%
mini_ensg_df_2 = mini_ensg_df[['alias_symbol', 'ENSG_ID', 'gene_symbol', 'source']]
mini_ensg_df_2
# Out:
#       alias_symbol          ENSG_ID gene_symbol source
# 672         15.212  ENSG00000277362     KIR2DL4   ENSG
# 8516        15.212  ENSG00000284365     KIR2DL4   ENSG
# 8515        15.212  ENSG00000284365     KIR2DL4   ENSG
# 8349        15.212  ENSG00000284206     KIR2DL4   ENSG
# 8348        15.212  ENSG00000284206     KIR2DL4   ENSG
# ...            ...              ...         ...    ...
# 23567          p56  ENSG00000227211       H3P45   ENSG
# 7724     promethin  ENSG00000283997       LDAF1   ENSG
# 37151    promethin  ENSG00000011638       LDAF1   ENSG
# 27797    psiTPTE22  ENSG00000100181      TPTEP1   ENSG
# 27801    psiTPTE22  ENSG00000290418      TPTEP1   ENSG
#
# [20879 rows x 4 columns]

# %% [markdown]
# ### <a id='toc1_1_12_'></a>[Merge rows with matching alias symbols](#toc0_)

# %%
mini_ensg_df_2 = mini_ensg_df_2.drop_duplicates(subset = ["alias_symbol", "gene_symbol"], keep = 'first')

# %%
mini_ensg_df_2 = mini_ensg_df_2.applymap(str)
mini_ensg_df_2
# Out:
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_14988/1088055158.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   mini_ensg_df_2 = mini_ensg_df_2.applymap(str)
#       alias_symbol          ENSG_ID gene_symbol source
# 672         15.212  ENSG00000277362     KIR2DL4   ENSG
# 26945       5T4-AG  ENSG00000146242        TPBG   ENSG
# 12461         A1AT  ENSG00000277377    SERPINA1   ENSG
# 5321       A3GALT1  ENSG00000281879         ABO   ENSG
# 2816           AAP  ENSG00000276838    SERPINF2   ENSG
# ...            ...              ...         ...    ...
# 50103          p55  ENSG00000117461      PIK3R3   ENSG
# 8105           p56  ENSG00000100764       PSMC1   ENSG
# 23567          p56  ENSG00000227211       H3P45   ENSG
# 7724     promethin  ENSG00000283997       LDAF1   ENSG
# 27797    psiTPTE22  ENSG00000100181      TPTEP1   ENSG
#
# [6524 rows x 4 columns]

# %%
mini_ensg_df_2 = mini_ensg_df_2.groupby('alias_symbol').agg({'ENSG_ID': ', '.join, 
                             'gene_symbol': ', '.join, 
                             'source':'first' }).reset_index()
mini_ensg_df_2
# Out:
#      alias_symbol                           ENSG_ID     gene_symbol source
# 0          15.212                   ENSG00000277362         KIR2DL4   ENSG
# 1          5T4-AG                   ENSG00000146242            TPBG   ENSG
# 2            A1AT                   ENSG00000277377        SERPINA1   ENSG
# 3         A3GALT1                   ENSG00000281879             ABO   ENSG
# 4             AAP                   ENSG00000276838        SERPINF2   ENSG
# ...           ...                               ...             ...    ...
# 5302          p42  ENSG00000100519, ENSG00000227443    PSMC6, H3P30   ENSG
# 5303          p55  ENSG00000197170, ENSG00000117461  PSMD12, PIK3R3   ENSG
# 5304          p56  ENSG00000100764, ENSG00000227211    PSMC1, H3P45   ENSG
# 5305    promethin                   ENSG00000283997           LDAF1   ENSG
# 5306    psiTPTE22                   ENSG00000100181          TPTEP1   ENSG
#
# [5307 rows x 4 columns]

# %% [markdown]
# # <a id='toc2_'></a>[HGNC](#toc0_)

# %%
df1 = pd.read_csv("hgnc_filtered.csv")

# %% [markdown]
# ### <a id='toc2_1_1_'></a>[Drop all columns besides ENSG_ID, gene_symbol, and alias_symbol](#toc0_)

# %%
mini_hgnc_df = df1.drop(['Unnamed: 0', 'hgnc_id', 'locus_type', 'name', 'mane_select', 'locus_group', 'entrez_id', 'agr', 'refseq_accession', 'alias_name', 'ENSEMBLtrans', 'NA', 'unknown'], axis=1)
mini_hgnc_df = mini_hgnc_df.rename(columns = {'ensembl_gene_id':'ENSG_ID', 'symbol':'gene_symbol'})
mini_hgnc_df
# Out:
#       gene_symbol          ENSG_ID                   alias_symbol
# 0            A1BG  ENSG00000121410                            NaN
# 1        A1BG-AS1  ENSG00000268895                       FLJ23569
# 2            A1CF  ENSG00000148584  ACF;ASP;ACF64;ACF65;APOBEC1CF
# 3             A2M  ENSG00000175899           FWP007;S863-7;CPAMD5
# 4         A2M-AS1  ENSG00000245105                            NaN
# ...           ...              ...                            ...
# 43159      ZYG11B  ENSG00000162378                       FLJ13456
# 43160         ZYX  ENSG00000159840                            NaN
# 43161       ZYXP1  ENSG00000274572                            NaN
# 43162       ZZEF1  ENSG00000074755         KIAA0399;ZZZ4;FLJ10821
# 43163        ZZZ3  ENSG00000036549             DKFZP564I052;ATAC1
#
# [43164 rows x 3 columns]

# %% [markdown]
# ### <a id='toc2_1_2_'></a>[How many total unique gene records are there](#toc0_)

# %%
hgnc_gene_symbol_set = set(mini_hgnc_df['gene_symbol'])
len(hgnc_gene_symbol_set)
# Out:
# 43164

# %% [markdown]
# Looking at IGHV as an example:

# %%
hgnc_IGHV_alias_df = mini_hgnc_df[mini_hgnc_df['gene_symbol'].str.contains('IGHV')]

# %%
type(mini_hgnc_df.gene_symbol[0])
# Out:
# str

# %%
hgnc_IGHV_alias_df.to_csv('../hgnc_IGHV_alias_df.csv')

# %%
hgnc_IGHV_alias_count_df = mini_hgnc_df.copy
hgnc_IGHV_alias_count_df = mini_hgnc_df.loc[mini_hgnc_df['gene_symbol'] == "IGHV1-24" ]
hgnc_IGHV_alias_count_df
# Out:
#       gene_symbol          ENSG_ID alias_symbol
# 12539    IGHV1-24  ENSG00000211950          NaN

# %%
hgnc_IGHV_alias_count_df = mini_hgnc_df.copy
hgnc_IGHV_alias_count_df = mini_hgnc_df.loc[mini_hgnc_df['ENSG_ID'] == "ENSG00000211950" ]
hgnc_IGHV_alias_count_df
# Out:
#       gene_symbol          ENSG_ID alias_symbol
# 12539    IGHV1-24  ENSG00000211950          NaN

# %% [markdown]
# ### <a id='toc2_1_3_'></a>[Drop genes with no aliases](#toc0_)

# %%
mini_hgnc_df = mini_hgnc_df[mini_hgnc_df["alias_symbol"].str.contains("NaN") == False]
mini_hgnc_df
# Out:
#       gene_symbol          ENSG_ID                   alias_symbol
# 1        A1BG-AS1  ENSG00000268895                       FLJ23569
# 2            A1CF  ENSG00000148584  ACF;ASP;ACF64;ACF65;APOBEC1CF
# 3             A2M  ENSG00000175899           FWP007;S863-7;CPAMD5
# 5           A2ML1  ENSG00000166535                  FLJ25179;p170
# 9         A3GALT2  ENSG00000184389                   IGBS3S;IGB3S
# ...           ...              ...                            ...
# 43156        ZXDC  ENSG00000070476              MGC11349;FLJ13861
# 43157      ZYG11A  ENSG00000203995                          ZYG11
# 43159      ZYG11B  ENSG00000162378                       FLJ13456
# 43162       ZZEF1  ENSG00000074755         KIAA0399;ZZZ4;FLJ10821
# 43163        ZZZ3  ENSG00000036549             DKFZP564I052;ATAC1
#
# [21967 rows x 3 columns]

# %% [markdown]
# ### <a id='toc2_1_4_'></a>[Make each row in alias_symbol a set:](#toc0_)
#     covert to a list
#     make a set

# %%
mini_hgnc_df['alias_symbol'] = mini_hgnc_df['alias_symbol'].astype(str)
mini_hgnc_df['alias_symbol'] = [x.split(';') for x in mini_hgnc_df.alias_symbol]
mini_hgnc_df['alias_symbol']=np.where(mini_hgnc_df.alias_symbol=='','',mini_hgnc_df.alias_symbol.map(set))
mini_hgnc_df.head(1)
# Out:
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_14988/1085824394.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mini_hgnc_df['alias_symbol'] = mini_hgnc_df['alias_symbol'].astype(str)
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_14988/1085824394.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mini_hgnc_df['alias_symbol'] = [x.split(';') for x in mini_hgnc_df.alias_symbol]
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_14988/1085824394.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mini_hgnc_df['alias_symbol']=np.where(mini_hgnc_df.alias_symbol=='','',mini_hgnc_df.alias_symbol.map(set))
#   gene_symbol          ENSG_ID alias_symbol
# 1    A1BG-AS1  ENSG00000268895   {FLJ23569}

# %% [markdown]
# ### <a id='toc2_1_5_'></a>[Explode the alias sets so that it is one per row](#toc0_)

# %%
mini_hgnc_df = mini_hgnc_df.explode(column="alias_symbol")
mini_hgnc_df.head(5)
# Out:
#   gene_symbol          ENSG_ID alias_symbol
# 1    A1BG-AS1  ENSG00000268895     FLJ23569
# 2        A1CF  ENSG00000148584          ASP
# 2        A1CF  ENSG00000148584          ACF
# 2        A1CF  ENSG00000148584        ACF64
# 2        A1CF  ENSG00000148584        ACF65

# %% [markdown]
# Looking at CD158b as an example:

# %%
mini_hgnc_df.loc[mini_hgnc_df['gene_symbol'] == "CD158b" ]
# Out:
# Empty DataFrame
# Columns: [gene_symbol, ENSG_ID, alias_symbol]
# Index: []

# %%
hgnc_CD158b_alias_count_df = mini_hgnc_df.copy
hgnc_CD158b_alias_count_df = mini_hgnc_df.loc[mini_hgnc_df['alias_symbol'] == "CD158b" ]
hgnc_CD158b_alias_count_df
# Out:
# Empty DataFrame
# Columns: [gene_symbol, ENSG_ID, alias_symbol]
# Index: []

# %%
hgnc_CD158b_alias_count_df.to_csv('../hgnc_CD158b_alias_count_df.csv')

# %% [markdown]
# ### <a id='toc2_1_6_'></a>[How many total unique aliases are there](#toc0_)

# %%
hgnc_alias_symbol_set = set(mini_hgnc_df['alias_symbol'])
hgnc_alias_len = len(hgnc_alias_symbol_set)
hgnc_alias_len
# Out:
# 41589

# %% [markdown]
# ### <a id='toc2_1_7_'></a>[Pull out all the rows that have an alias symbol that can be found elsewhere](#toc0_)

# %%
mini_hgnc_df['alias_duplicates'] = mini_hgnc_df.duplicated(subset= 'alias_symbol', keep=False)
mini_hgnc_df = mini_hgnc_df[mini_hgnc_df['alias_duplicates'] == True]
mini_hgnc_df = mini_hgnc_df.drop(['alias_duplicates'], axis=1)
mini_hgnc_df.head(5)
# Out:
#    gene_symbol          ENSG_ID alias_symbol
# 2         A1CF  ENSG00000148584          ASP
# 22       AAGAB  ENSG00000103591          p34
# 65       ABCB8  ENSG00000197150       M-ABC1
# 67      ABCB10  ENSG00000135776       M-ABC2
# 68    ABCB10P1  ENSG00000274099       M-ABC2

# %% [markdown]
# ### <a id='toc2_1_8_'></a>[Sort alias symbols alphabetically](#toc0_)

# %%
mini_hgnc_df = mini_hgnc_df.sort_values('alias_symbol')
mini_hgnc_df
# Out:
#       gene_symbol          ENSG_ID alias_symbol
# 35226     SLC25A5  ENSG00000005022          2F1
# 13978       KLRG1  ENSG00000139187          2F1
# 33987      S100A8  ENSG00000143546       60B8AG
# 33988      S100A9  ENSG00000163220       60B8AG
# 31335       RNU6V  ENSG00000206832         87U6
# ...           ...              ...          ...
# 38078     TEX28P2  ENSG00000277008         pTEX
# 26200     PPP4R3A  ENSG00000100796         smk1
# 26203     PPP4R3C  ENSG00000224960         smk1
# 36662     SPATA2L  ENSG00000158792         tamo
# 36661      SPATA2  ENSG00000158480         tamo
#
# [2348 rows x 3 columns]

# %% [markdown]
# ### <a id='toc2_1_9_'></a>[Number of records with an alias that is shared](#toc0_)

# %%
hgnc_gene_symbol_set_wsharedalias = set(mini_hgnc_df['gene_symbol'])
len(hgnc_gene_symbol_set_wsharedalias)
# Out:
# 2084

# %%
mini_hgnc_df['source'] = 'HGNC'
mini_hgnc_df
# Out:
#       gene_symbol          ENSG_ID alias_symbol source
# 35226     SLC25A5  ENSG00000005022          2F1   HGNC
# 13978       KLRG1  ENSG00000139187          2F1   HGNC
# 33987      S100A8  ENSG00000143546       60B8AG   HGNC
# 33988      S100A9  ENSG00000163220       60B8AG   HGNC
# 31335       RNU6V  ENSG00000206832         87U6   HGNC
# ...           ...              ...          ...    ...
# 38078     TEX28P2  ENSG00000277008         pTEX   HGNC
# 26200     PPP4R3A  ENSG00000100796         smk1   HGNC
# 26203     PPP4R3C  ENSG00000224960         smk1   HGNC
# 36662     SPATA2L  ENSG00000158792         tamo   HGNC
# 36661      SPATA2  ENSG00000158480         tamo   HGNC
#
# [2348 rows x 4 columns]

# %% [markdown]
# ### <a id='toc2_1_10_'></a>[Count the number of times each multi-use alias is used](#toc0_)

# %%
hgnc_dup_alias_count_df = mini_hgnc_df.pivot_table(index = ['alias_symbol'], aggfunc ='size')
hgnc_dup_alias_count_df
# Out:
# alias_symbol
# 2F1       2
# 60B8AG    2
# 87U6      2
# 9G8       2
# A1        3
#          ..
# p97       4
# pH2A/f    2
# pTEX      2
# smk1      2
# tamo      2
# Length: 1040, dtype: int64

# %%
hgnc_dup_alias_count_df = hgnc_dup_alias_count_df.reset_index()
hgnc_dup_alias_count_df
# Out:
#      alias_symbol  0
# 0             2F1  2
# 1          60B8AG  2
# 2            87U6  2
# 3             9G8  2
# 4              A1  3
# ...           ... ..
# 1035          p97  4
# 1036       pH2A/f  2
# 1037         pTEX  2
# 1038         smk1  2
# 1039         tamo  2
#
# [1040 rows x 2 columns]

# %%
print(hgnc_dup_alias_count_df.columns)
# Out:
# Index(['alias_symbol', 0], dtype='object')

# %%
hgnc_dup_alias_count_df.rename(columns={0:'num_gene_records'}, inplace=True )
hgnc_dup_alias_count_df
# Out:
#      alias_symbol  num_gene_records
# 0             2F1                 2
# 1          60B8AG                 2
# 2            87U6                 2
# 3             9G8                 2
# 4              A1                 3
# ...           ...               ...
# 1035          p97                 4
# 1036       pH2A/f                 2
# 1037         pTEX                 2
# 1038         smk1                 2
# 1039         tamo                 2
#
# [1040 rows x 2 columns]

# %%
hgnc_dup_alias_count_df = hgnc_dup_alias_count_df.sort_values('num_gene_records', ascending=False)
hgnc_dup_alias_count_df.head(30)
# Out:
#      alias_symbol  num_gene_records
# 68            ASP                 7
# 653           PAP                 7
# 935            U4                 7
# 118           CAP                 6
# 568           MYM                 6
# 267          F379                 6
# 27           AIP1                 6
# 1012          p40                 5
# 31            ALP                 5
# 571          NAP1                 5
# 933            U3                 5
# 100          BTF2                 5
# 735           PSP                 5
# 932            U2                 5
# 991           p18                 5
# 986           p14                 5
# 1024          p55                 5
# 718        PPIase                 5
# 887         TFIIH                 5
# 18            ACT                 4
# 766           RIP                 4
# 1034          p85                 4
# 1035          p97                 4
# 308           GBP                 4
# 863            T1                 4
# 375          HCP1                 4
# 55            ARP                 4
# 56           ARP1                 4
# 929           U13                 4
# 425         ILWEQ                 4

# %%
hgnc_alias_alias_collision_set = set(hgnc_dup_alias_count_df['alias_symbol'])
len(hgnc_alias_alias_collision_set)
# Out:
# 1040

# %%
hgnc_dup_alias_count_df.to_csv('../hgnc_dup_alias_count_df.csv', index=True)

# %%
hgnc_alias_count_histogram_df = hgnc_dup_alias_count_df.pivot_table(index = ['num_gene_records'], aggfunc ='size')
hgnc_alias_count_histogram_df
# Out:
# num_gene_records
# 2    858
# 3    125
# 4     38
# 5     12
# 6      4
# 7      3
# dtype: int64

# %%
hgnc_alias_count_histogram_df = hgnc_alias_count_histogram_df.reset_index()
hgnc_alias_count_histogram_df
# Out:
#    num_gene_records    0
# 0                 2  858
# 1                 3  125
# 2                 4   38
# 3                 5   12
# 4                 6    4
# 5                 7    3

# %%
hgnc_alias_count_histogram_df.rename(columns={0:'num_alias_symbol'}, inplace=True )
hgnc_alias_count_histogram_df
# Out:
#    num_gene_records  num_alias_symbol
# 0                 2               858
# 1                 3               125
# 2                 4                38
# 3                 5                12
# 4                 6                 4
# 5                 7                 3

# %%
hgnc_alias_count_histogram_df['percent_alias_symbol'] = ((hgnc_alias_count_histogram_df['num_alias_symbol'] / hgnc_alias_len) * 100)
hgnc_alias_count_histogram_df
# Out:
#    num_gene_records  num_alias_symbol  percent_alias_symbol
# 0                 2               858              2.063046
# 1                 3               125              0.300560
# 2                 4                38              0.091370
# 3                 5                12              0.028854
# 4                 6                 4              0.009618
# 5                 7                 3              0.007213

# %%
hgnc_alias_count_histogram_df = hgnc_alias_count_histogram_df.drop('num_alias_symbol', axis=1)
hgnc_alias_count_histogram_df
# Out:
#    num_gene_records  percent_alias_symbol
# 0                 2              2.063046
# 1                 3              0.300560
# 2                 4              0.091370
# 3                 5              0.028854
# 4                 6              0.009618
# 5                 7              0.007213

# %%
#px.bar(hgnc_alias_count_histogram_df, x='num_gene_records', y='percent_alias_symbol')

# %% [markdown]
# #### <a id='toc2_1_10_1_'></a>[Save as csv](#toc0_)

# %%
#mini_hgnc_df_explode.to_csv('../hgnc_alias_overlap.csv', index=False)

# %% [markdown]
# ### <a id='toc2_1_11_'></a>[Put columns in different order to ephasize alias symbols instead of gene records](#toc0_)

# %%
mini_hgnc_df_2 = mini_hgnc_df.drop_duplicates(subset = ["alias_symbol", "gene_symbol"], keep = 'first')

# %%
mini_hgnc_df_2 = mini_hgnc_df[['alias_symbol', 'ENSG_ID', 'gene_symbol', 'source']]
mini_hgnc_df_2
# Out:
#       alias_symbol          ENSG_ID gene_symbol source
# 35226          2F1  ENSG00000005022     SLC25A5   HGNC
# 13978          2F1  ENSG00000139187       KLRG1   HGNC
# 33987       60B8AG  ENSG00000143546      S100A8   HGNC
# 33988       60B8AG  ENSG00000163220      S100A9   HGNC
# 31335         87U6  ENSG00000206832       RNU6V   HGNC
# ...            ...              ...         ...    ...
# 38078         pTEX  ENSG00000277008     TEX28P2   HGNC
# 26200         smk1  ENSG00000100796     PPP4R3A   HGNC
# 26203         smk1  ENSG00000224960     PPP4R3C   HGNC
# 36662         tamo  ENSG00000158792     SPATA2L   HGNC
# 36661         tamo  ENSG00000158480      SPATA2   HGNC
#
# [2348 rows x 4 columns]

# %% [markdown]
# ### <a id='toc2_1_12_'></a>[Merge rows with matching alias symbols](#toc0_)

# %%
mini_hgnc_df_2 = mini_hgnc_df_2.applymap(str)
mini_hgnc_df_2
# Out:
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_14988/2517928805.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   mini_hgnc_df_2 = mini_hgnc_df_2.applymap(str)
#       alias_symbol          ENSG_ID gene_symbol source
# 35226          2F1  ENSG00000005022     SLC25A5   HGNC
# 13978          2F1  ENSG00000139187       KLRG1   HGNC
# 33987       60B8AG  ENSG00000143546      S100A8   HGNC
# 33988       60B8AG  ENSG00000163220      S100A9   HGNC
# 31335         87U6  ENSG00000206832       RNU6V   HGNC
# ...            ...              ...         ...    ...
# 38078         pTEX  ENSG00000277008     TEX28P2   HGNC
# 26200         smk1  ENSG00000100796     PPP4R3A   HGNC
# 26203         smk1  ENSG00000224960     PPP4R3C   HGNC
# 36662         tamo  ENSG00000158792     SPATA2L   HGNC
# 36661         tamo  ENSG00000158480      SPATA2   HGNC
#
# [2348 rows x 4 columns]

# %%
mini_hgnc_df_2 = mini_hgnc_df_2.groupby('alias_symbol').agg({'ENSG_ID': ', '.join, 
                             'gene_symbol': ', '.join, 
                             'source':'first' }).reset_index()
mini_hgnc_df_2
# Out:
#      alias_symbol                                            ENSG_ID  \
# 0             2F1                   ENSG00000005022, ENSG00000139187
# 1          60B8AG                   ENSG00000143546, ENSG00000163220
# 2            87U6                   ENSG00000206832, ENSG00000065135
# 3             9G8                   ENSG00000164609, ENSG00000115875
# 4              A1  ENSG00000035928, ENSG00000163918, ENSG00000049541
# ...           ...                                                ...
# 1035          p97  ENSG00000179409, ENSG00000110321, ENSG00000153...
# 1036       pH2A/f                   ENSG00000234816, ENSG00000196787
# 1037         pTEX                   ENSG00000274962, ENSG00000277008
# 1038         smk1                   ENSG00000100796, ENSG00000224960
# 1039         tamo                   ENSG00000158792, ENSG00000158480
#
#                      gene_symbol source
# 0                 SLC25A5, KLRG1   HGNC
# 1                 S100A8, S100A9   HGNC
# 2                   RNU6V, GNAI3   HGNC
# 3                    SLU7, SRSF7   HGNC
# 4               RFC1, RFC4, RFC2   HGNC
# ...                          ...    ...
# 1035  GEMIN4, EIF4G2, CFDP1, VCP   HGNC
# 1036              H2AC5P, H2AC11   HGNC
# 1037            TEX28P1, TEX28P2   HGNC
# 1038            PPP4R3A, PPP4R3C   HGNC
# 1039             SPATA2L, SPATA2   HGNC
#
# [1040 rows x 4 columns]

# %%
#mini_hgnc_df_2.to_csv('../hgnc_alias_overlap_2.csv', index=False)

# %% [markdown]
# # <a id='toc3_'></a>[NCBI Info](#toc0_)

# %%
df2 = pd.read_csv("ncbi_info_20220719_filtered.csv")
# Out:
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_14988/259522327.py:1: DtypeWarning: Columns (15,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2 = pd.read_csv("ncbi_info_20220719_filtered.csv")

# %% [markdown]
# ### <a id='toc3_1_1_'></a>[Drop all columns besides ENSG_ID, gene_symbol, and alias_symbol](#toc0_)

# %%
mini_ncbi_df = df2.drop(['Unnamed: 0', '#tax_id','GeneID', 'dbXrefs', 'description', 'type_of_gene', 'Symbol_from_nomenclature_authority', 'Full_name_from_nomenclature_authority', 'Other_designations', 'MIM', 'HGNC', 'AllianceGenome','MIRbase', 'IMGTgene_db', 'dash', 'unknown'], axis=1)
mini_ncbi_df = mini_ncbi_df.rename(columns = {'Symbol':'gene_symbol','Synonyms':'alias_symbol', 'ENSEMBL':'ENSG_ID'})
mini_ncbi_df['ENSG_ID'] = mini_ncbi_df['ENSG_ID'].astype(str)
mini_ncbi_df['ENSG_ID'] = mini_ncbi_df['ENSG_ID'].apply(str.upper)
mini_ncbi_df
# Out:
#       gene_symbol               alias_symbol          ENSG_ID
# 0            A1BG       A1B|ABG|GAB|HYST2477  ENSG00000121410
# 1             A2M  A2MD|CPAMD5|FWP007|S863-7  ENSG00000175899
# 2           A2MP1                       A2MP  ENSG00000256069
# 3            NAT1       AAC1|MNAT|NAT-1|NATI  ENSG00000171428
# 4            NAT2            AAC2|NAT-2|PNAT  ENSG00000156006
# ...           ...                        ...              ...
# 75495        trnD                          -              NAN
# 75496        trnP                          -              NAN
# 75497        trnA                          -              NAN
# 75498        COX1                          -              NAN
# 75499    16S rRNA                          -              NAN
#
# [75500 rows x 3 columns]

# %% [markdown]
# ### <a id='toc3_1_2_'></a>[How many total unique gene records are there](#toc0_)

# %%
ncbi_gene_symbol_set = set(mini_ncbi_df['gene_symbol'])
len(ncbi_gene_symbol_set)
# Out:
# 75346

# %% [markdown]
# ### <a id='toc3_1_3_'></a>[Drop genes with no aliases](#toc0_)

# %%
mini_ncbi_df = mini_ncbi_df.replace("-", np.nan)
mini_ncbi_df
# Out:
#       gene_symbol               alias_symbol          ENSG_ID
# 0            A1BG       A1B|ABG|GAB|HYST2477  ENSG00000121410
# 1             A2M  A2MD|CPAMD5|FWP007|S863-7  ENSG00000175899
# 2           A2MP1                       A2MP  ENSG00000256069
# 3            NAT1       AAC1|MNAT|NAT-1|NATI  ENSG00000171428
# 4            NAT2            AAC2|NAT-2|PNAT  ENSG00000156006
# ...           ...                        ...              ...
# 75495        trnD                        NaN              NAN
# 75496        trnP                        NaN              NAN
# 75497        trnA                        NaN              NAN
# 75498        COX1                        NaN              NAN
# 75499    16S rRNA                        NaN              NAN
#
# [75500 rows x 3 columns]

# %%
mini_ncbi_df = mini_ncbi_df.dropna(subset=['alias_symbol'])
mini_ncbi_df
# Out:
#         gene_symbol               alias_symbol          ENSG_ID
# 0              A1BG       A1B|ABG|GAB|HYST2477  ENSG00000121410
# 1               A2M  A2MD|CPAMD5|FWP007|S863-7  ENSG00000175899
# 2             A2MP1                       A2MP  ENSG00000256069
# 3              NAT1       AAC1|MNAT|NAT-1|NATI  ENSG00000171428
# 4              NAT2            AAC2|NAT-2|PNAT  ENSG00000156006
# ...             ...                        ...              ...
# 71686  LOC124906931                       WASH              NAN
# 71738  LOC124906983                       WASH              NAN
# 72857  LOC124908102                       WASH              NAN
# 74876       POLGARF                 ORF-Y|POLG              NAN
# 75424       CDCA3P1                  lncCDCA3L              NAN
#
# [27316 rows x 3 columns]

# %% [markdown]
# ### <a id='toc3_1_4_'></a>[Make each row in alias_symbol a set:](#toc0_)
#     covert to a list
#     make a set

# %%
mini_ncbi_df['alias_symbol'] = mini_ncbi_df['alias_symbol'].astype(str)
mini_ncbi_df['alias_symbol'] = [x.split('|') for x in mini_ncbi_df.alias_symbol]
mini_ncbi_df['alias_symbol']=np.where(mini_ncbi_df.alias_symbol=='','',mini_ncbi_df.alias_symbol.map(set))
mini_ncbi_df.head(1)
# Out:
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_14988/2736731455.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mini_ncbi_df['alias_symbol'] = mini_ncbi_df['alias_symbol'].astype(str)
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_14988/2736731455.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mini_ncbi_df['alias_symbol'] = [x.split('|') for x in mini_ncbi_df.alias_symbol]
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_14988/2736731455.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mini_ncbi_df['alias_symbol']=np.where(mini_ncbi_df.alias_symbol=='','',mini_ncbi_df.alias_symbol.map(set))
#   gene_symbol               alias_symbol          ENSG_ID
# 0        A1BG  {ABG, A1B, HYST2477, GAB}  ENSG00000121410

# %% [markdown]
# ### <a id='toc3_1_5_'></a>[Explode the alias sets so that it is one per row](#toc0_)

# %%
mini_ncbi_df = mini_ncbi_df.explode(column="alias_symbol")
mini_ncbi_df.head(5)
# Out:
#   gene_symbol alias_symbol          ENSG_ID
# 0        A1BG          ABG  ENSG00000121410
# 0        A1BG          A1B  ENSG00000121410
# 0        A1BG     HYST2477  ENSG00000121410
# 0        A1BG          GAB  ENSG00000121410
# 1         A2M       CPAMD5  ENSG00000175899

# %%
#ncbi_CD158b_alias_count_df.to_csv('../ncbi_CD158b_alias_count_df.csv')

# %% [markdown]
# ### <a id='toc3_1_6_'></a>[How many unique aliases are there](#toc0_)

# %%
ncbi_alias_symbol_set = set(mini_ncbi_df['alias_symbol'])
ncbi_alias_len = len(ncbi_alias_symbol_set)
ncbi_alias_len
# Out:
# 67454

# %% [markdown]
# ### <a id='toc3_1_7_'></a>[Pull out all the rows that have an alias symbol that can be found elsewhere](#toc0_)

# %%
mini_ncbi_df['alias_duplicates'] = mini_ncbi_df.duplicated(subset= 'alias_symbol', keep=False)
mini_ncbi_df = mini_ncbi_df[mini_ncbi_df['alias_duplicates'] == True]
mini_ncbi_df = mini_ncbi_df.drop(['alias_duplicates'], axis=1)
mini_ncbi_df.head(5)
# Out:
#   gene_symbol alias_symbol          ENSG_ID
# 0        A1BG          A1B  ENSG00000121410
# 3        NAT1         AAC1  ENSG00000171428
# 3        NAT1        NAT-1  ENSG00000171428
# 4        NAT2         AAC2  ENSG00000156006
# 6    SERPINA3          ACT  ENSG00000196136

# %% [markdown]
# ### <a id='toc3_1_8_'></a>[Sort alias symbols alphabetically](#toc0_)

# %%
mini_ncbi_df = mini_ncbi_df.sort_values('alias_symbol')
mini_ncbi_df.head(5)
# Out:
#      gene_symbol alias_symbol          ENSG_ID
# 4534        PTEN     10q23del  ENSG00000171862
# 537       BMPR1A     10q23del  ENSG00000107779
# 199       ALOX12       12-LOX  ENSG00000108839
# 205       ALOX15       12-LOX  ENSG00000161905
# 245      SLC25A5          2F1  ENSG00000005022

# %% [markdown]
# ### <a id='toc3_1_9_'></a>[Number of records with an alias that is shared](#toc0_)

# %%
ncbi_gene_symbol_set_wsharedalias = set(mini_ncbi_df['gene_symbol'])
len(ncbi_gene_symbol_set_wsharedalias)
# Out:
# 5670

# %%
mini_ncbi_df['source'] = 'NCBI Info'
mini_ncbi_df
# Out:
#       gene_symbol alias_symbol          ENSG_ID     source
# 4534         PTEN     10q23del  ENSG00000171862  NCBI Info
# 537        BMPR1A     10q23del  ENSG00000107779  NCBI Info
# 199        ALOX12       12-LOX  ENSG00000108839  NCBI Info
# 205        ALOX15       12-LOX  ENSG00000161905  NCBI Info
# 245       SLC25A5          2F1  ENSG00000005022  NCBI Info
# ...           ...          ...              ...        ...
# 12929     PPP4R3A         smk1  ENSG00000100796  NCBI Info
# 13546     PPP4R3B         smk1  ENSG00000275052  NCBI Info
# 18205     PPP4R3C         smk1  ENSG00000224960  NCBI Info
# 17549     SPATA2L         tamo  ENSG00000158792  NCBI Info
# 7647       SPATA2         tamo  ENSG00000158480  NCBI Info
#
# [8247 rows x 4 columns]

# %% [markdown]
# ### <a id='toc3_1_10_'></a>[Count the number of times each multi-use alias is used](#toc0_)

# %%
ncbi_dup_alias_count_df = mini_ncbi_df.pivot_table(index = ['alias_symbol'], aggfunc ='size')
ncbi_dup_alias_count_df
# Out:
# alias_symbol
# 10q23del       2
# 12-LOX         2
# 2F1            2
# 3-alpha-HSD    2
# 35DAG          2
#               ..
# pTEX           2
# polymerase     3
# rpL7a          2
# smk1           3
# tamo           2
# Length: 3427, dtype: int64

# %%
ncbi_dup_alias_count_df.to_csv('../ncbi_alias_overlap_count.csv', index=True)

# %%
ncbi_dup_alias_count_df = ncbi_dup_alias_count_df.reset_index()
ncbi_dup_alias_count_df
# Out:
#      alias_symbol  0
# 0        10q23del  2
# 1          12-LOX  2
# 2             2F1  2
# 3     3-alpha-HSD  2
# 4           35DAG  2
# ...           ... ..
# 3422         pTEX  2
# 3423   polymerase  3
# 3424        rpL7a  2
# 3425         smk1  3
# 3426         tamo  2
#
# [3427 rows x 2 columns]

# %%
ncbi_dup_alias_count_df.rename(columns={0:'num_gene_records'}, inplace=True )
ncbi_dup_alias_count_df
# Out:
#      alias_symbol  num_gene_records
# 0        10q23del                 2
# 1          12-LOX                 2
# 2             2F1                 2
# 3     3-alpha-HSD                 2
# 4           35DAG                 2
# ...           ...               ...
# 3422         pTEX                 2
# 3423   polymerase                 3
# 3424        rpL7a                 2
# 3425         smk1                 3
# 3426         tamo                 2
#
# [3427 rows x 2 columns]

# %%
ncbi_dup_alias_count_df = ncbi_dup_alias_count_df.sort_values('num_gene_records', ascending=False)
ncbi_dup_alias_count_df.head(30)
# Out:
#      alias_symbol  num_gene_records
# 3260           VH                36
# 1284        H4-16                14
# 1297         H4C9                13
# 1286        H4C11                13
# 1287        H4C12                13
# 1288        H4C13                13
# 1296         H4C8                13
# 1289        H4C14                13
# 1290        H4C15                13
# 1291         H4C2                13
# 1292         H4C3                13
# 1293         H4C4                13
# 1294         H4C5                13
# 1295         H4C6                13
# 1285         H4C1                13
# 1958          MT1                12
# 1192         GPCR                11
# 1442         HOX1                10
# 2455           PR                10
# 1444         HOX2                 9
# 1272        H3C12                 9
# 3225        UDPGT                 9
# 3233         UGT1                 9
# 1269         H3C1                 9
# 2447       PPIase                 9
# 1270        H3C10                 9
# 1271        H3C11                 9
# 1992         NAP1                 9
# 1276         H3C2                 9
# 1277         H3C3                 9

# %%
ncbi_alias_alias_collision_set = set(ncbi_dup_alias_count_df['alias_symbol'])
len(ncbi_alias_alias_collision_set)
# Out:
# 3427

# %%
ncbi_dup_alias_count_df.to_csv('../ncbi_dup_alias_count_df.csv', index=True)

# %%
ncbi_alias_count_histogram_df = ncbi_dup_alias_count_df.pivot_table(index = ['num_gene_records'], aggfunc ='size')
ncbi_alias_count_histogram_df
# Out:
# num_gene_records
# 2     2748
# 3      404
# 4      142
# 5       51
# 6       24
# 7       17
# 8        7
# 9       15
# 10       2
# 11       1
# 12       1
# 13      13
# 14       1
# 36       1
# dtype: int64

# %%
ncbi_alias_count_histogram_df = ncbi_alias_count_histogram_df.reset_index()
ncbi_alias_count_histogram_df
# Out:
#     num_gene_records     0
# 0                  2  2748
# 1                  3   404
# 2                  4   142
# 3                  5    51
# 4                  6    24
# 5                  7    17
# 6                  8     7
# 7                  9    15
# 8                 10     2
# 9                 11     1
# 10                12     1
# 11                13    13
# 12                14     1
# 13                36     1

# %%
ncbi_alias_count_histogram_df.rename(columns={0:'num_alias_symbol'}, inplace=True )
ncbi_alias_count_histogram_df
# Out:
#     num_gene_records  num_alias_symbol
# 0                  2              2748
# 1                  3               404
# 2                  4               142
# 3                  5                51
# 4                  6                24
# 5                  7                17
# 6                  8                 7
# 7                  9                15
# 8                 10                 2
# 9                 11                 1
# 10                12                 1
# 11                13                13
# 12                14                 1
# 13                36                 1

# %%
ncbi_alias_count_histogram_df['percent_alias_symbol'] = ((ncbi_alias_count_histogram_df['num_alias_symbol'] / ncbi_alias_len) * 100)
ncbi_alias_count_histogram_df
# Out:
#     num_gene_records  num_alias_symbol  percent_alias_symbol
# 0                  2              2748              4.073887
# 1                  3               404              0.598927
# 2                  4               142              0.210514
# 3                  5                51              0.075607
# 4                  6                24              0.035580
# 5                  7                17              0.025202
# 6                  8                 7              0.010377
# 7                  9                15              0.022237
# 8                 10                 2              0.002965
# 9                 11                 1              0.001482
# 10                12                 1              0.001482
# 11                13                13              0.019272
# 12                14                 1              0.001482
# 13                36                 1              0.001482

# %%
ncbi_alias_count_histogram_df = ncbi_alias_count_histogram_df.drop('num_alias_symbol', axis=1)
ncbi_alias_count_histogram_df
# Out:
#     num_gene_records  percent_alias_symbol
# 0                  2              4.073887
# 1                  3              0.598927
# 2                  4              0.210514
# 3                  5              0.075607
# 4                  6              0.035580
# 5                  7              0.025202
# 6                  8              0.010377
# 7                  9              0.022237
# 8                 10              0.002965
# 9                 11              0.001482
# 10                12              0.001482
# 11                13              0.019272
# 12                14              0.001482
# 13                36              0.001482

# %%
# px.bar(ncbi_alias_count_histogram_df, x='num_gene_records', y='percent_alias_symbol')

# %% [markdown]
# ### <a id='toc3_1_11_'></a>[Put columns in different order to ephasize alias symbols instead of gene records](#toc0_)

# %%
mini_ncbi_df_2 = mini_ncbi_df.drop_duplicates(subset = ["alias_symbol", "gene_symbol"], keep = 'first')

# %%
mini_ncbi_df_2 = mini_ncbi_df[['alias_symbol', 'ENSG_ID', 'gene_symbol', 'source']]
mini_ncbi_df_2
# Out:
#       alias_symbol          ENSG_ID gene_symbol     source
# 4534      10q23del  ENSG00000171862        PTEN  NCBI Info
# 537       10q23del  ENSG00000107779      BMPR1A  NCBI Info
# 199         12-LOX  ENSG00000108839      ALOX12  NCBI Info
# 205         12-LOX  ENSG00000161905      ALOX15  NCBI Info
# 245            2F1  ENSG00000005022     SLC25A5  NCBI Info
# ...            ...              ...         ...        ...
# 12929         smk1  ENSG00000100796     PPP4R3A  NCBI Info
# 13546         smk1  ENSG00000275052     PPP4R3B  NCBI Info
# 18205         smk1  ENSG00000224960     PPP4R3C  NCBI Info
# 17549         tamo  ENSG00000158792     SPATA2L  NCBI Info
# 7647          tamo  ENSG00000158480      SPATA2  NCBI Info
#
# [8247 rows x 4 columns]

# %% [markdown]
# ### <a id='toc3_1_12_'></a>[Merge rows with matching alias symbols](#toc0_)

# %%
mini_ncbi_df_2 = mini_ncbi_df_2.applymap(str)
mini_ncbi_df_2
# Out:
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_14988/792032257.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   mini_ncbi_df_2 = mini_ncbi_df_2.applymap(str)
#       alias_symbol          ENSG_ID gene_symbol     source
# 4534      10q23del  ENSG00000171862        PTEN  NCBI Info
# 537       10q23del  ENSG00000107779      BMPR1A  NCBI Info
# 199         12-LOX  ENSG00000108839      ALOX12  NCBI Info
# 205         12-LOX  ENSG00000161905      ALOX15  NCBI Info
# 245            2F1  ENSG00000005022     SLC25A5  NCBI Info
# ...            ...              ...         ...        ...
# 12929         smk1  ENSG00000100796     PPP4R3A  NCBI Info
# 13546         smk1  ENSG00000275052     PPP4R3B  NCBI Info
# 18205         smk1  ENSG00000224960     PPP4R3C  NCBI Info
# 17549         tamo  ENSG00000158792     SPATA2L  NCBI Info
# 7647          tamo  ENSG00000158480      SPATA2  NCBI Info
#
# [8247 rows x 4 columns]

# %%
mini_ncbi_df_2['ENSG_ID'] = mini_ncbi_df_2['ENSG_ID'].str.replace('NAN','nan')
mini_ncbi_df_2
# Out:
#       alias_symbol          ENSG_ID gene_symbol     source
# 4534      10q23del  ENSG00000171862        PTEN  NCBI Info
# 537       10q23del  ENSG00000107779      BMPR1A  NCBI Info
# 199         12-LOX  ENSG00000108839      ALOX12  NCBI Info
# 205         12-LOX  ENSG00000161905      ALOX15  NCBI Info
# 245            2F1  ENSG00000005022     SLC25A5  NCBI Info
# ...            ...              ...         ...        ...
# 12929         smk1  ENSG00000100796     PPP4R3A  NCBI Info
# 13546         smk1  ENSG00000275052     PPP4R3B  NCBI Info
# 18205         smk1  ENSG00000224960     PPP4R3C  NCBI Info
# 17549         tamo  ENSG00000158792     SPATA2L  NCBI Info
# 7647          tamo  ENSG00000158480      SPATA2  NCBI Info
#
# [8247 rows x 4 columns]

# %%
mini_ncbi_df_2 = mini_ncbi_df_2.groupby('alias_symbol').agg({'ENSG_ID': ', '.join, 
                             'gene_symbol': ', '.join, 
                             'source':'first' }).reset_index()
mini_ncbi_df_2
# Out:
#      alias_symbol                                            ENSG_ID  \
# 0        10q23del                   ENSG00000171862, ENSG00000107779
# 1          12-LOX                   ENSG00000108839, ENSG00000161905
# 2             2F1                   ENSG00000005022, ENSG00000139187
# 3     3-alpha-HSD                   ENSG00000198610, ENSG00000073737
# 4           35DAG                   ENSG00000170624, ENSG00000102683
# ...           ...                                                ...
# 3422         pTEX                   ENSG00000274962, ENSG00000277008
# 3423   polymerase                                      nan, nan, nan
# 3424        rpL7a                   ENSG00000213272, ENSG00000240522
# 3425         smk1  ENSG00000100796, ENSG00000275052, ENSG00000224960
# 3426         tamo                   ENSG00000158792, ENSG00000158480
#
#                     gene_symbol     source
# 0                  PTEN, BMPR1A  NCBI Info
# 1                ALOX12, ALOX15  NCBI Info
# 2                SLC25A5, KLRG1  NCBI Info
# 3                 AKR1C4, DHRS9  NCBI Info
# 4                    SGCD, SGCG  NCBI Info
# ...                         ...        ...
# 3422           TEX28P1, TEX28P2  NCBI Info
# 3423   ERVK-11, ERVK-9, ERVK-19  NCBI Info
# 3424          RPL7AP9, RPL7AP10  NCBI Info
# 3425  PPP4R3A, PPP4R3B, PPP4R3C  NCBI Info
# 3426            SPATA2L, SPATA2  NCBI Info
#
# [3427 rows x 4 columns]

# %% [markdown]
# # <a id='toc4_'></a>[Merge to create Alias Overlap Table 1 - Gene Symbol](#toc0_)

# %%
merged_alias_overlap_df_1 = pd.concat([mini_hgnc_df[['gene_symbol', 'ENSG_ID', 'alias_symbol', 'source']],mini_ncbi_df[['gene_symbol', 'ENSG_ID', 'alias_symbol', 'source']], mini_ensg_df[['gene_symbol', 'ENSG_ID', 'alias_symbol', 'source']]])
merged_alias_overlap_df_1
# Out:
#       gene_symbol          ENSG_ID alias_symbol source
# 35226     SLC25A5  ENSG00000005022          2F1   HGNC
# 13978       KLRG1  ENSG00000139187          2F1   HGNC
# 33987      S100A8  ENSG00000143546       60B8AG   HGNC
# 33988      S100A9  ENSG00000163220       60B8AG   HGNC
# 31335       RNU6V  ENSG00000206832         87U6   HGNC
# ...           ...              ...          ...    ...
# 23567       H3P45  ENSG00000227211          p56   ENSG
# 7724        LDAF1  ENSG00000283997    promethin   ENSG
# 37151       LDAF1  ENSG00000011638    promethin   ENSG
# 27797      TPTEP1  ENSG00000100181    psiTPTE22   ENSG
# 27801      TPTEP1  ENSG00000290418    psiTPTE22   ENSG
#
# [31474 rows x 4 columns]

# %%
merged_alias_overlap_df_1.to_csv('../merged_alias_overlap_df_1.csv', index=False)

# %%
merged_alias_overlap_df_1.loc[merged_alias_overlap_df_1.gene_symbol == 'H4-16']
# Out:
# Empty DataFrame
# Columns: [gene_symbol, ENSG_ID, alias_symbol, source]
# Index: []

# %%
merged_alias_overlap_df_1.loc[merged_alias_overlap_df_1.alias_symbol == 'H4-16' ]
# Out:
#       gene_symbol          ENSG_ID alias_symbol     source
# 6491        H4C13  ENSG00000275126        H4-16  NCBI Info
# 6487         H4C3  ENSG00000197061        H4-16  NCBI Info
# 6483         H4C4  ENSG00000277157        H4-16  NCBI Info
# 6486        H4C11  ENSG00000197238        H4-16  NCBI Info
# 6482         H4C1  ENSG00000278637        H4-16  NCBI Info
# 6493        H4C14  ENSG00000270882        H4-16  NCBI Info
# 6484         H4C6  ENSG00000274618        H4-16  NCBI Info
# 6485        H4C12  ENSG00000273542        H4-16  NCBI Info
# 17448       H4C16  ENSG00000197837        H4-16  NCBI Info
# 6430         H4C9  ENSG00000276180        H4-16  NCBI Info
# 6490         H4C5  ENSG00000276966        H4-16  NCBI Info
# 6489         H4C2  ENSG00000278705        H4-16  NCBI Info
# 6488         H4C8  ENSG00000158406        H4-16  NCBI Info
# 25509       H4C15  ENSG00000270276        H4-16  NCBI Info
# 47957       H4C16  ENSG00000197837        H4-16       ENSG
# 47958       H4C16  ENSG00000197837        H4-16       ENSG

# %%
merged_alias_overlap_df_1['source'].value_counts()
# Out:
# source
# ENSG         20879
# NCBI Info     8247
# HGNC          2348
# Name: count, dtype: int64

# %% [markdown]
# # <a id='toc5_'></a>[Merge to create Alias Overlap Table 2 - Alias Symbol](#toc0_)

# %%
merged_alias_overlap_df_2 = pd.concat([mini_hgnc_df_2[['alias_symbol', 'gene_symbol', 'ENSG_ID', 'source']],mini_ncbi_df_2[['alias_symbol', 'gene_symbol', 'ENSG_ID', 'source']], mini_ensg_df_2[['alias_symbol', 'gene_symbol', 'ENSG_ID', 'source']]])
merged_alias_overlap_df_2
# Out:
#      alias_symbol       gene_symbol  \
# 0             2F1    SLC25A5, KLRG1
# 1          60B8AG    S100A8, S100A9
# 2            87U6      RNU6V, GNAI3
# 3             9G8       SLU7, SRSF7
# 4              A1  RFC1, RFC4, RFC2
# ...           ...               ...
# 5302          p42      PSMC6, H3P30
# 5303          p55    PSMD12, PIK3R3
# 5304          p56      PSMC1, H3P45
# 5305    promethin             LDAF1
# 5306    psiTPTE22            TPTEP1
#
#                                                 ENSG_ID source
# 0                      ENSG00000005022, ENSG00000139187   HGNC
# 1                      ENSG00000143546, ENSG00000163220   HGNC
# 2                      ENSG00000206832, ENSG00000065135   HGNC
# 3                      ENSG00000164609, ENSG00000115875   HGNC
# 4     ENSG00000035928, ENSG00000163918, ENSG00000049541   HGNC
# ...                                                 ...    ...
# 5302                   ENSG00000100519, ENSG00000227443   ENSG
# 5303                   ENSG00000197170, ENSG00000117461   ENSG
# 5304                   ENSG00000100764, ENSG00000227211   ENSG
# 5305                                    ENSG00000283997   ENSG
# 5306                                    ENSG00000100181   ENSG
#
# [9774 rows x 4 columns]

# %%
merged_alias_overlap_df_2.loc[merged_alias_overlap_df_2['alias_symbol'] == "RN5S3" ]
# Out:
#      alias_symbol gene_symbol          ENSG_ID source
# 4853        RN5S3      RNA5S3  ENSG00000285168   ENSG

# %%
merged_alias_overlap_df_2['gene_symbol'] = merged_alias_overlap_df_2['gene_symbol'].str.split(",")
merged_alias_overlap_df_2
# Out:
#      alias_symbol           gene_symbol  \
# 0             2F1     [SLC25A5,  KLRG1]
# 1          60B8AG     [S100A8,  S100A9]
# 2            87U6       [RNU6V,  GNAI3]
# 3             9G8        [SLU7,  SRSF7]
# 4              A1  [RFC1,  RFC4,  RFC2]
# ...           ...                   ...
# 5302          p42       [PSMC6,  H3P30]
# 5303          p55     [PSMD12,  PIK3R3]
# 5304          p56       [PSMC1,  H3P45]
# 5305    promethin               [LDAF1]
# 5306    psiTPTE22              [TPTEP1]
#
#                                                 ENSG_ID source
# 0                      ENSG00000005022, ENSG00000139187   HGNC
# 1                      ENSG00000143546, ENSG00000163220   HGNC
# 2                      ENSG00000206832, ENSG00000065135   HGNC
# 3                      ENSG00000164609, ENSG00000115875   HGNC
# 4     ENSG00000035928, ENSG00000163918, ENSG00000049541   HGNC
# ...                                                 ...    ...
# 5302                   ENSG00000100519, ENSG00000227443   ENSG
# 5303                   ENSG00000197170, ENSG00000117461   ENSG
# 5304                   ENSG00000100764, ENSG00000227211   ENSG
# 5305                                    ENSG00000283997   ENSG
# 5306                                    ENSG00000100181   ENSG
#
# [9774 rows x 4 columns]

# %%
merged_alias_overlap_df_2['gene_symbol_count'] = [len(c) for c in merged_alias_overlap_df_2['gene_symbol']]
merged_alias_overlap_df_2
# Out:
#      alias_symbol           gene_symbol  \
# 0             2F1     [SLC25A5,  KLRG1]
# 1          60B8AG     [S100A8,  S100A9]
# 2            87U6       [RNU6V,  GNAI3]
# 3             9G8        [SLU7,  SRSF7]
# 4              A1  [RFC1,  RFC4,  RFC2]
# ...           ...                   ...
# 5302          p42       [PSMC6,  H3P30]
# 5303          p55     [PSMD12,  PIK3R3]
# 5304          p56       [PSMC1,  H3P45]
# 5305    promethin               [LDAF1]
# 5306    psiTPTE22              [TPTEP1]
#
#                                                 ENSG_ID source  \
# 0                      ENSG00000005022, ENSG00000139187   HGNC
# 1                      ENSG00000143546, ENSG00000163220   HGNC
# 2                      ENSG00000206832, ENSG00000065135   HGNC
# 3                      ENSG00000164609, ENSG00000115875   HGNC
# 4     ENSG00000035928, ENSG00000163918, ENSG00000049541   HGNC
# ...                                                 ...    ...
# 5302                   ENSG00000100519, ENSG00000227443   ENSG
# 5303                   ENSG00000197170, ENSG00000117461   ENSG
# 5304                   ENSG00000100764, ENSG00000227211   ENSG
# 5305                                    ENSG00000283997   ENSG
# 5306                                    ENSG00000100181   ENSG
#
#       gene_symbol_count
# 0                     2
# 1                     2
# 2                     2
# 3                     2
# 4                     3
# ...                 ...
# 5302                  2
# 5303                  2
# 5304                  2
# 5305                  1
# 5306                  1
#
# [9774 rows x 5 columns]

# %%
merged_alias_overlap_df_2 = merged_alias_overlap_df_2.sort_values(by='gene_symbol_count', ascending= False)
merged_alias_overlap_df_2
# Out:
#      alias_symbol                                        gene_symbol  \
# 3260           VH  [IGHV1-24,  IGHV3-43,  IGHM,  IGHV3-9,  IGHV3-...
# 1284        H4-16  [H4C13,  H4C3,  H4C4,  H4C11,  H4C1,  H4C14,  ...
# 1287        H4C12  [H4C15,  H4C5,  H4C3,  H4C1,  H4C4,  H4C6,  H4...
# 1294         H4C5  [H4C6,  H4C4,  H4C12,  H4C16,  H4C11,  H4C14, ...
# 1292         H4C3  [H4C14,  H4C4,  H4C1,  H4C8,  H4C5,  H4C15,  H...
# ...           ...                                                ...
# 1937       PNUTL4                                          [SEPTIN9]
# 1936        PNOCR                                            [OPRL1]
# 1935        PNMA4                                            [MOAP1]
# 1932        PMSR3                                           [PMS2P3]
# 5306    psiTPTE22                                           [TPTEP1]
#
#                                                 ENSG_ID     source  \
# 3260  ENSG00000211950, ENSG00000232216, ENSG00000211...  NCBI Info
# 1284  ENSG00000275126, ENSG00000197061, ENSG00000277...  NCBI Info
# 1287  ENSG00000270276, ENSG00000276966, ENSG00000197...  NCBI Info
# 1294  ENSG00000274618, ENSG00000277157, ENSG00000273...  NCBI Info
# 1292  ENSG00000270882, ENSG00000277157, ENSG00000278...  NCBI Info
# ...                                                 ...        ...
# 1937                                    ENSG00000282302       ENSG
# 1936                                    ENSG00000125510       ENSG
# 1935                                    ENSG00000165943       ENSG
# 1932                                    ENSG00000291092       ENSG
# 5306                                    ENSG00000100181       ENSG
#
#       gene_symbol_count
# 3260                 36
# 1284                 14
# 1287                 13
# 1294                 13
# 1292                 13
# ...                 ...
# 1937                  1
# 1936                  1
# 1935                  1
# 1932                  1
# 5306                  1
#
# [9774 rows x 5 columns]

# %%
merged_alias_overlap_df_2['source'].value_counts()
# Out:
# source
# ENSG         5307
# NCBI Info    3427
# HGNC         1040
# Name: count, dtype: int64

# %%
merged_alias_overlap_df_2.to_csv('../merged_alias_overlap_df_2.csv', index=True)

# %% [markdown]
# # DGIdb ambiguous query

# %%
dgidb_gene_df = pd.read_csv("dgidb_genes_df.tsv", sep='\t')
dgidb_gene_df
# Out:
#            name nomenclature  concept_id gene_claim_name  \
# 0           MN1  Gene Symbol   hgnc:7180             MN1
# 1         P2RX7  Gene Symbol   hgnc:8537           P2RX7
# 2        CHRNA7  Gene Symbol   hgnc:1960          CHRNA7
# 3         MAPK8  Gene Symbol   hgnc:6881           MAPK8
# 4        MAPK10  Gene Symbol   hgnc:6872          MAPK10
# ...         ...          ...         ...             ...
# 73884  MAPKAPK5    Gene Name   hgnc:6889        MAPKAPK5
# 73885    PTGER3    Gene Name   hgnc:9595          PTGER3
# 73886      CD1D    Gene Name   hgnc:1637            CD1D
# 73887   SLC26A1  Gene Symbol  hgnc:10993         SLC26A1
# 73888     SOCS1  Gene Symbol  hgnc:19383           SOCS1
#
#                    source_db_name source_db_version
# 0      CarisMolecularIntelligence          5-Jun-23
# 1                          ChEMBL                32
# 2                          ChEMBL                32
# 3                          ChEMBL                32
# 4                          ChEMBL                32
# ...                           ...               ...
# 73884                         DTC          5-Jun-23
# 73885                         DTC          5-Jun-23
# 73886                         DTC          5-Jun-23
# 73887                         IDG         15-Jul-19
# 73888          FoundationOneGenes          5-Jun-23
#
# [73889 rows x 6 columns]

# %%
symbol_col_comparison = dgidb_gene_df['name'] == dgidb_gene_df['gene_claim_name']
symbol_col_comparison.value_counts()
# Out:
# True     62221
# False    11668
# Name: count, dtype: int64

# %%
symbol_col_comparison
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 73884    True
# 73885    True
# 73886    True
# 73887    True
# 73888    True
# Length: 73889, dtype: bool

# %%
dgidb_gene_df.dtypes
# Out:
# name                 object
# nomenclature         object
# concept_id           object
# gene_claim_name      object
# source_db_name       object
# source_db_version    object
# dtype: object

# %%
dgidb_gene_df.query('name != gene_claim_name')
# Out:
#                           name     nomenclature  concept_id gene_claim_name  \
# 25                       HSP90      Gene Symbol   hgnc:5253        HSP90AA1
# 100                       RPLP      Gene Symbol         NaN             NaN
# 167                      SEPT6      Gene Symbol  hgnc:15848         SEPTIN6
# 169                      SEPT5      Gene Symbol   hgnc:9164         SEPTIN5
# 213                      WISP3      Gene Symbol  hgnc:12771            CCN6
# ...                        ...              ...         ...             ...
# 73631  ENSEMBL:ENSG00000185821  Ensembl Gene ID  hgnc:31305          OR6C76
# 73642                 C11ORF30      Gene Symbol  hgnc:18071            EMSY
# 73727  ENSEMBL:ENSG00000183921  Ensembl Gene ID  hgnc:35414         SDR42E2
# 73872                       MR   NCBI Gene Name   hgnc:7979           NR3C2
# 73878  ENSEMBL:ENSG00000173213  Ensembl Gene ID  hgnc:24983          TUBB8B
#
#                    source_db_name source_db_version
# 25                         ChEMBL                32
# 100                        ChEMBL                32
# 167    CarisMolecularIntelligence          5-Jun-23
# 169    CarisMolecularIntelligence          5-Jun-23
# 213    CarisMolecularIntelligence          5-Jun-23
# ...                           ...               ...
# 73631                  RussLampel         26-Jul-11
# 73642          FoundationOneGenes          5-Jun-23
# 73727                  RussLampel         26-Jul-11
# 73872                    BaderLab            14-Feb
# 73878                  RussLampel         26-Jul-11
#
# [11668 rows x 6 columns]

# %%
no_claim_symbols_df = dgidb_gene_df[dgidb_gene_df['gene_claim_name'].isnull()]
no_claim_symbols_df
# Out:
#                     name nomenclature concept_id gene_claim_name  \
# 100                 RPLP  Gene Symbol        NaN             NaN
# 353                 EMBA  Gene Symbol        NaN             NaN
# 355                 RPLQ  Gene Symbol        NaN             NaN
# 402                 ILES  Gene Symbol        NaN             NaN
# 439                 MURA  Gene Symbol        NaN             NaN
# ...                  ...          ...        ...             ...
# 26386   CCNK-CDK13_HUMAN  Gene Symbol        NaN             NaN
# 26387      INO80_HUMAN-1  Gene Symbol        NaN             NaN
# 26388    CCNC-CDK3_HUMAN  Gene Symbol        NaN             NaN
# 26573  TRYPTASE_B2_HUMAN  Gene Symbol        NaN             NaN
# 26574  TRYPTASE_B1_HUMAN  Gene Symbol        NaN             NaN
#
#       source_db_name source_db_version
# 100           ChEMBL                32
# 353           ChEMBL                32
# 355           ChEMBL                32
# 402           ChEMBL                32
# 439           ChEMBL                32
# ...              ...               ...
# 26386             GO          5-Jun-23
# 26387             GO          5-Jun-23
# 26388             GO          5-Jun-23
# 26573             GO          5-Jun-23
# 26574             GO          5-Jun-23
#
# [2159 rows x 6 columns]

# %%
no_name_symbols_df = dgidb_gene_df[dgidb_gene_df['name'].isnull()]
no_name_symbols_df
# Out:
#      name nomenclature  concept_id gene_claim_name source_db_name  \
# 463   NaN  Gene Symbol  hgnc:12811              XK         ChEMBL
# 4643  NaN    Gene Name  hgnc:12811              XK       DrugBank
#
#      source_db_version
# 463                 32
# 4643             5.1.9

# %%
dgidb_name_set = set(dgidb_gene_df['name'])
len(dgidb_name_set)
# Out:
# 21619

# %%
dgidb_gene_claim_name_set = set(dgidb_gene_df['gene_claim_name'])
len(dgidb_gene_claim_name_set)
# Out:
# 11287

# %%
name_ensg_notmatch = dgidb_name_set.difference(ensg_gene_symbol_set)
len(name_ensg_notmatch)
# Out:
# 10422

# %%
gene_claim_name_ensg_notmatch = dgidb_gene_claim_name_set.difference(ensg_gene_symbol_set)
len(gene_claim_name_ensg_notmatch)
# Out:
# 107

# %%
cleaned_gene_claim_name_ensg_notmatch = [x for x in gene_claim_name_ensg_notmatch if str(x) != 'NaN']
len(cleaned_gene_claim_name_ensg_notmatch)
# Out:
# 107

# %%
name_hgnc_notmatch = dgidb_name_set.difference(hgnc_gene_symbol_set)
len(name_hgnc_notmatch)
# Out:
# 10374

# %%
name_hngc_notmatch_aacollision = name_hgnc_notmatch.intersection(hgnc_alias_alias_collision_set)
len(name_hngc_notmatch_aacollision)
# Out:
# 29

# %%
cleaned_name_hgnc_notmatch = [x for x in name_hgnc_notmatch if str(x) != 'NaN']
len(cleaned_name_hgnc_notmatch)
# Out:
# 10374

# %%
gene_claim_name_hgnc_notmatch = dgidb_gene_claim_name_set.difference(hgnc_gene_symbol_set)
len(gene_claim_name_hgnc_notmatch)
# Out:
# 66

# %%
name_ncbi_notmatch = dgidb_name_set.difference(ncbi_gene_symbol_set)
len(name_ncbi_notmatch)
# Out:
# 10351

# %%
name_ncbi_notmatch_aacollision = name_ncbi_notmatch.intersection(ncbi_alias_alias_collision_set)
len(name_ncbi_notmatch_aacollision)
# Out:
# 96

# %%
name_ncbi_hgnc_notmatch = name_ncbi_notmatch.difference(hgnc_gene_symbol_set)
len(name_ncbi_hgnc_notmatch)
# Out:
# 10335

# %%
name_ncbi_hgnc_ensg_notmatch = name_ncbi_hgnc_notmatch.difference(ensg_gene_symbol_set)
len(name_ncbi_hgnc_ensg_notmatch)
# Out:
# 10331

# %%
gene_claim_name_ncbi_notmatch = dgidb_gene_claim_name_set.difference(ncbi_gene_symbol_set)
len(gene_claim_name_ncbi_notmatch)
# Out:
# 63

# %%
gene_claim_name_ncbi_hngc_notmatch = gene_claim_name_ncbi_notmatch.difference(hgnc_gene_symbol_set)
len(gene_claim_name_ncbi_hngc_notmatch)
# Out:
# 47

# %%
gene_claim_name_ncbi_hngc_ensg_notmatch = gene_claim_name_ncbi_hngc_notmatch.difference(ensg_gene_symbol_set)
len(gene_claim_name_ncbi_hngc_ensg_notmatch)
# Out:
# 44

# %%
name_hgnc_match = dgidb_name_set.intersection(hgnc_gene_symbol_set)
len(name_hgnc_match)
# Out:
# 11245

# %%
name_hgnc_match_aacollision = name_hgnc_match.intersection(hgnc_alias_alias_collision_set)
len(name_hgnc_match_aacollision)
# Out:
# 29

# %%
name_ensg_match = dgidb_name_set.intersection(ensg_gene_symbol_set)
len(name_ensg_match)
# Out:
# 11197

# %%
name_ncbi_match = dgidb_name_set.intersection(ncbi_gene_symbol_set)
len(name_ncbi_match)
# Out:
# 11268

# %%
name_ncbi_match_aacollision = name_ncbi_match.intersection(ncbi_alias_alias_collision_set)
len(name_ncbi_match_aacollision)
# Out:
# 112

# %%
name_ncbi_ensg_match = name_ncbi_match.intersection(ensg_gene_symbol_set)
len(name_ncbi_ensg_match)
# Out:
# 11178

# %%
name_ncbi_ensg_hgnc_match = name_ncbi_ensg_match.intersection(hgnc_gene_symbol_set)
len(name_ncbi_ensg_hgnc_match)
# Out:
# 11176

# %%
gene_claim_name_hgnc_match = dgidb_gene_claim_name_set.intersection(hgnc_gene_symbol_set)
len(gene_claim_name_hgnc_match)
# Out:
# 11221

# %%
gene_claim_name_ensg_match = dgidb_gene_claim_name_set.intersection(ensg_gene_symbol_set)
len(gene_claim_name_ensg_match)
# Out:
# 11180

# %%
gene_claim_name_ensg_aacollision_match = dgidb_gene_claim_name_set.intersection(ensg_alias_alias_collision_set)
len(gene_claim_name_ensg_aacollision_match)
# Out:
# 14

# %%
gene_claim_name_hgnc_aacollision_match = dgidb_gene_claim_name_set.intersection(hgnc_alias_alias_collision_set)
len(gene_claim_name_hgnc_aacollision_match)
# Out:
# 30

# %%
gene_claim_name_ncbi_aacollision_match = dgidb_gene_claim_name_set.intersection(ncbi_alias_alias_collision_set)
len(gene_claim_name_ncbi_aacollision_match)
# Out:
# 113

# %%
name_ensg_aacollision_match = dgidb_name_set.intersection(ensg_alias_alias_collision_set)
len(name_ensg_aacollision_match)
# Out:
# 43

# %%
name_hgnc_aacollision_match = dgidb_name_set.intersection(hgnc_alias_alias_collision_set)
len(name_hgnc_aacollision_match)
# Out:
# 58

# %%
name_ncbi_aacollision_match = dgidb_name_set.intersection(ncbi_alias_alias_collision_set)
len(name_ncbi_aacollision_match)
# Out:
# 208

# %%
gene_claim_name_hgnc_notmatch = dgidb_gene_claim_name_set.difference(hgnc_gene_symbol_set)
len(gene_claim_name_hgnc_notmatch)
# Out:
# 66

# %%
gene_claim_name_hgnc_notmatch_aacollision = gene_claim_name_hgnc_notmatch.intersection(hgnc_alias_alias_collision_set)
len(gene_claim_name_hgnc_notmatch_aacollision)
# Out:
# 1

# %%
gene_claim_name_ensg_notmatch = dgidb_gene_claim_name_set.difference(ensg_gene_symbol_set)
len(gene_claim_name_ensg_notmatch)
# Out:
# 107

# %%
gene_claim_name_ncbi_notmatch = dgidb_gene_claim_name_set.difference(ncbi_gene_symbol_set)
len(gene_claim_name_ncbi_notmatch)
# Out:
# 63

# %%
gene_claim_name_ncbi_notmatch_aacollision = gene_claim_name_ncbi_notmatch.intersection(ncbi_alias_alias_collision_set)
len(gene_claim_name_ncbi_notmatch_aacollision)
# Out:
# 1

# %%
gene_claim_name_hgnc_match = dgidb_gene_claim_name_set.intersection(hgnc_gene_symbol_set)
len(gene_claim_name_hgnc_match)
# Out:
# 11221

# %%
gene_claim_name_hgnc_match_aacollision = gene_claim_name_hgnc_match.intersection(hgnc_alias_alias_collision_set)
len(gene_claim_name_hgnc_match_aacollision)
# Out:
# 29

# %%
gene_claim_name_ncbi_match = dgidb_gene_claim_name_set.intersection(ncbi_gene_symbol_set)
len(gene_claim_name_ncbi_match)
# Out:
# 11224

# %%
gene_claim_name_ncbi_match_aacollision = gene_claim_name_ncbi_match.intersection(ncbi_alias_alias_collision_set)
len(gene_claim_name_ncbi_match_aacollision)
# Out:
# 112

# %%
name_ensg_match_aacollision = name_ensg_match.intersection(ensg_alias_alias_collision_set)
len(name_ensg_match_aacollision)
# Out:
# 13

# %%
len(gene_claim_name_ncbi_hngc_ensg_notmatch)
# Out:
# 44

# %%
len(name_ncbi_hgnc_ensg_notmatch)
# Out:
# 10331

# %%
len(dgidb_name_set)
# Out:
# 21619

# %%
len(dgidb_gene_claim_name_set)
# Out:
# 11287

# %%
name_ensg_notmatch_aacollision = name_ensg_notmatch.intersection(ensg_alias_alias_collision_set)
len(name_ensg_notmatch_aacollision)
# Out:
# 30

# %%
gene_claim_name_ensg_match_aacollision = gene_claim_name_ensg_match.intersection(ensg_alias_alias_collision_set)
len(gene_claim_name_ensg_match_aacollision)
# Out:
# 13

# %%
gene_claim_name_ensg_notmatch_aacollision = gene_claim_name_ensg_notmatch.intersection(ensg_alias_alias_collision_set)
len(gene_claim_name_ensg_notmatch_aacollision)
# Out:
# 1

# %%
gene_claim_name_ncbi_notmatch_aacollision = gene_claim_name_ncbi_notmatch.intersection(ncbi_alias_alias_collision_set)
len(gene_claim_name_ncbi_notmatch_aacollision)
# Out:
# 1

# %%
gene_claim_name_ncbi_match_aacollision = gene_claim_name_ncbi_match.intersection(ncbi_alias_alias_collision_set)
len(gene_claim_name_ncbi_match_aacollision)
# Out:
# 112

# %%
gene_claim_name_hgnc_match_aacollision = gene_claim_name_hgnc_match.intersection(hgnc_alias_alias_collision_set)
len(gene_claim_name_hgnc_match_aacollision)
# Out:
# 29

# %%
gene_claim_name_hgnc_notmatch_aacollision = gene_claim_name_hgnc_notmatch.intersection(hgnc_alias_alias_collision_set)
len(gene_claim_name_hgnc_notmatch_aacollision)
# Out:
# 1

# %% [markdown]
# Pull out instances of claim symbols that match to a primary gene symbol and the corresponding group symbols not matching to a primary gene symbol. Check for patterns of modes of error

# %%
dgidb_gene_df['hgnc_claim_match_status'] = dgidb_gene_df['gene_claim_name'].isin(hgnc_gene_symbol_set)
dgidb_gene_df
# Out:
#            name nomenclature  concept_id gene_claim_name  \
# 0           MN1  Gene Symbol   hgnc:7180             MN1
# 1         P2RX7  Gene Symbol   hgnc:8537           P2RX7
# 2        CHRNA7  Gene Symbol   hgnc:1960          CHRNA7
# 3         MAPK8  Gene Symbol   hgnc:6881           MAPK8
# 4        MAPK10  Gene Symbol   hgnc:6872          MAPK10
# ...         ...          ...         ...             ...
# 73884  MAPKAPK5    Gene Name   hgnc:6889        MAPKAPK5
# 73885    PTGER3    Gene Name   hgnc:9595          PTGER3
# 73886      CD1D    Gene Name   hgnc:1637            CD1D
# 73887   SLC26A1  Gene Symbol  hgnc:10993         SLC26A1
# 73888     SOCS1  Gene Symbol  hgnc:19383           SOCS1
#
#                    source_db_name source_db_version  hgnc_claim_match_status
# 0      CarisMolecularIntelligence          5-Jun-23                     True
# 1                          ChEMBL                32                     True
# 2                          ChEMBL                32                     True
# 3                          ChEMBL                32                     True
# 4                          ChEMBL                32                     True
# ...                           ...               ...                      ...
# 73884                         DTC          5-Jun-23                     True
# 73885                         DTC          5-Jun-23                     True
# 73886                         DTC          5-Jun-23                     True
# 73887                         IDG         15-Jul-19                     True
# 73888          FoundationOneGenes          5-Jun-23                     True
#
# [73889 rows x 7 columns]

# %%
dgidb_gene_df['hgnc_name_match_status'] = dgidb_gene_df['name'].isin(hgnc_gene_symbol_set)
dgidb_gene_df
# Out:
#            name nomenclature  concept_id gene_claim_name  \
# 0           MN1  Gene Symbol   hgnc:7180             MN1
# 1         P2RX7  Gene Symbol   hgnc:8537           P2RX7
# 2        CHRNA7  Gene Symbol   hgnc:1960          CHRNA7
# 3         MAPK8  Gene Symbol   hgnc:6881           MAPK8
# 4        MAPK10  Gene Symbol   hgnc:6872          MAPK10
# ...         ...          ...         ...             ...
# 73884  MAPKAPK5    Gene Name   hgnc:6889        MAPKAPK5
# 73885    PTGER3    Gene Name   hgnc:9595          PTGER3
# 73886      CD1D    Gene Name   hgnc:1637            CD1D
# 73887   SLC26A1  Gene Symbol  hgnc:10993         SLC26A1
# 73888     SOCS1  Gene Symbol  hgnc:19383           SOCS1
#
#                    source_db_name source_db_version  hgnc_claim_match_status  \
# 0      CarisMolecularIntelligence          5-Jun-23                     True
# 1                          ChEMBL                32                     True
# 2                          ChEMBL                32                     True
# 3                          ChEMBL                32                     True
# 4                          ChEMBL                32                     True
# ...                           ...               ...                      ...
# 73884                         DTC          5-Jun-23                     True
# 73885                         DTC          5-Jun-23                     True
# 73886                         DTC          5-Jun-23                     True
# 73887                         IDG         15-Jul-19                     True
# 73888          FoundationOneGenes          5-Jun-23                     True
#
#        hgnc_name_match_status
# 0                        True
# 1                        True
# 2                        True
# 3                        True
# 4                        True
# ...                       ...
# 73884                    True
# 73885                    True
# 73886                    True
# 73887                    True
# 73888                    True
#
# [73889 rows x 8 columns]

# %%
claim_true_name_false_df = dgidb_gene_df.loc[dgidb_gene_df['hgnc_claim_match_status'] & ~dgidb_gene_df['hgnc_name_match_status']]
claim_true_name_false_df
# Out:
#                           name     nomenclature  concept_id gene_claim_name  \
# 25                       HSP90      Gene Symbol   hgnc:5253        HSP90AA1
# 167                      SEPT6      Gene Symbol  hgnc:15848         SEPTIN6
# 169                      SEPT5      Gene Symbol   hgnc:9164         SEPTIN5
# 213                      WISP3      Gene Symbol  hgnc:12771            CCN6
# 294                       MLL2        Gene Name   hgnc:7133           KMT2D
# ...                        ...              ...         ...             ...
# 73631  ENSEMBL:ENSG00000185821  Ensembl Gene ID  hgnc:31305          OR6C76
# 73642                 C11ORF30      Gene Symbol  hgnc:18071            EMSY
# 73727  ENSEMBL:ENSG00000183921  Ensembl Gene ID  hgnc:35414         SDR42E2
# 73872                       MR   NCBI Gene Name   hgnc:7979           NR3C2
# 73878  ENSEMBL:ENSG00000173213  Ensembl Gene ID  hgnc:24983          TUBB8B
#
#                    source_db_name source_db_version  hgnc_claim_match_status  \
# 25                         ChEMBL                32                     True
# 167    CarisMolecularIntelligence          5-Jun-23                     True
# 169    CarisMolecularIntelligence          5-Jun-23                     True
# 213    CarisMolecularIntelligence          5-Jun-23                     True
# 294                           CGI          5-Jun-23                     True
# ...                           ...               ...                      ...
# 73631                  RussLampel         26-Jul-11                     True
# 73642          FoundationOneGenes          5-Jun-23                     True
# 73727                  RussLampel         26-Jul-11                     True
# 73872                    BaderLab            14-Feb                     True
# 73878                  RussLampel         26-Jul-11                     True
#
#        hgnc_name_match_status
# 25                      False
# 167                     False
# 169                     False
# 213                     False
# 294                     False
# ...                       ...
# 73631                   False
# 73642                   False
# 73727                   False
# 73872                   False
# 73878                   False
#
# [9378 rows x 8 columns]

# %%
merged_alias_overlap_df_2
# Out:
#      alias_symbol                                        gene_symbol  \
# 3260           VH  [IGHV1-24,  IGHV3-43,  IGHM,  IGHV3-9,  IGHV3-...
# 1284        H4-16  [H4C13,  H4C3,  H4C4,  H4C11,  H4C1,  H4C14,  ...
# 1287        H4C12  [H4C15,  H4C5,  H4C3,  H4C1,  H4C4,  H4C6,  H4...
# 1294         H4C5  [H4C6,  H4C4,  H4C12,  H4C16,  H4C11,  H4C14, ...
# 1292         H4C3  [H4C14,  H4C4,  H4C1,  H4C8,  H4C5,  H4C15,  H...
# ...           ...                                                ...
# 1937       PNUTL4                                          [SEPTIN9]
# 1936        PNOCR                                            [OPRL1]
# 1935        PNMA4                                            [MOAP1]
# 1932        PMSR3                                           [PMS2P3]
# 5306    psiTPTE22                                           [TPTEP1]
#
#                                                 ENSG_ID     source  \
# 3260  ENSG00000211950, ENSG00000232216, ENSG00000211...  NCBI Info
# 1284  ENSG00000275126, ENSG00000197061, ENSG00000277...  NCBI Info
# 1287  ENSG00000270276, ENSG00000276966, ENSG00000197...  NCBI Info
# 1294  ENSG00000274618, ENSG00000277157, ENSG00000273...  NCBI Info
# 1292  ENSG00000270882, ENSG00000277157, ENSG00000278...  NCBI Info
# ...                                                 ...        ...
# 1937                                    ENSG00000282302       ENSG
# 1936                                    ENSG00000125510       ENSG
# 1935                                    ENSG00000165943       ENSG
# 1932                                    ENSG00000291092       ENSG
# 5306                                    ENSG00000100181       ENSG
#
#       gene_symbol_count
# 3260                 36
# 1284                 14
# 1287                 13
# 1294                 13
# 1292                 13
# ...                 ...
# 1937                  1
# 1936                  1
# 1935                  1
# 1932                  1
# 5306                  1
#
# [9774 rows x 5 columns]

# %%
data = {}

for row in merged_alias_overlap_df_2.itertuples():
    print(row)
    break
# Out:
# Pandas(Index=3260, alias_symbol='VH', gene_symbol=['IGHV1-24', ' IGHV3-43', ' IGHM', ' IGHV3-9', ' IGHV3-16', ' IGHV2-5', ' IGHV3-20', ' IGHV3-21', ' IGHV1-58', ' IGHV1-45', ' IGHV3-35', ' IGHV3-33', ' IGHV3-11', ' IGHV3-30', ' IGHV3-7', ' IGHV3-38', ' IGHV3-15', ' IGHV3-74', ' SLC7A4', ' IGHV6-1', ' IGHV5-51', ' IGHV4-61', ' IGHV4-59', ' IGHV4-39', ' IGHV4-28', ' IGHV4-4', ' IGHV2-26', ' IGHV3-73', ' IGHV3-72', ' IGHV4-34', ' IGHV3-66', ' IGHV3-48', ' IGHV3-53', ' IGHV3-64', ' IGHV3-49', ' IGHV2-70'], ENSG_ID='ENSG00000211950, ENSG00000232216, ENSG00000211899, nan, ENSG00000211944, ENSG00000211937, ENSG00000211946, ENSG00000211947, ENSG00000211968, ENSG00000211961, ENSG00000211957, ENSG00000211955, ENSG00000211941, ENSG00000270550, ENSG00000211938, ENSG00000211958, ENSG00000211943, ENSG00000224650, ENSG00000099960, ENSG00000211933, ENSG00000211966, ENSG00000211970, ENSG00000224373, ENSG00000211959, ENSG00000211952, ENSG00000276775, ENSG00000211951, ENSG00000211976, ENSG00000225698, ENSG00000211956, ENSG00000211972, ENSG00000211964, ENSG00000211967, ENSG00000223648, ENSG00000211965, ENSG00000274576', source='NCBI Info', gene_symbol_count=36)

# %%
import yaml
import os

folder_path = 'new_alias-alias_collision_records'
os.makedirs(folder_path, exist_ok=True)

data = []

for row in merged_alias_overlap_df_2.itertuples():
    
    collision_record = {
        "collision_symbol": row.alias_symbol,
    }

    collision_group = []

    len_gene_symbols = len(row.gene_symbol)
    ensg_ids = [r.strip() for r in row.ENSG_ID.split(",")]
    len_ensg_ids = len(ensg_ids)

    # if len_gene_symbols != len_ensg_ids:
    #     print(row)
    for i in range(0, len_gene_symbols):
        collision_group_item = {
            "gene_symbol": row.gene_symbol[i],
            "ensg_id": ensg_ids[i].upper()
        }
        collision_group.append(collision_group_item)

    collision_record["collision_group"] = collision_group
    data.append(collision_record)

    file_path = os.path.join(folder_path, f"{(row.alias_symbol.replace('/', '_'))}_collision_record.yaml")

    with open(file_path, "w") as wf:
        yaml.dump(collision_record, wf, default_flow_style=False)

data
# Out:
# [{'collision_symbol': 'VH',
#   'collision_group': [{'gene_symbol': 'IGHV1-24',
#     'ensg_id': 'ENSG00000211950'},
#    {'gene_symbol': ' IGHV3-43', 'ensg_id': 'ENSG00000232216'},
#    {'gene_symbol': ' IGHM', 'ensg_id': 'ENSG00000211899'},
#    {'gene_symbol': ' IGHV3-9', 'ensg_id': 'NAN'},
#    {'gene_symbol': ' IGHV3-16', 'ensg_id': 'ENSG00000211944'},
#    {'gene_symbol': ' IGHV2-5', 'ensg_id': 'ENSG00000211937'},
#    {'gene_symbol': ' IGHV3-20', 'ensg_id': 'ENSG00000211946'},
#    {'gene_symbol': ' IGHV3-21', 'ensg_id': 'ENSG00000211947'},
#    {'gene_symbol': ' IGHV1-58', 'ensg_id': 'ENSG00000211968'},
#    {'gene_symbol': ' IGHV1-45', 'ensg_id': 'ENSG00000211961'},
#    {'gene_symbol': ' IGHV3-35', 'ensg_id': 'ENSG00000211957'},
#    {'gene_symbol': ' IGHV3-33', 'ensg_id': 'ENSG00000211955'},
#    {'gene_symbol': ' IGHV3-11', 'ensg_id': 'ENSG00000211941'},
#    {'gene_symbol': ' IGHV3-30', 'ensg_id': 'ENSG00000270550'},
#    {'gene_symbol': ' IGHV3-7', 'ensg_id': 'ENSG00000211938'},
#    {'gene_symbol': ' IGHV3-38', 'ensg_id': 'ENSG00000211958'},
#    {'gene_symbol': ' IGHV3-15', 'ensg_id': 'ENSG00000211943'},
#    {'gene_symbol': ' IGHV3-74', 'ensg_id': 'ENSG00000224650'},
#    {'gene_symbol': ' SLC7A4', 'ensg_id': 'ENSG00000099960'},
#    {'gene_symbol': ' IGHV6-1', 'ensg_id': 'ENSG00000211933'},
#    {'gene_symbol': ' IGHV5-51', 'ensg_id': 'ENSG00000211966'},
#    {'gene_symbol': ' IGHV4-61', 'ensg_id': 'ENSG00000211970'},
#    {'gene_symbol': ' IGHV4-59', 'ensg_id': 'ENSG00000224373'},
#    {'gene_symbol': ' IGHV4-39', 'ensg_id': 'ENSG00000211959'},
#    {'gene_symbol': ' IGHV4-28', 'ensg_id': 'ENSG00000211952'},
#    {'gene_symbol': ' IGHV4-4', 'ensg_id': 'ENSG00000276775'},
#    {'gene_symbol': ' IGHV2-26', 'ensg_id': 'ENSG00000211951'},
#    {'gene_symbol': ' IGHV3-73', 'ensg_id': 'ENSG00000211976'},
#    {'gene_symbol': ' IGHV3-72', 'ensg_id': 'ENSG00000225698'},
#    {'gene_symbol': ' IGHV4-34', 'ensg_id': 'ENSG00000211956'},
#    {'gene_symbol': ' IGHV3-66', 'ensg_id': 'ENSG00000211972'},
#    {'gene_symbol': ' IGHV3-48', 'ensg_id': 'ENSG00000211964'},
#    {'gene_symbol': ' IGHV3-53', 'ensg_id': 'ENSG00000211967'},
#    {'gene_symbol': ' IGHV3-64', 'ensg_id': 'ENSG00000223648'},
#    {'gene_symbol': ' IGHV3-49', 'ensg_id': 'ENSG00000211965'},
#    {'gene_symbol': ' IGHV2-70', 'ensg_id': 'ENSG00000274576'}]},
#  {'collision_symbol': 'H4-16',
#   'collision_group': [{'gene_symbol': 'H4C13', 'ensg_id': 'ENSG00000275126'},
#    {'gene_symbol': ' H4C3', 'ensg_id': 'ENSG00000197061'},
#    {'gene_symbol': ' H4C4', 'ensg_id': 'ENSG00000277157'},
#    {'gene_symbol': ' H4C11', 'ensg_id': 'ENSG00000197238'},
#    {'gene_symbol': ' H4C1', 'ensg_id': 'ENSG00000278637'},
#    {'gene_symbol': ' H4C14', 'ensg_id': 'ENSG00000270882'},
#    {'gene_symbol': ' H4C6', 'ensg_id': 'ENSG00000274618'},
#    {'gene_symbol': ' H4C12', 'ensg_id': 'ENSG00000273542'},
#    {'gene_symbol': ' H4C16', 'ensg_id': 'ENSG00000197837'},
#    {'gene_symbol': ' H4C9', 'ensg_id': 'ENSG00000276180'},
#    {'gene_symbol': ' H4C5', 'ensg_id': 'ENSG00000276966'},
#    {'gene_symbol': ' H4C2', 'ensg_id': 'ENSG00000278705'},
#    {'gene_symbol': ' H4C8', 'ensg_id': 'ENSG00000158406'},
#    {'gene_symbol': ' H4C15', 'ensg_id': 'ENSG00000270276'}]},
#  {'collision_symbol': 'H4C12',
#   'collision_group': [{'gene_symbol': 'H4C15', 'ensg_id': 'ENSG00000270276'},
#    {'gene_symbol': ' H4C5', 'ensg_id': 'ENSG00000276966'},
#    {'gene_symbol': ' H4C3', 'ensg_id': 'ENSG00000197061'},
#    {'gene_symbol': ' H4C1', 'ensg_id': 'ENSG00000278637'},
#    {'gene_symbol': ' H4C4', 'ensg_id': 'ENSG00000277157'},
#    {'gene_symbol': ' H4C6', 'ensg_id': 'ENSG00000274618'},
#    {'gene_symbol': ' H4C9', 'ensg_id': 'ENSG00000276180'},
#    {'gene_symbol': ' H4C13', 'ensg_id': 'ENSG00000275126'},
#    {'gene_symbol': ' H4C14', 'ensg_id': 'ENSG00000270882'},
#    {'gene_symbol': ' H4C2', 'ensg_id': 'ENSG00000278705'},
#    {'gene_symbol': ' H4C8', 'ensg_id': 'ENSG00000158406'},
#    {'gene_symbol': ' H4C16', 'ensg_id': 'ENSG00000197837'},
#    {'gene_symbol': ' H4C11', 'ensg_id': 'ENSG00000197238'}]},
#  {'collision_symbol': 'H4C5',
#   'collision_group': [{'gene_symbol': 'H4C6', 'ensg_id': 'ENSG00000274618'},
#    {'gene_symbol': ' H4C4', 'ensg_id': 'ENSG00000277157'},
#    {'gene_symbol': ' H4C12', 'ensg_id': 'ENSG00000273542'},
#    {'gene_symbol': ' H4C16', 'ensg_id': 'ENSG00000197837'},
#    {'gene_symbol': ' H4C11', 'ensg_id': 'ENSG00000197238'},
#    {'gene_symbol': ' H4C14', 'ensg_id': 'ENSG00000270882'},
#    {'gene_symbol': ' H4C9', 'ensg_id': 'ENSG00000276180'},
#    {'gene_symbol': ' H4C13', 'ensg_id': 'ENSG00000275126'},
#    {'gene_symbol': ' H4C2', 'ensg_id': 'ENSG00000278705'},
#    {'gene_symbol': ' H4C15', 'ensg_id': 'ENSG00000270276'},
#    {'gene_symbol': ' H4C1', 'ensg_id': 'ENSG00000278637'},
#    {'gene_symbol': ' H4C3', 'ensg_id': 'ENSG00000197061'},
#    {'gene_symbol': ' H4C8', 'ensg_id': 'ENSG00000158406'}]},
#  {'collision_symbol': 'H4C3',
#   'collision_group': [{'gene_symbol': 'H4C14', 'ensg_id': 'ENSG00000270882'},
#    {'gene_symbol': ' H4C4', 'ensg_id': 'ENSG00000277157'},
#    {'gene_symbol': ' H4C1', 'ensg_id': 'ENSG00000278637'},
#    {'gene_symbol': ' H4C8', 'ensg_id': 'ENSG00000158406'},
#    {'gene_symbol': ' H4C5', 'ensg_id': 'ENSG00000276966'},
#    {'gene_symbol': ' H4C15', 'ensg_id': 'ENSG00000270276'},
#    {'gene_symbol': ' H4C11', 'ensg_id': 'ENSG00000197238'},
#    {'gene_symbol': ' H4C16', 'ensg_id': 'ENSG00000197837'},
#    {'gene_symbol': ' H4C12', 'ensg_id': 'ENSG00000273542'},
#    {'gene_symbol': ' H4C13', 'ensg_id': 'ENSG00000275126'},
#    {'gene_symbol': ' H4C6', 'ensg_id': 'ENSG00000274618'},
#    {'gene_symbol': ' H4C9', 'ensg_id': 'ENSG00000276180'},
#    {'gene_symbol': ' H4C2', 'ensg_id': 'ENSG00000278705'}]},
#  {'collision_symbol': 'H4C15',
#   'collision_group': [{'gene_symbol': 'H4C1', 'ensg_id': 'ENSG00000278637'},
#    {'gene_symbol': ' H4C13', 'ensg_id': 'ENSG00000275126'},
#    {'gene_symbol': ' H4C5', 'ensg_id': 'ENSG00000276966'},
#    {'gene_symbol': ' H4C16', 'ensg_id': 'ENSG00000197837'},
#    {'gene_symbol': ' H4C14', 'ensg_id': 'ENSG00000270882'},
#    {'gene_symbol': ' H4C11', 'ensg_id': 'ENSG00000197238'},
#    {'gene_symbol': ' H4C8', 'ensg_id': 'ENSG00000158406'},
#    {'gene_symbol': ' H4C9', 'ensg_id': 'ENSG00000276180'},
#    {'gene_symbol': ' H4C6', 'ensg_id': 'ENSG00000274618'},
#    {'gene_symbol': ' H4C2', 'ensg_id': 'ENSG00000278705'},
#    {'gene_symbol': ' H4C3', 'ensg_id': 'ENSG00000197061'},
#    {'gene_symbol': ' H4C4', 'ensg_id': 'ENSG00000277157'},
#    {'gene_symbol': ' H4C12', 'ensg_id': 'ENSG00000273542'}]},
#  {'collision_symbol': 'H4C14',
#   'collision_group': [{'gene_symbol': 'H4C9', 'ensg_id': 'ENSG00000276180'},
#    {'gene_symbol': ' H4C16', 'ensg_id': 'ENSG00000197837'},
#    {'gene_symbol': ' H4C15', 'ensg_id': 'ENSG00000270276'},
#    {'gene_symbol': ' H4C4', 'ensg_id': 'ENSG00000277157'},
#    {'gene_symbol': ' H4C1', 'ensg_id': 'ENSG00000278637'},
#    {'gene_symbol': ' H4C13', 'ensg_id': 'ENSG00000275126'},
#    {'gene_symbol': ' H4C6', 'ensg_id': 'ENSG00000274618'},
#    {'gene_symbol': ' H4C5', 'ensg_id': 'ENSG00000276966'},
#    {'gene_symbol': ' H4C11', 'ensg_id': 'ENSG00000197238'},
#    {'gene_symbol': ' H4C2', 'ensg_id': 'ENSG00000278705'},
#    {'gene_symbol': ' H4C3', 'ensg_id': 'ENSG00000197061'},
#    {'gene_symbol': ' H4C12', 'ensg_id': 'ENSG00000273542'},
#    {'gene_symbol': ' H4C8', 'ensg_id': 'ENSG00000158406'}]},
#  {'collision_symbol': 'H4C13',
#   'collision_group': [{'gene_symbol': 'H4C9', 'ensg_id': 'ENSG00000276180'},
#    {'gene_symbol': ' H4C5', 'ensg_id': 'ENSG00000276966'},
#    {'gene_symbol': ' H4C16', 'ensg_id': 'ENSG00000197837'},
#    {'gene_symbol': ' H4C1', 'ensg_id': 'ENSG00000278637'},
#    {'gene_symbol': ' H4C4', 'ensg_id': 'ENSG00000277157'},
#    {'gene_symbol': ' H4C8', 'ensg_id': 'ENSG00000158406'},
#    {'gene_symbol': ' H4C11', 'ensg_id': 'ENSG00000197238'},
#    {'gene_symbol': ' H4C3', 'ensg_id': 'ENSG00000197061'},
#    {'gene_symbol': ' H4C12', 'ensg_id': 'ENSG00000273542'},
#    {'gene_symbol': ' H4C2', 'ensg_id': 'ENSG00000278705'},
#    {'gene_symbol': ' H4C6', 'ensg_id': 'ENSG00000274618'},
#    {'gene_symbol': ' H4C15', 'ensg_id': 'ENSG00000270276'},
#    {'gene_symbol': ' H4C14', 'ensg_id': 'ENSG00000270882'}]},
#  {'collision_symbol': 'H4C9',
#   'collision_group': [{'gene_symbol': 'H4C1', 'ensg_id': 'ENSG00000278637'},
#    {'gene_symbol': ' H4C12', 'ensg_id': 'ENSG00000273542'},
#    {'gene_symbol': ' H4C8', 'ensg_id': 'ENSG00000158406'},
#    {'gene_symbol': ' H4C6', 'ensg_id': 'ENSG00000274618'},
#    {'gene_symbol': ' H4C4', 'ensg_id': 'ENSG00000277157'},
#    {'gene_symbol': ' H4C13', 'ensg_id': 'ENSG00000275126'},
#    {'gene_symbol': ' H4C5', 'ensg_id': 'ENSG00000276966'},
#    {'gene_symbol': ' H4C15', 'ensg_id': 'ENSG00000270276'},
#    {'gene_symbol': ' H4C16', 'ensg_id': 'ENSG00000197837'},
#    {'gene_symbol': ' H4C11', 'ensg_id': 'ENSG00000197238'},
#    {'gene_symbol': ' H4C3', 'ensg_id': 'ENSG00000197061'},
#    {'gene_symbol': ' H4C2', 'ensg_id': 'ENSG00000278705'},
#    {'gene_symbol': ' H4C14', 'ensg_id': 'ENSG00000270882'}]},
#  {'collision_symbol': 'H4C11',
#   'collision_group': [{'gene_symbol': 'H4C3', 'ensg_id': 'ENSG00000197061'},
#    {'gene_symbol': ' H4C2', 'ensg_id': 'ENSG00000278705'},
#    {'gene_symbol': ' H4C1', 'ensg_id': 'ENSG00000278637'},
#    {'gene_symbol': ' H4C9', 'ensg_id': 'ENSG00000276180'},
#    {'gene_symbol': ' H4C6', 'ensg_id': 'ENSG00000274618'},
#    {'gene_symbol': ' H4C13', 'ensg_id': 'ENSG00000275126'},
#    {'gene_symbol': ' H4C16', 'ensg_id': 'ENSG00000197837'},
#    {'gene_symbol': ' H4C4', 'ensg_id': 'ENSG00000277157'},
#    {'gene_symbol': ' H4C14', 'ensg_id': 'ENSG00000270882'},
#    {'gene_symbol': ' H4C12', 'ensg_id': 'ENSG00000273542'},
#    {'gene_symbol': ' H4C5', 'ensg_id': 'ENSG00000276966'},
#    {'gene_symbol': ' H4C15', 'ensg_id': 'ENSG00000270276'},
#    {'gene_symbol': ' H4C8', 'ensg_id': 'ENSG00000158406'}]},
#  {'collision_symbol': 'H4C4',
#   'collision_group': [{'gene_symbol': 'H4C5', 'ensg_id': 'ENSG00000276966'},
#    {'gene_symbol': ' H4C3', 'ensg_id': 'ENSG00000197061'},
#    {'gene_symbol': ' H4C8', 'ensg_id': 'ENSG00000158406'},
#    {'gene_symbol': ' H4C16', 'ensg_id': 'ENSG00000197837'},
#    {'gene_symbol': ' H4C12', 'ensg_id': 'ENSG00000273542'},
#    {'gene_symbol': ' H4C6', 'ensg_id': 'ENSG00000274618'},
#    {'gene_symbol': ' H4C1', 'ensg_id': 'ENSG00000278637'},
#    {'gene_symbol': ' H4C9', 'ensg_id': 'ENSG00000276180'},
#    {'gene_symbol': ' H4C15', 'ensg_id': 'ENSG00000270276'},
#    {'gene_symbol': ' H4C14', 'ensg_id': 'ENSG00000270882'},
#    {'gene_symbol': ' H4C13', 'ensg_id': 'ENSG00000275126'},
#    {'gene_symbol': ' H4C11', 'ensg_id': 'ENSG00000197238'},
#    {'gene_symbol': ' H4C2', 'ensg_id': 'ENSG00000278705'}]},
#  {'collision_symbol': 'H4C2',
#   'collision_group': [{'gene_symbol': 'H4C8', 'ensg_id': 'ENSG00000158406'},
#    {'gene_symbol': ' H4C16', 'ensg_id': 'ENSG00000197837'},
#    {'gene_symbol': ' H4C15', 'ensg_id': 'ENSG00000270276'},
#    {'gene_symbol': ' H4C11', 'ensg_id': 'ENSG00000197238'},
#    {'gene_symbol': ' H4C14', 'ensg_id': 'ENSG00000270882'},
#    {'gene_symbol': ' H4C12', 'ensg_id': 'ENSG00000273542'},
#    {'gene_symbol': ' H4C5', 'ensg_id': 'ENSG00000276966'},
#    {'gene_symbol': ' H4C3', 'ensg_id': 'ENSG00000197061'},
#    {'gene_symbol': ' H4C4', 'ensg_id': 'ENSG00000277157'},
#    {'gene_symbol': ' H4C9', 'ensg_id': 'ENSG00000276180'},
#    {'gene_symbol': ' H4C13', 'ensg_id': 'ENSG00000275126'},
#    {'gene_symbol': ' H4C1', 'ensg_id': 'ENSG00000278637'},
#    {'gene_symbol': ' H4C6', 'ensg_id': 'ENSG00000274618'}]},
#  {'collision_symbol': 'H4C1',
#   'collision_group': [{'gene_symbol': 'H4C14', 'ensg_id': 'ENSG00000270882'},
#    {'gene_symbol': ' H4C6', 'ensg_id': 'ENSG00000274618'},
#    {'gene_symbol': ' H4C9', 'ensg_id': 'ENSG00000276180'},
#    {'gene_symbol': ' H4C13', 'ensg_id': 'ENSG00000275126'},
#    {'gene_symbol': ' H4C5', 'ensg_id': 'ENSG00000276966'},
#    {'gene_symbol': ' H4C12', 'ensg_id': 'ENSG00000273542'},
#    {'gene_symbol': ' H4C11', 'ensg_id': 'ENSG00000197238'},
#    {'gene_symbol': ' H4C15', 'ensg_id': 'ENSG00000270276'},
#    {'gene_symbol': ' H4C2', 'ensg_id': 'ENSG00000278705'},
#    {'gene_symbol': ' H4C4', 'ensg_id': 'ENSG00000277157'},
#    {'gene_symbol': ' H4C3', 'ensg_id': 'ENSG00000197061'},
#    {'gene_symbol': ' H4C16', 'ensg_id': 'ENSG00000197837'},
#    {'gene_symbol': ' H4C8', 'ensg_id': 'ENSG00000158406'}]},
#  {'collision_symbol': 'H4C6',
#   'collision_group': [{'gene_symbol': 'H4C9', 'ensg_id': 'ENSG00000276180'},
#    {'gene_symbol': ' H4C8', 'ensg_id': 'ENSG00000158406'},
#    {'gene_symbol': ' H4C15', 'ensg_id': 'ENSG00000270276'},
#    {'gene_symbol': ' H4C2', 'ensg_id': 'ENSG00000278705'},
#    {'gene_symbol': ' H4C5', 'ensg_id': 'ENSG00000276966'},
#    {'gene_symbol': ' H4C4', 'ensg_id': 'ENSG00000277157'},
#    {'gene_symbol': ' H4C13', 'ensg_id': 'ENSG00000275126'},
#    {'gene_symbol': ' H4C3', 'ensg_id': 'ENSG00000197061'},
#    {'gene_symbol': ' H4C14', 'ensg_id': 'ENSG00000270882'},
#    {'gene_symbol': ' H4C12', 'ensg_id': 'ENSG00000273542'},
#    {'gene_symbol': ' H4C11', 'ensg_id': 'ENSG00000197238'},
#    {'gene_symbol': ' H4C1', 'ensg_id': 'ENSG00000278637'},
#    {'gene_symbol': ' H4C16', 'ensg_id': 'ENSG00000197837'}]},
#  {'collision_symbol': 'H4C8',
#   'collision_group': [{'gene_symbol': 'H4C12', 'ensg_id': 'ENSG00000273542'},
#    {'gene_symbol': ' H4C11', 'ensg_id': 'ENSG00000197238'},
#    {'gene_symbol': ' H4C13', 'ensg_id': 'ENSG00000275126'},
#    {'gene_symbol': ' H4C16', 'ensg_id': 'ENSG00000197837'},
#    {'gene_symbol': ' H4C15', 'ensg_id': 'ENSG00000270276'},
#    {'gene_symbol': ' H4C2', 'ensg_id': 'ENSG00000278705'},
#    {'gene_symbol': ' H4C6', 'ensg_id': 'ENSG00000274618'},
#    {'gene_symbol': ' H4C5', 'ensg_id': 'ENSG00000276966'},
#    {'gene_symbol': ' H4C1', 'ensg_id': 'ENSG00000278637'},
#    {'gene_symbol': ' H4C4', 'ensg_id': 'ENSG00000277157'},
#    {'gene_symbol': ' H4C3', 'ensg_id': 'ENSG00000197061'},
#    {'gene_symbol': ' H4C9', 'ensg_id': 'ENSG00000276180'},
#    {'gene_symbol': ' H4C14', 'ensg_id': 'ENSG00000270882'}]},
#  {'collision_symbol': 'MT1',
#   'collision_group': [{'gene_symbol': 'MT1E', 'ensg_id': 'ENSG00000169715'},
#    {'gene_symbol': ' MT1G', 'ensg_id': 'ENSG00000125144'},
#    {'gene_symbol': ' MT1JP', 'ensg_id': 'ENSG00000255986'},
#    {'gene_symbol': ' MT1H', 'ensg_id': 'ENSG00000205358'},
#    {'gene_symbol': ' MT1M', 'ensg_id': 'ENSG00000205364'},
#    {'gene_symbol': ' MT1L', 'ensg_id': 'ENSG00000260549'},
#    {'gene_symbol': ' MT1A', 'ensg_id': 'ENSG00000205362'},
#    {'gene_symbol': ' MT1F', 'ensg_id': 'ENSG00000198417'},
#    {'gene_symbol': ' MT1B', 'ensg_id': 'ENSG00000169688'},
#    {'gene_symbol': ' MT1IP', 'ensg_id': 'NAN'},
#    {'gene_symbol': ' MTNR1A', 'ensg_id': 'ENSG00000168412'},
#    {'gene_symbol': ' MT1X', 'ensg_id': 'ENSG00000187193'}]},
#  {'collision_symbol': 'GPCR',
#   'collision_group': [{'gene_symbol': 'LPAR3', 'ensg_id': 'ENSG00000171517'},
#    {'gene_symbol': ' MRGPRX1', 'ensg_id': 'ENSG00000170255'},
#    {'gene_symbol': ' GPRC6A', 'ensg_id': 'ENSG00000173612'},
#    {'gene_symbol': ' LGR6', 'ensg_id': 'ENSG00000133067'},
#    {'gene_symbol': ' OXER1', 'ensg_id': 'ENSG00000162881'},
#    {'gene_symbol': ' GPR151', 'ensg_id': 'ENSG00000173250'},
#    {'gene_symbol': ' VN1R17P', 'ensg_id': 'NAN'},
#    {'gene_symbol': ' GPR166P', 'ensg_id': 'ENSG00000220349'},
#    {'gene_symbol': ' MRGPRX3', 'ensg_id': 'ENSG00000179826'},
#    {'gene_symbol': ' MRGPRX4', 'ensg_id': 'ENSG00000179817'},
#    {'gene_symbol': ' FZD4', 'ensg_id': 'ENSG00000174804'}]},
#  {'collision_symbol': 'HOX1',
#   'collision_group': [{'gene_symbol': 'HOXA1', 'ensg_id': 'ENSG00000105991'},
#    {'gene_symbol': ' HOXA6', 'ensg_id': 'ENSG00000106006'},
#    {'gene_symbol': ' HOXA7', 'ensg_id': 'ENSG00000122592'},
#    {'gene_symbol': ' HOXA10', 'ensg_id': 'ENSG00000253293'},
#    {'gene_symbol': ' HOXA4', 'ensg_id': 'ENSG00000197576'},
#    {'gene_symbol': ' HOXA11', 'ensg_id': 'ENSG00000005073'},
#    {'gene_symbol': ' HOXA13', 'ensg_id': 'ENSG00000106031'},
#    {'gene_symbol': ' HOXA5', 'ensg_id': 'ENSG00000106004'},
#    {'gene_symbol': ' HOXA9', 'ensg_id': 'ENSG00000078399'},
#    {'gene_symbol': ' HOXA3', 'ensg_id': 'ENSG00000105997'}]},
#  {'collision_symbol': 'PR',
#   'collision_group': [{'gene_symbol': 'ERVK-18', 'ensg_id': 'NAN'},
#    {'gene_symbol': ' ERVK-24', 'ensg_id': 'NAN'},
#    {'gene_symbol': ' ERVK-8', 'ensg_id': 'NAN'},
#    {'gene_symbol': ' ERVK-21', 'ensg_id': 'NAN'},
#    {'gene_symbol': ' PGR', 'ensg_id': 'ENSG00000082175'},
#    {'gene_symbol': ' ERVK-10', 'ensg_id': 'NAN'},
#    {'gene_symbol': ' ERVK-9', 'ensg_id': 'NAN'},
#    {'gene_symbol': ' ERVK-25', 'ensg_id': 'NAN'},
#    {'gene_symbol': ' TMEM37', 'ensg_id': 'ENSG00000171227'},
#    {'gene_symbol': ' ERVK-19', 'ensg_id': 'NAN'}]},
#  {'collision_symbol': 'MT1',
#   'collision_group': [{'gene_symbol': 'MT1IP', 'ensg_id': 'ENSG00000275691'},
#    {'gene_symbol': ' MT1JP', 'ensg_id': 'ENSG00000290662'},
#    {'gene_symbol': ' MT1B', 'ensg_id': 'ENSG00000169688'},
#    {'gene_symbol': ' MT1A', 'ensg_id': 'ENSG00000205362'},
#    {'gene_symbol': ' MT1M', 'ensg_id': 'ENSG00000205364'},
#    {'gene_symbol': ' MT1H', 'ensg_id': 'ENSG00000205358'},
#    {'gene_symbol': ' MT1G', 'ensg_id': 'ENSG00000125144'},
#    {'gene_symbol': ' MT1E', 'ensg_id': 'ENSG00000169715'},
#    {'gene_symbol': ' MT1F', 'ensg_id': 'ENSG00000198417'},
#    {'gene_symbol': ' MT1L', 'ensg_id': 'ENSG00000260549'}]},
#  {'collision_symbol': 'HOX1',
#   'collision_group': [{'gene_symbol': 'HOXA4', 'ensg_id': 'ENSG00000197576'},
#    {'gene_symbol': ' HOXA10', 'ensg_id': 'ENSG00000253293'},
#    {'gene_symbol': ' HOXA1', 'ensg_id': 'ENSG00000105991'},
#    {'gene_symbol': ' HOXA3', 'ensg_id': 'ENSG00000105997'},
#    {'gene_symbol': ' HOXA11', 'ensg_id': 'ENSG00000005073'},
#    {'gene_symbol': ' HOXA13', 'ensg_id': 'ENSG00000106031'},
#    {'gene_symbol': ' HOXA6', 'ensg_id': 'ENSG00000106006'},
#    {'gene_symbol': ' HOXA7', 'ensg_id': 'ENSG00000122592'},
#    {'gene_symbol': ' HOXA5', 'ensg_id': 'ENSG00000106004'},
#    {'gene_symbol': ' HOXA9', 'ensg_id': 'ENSG00000078399'}]},
#  {'collision_symbol': 'UGT1',
#   'collision_group': [{'gene_symbol': 'UGT1A8', 'ensg_id': 'ENSG00000242366'},
#    {'gene_symbol': ' UGGT1', 'ensg_id': 'ENSG00000136731'},
#    {'gene_symbol': ' SLC35A2', 'ensg_id': 'ENSG00000102100'},
#    {'gene_symbol': ' UGT1A4', 'ensg_id': 'ENSG00000244474'},
#    {'gene_symbol': ' UGT1A7', 'ensg_id': 'ENSG00000244122'},
#    {'gene_symbol': ' UGT1A1', 'ensg_id': 'ENSG00000241635'},
#    {'gene_symbol': ' UGT1A', 'ensg_id': 'NAN'},
#    {'gene_symbol': ' UGT1A10', 'ensg_id': 'ENSG00000242515'},
#    {'gene_symbol': ' UGT1A6', 'ensg_id': 'ENSG00000167165'}]},
#  {'collision_symbol': 'PPIase',
#   'collision_group': [{'gene_symbol': 'FKBP4', 'ensg_id': 'ENSG00000004478'},
#    {'gene_symbol': ' PPIL6', 'ensg_id': 'ENSG00000185250'},
#    {'gene_symbol': ' FKBP3', 'ensg_id': 'ENSG00000100442'},
#    {'gene_symbol': ' FKBP7', 'ensg_id': 'ENSG00000079150'},
#    {'gene_symbol': ' PPIL1', 'ensg_id': 'ENSG00000137168'},
#    {'gene_symbol': ' FKBP1B', 'ensg_id': 'ENSG00000119782'},
#    {'gene_symbol': ' FKBP9', 'ensg_id': 'ENSG00000122642'},
#    {'gene_symbol': ' FKBP5', 'ensg_id': 'ENSG00000096060'},
#    {'gene_symbol': ' FKBP2', 'ensg_id': 'ENSG00000173486'}]},
#  {'collision_symbol': 'H3C4',
#   'collision_group': [{'gene_symbol': 'H3C2', 'ensg_id': 'ENSG00000286522'},
#    {'gene_symbol': ' H3C10', 'ensg_id': 'ENSG00000278828'},
#    {'gene_symbol': ' H3C8', 'ensg_id': 'ENSG00000273983'},
#    {'gene_symbol': ' H3C12', 'ensg_id': 'ENSG00000197153'},
#    {'gene_symbol': ' H3C11', 'ensg_id': 'ENSG00000275379'},
#    {'gene_symbol': ' H3C6', 'ensg_id': 'ENSG00000274750'},
#    {'gene_symbol': ' H3C1', 'ensg_id': 'ENSG00000275714'},
#    {'gene_symbol': ' H3C3', 'ensg_id': 'ENSG00000287080'},
#    {'gene_symbol': ' H3C7', 'ensg_id': 'ENSG00000277775'}]},
#  {'collision_symbol': 'H3C8',
#   'collision_group': [{'gene_symbol': 'H3C12', 'ensg_id': 'ENSG00000197153'},
#    {'gene_symbol': ' H3C4', 'ensg_id': 'ENSG00000197409'},
#    {'gene_symbol': ' H3C11', 'ensg_id': 'ENSG00000275379'},
#    {'gene_symbol': ' H3C10', 'ensg_id': 'ENSG00000278828'},
#    {'gene_symbol': ' H3C1', 'ensg_id': 'ENSG00000275714'},
#    {'gene_symbol': ' H3C2', 'ensg_id': 'ENSG00000286522'},
#    {'gene_symbol': ' H3C6', 'ensg_id': 'ENSG00000274750'},
#    {'gene_symbol': ' H3C3', 'ensg_id': 'ENSG00000287080'},
#    {'gene_symbol': ' H3C7', 'ensg_id': 'ENSG00000277775'}]},
#  {'collision_symbol': 'UDPGT',
#   'collision_group': [{'gene_symbol': 'UGT1A6', 'ensg_id': 'ENSG00000167165'},
#    {'gene_symbol': ' UGT1A10', 'ensg_id': 'ENSG00000242515'},
#    {'gene_symbol': ' UGT1A8', 'ensg_id': 'ENSG00000242366'},
#    {'gene_symbol': ' UGT1A3', 'ensg_id': 'ENSG00000288702'},
#    {'gene_symbol': ' UGT1A7', 'ensg_id': 'ENSG00000244122'},
#    {'gene_symbol': ' UGT1A5', 'ensg_id': 'ENSG00000288705'},
#    {'gene_symbol': ' UGT1A1', 'ensg_id': 'ENSG00000241635'},
#    {'gene_symbol': ' UGT1A4', 'ensg_id': 'ENSG00000244474'},
#    {'gene_symbol': ' UGT1A9', 'ensg_id': 'ENSG00000241119'}]},
#  {'collision_symbol': 'H3C3',
#   'collision_group': [{'gene_symbol': 'H3C4', 'ensg_id': 'ENSG00000197409'},
#    {'gene_symbol': ' H3C12', 'ensg_id': 'ENSG00000197153'},
#    {'gene_symbol': ' H3C11', 'ensg_id': 'ENSG00000275379'},
#    {'gene_symbol': ' H3C1', 'ensg_id': 'ENSG00000275714'},
#    {'gene_symbol': ' H3C10', 'ensg_id': 'ENSG00000278828'},
#    {'gene_symbol': ' H3C7', 'ensg_id': 'ENSG00000277775'},
#    {'gene_symbol': ' H3C6', 'ensg_id': 'ENSG00000274750'},
#    {'gene_symbol': ' H3C2', 'ensg_id': 'ENSG00000286522'},
#    {'gene_symbol': ' H3C8', 'ensg_id': 'ENSG00000273983'}]},
#  {'collision_symbol': 'NAP1',
#   'collision_group': [{'gene_symbol': 'NAA25', 'ensg_id': 'ENSG00000111300'},
#    {'gene_symbol': ' NAPSA', 'ensg_id': 'ENSG00000131400'},
#    {'gene_symbol': ' NCKAP1', 'ensg_id': 'ENSG00000061676'},
#    {'gene_symbol': ' TRMO', 'ensg_id': 'ENSG00000136932'},
#    {'gene_symbol': ' AZI2', 'ensg_id': 'ENSG00000163512'},
#    {'gene_symbol': ' NAP1L1', 'ensg_id': 'ENSG00000187109'},
#    {'gene_symbol': ' CXCL8', 'ensg_id': 'ENSG00000169429'},
#    {'gene_symbol': ' TAB3', 'ensg_id': 'ENSG00000157625'},
#    {'gene_symbol': ' ACOT8', 'ensg_id': 'ENSG00000101473'}]},
#  {'collision_symbol': 'H3C7',
#   'collision_group': [{'gene_symbol': 'H3C2', 'ensg_id': 'ENSG00000286522'},
#    {'gene_symbol': ' H3C3', 'ensg_id': 'ENSG00000287080'},
#    {'gene_symbol': ' H3C6', 'ensg_id': 'ENSG00000274750'},
#    {'gene_symbol': ' H3C11', 'ensg_id': 'ENSG00000275379'},
#    {'gene_symbol': ' H3C4', 'ensg_id': 'ENSG00000197409'},
#    {'gene_symbol': ' H3C8', 'ensg_id': 'ENSG00000273983'},
#    {'gene_symbol': ' H3C12', 'ensg_id': 'ENSG00000197153'},
#    {'gene_symbol': ' H3C10', 'ensg_id': 'ENSG00000278828'},
#    {'gene_symbol': ' H3C1', 'ensg_id': 'ENSG00000275714'}]},
#  {'collision_symbol': 'HOX2',
#   'collision_group': [{'gene_symbol': 'HOXB9', 'ensg_id': 'ENSG00000170689'},
#    {'gene_symbol': ' HOXB8', 'ensg_id': 'ENSG00000120068'},
#    {'gene_symbol': ' HOXB1', 'ensg_id': 'ENSG00000120094'},
#    {'gene_symbol': ' HOXB2', 'ensg_id': 'ENSG00000173917'},
#    {'gene_symbol': ' HOXB3', 'ensg_id': 'ENSG00000120093'},
#    {'gene_symbol': ' HOXB7', 'ensg_id': 'ENSG00000260027'},
#    {'gene_symbol': ' HOXB6', 'ensg_id': 'ENSG00000108511'},
#    {'gene_symbol': ' HOXB4', 'ensg_id': 'ENSG00000182742'},
#    {'gene_symbol': ' HOXB5', 'ensg_id': 'ENSG00000120075'}]},
#  {'collision_symbol': 'H3C6',
#   'collision_group': [{'gene_symbol': 'H3C12', 'ensg_id': 'ENSG00000197153'},
#    {'gene_symbol': ' H3C4', 'ensg_id': 'ENSG00000197409'},
#    {'gene_symbol': ' H3C11', 'ensg_id': 'ENSG00000275379'},
#    {'gene_symbol': ' H3C1', 'ensg_id': 'ENSG00000275714'},
#    {'gene_symbol': ' H3C8', 'ensg_id': 'ENSG00000273983'},
#    {'gene_symbol': ' H3C7', 'ensg_id': 'ENSG00000277775'},
#    {'gene_symbol': ' H3C10', 'ensg_id': 'ENSG00000278828'},
#    {'gene_symbol': ' H3C3', 'ensg_id': 'ENSG00000287080'},
#    {'gene_symbol': ' H3C2', 'ensg_id': 'ENSG00000286522'}]},
#  {'collision_symbol': 'H3C2',
#   'collision_group': [{'gene_symbol': 'H3C6', 'ensg_id': 'ENSG00000274750'},
#    {'gene_symbol': ' H3C10', 'ensg_id': 'ENSG00000278828'},
#    {'gene_symbol': ' H3C7', 'ensg_id': 'ENSG00000277775'},
#    {'gene_symbol': ' H3C12', 'ensg_id': 'ENSG00000197153'},
#    {'gene_symbol': ' H3C1', 'ensg_id': 'ENSG00000275714'},
#    {'gene_symbol': ' H3C4', 'ensg_id': 'ENSG00000197409'},
#    {'gene_symbol': ' H3C3', 'ensg_id': 'ENSG00000287080'},
#    {'gene_symbol': ' H3C11', 'ensg_id': 'ENSG00000275379'},
#    {'gene_symbol': ' H3C8', 'ensg_id': 'ENSG00000273983'}]},
#  {'collision_symbol': 'HOX2',
#   'collision_group': [{'gene_symbol': 'HOXB9', 'ensg_id': 'ENSG00000170689'},
#    {'gene_symbol': ' HOXB3', 'ensg_id': 'ENSG00000120093'},
#    {'gene_symbol': ' HOXB6', 'ensg_id': 'ENSG00000108511'},
#    {'gene_symbol': ' HOXB2', 'ensg_id': 'ENSG00000173917'},
#    {'gene_symbol': ' HOXB4', 'ensg_id': 'ENSG00000182742'},
#    {'gene_symbol': ' HOXB5', 'ensg_id': 'ENSG00000120075'},
#    {'gene_symbol': ' HOXB8', 'ensg_id': 'ENSG00000120068'},
#    {'gene_symbol': ' HOXB7', 'ensg_id': 'ENSG00000260027'},
#    {'gene_symbol': ' HOXB1', 'ensg_id': 'ENSG00000120094'}]},
#  {'collision_symbol': 'H3C10',
#   'collision_group': [{'gene_symbol': 'H3C11', 'ensg_id': 'ENSG00000275379'},
#    {'gene_symbol': ' H3C4', 'ensg_id': 'ENSG00000197409'},
#    {'gene_symbol': ' H3C12', 'ensg_id': 'ENSG00000197153'},
#    {'gene_symbol': ' H3C1', 'ensg_id': 'ENSG00000275714'},
#    {'gene_symbol': ' H3C8', 'ensg_id': 'ENSG00000273983'},
#    {'gene_symbol': ' H3C6', 'ensg_id': 'ENSG00000274750'},
#    {'gene_symbol': ' H3C2', 'ensg_id': 'ENSG00000286522'},
#    {'gene_symbol': ' H3C3', 'ensg_id': 'ENSG00000287080'},
#    {'gene_symbol': ' H3C7', 'ensg_id': 'ENSG00000277775'}]},
#  {'collision_symbol': 'H3C12',
#   'collision_group': [{'gene_symbol': 'H3C7', 'ensg_id': 'ENSG00000277775'},
#    {'gene_symbol': ' H3C3', 'ensg_id': 'ENSG00000287080'},
#    {'gene_symbol': ' H3C2', 'ensg_id': 'ENSG00000286522'},
#    {'gene_symbol': ' H3C4', 'ensg_id': 'ENSG00000197409'},
#    {'gene_symbol': ' H3C6', 'ensg_id': 'ENSG00000274750'},
#    {'gene_symbol': ' H3C11', 'ensg_id': 'ENSG00000275379'},
#    {'gene_symbol': ' H3C1', 'ensg_id': 'ENSG00000275714'},
#    {'gene_symbol': ' H3C10', 'ensg_id': 'ENSG00000278828'},
#    {'gene_symbol': ' H3C8', 'ensg_id': 'ENSG00000273983'}]},
#  {'collision_symbol': 'H3C1',
#   'collision_group': [{'gene_symbol': 'H3C8', 'ensg_id': 'ENSG00000273983'},
#    {'gene_symbol': ' H3C3', 'ensg_id': 'ENSG00000287080'},
#    {'gene_symbol': ' H3C6', 'ensg_id': 'ENSG00000274750'},
#    {'gene_symbol': ' H3C4', 'ensg_id': 'ENSG00000197409'},
#    {'gene_symbol': ' H3C11', 'ensg_id': 'ENSG00000275379'},
#    {'gene_symbol': ' H3C12', 'ensg_id': 'ENSG00000197153'},
#    {'gene_symbol': ' H3C2', 'ensg_id': 'ENSG00000286522'},
#    {'gene_symbol': ' H3C10', 'ensg_id': 'ENSG00000278828'},
#    {'gene_symbol': ' H3C7', 'ensg_id': 'ENSG00000277775'}]},
#  {'collision_symbol': 'H3C11',
#   'collision_group': [{'gene_symbol': 'H3C1', 'ensg_id': 'ENSG00000275714'},
#    {'gene_symbol': ' H3C7', 'ensg_id': 'ENSG00000277775'},
#    {'gene_symbol': ' H3C6', 'ensg_id': 'ENSG00000274750'},
#    {'gene_symbol': ' H3C10', 'ensg_id': 'ENSG00000278828'},
#    {'gene_symbol': ' H3C3', 'ensg_id': 'ENSG00000287080'},
#    {'gene_symbol': ' H3C2', 'ensg_id': 'ENSG00000286522'},
#    {'gene_symbol': ' H3C4', 'ensg_id': 'ENSG00000197409'},
#    {'gene_symbol': ' H3C12', 'ensg_id': 'ENSG00000197153'},
#    {'gene_symbol': ' H3C8', 'ensg_id': 'ENSG00000273983'}]},
#  {'collision_symbol': 'Proteinase',
#   'collision_group': [{'gene_symbol': 'ERVK-18', 'ensg_id': 'NAN'},
#    {'gene_symbol': ' ERVK-25', 'ensg_id': 'NAN'},
#    {'gene_symbol': ' ERVK-9', 'ensg_id': 'NAN'},
#    {'gene_symbol': ' ERVK-21', 'ensg_id': 'NAN'},
#    {'gene_symbol': ' ERVK-8', 'ensg_id': 'NAN'},
#    {'gene_symbol': ' ERVK-19', 'ensg_id': 'NAN'},
#    {'gene_symbol': ' ERVK-10', 'ensg_id': 'NAN'},
#    {'gene_symbol': ' ERVK-24', 'ensg_id': 'NAN'}]},
#  {'collision_symbol': 'ACT',
#   'collision_group': [{'gene_symbol': 'ACTG1', 'ensg_id': 'ENSG00000184009'},
#    {'gene_symbol': ' FHL5', 'ensg_id': 'ENSG00000112214'},
#    {'gene_symbol': ' ACOT7', 'ensg_id': 'ENSG00000097021'},
#    {'gene_symbol': ' ACTG2', 'ensg_id': 'ENSG00000163017'},
#    {'gene_symbol': ' POTEM', 'ensg_id': 'ENSG00000222036'},
#    {'gene_symbol': ' POTEKP', 'ensg_id': 'NAN'},
#    {'gene_symbol': ' ACTBL2', 'ensg_id': 'ENSG00000169067'},
#    {'gene_symbol': ' SERPINA3', 'ensg_id': 'ENSG00000196136'}]},
#  {'collision_symbol': 'AIP1',
#   'collision_group': [{'gene_symbol': 'ABI2', 'ensg_id': 'ENSG00000138443'},
#    {'gene_symbol': ' PDCD6IP', 'ensg_id': 'ENSG00000170248'},
#    {'gene_symbol': ' WDR1', 'ensg_id': 'ENSG00000071127'},
#    {'gene_symbol': ' BIRC3', 'ensg_id': 'ENSG00000023445'},
#    {'gene_symbol': ' DAB2IP', 'ensg_id': 'ENSG00000136848'},
#    {'gene_symbol': ' MAGI2', 'ensg_id': 'ENSG00000187391'},
#    {'gene_symbol': ' ACTRT1', 'ensg_id': 'ENSG00000123165'},
#    {'gene_symbol': ' ARL6IP1', 'ensg_id': 'ENSG00000170540'}]},
#  {'collision_symbol': 'Protease',
#   'collision_group': [{'gene_symbol': 'ERVK-10', 'ensg_id': 'NAN'},
#    {'gene_symbol': ' ERVK-21', 'ensg_id': 'NAN'},
#    {'gene_symbol': ' ERVK-24', 'ensg_id': 'NAN'},
#    {'gene_symbol': ' ERVK-9', 'ensg_id': 'NAN'},
#    {'gene_symbol': ' ERVK-18', 'ensg_id': 'NAN'},
#    {'gene_symbol': ' ERVK-19', 'ensg_id': 'NAN'},
#    {'gene_symbol': ' ERVK-8', 'ensg_id': 'NAN'},
#    {'gene_symbol': ' ERVK-25', 'ensg_id': 'NAN'}]},
#  {'collision_symbol': 'ASP',
#   'collision_group': [{'gene_symbol': 'ASPM', 'ensg_id': 'ENSG00000066279'},
#    {'gene_symbol': ' TMPRSS11D', 'ensg_id': 'ENSG00000153802'},
#    {'gene_symbol': ' A1CF', 'ensg_id': 'ENSG00000148584'},
#    {'gene_symbol': ' ATG5', 'ensg_id': 'ENSG00000057663'},
#    {'gene_symbol': ' ROPN1L', 'ensg_id': 'ENSG00000145491'},
#    {'gene_symbol': ' C3', 'ensg_id': 'ENSG00000125730'},
#    {'gene_symbol': ' ASIP', 'ensg_id': 'ENSG00000101440'},
#    {'gene_symbol': ' ASPA', 'ensg_id': 'ENSG00000108381'}]},
#  {'collision_symbol': 'p55',
#   'collision_group': [{'gene_symbol': 'TNFRSF1A',
#     'ensg_id': 'ENSG00000067182'},
#    {'gene_symbol': ' IL2RA', 'ensg_id': 'ENSG00000134460'},
#    {'gene_symbol': ' ERG', 'ensg_id': 'ENSG00000157554'},
#    {'gene_symbol': ' PSMD12', 'ensg_id': 'ENSG00000197170'},
#    {'gene_symbol': ' FOS', 'ensg_id': 'ENSG00000170345'},
#    {'gene_symbol': ' PIK3R3', 'ensg_id': 'ENSG00000117461'},
#    {'gene_symbol': ' H3P44', 'ensg_id': 'NAN'},
#    {'gene_symbol': ' FSCN1', 'ensg_id': 'ENSG00000075618'}]},
#  {'collision_symbol': 'ALP',
#   'collision_group': [{'gene_symbol': 'NAT10', 'ensg_id': 'ENSG00000135372'},
#    {'gene_symbol': ' ATHS', 'ensg_id': 'NAN'},
#    {'gene_symbol': ' ASRGL1', 'ensg_id': 'ENSG00000162174'},
#    {'gene_symbol': ' ATRNL1', 'ensg_id': 'ENSG00000107518'},
#    {'gene_symbol': ' PDLIM3', 'ensg_id': 'ENSG00000154553'},
#    {'gene_symbol': ' ALPP', 'ensg_id': 'ENSG00000163283'},
#    {'gene_symbol': ' SLPI', 'ensg_id': 'ENSG00000124107'},
#    {'gene_symbol': ' CCL27', 'ensg_id': 'ENSG00000213927'}]},
#  {'collision_symbol': 'PAP',
#   'collision_group': [{'gene_symbol': 'ACP3', 'ensg_id': 'ENSG00000014257'},
#    {'gene_symbol': ' PAPOLA', 'ensg_id': 'ENSG00000090060'},
#    {'gene_symbol': ' TUSC2', 'ensg_id': 'ENSG00000114383'},
#    {'gene_symbol': ' MRPS30', 'ensg_id': 'ENSG00000112996'},
#    {'gene_symbol': ' ASAP1', 'ensg_id': 'ENSG00000153317'},
#    {'gene_symbol': ' PDAP1', 'ensg_id': 'ENSG00000106244'},
#    {'gene_symbol': ' ASAP2', 'ensg_id': 'ENSG00000151693'}]},
#  {'collision_symbol': 'TP53TG3F',
#   'collision_group': [{'gene_symbol': 'TP53TG3C',
#     'ensg_id': 'ENSG00000205457'},
#    {'gene_symbol': ' LOC102723713', 'ensg_id': 'ENSG00000275869'},
#    {'gene_symbol': ' TP53TG3B', 'ensg_id': 'ENSG00000261509'},
#    {'gene_symbol': ' TP53TG3E', 'ensg_id': 'ENSG00000275034'},
#    {'gene_symbol': ' TP53TG3', 'ensg_id': 'ENSG00000183632'},
#    {'gene_symbol': ' TP53TG3D', 'ensg_id': 'ENSG00000205456'},
#    {'gene_symbol': ' LOC102723655', 'ensg_id': 'NAN'}]},
#  {'collision_symbol': 'TP53TG3E',
#   'collision_group': [{'gene_symbol': 'TP53TG3D',
#     'ensg_id': 'ENSG00000205456'},
#    {'gene_symbol': ' LOC102723713', 'ensg_id': 'ENSG00000275869'},
#    {'gene_symbol': ' TP53TG3', 'ensg_id': 'ENSG00000183632'},
#    {'gene_symbol': ' TP53TG3B', 'ensg_id': 'ENSG00000261509'},
#    {'gene_symbol': ' LOC102723655', 'ensg_id': 'NAN'},
#    {'gene_symbol': ' TP53TG3C', 'ensg_id': 'ENSG00000205457'},
#    {'gene_symbol': ' TP53TG3F', 'ensg_id': 'ENSG00000278848'}]},
#  {'collision_symbol': 'p40',
#   'collision_group': [{'gene_symbol': 'TP63', 'ensg_id': 'ENSG00000073282'},
#    {'gene_symbol': ' ARMH1', 'ensg_id': 'ENSG00000198520'},
#    {'gene_symbol': ' MAPK1', 'ensg_id': 'ENSG00000100030'},
#    {'gene_symbol': ' H3P28', 'ensg_id': 'NAN'},
#    {'gene_symbol': ' LANCL1', 'ensg_id': 'ENSG00000115365'},
#    {'gene_symbol': ' RABEPK', 'ensg_id': 'ENSG00000136933'},
#    {'gene_symbol': ' RPSA', 'ensg_id': 'ENSG00000168028'}]},
#  {'collision_symbol': 'p120',
#   'collision_group': [{'gene_symbol': 'BRD8', 'ensg_id': 'ENSG00000112983'},
#    {'gene_symbol': ' RASA1', 'ensg_id': 'ENSG00000145715'},
#    {'gene_symbol': ' IGSF1', 'ensg_id': 'ENSG00000147255'},
#    {'gene_symbol': ' NSUN5', 'ensg_id': 'ENSG00000130305'},
#    {'gene_symbol': ' NOP2', 'ensg_id': 'ENSG00000111641'},
#    {'gene_symbol': ' CTNND1', 'ensg_id': 'ENSG00000198561'},
#    {'gene_symbol': ' TRPA1', 'ensg_id': 'ENSG00000104321'}]},
#  {'collision_symbol': 'PSP',
#   'collision_group': [{'gene_symbol': 'RIDA', 'ensg_id': 'ENSG00000132541'},
#    {'gene_symbol': ' MSMB', 'ensg_id': 'ENSG00000263639'},
#    {'gene_symbol': ' STXBP3', 'ensg_id': 'ENSG00000116266'},
#    {'gene_symbol': ' PSPH', 'ensg_id': 'ENSG00000146733'},
#    {'gene_symbol': ' REG1A', 'ensg_id': 'ENSG00000115386'},
#    {'gene_symbol': ' PSPN', 'ensg_id': 'ENSG00000125650'},
#    {'gene_symbol': ' BPIFA2', 'ensg_id': 'ENSG00000131050'}]},
#  {'collision_symbol': 'ASP',
#   'collision_group': [{'gene_symbol': 'TMPRSS11D',
#     'ensg_id': 'ENSG00000153802'},
#    {'gene_symbol': ' ROPN1L', 'ensg_id': 'ENSG00000145491'},
#    {'gene_symbol': ' ATG5', 'ensg_id': 'ENSG00000057663'},
#    {'gene_symbol': ' A1CF', 'ensg_id': 'ENSG00000148584'},
#    {'gene_symbol': ' ASPM', 'ensg_id': 'ENSG00000066279'},
#    {'gene_symbol': ' ASPA', 'ensg_id': 'ENSG00000108381'},
#    {'gene_symbol': ' ASIP', 'ensg_id': 'ENSG00000101440'}]},
#  {'collision_symbol': 'U4',
#   'collision_group': [{'gene_symbol': 'RNU4-7P', 'ensg_id': 'NAN'},
#    {'gene_symbol': ' RNU4-8P', 'ensg_id': 'NAN'},
#    {'gene_symbol': ' RNU4-1', 'ensg_id': 'ENSG00000200795'},
#    {'gene_symbol': ' RNU4-6P', 'ensg_id': 'NAN'},
#    {'gene_symbol': ' RNU4-5P', 'ensg_id': 'NAN'},
#    {'gene_symbol': ' RNU4-4P', 'ensg_id': 'NAN'},
#    {'gene_symbol': ' RNU4-3P', 'ensg_id': 'NAN'}]},
#  {'collision_symbol': 'NPIP',
#   'collision_group': [{'gene_symbol': 'NPIPB3', 'ensg_id': 'NAN'},
#    {'gene_symbol': ' NPIPB10P', 'ensg_id': 'NAN'},
#    {'gene_symbol': ' NPIPA2', 'ensg_id': 'ENSG00000254852'},
#    {'gene_symbol': ' NPIPB11', 'ensg_id': 'ENSG00000254206'},
#    {'gene_symbol': ' NPIPA5', 'ensg_id': 'ENSG00000183793'},
#    {'gene_symbol': ' NPIPA1', 'ensg_id': 'ENSG00000183426'},
#    {'gene_symbol': ' PKD1P1', 'ensg_id': 'NAN'}]},
#  {'collision_symbol': 'PAP',
#   'collision_group': [{'gene_symbol': 'MRPS30', 'ensg_id': 'ENSG00000112996'},
#    {'gene_symbol': ' PAPOLA', 'ensg_id': 'ENSG00000090060'},
#    {'gene_symbol': ' TUSC2', 'ensg_id': 'ENSG00000114383'},
#    {'gene_symbol': ' REG3A', 'ensg_id': 'ENSG00000172016'},
#    {'gene_symbol': ' PDAP1', 'ensg_id': 'ENSG00000106244'},
#    {'gene_symbol': ' ASAP1', 'ensg_id': 'ENSG00000153317'},
#    {'gene_symbol': ' ASAP2', 'ensg_id': 'ENSG00000151693'}]},
#  {'collision_symbol': 'CAR',
#   'collision_group': [{'gene_symbol': 'SPG7', 'ensg_id': 'ENSG00000197912'},
#    {'gene_symbol': ' PRKAR1A', 'ensg_id': 'ENSG00000108946'},
#    {'gene_symbol': ' CXADRP1', 'ensg_id': 'ENSG00000214319'},
#    {'gene_symbol': ' NR1I3', 'ensg_id': 'ENSG00000143257'},
#    {'gene_symbol': ' CXADR', 'ensg_id': 'ENSG00000154639'},
#    {'gene_symbol': ' CASR', 'ensg_id': 'ENSG00000036828'},
#    {'gene_symbol': ' TRIM13', 'ensg_id': 'ENSG00000204977'}]},
#  {'collision_symbol': 'CAP',
#   'collision_group': [{'gene_symbol': 'SERPINB6',
#     'ensg_id': 'ENSG00000124570'},
#    {'gene_symbol': ' SORBS1', 'ensg_id': 'ENSG00000095637'},
#    {'gene_symbol': ' HACD1', 'ensg_id': 'ENSG00000165996'},
#    {'gene_symbol': ' LNPEP', 'ensg_id': 'ENSG00000113441'},
#    {'gene_symbol': ' CAP1', 'ensg_id': 'ENSG00000131236'},
#    {'gene_symbol': ' CTAA1', 'ensg_id': 'NAN'},
#    {'gene_symbol': ' BRD4', 'ensg_id': 'ENSG00000141867'}]},
#  {'collision_symbol': 'p75',
#   'collision_group': [{'gene_symbol': 'KHSRP', 'ensg_id': 'ENSG00000088247'},
#    {'gene_symbol': ' HCLS1', 'ensg_id': 'ENSG00000180353'},
#    {'gene_symbol': ' SIGLEC7', 'ensg_id': 'ENSG00000168995'},
#    {'gene_symbol': ' TCF3', 'ensg_id': 'ENSG00000071564'},
#    {'gene_symbol': ' PSIP1', 'ensg_id': 'ENSG00000164985'},
#    {'gene_symbol': ' TNFRSF1B', 'ensg_id': 'ENSG00000028137'},
#    {'gene_symbol': ' CUX1', 'ensg_id': 'ENSG00000257923'}]},
#  {'collision_symbol': 'U4',
#   'collision_group': [{'gene_symbol': 'RNU4-7P', 'ensg_id': 'ENSG00000201628'},
#    {'gene_symbol': ' RNU4-6P', 'ensg_id': 'ENSG00000222736'},
#    {'gene_symbol': ' RNU4-1', 'ensg_id': 'ENSG00000200795'},
#    {'gene_symbol': ' RNU4-3P', 'ensg_id': 'NAN'},
#    {'gene_symbol': ' RNU4-4P', 'ensg_id': 'ENSG00000201458'},
#    {'gene_symbol': ' RNU4-5P', 'ensg_id': 'ENSG00000272160'},
#    {'gene_symbol': ' RNU4-8P', 'ensg_id': 'ENSG00000201806'}]},
#  {'collision_symbol': 'GNT1',
#   'collision_group': [{'gene_symbol': 'UGT1A', 'ensg_id': 'NAN'},
#    {'gene_symbol': ' UGT1A7', 'ensg_id': 'ENSG00000244122'},
#    {'gene_symbol': ' UGT1A6', 'ensg_id': 'ENSG00000167165'},
#    {'gene_symbol': ' UGT1A8', 'ensg_id': 'ENSG00000242366'},
#    {'gene_symbol': ' UGT1A4', 'ensg_id': 'ENSG00000244474'},
#    {'gene_symbol': ' UGT1A10', 'ensg_id': 'ENSG00000242515'},
#    {'gene_symbol': ' UGT1A1', 'ensg_id': 'ENSG00000241635'}]},
#  {'collision_symbol': 'TFIIH',
#   'collision_group': [{'gene_symbol': 'GTF2H4', 'ensg_id': 'ENSG00000213780'},
#    {'gene_symbol': ' GTF2H2', 'ensg_id': 'ENSG00000145736'},
#    {'gene_symbol': ' GTF2H3', 'ensg_id': 'ENSG00000111358'},
#    {'gene_symbol': ' ERCC2', 'ensg_id': 'ENSG00000104884'},
#    {'gene_symbol': ' ERCC3', 'ensg_id': 'ENSG00000163161'},
#    {'gene_symbol': ' GTF2H1', 'ensg_id': 'ENSG00000110768'},
#    {'gene_symbol': ' GTF2H5', 'ensg_id': 'ENSG00000272047'}]},
#  {'collision_symbol': 'HOX3',
#   'collision_group': [{'gene_symbol': 'HOXC4', 'ensg_id': 'ENSG00000198353'},
#    {'gene_symbol': ' HOXC5', 'ensg_id': 'ENSG00000273046'},
#    {'gene_symbol': ' HOXC6', 'ensg_id': 'ENSG00000197757'},
#    {'gene_symbol': ' HOXC8', 'ensg_id': 'ENSG00000037965'},
#    {'gene_symbol': ' HOXC9', 'ensg_id': 'ENSG00000180806'},
#    {'gene_symbol': ' HOXC13', 'ensg_id': 'ENSG00000123364'},
#    {'gene_symbol': ' HOXC12', 'ensg_id': 'ENSG00000123407'}]},
#  {'collision_symbol': 'HOX4',
#   'collision_group': [{'gene_symbol': 'HOXD11', 'ensg_id': 'ENSG00000128713'},
#    {'gene_symbol': ' HOXD1', 'ensg_id': 'ENSG00000128645'},
#    {'gene_symbol': ' HOXD3', 'ensg_id': 'ENSG00000128652'},
#    {'gene_symbol': ' HOXD4', 'ensg_id': 'ENSG00000170166'},
#    {'gene_symbol': ' HOXD10', 'ensg_id': 'ENSG00000128710'},
#    {'gene_symbol': ' HOXD8', 'ensg_id': 'ENSG00000175879'},
#    {'gene_symbol': ' HOXD9', 'ensg_id': 'ENSG00000128709'}]},
#  {'collision_symbol': 'DUX4',
#   'collision_group': [{'gene_symbol': 'DUX4L1', 'ensg_id': 'ENSG00000280757'},
#    {'gene_symbol': ' LOC107987485', 'ensg_id': 'NAN'},
#    {'gene_symbol': ' LOC107987486', 'ensg_id': 'NAN'},
#    {'gene_symbol': ' DUX4L2', 'ensg_id': 'ENSG00000280457'},
#    {'gene_symbol': ' LOC107987484', 'ensg_id': 'NAN'},
#    {'gene_symbol': ' LOC124906461', 'ensg_id': 'NAN'},
#    {'gene_symbol': ' LOC107987487', 'ensg_id': 'NAN'}]},
#  {'collision_symbol': 'DUX10',
#   'collision_group': [{'gene_symbol': 'DUX4L1', 'ensg_id': 'ENSG00000280757'},
#    {'gene_symbol': ' LOC107987487', 'ensg_id': 'NAN'},
#    {'gene_symbol': ' DUX4L10', 'ensg_id': 'ENSG00000278664'},
#    {'gene_symbol': ' LOC107987485', 'ensg_id': 'NAN'},
#    {'gene_symbol': ' LOC124906455', 'ensg_id': 'NAN'},
#    {'gene_symbol': ' LOC107987484', 'ensg_id': 'NAN'},
#    {'gene_symbol': ' LOC107987486', 'ensg_id': 'NAN'}]},
#  {'collision_symbol': 'PRC17',
#   'collision_group': [{'gene_symbol': 'TBC1D3I', 'ensg_id': 'ENSG00000274933'},
#    {'gene_symbol': ' TBC1D3E', 'ensg_id': 'ENSG00000278599'},
#    {'gene_symbol': ' TBC1D3B', 'ensg_id': 'ENSG00000274808'},
#    {'gene_symbol': ' TBC1D3D', 'ensg_id': 'ENSG00000274419'},
#    {'gene_symbol': ' TBC1D3', 'ensg_id': 'ENSG00000274611'},
#    {'gene_symbol': ' TBC1D3C', 'ensg_id': 'ENSG00000278299'}]},
#  {'collision_symbol': ' U4',
#   'collision_group': [{'gene_symbol': 'RNU4-8P', 'ensg_id': 'ENSG00000201806'},
#    {'gene_symbol': ' RNU4-1', 'ensg_id': 'ENSG00000200795'},
#    {'gene_symbol': ' RNU4-5P', 'ensg_id': 'ENSG00000272160'},
#    {'gene_symbol': ' RNU4-6P', 'ensg_id': 'ENSG00000222736'},
#    {'gene_symbol': ' RNU4-7P', 'ensg_id': 'ENSG00000201628'},
#    {'gene_symbol': ' RNU4-4P', 'ensg_id': 'ENSG00000201458'}]},
#  {'collision_symbol': 'CAP',
#   'collision_group': [{'gene_symbol': 'HACD1', 'ensg_id': 'ENSG00000165996'},
#    {'gene_symbol': ' LNPEP', 'ensg_id': 'ENSG00000113441'},
#    {'gene_symbol': ' BRD4', 'ensg_id': 'ENSG00000141867'},
#    {'gene_symbol': ' SORBS1', 'ensg_id': 'ENSG00000095637'},
#    {'gene_symbol': ' SERPINB6', 'ensg_id': 'ENSG00000124570'},
#    {'gene_symbol': ' CAP1', 'ensg_id': 'ENSG00000131236'}]},
#  {'collision_symbol': 'TP53TG3',
#   'collision_group': [{'gene_symbol': 'TP53TG3E',
#     'ensg_id': 'ENSG00000275034'},
#    {'gene_symbol': ' LOC102723713', 'ensg_id': 'ENSG00000275869'},
#    {'gene_symbol': ' TP53TG3F', 'ensg_id': 'ENSG00000278848'},
#    {'gene_symbol': ' LOC102723655', 'ensg_id': 'NAN'},
#    {'gene_symbol': ' TP53TG3C', 'ensg_id': 'ENSG00000205457'},
#    {'gene_symbol': ' TP53TG3D', 'ensg_id': 'ENSG00000205456'}]},
#  {'collision_symbol': 'TR',
#   'collision_group': [{'gene_symbol': 'TMEFF2', 'ensg_id': 'ENSG00000144339'},
#    {'gene_symbol': ' TXNRD2', 'ensg_id': 'ENSG00000184470'},
#    {'gene_symbol': ' F2R', 'ensg_id': 'ENSG00000181104'},
#    {'gene_symbol': ' TERC', 'ensg_id': 'ENSG00000277925'},
#    {'gene_symbol': ' TFRC', 'ensg_id': 'ENSG00000072274'},
#    {'gene_symbol': ' TXNRD1', 'ensg_id': 'ENSG00000198431'}]},
#  {'collision_symbol': 'MYM',
#   'collision_group': [{'gene_symbol': 'ZMYM1', 'ensg_id': 'ENSG00000197056'},
#    {'gene_symbol': ' ZMYM5', 'ensg_id': 'ENSG00000132950'},
#    {'gene_symbol': ' ZMYM4', 'ensg_id': 'ENSG00000146463'},
#    {'gene_symbol': ' ZMYM6', 'ensg_id': 'ENSG00000163867'},
#    {'gene_symbol': ' ZMYM3', 'ensg_id': 'ENSG00000147130'},
#    {'gene_symbol': ' ZMYM2', 'ensg_id': 'ENSG00000121741'}]},
#  {'collision_symbol': 'HOX3',
#   'collision_group': [{'gene_symbol': 'HOXC8', 'ensg_id': 'ENSG00000037965'},
#    {'gene_symbol': ' HOXC6', 'ensg_id': 'ENSG00000197757'},
#    {'gene_symbol': ' HOXC4', 'ensg_id': 'ENSG00000198353'},
#    {'gene_symbol': ' HOXC13', 'ensg_id': 'ENSG00000123364'},
#    {'gene_symbol': ' HOXC9', 'ensg_id': 'ENSG00000180806'},
#    {'gene_symbol': ' HOXC5', 'ensg_id': 'ENSG00000172789'}]},
#  {'collision_symbol': 'UGT1A',
#   'collision_group': [{'gene_symbol': 'UGT1A6', 'ensg_id': 'ENSG00000167165'},
#    {'gene_symbol': ' UGT1A4', 'ensg_id': 'ENSG00000244474'},
#    {'gene_symbol': ' UGT1A7', 'ensg_id': 'ENSG00000244122'},
#    {'gene_symbol': ' UGT1A1', 'ensg_id': 'ENSG00000241635'},
#    {'gene_symbol': ' UGT1A8', 'ensg_id': 'ENSG00000242366'},
#    {'gene_symbol': ' UGT1A10', 'ensg_id': 'ENSG00000242515'}]},
#  {'collision_symbol': 'FBP',
#   'collision_group': [{'gene_symbol': 'FUBP1', 'ensg_id': 'ENSG00000162613'},
#    {'gene_symbol': ' RAB14', 'ensg_id': 'ENSG00000119396'},
#    {'gene_symbol': ' FOLR2', 'ensg_id': 'ENSG00000165457'},
#    {'gene_symbol': ' ECB2', 'ensg_id': 'NAN'},
#    {'gene_symbol': ' FOLR1', 'ensg_id': 'ENSG00000110195'},
#    {'gene_symbol': ' FBP1', 'ensg_id': 'ENSG00000165140'}]},
#  {'collision_symbol': ' PAP',
#   'collision_group': [{'gene_symbol': 'PDAP1', 'ensg_id': 'ENSG00000106244'},
#    {'gene_symbol': ' ASAP2', 'ensg_id': 'ENSG00000151693'},
#    {'gene_symbol': ' REG3A', 'ensg_id': 'ENSG00000172016'},
#    {'gene_symbol': ' ACP3', 'ensg_id': 'ENSG00000014257'},
#    {'gene_symbol': ' TUSC2', 'ensg_id': 'ENSG00000114383'},
#    {'gene_symbol': ' ASAP1', 'ensg_id': 'ENSG00000153317'}]},
#  {'collision_symbol': 'C13orf25',
#   'collision_group': [{'gene_symbol': 'MIR17HG', 'ensg_id': 'ENSG00000215417'},
#    {'gene_symbol': ' MIR18A', 'ensg_id': 'ENSG00000283815'},
#    {'gene_symbol': ' MIR20A', 'ensg_id': 'ENSG00000283762'},
#    {'gene_symbol': ' MIR92A1', 'ensg_id': 'ENSG00000283705'},
#    {'gene_symbol': ' MIR19A', 'ensg_id': 'ENSG00000284204'},
#    {'gene_symbol': ' MIR19B1', 'ensg_id': 'ENSG00000284375'}]},
#  {'collision_symbol': 'IGLC',
#   'collision_group': [{'gene_symbol': 'IGLC2', 'ensg_id': 'ENSG00000211677'},
#    {'gene_symbol': ' IGLC1', 'ensg_id': 'ENSG00000211675'},
#    {'gene_symbol': ' IGLC6', 'ensg_id': 'ENSG00000222037'},
#    {'gene_symbol': ' IGLC4', 'ensg_id': 'ENSG00000254029'},
#    {'gene_symbol': ' IGLC5', 'ensg_id': 'ENSG00000254030'},
#    {'gene_symbol': ' IGLC3', 'ensg_id': 'ENSG00000211679'}]},
#  {'collision_symbol': 'HARP',
#   'collision_group': [{'gene_symbol': 'ANGPTL4', 'ensg_id': 'ENSG00000167772'},
#    {'gene_symbol': ' ANKS4B', 'ensg_id': 'ENSG00000175311'},
#    {'gene_symbol': ' PANK2', 'ensg_id': 'ENSG00000125779'},
#    {'gene_symbol': ' ANGPTL2', 'ensg_id': 'ENSG00000136859'},
#    {'gene_symbol': ' SMARCAL1', 'ensg_id': 'ENSG00000138375'},
#    {'gene_symbol': ' PTN', 'ensg_id': 'ENSG00000105894'}]},
#  {'collision_symbol': 'ZNF',
#   'collision_group': [{'gene_symbol': 'ZNF436', 'ensg_id': 'ENSG00000125945'},
#    {'gene_symbol': ' ZNF44', 'ensg_id': 'ENSG00000197857'},
#    {'gene_symbol': ' ZNF569', 'ensg_id': 'ENSG00000196437'},
#    {'gene_symbol': ' ZNF501', 'ensg_id': 'ENSG00000186446'},
#    {'gene_symbol': ' ZNF763', 'ensg_id': 'ENSG00000197054'},
#    {'gene_symbol': ' ZNF629', 'ensg_id': 'ENSG00000102870'}]},
#  {'collision_symbol': 'F379',
#   'collision_group': [{'gene_symbol': 'FAM138E', 'ensg_id': 'ENSG00000248893'},
#    {'gene_symbol': ' FAM138A', 'ensg_id': 'ENSG00000237613'},
#    {'gene_symbol': ' FAM138F', 'ensg_id': 'ENSG00000282591'},
#    {'gene_symbol': ' FAM138C', 'ensg_id': 'ENSG00000218839'},
#    {'gene_symbol': ' FAM138B', 'ensg_id': 'ENSG00000226516'},
#    {'gene_symbol': ' FAM138D', 'ensg_id': 'ENSG00000249054'}]},
#  {'collision_symbol': 'MDS',
#   'collision_group': [{'gene_symbol': 'TET2', 'ensg_id': 'ENSG00000168769'},
#    {'gene_symbol': ' GNB1', 'ensg_id': 'ENSG00000078369'},
#    {'gene_symbol': ' ASXL1', 'ensg_id': 'ENSG00000171456'},
#    {'gene_symbol': ' PAFAH1B1', 'ensg_id': 'ENSG00000007168'},
#    {'gene_symbol': ' SF3B1', 'ensg_id': 'ENSG00000115524'},
#    {'gene_symbol': ' YWHAE', 'ensg_id': 'ENSG00000108953'}]},
#  {'collision_symbol': 'HOX4',
#   'collision_group': [{'gene_symbol': 'HOXD4', 'ensg_id': 'ENSG00000170166'},
#    {'gene_symbol': ' HOXD8', 'ensg_id': 'ENSG00000175879'},
#    {'gene_symbol': ' HOXD10', 'ensg_id': 'ENSG00000128710'},
#    {'gene_symbol': ' HOXD9', 'ensg_id': 'ENSG00000128709'},
#    {'gene_symbol': ' HOXD1', 'ensg_id': 'ENSG00000128645'},
#    {'gene_symbol': ' HOXD11', 'ensg_id': 'ENSG00000128713'}]},
#  {'collision_symbol': 'LRRC37',
#   'collision_group': [{'gene_symbol': 'LRRC37B', 'ensg_id': 'ENSG00000185158'},
#    {'gene_symbol': ' LRRC37A', 'ensg_id': 'ENSG00000176681'},
#    {'gene_symbol': ' LRRC37A2', 'ensg_id': 'ENSG00000260075'},
#    {'gene_symbol': ' LOC646030', 'ensg_id': 'NAN'},
#    {'gene_symbol': ' LRRC37A3', 'ensg_id': 'ENSG00000176809'},
#    {'gene_symbol': ' LRRC37A4P', 'ensg_id': 'NAN'}]},
#  {'collision_symbol': 'p100',
#   'collision_group': [{'gene_symbol': 'TPX2', 'ensg_id': 'ENSG00000088325'},
#    {'gene_symbol': ' CUX1', 'ensg_id': 'ENSG00000257923'},
#    {'gene_symbol': ' SND1', 'ensg_id': 'ENSG00000197157'},
#    {'gene_symbol': ' NFKB2', 'ensg_id': 'ENSG00000077150'},
#    {'gene_symbol': ' ASCC2', 'ensg_id': 'ENSG00000100325'},
#    {'gene_symbol': ' OAS3', 'ensg_id': 'ENSG00000111331'}]},
#  {'collision_symbol': 'IGLC',
# ...
#    {'gene_symbol': ' MBL2', 'ensg_id': 'ENSG00000165471'}]},
#  {'collision_symbol': 'PI-PLC',
#   'collision_group': [{'gene_symbol': 'PDIA3', 'ensg_id': 'ENSG00000167004'},
#    {'gene_symbol': ' PLCB4', 'ensg_id': 'ENSG00000101333'},
#    {'gene_symbol': ' PLCB1', 'ensg_id': 'ENSG00000182621'}]},
#  {'collision_symbol': 'PAR1',
#   'collision_group': [{'gene_symbol': 'SLC52A2', 'ensg_id': 'ENSG00000185803'},
#    {'gene_symbol': ' PWAR1', 'ensg_id': 'ENSG00000279050'},
#    {'gene_symbol': ' F2R', 'ensg_id': 'ENSG00000181104'}]},
#  {'collision_symbol': 'PLA2',
#   'collision_group': [{'gene_symbol': 'PLA2G2A', 'ensg_id': 'ENSG00000188257'},
#    {'gene_symbol': ' PLA2G1B', 'ensg_id': 'ENSG00000170890'},
#    {'gene_symbol': ' PLA2G6', 'ensg_id': 'ENSG00000184381'}]},
#  {'collision_symbol': 'HSP70-2',
#   'collision_group': [{'gene_symbol': 'HSPA1B', 'ensg_id': 'ENSG00000204388'},
#    {'gene_symbol': ' HSPA1A', 'ensg_id': 'ENSG00000204389'},
#    {'gene_symbol': ' HSPA2', 'ensg_id': 'ENSG00000126803'}]},
#  {'collision_symbol': 'P21',
#   'collision_group': [{'gene_symbol': 'CDKN1A', 'ensg_id': 'ENSG00000124762'},
#    {'gene_symbol': ' TCEAL1', 'ensg_id': 'ENSG00000172465'},
#    {'gene_symbol': ' NSG1', 'ensg_id': 'ENSG00000168824'}]},
#  {'collision_symbol': 'PHKD',
#   'collision_group': [{'gene_symbol': 'CALM3', 'ensg_id': 'ENSG00000160014'},
#    {'gene_symbol': ' CALM2', 'ensg_id': 'ENSG00000143933'},
#    {'gene_symbol': ' CALM1', 'ensg_id': 'ENSG00000198668'}]},
#  {'collision_symbol': 'OCT4',
#   'collision_group': [{'gene_symbol': 'POU5F1P3',
#     'ensg_id': 'ENSG00000235602'},
#    {'gene_symbol': ' POU5F1', 'ensg_id': 'ENSG00000204531'},
#    {'gene_symbol': ' POU5F1P4', 'ensg_id': 'ENSG00000237872'}]},
#  {'collision_symbol': 'ALR',
#   'collision_group': [{'gene_symbol': 'GFER', 'ensg_id': 'ENSG00000127554'},
#    {'gene_symbol': ' AKR1A1', 'ensg_id': 'ENSG00000117448'},
#    {'gene_symbol': ' KMT2D', 'ensg_id': 'ENSG00000167548'}]},
#  {'collision_symbol': 'ESA',
#   'collision_group': [{'gene_symbol': 'EPCAM', 'ensg_id': 'ENSG00000119888'},
#    {'gene_symbol': ' PON1', 'ensg_id': 'ENSG00000005421'},
#    {'gene_symbol': ' FLOT2', 'ensg_id': 'ENSG00000132589'}]},
#  {'collision_symbol': 'GCP2',
#   'collision_group': [{'gene_symbol': 'FOLH1', 'ensg_id': 'ENSG00000086205'},
#    {'gene_symbol': ' GOLGA4', 'ensg_id': 'ENSG00000144674'},
#    {'gene_symbol': ' TUBGCP2', 'ensg_id': 'ENSG00000130640'}]},
#  {'collision_symbol': 'N2N',
#   'collision_group': [{'gene_symbol': 'NOTCH2NLA',
#     'ensg_id': 'ENSG00000264343'},
#    {'gene_symbol': ' NOTCH2NLB', 'ensg_id': 'ENSG00000286019'},
#    {'gene_symbol': ' NOTCH2NLC', 'ensg_id': 'ENSG00000286219'}]},
#  {'collision_symbol': ' p14',
#   'collision_group': [{'gene_symbol': 'LAMTOR2', 'ensg_id': 'ENSG00000116586'},
#    {'gene_symbol': ' CDK2AP2', 'ensg_id': 'ENSG00000167797'},
#    {'gene_symbol': ' CDKN2A', 'ensg_id': 'ENSG00000147889'}]},
#  {'collision_symbol': 'AN',
#   'collision_group': [{'gene_symbol': 'PAX6', 'ensg_id': 'ENSG00000007372'},
#    {'gene_symbol': ' DIAPH3', 'ensg_id': 'ENSG00000139734'},
#    {'gene_symbol': ' CCDC102B', 'ensg_id': 'ENSG00000150636'}]},
#  {'collision_symbol': ' p22',
#   'collision_group': [{'gene_symbol': 'PHB2', 'ensg_id': 'ENSG00000215021'},
#    {'gene_symbol': ' DYNC1H1', 'ensg_id': 'ENSG00000197102'},
#    {'gene_symbol': ' CHP1', 'ensg_id': 'ENSG00000187446'}]},
#  {'collision_symbol': 'MTTF1',
#   'collision_group': [{'gene_symbol': 'TFAM', 'ensg_id': 'ENSG00000108064'},
#    {'gene_symbol': ' TFAMP2', 'ensg_id': 'NAN'},
#    {'gene_symbol': ' TFAMP1', 'ensg_id': 'NAN'}]},
#  {'collision_symbol': 'PLA2L',
#   'collision_group': [{'gene_symbol': 'HHLA1', 'ensg_id': 'ENSG00000132297'},
#    {'gene_symbol': ' PLA2G2A', 'ensg_id': 'ENSG00000188257'},
#    {'gene_symbol': ' OC90', 'ensg_id': 'ENSG00000253117'}]},
#  {'collision_symbol': 'PLAP',
#   'collision_group': [{'gene_symbol': 'PLAA', 'ensg_id': 'ENSG00000137055'},
#    {'gene_symbol': ' LNPEP', 'ensg_id': 'ENSG00000113441'},
#    {'gene_symbol': ' ALPP', 'ensg_id': 'ENSG00000163283'}]},
#  {'collision_symbol': 'EIF-2B',
#   'collision_group': [{'gene_symbol': 'EIF2B1', 'ensg_id': 'ENSG00000111361'},
#    {'gene_symbol': ' EIF2B5', 'ensg_id': 'ENSG00000145191'},
#    {'gene_symbol': ' EIF2B3', 'ensg_id': 'ENSG00000070785'}]},
#  {'collision_symbol': 'FBP',
#   'collision_group': [{'gene_symbol': 'FUBP1', 'ensg_id': 'ENSG00000162613'},
#    {'gene_symbol': ' RAB14', 'ensg_id': 'ENSG00000119396'},
#    {'gene_symbol': ' FBP1', 'ensg_id': 'ENSG00000165140'}]},
#  {'collision_symbol': 'MSF',
#   'collision_group': [{'gene_symbol': 'FN1', 'ensg_id': 'ENSG00000115414'},
#    {'gene_symbol': ' PRG4', 'ensg_id': 'ENSG00000116690'},
#    {'gene_symbol': ' SEPTIN9', 'ensg_id': 'ENSG00000184640'}]},
#  {'collision_symbol': 'MTS1',
#   'collision_group': [{'gene_symbol': 'S100A4', 'ensg_id': 'ENSG00000196154'},
#    {'gene_symbol': ' CDKN2A', 'ensg_id': 'ENSG00000147889'},
#    {'gene_symbol': ' SAI1', 'ensg_id': 'NAN'}]},
#  {'collision_symbol': 'PDI',
#   'collision_group': [{'gene_symbol': 'PADI1', 'ensg_id': 'ENSG00000142623'},
#    {'gene_symbol': ' PDIA2', 'ensg_id': 'ENSG00000185615'},
#    {'gene_symbol': ' P4HB', 'ensg_id': 'ENSG00000185624'}]},
#  {'collision_symbol': ' p35',
#   'collision_group': [{'gene_symbol': 'CDK5R1', 'ensg_id': 'ENSG00000176749'},
#    {'gene_symbol': ' UPK3B', 'ensg_id': 'ENSG00000276184'},
#    {'gene_symbol': ' IL12A', 'ensg_id': 'ENSG00000168811'}]},
#  {'collision_symbol': 'PD1',
#   'collision_group': [{'gene_symbol': 'PDCD1', 'ensg_id': 'ENSG00000188389'},
#    {'gene_symbol': ' SPATA2', 'ensg_id': 'ENSG00000158480'},
#    {'gene_symbol': ' SNCA', 'ensg_id': 'ENSG00000145335'}]},
#  {'collision_symbol': 'M-PST',
#   'collision_group': [{'gene_symbol': 'SULT1A3', 'ensg_id': 'ENSG00000261052'},
#    {'gene_symbol': ' SULT1A4', 'ensg_id': 'ENSG00000213648'},
#    {'gene_symbol': ' SLX1A-SULT1A3', 'ensg_id': 'ENSG00000213599'}]},
#  {'collision_symbol': 'PAR2',
#   'collision_group': [{'gene_symbol': 'F2RL1', 'ensg_id': 'ENSG00000164251'},
#    {'gene_symbol': ' SLC52A1', 'ensg_id': 'ENSG00000132517'},
#    {'gene_symbol': ' NR1I2', 'ensg_id': 'ENSG00000144852'}]},
#  {'collision_symbol': 'ALK1',
#   'collision_group': [{'gene_symbol': 'ACVRL1', 'ensg_id': 'ENSG00000139567'},
#    {'gene_symbol': ' SLPI', 'ensg_id': 'ENSG00000124107'},
#    {'gene_symbol': ' ALK', 'ensg_id': 'ENSG00000171094'}]},
#  {'collision_symbol': 'PLAP',
#   'collision_group': [{'gene_symbol': 'ALPP', 'ensg_id': 'ENSG00000163283'},
#    {'gene_symbol': ' LNPEP', 'ensg_id': 'ENSG00000113441'},
#    {'gene_symbol': ' PLAA', 'ensg_id': 'ENSG00000137055'}]},
#  {'collision_symbol': 'H3',
#   'collision_group': [{'gene_symbol': 'H3C14', 'ensg_id': 'ENSG00000203811'},
#    {'gene_symbol': ' RLN3', 'ensg_id': 'ENSG00000171136'},
#    {'gene_symbol': ' FGFR1', 'ensg_id': 'ENSG00000077782'}]},
#  {'collision_symbol': 'GC1',
#   'collision_group': [{'gene_symbol': 'SLC25A22',
#     'ensg_id': 'ENSG00000177542'},
#    {'gene_symbol': ' SOD2', 'ensg_id': 'ENSG00000112096'},
#    {'gene_symbol': ' OLFM4', 'ensg_id': 'ENSG00000102837'}]},
#  {'collision_symbol': 'PHKD',
#   'collision_group': [{'gene_symbol': 'CALM3', 'ensg_id': 'ENSG00000160014'},
#    {'gene_symbol': ' CALM2', 'ensg_id': 'ENSG00000143933'},
#    {'gene_symbol': ' CALM1', 'ensg_id': 'ENSG00000198668'}]},
#  {'collision_symbol': 'EB1',
#   'collision_group': [{'gene_symbol': 'MAPRE2', 'ensg_id': 'ENSG00000166974'},
#    {'gene_symbol': ' MAPRE1', 'ensg_id': 'ENSG00000101367'},
#    {'gene_symbol': ' COX7A2L', 'ensg_id': 'ENSG00000115944'}]},
#  {'collision_symbol': 'EAP1',
#   'collision_group': [{'gene_symbol': 'IRF2BPL', 'ensg_id': 'ENSG00000119669'},
#    {'gene_symbol': ' EXOSC7', 'ensg_id': 'ENSG00000075914'},
#    {'gene_symbol': ' PTTG1', 'ensg_id': 'ENSG00000164611'}]},
#  {'collision_symbol': 'LST3',
#   'collision_group': [{'gene_symbol': 'ELMOD3', 'ensg_id': 'ENSG00000115459'},
#    {'gene_symbol': ' SLCO1B3', 'ensg_id': 'ENSG00000111700'},
#    {'gene_symbol': ' SLCO1B7', 'ensg_id': 'NAN'}]},
#  {'collision_symbol': ' UNR',
#   'collision_group': [{'gene_symbol': 'CSDE1', 'ensg_id': 'ENSG00000009307'},
#    {'gene_symbol': ' P2RY4', 'ensg_id': 'ENSG00000186912'},
#    {'gene_symbol': ' NR1H2', 'ensg_id': 'ENSG00000131408'}]},
#  {'collision_symbol': ' Stv1',
#   'collision_group': [{'gene_symbol': 'ATP6V0A4',
#     'ensg_id': 'ENSG00000105929'},
#    {'gene_symbol': ' ATP6V0A2', 'ensg_id': 'ENSG00000185344'},
#    {'gene_symbol': ' ATP6V0A1', 'ensg_id': 'ENSG00000033627'}]},
#  {'collision_symbol': 'OF',
#   'collision_group': [{'gene_symbol': 'TAF1', 'ensg_id': 'ENSG00000147133'},
#    {'gene_symbol': ' BRIP1', 'ensg_id': 'ENSG00000136492'},
#    {'gene_symbol': ' SPI1', 'ensg_id': 'ENSG00000066336'}]},
#  {'collision_symbol': 'PMI',
#   'collision_group': [{'gene_symbol': 'MPI', 'ensg_id': 'ENSG00000178802'},
#    {'gene_symbol': ' TMEM11', 'ensg_id': 'ENSG00000178307'},
#    {'gene_symbol': ' PMM2', 'ensg_id': 'ENSG00000140650'}]},
#  {'collision_symbol': 'E3',
#   'collision_group': [{'gene_symbol': 'DLD', 'ensg_id': 'ENSG00000091140'},
#    {'gene_symbol': ' ALDH9A1', 'ensg_id': 'ENSG00000143149'},
#    {'gene_symbol': ' SNORA63', 'ensg_id': 'ENSG00000200320'}]},
#  {'collision_symbol': ' p75',
#   'collision_group': [{'gene_symbol': 'TCF3', 'ensg_id': 'ENSG00000071564'},
#    {'gene_symbol': ' TNFRSF1B', 'ensg_id': 'ENSG00000028137'},
#    {'gene_symbol': ' PSIP1', 'ensg_id': 'ENSG00000164985'}]},
#  {'collision_symbol': 'NBP',
#   'collision_group': [{'gene_symbol': 'TP63', 'ensg_id': 'ENSG00000073282'},
#    {'gene_symbol': ' NUBP1', 'ensg_id': 'ENSG00000103274'},
#    {'gene_symbol': ' COASY', 'ensg_id': 'ENSG00000068120'}]},
#  {'collision_symbol': ' p8',
#   'collision_group': [{'gene_symbol': 'EXOSC7', 'ensg_id': 'ENSG00000075914'},
#    {'gene_symbol': ' NUPR1', 'ensg_id': 'ENSG00000176046'},
#    {'gene_symbol': ' CMC4', 'ensg_id': 'ENSG00000182712'}]},
#  {'collision_symbol': 'ESO1',
#   'collision_group': [{'gene_symbol': 'ESCO1', 'ensg_id': 'ENSG00000141446'},
#    {'gene_symbol': ' CTAG1B', 'ensg_id': 'ENSG00000184033'},
#    {'gene_symbol': ' CTAG1A', 'ensg_id': 'ENSG00000268651'}]},
#  {'collision_symbol': 'H4',
#   'collision_group': [{'gene_symbol': 'CCDC6', 'ensg_id': 'ENSG00000108091'},
#    {'gene_symbol': ' H4C6', 'ensg_id': 'ENSG00000274618'},
#    {'gene_symbol': ' FGFR1', 'ensg_id': 'ENSG00000077782'}]},
#  {'collision_symbol': ' p85',
#   'collision_group': [{'gene_symbol': 'PIK3R1', 'ensg_id': 'ENSG00000145675'},
#    {'gene_symbol': ' PPP1R13B', 'ensg_id': 'ENSG00000088808'},
#    {'gene_symbol': ' PPP1R12C', 'ensg_id': 'ENSG00000125503'}]},
#  {'collision_symbol': 'H5',
#   'collision_group': [{'gene_symbol': 'SEPTIN5', 'ensg_id': 'ENSG00000184702'},
#    {'gene_symbol': ' SEPTIN4', 'ensg_id': 'ENSG00000108387'},
#    {'gene_symbol': ' FGFR1', 'ensg_id': 'ENSG00000077782'}]},
#  {'collision_symbol': 'MT2',
#   'collision_group': [{'gene_symbol': 'MT2A', 'ensg_id': 'ENSG00000125148'},
#    {'gene_symbol': ' TMPRSS6', 'ensg_id': 'ENSG00000187045'},
#    {'gene_symbol': ' MTNR1B', 'ensg_id': 'ENSG00000134640'}]},
#  {'collision_symbol': 'LGS',
#   'collision_group': [{'gene_symbol': 'LGSN', 'ensg_id': 'ENSG00000146166'},
#    {'gene_symbol': ' BCL9', 'ensg_id': 'ENSG00000116128'},
#    {'gene_symbol': ' EXT1', 'ensg_id': 'ENSG00000182197'}]},
#  {'collision_symbol': 'E2',
#   'collision_group': [{'gene_symbol': 'CST12P', 'ensg_id': 'ENSG00000226344'},
#    {'gene_symbol': ' DLAT', 'ensg_id': 'ENSG00000150768'},
#    {'gene_symbol': ' SNORA62', 'ensg_id': 'ENSG00000202363'}]},
#  {'collision_symbol': 'P28',
#   'collision_group': [{'gene_symbol': 'DNALI1', 'ensg_id': 'ENSG00000163879'},
#    {'gene_symbol': ' GSTO1', 'ensg_id': 'ENSG00000148834'},
#    {'gene_symbol': ' GOSR1', 'ensg_id': 'ENSG00000108587'}]},
#  {'collision_symbol': ' NET1',
#   'collision_group': [{'gene_symbol': 'PRPF38B', 'ensg_id': 'ENSG00000134186'},
#    {'gene_symbol': ' SLC6A5', 'ensg_id': 'ENSG00000165970'},
#    {'gene_symbol': ' SLC6A2', 'ensg_id': 'ENSG00000103546'}]},
#  {'collision_symbol': ' p120',
#   'collision_group': [{'gene_symbol': 'RASA1', 'ensg_id': 'ENSG00000145715'},
#    {'gene_symbol': ' CTNND1', 'ensg_id': 'ENSG00000198561'},
#    {'gene_symbol': ' NOP2', 'ensg_id': 'ENSG00000111641'}]},
#  {'collision_symbol': 'H1',
#   'collision_group': [{'gene_symbol': 'RLN1', 'ensg_id': 'ENSG00000107018'},
#    {'gene_symbol': ' CLIC4', 'ensg_id': 'ENSG00000169504'},
#    {'gene_symbol': ' VPS45', 'ensg_id': 'ENSG00000136631'}]},
#  {'collision_symbol': 'PSA',
#   'collision_group': [{'gene_symbol': 'KLK3', 'ensg_id': 'ENSG00000142515'},
#    {'gene_symbol': ' PSAT1', 'ensg_id': 'ENSG00000135069'},
#    {'gene_symbol': ' NPEPPS', 'ensg_id': 'ENSG00000141279'}]},
#  {'collision_symbol': ' p50',
#   'collision_group': [{'gene_symbol': 'CD40', 'ensg_id': 'ENSG00000101017'},
#    {'gene_symbol': ' NFKB1', 'ensg_id': 'ENSG00000109320'},
#    {'gene_symbol': ' ASCC1', 'ensg_id': 'ENSG00000138303'}]},
#  {'collision_symbol': 'A2',
#   'collision_group': [{'gene_symbol': 'GPHA2', 'ensg_id': 'ENSG00000149735'},
#    {'gene_symbol': ' SGCA', 'ensg_id': 'ENSG00000108823'},
#    {'gene_symbol': ' CFAP410', 'ensg_id': 'ENSG00000160226'}]},
#  {'collision_symbol': 'HPS',
#   'collision_group': [{'gene_symbol': 'HPS1', 'ensg_id': 'ENSG00000107521'},
#    {'gene_symbol': ' AP3B1', 'ensg_id': 'ENSG00000132842'},
#    {'gene_symbol': ' FGL1', 'ensg_id': 'ENSG00000104760'}]},
#  {'collision_symbol': 'MRP8',
#   'collision_group': [{'gene_symbol': 'S100A8', 'ensg_id': 'ENSG00000143546'},
#    {'gene_symbol': ' ABCC11', 'ensg_id': 'ENSG00000121270'},
#    {'gene_symbol': ' ABCC8', 'ensg_id': 'ENSG00000006071'}]},
#  {'collision_symbol': 'PAC1',
#   'collision_group': [{'gene_symbol': 'PSMG1', 'ensg_id': 'ENSG00000183527'},
#    {'gene_symbol': ' KLF6', 'ensg_id': 'ENSG00000067082'},
#    {'gene_symbol': ' ADCYAP1R1', 'ensg_id': 'ENSG00000078549'}]},
#  {'collision_symbol': 'PGI',
#   'collision_group': [{'gene_symbol': 'BGN', 'ensg_id': 'ENSG00000182492'},
#    {'gene_symbol': ' PGPEP1', 'ensg_id': 'ENSG00000130517'},
#    {'gene_symbol': ' GPI', 'ensg_id': 'ENSG00000105220'}]},
#  {'collision_symbol': ' p55',
#   'collision_group': [{'gene_symbol': 'H3P44', 'ensg_id': 'ENSG00000226881'},
#    {'gene_symbol': ' ERG', 'ensg_id': 'ENSG00000157554'},
#    {'gene_symbol': ' FSCN1', 'ensg_id': 'ENSG00000075618'}]},
#  {'collision_symbol': ' MU',
#   'collision_group': [{'gene_symbol': 'BLOC1S5', 'ensg_id': 'ENSG00000188428'},
#    {'gene_symbol': ' GSTM1', 'ensg_id': 'ENSG00000134184'},
#    {'gene_symbol': ' PSMA2', 'ensg_id': 'ENSG00000106588'}]},
#  {'collision_symbol': 'PGR1',
#   'collision_group': [{'gene_symbol': 'GPR153', 'ensg_id': 'ENSG00000158292'},
#    {'gene_symbol': ' PTGR1', 'ensg_id': 'ENSG00000106853'},
#    {'gene_symbol': ' MRFAP1', 'ensg_id': 'ENSG00000179010'}]},
#  {'collision_symbol': 'MRP2',
#   'collision_group': [{'gene_symbol': 'SYCE1L', 'ensg_id': 'ENSG00000205078'},
#    {'gene_symbol': ' ABCC2', 'ensg_id': 'ENSG00000023839'},
#    {'gene_symbol': ' KLHL1', 'ensg_id': 'ENSG00000150361'}]},
#  {'collision_symbol': 'MRP1',
#   'collision_group': [{'gene_symbol': 'ABCC1', 'ensg_id': 'ENSG00000103222'},
#    {'gene_symbol': ' MDM4', 'ensg_id': 'ENSG00000198625'},
#    {'gene_symbol': ' MSH3', 'ensg_id': 'ENSG00000113318'}]},
#  {'collision_symbol': 'IBP',
#   'collision_group': [{'gene_symbol': 'DEF6', 'ensg_id': 'ENSG00000023892'},
#    {'gene_symbol': ' TSPO', 'ensg_id': 'ENSG00000100300'},
#    {'gene_symbol': ' TRAPPC9', 'ensg_id': 'ENSG00000167632'}]},
#  {'collision_symbol': 'AT1',
#   'collision_group': [{'gene_symbol': 'PGR-AS1', 'ensg_id': 'ENSG00000282728'},
#    {'gene_symbol': ' SLC33A1', 'ensg_id': 'ENSG00000169359'},
#    {'gene_symbol': ' AGTR1', 'ensg_id': 'ENSG00000144891'}]},
#  {'collision_symbol': 'A1',
#   'collision_group': [{'gene_symbol': 'RFC1', 'ensg_id': 'ENSG00000035928'},
#    {'gene_symbol': ' RFC4', 'ensg_id': 'ENSG00000163918'},
#    {'gene_symbol': ' RFC2', 'ensg_id': 'ENSG00000049541'}]},
#  {'collision_symbol': 'ESG',
#   'collision_group': [{'gene_symbol': 'TLE1', 'ensg_id': 'ENSG00000196781'},
#    {'gene_symbol': ' TLE3', 'ensg_id': 'ENSG00000140332'},
#    {'gene_symbol': ' TLE2', 'ensg_id': 'ENSG00000065717'}]},
#  ...]
