# %%
import pandas as pd
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import pandas as pd
#       2 import numpy as np
#
# ModuleNotFoundError: No module named 'pandas'

# %%
def remove_nan_from_set(s):
    """Remove null instances from set
    
    :param s: selected set
    :return: set with no null values
    """
    return {x for x in s if pd.notna(x)}

# %%
def read_subset_genes_csv(location, source= str):
    """Create a df of primary gene symbol- alias symbol pairs

    :param location: file location
    :param source: representation in the source of gene records
    return: a df of gene records
    """
    
    subset_genes_xxxx_df = pd.read_csv(
        location, index_col=[0],dtype={"NCBI_ID": str,"HGNC_ID":str})
    subset_genes_xxxx_df["source"] = str(source)
    subset_genes_xxxx_df['gene_symbol'] = subset_genes_xxxx_df['gene_symbol'].str.upper()
    subset_genes_xxxx_df['alias_symbol'] = subset_genes_xxxx_df['alias_symbol'].str.upper()
    return subset_genes_xxxx_df

# %%
def make_col_ortholog_match(recording_df, source_df, animal= str):
    """Check for ortholog matches in the primary gene symbol- alias symbol pairs. 
    Adds a T/F column for each pair. T if the alias is an ortholog from the specified animal and F if not

    :param recording_df: df that contains the primary gene symbol- alias symbol pairs
    :param source_df: df that contains the orthologs and their associated human genes
    :param animal: the animal from with the orthologs are being checked
    return: the number of primary gene symbol- alias symbol pairs where the alias is an ortholog from the specified animal
    """
    
    recording_df[f'{animal} Match'] = recording_df.apply(lambda row: 
                            any((source_df['Gene name'] == row['gene_symbol']) 
                                & 
                                (source_df[f'{animal} gene name'] == row['alias_symbol'])), axis=1)
    animal_df = recording_df[recording_df[f'{animal} Match']]
    return len(animal_df)

# %% [markdown]
# ## Download gene records from ENSG, HGNC, and NCBI

# %% [markdown]
# #### This subset file was created in the alias-primary collision analysis notebook by the following modifications:
#  - Gene records with no aliases were removed.
#  - Primary gene symbol- alias symbol pairs where the alias was an exact match to the primary symbol were removed.
#  - Primary gene symbol- alias symbol pairs that were duplicated were removed.

# %%
subset_genes_ensg_df = read_subset_genes_csv("created_files/subset_genes_ensg_df.csv", "ENSG")
subset_genes_hgnc_df = read_subset_genes_csv("created_files/subset_genes_hgnc_df.csv", "HGNC")
subset_genes_ncbi_df = read_subset_genes_csv("created_files/subset_genes_ncbi_df.csv", "NCBI")

# %% [markdown]
# ## Combine data from all sources

# %%
subset_genes_df = pd.concat([subset_genes_ensg_df, subset_genes_hgnc_df, subset_genes_ncbi_df], axis=0)
subset_genes_df
# Out:
#                 ENSG_ID gene_symbol alias_symbol HGNC_ID    NCBI_ID source
# 0       ENSG00000210049       MT-TF         MTTF    7481        NaN   ENSG
# 1       ENSG00000210049       MT-TF         TRNF    7481        NaN   ENSG
# 2       ENSG00000211459     MT-RNR1          12S    7470        NaN   ENSG
# 3       ENSG00000211459     MT-RNR1       MOTS-C    7470        NaN   ENSG
# 4       ENSG00000211459     MT-RNR1       MTRNR1    7470        NaN   ENSG
# ...                 ...         ...          ...     ...        ...    ...
# 190961              NaN       GLTC1         GLTC   56861  131840634   NCBI
# 193342              NaN  GABRA6-AS1        ARBAG   40248  132532400   NCBI
# 193377              NaN     LNCARGI         ARGI   56890  133395150   NCBI
# 193378              NaN       MLDHR         MP31   55481  133834869   NCBI
# 193378              NaN       MLDHR      PTENURF   55481  133834869   NCBI
#
# [175868 rows x 6 columns]

# %% [markdown]
# ## Group the associated data by primary gene symbol- alias symbol pairs

# %% [markdown]
# #### This will ensure that there are no duplicate primary gene symbol- alias symbol pairs as well as preserving in which sources these pairs occur

# %%
subset_genes_df = subset_genes_df.groupby(['gene_symbol',"alias_symbol"], as_index=False).agg({
    "HGNC_ID": lambda x: set(x),
    'ENSG_ID': lambda x: set(x),
    'NCBI_ID': lambda x: set(x),
    "source": lambda x: set(x)
})
subset_genes_df
# Out:
#       gene_symbol  alias_symbol  HGNC_ID            ENSG_ID      NCBI_ID  \
# 0      A-GAMMA3'E     A-GAMMA-E    {nan}              {nan}  {109951028}
# 1            A1BG           A1B      {5}  {ENSG00000121410}          {1}
# 2            A1BG           ABG      {5}  {ENSG00000121410}          {1}
# 3            A1BG           GAB      {5}  {ENSG00000121410}          {1}
# 4            A1BG      HYST2477      {5}  {ENSG00000121410}          {1}
# ...           ...           ...      ...                ...          ...
# 86768       ZZEF1      FLJ10821  {29027}  {ENSG00000074755}      {23140}
# 86769       ZZEF1      KIAA0399  {29027}  {ENSG00000074755}      {23140}
# 86770       ZZEF1          ZZZ4  {29027}  {ENSG00000074755}      {23140}
# 86771        ZZZ3         ATAC1  {24523}  {ENSG00000036549}      {26009}
# 86772        ZZZ3  DKFZP564I052  {24523}  {ENSG00000036549}      {26009}
#
#                    source
# 0                  {NCBI}
# 1                  {NCBI}
# 2                  {NCBI}
# 3                  {NCBI}
# 4                  {NCBI}
# ...                   ...
# 86768        {HGNC, ENSG}
# 86769        {HGNC, ENSG}
# 86770  {HGNC, ENSG, NCBI}
# 86771  {HGNC, ENSG, NCBI}
# 86772        {HGNC, ENSG}
#
# [86773 rows x 6 columns]

# %%
subset_genes_df['NCBI_ID'] = subset_genes_df['NCBI_ID'].apply(remove_nan_from_set)
subset_genes_df['ENSG_ID'] = subset_genes_df['ENSG_ID'].apply(remove_nan_from_set)
subset_genes_df['HGNC_ID'] = subset_genes_df['HGNC_ID'].apply(remove_nan_from_set)

# %% [markdown]
# # Ortholog Analysis

# %% [markdown]
# ## Download an Ensembl Biomart export file with the Gene Name and the Ortholog Gene Name

# %%
mur_dros_ortho_df = pd.read_csv(
    "downloaded_files/ensg_mart_export_dros_murin_ortho.txt", sep=",", index_col=[0])
mur_dros_ortho_df
# Out:
#                 Drosophila melanogaster (Fruit fly) gene name  \
# Gene stable ID
# ENSG00000210049                                           NaN
# ENSG00000211459                                           NaN
# ENSG00000210077                                           NaN
# ENSG00000210082                                           NaN
# ENSG00000209082                                           NaN
# ...                                                       ...
# ENSG00000232679                                           NaN
# ENSG00000200033                                           NaN
# ENSG00000228437                                           NaN
# ENSG00000229463                                           NaN
# ENSG00000229291                                           NaN
#
#                 Drosophila melanogaster (Fruit fly) gene stable ID  \
# Gene stable ID
# ENSG00000210049                                                NaN
# ENSG00000211459                                                NaN
# ENSG00000210077                                                NaN
# ENSG00000210082                                                NaN
# ENSG00000209082                                                NaN
# ...                                                            ...
# ENSG00000232679                                                NaN
# ENSG00000200033                                                NaN
# ENSG00000228437                                                NaN
# ENSG00000229463                                                NaN
# ENSG00000229291                                                NaN
#
#                 Mouse gene stable ID Mouse gene name  Gene name
# Gene stable ID
# ENSG00000210049                  NaN             NaN      MT-TF
# ENSG00000211459                  NaN             NaN    MT-RNR1
# ENSG00000210077                  NaN             NaN      MT-TV
# ENSG00000210082                  NaN             NaN    MT-RNR2
# ENSG00000209082                  NaN             NaN     MT-TL1
# ...                              ...             ...        ...
# ENSG00000232679                  NaN             NaN  LINC01705
# ENSG00000200033   ENSMUSG00000088001         Gm22883  RNU6-403P
# ENSG00000228437                  NaN             NaN  LINC02474
# ENSG00000229463                  NaN             NaN   LYST-AS1
# ENSG00000229291                  NaN             NaN  LINC02768
#
# [91822 rows x 5 columns]

# %% [markdown]
# ## Make all of the gene symbols all caps

# %% [markdown]
# Different species follow different gene nomenclature conventions. <br>
# For example, mouse genes have the first letter capitalized but the rest lowercase.<br>
# They need to be all caps for matching

# %%
mur_dros_ortho_df["Gene name"] = mur_dros_ortho_df["Gene name"].str.upper()
mur_dros_ortho_df["Drosophila melanogaster (Fruit fly) gene name"] = mur_dros_ortho_df["Drosophila melanogaster (Fruit fly) gene name"].str.upper()
mur_dros_ortho_df["Mouse gene name"] = mur_dros_ortho_df["Mouse gene name"].str.upper()

# %% [markdown]
# ## Match aliases to orthologs!

# %% [markdown]
# ### Drosophila melanogaster

# %%
ortholog_match_subset_genes_df = subset_genes_df.copy()

# %%
make_col_ortholog_match(ortholog_match_subset_genes_df, mur_dros_ortho_df,"Drosophila melanogaster (Fruit fly)")

# %% [markdown]
# ### Mouse

# %%
make_col_ortholog_match(ortholog_match_subset_genes_df, mur_dros_ortho_df,"Mouse")

# %%
ortholog_match_subset_genes_df[(ortholog_match_subset_genes_df['DM Match']) & (ortholog_match_subset_genes_df['Mouse Match'])]
# Out:
#       gene_symbol alias_symbol  HGNC_ID            ENSG_ID   NCBI_ID  \
# 9418        CCZ1B         CCZ1  {21717}  {ENSG00000146574}  {221960}
# 18951      EIF1AX        EIF1A   {3250}  {ENSG00000173674}    {1964}
# 59611       RAB7A         RAB7   {9788}  {ENSG00000075785}    {7879}
#
#              source  DM Match  Mouse Match
# 9418         {NCBI}      True         True
# 18951  {ENSG, NCBI}      True         True
# 59611  {ENSG, NCBI}      True         True

# %% [markdown]
# ## Abingdon Island Giant Tortoise

# %%
tortoise_ostrich_amouse_ortho_df = pd.read_csv(
    "downloaded_files/tortoise_ostrich_amouse_export.txt", sep=",")
# Out:
#        Gene name Abingdon island giant tortoise gene name  \
# 0          MT-TF                                      NaN
# 1        MT-RNR1                                      NaN
# 2          MT-TV                                      NaN
# 3        MT-RNR2                                      NaN
# 4         MT-TL1                                      NaN
# ...          ...                                      ...
# 87088  LINC01705                                      NaN
# 87089  RNU6-403P                                      NaN
# 87090  LINC02474                                      NaN
# 87091   LYST-AS1                                      NaN
# 87092  LINC02768                                      NaN
#
#       African ostrich gene name Algerian mouse gene name
# 0                           NaN                      NaN
# 1                           NaN                      NaN
# 2                           NaN                      NaN
# 3                           NaN                      NaN
# 4                           NaN                      NaN
# ...                         ...                      ...
# 87088                       NaN                      NaN
# 87089                       NaN                  Gm22883
# 87090                       NaN                      NaN
# 87091                       NaN                      NaN
# 87092                       NaN                      NaN
#
# [87093 rows x 4 columns]

# %%
tortoise_ostrich_amouse_ortho_df["Gene name"] = tortoise_ostrich_amouse_ortho_df["Gene name"].str.upper()
tortoise_ostrich_amouse_ortho_df["Abingdon island giant tortoise gene name"] = tortoise_ostrich_amouse_ortho_df["Abingdon island giant tortoise gene name"].str.upper()
tortoise_ostrich_amouse_ortho_df["African ostrich gene name"] = tortoise_ostrich_amouse_ortho_df["African ostrich gene name"].str.upper()
tortoise_ostrich_amouse_ortho_df["Algerian mouse gene name"] = tortoise_ostrich_amouse_ortho_df["Algerian mouse gene name"].str.upper()

# %%
make_col_ortholog_match(ortholog_match_subset_genes_df, tortoise_ostrich_amouse_ortho_df,"Abingdon island giant tortoise")
# Out:
#       gene_symbol  alias_symbol  HGNC_ID            ENSG_ID      NCBI_ID  \
# 0      A-GAMMA3'E     A-GAMMA-E       {}                 {}  {109951028}
# 1            A1BG           A1B      {5}  {ENSG00000121410}          {1}
# 2            A1BG           ABG      {5}  {ENSG00000121410}          {1}
# 3            A1BG           GAB      {5}  {ENSG00000121410}          {1}
# 4            A1BG      HYST2477      {5}  {ENSG00000121410}          {1}
# ...           ...           ...      ...                ...          ...
# 86768       ZZEF1      FLJ10821  {29027}  {ENSG00000074755}      {23140}
# 86769       ZZEF1      KIAA0399  {29027}  {ENSG00000074755}      {23140}
# 86770       ZZEF1          ZZZ4  {29027}  {ENSG00000074755}      {23140}
# 86771        ZZZ3         ATAC1  {24523}  {ENSG00000036549}      {26009}
# 86772        ZZZ3  DKFZP564I052  {24523}  {ENSG00000036549}      {26009}
#
#                    source  DM Match  Mouse Match  \
# 0                  {NCBI}     False        False
# 1                  {NCBI}     False        False
# 2                  {NCBI}     False        False
# 3                  {NCBI}     False        False
# 4                  {NCBI}     False        False
# ...                   ...       ...          ...
# 86768        {HGNC, ENSG}     False        False
# 86769        {HGNC, ENSG}     False        False
# 86770  {HGNC, ENSG, NCBI}     False        False
# 86771  {HGNC, ENSG, NCBI}      True        False
# 86772        {HGNC, ENSG}     False        False
#
#        Abingdon island giant tortoise Match
# 0                                     False
# 1                                     False
# 2                                     False
# 3                                     False
# 4                                     False
# ...                                     ...
# 86768                                 False
# 86769                                 False
# 86770                                 False
# 86771                                 False
# 86772                                 False
#
# [86773 rows x 9 columns]

# %% [markdown]
# ## African Ostrich

# %%
make_col_ortholog_match(ortholog_match_subset_genes_df, tortoise_ostrich_amouse_ortho_df,"African ostrich")
# Out:
#       gene_symbol  alias_symbol  HGNC_ID            ENSG_ID      NCBI_ID  \
# 0      A-GAMMA3'E     A-GAMMA-E       {}                 {}  {109951028}
# 1            A1BG           A1B      {5}  {ENSG00000121410}          {1}
# 2            A1BG           ABG      {5}  {ENSG00000121410}          {1}
# 3            A1BG           GAB      {5}  {ENSG00000121410}          {1}
# 4            A1BG      HYST2477      {5}  {ENSG00000121410}          {1}
# ...           ...           ...      ...                ...          ...
# 86768       ZZEF1      FLJ10821  {29027}  {ENSG00000074755}      {23140}
# 86769       ZZEF1      KIAA0399  {29027}  {ENSG00000074755}      {23140}
# 86770       ZZEF1          ZZZ4  {29027}  {ENSG00000074755}      {23140}
# 86771        ZZZ3         ATAC1  {24523}  {ENSG00000036549}      {26009}
# 86772        ZZZ3  DKFZP564I052  {24523}  {ENSG00000036549}      {26009}
#
#                    source  DM Match  Mouse Match  \
# 0                  {NCBI}     False        False
# 1                  {NCBI}     False        False
# 2                  {NCBI}     False        False
# 3                  {NCBI}     False        False
# 4                  {NCBI}     False        False
# ...                   ...       ...          ...
# 86768        {HGNC, ENSG}     False        False
# 86769        {HGNC, ENSG}     False        False
# 86770  {HGNC, ENSG, NCBI}     False        False
# 86771  {HGNC, ENSG, NCBI}      True        False
# 86772        {HGNC, ENSG}     False        False
#
#        Abingdon island giant tortoise Match  African ostrich Match
# 0                                     False                  False
# 1                                     False                  False
# 2                                     False                  False
# 3                                     False                  False
# 4                                     False                  False
# ...                                     ...                    ...
# 86768                                 False                  False
# 86769                                 False                  False
# 86770                                 False                  False
# 86771                                 False                  False
# 86772                                 False                  False
#
# [86773 rows x 10 columns]

# %% [markdown]
# ## Algerian Mouse

# %%
make_col_ortholog_match(ortholog_match_subset_genes_df, tortoise_ostrich_amouse_ortho_df,"Algerian mouse")
# Out:
#       gene_symbol  alias_symbol  HGNC_ID            ENSG_ID      NCBI_ID  \
# 0      A-GAMMA3'E     A-GAMMA-E       {}                 {}  {109951028}
# 1            A1BG           A1B      {5}  {ENSG00000121410}          {1}
# 2            A1BG           ABG      {5}  {ENSG00000121410}          {1}
# 3            A1BG           GAB      {5}  {ENSG00000121410}          {1}
# 4            A1BG      HYST2477      {5}  {ENSG00000121410}          {1}
# ...           ...           ...      ...                ...          ...
# 86768       ZZEF1      FLJ10821  {29027}  {ENSG00000074755}      {23140}
# 86769       ZZEF1      KIAA0399  {29027}  {ENSG00000074755}      {23140}
# 86770       ZZEF1          ZZZ4  {29027}  {ENSG00000074755}      {23140}
# 86771        ZZZ3         ATAC1  {24523}  {ENSG00000036549}      {26009}
# 86772        ZZZ3  DKFZP564I052  {24523}  {ENSG00000036549}      {26009}
#
#                    source  DM Match  Mouse Match  \
# 0                  {NCBI}     False        False
# 1                  {NCBI}     False        False
# 2                  {NCBI}     False        False
# 3                  {NCBI}     False        False
# 4                  {NCBI}     False        False
# ...                   ...       ...          ...
# 86768        {HGNC, ENSG}     False        False
# 86769        {HGNC, ENSG}     False        False
# 86770  {HGNC, ENSG, NCBI}     False        False
# 86771  {HGNC, ENSG, NCBI}      True        False
# 86772        {HGNC, ENSG}     False        False
#
#        Abingdon island giant tortoise Match  African ostrich Match  \
# 0                                     False                  False
# 1                                     False                  False
# 2                                     False                  False
# 3                                     False                  False
# 4                                     False                  False
# ...                                     ...                    ...
# 86768                                 False                  False
# 86769                                 False                  False
# 86770                                 False                  False
# 86771                                 False                  False
# 86772                                 False                  False
#
#        Algerian mouse Match
# 0                     False
# 1                     False
# 2                     False
# 3                     False
# 4                     False
# ...                     ...
# 86768                 False
# 86769                 False
# 86770                 False
# 86771                 False
# 86772                 False
#
# [86773 rows x 11 columns]

# %% [markdown]
# ## Alpaca

# %%
Alpaca_Amarmot_Amolly_Abison_Ablackbear_ortho_df = pd.read_csv(
    "downloaded_files/Alpaca_Amarmot_Amolly_Abison_Ablackbear_mart_export.txt", sep=",")
# Out:
#         Gene name Alpaca gene name Alpine marmot gene name  \
# 0           MT-TF              NaN                     NaN
# 1         MT-RNR1              NaN                     NaN
# 2           MT-TV              NaN                     NaN
# 3         MT-RNR2              NaN                     NaN
# 4          MT-TL1              NaN                     NaN
# ...           ...              ...                     ...
# 111858  LINC01705              NaN                     NaN
# 111859  RNU6-403P              NaN                     NaN
# 111860  LINC02474              NaN                     NaN
# 111861   LYST-AS1              NaN                     NaN
# 111862  LINC02768              NaN                     NaN
#
#        Amazon molly gene name American bison gene name  \
# 0                         NaN                      NaN
# 1                         NaN                      NaN
# 2                         NaN                      NaN
# 3                         NaN                      NaN
# 4                         NaN                      NaN
# ...                       ...                      ...
# 111858                    NaN                      NaN
# 111859                    NaN                      NaN
# 111860                    NaN                      NaN
# 111861                    NaN                      NaN
# 111862                    NaN                      NaN
#
#        American black bear gene name
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# ...                              ...
# 111858                           NaN
# 111859                           NaN
# 111860                           NaN
# 111861                           NaN
# 111862                           NaN
#
# [111863 rows x 6 columns]

# %%
Alpaca_Amarmot_Amolly_Abison_Ablackbear_ortho_df["Gene name"] = Alpaca_Amarmot_Amolly_Abison_Ablackbear_ortho_df["Gene name"].str.upper()
Alpaca_Amarmot_Amolly_Abison_Ablackbear_ortho_df["Alpaca gene name"] = Alpaca_Amarmot_Amolly_Abison_Ablackbear_ortho_df["Alpaca gene name"].str.upper()
Alpaca_Amarmot_Amolly_Abison_Ablackbear_ortho_df["Alpine marmot gene name"] = Alpaca_Amarmot_Amolly_Abison_Ablackbear_ortho_df["Alpine marmot gene name"].str.upper()
Alpaca_Amarmot_Amolly_Abison_Ablackbear_ortho_df["Amazon molly gene name"] = Alpaca_Amarmot_Amolly_Abison_Ablackbear_ortho_df["Amazon molly gene name"].str.upper()
Alpaca_Amarmot_Amolly_Abison_Ablackbear_ortho_df["American bison gene name"] = Alpaca_Amarmot_Amolly_Abison_Ablackbear_ortho_df["American bison gene name"].str.upper()
Alpaca_Amarmot_Amolly_Abison_Ablackbear_ortho_df["American black bear gene name"] = Alpaca_Amarmot_Amolly_Abison_Ablackbear_ortho_df["American black bear gene name"].str.upper()

# %%
make_col_ortholog_match(ortholog_match_subset_genes_df, Alpaca_Amarmot_Amolly_Abison_Ablackbear_ortho_df,"Alpaca")
# Out:
#       gene_symbol  alias_symbol  HGNC_ID            ENSG_ID      NCBI_ID  \
# 0      A-GAMMA3'E     A-GAMMA-E       {}                 {}  {109951028}
# 1            A1BG           A1B      {5}  {ENSG00000121410}          {1}
# 2            A1BG           ABG      {5}  {ENSG00000121410}          {1}
# 3            A1BG           GAB      {5}  {ENSG00000121410}          {1}
# 4            A1BG      HYST2477      {5}  {ENSG00000121410}          {1}
# ...           ...           ...      ...                ...          ...
# 86768       ZZEF1      FLJ10821  {29027}  {ENSG00000074755}      {23140}
# 86769       ZZEF1      KIAA0399  {29027}  {ENSG00000074755}      {23140}
# 86770       ZZEF1          ZZZ4  {29027}  {ENSG00000074755}      {23140}
# 86771        ZZZ3         ATAC1  {24523}  {ENSG00000036549}      {26009}
# 86772        ZZZ3  DKFZP564I052  {24523}  {ENSG00000036549}      {26009}
#
#                    source  DM Match  Mouse Match  \
# 0                  {NCBI}     False        False
# 1                  {NCBI}     False        False
# 2                  {NCBI}     False        False
# 3                  {NCBI}     False        False
# 4                  {NCBI}     False        False
# ...                   ...       ...          ...
# 86768        {HGNC, ENSG}     False        False
# 86769        {HGNC, ENSG}     False        False
# 86770  {HGNC, ENSG, NCBI}     False        False
# 86771  {HGNC, ENSG, NCBI}      True        False
# 86772        {HGNC, ENSG}     False        False
#
#        Abingdon island giant tortoise Match  African ostrich Match  \
# 0                                     False                  False
# 1                                     False                  False
# 2                                     False                  False
# 3                                     False                  False
# 4                                     False                  False
# ...                                     ...                    ...
# 86768                                 False                  False
# 86769                                 False                  False
# 86770                                 False                  False
# 86771                                 False                  False
# 86772                                 False                  False
#
#        Algerian mouse Match  Alpaca Match
# 0                     False         False
# 1                     False         False
# 2                     False         False
# 3                     False         False
# 4                     False         False
# ...                     ...           ...
# 86768                 False         False
# 86769                 False         False
# 86770                 False         False
# 86771                 False         False
# 86772                 False         False
#
# [86773 rows x 12 columns]

# %% [markdown]
# ## Alpine Marmot

# %%
make_col_ortholog_match(ortholog_match_subset_genes_df, Alpaca_Amarmot_Amolly_Abison_Ablackbear_ortho_df,"Alpine marmot")
# Out:
#       gene_symbol  alias_symbol  HGNC_ID            ENSG_ID      NCBI_ID  \
# 0      A-GAMMA3'E     A-GAMMA-E       {}                 {}  {109951028}
# 1            A1BG           A1B      {5}  {ENSG00000121410}          {1}
# 2            A1BG           ABG      {5}  {ENSG00000121410}          {1}
# 3            A1BG           GAB      {5}  {ENSG00000121410}          {1}
# 4            A1BG      HYST2477      {5}  {ENSG00000121410}          {1}
# ...           ...           ...      ...                ...          ...
# 86768       ZZEF1      FLJ10821  {29027}  {ENSG00000074755}      {23140}
# 86769       ZZEF1      KIAA0399  {29027}  {ENSG00000074755}      {23140}
# 86770       ZZEF1          ZZZ4  {29027}  {ENSG00000074755}      {23140}
# 86771        ZZZ3         ATAC1  {24523}  {ENSG00000036549}      {26009}
# 86772        ZZZ3  DKFZP564I052  {24523}  {ENSG00000036549}      {26009}
#
#                    source  DM Match  Mouse Match  \
# 0                  {NCBI}     False        False
# 1                  {NCBI}     False        False
# 2                  {NCBI}     False        False
# 3                  {NCBI}     False        False
# 4                  {NCBI}     False        False
# ...                   ...       ...          ...
# 86768        {HGNC, ENSG}     False        False
# 86769        {HGNC, ENSG}     False        False
# 86770  {HGNC, ENSG, NCBI}     False        False
# 86771  {HGNC, ENSG, NCBI}      True        False
# 86772        {HGNC, ENSG}     False        False
#
#        Abingdon island giant tortoise Match  African ostrich Match  \
# 0                                     False                  False
# 1                                     False                  False
# 2                                     False                  False
# 3                                     False                  False
# 4                                     False                  False
# ...                                     ...                    ...
# 86768                                 False                  False
# 86769                                 False                  False
# 86770                                 False                  False
# 86771                                 False                  False
# 86772                                 False                  False
#
#        Algerian mouse Match  Alpaca Match  Alpine marmot Match
# 0                     False         False                False
# 1                     False         False                False
# 2                     False         False                False
# 3                     False         False                False
# 4                     False         False                False
# ...                     ...           ...                  ...
# 86768                 False         False                False
# 86769                 False         False                False
# 86770                 False         False                False
# 86771                 False         False                False
# 86772                 False         False                False
#
# [86773 rows x 13 columns]

# %% [markdown]
# ## Amazon Molly

# %%
make_col_ortholog_match(ortholog_match_subset_genes_df, Alpaca_Amarmot_Amolly_Abison_Ablackbear_ortho_df,"Amazon molly")
subset_genes_df
# Out:
#       gene_symbol  alias_symbol  HGNC_ID            ENSG_ID      NCBI_ID  \
# 0      A-GAMMA3'E     A-GAMMA-E       {}                 {}  {109951028}
# 1            A1BG           A1B      {5}  {ENSG00000121410}          {1}
# 2            A1BG           ABG      {5}  {ENSG00000121410}          {1}
# 3            A1BG           GAB      {5}  {ENSG00000121410}          {1}
# 4            A1BG      HYST2477      {5}  {ENSG00000121410}          {1}
# ...           ...           ...      ...                ...          ...
# 86768       ZZEF1      FLJ10821  {29027}  {ENSG00000074755}      {23140}
# 86769       ZZEF1      KIAA0399  {29027}  {ENSG00000074755}      {23140}
# 86770       ZZEF1          ZZZ4  {29027}  {ENSG00000074755}      {23140}
# 86771        ZZZ3         ATAC1  {24523}  {ENSG00000036549}      {26009}
# 86772        ZZZ3  DKFZP564I052  {24523}  {ENSG00000036549}      {26009}
#
#                    source  DM Match  Mouse Match  \
# 0                  {NCBI}     False        False
# 1                  {NCBI}     False        False
# 2                  {NCBI}     False        False
# 3                  {NCBI}     False        False
# 4                  {NCBI}     False        False
# ...                   ...       ...          ...
# 86768        {HGNC, ENSG}     False        False
# 86769        {HGNC, ENSG}     False        False
# 86770  {HGNC, ENSG, NCBI}     False        False
# 86771  {HGNC, ENSG, NCBI}      True        False
# 86772        {HGNC, ENSG}     False        False
#
#        Abingdon island giant tortoise Match  African ostrich Match  \
# 0                                     False                  False
# 1                                     False                  False
# 2                                     False                  False
# 3                                     False                  False
# 4                                     False                  False
# ...                                     ...                    ...
# 86768                                 False                  False
# 86769                                 False                  False
# 86770                                 False                  False
# 86771                                 False                  False
# 86772                                 False                  False
#
#        Algerian mouse Match  Alpaca Match  Alpine marmot Match  \
# 0                     False         False                False
# 1                     False         False                False
# 2                     False         False                False
# 3                     False         False                False
# 4                     False         False                False
# ...                     ...           ...                  ...
# 86768                 False         False                False
# 86769                 False         False                False
# 86770                 False         False                False
# 86771                 False         False                False
# 86772                 False         False                False
#
#        Amazon molly Match
# 0                   False
# 1                   False
# 2                   False
# 3                   False
# 4                   False
# ...                   ...
# 86768               False
# 86769               False
# 86770               False
# 86771               False
# 86772               False
#
# [86773 rows x 14 columns]

# %% [markdown]
# ## American Bison

# %%
make_col_ortholog_match(ortholog_match_subset_genes_df, Alpaca_Amarmot_Amolly_Abison_Ablackbear_ortho_df,"American bison")
# Out:
#       gene_symbol  alias_symbol  HGNC_ID            ENSG_ID      NCBI_ID  \
# 0      A-GAMMA3'E     A-GAMMA-E       {}                 {}  {109951028}
# 1            A1BG           A1B      {5}  {ENSG00000121410}          {1}
# 2            A1BG           ABG      {5}  {ENSG00000121410}          {1}
# 3            A1BG           GAB      {5}  {ENSG00000121410}          {1}
# 4            A1BG      HYST2477      {5}  {ENSG00000121410}          {1}
# ...           ...           ...      ...                ...          ...
# 86768       ZZEF1      FLJ10821  {29027}  {ENSG00000074755}      {23140}
# 86769       ZZEF1      KIAA0399  {29027}  {ENSG00000074755}      {23140}
# 86770       ZZEF1          ZZZ4  {29027}  {ENSG00000074755}      {23140}
# 86771        ZZZ3         ATAC1  {24523}  {ENSG00000036549}      {26009}
# 86772        ZZZ3  DKFZP564I052  {24523}  {ENSG00000036549}      {26009}
#
#                    source  DM Match  Mouse Match  \
# 0                  {NCBI}     False        False
# 1                  {NCBI}     False        False
# 2                  {NCBI}     False        False
# 3                  {NCBI}     False        False
# 4                  {NCBI}     False        False
# ...                   ...       ...          ...
# 86768        {HGNC, ENSG}     False        False
# 86769        {HGNC, ENSG}     False        False
# 86770  {HGNC, ENSG, NCBI}     False        False
# 86771  {HGNC, ENSG, NCBI}      True        False
# 86772        {HGNC, ENSG}     False        False
#
#        Abingdon island giant tortoise Match  African ostrich Match  \
# 0                                     False                  False
# 1                                     False                  False
# 2                                     False                  False
# 3                                     False                  False
# 4                                     False                  False
# ...                                     ...                    ...
# 86768                                 False                  False
# 86769                                 False                  False
# 86770                                 False                  False
# 86771                                 False                  False
# 86772                                 False                  False
#
#        Algerian mouse Match  Alpaca Match  Alpine marmot Match  \
# 0                     False         False                False
# 1                     False         False                False
# 2                     False         False                False
# 3                     False         False                False
# 4                     False         False                False
# ...                     ...           ...                  ...
# 86768                 False         False                False
# 86769                 False         False                False
# 86770                 False         False                False
# 86771                 False         False                False
# 86772                 False         False                False
#
#        Amazon molly Match  American bison Match
# 0                   False                 False
# 1                   False                 False
# 2                   False                 False
# 3                   False                 False
# 4                   False                 False
# ...                   ...                   ...
# 86768               False                 False
# 86769               False                 False
# 86770               False                 False
# 86771               False                 False
# 86772               False                 False
#
# [86773 rows x 15 columns]

# %% [markdown]
# ## American Black Bear

# %%
make_col_ortholog_match(ortholog_match_subset_genes_df, Alpaca_Amarmot_Amolly_Abison_Ablackbear_ortho_df,"American black bear")
# Out:
#       gene_symbol  alias_symbol  HGNC_ID            ENSG_ID      NCBI_ID  \
# 0      A-GAMMA3'E     A-GAMMA-E       {}                 {}  {109951028}
# 1            A1BG           A1B      {5}  {ENSG00000121410}          {1}
# 2            A1BG           ABG      {5}  {ENSG00000121410}          {1}
# 3            A1BG           GAB      {5}  {ENSG00000121410}          {1}
# 4            A1BG      HYST2477      {5}  {ENSG00000121410}          {1}
# ...           ...           ...      ...                ...          ...
# 86768       ZZEF1      FLJ10821  {29027}  {ENSG00000074755}      {23140}
# 86769       ZZEF1      KIAA0399  {29027}  {ENSG00000074755}      {23140}
# 86770       ZZEF1          ZZZ4  {29027}  {ENSG00000074755}      {23140}
# 86771        ZZZ3         ATAC1  {24523}  {ENSG00000036549}      {26009}
# 86772        ZZZ3  DKFZP564I052  {24523}  {ENSG00000036549}      {26009}
#
#                    source  DM Match  Mouse Match  \
# 0                  {NCBI}     False        False
# 1                  {NCBI}     False        False
# 2                  {NCBI}     False        False
# 3                  {NCBI}     False        False
# 4                  {NCBI}     False        False
# ...                   ...       ...          ...
# 86768        {HGNC, ENSG}     False        False
# 86769        {HGNC, ENSG}     False        False
# 86770  {HGNC, ENSG, NCBI}     False        False
# 86771  {HGNC, ENSG, NCBI}      True        False
# 86772        {HGNC, ENSG}     False        False
#
#        Abingdon island giant tortoise Match  African ostrich Match  \
# 0                                     False                  False
# 1                                     False                  False
# 2                                     False                  False
# 3                                     False                  False
# 4                                     False                  False
# ...                                     ...                    ...
# 86768                                 False                  False
# 86769                                 False                  False
# 86770                                 False                  False
# 86771                                 False                  False
# 86772                                 False                  False
#
#        Algerian mouse Match  Alpaca Match  Alpine marmot Match  \
# 0                     False         False                False
# 1                     False         False                False
# 2                     False         False                False
# 3                     False         False                False
# 4                     False         False                False
# ...                     ...           ...                  ...
# 86768                 False         False                False
# 86769                 False         False                False
# 86770                 False         False                False
# 86771                 False         False                False
# 86772                 False         False                False
#
#        Amazon molly Match  American bison Match  American black bear Match
# 0                   False                 False                      False
# 1                   False                 False                      False
# 2                   False                 False                      False
# 3                   False                 False                      False
# 4                   False                 False                      False
# ...                   ...                   ...                        ...
# 86768               False                 False                      False
# 86769               False                 False                      False
# 86770               False                 False                      False
# 86771               False                 False                      False
# 86772               False                 False                      False
#
# [86773 rows x 16 columns]

# %% [markdown]
# ## American Mink

# %%
Americanmink_Arabiancamel_Arcticsquirrel_Argentinetegu_Armadillo_Asianbonytongue_ortho_df = pd.read_csv(
    "downloaded_files/Americanmink_Arabiancamel_Arcticsquirrel_Argentinetegu_Armadillo_Asianbonytongue.txt", sep="\t")
Americanmink_Arabiancamel_Arcticsquirrel_Argentinetegu_Armadillo_Asianbonytongue_ortho_df
# Out:
#         Gene name American mink gene name Arabian camel gene name  \
# 0           MT-TF                     NaN                     NaN
# 1         MT-RNR1                     NaN                     NaN
# 2           MT-TV                     NaN                     NaN
# 3         MT-RNR2                     NaN                     NaN
# 4          MT-TL1                     NaN                     NaN
# ...           ...                     ...                     ...
# 125912  LINC01705                     NaN                     NaN
# 125913  RNU6-403P                     NaN                     NaN
# 125914  LINC02474                     NaN                     NaN
# 125915   LYST-AS1                     NaN                     NaN
# 125916  LINC02768                     NaN                     NaN
#
#        Arctic ground squirrel gene name  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# ...                                 ...
# 125912                              NaN
# 125913                              NaN
# 125914                              NaN
# 125915                              NaN
# 125916                              NaN
#
#        Argentine black and white tegu gene name Armadillo gene name  \
# 0                                           NaN                 NaN
# 1                                           NaN                 NaN
# 2                                           NaN                 NaN
# 3                                           NaN                 NaN
# 4                                           NaN                 NaN
# ...                                         ...                 ...
# 125912                                      NaN                 NaN
# 125913                                      NaN                 NaN
# 125914                                      NaN                 NaN
# 125915                                      NaN                 NaN
# 125916                                      NaN                 NaN
#
#        Asian bonytongue gene name
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
# ...                           ...
# 125912                        NaN
# 125913                        NaN
# 125914                        NaN
# 125915                        NaN
# 125916                        NaN
#
# [125917 rows x 7 columns]

# %%
Americanmink_Arabiancamel_Arcticsquirrel_Argentinetegu_Armadillo_Asianbonytongue_ortho_df["Gene name"] = Americanmink_Arabiancamel_Arcticsquirrel_Argentinetegu_Armadillo_Asianbonytongue_ortho_df["Gene name"].str.upper()
Americanmink_Arabiancamel_Arcticsquirrel_Argentinetegu_Armadillo_Asianbonytongue_ortho_df["American mink gene name"] = Americanmink_Arabiancamel_Arcticsquirrel_Argentinetegu_Armadillo_Asianbonytongue_ortho_df["American mink gene name"].str.upper()
Americanmink_Arabiancamel_Arcticsquirrel_Argentinetegu_Armadillo_Asianbonytongue_ortho_df["Arabian camel gene name"] = Americanmink_Arabiancamel_Arcticsquirrel_Argentinetegu_Armadillo_Asianbonytongue_ortho_df["Arabian camel gene name"].str.upper()
Americanmink_Arabiancamel_Arcticsquirrel_Argentinetegu_Armadillo_Asianbonytongue_ortho_df["Arctic ground squirrel gene name"] = Americanmink_Arabiancamel_Arcticsquirrel_Argentinetegu_Armadillo_Asianbonytongue_ortho_df["Arctic ground squirrel gene name"].str.upper()
Americanmink_Arabiancamel_Arcticsquirrel_Argentinetegu_Armadillo_Asianbonytongue_ortho_df["Argentine black and white tegu gene name"] = Americanmink_Arabiancamel_Arcticsquirrel_Argentinetegu_Armadillo_Asianbonytongue_ortho_df["Argentine black and white tegu gene name"].str.upper()
Americanmink_Arabiancamel_Arcticsquirrel_Argentinetegu_Armadillo_Asianbonytongue_ortho_df["Armadillo gene name"] = Americanmink_Arabiancamel_Arcticsquirrel_Argentinetegu_Armadillo_Asianbonytongue_ortho_df["Armadillo gene name"].str.upper()
Americanmink_Arabiancamel_Arcticsquirrel_Argentinetegu_Armadillo_Asianbonytongue_ortho_df["Asian bonytongue gene name"] = Americanmink_Arabiancamel_Arcticsquirrel_Argentinetegu_Armadillo_Asianbonytongue_ortho_df["Asian bonytongue gene name"].str.upper()

# %%
make_col_ortholog_match(ortholog_match_subset_genes_df, Americanmink_Arabiancamel_Arcticsquirrel_Argentinetegu_Armadillo_Asianbonytongue_ortho_df,"American mink")
# Out:
#       gene_symbol  alias_symbol  HGNC_ID            ENSG_ID      NCBI_ID  \
# 0      A-GAMMA3'E     A-GAMMA-E       {}                 {}  {109951028}
# 1            A1BG           A1B      {5}  {ENSG00000121410}          {1}
# 2            A1BG           ABG      {5}  {ENSG00000121410}          {1}
# 3            A1BG           GAB      {5}  {ENSG00000121410}          {1}
# 4            A1BG      HYST2477      {5}  {ENSG00000121410}          {1}
# ...           ...           ...      ...                ...          ...
# 86768       ZZEF1      FLJ10821  {29027}  {ENSG00000074755}      {23140}
# 86769       ZZEF1      KIAA0399  {29027}  {ENSG00000074755}      {23140}
# 86770       ZZEF1          ZZZ4  {29027}  {ENSG00000074755}      {23140}
# 86771        ZZZ3         ATAC1  {24523}  {ENSG00000036549}      {26009}
# 86772        ZZZ3  DKFZP564I052  {24523}  {ENSG00000036549}      {26009}
#
#                    source  DM Match  Mouse Match  \
# 0                  {NCBI}     False        False
# 1                  {NCBI}     False        False
# 2                  {NCBI}     False        False
# 3                  {NCBI}     False        False
# 4                  {NCBI}     False        False
# ...                   ...       ...          ...
# 86768        {HGNC, ENSG}     False        False
# 86769        {HGNC, ENSG}     False        False
# 86770  {HGNC, ENSG, NCBI}     False        False
# 86771  {HGNC, ENSG, NCBI}      True        False
# 86772        {HGNC, ENSG}     False        False
#
#        Abingdon island giant tortoise Match  African ostrich Match  \
# 0                                     False                  False
# 1                                     False                  False
# 2                                     False                  False
# 3                                     False                  False
# 4                                     False                  False
# ...                                     ...                    ...
# 86768                                 False                  False
# 86769                                 False                  False
# 86770                                 False                  False
# 86771                                 False                  False
# 86772                                 False                  False
#
#        Algerian mouse Match  Alpaca Match  Alpine marmot Match  \
# 0                     False         False                False
# 1                     False         False                False
# 2                     False         False                False
# 3                     False         False                False
# 4                     False         False                False
# ...                     ...           ...                  ...
# 86768                 False         False                False
# 86769                 False         False                False
# 86770                 False         False                False
# 86771                 False         False                False
# 86772                 False         False                False
#
#        Amazon molly Match  American bison Match  American black bear Match  \
# 0                   False                 False                      False
# 1                   False                 False                      False
# 2                   False                 False                      False
# 3                   False                 False                      False
# 4                   False                 False                      False
# ...                   ...                   ...                        ...
# 86768               False                 False                      False
# 86769               False                 False                      False
# 86770               False                 False                      False
# 86771               False                 False                      False
# 86772               False                 False                      False
#
#        American mink Match
# 0                    False
# 1                    False
# 2                    False
# 3                    False
# 4                    False
# ...                    ...
# 86768                False
# 86769                False
# 86770                False
# 86771                False
# 86772                False
#
# [86773 rows x 17 columns]

# %% [markdown]
# ## Arabian Camel

# %%
make_col_ortholog_match(ortholog_match_subset_genes_df, Americanmink_Arabiancamel_Arcticsquirrel_Argentinetegu_Armadillo_Asianbonytongue_ortho_df,"Arabian camel")
# Out:
# 13

# %% [markdown]
# ## Arctic Ground Squirrel

# %%
make_col_ortholog_match(ortholog_match_subset_genes_df, Americanmink_Arabiancamel_Arcticsquirrel_Argentinetegu_Armadillo_Asianbonytongue_ortho_df,"Arctic ground squirrel")
# Out:
# 1

# %% [markdown]
# ## Argentine Black and White Tegu

# %%
make_col_ortholog_match(ortholog_match_subset_genes_df, Americanmink_Arabiancamel_Arcticsquirrel_Argentinetegu_Armadillo_Asianbonytongue_ortho_df,"Argentine black and white tegu")
# Out:
# 5

# %% [markdown]
# ## Armadillo

# %%
make_col_ortholog_match(ortholog_match_subset_genes_df, Americanmink_Arabiancamel_Arcticsquirrel_Argentinetegu_Armadillo_Asianbonytongue_ortho_df,"Armadillo")
# Out:
# 17

# %% [markdown]
# ## Asian Bonytongue

# %%
make_col_ortholog_match(ortholog_match_subset_genes_df, Americanmink_Arabiancamel_Arcticsquirrel_Argentinetegu_Armadillo_Asianbonytongue_ortho_df,"Asian bonytongue")
# Out:
# 91

# %% [markdown]
# ## Atlantic Cod

# %%
Atlanticcod_Atlanticherring_Atlanticsalmon_Australiancrocodile_Ballanwrasse_ortho_df = pd.read_csv(
    "downloaded_files/Atlanticcod_Atlanticherring_Atlanticsalmon_Australiancrocodile_Ballanwrasse.txt", sep=",")
Atlanticcod_Atlanticherring_Atlanticsalmon_Australiancrocodile_Ballanwrasse_ortho_df
# Out:
#         Gene name Barramundi perch gene name Beluga whale gene name  \
# 0           MT-TF                        NaN                    NaN
# 1         MT-RNR1                        NaN                    NaN
# 2           MT-TV                        NaN                    NaN
# 3         MT-RNR2                        NaN                    NaN
# 4          MT-TL1                        NaN                    NaN
# ...           ...                        ...                    ...
# 115851  LINC01705                        NaN                    NaN
# 115852  RNU6-403P                        NaN                    NaN
# 115853  LINC02474                        NaN                    NaN
# 115854   LYST-AS1                        NaN                    NaN
# 115855  LINC02768                        NaN                    NaN
#
#        Bicolor damselfish gene name Black snub-nosed monkey gene name  \
# 0                               NaN                               NaN
# 1                               NaN                               NaN
# 2                               NaN                               NaN
# 3                               NaN                               NaN
# 4                               NaN                               NaN
# ...                             ...                               ...
# 115851                          NaN                               NaN
# 115852                          NaN                               NaN
# 115853                          NaN                               NaN
# 115854                          NaN                               NaN
# 115855                          NaN                               NaN
#
#        Blue whale gene name
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# ...                     ...
# 115851                  NaN
# 115852                  NaN
# 115853                  NaN
# 115854                  NaN
# 115855                  NaN
#
# [115856 rows x 6 columns]

# %%
Barramundiperch_Belugawhale_Bicolordamselfish_Blacksnubnosedmonkey_Bluewhale_ortho_df = pd.read_csv(
    "downloaded_files/Barramundiperch_Belugawhale_Bicolordamselfish_Blacksnubnosedmonkey_Bluewhale.txt", sep=",")
Barramundiperch_Belugawhale_Bicolordamselfish_Blacksnubnosedmonkey_Bluewhale_ortho_df
# Out:
#         Gene name Barramundi perch gene name Beluga whale gene name  \
# 0           MT-TF                        NaN                    NaN
# 1         MT-RNR1                        NaN                    NaN
# 2           MT-TV                        NaN                    NaN
# 3         MT-RNR2                        NaN                    NaN
# 4          MT-TL1                        NaN                    NaN
# ...           ...                        ...                    ...
# 115851  LINC01705                        NaN                    NaN
# 115852  RNU6-403P                        NaN                    NaN
# 115853  LINC02474                        NaN                    NaN
# 115854   LYST-AS1                        NaN                    NaN
# 115855  LINC02768                        NaN                    NaN
#
#        Bicolor damselfish gene name Black snub-nosed monkey gene name  \
# 0                               NaN                               NaN
# 1                               NaN                               NaN
# 2                               NaN                               NaN
# 3                               NaN                               NaN
# 4                               NaN                               NaN
# ...                             ...                               ...
# 115851                          NaN                               NaN
# 115852                          NaN                               NaN
# 115853                          NaN                               NaN
# 115854                          NaN                               NaN
# 115855                          NaN                               NaN
#
#        Blue whale gene name
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# ...                     ...
# 115851                  NaN
# 115852                  NaN
# 115853                  NaN
# 115854                  NaN
# 115855                  NaN
#
# [115856 rows x 6 columns]

# %%
Barramundiperch_Belugawhale_Bicolordamselfish_Blacksnubnosedmonkey_Bluewhale_ortho_df["Gene name"] = Barramundiperch_Belugawhale_Bicolordamselfish_Blacksnubnosedmonkey_Bluewhale_ortho_df["Gene name"].str.upper()
Barramundiperch_Belugawhale_Bicolordamselfish_Blacksnubnosedmonkey_Bluewhale_ortho_df["Barramundi perch gene name"] = Barramundiperch_Belugawhale_Bicolordamselfish_Blacksnubnosedmonkey_Bluewhale_ortho_df["Barramundi perch gene name"].str.upper()
Barramundiperch_Belugawhale_Bicolordamselfish_Blacksnubnosedmonkey_Bluewhale_ortho_df["Beluga whale gene name"] = Barramundiperch_Belugawhale_Bicolordamselfish_Blacksnubnosedmonkey_Bluewhale_ortho_df["Beluga whale gene name"].str.upper()
Barramundiperch_Belugawhale_Bicolordamselfish_Blacksnubnosedmonkey_Bluewhale_ortho_df["Bicolor damselfish gene name"] = Barramundiperch_Belugawhale_Bicolordamselfish_Blacksnubnosedmonkey_Bluewhale_ortho_df["Bicolor damselfish gene name"].str.upper()
Barramundiperch_Belugawhale_Bicolordamselfish_Blacksnubnosedmonkey_Bluewhale_ortho_df["Black snub-nosed monkey gene name"] = Barramundiperch_Belugawhale_Bicolordamselfish_Blacksnubnosedmonkey_Bluewhale_ortho_df["Black snub-nosed monkey gene name"].str.upper()
Barramundiperch_Belugawhale_Bicolordamselfish_Blacksnubnosedmonkey_Bluewhale_ortho_df["Blue whale gene name"] = Barramundiperch_Belugawhale_Bicolordamselfish_Blacksnubnosedmonkey_Bluewhale_ortho_df["Blue whale gene name"].str.upper()

# %%
make_col_ortholog_match(ortholog_match_subset_genes_df, Barramundiperch_Belugawhale_Bicolordamselfish_Blacksnubnosedmonkey_Bluewhale_ortho_df,"Barramundi perch")
# Out:
# 95

# %%
make_col_ortholog_match(ortholog_match_subset_genes_df, Barramundiperch_Belugawhale_Bicolordamselfish_Blacksnubnosedmonkey_Bluewhale_ortho_df,"Beluga whale")
# Out:
# 228

# %%
make_col_ortholog_match(ortholog_match_subset_genes_df, Barramundiperch_Belugawhale_Bicolordamselfish_Blacksnubnosedmonkey_Bluewhale_ortho_df,"Bicolor damselfish")
# Out:
# 93

# %%
make_col_ortholog_match(ortholog_match_subset_genes_df, Barramundiperch_Belugawhale_Bicolordamselfish_Blacksnubnosedmonkey_Bluewhale_ortho_df,"Black snub-nosed monkey")
# Out:
# 14

# %%
make_col_ortholog_match(ortholog_match_subset_genes_df, Barramundiperch_Belugawhale_Bicolordamselfish_Blacksnubnosedmonkey_Bluewhale_ortho_df,"Blue whale")
# Out:
# 7

# %% [markdown]
# ## Trying to load in a file about gene families?

# %%
from Bio import AlignIO
import pandas as pd

# Load the EMF file
input_file = "downloaded_files/Compara.112.ncrna_default.nh.emf"  # Update with the extracted filename
output_csv = "output.csv"
output_tsv = "output.tsv"

# Read the EMF file
alignment = AlignIO.read(input_file, "emf")

# Convert to a DataFrame
data = []
for record in alignment:
    data.append([record.id] + record.seq)

df = pd.DataFrame(data)

# Save to CSV
df.to_csv(output_csv, index=False)
# Save to TSV
df.to_csv(output_tsv, sep='\t', index=False)

print("Conversion complete!")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[698], line 10
#       7 output_tsv = "output.tsv"
#       9 # Read the EMF file
# ---> 10 alignment = AlignIO.read(input_file, "emf")
#      12 # Convert to a DataFrame
#      13 data = []
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/Bio/AlignIO/__init__.py:384, in read(handle, format, seq_count)
#     382 iterator = parse(handle, format, seq_count)
#     383 try:
# --> 384     alignment = next(iterator)
#     385 except StopIteration:
#     386     raise ValueError("No records found in handle") from None
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/Bio/AlignIO/__init__.py:333, in parse(handle, format, seq_count)
#     331     i = _SeqIO_to_alignment_iterator(fp, format, seq_count=seq_count)
#     332 else:
# --> 333     raise ValueError(f"Unknown format '{format}'")
#     335 yield from i
#
# ValueError: Unknown format 'emf'

# %%
import pandas as pd

# Initialize lists to hold data
data = []

# Open and read the EMF file
with open("downloaded_files/Compara.112.ncrna_default.nh.emf", "r") as infile:
    for line in infile:
        # Skip comments or empty lines if necessary
        if line.startswith("#") or not line.strip():
            continue
        
        # Split line into components (adjust this based on the actual format)
        components = line.strip().split()
        
        # Append the components to the data list
        data.append(components)

# Create a DataFrame from the data list
df = pd.DataFrame(data)

# Save to CSV
df.to_csv("output.csv", index=False)
# Save to TSV
df.to_csv("output.tsv", sep='\t', index=False)

print("Conversion complete!")
# Out:
# Conversion complete!

# %%
output_df = pd.read_csv(
    "output.csv", sep=",")
output_df
# Out:
#                                                         0  \
# 0                                                     SEQ
# 1                                                     SEQ
# 2                                                     SEQ
# 3                                                     SEQ
# 4                                                     SEQ
# ...                                                   ...
# 372964                                                SEQ
# 372965                                                SEQ
# 372966                                               DATA
# 372967  ((((((((ENSBGRT00000042759:0,ENSBGRT0000004275...
# 372968                                                 //
#
#                                  1                       2               3  \
# 0                  cavia_porcellus      ENSCPOT00000029270      DS562967.1
# 1                  cavia_porcellus      ENSCPOT00000025916      DS562884.1
# 2       cervus_hanglu_yarkandensis      ENSCHYT00000027762              23
# 3                canis_lupus_dingo      ENSCAFT00020034875  QKWQ01000243.1
# 4           canis_lupus_familiaris      ENSCAFT00845017353               2
# ...                            ...                     ...             ...
# 372964                  mus_caroli  MGP_CAROLIEiJ_T0095453               8
# 372965                 mus_spretus   MGP_SPRETEiJ_T0098898               8
# 372966                         NaN                     NaN             NaN
# 372967                         NaN                     NaN             NaN
# 372968                         NaN                     NaN             NaN
#
#               4        5   6                       7        8
# 0       4315635  4315772  -1      ENSCPOG00000028438      NaN
# 1      16918525 16918605   1      ENSCPOG00000025829      NaN
# 2      34283733 34283858   1      ENSCHYG00000016461      NaN
# 3      12158129 12158261  -1      ENSCAFG00020023588  SNORA61
# 4      72475732 72475864   1      ENSCAFG00845009868      NaN
# ...         ...      ...  ..                     ...      ...
# 372964 39879594 39879690   1  MGP_CAROLIEiJ_G0035515      NaN
# 372965 44218146 44218242   1   MGP_SPRETEiJ_G0036433      NaN
# 372966      NaN      NaN NaN                     NaN      NaN
# 372967      NaN      NaN NaN                     NaN      NaN
# 372968      NaN      NaN NaN                     NaN      NaN
#
# [372969 rows x 9 columns]

# %% [markdown]
# ## Summarize

# %%
ortholog_match_subset_genes_df.to_csv(
    "created_files/ortholog_alias_match_df.csv", index=True
)

# %%
ortholog_match_subset_genes_df.loc[
    ortholog_match_subset_genes_df["alias_symbol"] == "CALMBP1"
]
# Out:
#      gene_symbol alias_symbol  HGNC_ID            ENSG_ID   NCBI_ID  \
# 4476        ASPM      CALMBP1  {19048}  {ENSG00000066279}  {259266}
#
#                   source  DM Match  Mouse Match  \
# 4476  {HGNC, ENSG, NCBI}     False        False
#
#       Abingdon island giant tortoise Match  African ostrich Match  ...  \
# 4476                                 False                  False  ...
#
#       Arabian camel Match  Arctic ground squirrel Match  \
# 4476                False                         False
#
#       Argentine black and white tegu Match  Armadillo Match  \
# 4476                                 False            False
#
#       Asian bonytongue Match  Barramundi perch Match  Beluga whale Match  \
# 4476                   False                   False               False
#
#       Bicolor damselfish Match  Black snub-nosed monkey Match  \
# 4476                     False                          False
#
#       Blue whale Match
# 4476             False
#
# [1 rows x 27 columns]

# %% [markdown]
# how many gene alias pairs dont match any orthologs

# %%
no_ortholog_match_subset_genes_df = ortholog_match_subset_genes_df[~ortholog_match_subset_genes_df.select_dtypes(include='bool').any(axis=1)]

# %%
no_ortholog_match_subset_genes_df.head(20)
# Out:
#    gene_symbol alias_symbol  HGNC_ID            ENSG_ID      NCBI_ID  \
# 0   A-GAMMA3'E    A-GAMMA-E       {}                 {}  {109951028}
# 1         A1BG          A1B      {5}  {ENSG00000121410}          {1}
# 2         A1BG          ABG      {5}  {ENSG00000121410}          {1}
# 3         A1BG          GAB      {5}  {ENSG00000121410}          {1}
# 4         A1BG     HYST2477      {5}  {ENSG00000121410}          {1}
# 5     A1BG-AS1      A1BG-AS  {37133}  {ENSG00000268895}     {503538}
# 6     A1BG-AS1       A1BGAS  {37133}  {ENSG00000268895}     {503538}
# 7     A1BG-AS1     FLJ23569  {37133}  {ENSG00000268895}     {503538}
# 8     A1BG-AS1   NCRNA00181  {37133}  {ENSG00000268895}     {503538}
# 9         A1CF          ACF  {24086}  {ENSG00000148584}      {29974}
# 10        A1CF        ACF64  {24086}  {ENSG00000148584}      {29974}
# 11        A1CF        ACF65  {24086}  {ENSG00000148584}      {29974}
# 12        A1CF    APOBEC1CF  {24086}  {ENSG00000148584}      {29974}
# 13        A1CF          ASP  {24086}  {ENSG00000148584}      {29974}
# 14         A2M         A2MD      {7}  {ENSG00000175899}          {2}
# 15         A2M       CPAMD5      {7}  {ENSG00000175899}          {2}
# 16         A2M       FWP007      {7}  {ENSG00000175899}          {2}
# 17         A2M       S863-7      {7}  {ENSG00000175899}          {2}
# 18       A2ML1       CPAMD9  {23336}  {ENSG00000166535}     {144568}
# 19       A2ML1     FLJ25179  {23336}  {ENSG00000166535}     {144568}
#
#                 source  DM Match  Mouse Match  \
# 0               {NCBI}     False        False
# 1               {NCBI}     False        False
# 2               {NCBI}     False        False
# 3               {NCBI}     False        False
# 4               {NCBI}     False        False
# 5         {ENSG, NCBI}     False        False
# 6         {ENSG, NCBI}     False        False
# 7         {HGNC, ENSG}     False        False
# 8         {ENSG, NCBI}     False        False
# 9   {HGNC, ENSG, NCBI}     False        False
# 10  {HGNC, ENSG, NCBI}     False        False
# 11  {HGNC, ENSG, NCBI}     False        False
# 12  {HGNC, ENSG, NCBI}     False        False
# 13  {HGNC, ENSG, NCBI}     False        False
# 14              {NCBI}     False        False
# 15  {HGNC, ENSG, NCBI}     False        False
# 16  {HGNC, ENSG, NCBI}     False        False
# 17  {HGNC, ENSG, NCBI}     False        False
# 18        {ENSG, NCBI}     False        False
# 19        {HGNC, ENSG}     False        False
#
#     Abingdon island giant tortoise Match  African ostrich Match  ...  \
# 0                                  False                  False  ...
# 1                                  False                  False  ...
# 2                                  False                  False  ...
# 3                                  False                  False  ...
# 4                                  False                  False  ...
# 5                                  False                  False  ...
# 6                                  False                  False  ...
# 7                                  False                  False  ...
# 8                                  False                  False  ...
# 9                                  False                  False  ...
# 10                                 False                  False  ...
# 11                                 False                  False  ...
# 12                                 False                  False  ...
# 13                                 False                  False  ...
# 14                                 False                  False  ...
# 15                                 False                  False  ...
# 16                                 False                  False  ...
# 17                                 False                  False  ...
# 18                                 False                  False  ...
# 19                                 False                  False  ...
#
#     Arabian camel Match  Arctic ground squirrel Match  \
# 0                 False                         False
# 1                 False                         False
# 2                 False                         False
# 3                 False                         False
# 4                 False                         False
# 5                 False                         False
# 6                 False                         False
# 7                 False                         False
# 8                 False                         False
# 9                 False                         False
# 10                False                         False
# 11                False                         False
# 12                False                         False
# 13                False                         False
# 14                False                         False
# 15                False                         False
# 16                False                         False
# 17                False                         False
# 18                False                         False
# 19                False                         False
#
#     Argentine black and white tegu Match  Armadillo Match  \
# 0                                  False            False
# 1                                  False            False
# 2                                  False            False
# 3                                  False            False
# 4                                  False            False
# 5                                  False            False
# 6                                  False            False
# 7                                  False            False
# 8                                  False            False
# 9                                  False            False
# 10                                 False            False
# 11                                 False            False
# 12                                 False            False
# 13                                 False            False
# 14                                 False            False
# 15                                 False            False
# 16                                 False            False
# 17                                 False            False
# 18                                 False            False
# 19                                 False            False
#
#     Asian bonytongue Match  Barramundi perch Match  Beluga whale Match  \
# 0                    False                   False               False
# 1                    False                   False               False
# 2                    False                   False               False
# 3                    False                   False               False
# 4                    False                   False               False
# 5                    False                   False               False
# 6                    False                   False               False
# 7                    False                   False               False
# 8                    False                   False               False
# 9                    False                   False               False
# 10                   False                   False               False
# 11                   False                   False               False
# 12                   False                   False               False
# 13                   False                   False               False
# 14                   False                   False               False
# 15                   False                   False               False
# 16                   False                   False               False
# 17                   False                   False               False
# 18                   False                   False               False
# 19                   False                   False               False
#
#     Bicolor damselfish Match  Black snub-nosed monkey Match  Blue whale Match
# 0                      False                          False             False
# 1                      False                          False             False
# 2                      False                          False             False
# 3                      False                          False             False
# 4                      False                          False             False
# 5                      False                          False             False
# 6                      False                          False             False
# 7                      False                          False             False
# 8                      False                          False             False
# 9                      False                          False             False
# 10                     False                          False             False
# 11                     False                          False             False
# 12                     False                          False             False
# 13                     False                          False             False
# 14                     False                          False             False
# 15                     False                          False             False
# 16                     False                          False             False
# 17                     False                          False             False
# 18                     False                          False             False
# 19                     False                          False             False
#
# [20 rows x 27 columns]

# %% [markdown]
# # HGNC Previous Symbol Analysis

# %% [markdown]
# ## Download the HGNC custom download including the gene symbol, ID, and previous symbols

# %%
hgnc_previous_symbols_df = pd.read_csv(
    "downloaded_files/HGNC_previous_symbols20241010.txt", sep="\t")
hgnc_previous_symbols_df
# Out:
#           HGNC ID Approved symbol             Previous symbols
# 0          HGNC:5            A1BG                          NaN
# 1      HGNC:37133        A1BG-AS1  NCRNA00181, A1BGAS, A1BG-AS
# 2      HGNC:24086            A1CF                          NaN
# 3          HGNC:6           A1S9T                          NaN
# 4          HGNC:7             A2M                          NaN
# ...           ...             ...                          ...
# 49077  HGNC:25820          ZYG11B                        ZYG11
# 49078  HGNC:13200             ZYX                          NaN
# 49079  HGNC:51695           ZYXP1                          NaN
# 49080  HGNC:29027           ZZEF1                          NaN
# 49081  HGNC:24523            ZZZ3                          NaN
#
# [49082 rows x 3 columns]

# %% [markdown]
# ## Remove all genes with no previous symbols

# %%
hgnc_previous_symbols_df = hgnc_previous_symbols_df.dropna(subset=["Previous symbols"])
hgnc_previous_symbols_df
# Out:
#           HGNC ID Approved symbol             Previous symbols
# 1      HGNC:37133        A1BG-AS1  NCRNA00181, A1BGAS, A1BG-AS
# 6      HGNC:23336           A2ML1                       CPAMD9
# 9          HGNC:8           A2MP1                         A2MP
# 12     HGNC:30005         A3GALT2                     A3GALT2P
# 13     HGNC:18149          A4GALT                           P1
# ...           ...             ...                          ...
# 49063  HGNC:23528          ZSWIM8                     KIAA0913
# 49065  HGNC:34495          ZSWIM9                     C19orf68
# 49066  HGNC:21224            ZUP1              C6orf113, ZUFSP
# 49071  HGNC:13197            ZWS1                          ZWS
# 49077  HGNC:25820          ZYG11B                        ZYG11
#
# [13067 rows x 3 columns]

# %% [markdown]
# ## Explode the previous symbols so that it is only one symbol per row

# %%
hgnc_previous_symbols_df["previous_symbol"] = hgnc_previous_symbols_df['Previous symbols'].str.split(',').apply(lambda x: [s.strip() for s in x])
hgnc_previous_symbols_df = hgnc_previous_symbols_df.explode('previous_symbol')
hgnc_previous_symbols_df = hgnc_previous_symbols_df.drop(columns=['Previous symbols'])
hgnc_previous_symbols_df
# Out:
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_83616/994957772.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hgnc_previous_symbols_df["previous_symbol"] = hgnc_previous_symbols_df['Previous symbols'].str.split(',').apply(lambda x: [s.strip() for s in x])
#           HGNC ID Approved symbol previous_symbol
# 1      HGNC:37133        A1BG-AS1      NCRNA00181
# 1      HGNC:37133        A1BG-AS1          A1BGAS
# 1      HGNC:37133        A1BG-AS1         A1BG-AS
# 6      HGNC:23336           A2ML1          CPAMD9
# 9          HGNC:8           A2MP1            A2MP
# ...           ...             ...             ...
# 49065  HGNC:34495          ZSWIM9        C19orf68
# 49066  HGNC:21224            ZUP1        C6orf113
# 49066  HGNC:21224            ZUP1           ZUFSP
# 49071  HGNC:13197            ZWS1             ZWS
# 49077  HGNC:25820          ZYG11B           ZYG11
#
# [16274 rows x 3 columns]

# %% [markdown]
# ## Make all of the gene symbols all caps

# %% [markdown]
# Different species follow different gene nomenclature conventions. <br>
# For example, mouse genes have the first letter capitalized but the rest lowercase.<br>
# They need to be all caps for matching

# %%
hgnc_previous_symbols_df["Approved symbol"] = hgnc_previous_symbols_df["Approved symbol"].str.upper()
hgnc_previous_symbols_df["previous_symbol"] = hgnc_previous_symbols_df["previous_symbol"].str.upper()

# %% [markdown]
# ## Match aliases to previous symbols!

# %%
previous_symbol_match_subset_genes_df = subset_genes_df.copy()
previous_symbol_match_subset_genes_df
# Out:
#       gene_symbol  alias_symbol  HGNC_ID            ENSG_ID      NCBI_ID  \
# 0      A-GAMMA3'E     A-GAMMA-E       {}                 {}  {109951028}
# 1            A1BG           A1B      {5}  {ENSG00000121410}          {1}
# 2            A1BG           ABG      {5}  {ENSG00000121410}          {1}
# 3            A1BG           GAB      {5}  {ENSG00000121410}          {1}
# 4            A1BG      HYST2477      {5}  {ENSG00000121410}          {1}
# ...           ...           ...      ...                ...          ...
# 86768       ZZEF1      FLJ10821  {29027}  {ENSG00000074755}      {23140}
# 86769       ZZEF1      KIAA0399  {29027}  {ENSG00000074755}      {23140}
# 86770       ZZEF1          ZZZ4  {29027}  {ENSG00000074755}      {23140}
# 86771        ZZZ3         ATAC1  {24523}  {ENSG00000036549}      {26009}
# 86772        ZZZ3  DKFZP564I052  {24523}  {ENSG00000036549}      {26009}
#
#                    source
# 0                  {NCBI}
# 1                  {NCBI}
# 2                  {NCBI}
# 3                  {NCBI}
# 4                  {NCBI}
# ...                   ...
# 86768        {HGNC, ENSG}
# 86769        {HGNC, ENSG}
# 86770  {HGNC, ENSG, NCBI}
# 86771  {HGNC, ENSG, NCBI}
# 86772        {HGNC, ENSG}
#
# [86773 rows x 6 columns]

# %%
previous_symbol_match_subset_genes_df["Previous Symbol Match"] = previous_symbol_match_subset_genes_df.apply(lambda row: 
                        any((hgnc_previous_symbols_df['Approved symbol'] == row['gene_symbol']) 
                            & 
                            (hgnc_previous_symbols_df["previous_symbol"] == row['alias_symbol'])), axis=1)
previous_symbol_match_df = previous_symbol_match_subset_genes_df[previous_symbol_match_subset_genes_df["Previous Symbol Match"]]
previous_symbol_match_df
# Out:
#       gene_symbol alias_symbol  HGNC_ID                             ENSG_ID  \
# 5        A1BG-AS1      A1BG-AS  {37133}                   {ENSG00000268895}
# 6        A1BG-AS1       A1BGAS  {37133}                   {ENSG00000268895}
# 8        A1BG-AS1   NCRNA00181  {37133}                   {ENSG00000268895}
# 18          A2ML1       CPAMD9  {23336}                   {ENSG00000166535}
# 22          A2MP1         A2MP      {8}  {ENSG00000291190, ENSG00000256069}
# ...           ...          ...      ...                                 ...
# 86738      ZSWIM8     KIAA0913  {23528}                   {ENSG00000214655}
# 86739      ZSWIM9     C19ORF68  {34495}                   {ENSG00000185453}
# 86741        ZUP1     C6ORF113  {21224}                   {ENSG00000153975}
# 86744        ZUP1        ZUFSP  {21224}                   {ENSG00000153975}
# 86765      ZYG11B        ZYG11  {25820}                   {ENSG00000162378}
#
#         NCBI_ID        source  Previous Symbol Match
# 5      {503538}  {ENSG, NCBI}                   True
# 6      {503538}  {ENSG, NCBI}                   True
# 8      {503538}  {ENSG, NCBI}                   True
# 18     {144568}  {ENSG, NCBI}                   True
# 22          {3}  {ENSG, NCBI}                   True
# ...         ...           ...                    ...
# 86738   {23053}  {ENSG, NCBI}                   True
# 86739  {374920}  {ENSG, NCBI}                   True
# 86741  {221302}  {ENSG, NCBI}                   True
# 86744  {221302}  {ENSG, NCBI}                   True
# 86765   {79699}  {ENSG, NCBI}                   True
#
# [15585 rows x 7 columns]

# %%
previous_symbol_match_subset_genes_df.head(20)
# Out:
#    gene_symbol alias_symbol  HGNC_ID            ENSG_ID      NCBI_ID  \
# 0   A-GAMMA3'E    A-GAMMA-E       {}                 {}  {109951028}
# 1         A1BG          A1B      {5}  {ENSG00000121410}          {1}
# 2         A1BG          ABG      {5}  {ENSG00000121410}          {1}
# 3         A1BG          GAB      {5}  {ENSG00000121410}          {1}
# 4         A1BG     HYST2477      {5}  {ENSG00000121410}          {1}
# 5     A1BG-AS1      A1BG-AS  {37133}  {ENSG00000268895}     {503538}
# 6     A1BG-AS1       A1BGAS  {37133}  {ENSG00000268895}     {503538}
# 7     A1BG-AS1     FLJ23569  {37133}  {ENSG00000268895}     {503538}
# 8     A1BG-AS1   NCRNA00181  {37133}  {ENSG00000268895}     {503538}
# 9         A1CF          ACF  {24086}  {ENSG00000148584}      {29974}
# 10        A1CF        ACF64  {24086}  {ENSG00000148584}      {29974}
# 11        A1CF        ACF65  {24086}  {ENSG00000148584}      {29974}
# 12        A1CF    APOBEC1CF  {24086}  {ENSG00000148584}      {29974}
# 13        A1CF          ASP  {24086}  {ENSG00000148584}      {29974}
# 14         A2M         A2MD      {7}  {ENSG00000175899}          {2}
# 15         A2M       CPAMD5      {7}  {ENSG00000175899}          {2}
# 16         A2M       FWP007      {7}  {ENSG00000175899}          {2}
# 17         A2M       S863-7      {7}  {ENSG00000175899}          {2}
# 18       A2ML1       CPAMD9  {23336}  {ENSG00000166535}     {144568}
# 19       A2ML1     FLJ25179  {23336}  {ENSG00000166535}     {144568}
#
#                 source  Previous Symbol Match
# 0               {NCBI}                  False
# 1               {NCBI}                  False
# 2               {NCBI}                  False
# 3               {NCBI}                  False
# 4               {NCBI}                  False
# 5         {ENSG, NCBI}                   True
# 6         {ENSG, NCBI}                   True
# 7         {HGNC, ENSG}                  False
# 8         {ENSG, NCBI}                   True
# 9   {HGNC, ENSG, NCBI}                  False
# 10  {HGNC, ENSG, NCBI}                  False
# 11  {HGNC, ENSG, NCBI}                  False
# 12  {HGNC, ENSG, NCBI}                  False
# 13  {HGNC, ENSG, NCBI}                  False
# 14              {NCBI}                  False
# 15  {HGNC, ENSG, NCBI}                  False
# 16  {HGNC, ENSG, NCBI}                  False
# 17  {HGNC, ENSG, NCBI}                  False
# 18        {ENSG, NCBI}                   True
# 19        {HGNC, ENSG}                  False

# %% [markdown]
# # Clone Names Analysis

# %%
with open("downloaded_files/Conversion_table_FLJ(1).txt", 'r') as file:
    for i, line in enumerate(file):
        print(f"Line {i}: {line.strip()}")

# %%
clone_symbols_df = pd.read_csv(
    "downloaded_files/Conversion_table_FLJ(1).txt", 
    sep="\t", 
    skiprows=3
)
clone_symbols_df
# Out:
#       Accesion No              FLJ ID      Clone ID     Sequence ID  \
# 0        AK075326  PSEC0001(FLJ91001)  NT2RM1000066  C-NT2RM1000066
# 1        AK172724  PSEC0002(FLJ91002)  NT2RM1000295  C-NT2RM1000295
# 2        AK075327  PSEC0003(FLJ91003)  NT2RM1000361  C-NT2RM1000361
# 3        AK075328  PSEC0004(FLJ91004)  NT2RM1000558  C-NT2RM1000558
# 4        AK075329  PSEC0005(FLJ91005)  NT2RM1000566  C-NT2RM1000566
# ...           ...                 ...           ...             ...
# 30321    AK057825            FLJ25096      CBR00778      C-CBR00778
# 30322    AK000479            FLJ20472      KAT07023      C-KAT07023
# 30323    AK125921            FLJ43933  TESTI4013685  C-TESTI4013685
# 30324    AK125959            FLJ43971  TESTI4017901  C-TESTI4017901
# 30325    AK000594            FLJ20587      KAT09116      C-KAT09116
#
#        Another Sequence ID
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# ...                    ...
# 30321                  NaN
# 30322                  NaN
# 30323                  NaN
# 30324                  NaN
# 30325                  NaN
#
# [30326 rows x 5 columns]

# %%
extracted_ids = clone_symbols_df['FLJ ID'].str.extract(r'([^()]+)\((.+?)\)')

# Create a DataFrame to hold the results
result_rows = []

# Iterate over the original DataFrame and extract values
for index, row in clone_symbols_df.iterrows():
    flj_id = row['FLJ ID']
    if pd.notnull(extracted_ids.iloc[index, 0]):  # Check if there is a match
        result_rows.append({'Accesion No': row['Accesion No'], 'ID': extracted_ids.iloc[index, 0]})  # First part
        result_rows.append({'Accesion No': row['Accesion No'], 'ID': extracted_ids.iloc[index, 1]})  # Second part
    else:
        result_rows.append({'Accesion No': row['Accesion No'], 'ID': flj_id})  # Keep the original if no match

# Create the final result DataFrame
result_df = pd.DataFrame(result_rows)

# Display the result
result_df
# Out:
#       Accesion No        ID
# 0        AK075326  PSEC0001
# 1        AK075326  FLJ91001
# 2        AK172724  PSEC0002
# 3        AK172724  FLJ91002
# 4        AK075327  PSEC0003
# ...           ...       ...
# 30581    AK057825  FLJ25096
# 30582    AK000479  FLJ20472
# 30583    AK125921  FLJ43933
# 30584    AK125959  FLJ43971
# 30585    AK000594  FLJ20587
#
# [30586 rows x 2 columns]

# %%
result_df.loc[
    result_df["ID"] == "FLJ25179"
]
# Out:
#       Accesion No        ID
# 11650    AK057908  FLJ25179

# %%
result_df["ID"] = result_df["ID"].str.strip()

# %%
previous_symbol_match_subset_genes_df = subset_genes_df.copy()
previous_symbol_match_subset_genes_df
# Out:
#       gene_symbol  alias_symbol  HGNC_ID            ENSG_ID      NCBI_ID  \
# 0      A-GAMMA3'E     A-GAMMA-E       {}                 {}  {109951028}
# 1            A1BG           A1B      {5}  {ENSG00000121410}          {1}
# 2            A1BG           ABG      {5}  {ENSG00000121410}          {1}
# 3            A1BG           GAB      {5}  {ENSG00000121410}          {1}
# 4            A1BG      HYST2477      {5}  {ENSG00000121410}          {1}
# ...           ...           ...      ...                ...          ...
# 86768       ZZEF1      FLJ10821  {29027}  {ENSG00000074755}      {23140}
# 86769       ZZEF1      KIAA0399  {29027}  {ENSG00000074755}      {23140}
# 86770       ZZEF1          ZZZ4  {29027}  {ENSG00000074755}      {23140}
# 86771        ZZZ3         ATAC1  {24523}  {ENSG00000036549}      {26009}
# 86772        ZZZ3  DKFZP564I052  {24523}  {ENSG00000036549}      {26009}
#
#                    source
# 0                  {NCBI}
# 1                  {NCBI}
# 2                  {NCBI}
# 3                  {NCBI}
# 4                  {NCBI}
# ...                   ...
# 86768        {HGNC, ENSG}
# 86769        {HGNC, ENSG}
# 86770  {HGNC, ENSG, NCBI}
# 86771  {HGNC, ENSG, NCBI}
# 86772        {HGNC, ENSG}
#
# [86773 rows x 6 columns]

# %%
previous_symbol_match_subset_genes_df["Clone Symbol Match"] = previous_symbol_match_subset_genes_df['alias_symbol'].isin(result_df['ID'])

df = previous_symbol_match_subset_genes_df[previous_symbol_match_subset_genes_df["Clone Symbol Match"]]
previous_symbol_match_subset_genes_df.head(20)
# Out:
#    gene_symbol alias_symbol  HGNC_ID            ENSG_ID      NCBI_ID  \
# 0   A-GAMMA3'E    A-GAMMA-E       {}                 {}  {109951028}
# 1         A1BG          A1B      {5}  {ENSG00000121410}          {1}
# 2         A1BG          ABG      {5}  {ENSG00000121410}          {1}
# 3         A1BG          GAB      {5}  {ENSG00000121410}          {1}
# 4         A1BG     HYST2477      {5}  {ENSG00000121410}          {1}
# 5     A1BG-AS1      A1BG-AS  {37133}  {ENSG00000268895}     {503538}
# 6     A1BG-AS1       A1BGAS  {37133}  {ENSG00000268895}     {503538}
# 7     A1BG-AS1     FLJ23569  {37133}  {ENSG00000268895}     {503538}
# 8     A1BG-AS1   NCRNA00181  {37133}  {ENSG00000268895}     {503538}
# 9         A1CF          ACF  {24086}  {ENSG00000148584}      {29974}
# 10        A1CF        ACF64  {24086}  {ENSG00000148584}      {29974}
# 11        A1CF        ACF65  {24086}  {ENSG00000148584}      {29974}
# 12        A1CF    APOBEC1CF  {24086}  {ENSG00000148584}      {29974}
# 13        A1CF          ASP  {24086}  {ENSG00000148584}      {29974}
# 14         A2M         A2MD      {7}  {ENSG00000175899}          {2}
# 15         A2M       CPAMD5      {7}  {ENSG00000175899}          {2}
# 16         A2M       FWP007      {7}  {ENSG00000175899}          {2}
# 17         A2M       S863-7      {7}  {ENSG00000175899}          {2}
# 18       A2ML1       CPAMD9  {23336}  {ENSG00000166535}     {144568}
# 19       A2ML1     FLJ25179  {23336}  {ENSG00000166535}     {144568}
#
#                 source  Clone Symbol Match
# 0               {NCBI}               False
# 1               {NCBI}               False
# 2               {NCBI}               False
# 3               {NCBI}               False
# 4               {NCBI}               False
# 5         {ENSG, NCBI}               False
# 6         {ENSG, NCBI}               False
# 7         {HGNC, ENSG}                True
# 8         {ENSG, NCBI}               False
# 9   {HGNC, ENSG, NCBI}               False
# 10  {HGNC, ENSG, NCBI}               False
# 11  {HGNC, ENSG, NCBI}               False
# 12  {HGNC, ENSG, NCBI}               False
# 13  {HGNC, ENSG, NCBI}               False
# 14              {NCBI}               False
# 15  {HGNC, ENSG, NCBI}               False
# 16  {HGNC, ENSG, NCBI}               False
# 17  {HGNC, ENSG, NCBI}               False
# 18        {ENSG, NCBI}               False
# 19        {HGNC, ENSG}                True

# %%
df
# Out:
#       gene_symbol alias_symbol  HGNC_ID                             ENSG_ID  \
# 7        A1BG-AS1     FLJ23569  {37133}                   {ENSG00000268895}
# 19          A2ML1     FLJ25179  {23336}                   {ENSG00000166535}
# 45           AACS     FLJ12389  {21298}                   {ENSG00000081760}
# 56          AAGAB     FLJ11506  {25662}                   {ENSG00000103591}
# 65          AAMDC     FLJ21035  {30205}                   {ENSG00000087884}
# ...           ...          ...      ...                                 ...
# 86729      ZSWIM4     FLJ12221  {25704}  {ENSG00000132003, ENSG00000288360}
# 86747      ZWILCH     FLJ10036  {25468}                   {ENSG00000174442}
# 86760        ZXDC     FLJ13861  {28160}                   {ENSG00000070476}
# 86764      ZYG11B     FLJ13456  {25820}                   {ENSG00000162378}
# 86768       ZZEF1     FLJ10821  {29027}                   {ENSG00000074755}
#
#         NCBI_ID        source  Clone Symbol Match
# 7      {503538}  {HGNC, ENSG}                True
# 19     {144568}  {HGNC, ENSG}                True
# 45      {65985}  {HGNC, ENSG}                True
# 56      {79719}  {HGNC, ENSG}                True
# 65      {28971}  {HGNC, ENSG}                True
# ...         ...           ...                 ...
# 86729   {65249}  {HGNC, ENSG}                True
# 86747   {55055}  {HGNC, ENSG}                True
# 86760   {79364}  {HGNC, ENSG}                True
# 86764   {79699}  {HGNC, ENSG}                True
# 86768   {23140}  {HGNC, ENSG}                True
#
# [3585 rows x 7 columns]

# %% [markdown]
# # Gene Family Analysis

# %%
hgnc_genefamilies_df = pd.read_csv(
    "downloaded_files/hgnc_genefamily.csv", sep=",")
hgnc_genefamilies_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 hgnc_genefamilies_df = pd.read_csv(
#       2     "downloaded_files/hgnc_genefamily.csv", sep=",")
#       3 hgnc_genefamilies_df
#
# NameError: name 'pd' is not defined
