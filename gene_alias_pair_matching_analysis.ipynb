# %%
import pandas as pd
import numpy as np

# %%
def remove_nan_from_set(s):
    """Remove null instances from set
    
    :param s: selected set
    :return: set with no null values
    """
    return {x for x in s if pd.notna(x)}

# %%
def read_subset_genes_csv(location, source= str):
    """Create a df of primary gene symbol- alias symbol pairs

    :param location: file location
    :param source: representation in the source of gene records
    return: a df of gene records
    """
    
    subset_genes_xxxx_df = pd.read_csv(
        location, index_col=[0],dtype={"NCBI_ID": str,"HGNC_ID":str})
    subset_genes_xxxx_df["source"] = str(source)
    subset_genes_xxxx_df['gene_symbol'] = subset_genes_xxxx_df['gene_symbol'].str.upper()
    subset_genes_xxxx_df['alias_symbol'] = subset_genes_xxxx_df['alias_symbol'].str.upper()
    return subset_genes_xxxx_df

# %%
def convert_all_columns_to_uppercase(df):
    """Convert gene symbols to all-caps. Diffferent species have differing capitalization requirements and this will standardize.

    :param df: DataFrame containing gene symbols of unknown capitalizations
    :return: a DataFrame with all gene symbols all-caps
    """
    for column in df.columns:
        if df[column].dtype == 'object':  # Check if the column type is object
            df[column] = df[column].str.upper()

    return df

# %%
def combine_rows(series):
    """Combine duplicate rows.

    :param series: a Pandas Series containing values from a DataFrame column.
                    this Series may contain NaN values, and the function will
                    return the first non-null value, or None if all values are NaN.
    :return: combined value from the Series, or None if the Series is empty or contains only NaNs.
    """
    return series.ffill().bfill().drop_duplicates().values[0] if not series.dropna().empty else None

# %%
def make_col_ortholog_match(recording_df, source_df, animal= str):
    """Check for ortholog matches in the primary gene symbol- alias symbol pairs. 
    Adds a T/F column for each pair. T if the alias is an ortholog from the specified animal and F if not

    :param recording_df: df that contains the primary gene symbol- alias symbol pairs
    :param source_df: df that contains the orthologs and their associated human genes
    :param animal: the animal from with the orthologs are being checked
    return: the number of primary gene symbol- alias symbol pairs where the alias is an ortholog from the specified animal
    """
    recording_df[f'{animal} Match'] = recording_df.apply(lambda row: 
                            any((source_df['Gene name'] == row['gene_symbol']) 
                                & 
                                (source_df[f'{animal} gene name'] == row['alias_symbol'])), axis=1)
    print(f"Added column: {animal} Match")
    return recording_df

# %%
def match_alias_to_ortholog(og_recording_df, source_df):
    """Apply the make_col_ortholog_match function to all animal columns in the DataFrame.

    :param og_recording_df: DataFrame containing the primary gene symbol- alias symbol pairs
    :param source_df: DataFrame containing the orthologs and their associated human genes
    :return: a DataFrame with all match columns added
    """
    source_df = source_df.dropna(subset=['Gene name'])

    source_df = convert_all_columns_to_uppercase(source_df)
    
    source_df = source_df.groupby('Gene name', as_index=False).agg(combine_rows)

    recording_df = og_recording_df.copy()
    recording_df.columns = recording_df.columns.str.strip().str.replace(r'\s+', ' ', regex=True)
    source_df.columns = source_df.columns.str.strip().str.replace(r'\s+', ' ', regex=True)

    animal_columns = [col for col in source_df.columns if 'gene name' in col and col != 'Gene name']
    
    true_counts = {}

    for animal in animal_columns:
        # Extract the animal name
        animal_name = animal.replace(' gene name', '')
        recording_df = make_col_ortholog_match(recording_df, source_df, animal_name)

        true_count = recording_df[f'{animal_name} Match'].sum()
        true_counts[animal_name] = true_count
    return recording_df, true_counts

# %% [markdown]
# ## Download gene records from ENSG, HGNC, and NCBI

# %% [markdown]
# #### This subset file was created in the alias-primary collision analysis notebook by the following modifications:
#  - Gene records with no aliases were removed.
#  - Primary gene symbol- alias symbol pairs where the alias was an exact match to the primary symbol were removed.
#  - Primary gene symbol- alias symbol pairs that were duplicated were removed.

# %%
subset_genes_ensg_df = read_subset_genes_csv("created_files/subset_genes_ensg_df.csv", "ENSG")
subset_genes_hgnc_df = read_subset_genes_csv("created_files/subset_genes_hgnc_df.csv", "HGNC")
subset_genes_ncbi_df = read_subset_genes_csv("created_files/subset_genes_ncbi_df.csv", "NCBI")

# %% [markdown]
# ## Combine data from all sources

# %%
subset_genes_df = pd.concat([subset_genes_ensg_df, subset_genes_hgnc_df, subset_genes_ncbi_df], axis=0)
subset_genes_df
# Out:
#                 ENSG_ID gene_symbol alias_symbol HGNC_ID    NCBI_ID source
# 0       ENSG00000210049       MT-TF         MTTF    7481        NaN   ENSG
# 1       ENSG00000210049       MT-TF         TRNF    7481        NaN   ENSG
# 2       ENSG00000211459     MT-RNR1          12S    7470        NaN   ENSG
# 3       ENSG00000211459     MT-RNR1       MOTS-C    7470        NaN   ENSG
# 4       ENSG00000211459     MT-RNR1       MTRNR1    7470        NaN   ENSG
# ...                 ...         ...          ...     ...        ...    ...
# 190961              NaN       GLTC1         GLTC   56861  131840634   NCBI
# 193342              NaN  GABRA6-AS1        ARBAG   40248  132532400   NCBI
# 193377              NaN     LNCARGI         ARGI   56890  133395150   NCBI
# 193378              NaN       MLDHR         MP31   55481  133834869   NCBI
# 193378              NaN       MLDHR      PTENURF   55481  133834869   NCBI
#
# [175868 rows x 6 columns]

# %% [markdown]
# ## Group the associated data by primary gene symbol- alias symbol pairs

# %% [markdown]
# #### This will ensure that there are no duplicate primary gene symbol- alias symbol pairs as well as preserving in which sources these pairs occur

# %%
subset_genes_df = subset_genes_df.groupby(['gene_symbol',"alias_symbol"], as_index=False).agg({
    "HGNC_ID": lambda x: set(x),
    'ENSG_ID': lambda x: set(x),
    'NCBI_ID': lambda x: set(x),
    "source": lambda x: set(x)
})
subset_genes_df
# Out:
#       gene_symbol  alias_symbol  HGNC_ID            ENSG_ID      NCBI_ID  \
# 0      A-GAMMA3'E     A-GAMMA-E    {nan}              {nan}  {109951028}
# 1            A1BG           A1B      {5}  {ENSG00000121410}          {1}
# 2            A1BG           ABG      {5}  {ENSG00000121410}          {1}
# 3            A1BG           GAB      {5}  {ENSG00000121410}          {1}
# 4            A1BG      HYST2477      {5}  {ENSG00000121410}          {1}
# ...           ...           ...      ...                ...          ...
# 86768       ZZEF1      FLJ10821  {29027}  {ENSG00000074755}      {23140}
# 86769       ZZEF1      KIAA0399  {29027}  {ENSG00000074755}      {23140}
# 86770       ZZEF1          ZZZ4  {29027}  {ENSG00000074755}      {23140}
# 86771        ZZZ3         ATAC1  {24523}  {ENSG00000036549}      {26009}
# 86772        ZZZ3  DKFZP564I052  {24523}  {ENSG00000036549}      {26009}
#
#                    source
# 0                  {NCBI}
# 1                  {NCBI}
# 2                  {NCBI}
# 3                  {NCBI}
# 4                  {NCBI}
# ...                   ...
# 86768        {ENSG, HGNC}
# 86769        {ENSG, HGNC}
# 86770  {ENSG, NCBI, HGNC}
# 86771  {ENSG, NCBI, HGNC}
# 86772        {ENSG, HGNC}
#
# [86773 rows x 6 columns]

# %%
subset_genes_df['NCBI_ID'] = subset_genes_df['NCBI_ID'].apply(remove_nan_from_set)
subset_genes_df['ENSG_ID'] = subset_genes_df['ENSG_ID'].apply(remove_nan_from_set)
subset_genes_df['HGNC_ID'] = subset_genes_df['HGNC_ID'].apply(remove_nan_from_set)

# %% [markdown]
# # Ortholog Analysis

# %% [markdown]
# ## Download an Ensembl Biomart export file with the Gene Name and the Ortholog Gene Name

# %%
mur_dros_ortho_df = pd.read_csv(
    "downloaded_files/ensg_mart_export_dros_murin_ortho.txt", sep=",", index_col=[0])
mur_dros_ortho_df
# Out:
#                 Drosophila melanogaster (Fruit fly) gene name  \
# Gene stable ID
# ENSG00000210049                                           NaN
# ENSG00000211459                                           NaN
# ENSG00000210077                                           NaN
# ENSG00000210082                                           NaN
# ENSG00000209082                                           NaN
# ...                                                       ...
# ENSG00000232679                                           NaN
# ENSG00000200033                                           NaN
# ENSG00000228437                                           NaN
# ENSG00000229463                                           NaN
# ENSG00000229291                                           NaN
#
#                 Drosophila melanogaster (Fruit fly) gene stable ID  \
# Gene stable ID
# ENSG00000210049                                                NaN
# ENSG00000211459                                                NaN
# ENSG00000210077                                                NaN
# ENSG00000210082                                                NaN
# ENSG00000209082                                                NaN
# ...                                                            ...
# ENSG00000232679                                                NaN
# ENSG00000200033                                                NaN
# ENSG00000228437                                                NaN
# ENSG00000229463                                                NaN
# ENSG00000229291                                                NaN
#
#                 Mouse gene stable ID Mouse gene name  Gene name
# Gene stable ID
# ENSG00000210049                  NaN             NaN      MT-TF
# ENSG00000211459                  NaN             NaN    MT-RNR1
# ENSG00000210077                  NaN             NaN      MT-TV
# ENSG00000210082                  NaN             NaN    MT-RNR2
# ENSG00000209082                  NaN             NaN     MT-TL1
# ...                              ...             ...        ...
# ENSG00000232679                  NaN             NaN  LINC01705
# ENSG00000200033   ENSMUSG00000088001         Gm22883  RNU6-403P
# ENSG00000228437                  NaN             NaN  LINC02474
# ENSG00000229463                  NaN             NaN   LYST-AS1
# ENSG00000229291                  NaN             NaN  LINC02768
#
# [91822 rows x 5 columns]

# %% [markdown]
# ## Make all of the gene symbols all caps

# %% [markdown]
# Different species follow different gene nomenclature conventions. <br>
# For example, mouse genes have the first letter capitalized but the rest lowercase.<br>
# They need to be all caps for matching

# %%
mur_dros_ortho_df = convert_all_columns_to_uppercase(mur_dros_ortho_df)

# %% [markdown]
# ## Match aliases to orthologs!

# %% [markdown]
# ### Drosophila melanogaster

# %%
fruitfly_df = make_col_ortholog_match(subset_genes_df, mur_dros_ortho_df,"Drosophila melanogaster (Fruit fly)")
print(len(fruitfly_df))

# %% [markdown]
# ### Mouse

# %%
mouse_df = make_col_ortholog_match(subset_genes_df, mur_dros_ortho_df,"Mouse")
print(len(mouse_df))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 mouse_df = make_col_ortholog_match(subset_genes_df, mur_dros_ortho_df,"Mouse")
#       2 print(len(mouse_df))
#
# NameError: name 'make_col_ortholog_match' is not defined

# %%
fruitfly_mouse_df = pd.merge(fruitfly_df, mouse_df, how='inner', 
                  left_on=["gene_symbol", "alias_symbol", "HGNC_ID", "ENSG_ID","NCBI_ID", "source"],
                  right_on=["gene_symbol", "alias_symbol", "HGNC_ID", "ENSG_ID","NCBI_ID", "source"])
fruitfly_mouse_df[(fruitfly_mouse_df['DM Match']) & (fruitfly_mouse_df['Mouse Match'])]
# Out:
#       gene_symbol alias_symbol  HGNC_ID            ENSG_ID   NCBI_ID  \
# 9418        CCZ1B         CCZ1  {21717}  {ENSG00000146574}  {221960}
# 18951      EIF1AX        EIF1A   {3250}  {ENSG00000173674}    {1964}
# 59611       RAB7A         RAB7   {9788}  {ENSG00000075785}    {7879}
#
#              source  DM Match  Mouse Match
# 9418         {NCBI}      True         True
# 18951  {ENSG, NCBI}      True         True
# 59611  {ENSG, NCBI}      True         True

# %% [markdown]
# ### (1)Abingdon island giant tortoise
# ### (1)African ostrich
# ### (1)Algerian mouse

# %%
tortoise_ostrich_amouse_ortho_df = pd.read_csv(
    "downloaded_files/tortoise_ostrich_amouse_export.txt", sep=",")

# %%
ortholog_analysis_one_df, ortholog_analysis_one_counts = match_alias_to_ortholog(subset_genes_df, tortoise_ostrich_amouse_ortho_df)
print(ortholog_analysis_one_counts)
# Out:
# Added column: Abingdon island giant tortoise Match
# Added column: African ostrich Match
# Added column: Algerian mouse Match
# {'Abingdon island giant tortoise': 1, 'African ostrich': 2, 'Algerian mouse': 167}
#       gene_symbol  alias_symbol  HGNC_ID            ENSG_ID      NCBI_ID  \
# 0      A-GAMMA3'E     A-GAMMA-E       {}                 {}  {109951028}
# 1            A1BG           A1B      {5}  {ENSG00000121410}          {1}
# 2            A1BG           ABG      {5}  {ENSG00000121410}          {1}
# 3            A1BG           GAB      {5}  {ENSG00000121410}          {1}
# 4            A1BG      HYST2477      {5}  {ENSG00000121410}          {1}
# ...           ...           ...      ...                ...          ...
# 86768       ZZEF1      FLJ10821  {29027}  {ENSG00000074755}      {23140}
# 86769       ZZEF1      KIAA0399  {29027}  {ENSG00000074755}      {23140}
# 86770       ZZEF1          ZZZ4  {29027}  {ENSG00000074755}      {23140}
# 86771        ZZZ3         ATAC1  {24523}  {ENSG00000036549}      {26009}
# 86772        ZZZ3  DKFZP564I052  {24523}  {ENSG00000036549}      {26009}
#
#                    source  Abingdon island giant tortoise Match  \
# 0                  {NCBI}                                 False
# 1                  {NCBI}                                 False
# 2                  {NCBI}                                 False
# 3                  {NCBI}                                 False
# 4                  {NCBI}                                 False
# ...                   ...                                   ...
# 86768        {ENSG, HGNC}                                 False
# 86769        {ENSG, HGNC}                                 False
# 86770  {ENSG, HGNC, NCBI}                                 False
# 86771  {ENSG, HGNC, NCBI}                                 False
# 86772        {ENSG, HGNC}                                 False
#
#        African ostrich Match  Algerian mouse Match
# 0                      False                 False
# 1                      False                 False
# 2                      False                 False
# 3                      False                 False
# 4                      False                 False
# ...                      ...                   ...
# 86768                  False                 False
# 86769                  False                 False
# 86770                  False                 False
# 86771                  False                 False
# 86772                  False                 False
#
# [86773 rows x 9 columns]

# %%
ortholog_analysis_one_df.head()
# Out:
#       gene_symbol  alias_symbol  HGNC_ID            ENSG_ID      NCBI_ID  \
# 0      A-GAMMA3'E     A-GAMMA-E       {}                 {}  {109951028}
# 1            A1BG           A1B      {5}  {ENSG00000121410}          {1}
# 2            A1BG           ABG      {5}  {ENSG00000121410}          {1}
# 3            A1BG           GAB      {5}  {ENSG00000121410}          {1}
# 4            A1BG      HYST2477      {5}  {ENSG00000121410}          {1}
# ...           ...           ...      ...                ...          ...
# 86768       ZZEF1      FLJ10821  {29027}  {ENSG00000074755}      {23140}
# 86769       ZZEF1      KIAA0399  {29027}  {ENSG00000074755}      {23140}
# 86770       ZZEF1          ZZZ4  {29027}  {ENSG00000074755}      {23140}
# 86771        ZZZ3         ATAC1  {24523}  {ENSG00000036549}      {26009}
# 86772        ZZZ3  DKFZP564I052  {24523}  {ENSG00000036549}      {26009}
#
#                    source  Abingdon island giant tortoise Match  \
# 0                  {NCBI}                                 False
# 1                  {NCBI}                                 False
# 2                  {NCBI}                                 False
# 3                  {NCBI}                                 False
# 4                  {NCBI}                                 False
# ...                   ...                                   ...
# 86768        {ENSG, HGNC}                                 False
# 86769        {ENSG, HGNC}                                 False
# 86770  {ENSG, HGNC, NCBI}                                 False
# 86771  {ENSG, HGNC, NCBI}                                 False
# 86772        {ENSG, HGNC}                                 False
#
#        African ostrich Match  Algerian mouse Match
# 0                      False                 False
# 1                      False                 False
# 2                      False                 False
# 3                      False                 False
# 4                      False                 False
# ...                      ...                   ...
# 86768                  False                 False
# 86769                  False                 False
# 86770                  False                 False
# 86771                  False                 False
# 86772                  False                 False
#
# [86773 rows x 9 columns]

# %% [markdown]
# ### (2)Alpaca
# ### (2)Alpine marmot
# ### (2)Amazon molly
# ### (2)American bison
# ### (2)American black bear

# %%
Alpaca_Amarmot_Amolly_Abison_Ablackbear_ortho_df = pd.read_csv(
    "downloaded_files/Alpaca_Amarmot_Amolly_Abison_Ablackbear_mart_export.txt", sep=",")

# %%
ortholog_analysis_two_df, ortholog_analysis_two_counts = match_alias_to_ortholog(subset_genes_df, Alpaca_Amarmot_Amolly_Abison_Ablackbear_ortho_df)
print(ortholog_analysis_two_counts)
# Out:
# Added column: Alpaca Match
# Added column: Alpine marmot Match
# Added column: Amazon molly Match
# Added column: American bison Match
# Added column: American black bear Match
# {'Alpaca': 13, 'Alpine marmot': 8, 'Amazon molly': 101, 'American bison': 1, 'American black bear': 1}

# %%
ortholog_analysis_two_df.head()
# Out:
#   gene_symbol alias_symbol HGNC_ID            ENSG_ID      NCBI_ID  source  \
# 0  A-GAMMA3'E    A-GAMMA-E      {}                 {}  {109951028}  {NCBI}
# 1        A1BG          A1B     {5}  {ENSG00000121410}          {1}  {NCBI}
# 2        A1BG          ABG     {5}  {ENSG00000121410}          {1}  {NCBI}
# 3        A1BG          GAB     {5}  {ENSG00000121410}          {1}  {NCBI}
# 4        A1BG     HYST2477     {5}  {ENSG00000121410}          {1}  {NCBI}
#
#    Alpaca Match  Alpine marmot Match  Amazon molly Match  \
# 0         False                False               False
# 1         False                False               False
# 2         False                False               False
# 3         False                False               False
# 4         False                False               False
#
#    American bison Match  American black bear Match
# 0                 False                      False
# 1                 False                      False
# 2                 False                      False
# 3                 False                      False
# 4                 False                      False

# %% [markdown]
# ### (3)American Mink
# ### (3)Arabian camel
# ### (3)Arctic ground squirrel
# ### (3)Argentine black and white tegu
# ### (3)Armadillo
# ### (3)Asian bonytongue

# %%
Americanmink_Arabiancamel_Arcticsquirrel_Argentinetegu_Armadillo_Asianbonytongue_ortho_df = pd.read_csv(
    "downloaded_files/Americanmink_Arabiancamel_Arcticsquirrel_Argentinetegu_Armadillo_Asianbonytongue.txt", sep="\t")

# %%
ortholog_analysis_three_df, ortholog_analysis_three_counts = match_alias_to_ortholog(subset_genes_df, Americanmink_Arabiancamel_Arcticsquirrel_Argentinetegu_Armadillo_Asianbonytongue_ortho_df)
print(ortholog_analysis_three_counts)
# Out:
# Added column: American mink Match
# Added column: Arabian camel Match
# Added column: Arctic ground squirrel Match
# Added column: Argentine black and white tegu Match
# Added column: Armadillo Match
# Added column: Asian bonytongue Match
# {'American mink': 182, 'Arabian camel': 13, 'Arctic ground squirrel': 1, 'Argentine black and white tegu': 5, 'Armadillo': 17, 'Asian bonytongue': 91}

# %%
ortholog_analysis_three_df.head()
# Out:
#   gene_symbol alias_symbol HGNC_ID            ENSG_ID      NCBI_ID  source  \
# 0  A-GAMMA3'E    A-GAMMA-E      {}                 {}  {109951028}  {NCBI}
# 1        A1BG          A1B     {5}  {ENSG00000121410}          {1}  {NCBI}
# 2        A1BG          ABG     {5}  {ENSG00000121410}          {1}  {NCBI}
# 3        A1BG          GAB     {5}  {ENSG00000121410}          {1}  {NCBI}
# 4        A1BG     HYST2477     {5}  {ENSG00000121410}          {1}  {NCBI}
#
#    American mink Match  Arabian camel Match  Arctic ground squirrel Match  \
# 0                False                False                         False
# 1                False                False                         False
# 2                False                False                         False
# 3                False                False                         False
# 4                False                False                         False
#
#    Argentine black and white tegu Match  Armadillo Match  \
# 0                                 False            False
# 1                                 False            False
# 2                                 False            False
# 3                                 False            False
# 4                                 False            False
#
#    Asian bonytongue Match
# 0                   False
# 1                   False
# 2                   False
# 3                   False
# 4                   False

# %% [markdown]
# ### (4)Atlantic Cod
# ### (4)Atlantic herring
# ### (4)Atlantic salmon
# ### (4)Australian saltwater crocodile
# ### (4)Ballan wrasse

# %%
Atlanticcod_Atlanticherring_Atlanticsalmon_Australiancrocodile_Ballanwrasse_ortho_df = pd.read_csv(
    "downloaded_files/Atlanticcod_Atlanticherring_Atlanticsalmon_Australiancrocodile_Ballanwrasse.txt", sep=",")
Atlanticcod_Atlanticherring_Atlanticsalmon_Australiancrocodile_Ballanwrasse_ortho_df.head(50)
# Out:
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_3948/3250038618.py:1: DtypeWarning: Columns (1,3,4,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   Atlanticcod_Atlanticherring_Atlanticsalmon_Australiancrocodile_Ballanwrasse_ortho_df = pd.read_csv(
#    Gene name Atlantic cod gene name Atlantic herring  gene name  \
# 0      MT-TF                    NaN                         NaN
# 1    MT-RNR1                    NaN                         NaN
# 2      MT-TV                    NaN                         NaN
# 3    MT-RNR2                    NaN                         NaN
# 4     MT-TL1                    NaN                         NaN
# 5     MT-ND1                    NaN                         ND1
# 6     MT-ND1                    NaN                         ND1
# 7      MT-TI                    NaN                         NaN
# 8      MT-TQ                    NaN                         NaN
# 9      MT-TM                    NaN                         NaN
# 10    MT-ND2                    NaN                         ND2
# 11     MT-TW                    NaN                         NaN
# 12     MT-TA                    NaN                         NaN
# 13     MT-TN                    NaN                         NaN
# 14     MT-TC                    NaN                         NaN
# 15     MT-TY                    NaN                         NaN
# 16    MT-CO1                    NaN                        COX1
# 17    MT-TS1                    NaN                         NaN
# 18     MT-TD                    NaN                         NaN
# 19    MT-CO2                    NaN                        COX2
# 20     MT-TK                    NaN                         NaN
# 21   MT-ATP8                    NaN                         NaN
# 22   MT-ATP6                    NaN                        ATP6
# 23    MT-CO3                    NaN                        COX3
# 24     MT-TG                    NaN                         NaN
# 25    MT-ND3                    NaN                         ND3
# 26     MT-TR                    NaN                         NaN
# 27   MT-ND4L                    NaN                         NaN
# 28    MT-ND4                    NaN                         ND4
# 29     MT-TH                    NaN                         NaN
# 30    MT-TS2                    NaN                         NaN
# 31    MT-TL2                    NaN                         NaN
# 32    MT-ND5                    NaN                         ND5
# 33    MT-ND6                    NaN                         ND6
# 34    MT-ND6                    NaN                         ND6
# 35     MT-TE                    NaN                         NaN
# 36    MT-CYB                    NaN                        CYTB
# 37     MT-TT                    NaN                         NaN
# 38     MT-TP                    NaN                         NaN
# 39       NaN                    NaN                         NaN
# 40        U6                    NaN                         NaN
# 41   5S_rRNA                    NaN                         NaN
# 42       NaN                    NaN                         NaN
# 43     Y_RNA                    NaN                         NaN
# 44       NaN                    NaN                         NaN
# 45       NaN                    NaN                         NaN
# 46       NaN                   frg1                        frg1
# 47       NaN                   frg1                        frg1
# 48       NaN                    NaN                         NaN
# 49        U2                    NaN                         NaN
#
#    Atlantic salmon gene name Australian saltwater crocodile gene name  \
# 0                        NaN                                      NaN
# 1                        NaN                                      NaN
# 2                        NaN                                      NaN
# 3                        NaN                                      NaN
# 4                        NaN                                      NaN
# 5                        NaN                                      ND1
# 6                        NaN                                      ND1
# 7                        NaN                                      NaN
# 8                        NaN                                      NaN
# 9                        NaN                                      NaN
# 10                       NaN                                      ND2
# 11                       NaN                                      NaN
# 12                       NaN                                      NaN
# 13                       NaN                                      NaN
# 14                       NaN                                      NaN
# 15                       NaN                                      NaN
# 16                       NaN                                     COX1
# 17                       NaN                                      NaN
# 18                       NaN                                      NaN
# 19                       NaN                                     COX2
# 20                       NaN                                      NaN
# 21                       NaN                                      NaN
# 22                       NaN                                     ATP6
# 23                       NaN                                     COX3
# 24                       NaN                                      NaN
# 25                       NaN                                      ND3
# 26                       NaN                                      NaN
# 27                       NaN                                      NaN
# 28                       NaN                                      ND4
# 29                       NaN                                      NaN
# 30                       NaN                                      NaN
# 31                       NaN                                      NaN
# 32                       NaN                                      ND5
# 33                       NaN                                      NaN
# 34                       NaN                                      NaN
# 35                       NaN                                      NaN
# 36                       NaN                                     CYTB
# 37                       NaN                                      NaN
# 38                       NaN                                      NaN
# 39                       NaN                                      NaN
# 40                       NaN                                      NaN
# 41                       NaN                                      NaN
# 42                       NaN                                      NaN
# 43                       NaN                                      NaN
# 44                       NaN                                      NaN
# 45                       NaN                                      NaN
# 46                      frg1                                      NaN
# 47                      frg1                                      NaN
# 48                       NaN                                      NaN
# 49                       NaN                                      NaN
#
#    Ballan wrasse gene name
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# 5                      NaN
# 6                      NaN
# 7                      NaN
# 8                      NaN
# 9                      NaN
# 10                     NaN
# 11                     NaN
# 12                     NaN
# 13                     NaN
# 14                     NaN
# 15                     NaN
# 16                     NaN
# 17                     NaN
# 18                     NaN
# 19                     NaN
# 20                     NaN
# 21                     NaN
# 22                 mt-atp6
# 23                     NaN
# 24                     NaN
# 25                     NaN
# 26                     NaN
# 27                     NaN
# 28                     NaN
# 29                     NaN
# 30                     NaN
# 31                     NaN
# 32                     NaN
# 33                  mt-nd6
# 34                  mt-nd6
# 35                     NaN
# 36                     NaN
# 37                     NaN
# 38                     NaN
# 39                     NaN
# 40                     NaN
# 41                     NaN
# 42                     NaN
# 43                     NaN
# 44                     NaN
# 45                     NaN
# 46                    frg1
# 47                    frg1
# 48                     NaN
# 49                     NaN

# %%
Atlanticcod_Atlanticherring_Atlanticsalmon_Australiancrocodile_Ballanwrasse_ortho_df = Atlanticcod_Atlanticherring_Atlanticsalmon_Australiancrocodile_Ballanwrasse_ortho_df.groupby('Gene name', as_index=False).agg(combine_rows)

# %%
ortholog_analysis_four_df, ortholog_analysis_four_counts = match_alias_to_ortholog(subset_genes_df, Atlanticcod_Atlanticherring_Atlanticsalmon_Australiancrocodile_Ballanwrasse_ortho_df)
print(ortholog_analysis_four_counts)
# Out:
# Added column: Atlantic cod Match
# Added column: Atlantic herring Match
# Added column: Atlantic salmon Match
# Added column: Australian saltwater crocodile Match
# Added column: Ballan wrasse Match
# {'Atlantic cod': 49, 'Atlantic herring': 211, 'Atlantic salmon': 194, 'Australian saltwater crocodile': 12, 'Ballan wrasse': 85}

# %%
ortholog_analysis_four_df.head()
# Out:
#   gene_symbol alias_symbol HGNC_ID            ENSG_ID      NCBI_ID  source  \
# 0  A-GAMMA3'E    A-GAMMA-E      {}                 {}  {109951028}  {NCBI}
# 1        A1BG          A1B     {5}  {ENSG00000121410}          {1}  {NCBI}
# 2        A1BG          ABG     {5}  {ENSG00000121410}          {1}  {NCBI}
# 3        A1BG          GAB     {5}  {ENSG00000121410}          {1}  {NCBI}
# 4        A1BG     HYST2477     {5}  {ENSG00000121410}          {1}  {NCBI}
#
#    Atlantic cod Match  Atlantic herring Match  Atlantic salmon Match  \
# 0               False                   False                  False
# 1               False                   False                  False
# 2               False                   False                  False
# 3               False                   False                  False
# 4               False                   False                  False
#
#    Australian saltwater crocodile Match  Ballan wrasse Match
# 0                                 False                False
# 1                                 False                False
# 2                                 False                False
# 3                                 False                False
# 4                                 False                False

# %% [markdown]
# ### (5)Barramundi perch
# ### (5)Beluga whale
# ### (5)Bicolor damselfish
# ### (5)Black snub-nosed monkey
# ### (5)Blue whale

# %%
Barramundiperch_Belugawhale_Bicolordamselfish_Blacksnubnosedmonkey_Bluewhale_ortho_df = pd.read_csv(
    "downloaded_files/Barramundiperch_Belugawhale_Bicolordamselfish_Blacksnubnosedmonkey_Bluewhale.txt", sep=",")

# %%
ortholog_analysis_five_df, ortholog_analysis_five_counts = match_alias_to_ortholog(subset_genes_df, Barramundiperch_Belugawhale_Bicolordamselfish_Blacksnubnosedmonkey_Bluewhale_ortho_df)
print(ortholog_analysis_five_counts)
# Out:
# Added column: Barramundi perch Match
# Added column: Beluga whale Match
# Added column: Bicolor damselfish Match
# Added column: Black snub-nosed monkey Match
# Added column: Blue whale Match
# {'Barramundi perch': 95, 'Beluga whale': 228, 'Bicolor damselfish': 93, 'Black snub-nosed monkey': 14, 'Blue whale': 7}

# %%
Barramundiperch_Belugawhale_Bicolordamselfish_Blacksnubnosedmonkey_Bluewhale_ortho_df
# Out:
#         Gene name Barramundi perch gene name Beluga whale gene name  \
# 0           MT-TF                        NaN                    NaN
# 1         MT-RNR1                        NaN                    NaN
# 2           MT-TV                        NaN                    NaN
# 3         MT-RNR2                        NaN                    NaN
# 4          MT-TL1                        NaN                    NaN
# ...           ...                        ...                    ...
# 115851  LINC01705                        NaN                    NaN
# 115852  RNU6-403P                        NaN                    NaN
# 115853  LINC02474                        NaN                    NaN
# 115854   LYST-AS1                        NaN                    NaN
# 115855  LINC02768                        NaN                    NaN
#
#        Bicolor damselfish gene name Black snub-nosed monkey gene name  \
# 0                               NaN                               NaN
# 1                               NaN                               NaN
# 2                               NaN                               NaN
# 3                               NaN                               NaN
# 4                               NaN                               NaN
# ...                             ...                               ...
# 115851                          NaN                               NaN
# 115852                          NaN                               NaN
# 115853                          NaN                               NaN
# 115854                          NaN                               NaN
# 115855                          NaN                               NaN
#
#        Blue whale gene name
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# ...                     ...
# 115851                  NaN
# 115852                  NaN
# 115853                  NaN
# 115854                  NaN
# 115855                  NaN
#
# [115856 rows x 6 columns]

# %%
ortholog_analysis_five_df.head()
# Out:
#   gene_symbol alias_symbol HGNC_ID            ENSG_ID      NCBI_ID  source  \
# 0  A-GAMMA3'E    A-GAMMA-E      {}                 {}  {109951028}  {NCBI}
# 1        A1BG          A1B     {5}  {ENSG00000121410}          {1}  {NCBI}
# 2        A1BG          ABG     {5}  {ENSG00000121410}          {1}  {NCBI}
# 3        A1BG          GAB     {5}  {ENSG00000121410}          {1}  {NCBI}
# 4        A1BG     HYST2477     {5}  {ENSG00000121410}          {1}  {NCBI}
#
#    Barramundi perch Match  Beluga whale Match  Bicolor damselfish Match  \
# 0                   False               False                     False
# 1                   False               False                     False
# 2                   False               False                     False
# 3                   False               False                     False
# 4                   False               False                     False
#
#    Black snub-nosed monkey Match  Blue whale Match
# 0                          False             False
# 1                          False             False
# 2                          False             False
# 3                          False             False
# 4                          False             False

# %% [markdown]
# ### (6) Blue-ringed sea krait
# ### (6) Burton's mouthbrooder
# ### (6) C.intestinalis
# ### (6) C.savignyi
# ### (6) Caenorhabditis elegans (Nematode, N2)

# %%
Blueringedseakrait_Burtonmouthbrooder_Cintestinalis_Csavignyi_Caenorhabditiselegans_ortho_df = pd.read_csv(
    "downloaded_files/Blueringedseakrait_Burtonmouthbrooder_Cintestinalis_Csavignyi_Caenorhabditiselegans.txt", sep=",")
# Out:
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_3948/2484457589.py:1: DtypeWarning: Columns (1,3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   Blueringedseakrait_Burtonmouthbrooder_Cintestinalis_Csavignyi_Caenorhabditiselegans_ortho_df = pd.read_csv(

# %%
ortholog_analysis_six_df, ortholog_analysis_six_counts = match_alias_to_ortholog(subset_genes_df, Blueringedseakrait_Burtonmouthbrooder_Cintestinalis_Csavignyi_Caenorhabditiselegans_ortho_df)
print(ortholog_analysis_six_counts)
# Out:
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_3948/4030771151.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].str.upper()
# Added column: Blue-ringed sea krait Match
# Added column: Burton's mouthbrooder Match
# Added column: C.intestinalis Match
# Added column: C.savignyi Match
# Added column: Caenorhabditis elegans (Nematode, N2) Match
# {'Blue-ringed sea krait': 2, "Burton's mouthbrooder": 88, 'C.intestinalis': 34, 'C.savignyi': 9, 'Caenorhabditis elegans (Nematode, N2)': 101}

# %%
ortholog_analysis_six_df.head()
# Out:
#   gene_symbol alias_symbol HGNC_ID            ENSG_ID      NCBI_ID  source  \
# 0  A-GAMMA3'E    A-GAMMA-E      {}                 {}  {109951028}  {NCBI}
# 1        A1BG          A1B     {5}  {ENSG00000121410}          {1}  {NCBI}
# 2        A1BG          ABG     {5}  {ENSG00000121410}          {1}  {NCBI}
# 3        A1BG          GAB     {5}  {ENSG00000121410}          {1}  {NCBI}
# 4        A1BG     HYST2477     {5}  {ENSG00000121410}          {1}  {NCBI}
#
#    Blue-ringed sea krait Match  Burton's mouthbrooder Match  \
# 0                        False                        False
# 1                        False                        False
# 2                        False                        False
# 3                        False                        False
# 4                        False                        False
#
#    C.intestinalis Match  C.savignyi Match  \
# 0                 False             False
# 1                 False             False
# 2                 False             False
# 3                 False             False
# 4                 False             False
#
#    Caenorhabditis elegans (Nematode, N2) Match
# 0                                        False
# 1                                        False
# 2                                        False
# 3                                        False
# 4                                        False

# %% [markdown]
# ### (7) Cat
# ### (7) Chacoan peccary
# ### (7) Channel bull blenny
# ### (7) Channel catfish
# ### (7) Chicken

# %%
Cat_Chacoanpeccary_Channelbullblenny_Channelcatfish_Chicken_ortho_df = pd.read_csv(
    "downloaded_files/Cat_Chacoanpeccary_Channelbullblenny_Channelcatfish_Chicken.txt", sep=",")

# %%
ortholog_analysis_seven_df, ortholog_analysis_seven_counts = match_alias_to_ortholog(subset_genes_df, Cat_Chacoanpeccary_Channelbullblenny_Channelcatfish_Chicken_ortho_df)
print(ortholog_analysis_seven_counts)
# Out:
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_3948/4030771151.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].str.upper()
# Added column: Cat Match
# Added column: Chacoan peccary Match
# Added column: Channel bull blenny Match
# Added column: Channel catfish Match
# Added column: Chicken Match
# {'Cat': 30, 'Chacoan peccary': 10, 'Channel bull blenny': 129, 'Channel catfish': 172, 'Chicken': 154}

# %%
ortholog_analysis_seven_df.head()
# Out:
#   gene_symbol alias_symbol HGNC_ID            ENSG_ID      NCBI_ID  source  \
# 0  A-GAMMA3'E    A-GAMMA-E      {}                 {}  {109951028}  {NCBI}
# 1        A1BG          A1B     {5}  {ENSG00000121410}          {1}  {NCBI}
# 2        A1BG          ABG     {5}  {ENSG00000121410}          {1}  {NCBI}
# 3        A1BG          GAB     {5}  {ENSG00000121410}          {1}  {NCBI}
# 4        A1BG     HYST2477     {5}  {ENSG00000121410}          {1}  {NCBI}
#
#    Cat Match  Chacoan peccary Match  Channel bull blenny Match  \
# 0      False                  False                      False
# 1      False                  False                      False
# 2      False                  False                      False
# 3      False                  False                      False
# 4      False                  False                      False
#
#    Channel catfish Match  Chicken Match
# 0                  False          False
# 1                  False          False
# 2                  False          False
# 3                  False          False
# 4                  False          False

# %% [markdown]
# ## Summarize

# %%
print(globals().keys())
# Out:
# dict_keys(['__name__', '__doc__', '__package__', '__loader__', '__spec__', '__builtin__', '__builtins__', '_ih', '_oh', '_dh', 'In', 'Out', 'get_ipython', 'exit', 'quit', 'open', '_', '__', '___', '__vsc_ipynb_file__', '_i', '_ii', '_iii', '_i1', '_i2', 'pd', 'np', '_i3', 'remove_nan_from_set', '_i4', 'read_subset_genes_csv', '_i5', 'make_col_ortholog_match', '_i6', '_i7', '_i8', '_i9', '_i10', 'subset_genes_ensg_df', 'subset_genes_hgnc_df', 'subset_genes_ncbi_df', '_i11', 'subset_genes_df', '_11', '_i12', '_12', '_i13', '_i14', 'mur_dros_ortho_df', '_14', '_i15', '_i16', 'ortholog_match_subset_genes_df', '_i17', '_17', '_i18', '_i19', '_i20', '_i21', '_21', '_i22', '_22', '_i23', '_i24', '_24', '_i25', '_i26', 'fruitfly_df', '_i27', 'Atlanticcod_Atlanticherring_Atlanticsalmon_Australiancrocodile_Ballanwrasse_ortho_df', '_27', '_i28', '_28', '_i29', '_i30', '_i31', '_31', '_i32', '_i33', '_33', '_i34', '_i35', '_i36', '_36', '_i37', '_37', '_i38', '_i39', '_39', '_i40', '_40', '_i41', 'convert_all_columns_to_uppercase', '_i42', '_42', '_i43', '_43', '_i44', '_i45', '_45', '_i46', '_46', '_i47', '_47', '_i48', 'apply_to_all_animals', '_i49', '_i50', 'tortoise_ostrich_amouse_ortho_df', '_i51', '_i52', '_52', '_i53', '_i54', '_i55', '_i56', '_56', '_i57', '_i58', '_i59', '_i60', '_i61', '_61', '_i62', '_i63', '_i64', '_64', '_i65', '_i66', '_i67', '_i68', '_i69', '_69', '_i70', '_i71', '_i72', '_i73', '_i74', '_74', '_i75', '_75', '_i76', '_i77', '_i78', '_i79', '_79', '_i80', '_i81', '_i82', '_i83', '_i84', '_84', '_i85', '_i86', '_i87', 'match_alias_to_ortholog', '_i88', '_i89', '_i90', '_i91', 'ortholog_analysis_one_df', 'ortholog_analysis_one_counts', '_i92', 'Alpaca_Amarmot_Amolly_Abison_Ablackbear_ortho_df', '_i93', '_i94', '_i95', '_i96', '_96', '_i97', '_i98', 'ortholog_analysis_two_df', 'ortholog_analysis_two_counts', '_i99', '_99', '_i100', 'Americanmink_Arabiancamel_Arcticsquirrel_Argentinetegu_Armadillo_Asianbonytongue_ortho_df', '_i101', 'ortholog_analysis_three_df', 'ortholog_analysis_three_counts', '_i102', '_102', '_i103', '_i104', '_i105', '_105', '_i106', '_106', '_i107', '_i108', '_i109', '_i110', '_i111', 'Barramundiperch_Belugawhale_Bicolordamselfish_Blacksnubnosedmonkey_Bluewhale_ortho_df', '_i112', '_i113', '_i114', '_i115', 'ortholog_analysis_five_df', 'ortholog_analysis_five_counts', '_i116', '_116', '_i117', '_117', '_i118', '_118', '_i119', '_119', '_i120', '_120', '_i121', '_i122', '_122', '_i123', '_i124', '_i125', '_125', '_i126', '_i127', '_127', '_i128', '_i129', '_i130', '_130', '_i131', '_i132', '_i133', '_i134', '_i135', '_i136', '_i137', '_137', '_i138', '_138', '_i139', '_139', '_i140', '_140', '_i141', '_i142', '_142', '_i143', '_143', '_i144', '_144', '_i145', 'keep_row_with_most_nans', '_i146', 'duplicates', 'duplicate_rows', 'keep_row_with_least_nans', 'filtered_df', 'unique_rows', 'final_df', '_i147', '_147', '_i148', '_148', '_i149', '_i150', '_i151', '_151', '_i152', '_152', '_i153', '_153', '_i154', '_154', '_i155', '_155', '_i156', '_156', '_i157', '_i158', '_158', '_i159', '_i160', '_160', '_i161', '_161', '_i162', '_162', '_i163', '_163', '_i164', '_i165', '_i166', '_i167', '_167', '_i168', '_168', '_i169', '_169', '_i170', '_170', '_i171', '_i172', '_i173', '_173', '_i174', '_174', '_i175', '_175', '_i176', '_176', '_i177', '_177', '_i178', '_178', '_i179', '_i180', '_180', '_i181', '_181', '_i182', '_182', '_i183', '_183', '_i184', '_184', '_i185', '_185', '_i186', '_186', '_i187', '_187', '_i188', '_i189', '_189', '_i190', '_i191', '_i192', '_192', '_i193', '_193', '_i194', '_i195', '_195', '_i196', '_196', '_i197', '_197', '_i198', '_198', '_i199', 'combine_rows', 'df_combined', '_199', '_i200', '_i201', '_201', '_i202', '_i203', '_203', '_i204', '_i205', '_i206', '_206', '_i207', 'ortholog_analysis_four_df', 'ortholog_analysis_four_counts', '_i208', '_208', '_i209', '_i210', 'Blueringedseakrait_Burtonmouthbrooder_Cintestinalis_Csavignyi_Caenorhabditiselegans_ortho_df', '_i211', ...

# %%
list_of_ortholog_analysis_dfs = [value for key, value in globals().items() 
                if key.startswith('ortholog_analysis') 
                and key.endswith('_df') 
                and isinstance(value, pd.DataFrame)]
list_of_ortholog_analysis_dfs
# Out:
# [      gene_symbol  alias_symbol  HGNC_ID            ENSG_ID      NCBI_ID  \
#  0      A-GAMMA3'E     A-GAMMA-E       {}                 {}  {109951028}
#  1            A1BG           A1B      {5}  {ENSG00000121410}          {1}
#  2            A1BG           ABG      {5}  {ENSG00000121410}          {1}
#  3            A1BG           GAB      {5}  {ENSG00000121410}          {1}
#  4            A1BG      HYST2477      {5}  {ENSG00000121410}          {1}
#  ...           ...           ...      ...                ...          ...
#  86768       ZZEF1      FLJ10821  {29027}  {ENSG00000074755}      {23140}
#  86769       ZZEF1      KIAA0399  {29027}  {ENSG00000074755}      {23140}
#  86770       ZZEF1          ZZZ4  {29027}  {ENSG00000074755}      {23140}
#  86771        ZZZ3         ATAC1  {24523}  {ENSG00000036549}      {26009}
#  86772        ZZZ3  DKFZP564I052  {24523}  {ENSG00000036549}      {26009}
#
#                     source  Abingdon island giant tortoise Match  \
#  0                  {NCBI}                                 False
#  1                  {NCBI}                                 False
#  2                  {NCBI}                                 False
#  3                  {NCBI}                                 False
#  4                  {NCBI}                                 False
#  ...                   ...                                   ...
#  86768        {ENSG, HGNC}                                 False
#  86769        {ENSG, HGNC}                                 False
#  86770  {ENSG, HGNC, NCBI}                                 False
#  86771  {ENSG, HGNC, NCBI}                                 False
#  86772        {ENSG, HGNC}                                 False
#
#         African ostrich Match  Algerian mouse Match
#  0                      False                 False
#  1                      False                 False
#  2                      False                 False
#  3                      False                 False
#  4                      False                 False
#  ...                      ...                   ...
#  86768                  False                 False
#  86769                  False                 False
#  86770                  False                 False
#  86771                  False                 False
#  86772                  False                 False
#
#  [86773 rows x 9 columns],
#        gene_symbol  alias_symbol  HGNC_ID            ENSG_ID      NCBI_ID  \
#  0      A-GAMMA3'E     A-GAMMA-E       {}                 {}  {109951028}
#  1            A1BG           A1B      {5}  {ENSG00000121410}          {1}
#  2            A1BG           ABG      {5}  {ENSG00000121410}          {1}
#  3            A1BG           GAB      {5}  {ENSG00000121410}          {1}
#  4            A1BG      HYST2477      {5}  {ENSG00000121410}          {1}
#  ...           ...           ...      ...                ...          ...
#  86768       ZZEF1      FLJ10821  {29027}  {ENSG00000074755}      {23140}
#  86769       ZZEF1      KIAA0399  {29027}  {ENSG00000074755}      {23140}
#  86770       ZZEF1          ZZZ4  {29027}  {ENSG00000074755}      {23140}
#  86771        ZZZ3         ATAC1  {24523}  {ENSG00000036549}      {26009}
#  86772        ZZZ3  DKFZP564I052  {24523}  {ENSG00000036549}      {26009}
#
#                     source  Alpaca Match  Alpine marmot Match  \
#  0                  {NCBI}         False                False
#  1                  {NCBI}         False                False
#  2                  {NCBI}         False                False
#  3                  {NCBI}         False                False
#  4                  {NCBI}         False                False
#  ...                   ...           ...                  ...
#  86768        {ENSG, HGNC}         False                False
#  86769        {ENSG, HGNC}         False                False
#  86770  {ENSG, HGNC, NCBI}         False                False
#  86771  {ENSG, HGNC, NCBI}         False                False
#  86772        {ENSG, HGNC}         False                False
#
#         Amazon molly Match  American bison Match  American black bear Match
#  0                   False                 False                      False
#  1                   False                 False                      False
#  2                   False                 False                      False
#  3                   False                 False                      False
#  4                   False                 False                      False
#  ...                   ...                   ...                        ...
#  86768               False                 False                      False
#  86769               False                 False                      False
#  86770               False                 False                      False
#  86771               False                 False                      False
#  86772               False                 False                      False
#
#  [86773 rows x 11 columns],
#        gene_symbol  alias_symbol  HGNC_ID            ENSG_ID      NCBI_ID  \
#  0      A-GAMMA3'E     A-GAMMA-E       {}                 {}  {109951028}
#  1            A1BG           A1B      {5}  {ENSG00000121410}          {1}
#  2            A1BG           ABG      {5}  {ENSG00000121410}          {1}
#  3            A1BG           GAB      {5}  {ENSG00000121410}          {1}
#  4            A1BG      HYST2477      {5}  {ENSG00000121410}          {1}
#  ...           ...           ...      ...                ...          ...
#  86768       ZZEF1      FLJ10821  {29027}  {ENSG00000074755}      {23140}
#  86769       ZZEF1      KIAA0399  {29027}  {ENSG00000074755}      {23140}
#  86770       ZZEF1          ZZZ4  {29027}  {ENSG00000074755}      {23140}
#  86771        ZZZ3         ATAC1  {24523}  {ENSG00000036549}      {26009}
#  86772        ZZZ3  DKFZP564I052  {24523}  {ENSG00000036549}      {26009}
#
#                     source  American mink Match  Arabian camel Match  \
#  0                  {NCBI}                False                False
#  1                  {NCBI}                False                False
#  2                  {NCBI}                False                False
#  3                  {NCBI}                False                False
#  4                  {NCBI}                False                False
#  ...                   ...                  ...                  ...
#  86768        {ENSG, HGNC}                False                False
#  86769        {ENSG, HGNC}                False                False
#  86770  {ENSG, HGNC, NCBI}                False                False
#  86771  {ENSG, HGNC, NCBI}                False                False
#  86772        {ENSG, HGNC}                False                False
#
#         Arctic ground squirrel Match  Argentine black and white tegu Match  \
#  0                             False                                 False
#  1                             False                                 False
#  2                             False                                 False
#  3                             False                                 False
#  4                             False                                 False
#  ...                             ...                                   ...
#  86768                         False                                 False
#  86769                         False                                 False
#  86770                         False                                 False
#  86771                         False                                 False
#  86772                         False                                 False
#
#         Armadillo Match  Asian bonytongue Match
#  0                False                   False
#  1                False                   False
#  2                False                   False
#  3                False                   False
#  4                False                   False
#  ...                ...                     ...
#  86768            False                   False
#  86769            False                   False
#  86770            False                   False
#  86771            False                   False
#  86772            False                   False
#
#  [86773 rows x 12 columns],
#        gene_symbol  alias_symbol  HGNC_ID            ENSG_ID      NCBI_ID  \
#  0      A-GAMMA3'E     A-GAMMA-E       {}                 {}  {109951028}
#  1            A1BG           A1B      {5}  {ENSG00000121410}          {1}
#  2            A1BG           ABG      {5}  {ENSG00000121410}          {1}
#  3            A1BG           GAB      {5}  {ENSG00000121410}          {1}
#  4            A1BG      HYST2477      {5}  {ENSG00000121410}          {1}
#  ...           ...           ...      ...                ...          ...
#  86768       ZZEF1      FLJ10821  {29027}  {ENSG00000074755}      {23140}
#  86769       ZZEF1      KIAA0399  {29027}  {ENSG00000074755}      {23140}
#  86770       ZZEF1          ZZZ4  {29027}  {ENSG00000074755}      {23140}
#  86771        ZZZ3         ATAC1  {24523}  {ENSG00000036549}      {26009}
#  86772        ZZZ3  DKFZP564I052  {24523}  {ENSG00000036549}      {26009}
#
#                     source  Barramundi perch Match  Beluga whale Match  \
#  0                  {NCBI}                   False               False
#  1                  {NCBI}                   False               False
#  2                  {NCBI}                   False               False
#  3                  {NCBI}                   False               False
#  4                  {NCBI}                   False               False
#  ...                   ...                     ...                 ...
#  86768        {ENSG, HGNC}                   False               False
#  86769        {ENSG, HGNC}                   False               False
#  86770  {ENSG, HGNC, NCBI}                   False               False
#  86771  {ENSG, HGNC, NCBI}                   False               False
#  86772        {ENSG, HGNC}                   False               False
#
#         Bicolor damselfish Match  Black snub-nosed monkey Match  \
#  0                         False                          False
#  1                         False                          False
#  2                         False                          False
#  3                         False                          False
#  4                         False                          False
#  ...                         ...                            ...
#  86768                     False                          False
#  86769                     False                          False
#  86770                     False                          False
#  86771                     False                          False
#  86772                     False                          False
#
#         Blue whale Match
#  0                 False
#  1                 False
#  2                 False
#  3                 False
#  4                 False
#  ...                 ...
#  86768             False
#  86769             False
#  86770             False
#  86771             False
#  86772             False
#
#  [86773 rows x 11 columns],
#        gene_symbol  alias_symbol  HGNC_ID            ENSG_ID      NCBI_ID  \
#  0      A-GAMMA3'E     A-GAMMA-E       {}                 {}  {109951028}
#  1            A1BG           A1B      {5}  {ENSG00000121410}          {1}
#  2            A1BG           ABG      {5}  {ENSG00000121410}          {1}
#  3            A1BG           GAB      {5}  {ENSG00000121410}          {1}
#  4            A1BG      HYST2477      {5}  {ENSG00000121410}          {1}
#  ...           ...           ...      ...                ...          ...
#  86768       ZZEF1      FLJ10821  {29027}  {ENSG00000074755}      {23140}
#  86769       ZZEF1      KIAA0399  {29027}  {ENSG00000074755}      {23140}
#  86770       ZZEF1          ZZZ4  {29027}  {ENSG00000074755}      {23140}
#  86771        ZZZ3         ATAC1  {24523}  {ENSG00000036549}      {26009}
#  86772        ZZZ3  DKFZP564I052  {24523}  {ENSG00000036549}      {26009}
#
#                     source  Atlantic cod Match  Atlantic herring Match  \
#  0                  {NCBI}               False                   False
#  1                  {NCBI}               False                   False
#  2                  {NCBI}               False                   False
#  3                  {NCBI}               False                   False
#  4                  {NCBI}               False                   False
#  ...                   ...                 ...                     ...
#  86768        {ENSG, HGNC}               False                   False
#  86769        {ENSG, HGNC}               False                   False
#  86770  {ENSG, HGNC, NCBI}               False                   False
#  86771  {ENSG, HGNC, NCBI}               False                   False
#  86772        {ENSG, HGNC}               False                   False
#
#         Atlantic salmon Match  Australian saltwater crocodile Match  \
#  0                      False                                 False
#  1                      False                                 False
#  2                      False                                 False
#  3                      False                                 False
#  4                      False                                 False
#  ...                      ...                                   ...
#  86768                  False                                 False
#  86769                  False                                 False
#  86770                  False                                 False
#  86771                  False                                 False
#  86772                  False                                 False
#
#         Ballan wrasse Match
#  0                    False
#  1                    False
#  2                    False
#  3                    False
#  4                    False
#  ...                    ...
#  86768                False
#  86769                False
#  86770                False
#  86771                False
#  86772                False
#
#  [86773 rows x 11 columns],
#        gene_symbol  alias_symbol  HGNC_ID            ENSG_ID      NCBI_ID  \
#  0      A-GAMMA3'E     A-GAMMA-E       {}                 {}  {109951028}
#  1            A1BG           A1B      {5}  {ENSG00000121410}          {1}
#  2            A1BG           ABG      {5}  {ENSG00000121410}          {1}
#  3            A1BG           GAB      {5}  {ENSG00000121410}          {1}
#  4            A1BG      HYST2477      {5}  {ENSG00000121410}          {1}
#  ...           ...           ...      ...                ...          ...
#  86768       ZZEF1      FLJ10821  {29027}  {ENSG00000074755}      {23140}
#  86769       ZZEF1      KIAA0399  {29027}  {ENSG00000074755}      {23140}
#  86770       ZZEF1          ZZZ4  {29027}  {ENSG00000074755}      {23140}
#  86771        ZZZ3         ATAC1  {24523}  {ENSG00000036549}      {26009}
#  86772        ZZZ3  DKFZP564I052  {24523}  {ENSG00000036549}      {26009}
#
#                     source  Blue-ringed sea krait Match  \
#  0                  {NCBI}                        False
#  1                  {NCBI}                        False
#  2                  {NCBI}                        False
#  3                  {NCBI}                        False
#  4                  {NCBI}                        False
#  ...                   ...                          ...
#  86768        {ENSG, HGNC}                        False
#  86769        {ENSG, HGNC}                        False
#  86770  {ENSG, HGNC, NCBI}                        False
#  86771  {ENSG, HGNC, NCBI}                        False
#  86772        {ENSG, HGNC}                        False
#
#         Burton's mouthbrooder Match  C.intestinalis Match  C.savignyi Match  \
#  0                            False                 False             False
#  1                            False                 False             False
#  2                            False                 False             False
#  3                            False                 False             False
#  4                            False                 False             False
#  ...                            ...                   ...               ...
#  86768                        False                 False             False
#  86769                        False                 False             False
#  86770                        False                 False             False
#  86771                        False                 False             False
#  86772                        False                 False             False
#
#         Caenorhabditis elegans (Nematode, N2) Match
#  0                                            False
#  1                                            False
#  2                                            False
#  3                                            False
#  4                                            False
#  ...                                            ...
#  86768                                        False
#  86769                                        False
#  86770                                        False
#  86771                                        False
#  86772                                        False
#
#  [86773 rows x 11 columns],
#        gene_symbol  alias_symbol  HGNC_ID            ENSG_ID      NCBI_ID  \
#  0      A-GAMMA3'E     A-GAMMA-E       {}                 {}  {109951028}
#  1            A1BG           A1B      {5}  {ENSG00000121410}          {1}
#  2            A1BG           ABG      {5}  {ENSG00000121410}          {1}
#  3            A1BG           GAB      {5}  {ENSG00000121410}          {1}
#  4            A1BG      HYST2477      {5}  {ENSG00000121410}          {1}
#  ...           ...           ...      ...                ...          ...
#  86768       ZZEF1      FLJ10821  {29027}  {ENSG00000074755}      {23140}
#  86769       ZZEF1      KIAA0399  {29027}  {ENSG00000074755}      {23140}
#  86770       ZZEF1          ZZZ4  {29027}  {ENSG00000074755}      {23140}
#  86771        ZZZ3         ATAC1  {24523}  {ENSG00000036549}      {26009}
#  86772        ZZZ3  DKFZP564I052  {24523}  {ENSG00000036549}      {26009}
#
#                     source  Cat Match  Chacoan peccary Match  \
#  0                  {NCBI}      False                  False
#  1                  {NCBI}      False                  False
#  2                  {NCBI}      False                  False
#  3                  {NCBI}      False                  False
#  4                  {NCBI}      False                  False
#  ...                   ...        ...                    ...
#  86768        {ENSG, HGNC}      False                  False
#  86769        {ENSG, HGNC}      False                  False
#  86770  {ENSG, HGNC, NCBI}      False                  False
#  86771  {ENSG, HGNC, NCBI}      False                  False
#  86772        {ENSG, HGNC}      False                  False
#
#         Channel bull blenny Match  Channel catfish Match  Chicken Match
#  0                          False                  False          False
#  1                          False                  False          False
#  2                          False                  False          False
#  3                          False                  False          False
#  4                          False                  False          False
#  ...                          ...                    ...            ...
#  86768                      False                  False          False
#  86769                      False                  False          False
#  86770                      False                  False          False
#  86771                      False                  False          False
#  86772                      False                  False          False
#
#  [86773 rows x 11 columns]]

# %%
ortholog_analysis_df = subset_genes_df.copy()
for df in list_of_ortholog_analysis_dfs:
    ortholog_columns = df.iloc[:, 6:]
    ortholog_analysis_df = pd.concat([ortholog_analysis_df, ortholog_columns], axis=1)

ortholog_analysis_df.reset_index(drop=True, inplace=True)

# %%
ortholog_analysis_df
# Out:
#       gene_symbol  alias_symbol  HGNC_ID            ENSG_ID      NCBI_ID  \
# 0      A-GAMMA3'E     A-GAMMA-E       {}                 {}  {109951028}
# 1            A1BG           A1B      {5}  {ENSG00000121410}          {1}
# 2            A1BG           ABG      {5}  {ENSG00000121410}          {1}
# 3            A1BG           GAB      {5}  {ENSG00000121410}          {1}
# 4            A1BG      HYST2477      {5}  {ENSG00000121410}          {1}
# ...           ...           ...      ...                ...          ...
# 86768       ZZEF1      FLJ10821  {29027}  {ENSG00000074755}      {23140}
# 86769       ZZEF1      KIAA0399  {29027}  {ENSG00000074755}      {23140}
# 86770       ZZEF1          ZZZ4  {29027}  {ENSG00000074755}      {23140}
# 86771        ZZZ3         ATAC1  {24523}  {ENSG00000036549}      {26009}
# 86772        ZZZ3  DKFZP564I052  {24523}  {ENSG00000036549}      {26009}
#
#                    source  Abingdon island giant tortoise Match  \
# 0                  {NCBI}                                 False
# 1                  {NCBI}                                 False
# 2                  {NCBI}                                 False
# 3                  {NCBI}                                 False
# 4                  {NCBI}                                 False
# ...                   ...                                   ...
# 86768        {ENSG, HGNC}                                 False
# 86769        {ENSG, HGNC}                                 False
# 86770  {ENSG, HGNC, NCBI}                                 False
# 86771  {ENSG, HGNC, NCBI}                                 False
# 86772        {ENSG, HGNC}                                 False
#
#        African ostrich Match  Algerian mouse Match  Alpaca Match  ...  \
# 0                      False                 False         False  ...
# 1                      False                 False         False  ...
# 2                      False                 False         False  ...
# 3                      False                 False         False  ...
# 4                      False                 False         False  ...
# ...                      ...                   ...           ...  ...
# 86768                  False                 False         False  ...
# 86769                  False                 False         False  ...
# 86770                  False                 False         False  ...
# 86771                  False                 False         False  ...
# 86772                  False                 False         False  ...
#
#        Blue-ringed sea krait Match  Burton's mouthbrooder Match  \
# 0                            False                        False
# 1                            False                        False
# 2                            False                        False
# 3                            False                        False
# 4                            False                        False
# ...                            ...                          ...
# 86768                        False                        False
# 86769                        False                        False
# 86770                        False                        False
# 86771                        False                        False
# 86772                        False                        False
#
#        C.intestinalis Match  C.savignyi Match  \
# 0                     False             False
# 1                     False             False
# 2                     False             False
# 3                     False             False
# 4                     False             False
# ...                     ...               ...
# 86768                 False             False
# 86769                 False             False
# 86770                 False             False
# 86771                 False             False
# 86772                 False             False
#
#        Caenorhabditis elegans (Nematode, N2) Match  Cat Match  \
# 0                                            False      False
# 1                                            False      False
# 2                                            False      False
# 3                                            False      False
# 4                                            False      False
# ...                                            ...        ...
# 86768                                        False      False
# 86769                                        False      False
# 86770                                        False      False
# 86771                                        False      False
# 86772                                        False      False
#
#        Chacoan peccary Match  Channel bull blenny Match  \
# 0                      False                      False
# 1                      False                      False
# 2                      False                      False
# 3                      False                      False
# 4                      False                      False
# ...                      ...                        ...
# 86768                  False                      False
# 86769                  False                      False
# 86770                  False                      False
# 86771                  False                      False
# 86772                  False                      False
#
#        Channel catfish Match  Chicken Match
# 0                      False          False
# 1                      False          False
# 2                      False          False
# 3                      False          False
# 4                      False          False
# ...                      ...            ...
# 86768                  False          False
# 86769                  False          False
# 86770                  False          False
# 86771                  False          False
# 86772                  False          False
#
# [86773 rows x 40 columns]

# %%
ortholog_analysis_df.shape
# Out:
# (86773, 40)

# %%
ortholog_analysis_df.to_csv(
    "created_files/ortholog_analysis_df.csv", index=True
)

# %%
ortholog_analysis_df.loc[
    ortholog_analysis_df["alias_symbol"] == "CALMBP1"
]
# Out:
#      gene_symbol alias_symbol  HGNC_ID            ENSG_ID   NCBI_ID  \
# 4476        ASPM      CALMBP1  {19048}  {ENSG00000066279}  {259266}
#
#                   source  Abingdon island giant tortoise Match  \
# 4476  {ENSG, HGNC, NCBI}                                 False
#
#       African ostrich Match  Algerian mouse Match  Alpaca Match  ...  \
# 4476                  False                 False         False  ...
#
#       Blue-ringed sea krait Match  Burton's mouthbrooder Match  \
# 4476                        False                        False
#
#       C.intestinalis Match  C.savignyi Match  \
# 4476                 False             False
#
#       Caenorhabditis elegans (Nematode, N2) Match  Cat Match  \
# 4476                                        False      False
#
#       Chacoan peccary Match  Channel bull blenny Match  Channel catfish Match  \
# 4476                  False                      False                  False
#
#       Chicken Match
# 4476          False
#
# [1 rows x 40 columns]

# %% [markdown]
# how many gene alias pairs dont match any orthologs

# %%
no_ortholog_match_genes_df = ortholog_analysis_df[~ortholog_analysis_df.select_dtypes(include='bool').any(axis=1)]

# %%
no_ortholog_match_genes_df
# Out:
#       gene_symbol  alias_symbol  HGNC_ID            ENSG_ID      NCBI_ID  \
# 0      A-GAMMA3'E     A-GAMMA-E       {}                 {}  {109951028}
# 1            A1BG           A1B      {5}  {ENSG00000121410}          {1}
# 2            A1BG           ABG      {5}  {ENSG00000121410}          {1}
# 3            A1BG           GAB      {5}  {ENSG00000121410}          {1}
# 4            A1BG      HYST2477      {5}  {ENSG00000121410}          {1}
# ...           ...           ...      ...                ...          ...
# 86768       ZZEF1      FLJ10821  {29027}  {ENSG00000074755}      {23140}
# 86769       ZZEF1      KIAA0399  {29027}  {ENSG00000074755}      {23140}
# 86770       ZZEF1          ZZZ4  {29027}  {ENSG00000074755}      {23140}
# 86771        ZZZ3         ATAC1  {24523}  {ENSG00000036549}      {26009}
# 86772        ZZZ3  DKFZP564I052  {24523}  {ENSG00000036549}      {26009}
#
#                    source  Abingdon island giant tortoise Match  \
# 0                  {NCBI}                                 False
# 1                  {NCBI}                                 False
# 2                  {NCBI}                                 False
# 3                  {NCBI}                                 False
# 4                  {NCBI}                                 False
# ...                   ...                                   ...
# 86768        {ENSG, HGNC}                                 False
# 86769        {ENSG, HGNC}                                 False
# 86770  {ENSG, HGNC, NCBI}                                 False
# 86771  {ENSG, HGNC, NCBI}                                 False
# 86772        {ENSG, HGNC}                                 False
#
#        African ostrich Match  Algerian mouse Match  Alpaca Match  ...  \
# 0                      False                 False         False  ...
# 1                      False                 False         False  ...
# 2                      False                 False         False  ...
# 3                      False                 False         False  ...
# 4                      False                 False         False  ...
# ...                      ...                   ...           ...  ...
# 86768                  False                 False         False  ...
# 86769                  False                 False         False  ...
# 86770                  False                 False         False  ...
# 86771                  False                 False         False  ...
# 86772                  False                 False         False  ...
#
#        Blue-ringed sea krait Match  Burton's mouthbrooder Match  \
# 0                            False                        False
# 1                            False                        False
# 2                            False                        False
# 3                            False                        False
# 4                            False                        False
# ...                            ...                          ...
# 86768                        False                        False
# 86769                        False                        False
# 86770                        False                        False
# 86771                        False                        False
# 86772                        False                        False
#
#        C.intestinalis Match  C.savignyi Match  \
# 0                     False             False
# 1                     False             False
# 2                     False             False
# 3                     False             False
# 4                     False             False
# ...                     ...               ...
# 86768                 False             False
# 86769                 False             False
# 86770                 False             False
# 86771                 False             False
# 86772                 False             False
#
#        Caenorhabditis elegans (Nematode, N2) Match  Cat Match  \
# 0                                            False      False
# 1                                            False      False
# 2                                            False      False
# 3                                            False      False
# 4                                            False      False
# ...                                            ...        ...
# 86768                                        False      False
# 86769                                        False      False
# 86770                                        False      False
# 86771                                        False      False
# 86772                                        False      False
#
#        Chacoan peccary Match  Channel bull blenny Match  \
# 0                      False                      False
# 1                      False                      False
# 2                      False                      False
# 3                      False                      False
# 4                      False                      False
# ...                      ...                        ...
# 86768                  False                      False
# 86769                  False                      False
# 86770                  False                      False
# 86771                  False                      False
# 86772                  False                      False
#
#        Channel catfish Match  Chicken Match
# 0                      False          False
# 1                      False          False
# 2                      False          False
# 3                      False          False
# 4                      False          False
# ...                      ...            ...
# 86768                  False          False
# 86769                  False          False
# 86770                  False          False
# 86771                  False          False
# 86772                  False          False
#
# [85691 rows x 40 columns]

# %% [markdown]
# # HGNC Previous Symbol Analysis

# %% [markdown]
# ## Download the HGNC custom download including the gene symbol, ID, and previous symbols

# %%
hgnc_previous_symbols_df = pd.read_csv(
    "downloaded_files/HGNC_previous_symbols20241010.txt", sep="\t")
hgnc_previous_symbols_df
# Out:
#           HGNC ID Approved symbol             Previous symbols
# 0          HGNC:5            A1BG                          NaN
# 1      HGNC:37133        A1BG-AS1  NCRNA00181, A1BGAS, A1BG-AS
# 2      HGNC:24086            A1CF                          NaN
# 3          HGNC:6           A1S9T                          NaN
# 4          HGNC:7             A2M                          NaN
# ...           ...             ...                          ...
# 49077  HGNC:25820          ZYG11B                        ZYG11
# 49078  HGNC:13200             ZYX                          NaN
# 49079  HGNC:51695           ZYXP1                          NaN
# 49080  HGNC:29027           ZZEF1                          NaN
# 49081  HGNC:24523            ZZZ3                          NaN
#
# [49082 rows x 3 columns]

# %% [markdown]
# ## Remove all genes with no previous symbols

# %%
hgnc_previous_symbols_df = hgnc_previous_symbols_df.dropna(subset=["Previous symbols"])
hgnc_previous_symbols_df
# Out:
#           HGNC ID Approved symbol             Previous symbols
# 1      HGNC:37133        A1BG-AS1  NCRNA00181, A1BGAS, A1BG-AS
# 6      HGNC:23336           A2ML1                       CPAMD9
# 9          HGNC:8           A2MP1                         A2MP
# 12     HGNC:30005         A3GALT2                     A3GALT2P
# 13     HGNC:18149          A4GALT                           P1
# ...           ...             ...                          ...
# 49063  HGNC:23528          ZSWIM8                     KIAA0913
# 49065  HGNC:34495          ZSWIM9                     C19orf68
# 49066  HGNC:21224            ZUP1              C6orf113, ZUFSP
# 49071  HGNC:13197            ZWS1                          ZWS
# 49077  HGNC:25820          ZYG11B                        ZYG11
#
# [13067 rows x 3 columns]

# %% [markdown]
# ## Explode the previous symbols so that it is only one symbol per row

# %%
hgnc_previous_symbols_df["previous_symbol"] = hgnc_previous_symbols_df['Previous symbols'].str.split(',').apply(lambda x: [s.strip() for s in x])
hgnc_previous_symbols_df = hgnc_previous_symbols_df.explode('previous_symbol')
hgnc_previous_symbols_df = hgnc_previous_symbols_df.drop(columns=['Previous symbols'])
hgnc_previous_symbols_df
# Out:
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_83616/994957772.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hgnc_previous_symbols_df["previous_symbol"] = hgnc_previous_symbols_df['Previous symbols'].str.split(',').apply(lambda x: [s.strip() for s in x])
#           HGNC ID Approved symbol previous_symbol
# 1      HGNC:37133        A1BG-AS1      NCRNA00181
# 1      HGNC:37133        A1BG-AS1          A1BGAS
# 1      HGNC:37133        A1BG-AS1         A1BG-AS
# 6      HGNC:23336           A2ML1          CPAMD9
# 9          HGNC:8           A2MP1            A2MP
# ...           ...             ...             ...
# 49065  HGNC:34495          ZSWIM9        C19orf68
# 49066  HGNC:21224            ZUP1        C6orf113
# 49066  HGNC:21224            ZUP1           ZUFSP
# 49071  HGNC:13197            ZWS1             ZWS
# 49077  HGNC:25820          ZYG11B           ZYG11
#
# [16274 rows x 3 columns]

# %% [markdown]
# ## Make all of the gene symbols all caps

# %% [markdown]
# Different species follow different gene nomenclature conventions. <br>
# For example, mouse genes have the first letter capitalized but the rest lowercase.<br>
# They need to be all caps for matching

# %%
hgnc_previous_symbols_df["Approved symbol"] = hgnc_previous_symbols_df["Approved symbol"].str.upper()
hgnc_previous_symbols_df["previous_symbol"] = hgnc_previous_symbols_df["previous_symbol"].str.upper()

# %% [markdown]
# ## Match aliases to previous symbols!

# %%
previous_symbol_match_subset_genes_df = subset_genes_df.copy()
previous_symbol_match_subset_genes_df
# Out:
#       gene_symbol  alias_symbol  HGNC_ID            ENSG_ID      NCBI_ID  \
# 0      A-GAMMA3'E     A-GAMMA-E       {}                 {}  {109951028}
# 1            A1BG           A1B      {5}  {ENSG00000121410}          {1}
# 2            A1BG           ABG      {5}  {ENSG00000121410}          {1}
# 3            A1BG           GAB      {5}  {ENSG00000121410}          {1}
# 4            A1BG      HYST2477      {5}  {ENSG00000121410}          {1}
# ...           ...           ...      ...                ...          ...
# 86768       ZZEF1      FLJ10821  {29027}  {ENSG00000074755}      {23140}
# 86769       ZZEF1      KIAA0399  {29027}  {ENSG00000074755}      {23140}
# 86770       ZZEF1          ZZZ4  {29027}  {ENSG00000074755}      {23140}
# 86771        ZZZ3         ATAC1  {24523}  {ENSG00000036549}      {26009}
# 86772        ZZZ3  DKFZP564I052  {24523}  {ENSG00000036549}      {26009}
#
#                    source
# 0                  {NCBI}
# 1                  {NCBI}
# 2                  {NCBI}
# 3                  {NCBI}
# 4                  {NCBI}
# ...                   ...
# 86768        {HGNC, ENSG}
# 86769        {HGNC, ENSG}
# 86770  {HGNC, ENSG, NCBI}
# 86771  {HGNC, ENSG, NCBI}
# 86772        {HGNC, ENSG}
#
# [86773 rows x 6 columns]

# %%
previous_symbol_match_subset_genes_df["Previous Symbol Match"] = previous_symbol_match_subset_genes_df.apply(lambda row: 
                        any((hgnc_previous_symbols_df['Approved symbol'] == row['gene_symbol']) 
                            & 
                            (hgnc_previous_symbols_df["previous_symbol"] == row['alias_symbol'])), axis=1)
previous_symbol_match_df = previous_symbol_match_subset_genes_df[previous_symbol_match_subset_genes_df["Previous Symbol Match"]]
previous_symbol_match_df
# Out:
#       gene_symbol alias_symbol  HGNC_ID                             ENSG_ID  \
# 5        A1BG-AS1      A1BG-AS  {37133}                   {ENSG00000268895}
# 6        A1BG-AS1       A1BGAS  {37133}                   {ENSG00000268895}
# 8        A1BG-AS1   NCRNA00181  {37133}                   {ENSG00000268895}
# 18          A2ML1       CPAMD9  {23336}                   {ENSG00000166535}
# 22          A2MP1         A2MP      {8}  {ENSG00000291190, ENSG00000256069}
# ...           ...          ...      ...                                 ...
# 86738      ZSWIM8     KIAA0913  {23528}                   {ENSG00000214655}
# 86739      ZSWIM9     C19ORF68  {34495}                   {ENSG00000185453}
# 86741        ZUP1     C6ORF113  {21224}                   {ENSG00000153975}
# 86744        ZUP1        ZUFSP  {21224}                   {ENSG00000153975}
# 86765      ZYG11B        ZYG11  {25820}                   {ENSG00000162378}
#
#         NCBI_ID        source  Previous Symbol Match
# 5      {503538}  {ENSG, NCBI}                   True
# 6      {503538}  {ENSG, NCBI}                   True
# 8      {503538}  {ENSG, NCBI}                   True
# 18     {144568}  {ENSG, NCBI}                   True
# 22          {3}  {ENSG, NCBI}                   True
# ...         ...           ...                    ...
# 86738   {23053}  {ENSG, NCBI}                   True
# 86739  {374920}  {ENSG, NCBI}                   True
# 86741  {221302}  {ENSG, NCBI}                   True
# 86744  {221302}  {ENSG, NCBI}                   True
# 86765   {79699}  {ENSG, NCBI}                   True
#
# [15585 rows x 7 columns]

# %%
previous_symbol_match_subset_genes_df.head(20)
# Out:
#    gene_symbol alias_symbol  HGNC_ID            ENSG_ID      NCBI_ID  \
# 0   A-GAMMA3'E    A-GAMMA-E       {}                 {}  {109951028}
# 1         A1BG          A1B      {5}  {ENSG00000121410}          {1}
# 2         A1BG          ABG      {5}  {ENSG00000121410}          {1}
# 3         A1BG          GAB      {5}  {ENSG00000121410}          {1}
# 4         A1BG     HYST2477      {5}  {ENSG00000121410}          {1}
# 5     A1BG-AS1      A1BG-AS  {37133}  {ENSG00000268895}     {503538}
# 6     A1BG-AS1       A1BGAS  {37133}  {ENSG00000268895}     {503538}
# 7     A1BG-AS1     FLJ23569  {37133}  {ENSG00000268895}     {503538}
# 8     A1BG-AS1   NCRNA00181  {37133}  {ENSG00000268895}     {503538}
# 9         A1CF          ACF  {24086}  {ENSG00000148584}      {29974}
# 10        A1CF        ACF64  {24086}  {ENSG00000148584}      {29974}
# 11        A1CF        ACF65  {24086}  {ENSG00000148584}      {29974}
# 12        A1CF    APOBEC1CF  {24086}  {ENSG00000148584}      {29974}
# 13        A1CF          ASP  {24086}  {ENSG00000148584}      {29974}
# 14         A2M         A2MD      {7}  {ENSG00000175899}          {2}
# 15         A2M       CPAMD5      {7}  {ENSG00000175899}          {2}
# 16         A2M       FWP007      {7}  {ENSG00000175899}          {2}
# 17         A2M       S863-7      {7}  {ENSG00000175899}          {2}
# 18       A2ML1       CPAMD9  {23336}  {ENSG00000166535}     {144568}
# 19       A2ML1     FLJ25179  {23336}  {ENSG00000166535}     {144568}
#
#                 source  Previous Symbol Match
# 0               {NCBI}                  False
# 1               {NCBI}                  False
# 2               {NCBI}                  False
# 3               {NCBI}                  False
# 4               {NCBI}                  False
# 5         {ENSG, NCBI}                   True
# 6         {ENSG, NCBI}                   True
# 7         {HGNC, ENSG}                  False
# 8         {ENSG, NCBI}                   True
# 9   {HGNC, ENSG, NCBI}                  False
# 10  {HGNC, ENSG, NCBI}                  False
# 11  {HGNC, ENSG, NCBI}                  False
# 12  {HGNC, ENSG, NCBI}                  False
# 13  {HGNC, ENSG, NCBI}                  False
# 14              {NCBI}                  False
# 15  {HGNC, ENSG, NCBI}                  False
# 16  {HGNC, ENSG, NCBI}                  False
# 17  {HGNC, ENSG, NCBI}                  False
# 18        {ENSG, NCBI}                   True
# 19        {HGNC, ENSG}                  False

# %% [markdown]
# # Clone Names Analysis

# %% [markdown]
# ## Download the FLJ database file including FLJ IDs
# - https://flj.lifesciencedb.jp/top/sys_info/02_about_database/accession_no/download_v032.html
# - https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2780955/
# - https://www.ncbi.nlm.nih.gov/nuccore/AK027222?report=GenBank

# %%
with open("downloaded_files/Conversion_table_FLJ(1).txt", 'r') as file:
    for i, line in enumerate(file):
        print(f"Line {i}: {line.strip()}")

# %%
clone_symbols_df = pd.read_csv(
    "downloaded_files/Conversion_table_FLJ(1).txt", 
    sep="\t", 
    skiprows=3
)
clone_symbols_df
# Out:
#       Accesion No              FLJ ID      Clone ID     Sequence ID  \
# 0        AK075326  PSEC0001(FLJ91001)  NT2RM1000066  C-NT2RM1000066
# 1        AK172724  PSEC0002(FLJ91002)  NT2RM1000295  C-NT2RM1000295
# 2        AK075327  PSEC0003(FLJ91003)  NT2RM1000361  C-NT2RM1000361
# 3        AK075328  PSEC0004(FLJ91004)  NT2RM1000558  C-NT2RM1000558
# 4        AK075329  PSEC0005(FLJ91005)  NT2RM1000566  C-NT2RM1000566
# ...           ...                 ...           ...             ...
# 30321    AK057825            FLJ25096      CBR00778      C-CBR00778
# 30322    AK000479            FLJ20472      KAT07023      C-KAT07023
# 30323    AK125921            FLJ43933  TESTI4013685  C-TESTI4013685
# 30324    AK125959            FLJ43971  TESTI4017901  C-TESTI4017901
# 30325    AK000594            FLJ20587      KAT09116      C-KAT09116
#
#        Another Sequence ID
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# ...                    ...
# 30321                  NaN
# 30322                  NaN
# 30323                  NaN
# 30324                  NaN
# 30325                  NaN
#
# [30326 rows x 5 columns]

# %%
extracted_ids = clone_symbols_df['FLJ ID'].str.extract(r'([^()]+)\((.+?)\)')

result_rows = []

# Extract values from the FLJ column so that there is only one ID per row
for index, row in clone_symbols_df.iterrows():
    flj_id = row['FLJ ID']
    if pd.notnull(extracted_ids.iloc[index, 0]):
        result_rows.append({'Accesion No': row['Accesion No'], 'ID': extracted_ids.iloc[index, 0]})  # First part
        result_rows.append({'Accesion No': row['Accesion No'], 'ID': extracted_ids.iloc[index, 1]})  # Second part
    else:
        result_rows.append({'Accesion No': row['Accesion No'], 'ID': flj_id})  # Keep the original if no match

result_df = pd.DataFrame(result_rows)

result_df
# Out:
#       Accesion No        ID
# 0        AK075326  PSEC0001
# 1        AK075326  FLJ91001
# 2        AK172724  PSEC0002
# 3        AK172724  FLJ91002
# 4        AK075327  PSEC0003
# ...           ...       ...
# 30581    AK057825  FLJ25096
# 30582    AK000479  FLJ20472
# 30583    AK125921  FLJ43933
# 30584    AK125959  FLJ43971
# 30585    AK000594  FLJ20587
#
# [30586 rows x 2 columns]

# %%
result_df.loc[
    result_df["ID"] == "FLJ25179"
]
# Out:
#       Accesion No        ID
# 11650    AK057908  FLJ25179

# %%
result_df["ID"] = result_df["ID"].str.strip()

# %%
previous_symbol_match_subset_genes_df = subset_genes_df.copy()
previous_symbol_match_subset_genes_df
# Out:
#       gene_symbol  alias_symbol  HGNC_ID            ENSG_ID      NCBI_ID  \
# 0      A-GAMMA3'E     A-GAMMA-E       {}                 {}  {109951028}
# 1            A1BG           A1B      {5}  {ENSG00000121410}          {1}
# 2            A1BG           ABG      {5}  {ENSG00000121410}          {1}
# 3            A1BG           GAB      {5}  {ENSG00000121410}          {1}
# 4            A1BG      HYST2477      {5}  {ENSG00000121410}          {1}
# ...           ...           ...      ...                ...          ...
# 86768       ZZEF1      FLJ10821  {29027}  {ENSG00000074755}      {23140}
# 86769       ZZEF1      KIAA0399  {29027}  {ENSG00000074755}      {23140}
# 86770       ZZEF1          ZZZ4  {29027}  {ENSG00000074755}      {23140}
# 86771        ZZZ3         ATAC1  {24523}  {ENSG00000036549}      {26009}
# 86772        ZZZ3  DKFZP564I052  {24523}  {ENSG00000036549}      {26009}
#
#                    source
# 0                  {NCBI}
# 1                  {NCBI}
# 2                  {NCBI}
# 3                  {NCBI}
# 4                  {NCBI}
# ...                   ...
# 86768        {HGNC, ENSG}
# 86769        {HGNC, ENSG}
# 86770  {HGNC, ENSG, NCBI}
# 86771  {HGNC, ENSG, NCBI}
# 86772        {HGNC, ENSG}
#
# [86773 rows x 6 columns]

# %%
previous_symbol_match_subset_genes_df["Clone Symbol Match"] = previous_symbol_match_subset_genes_df['alias_symbol'].isin(result_df['ID'])

df = previous_symbol_match_subset_genes_df[previous_symbol_match_subset_genes_df["Clone Symbol Match"]]
previous_symbol_match_subset_genes_df.head(20)
# Out:
#    gene_symbol alias_symbol  HGNC_ID            ENSG_ID      NCBI_ID  \
# 0   A-GAMMA3'E    A-GAMMA-E       {}                 {}  {109951028}
# 1         A1BG          A1B      {5}  {ENSG00000121410}          {1}
# 2         A1BG          ABG      {5}  {ENSG00000121410}          {1}
# 3         A1BG          GAB      {5}  {ENSG00000121410}          {1}
# 4         A1BG     HYST2477      {5}  {ENSG00000121410}          {1}
# 5     A1BG-AS1      A1BG-AS  {37133}  {ENSG00000268895}     {503538}
# 6     A1BG-AS1       A1BGAS  {37133}  {ENSG00000268895}     {503538}
# 7     A1BG-AS1     FLJ23569  {37133}  {ENSG00000268895}     {503538}
# 8     A1BG-AS1   NCRNA00181  {37133}  {ENSG00000268895}     {503538}
# 9         A1CF          ACF  {24086}  {ENSG00000148584}      {29974}
# 10        A1CF        ACF64  {24086}  {ENSG00000148584}      {29974}
# 11        A1CF        ACF65  {24086}  {ENSG00000148584}      {29974}
# 12        A1CF    APOBEC1CF  {24086}  {ENSG00000148584}      {29974}
# 13        A1CF          ASP  {24086}  {ENSG00000148584}      {29974}
# 14         A2M         A2MD      {7}  {ENSG00000175899}          {2}
# 15         A2M       CPAMD5      {7}  {ENSG00000175899}          {2}
# 16         A2M       FWP007      {7}  {ENSG00000175899}          {2}
# 17         A2M       S863-7      {7}  {ENSG00000175899}          {2}
# 18       A2ML1       CPAMD9  {23336}  {ENSG00000166535}     {144568}
# 19       A2ML1     FLJ25179  {23336}  {ENSG00000166535}     {144568}
#
#                 source  Clone Symbol Match
# 0               {NCBI}               False
# 1               {NCBI}               False
# 2               {NCBI}               False
# 3               {NCBI}               False
# 4               {NCBI}               False
# 5         {ENSG, NCBI}               False
# 6         {ENSG, NCBI}               False
# 7         {HGNC, ENSG}                True
# 8         {ENSG, NCBI}               False
# 9   {HGNC, ENSG, NCBI}               False
# 10  {HGNC, ENSG, NCBI}               False
# 11  {HGNC, ENSG, NCBI}               False
# 12  {HGNC, ENSG, NCBI}               False
# 13  {HGNC, ENSG, NCBI}               False
# 14              {NCBI}               False
# 15  {HGNC, ENSG, NCBI}               False
# 16  {HGNC, ENSG, NCBI}               False
# 17  {HGNC, ENSG, NCBI}               False
# 18        {ENSG, NCBI}               False
# 19        {HGNC, ENSG}                True

# %%
df
# Out:
#       gene_symbol alias_symbol  HGNC_ID                             ENSG_ID  \
# 7        A1BG-AS1     FLJ23569  {37133}                   {ENSG00000268895}
# 19          A2ML1     FLJ25179  {23336}                   {ENSG00000166535}
# 45           AACS     FLJ12389  {21298}                   {ENSG00000081760}
# 56          AAGAB     FLJ11506  {25662}                   {ENSG00000103591}
# 65          AAMDC     FLJ21035  {30205}                   {ENSG00000087884}
# ...           ...          ...      ...                                 ...
# 86729      ZSWIM4     FLJ12221  {25704}  {ENSG00000132003, ENSG00000288360}
# 86747      ZWILCH     FLJ10036  {25468}                   {ENSG00000174442}
# 86760        ZXDC     FLJ13861  {28160}                   {ENSG00000070476}
# 86764      ZYG11B     FLJ13456  {25820}                   {ENSG00000162378}
# 86768       ZZEF1     FLJ10821  {29027}                   {ENSG00000074755}
#
#         NCBI_ID        source  Clone Symbol Match
# 7      {503538}  {HGNC, ENSG}                True
# 19     {144568}  {HGNC, ENSG}                True
# 45      {65985}  {HGNC, ENSG}                True
# 56      {79719}  {HGNC, ENSG}                True
# 65      {28971}  {HGNC, ENSG}                True
# ...         ...           ...                 ...
# 86729   {65249}  {HGNC, ENSG}                True
# 86747   {55055}  {HGNC, ENSG}                True
# 86760   {79364}  {HGNC, ENSG}                True
# 86764   {79699}  {HGNC, ENSG}                True
# 86768   {23140}  {HGNC, ENSG}                True
#
# [3585 rows x 7 columns]

# %% [markdown]
# # Gene Family Analysis

# %%
hgnc_genefamilies_df = pd.read_csv(
    "downloaded_files/hgnc_genefamily.csv", sep=",")
hgnc_genefamilies_df
# Out:
#         id abbreviation                                          name  \
# 0        3         FSCN                                 Fascin family
# 1        4         ABHD                 Abhydrolase domain containing
# 2        6        ZYG11             ZYG11 cell cycle regulator family
# 3        8           ZP                  Zona pellucida glycoproteins
# 4       10          VNN                                  Vanin family
# ...    ...          ...                                           ...
# 1810  3338          NaN                                  WICH complex
# 1811  3339          NaN                                  NoRC complex
# 1812  3340          NaN                                   RSF complex
# 1813  3341          NaN  ATP-dependent chromatin remodeling complexes
# 1814  3342          NaN                        Zinc fingers CHHC-type
#
#      external_note          pubmed_ids  \
# 0              NaN            21618240
# 1              NaN            23328280
# 2              NaN                 NaN
# 3              NaN            15760956
# 4              NaN            22155241
# ...            ...                 ...
# 1810           NaN            21326359
# 1811           NaN                 NaN
# 1812           NaN                 NaN
# 1813           NaN            19355820
# 1814           NaN  18703587, 19217400
#
#                                            desc_comment  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3     There are four major zona pellucida glycoprote...
# 4                                                   NaN
# ...                                                 ...
# 1810  Chromatin remodeling complex required for main...
# 1811  NoRC remodels nucleosomes at the rDNA promoter...
# 1812  A nucleosome remodeling complex that participa...
# 1813                                                NaN
# 1814  The CHHC U11-48K-type zinc finger contains fou...
#
#                          desc_label  \
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3      Zona pellucida glycoproteins
# 4                               NaN
# ...                             ...
# 1810                   WICH complex
# 1811                   NoRC complex
# 1812                    RSF complex
# 1813                            NaN
# 1814  U11-48K-like CHHC zinc finger
#
#                                             desc_source desc_go typical_gene
# 0                                                   NaN     NaN        FSCN1
# 1                                                   NaN     NaN        ABHD1
# 2                                                   NaN     NaN          NaN
# 3     Wikipedia|https://en.wikipedia.org/wiki/Zona p...     NaN          ZP1
# 4                                                   NaN     NaN         VNN1
# ...                                                 ...     ...          ...
# 1810  Complex portal|https://www.ebi.ac.uk/complexpo...     NaN          NaN
# 1811  Complex Portal|https://www.ebi.ac.uk/complexpo...     NaN          NaN
# 1812  Complex Portal|https://www.ebi.ac.uk/complexpo...     NaN          NaN
# 1813                                                NaN     NaN          NaN
# 1814  InterPro|https://www.ebi.ac.uk/interpro/entry/...     NaN       TRMT13
#
# [1815 rows x 10 columns]

# %%
hgnc_genefamilies_df = hgnc_genefamilies_df[["id","abbreviation"]]
hgnc_genefamilies_df
# Out:
#         id abbreviation
# 0        3         FSCN
# 1        4         ABHD
# 2        6        ZYG11
# 3        8           ZP
# 4       10          VNN
# ...    ...          ...
# 1810  3338          NaN
# 1811  3339          NaN
# 1812  3340          NaN
# 1813  3341          NaN
# 1814  3342          NaN
#
# [1815 rows x 2 columns]

# %%
hgnc_genefamilies_df.rename(columns={'id': 'Gene group ID'}, inplace=True)
hgnc_genefamilies_df
# Out:
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_3948/2218688468.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hgnc_genefamilies_df.rename(columns={'id': 'Gene group ID'}, inplace=True)
#       Gene group ID abbreviation
# 0                 3         FSCN
# 1                 4         ABHD
# 2                 6        ZYG11
# 3                 8           ZP
# 4                10          VNN
# ...             ...          ...
# 1810           3338          NaN
# 1811           3339          NaN
# 1812           3340          NaN
# 1813           3341          NaN
# 1814           3342          NaN
#
# [1815 rows x 2 columns]

# %%
hgnc_gene_groupid_df = pd.read_csv(
    "downloaded_files/hgnc_id_symbol_genegroupid.txt", sep="\t")
hgnc_gene_groupid_df
# Out:
#           HGNC ID Approved symbol Gene group ID
# 0          HGNC:5            A1BG           594
# 1      HGNC:37133        A1BG-AS1          1987
# 2      HGNC:24086            A1CF           725
# 3          HGNC:6           A1S9T           NaN
# 4          HGNC:7             A2M          2148
# ...           ...             ...           ...
# 49078  HGNC:25820          ZYG11B        6|1492
# 49079  HGNC:13200             ZYX     1402|1691
# 49080  HGNC:51695           ZYXP1           NaN
# 49081  HGNC:29027           ZZEF1        91|863
# 49082  HGNC:24523            ZZZ3   91|532|1058
#
# [49083 rows x 3 columns]

# %%
hgnc_gene_groupid_df['HGNC ID'] = hgnc_gene_groupid_df['HGNC ID'].str.replace('^HGNC:', '', regex=True)

# %%
hgnc_gene_groupid_df['Gene group ID'] = hgnc_gene_groupid_df['Gene group ID'].str.split('|')
hgnc_gene_groupid_df = hgnc_gene_groupid_df.explode('Gene group ID')

# %%
hgnc_gene_groupid_df = hgnc_gene_groupid_df.dropna(subset=['Gene group ID'])

# %%
hgnc_gene_groupid_df['Gene group ID'] = hgnc_gene_groupid_df['Gene group ID'].astype(int)

# %%
hgnc_gene_group_root_df = hgnc_gene_groupid_df.merge(hgnc_genefamilies_df, on='Gene group ID', how='left')

# %%
hgnc_gene_group_root_df
# Out:
#       HGNC ID Approved symbol  Gene group ID abbreviation
# 0           5            A1BG            594          NaN
# 1       37133        A1BG-AS1           1987          NaN
# 2       24086            A1CF            725          RBM
# 3           7             A2M           2148          NaN
# 4       27057         A2M-AS1           1987          NaN
# ...       ...             ...            ...          ...
# 31399   29027           ZZEF1             91          ZZZ
# 31400   29027           ZZEF1            863          NaN
# 31401   24523            ZZZ3             91          ZZZ
# 31402   24523            ZZZ3            532          NaN
# 31403   24523            ZZZ3           1058         ATAC
#
# [31404 rows x 4 columns]

# %%
hgnc_gene_group_root_df = hgnc_gene_group_root_df.dropna(subset=['abbreviation'])

# %%
hgnc_gene_group_root_df["abbreviation"] = hgnc_gene_group_root_df["abbreviation"].str.upper()
hgnc_gene_group_root_df["Approved symbol"] = hgnc_gene_group_root_df["Approved symbol"].str.upper()
# Out:
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_3948/3423886471.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hgnc_gene_group_root_df["abbreviation"] = hgnc_gene_group_root_df["abbreviation"].str.upper()
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_3948/3423886471.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hgnc_gene_group_root_df["Approved symbol"] = hgnc_gene_group_root_df["Approved symbol"].str.upper()

# %%
gene_group_analysis_df = subset_genes_df.copy()
gene_group_analysis_df
# Out:
#       gene_symbol  alias_symbol  HGNC_ID            ENSG_ID      NCBI_ID  \
# 0      A-GAMMA3'E     A-GAMMA-E       {}                 {}  {109951028}
# 1            A1BG           A1B      {5}  {ENSG00000121410}          {1}
# 2            A1BG           ABG      {5}  {ENSG00000121410}          {1}
# 3            A1BG           GAB      {5}  {ENSG00000121410}          {1}
# 4            A1BG      HYST2477      {5}  {ENSG00000121410}          {1}
# ...           ...           ...      ...                ...          ...
# 86768       ZZEF1      FLJ10821  {29027}  {ENSG00000074755}      {23140}
# 86769       ZZEF1      KIAA0399  {29027}  {ENSG00000074755}      {23140}
# 86770       ZZEF1          ZZZ4  {29027}  {ENSG00000074755}      {23140}
# 86771        ZZZ3         ATAC1  {24523}  {ENSG00000036549}      {26009}
# 86772        ZZZ3  DKFZP564I052  {24523}  {ENSG00000036549}      {26009}
#
#                    source
# 0                  {NCBI}
# 1                  {NCBI}
# 2                  {NCBI}
# 3                  {NCBI}
# 4                  {NCBI}
# ...                   ...
# 86768        {ENSG, HGNC}
# 86769        {ENSG, HGNC}
# 86770  {ENSG, HGNC, NCBI}
# 86771  {ENSG, HGNC, NCBI}
# 86772        {ENSG, HGNC}
#
# [86773 rows x 6 columns]

# %%
gene_group_analysis_df["Gene Group Symbol Match"] = gene_group_analysis_df.apply(lambda row: 
                        any((hgnc_gene_group_root_df['Approved symbol'] == row['gene_symbol']) 
                            & 
                            (hgnc_gene_group_root_df["abbreviation"] == row['alias_symbol'])), axis=1)
gene_group_match_df = gene_group_analysis_df[gene_group_analysis_df["Gene Group Symbol Match"]]
gene_group_match_df
# Out:
#       gene_symbol alias_symbol  HGNC_ID            ENSG_ID   NCBI_ID  \
# 219         ABCC1         ABCC     {51}  {ENSG00000103222}    {4363}
# 451          ABL1          ABL     {76}  {ENSG00000097007}      {25}
# 817         ACSS2          ACS  {15814}  {ENSG00000131069}   {55902}
# 846        ACTBL2          ACT  {17780}  {ENSG00000169067}  {345651}
# 856         ACTG1          ACT    {144}  {ENSG00000184009}      {71}
# ...           ...          ...      ...                ...       ...
# 86152      ZNF569          ZNF  {24737}  {ENSG00000196437}  {148266}
# 86235      ZNF629          ZNF  {29008}  {ENSG00000102870}   {23361}
# 86433      ZNF763          ZNF  {27614}  {ENSG00000197054}  {284390}
# 86763      ZYG11A        ZYG11  {32058}  {ENSG00000203995}  {440590}
# 86765      ZYG11B        ZYG11  {25820}  {ENSG00000162378}   {79699}
#
#                    source  Gene Group Symbol Match
# 219                {NCBI}                     True
# 451          {ENSG, NCBI}                     True
# 817    {ENSG, HGNC, NCBI}                     True
# 846                {NCBI}                     True
# 856                {NCBI}                     True
# ...                   ...                      ...
# 86152              {NCBI}                     True
# 86235              {NCBI}                     True
# 86433              {NCBI}                     True
# 86763  {ENSG, HGNC, NCBI}                     True
# 86765        {ENSG, NCBI}                     True
#
# [231 rows x 7 columns]

# %%
gene_group_analysis_df["Gene Group Symbol Match"] = gene_group_analysis_df.apply(lambda row: 
                        any((hgnc_gene_group_root_df['Approved symbol'] == row['gene_symbol']) 
                            & 
                            (hgnc_gene_group_root_df["abbreviation"].str.extract(r'([A-Za-z]+)')[0] == row['alias_symbol'].str.extract(r'([A-Za-z]+)')[0])), axis=1)
gene_group_match_df = gene_group_analysis_df[gene_group_analysis_df["Gene Group Symbol Match"]]
gene_group_match_df
