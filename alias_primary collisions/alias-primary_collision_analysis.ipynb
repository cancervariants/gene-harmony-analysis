# %% [markdown]
# ### Import

# %%
import pandas as pd
import numpy as np
from civicpy import civic as civicpy

# %%
civic_molprof_ids = civicpy.get_all_molecular_profiles(
    include_status=["accepted", "submitted", "rejected"]
)

# %%
civic_variant_ids = civicpy.get_all_variants()

# %%
def transform_df_mp_id(df: pd.DataFrame) -> pd.DataFrame:
    """Transform dataframe to include molecular profile ID information

    :param df: Dataframe of variants
    :return: Transformed dataframe with molecular profile ID information
    """
    tmp_df = df.copy(deep=True)

    variants_molprof_ids = []
    variant_ids = list(tmp_df["civic_ids"])

    for v_id in variant_ids:
        variant_molprof_ids = []

        for variant in civic_variant_ids:
            if int(v_id) == variant.id:
                for mp in variant.molecular_profiles:
                    if mp.id not in variant_molprof_ids:
                        variant_molprof_ids.append(mp.id)

        variants_molprof_ids.append(variant_molprof_ids or "")

    tmp_df["molecular_profile_id"] = variants_molprof_ids
    return tmp_df

# %%
def transform_df_mp_score(df: pd.DataFrame) -> pd.DataFrame:
    """Transform dataframe to include molecular profile score information

    :param df: Dataframe of variants
    :return: Transformed dataframe with molecular profile score information
    """
    variants_molprof_scores = []
    normalized_variant_molprof_ids = list(df["molecular_profile_id"])

    for mp_ids in normalized_variant_molprof_ids:
        variant_molprof_scores = []
        for mp_id in mp_ids:
            for molprof in civic_molprof_ids:
                if int(mp_id) == molprof.id:
                    if molprof.molecular_profile_score not in variant_molprof_scores:
                        variant_molprof_scores.append(molprof.molecular_profile_score)

        variants_molprof_scores.append(variant_molprof_scores or "")

    df["molecular_profile_score"] = variants_molprof_scores
    return df

# %% [markdown]
# # Ensembl

# %%
mini_ensg_df = pd.read_csv(
    "../downloaded_files/ensg_biomart_gene20240626.txt", sep="\t",dtype={"NCBI gene (formerly Entrezgene) ID": pd.Int64Dtype()}
)
mini_ensg_df = mini_ensg_df.rename(
    columns={
        "HGNC ID": "HGNC_ID",
        "Gene Synonym": "alias_symbol",
        "Gene name": "gene_symbol",
        "Gene stable ID": "ENSG_ID",
        "NCBI gene (formerly Entrezgene) ID": "NCBI_ID",
    }
)
mini_ensg_df
# Out:
#                 ENSG_ID gene_symbol   alias_symbol     HGNC_ID  NCBI_ID
# 0       ENSG00000210049       MT-TF           MTTF   HGNC:7481      NaN
# 1       ENSG00000210049       MT-TF           TRNF   HGNC:7481      NaN
# 2       ENSG00000211459     MT-RNR1            12S   HGNC:7470      NaN
# 3       ENSG00000211459     MT-RNR1         MOTS-C   HGNC:7470      NaN
# 4       ENSG00000211459     MT-RNR1         MTRNR1   HGNC:7470      NaN
# ...                 ...         ...            ...         ...      ...
# 117135  ENSG00000200033   RNU6-403P            NaN  HGNC:47366      NaN
# 117136  ENSG00000228437   LINC02474       LNCSLCC1  HGNC:53417      NaN
# 117137  ENSG00000228437   LINC02474  RP11-400N13.2  HGNC:53417      NaN
# 117138  ENSG00000229463    LYST-AS1       LYST-IT2  HGNC:41320      NaN
# 117139  ENSG00000229291   LINC02768            NaN  HGNC:54288      NaN
#
# [117140 rows x 5 columns]

# %%
mini_ensg_df["alias_symbol"] = mini_ensg_df["alias_symbol"].fillna("").astype(str)
mini_ensg_df = (
    mini_ensg_df.groupby(
        ["ENSG_ID", "gene_symbol", "HGNC_ID", "NCBI_ID"], dropna=False
    )["alias_symbol"]
    .apply(lambda x: ", ".join(x.dropna()))
    .reset_index()
)
mini_ensg_df
# Out:
#                ENSG_ID gene_symbol     HGNC_ID      NCBI_ID  \
# 0      ENSG00000000003      TSPAN6  HGNC:11858       7105.0
# 1      ENSG00000000005        TNMD  HGNC:17757      64102.0
# 2      ENSG00000000419        DPM1   HGNC:3005       8813.0
# 3      ENSG00000000457       SCYL3  HGNC:19285      57147.0
# 4      ENSG00000000460       FIRRM  HGNC:25565      55732.0
# ...                ...         ...         ...          ...
# 75829  ENSG00000293596         NaN         NaN  105372654.0
# 75830  ENSG00000293597   LINC00970  HGNC:48730  101978719.0
# 75831  ENSG00000293599         NaN         NaN          NaN
# 75832  ENSG00000293600         NaN         NaN  131768270.0
# 75833  ENSG00000293604       ORAI1  HGNC:25896      84876.0
#
#                                    alias_symbol
# 0                         T245, TM4SF6, TSPAN-6
# 1          BRICD4, CHM1L, MYODULIN, TEM, TENDIN
# 2                                   CDGIE, MPDS
# 3                                 PACE-1, PACE1
# 4      APOLO1, C1ORF112, FLIP, FLJ10706, MEICA1
# ...                                         ...
# 75829
# 75830
# 75831
# 75832
# 75833                CRACM1, FLJ14466, TMEM142A
#
# [75834 rows x 5 columns]

# %%
# mini_ensg_df["NCBI_ID"] = mini_ensg_df["NCBI_ID"].astype(str).str.removesuffix(".0")
# mini_ensg_df
# Out:
#                ENSG_ID gene_symbol     HGNC_ID    NCBI_ID  \
# 0      ENSG00000000003      TSPAN6  HGNC:11858       7105
# 1      ENSG00000000005        TNMD  HGNC:17757      64102
# 2      ENSG00000000419        DPM1   HGNC:3005       8813
# 3      ENSG00000000457       SCYL3  HGNC:19285      57147
# 4      ENSG00000000460       FIRRM  HGNC:25565      55732
# ...                ...         ...         ...        ...
# 75829  ENSG00000293596         NaN         NaN  105372654
# 75830  ENSG00000293597   LINC00970  HGNC:48730  101978719
# 75831  ENSG00000293599         NaN         NaN        nan
# 75832  ENSG00000293600         NaN         NaN  131768270
# 75833  ENSG00000293604       ORAI1  HGNC:25896      84876
#
#                                    alias_symbol
# 0                         T245, TM4SF6, TSPAN-6
# 1          BRICD4, CHM1L, MYODULIN, TEM, TENDIN
# 2                                   CDGIE, MPDS
# 3                                 PACE-1, PACE1
# 4      APOLO1, C1ORF112, FLIP, FLJ10706, MEICA1
# ...                                         ...
# 75829
# 75830
# 75831
# 75832
# 75833                CRACM1, FLJ14466, TMEM142A
#
# [75834 rows x 5 columns]

# %%
mini_ensg_df["HGNC_ID"] = mini_ensg_df["HGNC_ID"].str.lstrip("HGNC:")
mini_ensg_df
# Out:
#                ENSG_ID gene_symbol HGNC_ID    NCBI_ID  \
# 0      ENSG00000000003      TSPAN6   11858       7105
# 1      ENSG00000000005        TNMD   17757      64102
# 2      ENSG00000000419        DPM1    3005       8813
# 3      ENSG00000000457       SCYL3   19285      57147
# 4      ENSG00000000460       FIRRM   25565      55732
# ...                ...         ...     ...        ...
# 75829  ENSG00000293596         NaN     NaN  105372654
# 75830  ENSG00000293597   LINC00970   48730  101978719
# 75831  ENSG00000293599         NaN     NaN        nan
# 75832  ENSG00000293600         NaN     NaN  131768270
# 75833  ENSG00000293604       ORAI1   25896      84876
#
#                                    alias_symbol
# 0                         T245, TM4SF6, TSPAN-6
# 1          BRICD4, CHM1L, MYODULIN, TEM, TENDIN
# 2                                   CDGIE, MPDS
# 3                                 PACE-1, PACE1
# 4      APOLO1, C1ORF112, FLIP, FLJ10706, MEICA1
# ...                                         ...
# 75829
# 75830
# 75831
# 75832
# 75833                CRACM1, FLJ14466, TMEM142A
#
# [75834 rows x 5 columns]

# %%
mini_ensg_df.to_csv("../created_files/mini_ensg_df.csv", index=False)
mini_ensg_df.head()
# Out:
#            ENSG_ID gene_symbol HGNC_ID NCBI_ID  \
# 0  ENSG00000000003      TSPAN6   11858    7105
# 1  ENSG00000000005        TNMD   17757   64102
# 2  ENSG00000000419        DPM1    3005    8813
# 3  ENSG00000000457       SCYL3   19285   57147
# 4  ENSG00000000460       FIRRM   25565   55732
#
#                                alias_symbol
# 0                     T245, TM4SF6, TSPAN-6
# 1      BRICD4, CHM1L, MYODULIN, TEM, TENDIN
# 2                               CDGIE, MPDS
# 3                             PACE-1, PACE1
# 4  APOLO1, C1ORF112, FLIP, FLJ10706, MEICA1

# %% [markdown]
# One gene symbol may have multiple NCBI IDs

# %%
mini_ensg_df["symbol_duplicates"] = mini_ensg_df.duplicated(
    subset="gene_symbol", keep=False
)
dup_symbol_mini_ensg_df = mini_ensg_df[mini_ensg_df["symbol_duplicates"] == True]
dup_symbol_mini_ensg_df
# Out:
#                ENSG_ID gene_symbol HGNC_ID    NCBI_ID  \
# 23     ENSG00000002586        CD99    7082       4267
# 66     ENSG00000004866         ST7   11351       7982
# 67     ENSG00000004866         ST7   11351      93655
# 73     ENSG00000005001      PRSS22   14368      64063
# 104    ENSG00000005700        IBTK   17853      25998
# ...                ...         ...     ...        ...
# 75829  ENSG00000293596         NaN     NaN  105372654
# 75830  ENSG00000293597   LINC00970   48730  101978719
# 75831  ENSG00000293599         NaN     NaN        nan
# 75832  ENSG00000293600         NaN     NaN  131768270
# 75833  ENSG00000293604       ORAI1   25896      84876
#
#                                        alias_symbol  symbol_duplicates
# 23                               MIC2, MIC2X, MIC2Y               True
# 66     ETS7Q, FAM4A, FAM4A1, HELG, RAY1, SEN4, TSG7               True
# 67     ETS7Q, FAM4A, FAM4A1, HELG, RAY1, SEN4, TSG7               True
# 73                         BSSP-4, HBSSP-4, SP001LA               True
# 104                      BTBD26, BTKI, DKFZP564B116               True
# ...                                             ...                ...
# 75829                                                             True
# 75830                                                             True
# 75831                                                             True
# 75832                                                             True
# 75833                    CRACM1, FLJ14466, TMEM142A               True
#
# [38380 rows x 6 columns]

# %%
mini_ensg_df.loc[mini_ensg_df["gene_symbol"] == "ST7"]
# Out:
#             ENSG_ID gene_symbol HGNC_ID NCBI_ID  \
# 66  ENSG00000004866         ST7   11351    7982
# 67  ENSG00000004866         ST7   11351   93655
#
#                                     alias_symbol  symbol_duplicates
# 66  ETS7Q, FAM4A, FAM4A1, HELG, RAY1, SEN4, TSG7               True
# 67  ETS7Q, FAM4A, FAM4A1, HELG, RAY1, SEN4, TSG7               True

# %%
mini_ensg_df = mini_ensg_df.drop("symbol_duplicates", axis=1)
mini_ensg_df
# Out:
#                ENSG_ID gene_symbol HGNC_ID    NCBI_ID  \
# 0      ENSG00000000003      TSPAN6   11858       7105
# 1      ENSG00000000005        TNMD   17757      64102
# 2      ENSG00000000419        DPM1    3005       8813
# 3      ENSG00000000457       SCYL3   19285      57147
# 4      ENSG00000000460       FIRRM   25565      55732
# ...                ...         ...     ...        ...
# 75829  ENSG00000293596         NaN     NaN  105372654
# 75830  ENSG00000293597   LINC00970   48730  101978719
# 75831  ENSG00000293599         NaN     NaN        nan
# 75832  ENSG00000293600         NaN     NaN  131768270
# 75833  ENSG00000293604       ORAI1   25896      84876
#
#                                    alias_symbol
# 0                         T245, TM4SF6, TSPAN-6
# 1          BRICD4, CHM1L, MYODULIN, TEM, TENDIN
# 2                                   CDGIE, MPDS
# 3                                 PACE-1, PACE1
# 4      APOLO1, C1ORF112, FLIP, FLJ10706, MEICA1
# ...                                         ...
# 75829
# 75830
# 75831
# 75832
# 75833                CRACM1, FLJ14466, TMEM142A
#
# [75834 rows x 5 columns]

# %% [markdown]
# ### Make a set of the primary gene symbols

# %%
ensg_gene_symbol_set = set(mini_ensg_df["gene_symbol"])

# %%
total_number_ensembl_gene_symbols = len(ensg_gene_symbol_set)
total_number_ensembl_gene_symbols
# Out:
# 41068

# %% [markdown]
# Drop genes with no aliases

# %%
mini_ensg_df = mini_ensg_df[
    ~mini_ensg_df["alias_symbol"].isnull() & (mini_ensg_df["alias_symbol"] != "")
]
mini_ensg_df
# Out:
#                ENSG_ID gene_symbol HGNC_ID NCBI_ID  \
# 0      ENSG00000000003      TSPAN6   11858    7105
# 1      ENSG00000000005        TNMD   17757   64102
# 2      ENSG00000000419        DPM1    3005    8813
# 3      ENSG00000000457       SCYL3   19285   57147
# 4      ENSG00000000460       FIRRM   25565   55732
# ...                ...         ...     ...     ...
# 75796  ENSG00000293549       HCG22     NaN  285834
# 75798  ENSG00000293551    PRAMEF22   34393  653606
# 75801  ENSG00000293555    FAM169BP   26835  283777
# 75828  ENSG00000293595   SLC25A3P1   26869  163742
# 75833  ENSG00000293604       ORAI1   25896   84876
#
#                                    alias_symbol
# 0                         T245, TM4SF6, TSPAN-6
# 1          BRICD4, CHM1L, MYODULIN, TEM, TENDIN
# 2                                   CDGIE, MPDS
# 3                                 PACE-1, PACE1
# 4      APOLO1, C1ORF112, FLIP, FLJ10706, MEICA1
# ...                                         ...
# 75796                                   PBMUCL2
# 75798                                  PRAMEF3L
# 75801              FAM169B, FLJ39743, KIAA0888L
# 75828                                  FLJ40434
# 75833                CRACM1, FLJ14466, TMEM142A
#
# [31851 rows x 5 columns]

# %% [markdown]
# ### Make each row in alias_symbol a set:
#     covert to a list
#     make a set

# %%
mini_ensg_df["alias_symbol"] = mini_ensg_df["alias_symbol"].astype(str)
mini_ensg_df["alias_symbol"] = [x.split(",") for x in mini_ensg_df.alias_symbol]
mini_ensg_df["alias_symbol"] = np.where(
    mini_ensg_df.alias_symbol == "", "", mini_ensg_df.alias_symbol.map(set)
)
mini_ensg_df.head(1)
# Out:
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_24200/2288946268.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mini_ensg_df["alias_symbol"] = mini_ensg_df["alias_symbol"].astype(str)
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_24200/2288946268.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mini_ensg_df["alias_symbol"] = [x.split(",") for x in mini_ensg_df.alias_symbol]
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_24200/2288946268.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mini_ensg_df["alias_symbol"] = np.where(
#            ENSG_ID gene_symbol HGNC_ID NCBI_ID               alias_symbol
# 0  ENSG00000000003      TSPAN6   11858    7105  {T245,  TM4SF6,  TSPAN-6}

# %% [markdown]
# ## Test for false positives (when a gene symbol has an alias that is exactly the same as the primary gene symbol)

# %%
mini_ensg_df["gene_symbol"] = mini_ensg_df["gene_symbol"].map(str)
print(mini_ensg_df.dtypes)
# Out:
# ENSG_ID         object
# gene_symbol     object
# HGNC_ID         object
# NCBI_ID         object
# alias_symbol    object
# dtype: object
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_24200/1166746605.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mini_ensg_df["gene_symbol"] = mini_ensg_df["gene_symbol"].map(str)

# %%
mini_ensg_df["gene_symbol"] = [x.split(",") for x in mini_ensg_df.gene_symbol]
mini_ensg_df["gene_symbol"] = np.where(
    mini_ensg_df.gene_symbol == "", "", mini_ensg_df.gene_symbol.map(set)
)
false_pos_mini_ensg_df = mini_ensg_df[
    mini_ensg_df.alias_symbol.apply(lambda x: x & ensg_gene_symbol_set)
    == mini_ensg_df.gene_symbol
]
false_pos_mini_ensg_df
# Out:
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_24200/1936330568.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mini_ensg_df["gene_symbol"] = [x.split(",") for x in mini_ensg_df.gene_symbol]
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_24200/1936330568.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mini_ensg_df["gene_symbol"] = np.where(
#                ENSG_ID gene_symbol HGNC_ID NCBI_ID  \
# 3004   ENSG00000104883    {PEX11G}   20208   92960
# 6532   ENSG00000131779    {PEX11B}    8853    8799
# 8199   ENSG00000141622     {ARK2C}   31696  494470
# 9578   ENSG00000152242     {ARK2N}   28172  147339
# 12749  ENSG00000169717    {ACTRT2}   24026  140625
# 33923  ENSG00000232795  {SCAND3P1}   42037     nan
# 47393  ENSG00000257400    {LNCHR1}   56254     nan
# 58590  ENSG00000275410     {HNF1B}   11630    6928
# 59459  ENSG00000276194     {HNF1B}   11630    6928
#
#                                            alias_symbol
# 3004                              {PEX11G,  PEX11GAMMA}
# 6532                               { PEX11BETA, PEX11B}
# 8199      { RNF111L2,  RNF165,  ARKL2, ARK2C,  LNCAMPC}
# 9578   { RNF111L1,  ARKL1, ARK2N,  MGC12909,  C18ORF25}
# 12749              { ARP-T2,  FLJ25424,  ARPM2, ACTRT2}
# 33923                              { ZBED9P1, SCAND3P1}
# 47393                                          {LNCHR1}
# 58590  { HNF1BETA,  MODY5,  LFB3, HNF1B,  VHNF1,  TCF2}
# 59459  { HNF1BETA,  MODY5,  LFB3, HNF1B,  VHNF1,  TCF2}

# %% [markdown]
# ### Need to remove aliases that match their primary key (gene symbol)

# %%
mini_ensg_df["alias_symbol"] = mini_ensg_df.alias_symbol - mini_ensg_df.gene_symbol
false_pos_mini_ensg_df = mini_ensg_df[
    mini_ensg_df.alias_symbol.apply(lambda x: x & ensg_gene_symbol_set)
    == mini_ensg_df.gene_symbol
]
false_pos_mini_ensg_df
# Out:
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_24200/3565006765.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mini_ensg_df["alias_symbol"] = mini_ensg_df.alias_symbol - mini_ensg_df.gene_symbol
# Empty DataFrame
# Columns: [ENSG_ID, gene_symbol, HGNC_ID, NCBI_ID, alias_symbol]
# Index: []

# %%
mini_ensg_df.loc[mini_ensg_df["NCBI_ID"] == "92960"]
# Out:
#               ENSG_ID gene_symbol HGNC_ID NCBI_ID   alias_symbol
# 3004  ENSG00000104883    {PEX11G}   20208   92960  { PEX11GAMMA}

# %% [markdown]
# ## Find intersection points using alias symbol sets

# %%
# alias_symbol_sets_series = mini_ensg_df.alias_symbol

# %%
mini_ensg_df["intersect_point"] = mini_ensg_df.alias_symbol.apply(
    lambda x: x & ensg_gene_symbol_set
)
ag_collision_ensg_df = mini_ensg_df[mini_ensg_df.intersect_point != set()]
ag_collision_ensg_df.head()
# Out:
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_24200/2650176716.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mini_ensg_df["intersect_point"] = mini_ensg_df.alias_symbol.apply(
#              ENSG_ID gene_symbol HGNC_ID NCBI_ID  \
# 88   ENSG00000005206    {SPPL2B}   30627   56928
# 223  ENSG00000008516     {MMP25}   14246   64386
# 324  ENSG00000012983    {MAP4K5}    6867   11183
# 340  ENSG00000013573     {DDX11}    2736    1663
# 379  ENSG00000018236     {CNTN1}    2171    1272
#
#                       alias_symbol intersect_point
# 88        { KIAA1532,  PSL1, IMP4}          {IMP4}
# 223      { MT6-MMP,  MMPL1, MMP20}         {MMP20}
# 324            {GCKR,  KHS,  KHS1}          {GCKR}
# 340  { KRG-2,  WABS,  CHLR1, CHL1}          {CHL1}
# 379                   { GP135, F3}            {F3}

# %%
ag_collision_ensg_df["source"] = "ENSG"
ag_collision_ensg_df
# Out:
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_24200/998379004.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ag_collision_ensg_df["source"] = "ENSG"
#                ENSG_ID gene_symbol HGNC_ID    NCBI_ID  \
# 88     ENSG00000005206    {SPPL2B}   30627      56928
# 223    ENSG00000008516     {MMP25}   14246      64386
# 324    ENSG00000012983    {MAP4K5}    6867      11183
# 340    ENSG00000013573     {DDX11}    2736       1663
# 379    ENSG00000018236     {CNTN1}    2171       1272
# ...                ...         ...     ...        ...
# 74459  ENSG00000291654    {PCDHA6}    8672      56142
# 74495  ENSG00000291690   {PCDHB11}    8682      56125
# 74578  ENSG00000291781      {TTC5}   19274      91875
# 74928  ENSG00000292149    {TCF7L1}   11640      83439
# 75490  ENSG00000293241   {GTF2IP4}     NaN  100093631
#
#                                alias_symbol intersect_point source
# 88                 { KIAA1532,  PSL1, IMP4}          {IMP4}   ENSG
# 223               { MT6-MMP,  MMPL1, MMP20}         {MMP20}   ENSG
# 324                     {GCKR,  KHS,  KHS1}          {GCKR}   ENSG
# 340           { KRG-2,  WABS,  CHLR1, CHL1}          {CHL1}   ENSG
# 379                            { GP135, F3}            {F3}   ENSG
# ...                                     ...             ...    ...
# 74459  {CNR2,  CNRS2,  PCDH-ALPHA6,  CRNR2}          {CNR2}   ENSG
# 74495                   { PCDH-BETA11, ME2}           {ME2}   ENSG
# 74578                               {STRAP}         {STRAP}   ENSG
# 74928                                {TCF3}          {TCF3}   ENSG
# 75490                               {GTF2I}         {GTF2I}   ENSG
#
# [279 rows x 7 columns]

# %% [markdown]
# make a set of collisions
# - some records have multiple collisions, need to explode to one per row so that when i change it back to a str and make a set it doesnt count two collisions seperated by a commma as one unique collision

# %%
ag_collision_ensg_df = ag_collision_ensg_df.explode(column="intersect_point")
ag_collision_ensg_df
# Out:
#                ENSG_ID gene_symbol HGNC_ID    NCBI_ID  \
# 88     ENSG00000005206    {SPPL2B}   30627      56928
# 223    ENSG00000008516     {MMP25}   14246      64386
# 324    ENSG00000012983    {MAP4K5}    6867      11183
# 340    ENSG00000013573     {DDX11}    2736       1663
# 379    ENSG00000018236     {CNTN1}    2171       1272
# ...                ...         ...     ...        ...
# 74459  ENSG00000291654    {PCDHA6}    8672      56142
# 74495  ENSG00000291690   {PCDHB11}    8682      56125
# 74578  ENSG00000291781      {TTC5}   19274      91875
# 74928  ENSG00000292149    {TCF7L1}   11640      83439
# 75490  ENSG00000293241   {GTF2IP4}     NaN  100093631
#
#                                alias_symbol intersect_point source
# 88                 { KIAA1532,  PSL1, IMP4}            IMP4   ENSG
# 223               { MT6-MMP,  MMPL1, MMP20}           MMP20   ENSG
# 324                     {GCKR,  KHS,  KHS1}            GCKR   ENSG
# 340           { KRG-2,  WABS,  CHLR1, CHL1}            CHL1   ENSG
# 379                            { GP135, F3}              F3   ENSG
# ...                                     ...             ...    ...
# 74459  {CNR2,  CNRS2,  PCDH-ALPHA6,  CRNR2}            CNR2   ENSG
# 74495                   { PCDH-BETA11, ME2}             ME2   ENSG
# 74578                               {STRAP}           STRAP   ENSG
# 74928                                {TCF3}            TCF3   ENSG
# 75490                               {GTF2I}           GTF2I   ENSG
#
# [279 rows x 7 columns]

# %%
duplicates_ag_collision_ensg_df = ag_collision_ensg_df[
    ag_collision_ensg_df.duplicated("gene_symbol", keep=False)
]
duplicates_ag_collision_ensg_df = duplicates_ag_collision_ensg_df.sort_values(
    "gene_symbol"
)
duplicates_ag_collision_ensg_df
# Out:
#                ENSG_ID gene_symbol HGNC_ID    NCBI_ID  \
# 1554   ENSG00000081842    {PCDHA6}    8672      56142
# 57502  ENSG00000274585    {RNU2-1}   10142  124907963
# 57503  ENSG00000274585    {RNU2-1}   10142  124907964
# 57504  ENSG00000274585    {RNU2-1}   10142  124907965
# 59227  ENSG00000275920  {KRTAP5-3}   23598     387266
# 59495  ENSG00000276234    {TADA2A}   11531       6871
# 59496  ENSG00000276238   {NANOGP7}   23105        nan
# 59565  ENSG00000276333    {HS3ST6}   14178      64711
# 60203  ENSG00000276876      {MYT1}    7622       4661
# 60328  ENSG00000277033   {B3GNTL1}   21727     146712
# 60329  ENSG00000277033   {B3GNTL1}   21727  128966610
# 60383  ENSG00000277104    {TADA2A}   11531       6871
# 60527  ENSG00000277291  {KRTAP5-5}   23601     439915
# 61963  ENSG00000278302  {KRTAP5-5}   23601     439915
# 62115  ENSG00000278489  {KRTAP5-2}   23597     440021
# 64039  ENSG00000281022     {MED22}   11477       6837
# 64129  ENSG00000281191  {KRTAP5-3}   23598     387266
# 64306  ENSG00000281533  {KRTAP5-2}   23597     440021
# 65192  ENSG00000282607      {MGAM}    7043       8972
# 67553  ENSG00000285136     {DEFA6}    2765       1671
# 74230  ENSG00000291434  {KRTAP5-2}   23597     440021
# 74231  ENSG00000291435  {KRTAP5-3}   23598     387266
# 74239  ENSG00000291443  {KRTAP5-5}   23601     439915
# 74457  ENSG00000291652    {PCDHA4}    8670      56144
# 74459  ENSG00000291654    {PCDHA6}    8672      56142
# 74495  ENSG00000291690   {PCDHB11}    8682      56125
# 57501  ENSG00000274585    {RNU2-1}   10142  124904143
# 74578  ENSG00000291781      {TTC5}   19274      91875
# 57500  ENSG00000274585    {RNU2-1}   10142  124904142
# 57498  ENSG00000274585    {RNU2-1}   10142  124904139
# 7300   ENSG00000136319      {TTC5}   19274      91875
# 7599   ENSG00000137843      {PAK6}   16061      56924
# 7600   ENSG00000137843      {PAK6}   16061  106821730
# 9132   ENSG00000148297     {MED22}   11477       6837
# 9584   ENSG00000152284    {TCF7L1}   11640      83439
# 10753  ENSG00000162040    {HS3ST6}   14178      64711
# 11531  ENSG00000164822     {DEFA6}    2765       1671
# 14046  ENSG00000175711   {B3GNTL1}   21727     146712
# 14047  ENSG00000175711   {B3GNTL1}   21727  128966610
# 16222  ENSG00000185829    {ARL17A}   24096      51326
# 16223  ENSG00000185829    {ARL17A}   24096  100506084
# 16256  ENSG00000185940  {KRTAP5-5}   23601     439915
# 17164  ENSG00000196132      {MYT1}    7622       4661
# 17197  ENSG00000196224  {KRTAP5-3}   23598     387266
# 17618  ENSG00000197479   {PCDHB11}    8682      56125
# 21718  ENSG00000204967    {PCDHA4}    8670      56144
# 21958  ENSG00000205867  {KRTAP5-2}   23597     440021
# 22223  ENSG00000206596  {RNU1-27P}   37497  124904613
# 22224  ENSG00000206596  {RNU1-27P}   37497  124905321
# 22225  ENSG00000206596  {RNU1-27P}   37497  124905573
# 22226  ENSG00000206596  {RNU1-27P}   37497  124905809
# 47361  ENSG00000257335      {MGAM}    7043       8972
# 48249  ENSG00000258774   {NANOGP7}   23105        nan
# 57496  ENSG00000274585    {RNU2-1}   10142       6066
# 57497  ENSG00000274585    {RNU2-1}   10142  124904138
# 57499  ENSG00000274585    {RNU2-1}   10142  124904141
# 74928  ENSG00000292149    {TCF7L1}   11640      83439
#
#                                            alias_symbol intersect_point source
# 1554               {CNR2,  CNRS2,  PCDH-ALPHA6,  CRNR2}            CNR2   ENSG
# 57502                                              {U2}              U2   ENSG
# 57503                                              {U2}              U2   ENSG
# 57504                                              {U2}              U2   ENSG
# 59227                             {KRTAP5-9,  KRTAP5.3}        KRTAP5-9   ENSG
# 59495                   {ADA2,  HADA2,  ADA2A,  TADA2L}            ADA2   ENSG
# 59496                                         {NANOGP3}         NANOGP3   ENSG
# 59565                                          {HS3ST5}          HS3ST5   ENSG
# 60203  { ZC2HC4A,  PLPB1,  MYTI,  ZC2H2C1,  NZF2, MTF1}            MTF1   ENSG
# 60328                                          {B3GNT8}          B3GNT8   ENSG
# 60329                                          {B3GNT8}          B3GNT8   ENSG
# 60383                   {ADA2,  HADA2,  ADA2A,  TADA2L}            ADA2   ENSG
# 60527                            { KRTAP5.5, KRTAP5-11}       KRTAP5-11   ENSG
# 61963                            { KRTAP5.5, KRTAP5-11}       KRTAP5-11   ENSG
# 62115                             {KRTAP5-8,  KRTAP5.2}        KRTAP5-8   ENSG
# 64039                            { SURF5, MED24,  SRB6}           MED24   ENSG
# 64129                             {KRTAP5-9,  KRTAP5.3}        KRTAP5-9   ENSG
# 64306                             {KRTAP5-8,  KRTAP5.2}        KRTAP5-8   ENSG
# 65192                                             {MGA}             MGA   ENSG
# 67553                                     { HD-6, DEF6}            DEF6   ENSG
# 74230                             {KRTAP5-8,  KRTAP5.2}        KRTAP5-8   ENSG
# 74231                             {KRTAP5-9,  KRTAP5.3}        KRTAP5-9   ENSG
# 74239                            { KRTAP5.5, KRTAP5-11}       KRTAP5-11   ENSG
# 74457              { CNRN1,  CRNR1,  PCDH-ALPHA4, CNR1}            CNR1   ENSG
# 74459              {CNR2,  CNRS2,  PCDH-ALPHA6,  CRNR2}            CNR2   ENSG
# 74495                               { PCDH-BETA11, ME2}             ME2   ENSG
# 57501                                              {U2}              U2   ENSG
# 74578                                           {STRAP}           STRAP   ENSG
# 57500                                              {U2}              U2   ENSG
# 57498                                              {U2}              U2   ENSG
# 7300                                            {STRAP}           STRAP   ENSG
# 7599                                             {PAK5}            PAK5   ENSG
# 7600                                             {PAK5}            PAK5   ENSG
# 9132                             { SURF5, MED24,  SRB6}           MED24   ENSG
# 9584                                             {TCF3}            TCF3   ENSG
# 10753                                          {HS3ST5}          HS3ST5   ENSG
# 11531                                     { HD-6, DEF6}            DEF6   ENSG
# 14046                                          {B3GNT8}          B3GNT8   ENSG
# 14047                                          {B3GNT8}          B3GNT8   ENSG
# 16222                                {ARF1P2,  ARL17P1}          ARF1P2   ENSG
# 16223                                {ARF1P2,  ARL17P1}          ARF1P2   ENSG
# 16256                            { KRTAP5.5, KRTAP5-11}       KRTAP5-11   ENSG
# 17164  { ZC2HC4A,  PLPB1,  MYTI,  ZC2H2C1,  NZF2, MTF1}            MTF1   ENSG
# 17197                             {KRTAP5-9,  KRTAP5.3}        KRTAP5-9   ENSG
# 17618                               { PCDH-BETA11, ME2}             ME2   ENSG
# 21718              { CNRN1,  CRNR1,  PCDH-ALPHA4, CNR1}            CNR1   ENSG
# 21958                             {KRTAP5-8,  KRTAP5.2}        KRTAP5-8   ENSG
# 22223                                         {RNU1-7P}         RNU1-7P   ENSG
# 22224                                         {RNU1-7P}         RNU1-7P   ENSG
# 22225                                         {RNU1-7P}         RNU1-7P   ENSG
# 22226                                         {RNU1-7P}         RNU1-7P   ENSG
# 47361                                             {MGA}             MGA   ENSG
# 48249                                         {NANOGP3}         NANOGP3   ENSG
# 57496                                              {U2}              U2   ENSG
# 57497                                              {U2}              U2   ENSG
# 57499                                              {U2}              U2   ENSG
# 74928                                            {TCF3}            TCF3   ENSG

# %%
ensg_alias_gene_collision_set = set(ag_collision_ensg_df["intersect_point"])
len(ensg_alias_gene_collision_set)
# Out:
# 229

# %%
ag_collision_ensg_df["gene_symbol"] = ag_collision_ensg_df["gene_symbol"].str.join(", ")

# %%
ensg_alias_gene_collision_primary_symbol_set = set(ag_collision_ensg_df["gene_symbol"])
len(ensg_alias_gene_collision_primary_symbol_set)
# Out:
# 242

# %% [markdown]
# 1. Why is the alias-gene collision set not the same length as the set of primary symbols with collisions ?
# 2. Why is the length of the alias-gene collison set shorter?
#  - A priamry gene symbol with an alias-gene collision has an alias that matches a different gene's primary gene symbol.
#  - Multiple genes can share a single alias (alias-alias collision)
#  - If that shared alias is an alias-gene collision, then there will be more unique gene symbols in the set of primary symbols with collisions than the set of alias-gene collisions.

# %% [markdown]
# ### Convert sets to str or list
#     works on the first pass, gets Assertion Error on passes after

# %%
ag_collision_ensg_df["gene_symbol"] = ag_collision_ensg_df["gene_symbol"].str.replace(
    r"[{}]", ""
)
ag_collision_ensg_df
# Out:
#                ENSG_ID gene_symbol HGNC_ID    NCBI_ID  \
# 88     ENSG00000005206      SPPL2B   30627      56928
# 223    ENSG00000008516       MMP25   14246      64386
# 324    ENSG00000012983      MAP4K5    6867      11183
# 340    ENSG00000013573       DDX11    2736       1663
# 379    ENSG00000018236       CNTN1    2171       1272
# ...                ...         ...     ...        ...
# 74459  ENSG00000291654      PCDHA6    8672      56142
# 74495  ENSG00000291690     PCDHB11    8682      56125
# 74578  ENSG00000291781        TTC5   19274      91875
# 74928  ENSG00000292149      TCF7L1   11640      83439
# 75490  ENSG00000293241     GTF2IP4     NaN  100093631
#
#                                alias_symbol intersect_point source
# 88                 { KIAA1532,  PSL1, IMP4}            IMP4   ENSG
# 223               { MT6-MMP,  MMPL1, MMP20}           MMP20   ENSG
# 324                     {GCKR,  KHS,  KHS1}            GCKR   ENSG
# 340           { KRG-2,  WABS,  CHLR1, CHL1}            CHL1   ENSG
# 379                            { GP135, F3}              F3   ENSG
# ...                                     ...             ...    ...
# 74459  {CNR2,  CNRS2,  PCDH-ALPHA6,  CRNR2}            CNR2   ENSG
# 74495                   { PCDH-BETA11, ME2}             ME2   ENSG
# 74578                               {STRAP}           STRAP   ENSG
# 74928                                {TCF3}            TCF3   ENSG
# 75490                               {GTF2I}           GTF2I   ENSG
#
# [279 rows x 7 columns]

# %% [markdown]
# ### Alphabetize alias_symbol

# %%
ag_collision_ensg_df["alias_symbol"] = ag_collision_ensg_df["alias_symbol"].apply(
    lambda x: sorted(list(x), key=str.casefold)
)
ag_collision_ensg_df
# Out:
#                ENSG_ID gene_symbol HGNC_ID    NCBI_ID  \
# 88     ENSG00000005206      SPPL2B   30627      56928
# 223    ENSG00000008516       MMP25   14246      64386
# 324    ENSG00000012983      MAP4K5    6867      11183
# 340    ENSG00000013573       DDX11    2736       1663
# 379    ENSG00000018236       CNTN1    2171       1272
# ...                ...         ...     ...        ...
# 74459  ENSG00000291654      PCDHA6    8672      56142
# 74495  ENSG00000291690     PCDHB11    8682      56125
# 74578  ENSG00000291781        TTC5   19274      91875
# 74928  ENSG00000292149      TCF7L1   11640      83439
# 75490  ENSG00000293241     GTF2IP4     NaN  100093631
#
#                                alias_symbol intersect_point source
# 88                 [ KIAA1532,  PSL1, IMP4]            IMP4   ENSG
# 223               [ MMPL1,  MT6-MMP, MMP20]           MMP20   ENSG
# 324                     [ KHS,  KHS1, GCKR]            GCKR   ENSG
# 340           [ CHLR1,  KRG-2,  WABS, CHL1]            CHL1   ENSG
# 379                            [ GP135, F3]              F3   ENSG
# ...                                     ...             ...    ...
# 74459  [ CNRS2,  CRNR2,  PCDH-ALPHA6, CNR2]            CNR2   ENSG
# 74495                   [ PCDH-BETA11, ME2]             ME2   ENSG
# 74578                               [STRAP]           STRAP   ENSG
# 74928                                [TCF3]            TCF3   ENSG
# 75490                               [GTF2I]           GTF2I   ENSG
#
# [279 rows x 7 columns]

# %% [markdown]
# ### Convert lists to str

# %%
ag_collision_ensg_df["alias_symbol"] = ag_collision_ensg_df["alias_symbol"].str.join(
    ", "
)

# %%
ag_collision_ensg_df = ag_collision_ensg_df.sort_values("intersect_point")
ag_collision_ensg_df
# Out:
#                ENSG_ID gene_symbol HGNC_ID NCBI_ID  \
# 65759  ENSG00000283293       RN7SK   10037  125050
# 12287  ENSG00000167780       SOAT2   11178    8435
# 25650  ENSG00000220267      ACTBP8     141     nan
# 59495  ENSG00000276234      TADA2A   11531    6871
# 60383  ENSG00000277104      TADA2A   11531    6871
# ...                ...         ...     ...     ...
# 8401   ENSG00000143258       USP21   12620   27005
# 9928   ENSG00000155313       USP25   12624   29761
# 54879  ENSG00000270858     VDAC1P5   12676     nan
# 42358  ENSG00000249947      XBP1P1   12802     nan
# 16971  ENSG00000188801    ZNF322P1   14003     nan
#
#                         alias_symbol intersect_point source
# 65759                            7SK             7SK   ENSG
# 12287                          ACAT2           ACAT2   ENSG
# 25650                         ACTBP2          ACTBP2   ENSG
# 59495   ADA2A,  HADA2,  TADA2L, ADA2            ADA2   ENSG
# 60383   ADA2A,  HADA2,  TADA2L, ADA2            ADA2   ENSG
# ...                              ...             ...    ...
# 8401                    USP23, USP16           USP16   ENSG
# 9928                           USP21           USP21   ENSG
# 54879                  VDAC5P, VDAC3           VDAC3   ENSG
# 42358                    XBPP1, XBP1            XBP1   ENSG
# 16971                ZNF322B, ZNF322          ZNF322   ENSG
#
# [279 rows x 7 columns]

# %%
ag_collision_ensg_df = ag_collision_ensg_df.drop_duplicates(
    subset=["gene_symbol", "intersect_point"], keep="first"
)
ag_collision_ensg_df
# Out:
#                ENSG_ID gene_symbol HGNC_ID NCBI_ID  \
# 65759  ENSG00000283293       RN7SK   10037  125050
# 12287  ENSG00000167780       SOAT2   11178    8435
# 25650  ENSG00000220267      ACTBP8     141     nan
# 59495  ENSG00000276234      TADA2A   11531    6871
# 594    ENSG00000042980      ADAM28     206   10863
# ...                ...         ...     ...     ...
# 8401   ENSG00000143258       USP21   12620   27005
# 9928   ENSG00000155313       USP25   12624   29761
# 54879  ENSG00000270858     VDAC1P5   12676     nan
# 42358  ENSG00000249947      XBP1P1   12802     nan
# 16971  ENSG00000188801    ZNF322P1   14003     nan
#
#                             alias_symbol intersect_point source
# 65759                                7SK             7SK   ENSG
# 12287                              ACAT2           ACAT2   ENSG
# 25650                             ACTBP2          ACTBP2   ENSG
# 59495       ADA2A,  HADA2,  TADA2L, ADA2            ADA2   ENSG
# 594     EMDCII,  MDC-LM,  MDC-LS, ADAM23          ADAM23   ENSG
# ...                                  ...             ...    ...
# 8401                        USP23, USP16           USP16   ENSG
# 9928                               USP21           USP21   ENSG
# 54879                      VDAC5P, VDAC3           VDAC3   ENSG
# 42358                        XBPP1, XBP1            XBP1   ENSG
# 16971                    ZNF322B, ZNF322          ZNF322   ENSG
#
# [242 rows x 7 columns]

# %% [markdown]
# ## Add civic_gene_id to table

# %%
genes = civicpy.get_all_genes()

# %%
ensg_NCBI_ID_list = list(ag_collision_ensg_df["NCBI_ID"])

# %%
civic_ids = []
for id in ensg_NCBI_ID_list:
    found_civic_id = ""
    for gene in genes:
        if id == str(gene.entrez_id):
            found_civic_id = gene.id
    civic_ids.append(found_civic_id)

ag_collision_ensg_df["civic_ids"] = civic_ids
ag_collision_ensg_df
# Out:
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_24200/737203686.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ag_collision_ensg_df["civic_ids"] = civic_ids
#                ENSG_ID gene_symbol HGNC_ID NCBI_ID  \
# 65759  ENSG00000283293       RN7SK   10037  125050
# 12287  ENSG00000167780       SOAT2   11178    8435
# 25650  ENSG00000220267      ACTBP8     141     nan
# 59495  ENSG00000276234      TADA2A   11531    6871
# 594    ENSG00000042980      ADAM28     206   10863
# ...                ...         ...     ...     ...
# 8401   ENSG00000143258       USP21   12620   27005
# 9928   ENSG00000155313       USP25   12624   29761
# 54879  ENSG00000270858     VDAC1P5   12676     nan
# 42358  ENSG00000249947      XBP1P1   12802     nan
# 16971  ENSG00000188801    ZNF322P1   14003     nan
#
#                             alias_symbol intersect_point source civic_ids
# 65759                                7SK             7SK   ENSG
# 12287                              ACAT2           ACAT2   ENSG
# 25650                             ACTBP2          ACTBP2   ENSG
# 59495       ADA2A,  HADA2,  TADA2L, ADA2            ADA2   ENSG
# 594     EMDCII,  MDC-LM,  MDC-LS, ADAM23          ADAM23   ENSG
# ...                                  ...             ...    ...       ...
# 8401                        USP23, USP16           USP16   ENSG
# 9928                               USP21           USP21   ENSG
# 54879                      VDAC5P, VDAC3           VDAC3   ENSG
# 42358                        XBPP1, XBP1            XBP1   ENSG
# 16971                    ZNF322B, ZNF322          ZNF322   ENSG
#
# [242 rows x 8 columns]

# %%
ag_collision_ensg_df["civic_ids"].replace("", np.nan, inplace=True)
ag_collision_ensg_df.head()
# Out:
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_24200/140549376.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   ag_collision_ensg_df["civic_ids"].replace("", np.nan, inplace=True)
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_24200/140549376.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ag_collision_ensg_df["civic_ids"].replace("", np.nan, inplace=True)
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_24200/140549376.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ag_collision_ensg_df["civic_ids"].replace("", np.nan, inplace=True)
#                ENSG_ID gene_symbol HGNC_ID NCBI_ID  \
# 65759  ENSG00000283293       RN7SK   10037  125050
# 12287  ENSG00000167780       SOAT2   11178    8435
# 25650  ENSG00000220267      ACTBP8     141     nan
# 59495  ENSG00000276234      TADA2A   11531    6871
# 594    ENSG00000042980      ADAM28     206   10863
#
#                             alias_symbol intersect_point source  civic_ids
# 65759                                7SK             7SK   ENSG        NaN
# 12287                              ACAT2           ACAT2   ENSG        NaN
# 25650                             ACTBP2          ACTBP2   ENSG        NaN
# 59495       ADA2A,  HADA2,  TADA2L, ADA2            ADA2   ENSG        NaN
# 594     EMDCII,  MDC-LM,  MDC-LS, ADAM23          ADAM23   ENSG        NaN

# %%
civic_ag_collision_ensg_df = ag_collision_ensg_df.copy()
civic_ag_collision_ensg_df.dropna(subset=["civic_ids"], inplace=True)
civic_ag_collision_ensg_df
# Out:
#                ENSG_ID gene_symbol HGNC_ID NCBI_ID  \
# 3677   ENSG00000109321        AREG     651     374
# 7325   ENSG00000136492       BRIP1   20473   83990
# 12645  ENSG00000169245      CXCL10   10637    3627
# 6208   ENSG00000129682       FGF13    3670    2258
# 4305   ENSG00000114353       GNAI2    4385    2771
# 6137   ENSG00000129071        MBD4    6919    8930
#
#                                             alias_symbol intersect_point  \
# 3677                            AREGB,  CRDGF,  SDGF, AR              AR
# 7325                                   FANCJ,  OF, BACH1           BACH1
# 12645   CRG-2,  GIP-10,  IFI10,  INP10,  IP-10,  MOB-...              C7
# 6208                   FHF2,  FLJ30672,  LINC00889, FGF2            FGF2
# 4305                                         GNAI2B, GIP             GIP
# 6137                                                MED1            MED1
#
#       source  civic_ids
# 3677    ENSG      389.0
# 7325    ENSG    15955.0
# 12645   ENSG     3017.0
# 6208    ENSG     1883.0
# 4305    ENSG     2312.0
# 6137    ENSG     7084.0

# %% [markdown]
# ## Add MP ID and score to table

# %%
civic_ag_collision_ensg_df_add_molprof_df = transform_df_mp_id(
    civic_ag_collision_ensg_df
)
civic_ag_collision_ensg_df_add_molprof_df
# Out:
#                ENSG_ID gene_symbol HGNC_ID NCBI_ID  \
# 3677   ENSG00000109321        AREG     651     374
# 7325   ENSG00000136492       BRIP1   20473   83990
# 12645  ENSG00000169245      CXCL10   10637    3627
# 6208   ENSG00000129682       FGF13    3670    2258
# 4305   ENSG00000114353       GNAI2    4385    2771
# 6137   ENSG00000129071        MBD4    6919    8930
#
#                                             alias_symbol intersect_point  \
# 3677                            AREGB,  CRDGF,  SDGF, AR              AR
# 7325                                   FANCJ,  OF, BACH1           BACH1
# 12645   CRG-2,  GIP-10,  IFI10,  INP10,  IP-10,  MOB-...              C7
# 6208                   FHF2,  FLJ30672,  LINC00889, FGF2            FGF2
# 4305                                         GNAI2B, GIP             GIP
# 6137                                                MED1            MED1
#
#       source  civic_ids molecular_profile_id
# 3677    ENSG      389.0                [385]
# 7325    ENSG    15955.0
# 12645   ENSG     3017.0
# 6208    ENSG     1883.0               [1759]
# 4305    ENSG     2312.0               [2185]
# 6137    ENSG     7084.0

# %%
civic_true_mini_ensg_add_molprof_score_df = transform_df_mp_score(
    civic_ag_collision_ensg_df_add_molprof_df
)
civic_true_mini_ensg_add_molprof_score_df
# Out:
#                ENSG_ID gene_symbol HGNC_ID NCBI_ID  \
# 3677   ENSG00000109321        AREG     651     374
# 7325   ENSG00000136492       BRIP1   20473   83990
# 12645  ENSG00000169245      CXCL10   10637    3627
# 6208   ENSG00000129682       FGF13    3670    2258
# 4305   ENSG00000114353       GNAI2    4385    2771
# 6137   ENSG00000129071        MBD4    6919    8930
#
#                                             alias_symbol intersect_point  \
# 3677                            AREGB,  CRDGF,  SDGF, AR              AR
# 7325                                   FANCJ,  OF, BACH1           BACH1
# 12645   CRG-2,  GIP-10,  IFI10,  INP10,  IP-10,  MOB-...              C7
# 6208                   FHF2,  FLJ30672,  LINC00889, FGF2            FGF2
# 4305                                         GNAI2B, GIP             GIP
# 6137                                                MED1            MED1
#
#       source  civic_ids molecular_profile_id molecular_profile_score
# 3677    ENSG      389.0                [385]                  [12.0]
# 7325    ENSG    15955.0
# 12645   ENSG     3017.0
# 6208    ENSG     1883.0               [1759]                  [10.0]
# 4305    ENSG     2312.0               [2185]                   [0.0]
# 6137    ENSG     7084.0

# %% [markdown]
# ## Add evidence_ids column

# %%
civic_variant_ids = civicpy.get_all_variants()

# %%
ensg_civic_id_list = list(civic_ag_collision_ensg_df["civic_ids"])

# %%
civic_ag_collision_ensg_df.civic_ids.astype(int)
# Out:
# 3677       389
# 7325     15955
# 12645     3017
# 6208      1883
# 4305      2312
# 6137      7084
# Name: civic_ids, dtype: int64

# %%
civic_eids = []
for civic_id in ensg_civic_id_list:
    gene_civic_eids = []
    for variant in civic_variant_ids:
        # print(civic_id, type(civic_id))
        # print(   = =variant.gene_id, type(variant.gene_id))
        if int(civic_id) == variant.gene_id:
            for mp in variant.molecular_profiles:
                for e in mp.evidence_items:
                    if e.id not in gene_civic_eids:
                        gene_civic_eids.append(e.id)
            gene_civic_eids = gene_civic_eids or ""
    civic_eids.append(gene_civic_eids)
civic_ag_collision_ensg_df["civic_eids"] = civic_eids
civic_ag_collision_ensg_df
# Out:
#                ENSG_ID gene_symbol HGNC_ID NCBI_ID  \
# 3677   ENSG00000109321        AREG     651     374
# 7325   ENSG00000136492       BRIP1   20473   83990
# 12645  ENSG00000169245      CXCL10   10637    3627
# 6208   ENSG00000129682       FGF13    3670    2258
# 4305   ENSG00000114353       GNAI2    4385    2771
# 6137   ENSG00000129071        MBD4    6919    8930
#
#                                             alias_symbol intersect_point  \
# 3677                            AREGB,  CRDGF,  SDGF, AR              AR
# 7325                                   FANCJ,  OF, BACH1           BACH1
# 12645   CRG-2,  GIP-10,  IFI10,  INP10,  IP-10,  MOB-...              C7
# 6208                   FHF2,  FLJ30672,  LINC00889, FGF2            FGF2
# 4305                                         GNAI2B, GIP             GIP
# 6137                                                MED1            MED1
#
#       source  civic_ids                       civic_eids
# 3677    ENSG      389.0  [1020, 788, 847, 781, 846, 780]
# 7325    ENSG    15955.0                          [11208]
# 12645   ENSG     3017.0                           [8026]
# 6208    ENSG     1883.0                           [1062]
# 4305    ENSG     2312.0                   [11943, 11839]
# 6137    ENSG     7084.0                           [7596]

# %%
civic_evidence_list = civicpy.get_all_evidence()

# %%
ensg_civic_eid_list = list(civic_ag_collision_ensg_df["civic_eids"])
ensg_civic_eid_list[0]
# Out:
# [1020, 788, 847, 781, 846, 780]

# %%
evidence_ratings = []
for eid_list in ensg_civic_eid_list:
    found_rating = []
    for eid in eid_list:
        for evidence in civic_evidence_list:
            if eid == evidence.id:
                found_rating.append(evidence.rating)
    evidence_ratings.append(found_rating)
civic_ag_collision_ensg_df["evidence_ratings"] = evidence_ratings
civic_ag_collision_ensg_df
# Out:
#                ENSG_ID gene_symbol HGNC_ID NCBI_ID  \
# 3677   ENSG00000109321        AREG     651     374
# 7325   ENSG00000136492       BRIP1   20473   83990
# 12645  ENSG00000169245      CXCL10   10637    3627
# 6208   ENSG00000129682       FGF13    3670    2258
# 4305   ENSG00000114353       GNAI2    4385    2771
# 6137   ENSG00000129071        MBD4    6919    8930
#
#                                             alias_symbol intersect_point  \
# 3677                            AREGB,  CRDGF,  SDGF, AR              AR
# 7325                                   FANCJ,  OF, BACH1           BACH1
# 12645   CRG-2,  GIP-10,  IFI10,  INP10,  IP-10,  MOB-...              C7
# 6208                   FHF2,  FLJ30672,  LINC00889, FGF2            FGF2
# 4305                                         GNAI2B, GIP             GIP
# 6137                                                MED1            MED1
#
#       source  civic_ids                       civic_eids    evidence_ratings
# 3677    ENSG      389.0  [1020, 788, 847, 781, 846, 780]  [4, 3, 3, 2, 2, 3]
# 7325    ENSG    15955.0                          [11208]                 [2]
# 12645   ENSG     3017.0                           [8026]                 [4]
# 6208    ENSG     1883.0                           [1062]                 [3]
# 4305    ENSG     2312.0                   [11943, 11839]              [4, 3]
# 6137    ENSG     7084.0                           [7596]                 [4]

# %%
average_evidence_rating = []
for alist in civic_ag_collision_ensg_df["evidence_ratings"]:
    avg_rating = sum(alist) / len(alist)
    average_evidence_rating.append(avg_rating)
civic_ag_collision_ensg_df["average_evidence_ratings"] = average_evidence_rating
civic_ag_collision_ensg_df
# Out:
#                ENSG_ID gene_symbol HGNC_ID NCBI_ID  \
# 3677   ENSG00000109321        AREG     651     374
# 7325   ENSG00000136492       BRIP1   20473   83990
# 12645  ENSG00000169245      CXCL10   10637    3627
# 6208   ENSG00000129682       FGF13    3670    2258
# 4305   ENSG00000114353       GNAI2    4385    2771
# 6137   ENSG00000129071        MBD4    6919    8930
#
#                                             alias_symbol intersect_point  \
# 3677                            AREGB,  CRDGF,  SDGF, AR              AR
# 7325                                   FANCJ,  OF, BACH1           BACH1
# 12645   CRG-2,  GIP-10,  IFI10,  INP10,  IP-10,  MOB-...              C7
# 6208                   FHF2,  FLJ30672,  LINC00889, FGF2            FGF2
# 4305                                         GNAI2B, GIP             GIP
# 6137                                                MED1            MED1
#
#       source  civic_ids                       civic_eids    evidence_ratings  \
# 3677    ENSG      389.0  [1020, 788, 847, 781, 846, 780]  [4, 3, 3, 2, 2, 3]
# 7325    ENSG    15955.0                          [11208]                 [2]
# 12645   ENSG     3017.0                           [8026]                 [4]
# 6208    ENSG     1883.0                           [1062]                 [3]
# 4305    ENSG     2312.0                   [11943, 11839]              [4, 3]
# 6137    ENSG     7084.0                           [7596]                 [4]
#
#        average_evidence_ratings
# 3677                   2.833333
# 7325                   2.000000
# 12645                  4.000000
# 6208                   3.000000
# 4305                   3.500000
# 6137                   4.000000

# %%
sum_evidence_rating = []
for alist in civic_ag_collision_ensg_df["evidence_ratings"]:
    sum_rating = sum(alist)
    sum_evidence_rating.append(sum_rating)
civic_ag_collision_ensg_df["sum_evidence_rating"] = sum_evidence_rating
civic_ag_collision_ensg_df
# Out:
#                ENSG_ID gene_symbol HGNC_ID NCBI_ID  \
# 3677   ENSG00000109321        AREG     651     374
# 7325   ENSG00000136492       BRIP1   20473   83990
# 12645  ENSG00000169245      CXCL10   10637    3627
# 6208   ENSG00000129682       FGF13    3670    2258
# 4305   ENSG00000114353       GNAI2    4385    2771
# 6137   ENSG00000129071        MBD4    6919    8930
#
#                                             alias_symbol intersect_point  \
# 3677                            AREGB,  CRDGF,  SDGF, AR              AR
# 7325                                   FANCJ,  OF, BACH1           BACH1
# 12645   CRG-2,  GIP-10,  IFI10,  INP10,  IP-10,  MOB-...              C7
# 6208                   FHF2,  FLJ30672,  LINC00889, FGF2            FGF2
# 4305                                         GNAI2B, GIP             GIP
# 6137                                                MED1            MED1
#
#       source  civic_ids                       civic_eids    evidence_ratings  \
# 3677    ENSG      389.0  [1020, 788, 847, 781, 846, 780]  [4, 3, 3, 2, 2, 3]
# 7325    ENSG    15955.0                          [11208]                 [2]
# 12645   ENSG     3017.0                           [8026]                 [4]
# 6208    ENSG     1883.0                           [1062]                 [3]
# 4305    ENSG     2312.0                   [11943, 11839]              [4, 3]
# 6137    ENSG     7084.0                           [7596]                 [4]
#
#        average_evidence_ratings  sum_evidence_rating
# 3677                   2.833333                   17
# 7325                   2.000000                    2
# 12645                  4.000000                    4
# 6208                   3.000000                    3
# 4305                   3.500000                    7
# 6137                   4.000000                    4

# %% [markdown]
# # HGNC

# %% [markdown]
# ## Set up table

# %%
mini_hgnc_df = pd.read_csv(
    "../downloaded_files/hgnc_biomart_gene20240626.txt", sep="\t",dtype={"NCBI gene ID": pd.Int64Dtype()}
)
mini_hgnc_df = mini_hgnc_df.rename(
    columns={
        "HGNC ID": "HGNC_ID",
        "Approved symbol": "gene_symbol",
        "Alias symbol": "alias_symbol",
        "Ensembl gene ID": "ENSG_ID",
        "NCBI gene ID": "NCBI_ID",
    }
)
mini_hgnc_df
# Out:
#           HGNC_ID  alias_symbol   NCBI_ID          ENSG_ID gene_symbol
# 0          HGNC:5           NaN       1.0  ENSG00000121410        A1BG
# 1      HGNC:37133      FLJ23569  503538.0  ENSG00000268895    A1BG-AS1
# 2      HGNC:24086           ACF   29974.0  ENSG00000148584        A1CF
# 3      HGNC:24086           ASP   29974.0  ENSG00000148584        A1CF
# 4      HGNC:24086         ACF64   29974.0  ENSG00000148584        A1CF
# ...           ...           ...       ...              ...         ...
# 67578  HGNC:29027      KIAA0399   23140.0  ENSG00000074755       ZZEF1
# 67579  HGNC:29027          ZZZ4   23140.0  ENSG00000074755       ZZEF1
# 67580  HGNC:29027      FLJ10821   23140.0  ENSG00000074755       ZZEF1
# 67581  HGNC:24523  DKFZP564I052   26009.0  ENSG00000036549        ZZZ3
# 67582  HGNC:24523         ATAC1   26009.0  ENSG00000036549        ZZZ3
#
# [67583 rows x 5 columns]

# %%
mini_hgnc_df["alias_symbol"] = mini_hgnc_df["alias_symbol"].fillna("").astype(str)
mini_hgnc_df = (
    mini_hgnc_df.groupby(
        ["ENSG_ID", "gene_symbol", "HGNC_ID", "NCBI_ID"], dropna=False
    )["alias_symbol"]
    .apply(lambda x: ", ".join(x.dropna()))
    .reset_index()
)
mini_hgnc_df
# Out:
#                ENSG_ID gene_symbol     HGNC_ID      NCBI_ID  \
# 0      ENSG00000000003      TSPAN6  HGNC:11858       7105.0
# 1      ENSG00000000005        TNMD  HGNC:17757      64102.0
# 2      ENSG00000000419        DPM1   HGNC:3005       8813.0
# 3      ENSG00000000457       SCYL3  HGNC:19285      57147.0
# 4      ENSG00000000460       FIRRM  HGNC:25565      55732.0
# ...                ...         ...         ...          ...
# 45641              NaN       ZNF97  HGNC:13173          NaN
# 45642              NaN       ZNFP1  HGNC:13181          NaN
# 45643              NaN       ZPAXP  HGNC:51635  105373450.0
# 45644              NaN         ZRK  HGNC:13193          NaN
# 45645              NaN     ZWINTAS  HGNC:13196          NaN
#
#                                alias_symbol
# 0                             T245, TSPAN-6
# 1      myodulin, ChM1L, tendin, TEM, BRICD4
# 2                               MPDS, CDGIE
# 3                             PACE-1, PACE1
# 4            FLJ10706, Apolo1, FLIP, MEICA1
# ...                                     ...
# 45641
# 45642
# 45643                                 ZPX1P
# 45644
# 45645            MPP5, MPHOSPH5, NCRNA00018
#
# [45646 rows x 5 columns]

# %%
# mini_hgnc_df["NCBI_ID"] = mini_hgnc_df["NCBI_ID"].astype(str).str.removesuffix(".0")
# mini_hgnc_df
# Out:
#                ENSG_ID gene_symbol     HGNC_ID    NCBI_ID  \
# 0      ENSG00000000003      TSPAN6  HGNC:11858       7105
# 1      ENSG00000000005        TNMD  HGNC:17757      64102
# 2      ENSG00000000419        DPM1   HGNC:3005       8813
# 3      ENSG00000000457       SCYL3  HGNC:19285      57147
# 4      ENSG00000000460       FIRRM  HGNC:25565      55732
# ...                ...         ...         ...        ...
# 45641              NaN       ZNF97  HGNC:13173        nan
# 45642              NaN       ZNFP1  HGNC:13181        nan
# 45643              NaN       ZPAXP  HGNC:51635  105373450
# 45644              NaN         ZRK  HGNC:13193        nan
# 45645              NaN     ZWINTAS  HGNC:13196        nan
#
#                                alias_symbol
# 0                             T245, TSPAN-6
# 1      myodulin, ChM1L, tendin, TEM, BRICD4
# 2                               MPDS, CDGIE
# 3                             PACE-1, PACE1
# 4            FLJ10706, Apolo1, FLIP, MEICA1
# ...                                     ...
# 45641
# 45642
# 45643                                 ZPX1P
# 45644
# 45645            MPP5, MPHOSPH5, NCRNA00018
#
# [45646 rows x 5 columns]

# %%
mini_hgnc_df["HGNC_ID"] = mini_hgnc_df["HGNC_ID"].str.lstrip("HGNC:")
mini_hgnc_df
# Out:
#                ENSG_ID gene_symbol HGNC_ID    NCBI_ID  \
# 0      ENSG00000000003      TSPAN6   11858       7105
# 1      ENSG00000000005        TNMD   17757      64102
# 2      ENSG00000000419        DPM1    3005       8813
# 3      ENSG00000000457       SCYL3   19285      57147
# 4      ENSG00000000460       FIRRM   25565      55732
# ...                ...         ...     ...        ...
# 45641              NaN       ZNF97   13173        nan
# 45642              NaN       ZNFP1   13181        nan
# 45643              NaN       ZPAXP   51635  105373450
# 45644              NaN         ZRK   13193        nan
# 45645              NaN     ZWINTAS   13196        nan
#
#                                alias_symbol
# 0                             T245, TSPAN-6
# 1      myodulin, ChM1L, tendin, TEM, BRICD4
# 2                               MPDS, CDGIE
# 3                             PACE-1, PACE1
# 4            FLJ10706, Apolo1, FLIP, MEICA1
# ...                                     ...
# 45641
# 45642
# 45643                                 ZPX1P
# 45644
# 45645            MPP5, MPHOSPH5, NCRNA00018
#
# [45646 rows x 5 columns]

# %%
mini_hgnc_df.to_csv("../created_files/mini_hgnc_df.csv", index=False)
mini_hgnc_df.head()
# Out:
#            ENSG_ID gene_symbol HGNC_ID NCBI_ID  \
# 0  ENSG00000000003      TSPAN6   11858    7105
# 1  ENSG00000000005        TNMD   17757   64102
# 2  ENSG00000000419        DPM1    3005    8813
# 3  ENSG00000000457       SCYL3   19285   57147
# 4  ENSG00000000460       FIRRM   25565   55732
#
#                            alias_symbol
# 0                         T245, TSPAN-6
# 1  myodulin, ChM1L, tendin, TEM, BRICD4
# 2                           MPDS, CDGIE
# 3                         PACE-1, PACE1
# 4        FLJ10706, Apolo1, FLIP, MEICA1

# %% [markdown]
# ### Make a set of the primary gene symbols

# %%
hgnc_gene_symbol_set = set(mini_hgnc_df["gene_symbol"])
# all_gene_symbols_set

# %%
total_number_hgnc_gene_symbols = len(hgnc_gene_symbol_set)
total_number_hgnc_gene_symbols
# Out:
# 45646

# %% [markdown]
# Drop genes with no aliases

# %%
mini_hgnc_df = mini_hgnc_df[
    ~mini_hgnc_df["alias_symbol"].isnull() & (mini_hgnc_df["alias_symbol"] != "")
]
mini_hgnc_df
# Out:
#                ENSG_ID gene_symbol HGNC_ID    NCBI_ID  \
# 0      ENSG00000000003      TSPAN6   11858       7105
# 1      ENSG00000000005        TNMD   17757      64102
# 2      ENSG00000000419        DPM1    3005       8813
# 3      ENSG00000000457       SCYL3   19285      57147
# 4      ENSG00000000460       FIRRM   25565      55732
# ...                ...         ...     ...        ...
# 45632              NaN     ZNF78L2   13152        nan
# 45636              NaN       ZNF88   13163        nan
# 45638              NaN       ZNF94   13170        nan
# 45643              NaN       ZPAXP   51635  105373450
# 45645              NaN     ZWINTAS   13196        nan
#
#                                alias_symbol
# 0                             T245, TSPAN-6
# 1      myodulin, ChM1L, tendin, TEM, BRICD4
# 2                               MPDS, CDGIE
# 3                             PACE-1, PACE1
# 4            FLJ10706, Apolo1, FLIP, MEICA1
# ...                                     ...
# 45632                                   pT3
# 45636                                  HPF8
# 45638                                F11465
# 45643                                 ZPX1P
# 45645            MPP5, MPHOSPH5, NCRNA00018
#
# [22647 rows x 5 columns]

# %% [markdown]
# ### Make each row in alias_symbol a set:
#     covert to a list
#     make a set

# %%
mini_hgnc_df["alias_symbol"] = mini_hgnc_df["alias_symbol"].astype(str)
type(mini_hgnc_df.alias_symbol[2].split(";"))
# Out:
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_24200/598450964.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mini_hgnc_df["alias_symbol"] = mini_hgnc_df["alias_symbol"].astype(str)
# list

# %%
mini_hgnc_df["alias_symbol"] = [x.split(";") for x in mini_hgnc_df.alias_symbol]
mini_hgnc_df.head(1)
# Out:
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_24200/521733868.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mini_hgnc_df["alias_symbol"] = [x.split(";") for x in mini_hgnc_df.alias_symbol]
#            ENSG_ID gene_symbol HGNC_ID NCBI_ID     alias_symbol
# 0  ENSG00000000003      TSPAN6   11858    7105  [T245, TSPAN-6]

# %%
mini_hgnc_df["alias_symbol"] = np.where(
    mini_hgnc_df.alias_symbol == "", "", mini_hgnc_df.alias_symbol.map(set)
)
mini_hgnc_df.head()
# Out:
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_24200/4167995068.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mini_hgnc_df["alias_symbol"] = np.where(
#            ENSG_ID gene_symbol HGNC_ID NCBI_ID  \
# 0  ENSG00000000003      TSPAN6   11858    7105
# 1  ENSG00000000005        TNMD   17757   64102
# 2  ENSG00000000419        DPM1    3005    8813
# 3  ENSG00000000457       SCYL3   19285   57147
# 4  ENSG00000000460       FIRRM   25565   55732
#
#                              alias_symbol
# 0                         {T245, TSPAN-6}
# 1  {myodulin, ChM1L, tendin, TEM, BRICD4}
# 2                           {MPDS, CDGIE}
# 3                         {PACE-1, PACE1}
# 4        {FLJ10706, Apolo1, FLIP, MEICA1}

# %% [markdown]
# ## Add test for false positives in the intersection points
# #### (places where x in alias_smbol matches x in mini_hgnc_df.gene_symbol in the same row)

# %%
mini_hgnc_df["gene_symbol"] = [x.split(";") for x in mini_hgnc_df.gene_symbol]
mini_hgnc_df["gene_symbol"] = np.where(
    mini_hgnc_df.gene_symbol == "", "", mini_hgnc_df.gene_symbol.map(set)
)
false_pos_mini_hgnc_df = mini_hgnc_df[
    mini_hgnc_df.alias_symbol.apply(lambda x: x & hgnc_gene_symbol_set)
    == mini_hgnc_df.gene_symbol
]
false_pos_mini_hgnc_df
# Out:
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_24200/4191048962.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mini_hgnc_df["gene_symbol"] = [x.split(";") for x in mini_hgnc_df.gene_symbol]
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_24200/4191048962.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mini_hgnc_df["gene_symbol"] = np.where(
# Empty DataFrame
# Columns: [ENSG_ID, gene_symbol, HGNC_ID, NCBI_ID, alias_symbol]
# Index: []

# %% [markdown]
# ### Need to remove aliases that match their primary key (gene symbol)

# %%
mini_hgnc_df["alias_symbol"] = mini_hgnc_df.alias_symbol - mini_hgnc_df.gene_symbol
# Out:
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_24200/1442966578.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mini_hgnc_df["alias_symbol"] = mini_hgnc_df.alias_symbol - mini_hgnc_df.gene_symbol

# %% [markdown]
# ## Find intersection points using alias symbol sets

# %%
# alias_symbol_sets_series = mini_hgnc_df.alias_symbol

# %%
mini_hgnc_df["intersect_point"] = mini_hgnc_df.alias_symbol.apply(
    lambda x: x & hgnc_gene_symbol_set
)
ag_collision_hgnc_df = mini_hgnc_df[mini_hgnc_df.intersect_point != set()]
ag_collision_hgnc_df
# Out:
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_24200/1698060902.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mini_hgnc_df["intersect_point"] = mini_hgnc_df.alias_symbol.apply(
#                ENSG_ID gene_symbol HGNC_ID NCBI_ID alias_symbol  \
# 25     ENSG00000002726      {AOC1}      80      26        {DAO}
# 461    ENSG00000027001     {MIPEP}    7104    4285        {MIP}
# 691    ENSG00000051341      {POLQ}    9186   10721       {POLH}
# 698    ENSG00000052344     {PRSS8}    9491    5652       {CAP1}
# 807    ENSG00000060069     {CTDP1}    2498    9150       {FCP1}
# ...                ...         ...     ...     ...          ...
# 42532              NaN     {L1RE3}   16899     nan       {LRE3}
# 42980              NaN    {MT-HPR}    7438     nan        {HPR}
# 43306              NaN    {PCDHA@}    8662   56117       {CNR1}
# 44660              NaN     {SPG32}   32314     nan      {SPG29}
# 45593              NaN    {ZNF159}   12944     nan        {F11}
#
#       intersect_point
# 25              {DAO}
# 461             {MIP}
# 691            {POLH}
# 698            {CAP1}
# 807            {FCP1}
# ...               ...
# 42532          {LRE3}
# 42980           {HPR}
# 43306          {CNR1}
# 44660         {SPG29}
# 45593           {F11}
#
# [96 rows x 6 columns]

# %%
ag_collision_hgnc_df["source"] = "HGNC"
ag_collision_hgnc_df.head()
# Out:
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_24200/3167554969.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ag_collision_hgnc_df["source"] = "HGNC"
#              ENSG_ID gene_symbol HGNC_ID NCBI_ID alias_symbol intersect_point  \
# 25   ENSG00000002726      {AOC1}      80      26        {DAO}           {DAO}
# 461  ENSG00000027001     {MIPEP}    7104    4285        {MIP}           {MIP}
# 691  ENSG00000051341      {POLQ}    9186   10721       {POLH}          {POLH}
# 698  ENSG00000052344     {PRSS8}    9491    5652       {CAP1}          {CAP1}
# 807  ENSG00000060069     {CTDP1}    2498    9150       {FCP1}          {FCP1}
#
#     source
# 25    HGNC
# 461   HGNC
# 691   HGNC
# 698   HGNC
# 807   HGNC

# %% [markdown]
# ### Convert sets to str or list

# %%
type(ag_collision_hgnc_df["gene_symbol"][25])
# Out:
# set

# %%
ag_collision_hgnc_df["gene_symbol"]
# Out:
# 25         {AOC1}
# 461       {MIPEP}
# 691        {POLQ}
# 698       {PRSS8}
# 807       {CTDP1}
#            ...
# 42532     {L1RE3}
# 42980    {MT-HPR}
# 43306    {PCDHA@}
# 44660     {SPG32}
# 45593    {ZNF159}
# Name: gene_symbol, Length: 96, dtype: object

# %%
list
# Out:
# list

# %%
def simple_func(arg):
    # arg = list(arg)
    print(arg)
    print(type(arg))
    print(list(arg))
    return arg


ag_collision_hgnc_df["gene_symbol"].apply(simple_func)
# Out:
# {'AOC1'}
# <class 'set'>
# ['AOC1']
# {'MIPEP'}
# <class 'set'>
# ['MIPEP']
# {'POLQ'}
# <class 'set'>
# ['POLQ']
# {'PRSS8'}
# <class 'set'>
# ['PRSS8']
# {'CTDP1'}
# <class 'set'>
# ['CTDP1']
# {'LZTS1'}
# <class 'set'>
# ['LZTS1']
# {'KIF2A'}
# <class 'set'>
# ['KIF2A']
# {'CDH19'}
# <class 'set'>
# ['CDH19']
# {'PTPN18'}
# <class 'set'>
# ['PTPN18']
# {'CADPS2'}
# <class 'set'>
# ['CADPS2']
# {'AKR1B1'}
# <class 'set'>
# ['AKR1B1']
# {'MLF2'}
# <class 'set'>
# ['MLF2']
# {'TOX4'}
# <class 'set'>
# ['TOX4']
# {'HOOK2'}
# <class 'set'>
# ['HOOK2']
# {'SEC14L3'}
# <class 'set'>
# ['SEC14L3']
# {'E2F1'}
# <class 'set'>
# ['E2F1']
# {'TIMP1'}
# <class 'set'>
# ['TIMP1']
# {'ACOD1'}
# <class 'set'>
# ['ACOD1']
# {'CRYM'}
# <class 'set'>
# ['CRYM']
# {'PPY'}
# <class 'set'>
# ['PPY']
# {'SMOC2'}
# <class 'set'>
# ['SMOC2']
# {'LAMA4'}
# <class 'set'>
# ['LAMA4']
# {'GNAI2'}
# <class 'set'>
# ['GNAI2']
# {'INSL6'}
# <class 'set'>
# ['INSL6']
# {'PMEPA1'}
# <class 'set'>
# ['PMEPA1']
# {'SOX9'}
# <class 'set'>
# ['SOX9']
# {'CPA4'}
# <class 'set'>
# ['CPA4']
# {'MBD4'}
# <class 'set'>
# ['MBD4']
# {'RNASE1'}
# <class 'set'>
# ['RNASE1']
# {'RIN2'}
# <class 'set'>
# ['RIN2']
# {'LGALS12'}
# <class 'set'>
# ['LGALS12']
# {'HOOK1'}
# <class 'set'>
# ['HOOK1']
# {'PAK6'}
# <class 'set'>
# ['PAK6']
# {'CPNE2'}
# <class 'set'>
# ['CPNE2']
# {'PDPK1'}
# <class 'set'>
# ['PDPK1']
# {'USP21'}
# <class 'set'>
# ['USP21']
# {'EIF2D'}
# <class 'set'>
# ['EIF2D']
# {'RGS18'}
# <class 'set'>
# ['RGS18']
# {'USP25'}
# <class 'set'>
# ['USP25']
# {'AFF2'}
# <class 'set'>
# ['AFF2']
# {'UGT2B4'}
# <class 'set'>
# ['UGT2B4']
# {'GALK2'}
# <class 'set'>
# ['GALK2']
# {'APPL1'}
# <class 'set'>
# ['APPL1']
# {'CLIC6'}
# <class 'set'>
# ['CLIC6']
# {'DDR2'}
# <class 'set'>
# ['DDR2']
# {'NPPC'}
# <class 'set'>
# ['NPPC']
# {'UCMA'}
# <class 'set'>
# ['UCMA']
# {'RNASE7'}
# <class 'set'>
# ['RNASE7']
# {'SERPINB8'}
# <class 'set'>
# ['SERPINB8']
# {'SOAT2'}
# <class 'set'>
# ['SOAT2']
# {'HOOK3'}
# <class 'set'>
# ['HOOK3']
# {'GLB1'}
# <class 'set'>
# ['GLB1']
# {'GAL3ST3'}
# <class 'set'>
# ['GAL3ST3']
# {'B3GNTL1'}
# <class 'set'>
# ['B3GNTL1']
# {'LYNX1'}
# <class 'set'>
# ['LYNX1']
# {'GET1'}
# <class 'set'>
# ['GET1']
# {'NELL2'}
# <class 'set'>
# ['NELL2']
# {'CFAP73'}
# <class 'set'>
# ['CFAP73']
# {'RGPD1'}
# <class 'set'>
# ['RGPD1']
# {'PMS2CL'}
# <class 'set'>
# ['PMS2CL']
# {'SYCP2'}
# <class 'set'>
# ['SYCP2']
# {'GALP'}
# <class 'set'>
# ['GALP']
# {'CYP2A7'}
# <class 'set'>
# ['CYP2A7']
# {'MB'}
# <class 'set'>
# ['MB']
# {'GNL1'}
# <class 'set'>
# ['GNL1']
# {'CDPF1'}
# <class 'set'>
# ['CDPF1']
# {'NUDT19'}
# <class 'set'>
# ['NUDT19']
# {'CPNE1'}
# <class 'set'>
# ['CPNE1']
# {'RSC1A1'}
# <class 'set'>
# ['RSC1A1']
# {'ACTBP8'}
# <class 'set'>
# ['ACTBP8']
# {'PPIAP10'}
# <class 'set'>
# ['PPIAP10']
# {'CYCSP5'}
# <class 'set'>
# ['CYCSP5']
# {'NANOGP2'}
# <class 'set'>
# ['NANOGP2']
# {'RHEBP1'}
# <class 'set'>
# ['RHEBP1']
# {'TCEA1P2'}
# <class 'set'>
# ['TCEA1P2']
# {'SEMA3F-AS1'}
# <class 'set'>
# ['SEMA3F-AS1']
# {'SPAAR'}
# <class 'set'>
# ['SPAAR']
# {'FABP5P1'}
# <class 'set'>
# ['FABP5P1']
# {'NANOGP4'}
# <class 'set'>
# ['NANOGP4']
# {'ZNF737'}
# <class 'set'>
# ['ZNF737']
# {'UGT1A1'}
# <class 'set'>
# ['UGT1A1']
# {'MGAM'}
# <class 'set'>
# ['MGAM']
# {'RNASE12'}
# <class 'set'>
# ['RNASE12']
# {'NANOGP7'}
# <class 'set'>
# ['NANOGP7']
# {'SMIM6'}
# <class 'set'>
# ['SMIM6']
# {'RNASEH1P1'}
# <class 'set'>
# ['RNASEH1P1']
# {'GAGE2E'}
# <class 'set'>
# ['GAGE2E']
# {'C3CER1'}
# <class 'set'>
# ['C3CER1']
# {'EXT3'}
# <class 'set'>
# ['EXT3']
# {'GAGE2D'}
# <class 'set'>
# ['GAGE2D']
# {'HPLH1'}
# <class 'set'>
# ['HPLH1']
# {'L1RE3'}
# <class 'set'>
# ['L1RE3']
# {'MT-HPR'}
# <class 'set'>
# ['MT-HPR']
# {'PCDHA@'}
# <class 'set'>
# ['PCDHA@']
# {'SPG32'}
# <class 'set'>
# ['SPG32']
# {'ZNF159'}
# <class 'set'>
# ['ZNF159']
# 25         {AOC1}
# 461       {MIPEP}
# 691        {POLQ}
# 698       {PRSS8}
# 807       {CTDP1}
#            ...
# 42532     {L1RE3}
# 42980    {MT-HPR}
# 43306    {PCDHA@}
# 44660     {SPG32}
# 45593    {ZNF159}
# Name: gene_symbol, Length: 96, dtype: object

# %%
# Assertion error if passed more than once
ag_collision_hgnc_df["gene_symbol"] = ag_collision_hgnc_df["gene_symbol"].apply(list)
ag_collision_hgnc_df
# Out:
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_24200/3077922419.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ag_collision_hgnc_df["gene_symbol"] = ag_collision_hgnc_df["gene_symbol"].apply(list)
#                ENSG_ID gene_symbol HGNC_ID NCBI_ID alias_symbol  \
# 25     ENSG00000002726      [AOC1]      80      26        {DAO}
# 461    ENSG00000027001     [MIPEP]    7104    4285        {MIP}
# 691    ENSG00000051341      [POLQ]    9186   10721       {POLH}
# 698    ENSG00000052344     [PRSS8]    9491    5652       {CAP1}
# 807    ENSG00000060069     [CTDP1]    2498    9150       {FCP1}
# ...                ...         ...     ...     ...          ...
# 42532              NaN     [L1RE3]   16899     nan       {LRE3}
# 42980              NaN    [MT-HPR]    7438     nan        {HPR}
# 43306              NaN    [PCDHA@]    8662   56117       {CNR1}
# 44660              NaN     [SPG32]   32314     nan      {SPG29}
# 45593              NaN    [ZNF159]   12944     nan        {F11}
#
#       intersect_point source
# 25              {DAO}   HGNC
# 461             {MIP}   HGNC
# 691            {POLH}   HGNC
# 698            {CAP1}   HGNC
# 807            {FCP1}   HGNC
# ...               ...    ...
# 42532          {LRE3}   HGNC
# 42980           {HPR}   HGNC
# 43306          {CNR1}   HGNC
# 44660         {SPG29}   HGNC
# 45593           {F11}   HGNC
#
# [96 rows x 7 columns]

# %%
# ag_collision_hgnc_df["ENSG_ID"] = ag_collision_hgnc_df["ENSG_ID"].astype(str)
# ag_collision_hgnc_df

# %% [markdown]
# ### Alphabetize alias_symbol

# %%
ag_collision_hgnc_df["alias_symbol"] = ag_collision_hgnc_df["alias_symbol"].apply(
    lambda x: sorted(list(x), key=str.casefold)
)
ag_collision_hgnc_df.head()
# Out:
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_24200/3065802178.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ag_collision_hgnc_df["alias_symbol"] = ag_collision_hgnc_df["alias_symbol"].apply(
#              ENSG_ID gene_symbol HGNC_ID NCBI_ID alias_symbol intersect_point  \
# 25   ENSG00000002726      [AOC1]      80      26        [DAO]           {DAO}
# 461  ENSG00000027001     [MIPEP]    7104    4285        [MIP]           {MIP}
# 691  ENSG00000051341      [POLQ]    9186   10721       [POLH]          {POLH}
# 698  ENSG00000052344     [PRSS8]    9491    5652       [CAP1]          {CAP1}
# 807  ENSG00000060069     [CTDP1]    2498    9150       [FCP1]          {FCP1}
#
#     source
# 25    HGNC
# 461   HGNC
# 691   HGNC
# 698   HGNC
# 807   HGNC

# %% [markdown]
# make a set of collisions
# - some records have multiple collisions, need to explode to one per row so that when i change it back to a str and make a set it doesnt count two collisions seperated by a commma as one unique collision

# %%
ag_collision_hgnc_df = ag_collision_hgnc_df.explode(column="intersect_point")
ag_collision_hgnc_df
# Out:
#                ENSG_ID gene_symbol HGNC_ID NCBI_ID alias_symbol  \
# 25     ENSG00000002726      [AOC1]      80      26        [DAO]
# 461    ENSG00000027001     [MIPEP]    7104    4285        [MIP]
# 691    ENSG00000051341      [POLQ]    9186   10721       [POLH]
# 698    ENSG00000052344     [PRSS8]    9491    5652       [CAP1]
# 807    ENSG00000060069     [CTDP1]    2498    9150       [FCP1]
# ...                ...         ...     ...     ...          ...
# 42532              NaN     [L1RE3]   16899     nan       [LRE3]
# 42980              NaN    [MT-HPR]    7438     nan        [HPR]
# 43306              NaN    [PCDHA@]    8662   56117       [CNR1]
# 44660              NaN     [SPG32]   32314     nan      [SPG29]
# 45593              NaN    [ZNF159]   12944     nan        [F11]
#
#       intersect_point source
# 25                DAO   HGNC
# 461               MIP   HGNC
# 691              POLH   HGNC
# 698              CAP1   HGNC
# 807              FCP1   HGNC
# ...               ...    ...
# 42532            LRE3   HGNC
# 42980             HPR   HGNC
# 43306            CNR1   HGNC
# 44660           SPG29   HGNC
# 45593             F11   HGNC
#
# [96 rows x 7 columns]

# %%
hgnc_alias_gene_collision_set = set(ag_collision_hgnc_df["intersect_point"])
len(hgnc_alias_gene_collision_set)
# Out:
# 94

# %%
ag_collision_hgnc_df["gene_symbol"] = ag_collision_hgnc_df["gene_symbol"].str.join(", ")

# %%
hgnc_alias_gene_collision_primary_symbol_set = set(ag_collision_hgnc_df["gene_symbol"])
len(hgnc_alias_gene_collision_primary_symbol_set)
# Out:
# 96

# %% [markdown]
# ### Alphabetize alias_symbol

# %%
ag_collision_hgnc_df["alias_symbol"] = ag_collision_hgnc_df["alias_symbol"].apply(
    lambda x: sorted(list(x), key=str.casefold)
)
ag_collision_hgnc_df.head()
# Out:
#              ENSG_ID gene_symbol HGNC_ID NCBI_ID alias_symbol intersect_point  \
# 25   ENSG00000002726        AOC1      80      26        [DAO]             DAO
# 461  ENSG00000027001       MIPEP    7104    4285        [MIP]             MIP
# 691  ENSG00000051341        POLQ    9186   10721       [POLH]            POLH
# 698  ENSG00000052344       PRSS8    9491    5652       [CAP1]            CAP1
# 807  ENSG00000060069       CTDP1    2498    9150       [FCP1]            FCP1
#
#     source
# 25    HGNC
# 461   HGNC
# 691   HGNC
# 698   HGNC
# 807   HGNC

# %%
print(type(ag_collision_hgnc_df.loc[25, "gene_symbol"]))
# Out:
# <class 'str'>

# %% [markdown]
# ### Convert lists to str

# %%
ag_collision_hgnc_df["alias_symbol"] = ag_collision_hgnc_df["alias_symbol"].str.join(
    ", "
)

# %%
ag_collision_hgnc_df = ag_collision_hgnc_df.sort_values("intersect_point")
ag_collision_hgnc_df
# Out:
#                ENSG_ID gene_symbol HGNC_ID    NCBI_ID alias_symbol  \
# 12161  ENSG00000167780       SOAT2   11178       8435        ACAT2
# 22389  ENSG00000220267      ACTBP8     141         68       ACTBP2
# 10075  ENSG00000157500       APPL1   24035      26060         APPL
# 1663   ENSG00000085662      AKR1B1     381        231           AR
# 13884  ENSG00000175711     B3GNTL1   21727     146712       B3GNT8
# ...                ...         ...     ...        ...          ...
# 30806  ENSG00000241635      UGT1A1   12530      54658        UGT1A
# 9908   ENSG00000156096      UGT2B4   12553       7363      UGT2B11
# 8327   ENSG00000143258       USP21   12620      27005        USP16
# 9829   ENSG00000155313       USP25   12624      29761        USP21
# 29427  ENSG00000237440      ZNF737   32468  100129842       ZNF102
#
#       intersect_point source
# 12161           ACAT2   HGNC
# 22389          ACTBP2   HGNC
# 10075            APPL   HGNC
# 1663               AR   HGNC
# 13884          B3GNT8   HGNC
# ...               ...    ...
# 30806           UGT1A   HGNC
# 9908          UGT2B11   HGNC
# 8327            USP16   HGNC
# 9829            USP21   HGNC
# 29427          ZNF102   HGNC
#
# [96 rows x 7 columns]

# %%
ag_collision_hgnc_df = ag_collision_hgnc_df.drop_duplicates(
    subset=["gene_symbol", "intersect_point"], keep="first"
)
ag_collision_hgnc_df
# Out:
#                ENSG_ID gene_symbol HGNC_ID    NCBI_ID alias_symbol  \
# 12161  ENSG00000167780       SOAT2   11178       8435        ACAT2
# 22389  ENSG00000220267      ACTBP8     141         68       ACTBP2
# 10075  ENSG00000157500       APPL1   24035      26060         APPL
# 1663   ENSG00000085662      AKR1B1     381        231           AR
# 13884  ENSG00000175711     B3GNTL1   21727     146712       B3GNT8
# ...                ...         ...     ...        ...          ...
# 30806  ENSG00000241635      UGT1A1   12530      54658        UGT1A
# 9908   ENSG00000156096      UGT2B4   12553       7363      UGT2B11
# 8327   ENSG00000143258       USP21   12620      27005        USP16
# 9829   ENSG00000155313       USP25   12624      29761        USP21
# 29427  ENSG00000237440      ZNF737   32468  100129842       ZNF102
#
#       intersect_point source
# 12161           ACAT2   HGNC
# 22389          ACTBP2   HGNC
# 10075            APPL   HGNC
# 1663               AR   HGNC
# 13884          B3GNT8   HGNC
# ...               ...    ...
# 30806           UGT1A   HGNC
# 9908          UGT2B11   HGNC
# 8327            USP16   HGNC
# 9829            USP21   HGNC
# 29427          ZNF102   HGNC
#
# [96 rows x 7 columns]

# %% [markdown]
# ## Add civic_gene_id to table

# %%
genes = civicpy.get_all_genes()

# %%
hgnc_NCBI_ID_list = list(ag_collision_hgnc_df["NCBI_ID"])

# %%
ag_collision_hgnc_df["NCBI_ID"] = ag_collision_hgnc_df["NCBI_ID"].str.replace(
    "nan", "000", regex=False
)
ag_collision_hgnc_df.head()
# Out:
#                ENSG_ID gene_symbol HGNC_ID NCBI_ID alias_symbol  \
# 12161  ENSG00000167780       SOAT2   11178    8435        ACAT2
# 22389  ENSG00000220267      ACTBP8     141      68       ACTBP2
# 10075  ENSG00000157500       APPL1   24035   26060         APPL
# 1663   ENSG00000085662      AKR1B1     381     231           AR
# 13884  ENSG00000175711     B3GNTL1   21727  146712       B3GNT8
#
#       intersect_point source
# 12161           ACAT2   HGNC
# 22389          ACTBP2   HGNC
# 10075            APPL   HGNC
# 1663               AR   HGNC
# 13884          B3GNT8   HGNC

# %%
ag_collision_hgnc_df["NCBI_ID"] = ag_collision_hgnc_df["NCBI_ID"].astype(int)

# %%
civic_ids = []
for entrez_id in hgnc_NCBI_ID_list:
    found_civic_id = ""
    for gene in genes:
        if entrez_id == str(gene.entrez_id):
            found_civic_id = gene.id
    civic_ids.append(found_civic_id)

ag_collision_hgnc_df["civic_ids"] = civic_ids
ag_collision_hgnc_df
# Out:
#                ENSG_ID gene_symbol HGNC_ID    NCBI_ID alias_symbol  \
# 12161  ENSG00000167780       SOAT2   11178       8435        ACAT2
# 22389  ENSG00000220267      ACTBP8     141         68       ACTBP2
# 10075  ENSG00000157500       APPL1   24035      26060         APPL
# 1663   ENSG00000085662      AKR1B1     381        231           AR
# 13884  ENSG00000175711     B3GNTL1   21727     146712       B3GNT8
# ...                ...         ...     ...        ...          ...
# 30806  ENSG00000241635      UGT1A1   12530      54658        UGT1A
# 9908   ENSG00000156096      UGT2B4   12553       7363      UGT2B11
# 8327   ENSG00000143258       USP21   12620      27005        USP16
# 9829   ENSG00000155313       USP25   12624      29761        USP21
# 29427  ENSG00000237440      ZNF737   32468  100129842       ZNF102
#
#       intersect_point source civic_ids
# 12161           ACAT2   HGNC
# 22389          ACTBP2   HGNC
# 10075            APPL   HGNC
# 1663               AR   HGNC
# 13884          B3GNT8   HGNC
# ...               ...    ...       ...
# 30806           UGT1A   HGNC     12422
# 9908          UGT2B11   HGNC
# 8327            USP16   HGNC
# 9829            USP21   HGNC
# 29427          ZNF102   HGNC
#
# [96 rows x 8 columns]

# %%
ag_collision_hgnc_df["civic_ids"].replace("", np.nan, inplace=True)
# Out:
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_24200/1342590437.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   ag_collision_hgnc_df["civic_ids"].replace("", np.nan, inplace=True)
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_24200/1342590437.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ag_collision_hgnc_df["civic_ids"].replace("", np.nan, inplace=True)

# %%
civic_ag_collision_hgnc_df = ag_collision_hgnc_df.copy()
civic_ag_collision_hgnc_df.dropna(subset=["civic_ids"], inplace=True)
civic_ag_collision_hgnc_df
# Out:
#                ENSG_ID gene_symbol HGNC_ID  NCBI_ID alias_symbol  \
# 2649   ENSG00000102265       TIMP1   11820     7076          EPO
# 4266   ENSG00000114353       GNAI2    4385     2771          GIP
# 6084   ENSG00000129071        MBD4    6919     8930         MED1
# 10780  ENSG00000162733        DDR2    2731     4921          TKT
# 30806  ENSG00000241635      UGT1A1   12530    54658        UGT1A
#
#       intersect_point source  civic_ids
# 2649              EPO   HGNC     5777.0
# 4266              GIP   HGNC     2312.0
# 6084             MED1   HGNC     7084.0
# 10780             TKT   HGNC       51.0
# 30806           UGT1A   HGNC    12422.0

# %%
ag_collision_hgnc_df.to_csv(
    "../created_files/ag_collision_hgnc_df_w_entrez_id.csv", index=False
)

# %% [markdown]
# ## Add MP ID & score

# %%
civic_ag_collision_hgnc_df_add_molprof_df = transform_df_mp_id(
    civic_ag_collision_hgnc_df
)
civic_ag_collision_hgnc_df_add_molprof_df
# Out:
#                ENSG_ID gene_symbol HGNC_ID  NCBI_ID alias_symbol  \
# 2649   ENSG00000102265       TIMP1   11820     7076          EPO
# 4266   ENSG00000114353       GNAI2    4385     2771          GIP
# 6084   ENSG00000129071        MBD4    6919     8930         MED1
# 10780  ENSG00000162733        DDR2    2731     4921          TKT
# 30806  ENSG00000241635      UGT1A1   12530    54658        UGT1A
#
#       intersect_point source  civic_ids molecular_profile_id
# 2649              EPO   HGNC     5777.0
# 4266              GIP   HGNC     2312.0               [2185]
# 6084             MED1   HGNC     7084.0
# 10780             TKT   HGNC       51.0
# 30806           UGT1A   HGNC    12422.0

# %%
civic_ag_collision_hgnc_df_add_molprof_score_df = transform_df_mp_score(
    civic_ag_collision_hgnc_df_add_molprof_df
)
civic_ag_collision_hgnc_df_add_molprof_score_df
# Out:
#                ENSG_ID gene_symbol HGNC_ID  NCBI_ID alias_symbol  \
# 2649   ENSG00000102265       TIMP1   11820     7076          EPO
# 4266   ENSG00000114353       GNAI2    4385     2771          GIP
# 6084   ENSG00000129071        MBD4    6919     8930         MED1
# 10780  ENSG00000162733        DDR2    2731     4921          TKT
# 30806  ENSG00000241635      UGT1A1   12530    54658        UGT1A
#
#       intersect_point source  civic_ids molecular_profile_id  \
# 2649              EPO   HGNC     5777.0
# 4266              GIP   HGNC     2312.0               [2185]
# 6084             MED1   HGNC     7084.0
# 10780             TKT   HGNC       51.0
# 30806           UGT1A   HGNC    12422.0
#
#       molecular_profile_score
# 2649
# 4266                    [0.0]
# 6084
# 10780
# 30806

# %% [markdown]
# ## Add evidence_ids column

# %%
civic_variant_ids = civicpy.get_all_variants()

# %%
hgnc_civic_id_list = list(civic_ag_collision_hgnc_df["civic_ids"])

# %%
civic_ag_collision_hgnc_df.civic_ids.astype(int)
# Out:
# 2649      5777
# 4266      2312
# 6084      7084
# 10780       51
# 30806    12422
# Name: civic_ids, dtype: int64

# %%
civic_eids = []
for civic_id in hgnc_civic_id_list:
    gene_civic_eids = []

    for variant in civic_variant_ids:
        if int(civic_id) == variant.gene_id:
            for mp in variant.molecular_profiles:
                for e in mp.evidence_items:
                    if e.id not in gene_civic_eids:
                        gene_civic_eids.append(e.id)

            gene_civic_eids = gene_civic_eids or ""
    civic_eids.append(gene_civic_eids)
civic_ag_collision_hgnc_df["civic_eids"] = civic_eids
civic_ag_collision_hgnc_df
# Out:
#                ENSG_ID gene_symbol HGNC_ID  NCBI_ID alias_symbol  \
# 2649   ENSG00000102265       TIMP1   11820     7076          EPO
# 4266   ENSG00000114353       GNAI2    4385     2771          GIP
# 6084   ENSG00000129071        MBD4    6919     8930         MED1
# 10780  ENSG00000162733        DDR2    2731     4921          TKT
# 30806  ENSG00000241635      UGT1A1   12530    54658        UGT1A
#
#       intersect_point source  civic_ids  \
# 2649              EPO   HGNC     5777.0
# 4266              GIP   HGNC     2312.0
# 6084             MED1   HGNC     7084.0
# 10780             TKT   HGNC       51.0
# 30806           UGT1A   HGNC    12422.0
#
#                                             civic_eids
# 2649                                        [927, 901]
# 4266                                    [11943, 11839]
# 6084                                            [7596]
# 10780  [266, 267, 268, 9853, 269, 270, 271, 9854, 272]
# 30806                                     [1792, 1795]

# %%
civic_evidence_list = civicpy.get_all_evidence()

# %%
hgnc_civic_eid_list = list(civic_ag_collision_hgnc_df["civic_eids"])
hgnc_civic_eid_list[0]
# Out:
# [927, 901]

# %%
evidence_ratings = []
for eid_list in hgnc_civic_eid_list:
    found_rating = []
    for eid in eid_list:
        for evidence in civic_evidence_list:
            if eid == evidence.id:
                found_rating.append(evidence.rating)
    evidence_ratings.append(found_rating)
civic_ag_collision_hgnc_df["evidence_ratings"] = evidence_ratings
civic_ag_collision_hgnc_df
# Out:
#                ENSG_ID gene_symbol HGNC_ID  NCBI_ID alias_symbol  \
# 2649   ENSG00000102265       TIMP1   11820     7076          EPO
# 4266   ENSG00000114353       GNAI2    4385     2771          GIP
# 6084   ENSG00000129071        MBD4    6919     8930         MED1
# 10780  ENSG00000162733        DDR2    2731     4921          TKT
# 30806  ENSG00000241635      UGT1A1   12530    54658        UGT1A
#
#       intersect_point source  civic_ids  \
# 2649              EPO   HGNC     5777.0
# 4266              GIP   HGNC     2312.0
# 6084             MED1   HGNC     7084.0
# 10780             TKT   HGNC       51.0
# 30806           UGT1A   HGNC    12422.0
#
#                                             civic_eids  \
# 2649                                        [927, 901]
# 4266                                    [11943, 11839]
# 6084                                            [7596]
# 10780  [266, 267, 268, 9853, 269, 270, 271, 9854, 272]
# 30806                                     [1792, 1795]
#
#                   evidence_ratings
# 2649                        [2, 2]
# 4266                        [4, 3]
# 6084                           [4]
# 10780  [4, 4, 4, 2, 4, 4, 4, 3, 3]
# 30806                       [5, 4]

# %%
average_evidence_rating = []
for alist in civic_ag_collision_hgnc_df["evidence_ratings"]:
    avg_rating = sum(alist) / len(alist)
    average_evidence_rating.append(avg_rating)
civic_ag_collision_hgnc_df["average_evidence_ratings"] = average_evidence_rating
civic_ag_collision_hgnc_df
# Out:
#                ENSG_ID gene_symbol HGNC_ID  NCBI_ID alias_symbol  \
# 2649   ENSG00000102265       TIMP1   11820     7076          EPO
# 4266   ENSG00000114353       GNAI2    4385     2771          GIP
# 6084   ENSG00000129071        MBD4    6919     8930         MED1
# 10780  ENSG00000162733        DDR2    2731     4921          TKT
# 30806  ENSG00000241635      UGT1A1   12530    54658        UGT1A
#
#       intersect_point source  civic_ids  \
# 2649              EPO   HGNC     5777.0
# 4266              GIP   HGNC     2312.0
# 6084             MED1   HGNC     7084.0
# 10780             TKT   HGNC       51.0
# 30806           UGT1A   HGNC    12422.0
#
#                                             civic_eids  \
# 2649                                        [927, 901]
# 4266                                    [11943, 11839]
# 6084                                            [7596]
# 10780  [266, 267, 268, 9853, 269, 270, 271, 9854, 272]
# 30806                                     [1792, 1795]
#
#                   evidence_ratings  average_evidence_ratings
# 2649                        [2, 2]                  2.000000
# 4266                        [4, 3]                  3.500000
# 6084                           [4]                  4.000000
# 10780  [4, 4, 4, 2, 4, 4, 4, 3, 3]                  3.555556
# 30806                       [5, 4]                  4.500000

# %%
sum_evidence_rating = []
for alist in civic_ag_collision_hgnc_df["evidence_ratings"]:
    sum_rating = sum(alist)
    sum_evidence_rating.append(sum_rating)
civic_ag_collision_hgnc_df["sum_evidence_rating"] = sum_evidence_rating
civic_ag_collision_hgnc_df
# Out:
#                ENSG_ID gene_symbol HGNC_ID  NCBI_ID alias_symbol  \
# 2649   ENSG00000102265       TIMP1   11820     7076          EPO
# 4266   ENSG00000114353       GNAI2    4385     2771          GIP
# 6084   ENSG00000129071        MBD4    6919     8930         MED1
# 10780  ENSG00000162733        DDR2    2731     4921          TKT
# 30806  ENSG00000241635      UGT1A1   12530    54658        UGT1A
#
#       intersect_point source  civic_ids  \
# 2649              EPO   HGNC     5777.0
# 4266              GIP   HGNC     2312.0
# 6084             MED1   HGNC     7084.0
# 10780             TKT   HGNC       51.0
# 30806           UGT1A   HGNC    12422.0
#
#                                             civic_eids  \
# 2649                                        [927, 901]
# 4266                                    [11943, 11839]
# 6084                                            [7596]
# 10780  [266, 267, 268, 9853, 269, 270, 271, 9854, 272]
# 30806                                     [1792, 1795]
#
#                   evidence_ratings  average_evidence_ratings  \
# 2649                        [2, 2]                  2.000000
# 4266                        [4, 3]                  3.500000
# 6084                           [4]                  4.000000
# 10780  [4, 4, 4, 2, 4, 4, 4, 3, 3]                  3.555556
# 30806                       [5, 4]                  4.500000
#
#        sum_evidence_rating
# 2649                     4
# 4266                     7
# 6084                     4
# 10780                   32
# 30806                    9

# %% [markdown]
# # NCBI Info

# %%
mini_ncbi_df = pd.read_csv("../downloaded_files/Homo_sapiens.gene_info20240627", sep="\t")

# %% [markdown]
# ### Drop all columns besides ENSG_ID, gene_symbol, and alias_symbol

# %%
mini_ncbi_df = mini_ncbi_df[
["GeneID", "Symbol", "Synonyms", "dbXrefs"]
]
mini_ncbi_df = mini_ncbi_df.rename(
    columns={"GeneID": "NCBI_ID", "Symbol": "gene_symbol", "Synonyms": "alias_symbol"}
)
mini_ncbi_df
# Out:
#    NCBI_ID gene_symbol               alias_symbol  \
# 0        1        A1BG       A1B|ABG|GAB|HYST2477
# 1        2         A2M  A2MD|CPAMD5|FWP007|S863-7
# 2        3       A2MP1                       A2MP
# 3        9        NAT1       AAC1|MNAT|NAT-1|NATI
# 4       10        NAT2            AAC2|NAT-2|PNAT
#
#                                              dbXrefs
# 0  MIM:138670|HGNC:HGNC:5|Ensembl:ENSG00000121410...
# 1  MIM:103950|HGNC:HGNC:7|Ensembl:ENSG00000175899...
# 2  HGNC:HGNC:8|Ensembl:ENSG00000291190|AllianceGe...
# 3  MIM:108345|HGNC:HGNC:7645|Ensembl:ENSG00000171...
# 4  MIM:612182|HGNC:HGNC:7646|Ensembl:ENSG00000156...

# %% [markdown]
# Split dbXrefs into individual columns

# %%
mini_ncbi_df = mini_ncbi_df.assign(
    MIM=np.nan,
    HGNC_ID=np.nan,
    ENSG_ID=np.nan,
    AllianceGenome=np.nan,
    MIRbase=np.nan,
    IMGTgene_db=np.nan,
    dash=np.nan,
    unknown=np.nan,
)

# %%
index_pos = 0

print(len(mini_ncbi_df))
while index_pos < len(mini_ncbi_df):
    xrefs = mini_ncbi_df["dbXrefs"][index_pos].split("|")

    for xref in xrefs:
        xref = xref.lower()
        if xref.startswith("mim:"):
            xref = xref.replace("mim:", "")
            mini_ncbi_df["MIM"][index_pos] = xref
        elif xref.startswith("hgnc:hgnc:"):
            xref = xref.replace("hgnc:hgnc:", "")
            mini_ncbi_df["HGNC_ID"][index_pos] = xref
        elif xref.startswith("ensembl:"):
            xref = xref.replace("ensembl:", "")
            mini_ncbi_df["ENSG_ID"][index_pos] = xref
        elif xref.startswith("alliancegenome:"):
            xref = xref.replace("alliancegenome:", "")
            mini_ncbi_df["AllianceGenome"][index_pos] = xref
        elif xref.startswith("mirbase"):
            xref = xref.replace("mirbase:", "")
            mini_ncbi_df["MIRbase"][index_pos] = xref
        elif xref.startswith("imgt/gene-db:"):
            xref = xref.replace("imgt/gene-db:", "")
            mini_ncbi_df["IMGTgene_db"][index_pos] = xref
        elif xref.startswith("-"):
            mini_ncbi_df["dash"][index_pos] = xref
        else:
            mini_ncbi_df["unknown"][index_pos] = xref

    index_pos += 1
    pass

print(index_pos)
# Out:
# 193456
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_24200/2507567125.py:11: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   mini_ncbi_df["MIM"][index_pos] = xref
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_24200/2507567125.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mini_ncbi_df["MIM"][index_pos] = xref
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_24200/2507567125.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '138670' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   mini_ncbi_df["MIM"][index_pos] = xref
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_24200/2507567125.py:14: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   mini_ncbi_df["HGNC_ID"][index_pos] = xref
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_24200/2507567125.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mini_ncbi_df["HGNC_ID"][index_pos] = xref
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_24200/2507567125.py:14: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '5' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   mini_ncbi_df["HGNC_ID"][index_pos] = xref
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_24200/2507567125.py:17: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   mini_ncbi_df["ENSG_ID"][index_pos] = xref
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_24200/2507567125.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mini_ncbi_df["ENSG_ID"][index_pos] = xref
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_24200/2507567125.py:17: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'ensg00000121410' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   mini_ncbi_df["ENSG_ID"][index_pos] = xref
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_24200/2507567125.py:20: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   mini_ncbi_df["AllianceGenome"][index_pos] = xref
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_24200/2507567125.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mini_ncbi_df["AllianceGenome"][index_pos] = xref
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_24200/2507567125.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'hgnc:5' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   mini_ncbi_df["AllianceGenome"][index_pos] = xref
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_24200/2507567125.py:26: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   mini_ncbi_df["IMGTgene_db"][index_pos] = xref
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_24200/2507567125.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mini_ncbi_df["IMGTgene_db"][index_pos] = xref
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_24200/2507567125.py:26: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'cd1d' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   mini_ncbi_df["IMGTgene_db"][index_pos] = xref
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_24200/2507567125.py:28: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   mini_ncbi_df["dash"][index_pos] = xref
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_24200/2507567125.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mini_ncbi_df["dash"][index_pos] = xref
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_24200/2507567125.py:28: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   mini_ncbi_df["dash"][index_pos] = xref
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_24200/2507567125.py:23: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   mini_ncbi_df["MIRbase"][index_pos] = xref
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_24200/2507567125.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mini_ncbi_df["MIRbase"][index_pos] = xref
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_24200/2507567125.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'mi0000060' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   mini_ncbi_df["MIRbase"][index_pos] = xref
# 193456

# %%
mini_ncbi_df["ENSG_ID"] = mini_ncbi_df["ENSG_ID"].str.replace("ensg", "ENSG", 1)

# %%
mini_ncbi_df = mini_ncbi_df.drop(
    [
        "AllianceGenome",
        "MIRbase",
        "IMGTgene_db",
        "dash",
        "unknown",
        "dbXrefs",
        "MIM",
    ],
    axis=1,
)
mini_ncbi_df = mini_ncbi_df.rename(columns={"HGNC_ID": "HGNC_ID"})
mini_ncbi_df
# Out:
#         NCBI_ID gene_symbol               alias_symbol HGNC_ID  \
# 0             1        A1BG       A1B|ABG|GAB|HYST2477       5
# 1             2         A2M  A2MD|CPAMD5|FWP007|S863-7       7
# 2             3       A2MP1                       A2MP       8
# 3             9        NAT1       AAC1|MNAT|NAT-1|NATI    7645
# 4            10        NAT2            AAC2|NAT-2|PNAT    7646
# ...         ...         ...                        ...     ...
# 193451  8923215        trnD                          -     NaN
# 193452  8923216        trnP                          -     NaN
# 193453  8923217        trnA                          -     NaN
# 193454  8923218        COX1                          -     NaN
# 193455  8923219    16S rRNA                          -     NaN
#
#                 ENSG_ID
# 0       ENSG00000121410
# 1       ENSG00000175899
# 2       ENSG00000291190
# 3       ENSG00000171428
# 4       ENSG00000156006
# ...                 ...
# 193451              NaN
# 193452              NaN
# 193453              NaN
# 193454              NaN
# 193455              NaN
#
# [193456 rows x 5 columns]

# %%
mini_ncbi_df.to_csv("../created_files/mini_ncbi_df.csv", index=False)
mini_ncbi_df.head()
# Out:
#    NCBI_ID gene_symbol               alias_symbol HGNC_ID          ENSG_ID
# 0        1        A1BG       A1B|ABG|GAB|HYST2477       5  ENSG00000121410
# 1        2         A2M  A2MD|CPAMD5|FWP007|S863-7       7  ENSG00000175899
# 2        3       A2MP1                       A2MP       8  ENSG00000291190
# 3        9        NAT1       AAC1|MNAT|NAT-1|NATI    7645  ENSG00000171428
# 4       10        NAT2            AAC2|NAT-2|PNAT    7646  ENSG00000156006

# %% [markdown]
# One gene symbol may have multiple NCBI IDs

# %%
mini_ncbi_df["symbol_duplicates"] = mini_ncbi_df.duplicated(
    subset="gene_symbol", keep=False
)
dup_symbol_mini_ncbi_df = mini_ncbi_df[mini_ncbi_df["symbol_duplicates"] == True]

# %%
dup_symbol_mini_ncbi_df = dup_symbol_mini_ncbi_df.sort_values("gene_symbol")
dup_symbol_mini_ncbi_df
# Out:
#         NCBI_ID gene_symbol    alias_symbol HGNC_ID ENSG_ID  symbol_duplicates
# 193408  6775087    12S rRNA               -     NaN     NaN               True
# 193449  8923213    12S rRNA               -     NaN     NaN               True
# 193424  8923188        ATP6               -     NaN     NaN               True
# 3541       4508        ATP6  ATPase6|MTATP6    7414     NaN               True
# 193395  6775074        ATP6               -     NaN     NaN               True
# ...         ...         ...             ...     ...     ...                ...
# 193411  6775090        trnV               -     NaN     NaN               True
# 193430  8923194        trnW               -     NaN     NaN               True
# 193413  6775092        trnW               -     NaN     NaN               True
# 193403  6775082        trnY               -     NaN     NaN               True
# 193439  8923203        trnY               -     NaN     NaN               True
#
# [203 rows x 6 columns]

# %%
mini_ncbi_df = mini_ncbi_df.drop(["symbol_duplicates"], axis=1)

# %% [markdown]
# ### Make a set of primary gene symbols

# %%
ncbi_gene_symbol_set = set(mini_ncbi_df["gene_symbol"])

# %%
total_number_ncbi_gene_symbols = len(ncbi_gene_symbol_set)
total_number_ncbi_gene_symbols
# Out:
# 193303

# %% [markdown]
# Drop genes with no aliases

# %%
mini_ncbi_df = mini_ncbi_df.replace("-", np.nan)
mini_ncbi_df
# Out:
#         NCBI_ID gene_symbol               alias_symbol HGNC_ID  \
# 0             1        A1BG       A1B|ABG|GAB|HYST2477       5
# 1             2         A2M  A2MD|CPAMD5|FWP007|S863-7       7
# 2             3       A2MP1                       A2MP       8
# 3             9        NAT1       AAC1|MNAT|NAT-1|NATI    7645
# 4            10        NAT2            AAC2|NAT-2|PNAT    7646
# ...         ...         ...                        ...     ...
# 193451  8923215        trnD                        NaN     NaN
# 193452  8923216        trnP                        NaN     NaN
# 193453  8923217        trnA                        NaN     NaN
# 193454  8923218        COX1                        NaN     NaN
# 193455  8923219    16S rRNA                        NaN     NaN
#
#                 ENSG_ID
# 0       ENSG00000121410
# 1       ENSG00000175899
# 2       ENSG00000291190
# 3       ENSG00000171428
# 4       ENSG00000156006
# ...                 ...
# 193451              NaN
# 193452              NaN
# 193453              NaN
# 193454              NaN
# 193455              NaN
#
# [193456 rows x 5 columns]

# %%
mini_ncbi_df = mini_ncbi_df.dropna(subset=["alias_symbol"])
mini_ncbi_df
# Out:
#           NCBI_ID   gene_symbol               alias_symbol HGNC_ID  \
# 0               1          A1BG       A1B|ABG|GAB|HYST2477       5
# 1               2           A2M  A2MD|CPAMD5|FWP007|S863-7       7
# 2               3         A2MP1                       A2MP       8
# 3               9          NAT1       AAC1|MNAT|NAT-1|NATI    7645
# 4              10          NAT2            AAC2|NAT-2|PNAT    7646
# ...           ...           ...                        ...     ...
# 190958  131696449  LOC131696449             PKD1P1-NPIPA5L     NaN
# 190961  131840634         GLTC1                       GLTC   56861
# 193342  132532400    GABRA6-AS1                      ARBAG   40248
# 193377  133395150       LNCARGI                       ARGI   56890
# 193378  133834869         MLDHR               MP31|PTENURF   55481
#
#                 ENSG_ID
# 0       ENSG00000121410
# 1       ENSG00000175899
# 2       ENSG00000291190
# 3       ENSG00000171428
# 4       ENSG00000156006
# ...                 ...
# 190958              NaN
# 190961              NaN
# 193342              NaN
# 193377              NaN
# 193378              NaN
#
# [27582 rows x 5 columns]

# %% [markdown]
# ### Make each row in alias_symbol a set:
#     covert to a list
#     make a set

# %%
# alias_symbol_sets = mini_ncbi_df.alias_symbol

# %%
mini_ncbi_df["alias_symbol"] = mini_ncbi_df["alias_symbol"].astype(str)
mini_ncbi_df["alias_symbol"] = [x.split("|") for x in mini_ncbi_df.alias_symbol]
mini_ncbi_df["alias_symbol"] = np.where(
    mini_ncbi_df.alias_symbol == " ", " ", mini_ncbi_df.alias_symbol.map(set)
)
mini_ncbi_df.head(1)
# Out:
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_24200/141386331.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mini_ncbi_df["alias_symbol"] = mini_ncbi_df["alias_symbol"].astype(str)
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_24200/141386331.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mini_ncbi_df["alias_symbol"] = [x.split("|") for x in mini_ncbi_df.alias_symbol]
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_24200/141386331.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mini_ncbi_df["alias_symbol"] = np.where(
#    NCBI_ID gene_symbol               alias_symbol HGNC_ID          ENSG_ID
# 0        1        A1BG  {HYST2477, ABG, GAB, A1B}       5  ENSG00000121410

# %% [markdown]
# ### Add test for false positives in the intersection points
# #### (places where x in alias_symbol matches x in mini_hgnc_df.gene_symbol in the same row)

# %%
mini_ncbi_df["gene_symbol"] = [x.split(";") for x in mini_ncbi_df.gene_symbol]
mini_ncbi_df["gene_symbol"] = np.where(
    mini_ncbi_df.gene_symbol == "", "", mini_ncbi_df.gene_symbol.map(set)
)
false_pos_mini_ncbi_df = mini_ncbi_df[
    mini_ncbi_df.alias_symbol.apply(lambda x: x & ncbi_gene_symbol_set)
    == mini_ncbi_df.gene_symbol
]
false_pos_mini_ncbi_df.head()
# Out:
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_24200/2999516832.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mini_ncbi_df["gene_symbol"] = [x.split(";") for x in mini_ncbi_df.gene_symbol]
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_24200/2999516832.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mini_ncbi_df["gene_symbol"] = np.where(
# Empty DataFrame
# Columns: [NCBI_ID, gene_symbol, alias_symbol, HGNC_ID, ENSG_ID]
# Index: []

# %%
mini_ncbi_df["alias_symbol"] = mini_ncbi_df.alias_symbol - mini_ncbi_df.gene_symbol
display(mini_ncbi_df.iloc[7805])
# Out:
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_24200/4160973246.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mini_ncbi_df["alias_symbol"] = mini_ncbi_df.alias_symbol - mini_ncbi_df.gene_symbol
# NCBI_ID                       10944
# gene_symbol              {C11orf58}
# alias_symbol    {SMAP, IMAGE145052}
# HGNC_ID                       16990
# ENSG_ID             ENSG00000110696
# Name: 8575, dtype: object

# %% [markdown]
# ### Find intersection points using alias symbol sets and gene_symbol

# %%
mini_ncbi_df["intersect_point"] = mini_ncbi_df.alias_symbol.apply(
    lambda x: x & ncbi_gene_symbol_set
)
ag_collision_ncbi_df = mini_ncbi_df[mini_ncbi_df.intersect_point != set()]
ag_collision_ncbi_df
# Out:
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_24200/3176496178.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mini_ncbi_df["intersect_point"] = mini_ncbi_df.alias_symbol.apply(
#           NCBI_ID     gene_symbol  \
# 9              15         {AANAT}
# 20             26          {AOC1}
# 34             40         {ASIC2}
# 44             53          {ACP2}
# 56             68        {ACTBP8}
# ...           ...             ...
# 70125   124905743  {LOC124905743}
# 70798   124906461  {LOC124906461}
# 74259   125316803       {POLGARF}
# 140700  127898561         {MIURF}
# 141209  128385376  {TMEM184B-AS1}
#
#                                             alias_symbol HGNC_ID  \
# 9                                           {DSPS, SNAT}      19
# 20                     {DAO, ABP1, ABP, DAO1, KAO, KDAO}      80
# 34      {ACCN, BNaC1, BNC1, ASIC2a, MDEG, ACCN1, hBNaC1}      99
# 44                                                 {LAP}     123
# 56                                              {ACTBP2}     141
# ...                                                  ...     ...
# 70125                                           {FCGR3B}     NaN
# 70798                                             {DUX4}     NaN
# 74259                                      {ORF-Y, POLG}   56246
# 140700             {MIEF1-MP, AltMIEF1, AltMiD51, MIEF1}     NaN
# 141209                                             {RP1}   56716
#
#                 ENSG_ID intersect_point
# 9       ENSG00000129673          {DSPS}
# 20      ENSG00000002726           {DAO}
# 34      ENSG00000108684          {BNC1}
# 44      ENSG00000134575           {LAP}
# 56                  NaN        {ACTBP2}
# ...                 ...             ...
# 70125               NaN        {FCGR3B}
# 70798               NaN          {DUX4}
# 74259   ENSG00000291307          {POLG}
# 140700  ENSG00000285025         {MIEF1}
# 141209  ENSG00000235246           {RP1}
#
# [1688 rows x 6 columns]

# %% [markdown]
# ### Replace NAN in ENSG_ID

# %%
ag_collision_ncbi_df["ENSG_ID"] = ag_collision_ncbi_df["ENSG_ID"].replace("NAN", "nan")
# Out:
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_24200/2807366171.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ag_collision_ncbi_df["ENSG_ID"] = ag_collision_ncbi_df["ENSG_ID"].replace("NAN", "nan")

# %%
ag_collision_ncbi_df["source"] = "NCBI Info"
ag_collision_ncbi_df.head()
# Out:
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_24200/1195603707.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ag_collision_ncbi_df["source"] = "NCBI Info"
#     NCBI_ID gene_symbol                                      alias_symbol  \
# 9        15     {AANAT}                                      {DSPS, SNAT}
# 20       26      {AOC1}                 {DAO, ABP1, ABP, DAO1, KAO, KDAO}
# 34       40     {ASIC2}  {ACCN, BNaC1, BNC1, ASIC2a, MDEG, ACCN1, hBNaC1}
# 44       53      {ACP2}                                             {LAP}
# 56       68    {ACTBP8}                                          {ACTBP2}
#
#    HGNC_ID          ENSG_ID intersect_point     source
# 9       19  ENSG00000129673          {DSPS}  NCBI Info
# 20      80  ENSG00000002726           {DAO}  NCBI Info
# 34      99  ENSG00000108684          {BNC1}  NCBI Info
# 44     123  ENSG00000134575           {LAP}  NCBI Info
# 56     141              NaN        {ACTBP2}  NCBI Info

# %% [markdown]
# ### Convert sets to str or list

# %%
# Assertion error when when run more than once
ag_collision_ncbi_df["gene_symbol"] = ag_collision_ncbi_df["gene_symbol"].apply(list)
ag_collision_ncbi_df.head()
# Out:
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_24200/2064384859.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ag_collision_ncbi_df["gene_symbol"] = ag_collision_ncbi_df["gene_symbol"].apply(list)
#     NCBI_ID gene_symbol                                      alias_symbol  \
# 9        15     [AANAT]                                      {DSPS, SNAT}
# 20       26      [AOC1]                 {DAO, ABP1, ABP, DAO1, KAO, KDAO}
# 34       40     [ASIC2]  {ACCN, BNaC1, BNC1, ASIC2a, MDEG, ACCN1, hBNaC1}
# 44       53      [ACP2]                                             {LAP}
# 56       68    [ACTBP8]                                          {ACTBP2}
#
#    HGNC_ID          ENSG_ID intersect_point     source
# 9       19  ENSG00000129673          {DSPS}  NCBI Info
# 20      80  ENSG00000002726           {DAO}  NCBI Info
# 34      99  ENSG00000108684          {BNC1}  NCBI Info
# 44     123  ENSG00000134575           {LAP}  NCBI Info
# 56     141              NaN        {ACTBP2}  NCBI Info

# %%
ag_collision_ncbi_df["ENSG_ID"] = ag_collision_ncbi_df["ENSG_ID"].astype(str)
ag_collision_ncbi_df.head()
# Out:
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_24200/3032823297.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ag_collision_ncbi_df["ENSG_ID"] = ag_collision_ncbi_df["ENSG_ID"].astype(str)
#     NCBI_ID gene_symbol                                      alias_symbol  \
# 9        15     [AANAT]                                      {DSPS, SNAT}
# 20       26      [AOC1]                 {DAO, ABP1, ABP, DAO1, KAO, KDAO}
# 34       40     [ASIC2]  {ACCN, BNaC1, BNC1, ASIC2a, MDEG, ACCN1, hBNaC1}
# 44       53      [ACP2]                                             {LAP}
# 56       68    [ACTBP8]                                          {ACTBP2}
#
#    HGNC_ID          ENSG_ID intersect_point     source
# 9       19  ENSG00000129673          {DSPS}  NCBI Info
# 20      80  ENSG00000002726           {DAO}  NCBI Info
# 34      99  ENSG00000108684          {BNC1}  NCBI Info
# 44     123  ENSG00000134575           {LAP}  NCBI Info
# 56     141              nan        {ACTBP2}  NCBI Info

# %% [markdown]
# ### Alphabetize alias_symbol

# %%
ag_collision_ncbi_df["alias_symbol"] = ag_collision_ncbi_df["alias_symbol"].apply(
    lambda x: sorted(list(x), key=str.casefold)
)
ag_collision_ncbi_df.head()
# Out:
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_24200/241426528.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ag_collision_ncbi_df["alias_symbol"] = ag_collision_ncbi_df["alias_symbol"].apply(
#     NCBI_ID gene_symbol                                      alias_symbol  \
# 9        15     [AANAT]                                      [DSPS, SNAT]
# 20       26      [AOC1]                 [ABP, ABP1, DAO, DAO1, KAO, KDAO]
# 34       40     [ASIC2]  [ACCN, ACCN1, ASIC2a, BNaC1, BNC1, hBNaC1, MDEG]
# 44       53      [ACP2]                                             [LAP]
# 56       68    [ACTBP8]                                          [ACTBP2]
#
#    HGNC_ID          ENSG_ID intersect_point     source
# 9       19  ENSG00000129673          {DSPS}  NCBI Info
# 20      80  ENSG00000002726           {DAO}  NCBI Info
# 34      99  ENSG00000108684          {BNC1}  NCBI Info
# 44     123  ENSG00000134575           {LAP}  NCBI Info
# 56     141              nan        {ACTBP2}  NCBI Info

# %% [markdown]
# make a set of collisions
# - some records have multiple collisions, need to explode to one per row so that when i change it back to a str and make a set it doesnt count two collisions seperated by a commma as one unique collision

# %%
intersect_explode_ag_collision_ncbi_df = ag_collision_ncbi_df.explode(
    column="intersect_point"
)
intersect_explode_ag_collision_ncbi_df
# Out:
#           NCBI_ID     gene_symbol  \
# 9              15         [AANAT]
# 20             26          [AOC1]
# 34             40         [ASIC2]
# 44             53          [ACP2]
# 56             68        [ACTBP8]
# ...           ...             ...
# 70125   124905743  [LOC124905743]
# 70798   124906461  [LOC124906461]
# 74259   125316803       [POLGARF]
# 140700  127898561         [MIURF]
# 141209  128385376  [TMEM184B-AS1]
#
#                                             alias_symbol HGNC_ID  \
# 9                                           [DSPS, SNAT]      19
# 20                     [ABP, ABP1, DAO, DAO1, KAO, KDAO]      80
# 34      [ACCN, ACCN1, ASIC2a, BNaC1, BNC1, hBNaC1, MDEG]      99
# 44                                                 [LAP]     123
# 56                                              [ACTBP2]     141
# ...                                                  ...     ...
# 70125                                           [FCGR3B]     NaN
# 70798                                             [DUX4]     NaN
# 74259                                      [ORF-Y, POLG]   56246
# 140700             [AltMiD51, AltMIEF1, MIEF1, MIEF1-MP]     NaN
# 141209                                             [RP1]   56716
#
#                 ENSG_ID intersect_point     source
# 9       ENSG00000129673            DSPS  NCBI Info
# 20      ENSG00000002726             DAO  NCBI Info
# 34      ENSG00000108684            BNC1  NCBI Info
# 44      ENSG00000134575             LAP  NCBI Info
# 56                  nan          ACTBP2  NCBI Info
# ...                 ...             ...        ...
# 70125               nan          FCGR3B  NCBI Info
# 70798               nan            DUX4  NCBI Info
# 74259   ENSG00000291307            POLG  NCBI Info
# 140700  ENSG00000285025           MIEF1  NCBI Info
# 141209  ENSG00000235246             RP1  NCBI Info
#
# [2128 rows x 7 columns]

# %%
ncbi_alias_gene_collision_set = set(
    intersect_explode_ag_collision_ncbi_df["intersect_point"]
)
len(ncbi_alias_gene_collision_set)
# Out:
# 1554

# %%
intersect_explode_ag_collision_ncbi_df["gene_symbol"] = (
    intersect_explode_ag_collision_ncbi_df["gene_symbol"].str.join(", ")
)

# %%
ncbi_alias_gene_collision_primary_symbol_set = set(
    intersect_explode_ag_collision_ncbi_df["gene_symbol"]
)
len(ncbi_alias_gene_collision_primary_symbol_set)
# Out:
# 1688

# %% [markdown]
# ### Alphabetize intersect_point

# %%
ag_collision_ncbi_df["intersect_point"] = ag_collision_ncbi_df["intersect_point"].apply(
    lambda x: sorted(list(x), key=str.casefold)
)
ag_collision_ncbi_df.head()
# Out:
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_24200/799254919.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ag_collision_ncbi_df["intersect_point"] = ag_collision_ncbi_df["intersect_point"].apply(
#     NCBI_ID gene_symbol                                      alias_symbol  \
# 9        15     [AANAT]                                      [DSPS, SNAT]
# 20       26      [AOC1]                 [ABP, ABP1, DAO, DAO1, KAO, KDAO]
# 34       40     [ASIC2]  [ACCN, ACCN1, ASIC2a, BNaC1, BNC1, hBNaC1, MDEG]
# 44       53      [ACP2]                                             [LAP]
# 56       68    [ACTBP8]                                          [ACTBP2]
#
#    HGNC_ID          ENSG_ID intersect_point     source
# 9       19  ENSG00000129673          [DSPS]  NCBI Info
# 20      80  ENSG00000002726           [DAO]  NCBI Info
# 34      99  ENSG00000108684          [BNC1]  NCBI Info
# 44     123  ENSG00000134575           [LAP]  NCBI Info
# 56     141              nan        [ACTBP2]  NCBI Info

# %% [markdown]
# ### Convert lists to str

# %%
ag_collision_ncbi_df["gene_symbol"] = ag_collision_ncbi_df["gene_symbol"].str.join(", ")
# Out:
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_24200/2858309106.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ag_collision_ncbi_df["gene_symbol"] = ag_collision_ncbi_df["gene_symbol"].str.join(", ")

# %%
ag_collision_ncbi_df["alias_symbol"] = ag_collision_ncbi_df["alias_symbol"].str.join(
    ", "
)
# Out:
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_24200/1783911757.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ag_collision_ncbi_df["alias_symbol"] = ag_collision_ncbi_df["alias_symbol"].str.join(

# %%
ag_collision_ncbi_df["intersect_point"] = ag_collision_ncbi_df[
    "intersect_point"
].str.join(", ")
ag_collision_ncbi_df
# Out:
# /var/folders/vt/znzp_c6s02q6kjcmqfk0cb500000gq/T/ipykernel_24200/2875730709.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ag_collision_ncbi_df["intersect_point"] = ag_collision_ncbi_df[
#           NCBI_ID   gene_symbol  \
# 9              15         AANAT
# 20             26          AOC1
# 34             40         ASIC2
# 44             53          ACP2
# 56             68        ACTBP8
# ...           ...           ...
# 70125   124905743  LOC124905743
# 70798   124906461  LOC124906461
# 74259   125316803       POLGARF
# 140700  127898561         MIURF
# 141209  128385376  TMEM184B-AS1
#
#                                           alias_symbol HGNC_ID  \
# 9                                           DSPS, SNAT      19
# 20                     ABP, ABP1, DAO, DAO1, KAO, KDAO      80
# 34      ACCN, ACCN1, ASIC2a, BNaC1, BNC1, hBNaC1, MDEG      99
# 44                                                 LAP     123
# 56                                              ACTBP2     141
# ...                                                ...     ...
# 70125                                           FCGR3B     NaN
# 70798                                             DUX4     NaN
# 74259                                      ORF-Y, POLG   56246
# 140700             AltMiD51, AltMIEF1, MIEF1, MIEF1-MP     NaN
# 141209                                             RP1   56716
#
#                 ENSG_ID intersect_point     source
# 9       ENSG00000129673            DSPS  NCBI Info
# 20      ENSG00000002726             DAO  NCBI Info
# 34      ENSG00000108684            BNC1  NCBI Info
# 44      ENSG00000134575             LAP  NCBI Info
# 56                  nan          ACTBP2  NCBI Info
# ...                 ...             ...        ...
# 70125               nan          FCGR3B  NCBI Info
# 70798               nan            DUX4  NCBI Info
# 74259   ENSG00000291307            POLG  NCBI Info
# 140700  ENSG00000285025           MIEF1  NCBI Info
# 141209  ENSG00000235246             RP1  NCBI Info
#
# [1688 rows x 7 columns]

# %% [markdown]
# # Merge 3 sets together

# %%
merged_alias_gene_intersections_df = pd.concat(
    [
        ag_collision_hgnc_df[
            ["gene_symbol", "alias_symbol", "intersect_point", "source"]
        ],
        ag_collision_ncbi_df[
            ["gene_symbol", "alias_symbol", "intersect_point", "source"]
        ],
        ag_collision_ensg_df[
            ["gene_symbol", "alias_symbol", "intersect_point", "source"]
        ],
    ]
)
merged_alias_gene_intersections_df
# Out:
#       gene_symbol      alias_symbol intersect_point source
# 12161       SOAT2             ACAT2           ACAT2   HGNC
# 22389      ACTBP8            ACTBP2          ACTBP2   HGNC
# 10075       APPL1              APPL            APPL   HGNC
# 1663       AKR1B1                AR              AR   HGNC
# 13884     B3GNTL1            B3GNT8          B3GNT8   HGNC
# ...           ...               ...             ...    ...
# 8401        USP21      USP23, USP16           USP16   ENSG
# 9928        USP25             USP21           USP21   ENSG
# 54879     VDAC1P5     VDAC5P, VDAC3           VDAC3   ENSG
# 42358      XBP1P1       XBPP1, XBP1            XBP1   ENSG
# 16971    ZNF322P1   ZNF322B, ZNF322          ZNF322   ENSG
#
# [2026 rows x 4 columns]

# %%
merged_alias_gene_intersections_df.loc[
    merged_alias_gene_intersections_df["intersect_point"] == "CFM1"
]
# Out:
#       gene_symbol   alias_symbol intersect_point     source
# 22292       RFLNB  CFM1, FAM101B            CFM1  NCBI Info

# %% [markdown]
# # Convert to csv

# %%
merged_alias_gene_intersections_df.to_csv(
    "../created_files/merged_alias_gene_intersections.csv", index=False
)

# %%
print(merged_alias_gene_intersections_df["source"].value_counts())
# Out:
# source
# NCBI Info    1688
# ENSG          242
# HGNC           96
# Name: count, dtype: int64

# %%
common_ag_collisions = (
    ncbi_alias_gene_collision_primary_symbol_set
    & hgnc_alias_gene_collision_primary_symbol_set
    & ensg_alias_gene_collision_primary_symbol_set
)
common_ag_collisions
# Out:
# {'ACOD1',
#  'ACTBP8',
#  'B3GNTL1',
#  'CADPS2',
#  'CDH19',
#  'CPA4',
#  'CPNE1',
#  'CPNE2',
#  'CYCSP5',
#  'FABP5P1',
#  'GAL3ST3',
#  'GALK2',
#  'GALP',
#  'GET1',
#  'GLB1',
#  'GNAI2',
#  'HOOK1',
#  'HOOK2',
#  'HOOK3',
#  'INSL6',
#  'KIF2A',
#  'LAMA4',
#  'LGALS12',
#  'LZTS1',
#  'MB',
#  'MBD4',
#  'MGAM',
#  'MIPEP',
#  'MLF2',
#  'NANOGP2',
#  'NANOGP4',
#  'NANOGP7',
#  'NELL2',
#  'NPPC',
#  'NUDT19',
#  'PAK6',
#  'PDPK1',
#  'PMEPA1',
#  'PMS2CL',
#  'PPIAP10',
#  'PPY',
#  'PRSS8',
#  'PTPN18',
#  'RGPD1',
#  'RGS18',
#  'RHEBP1',
#  'RIN2',
#  'RNASE1',
#  'RNASE12',
#  'RNASE7',
#  'RNASEH1P1',
#  'RSC1A1',
#  'SEC14L3',
#  'SEMA3F-AS1',
#  'SERPINB8',
#  'SMOC2',
#  'SOAT2',
#  'SYCP2',
#  'UGT2B4',
#  'USP21',
#  'USP25'}

# %%
len(common_ag_collisions)
# Out:
# 61
